# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Get all the pillar names from the excel

# %%
ls ../..
# Out:
# README.md
# UNDP Digital Assessment Data Framework Filename Matching V7.xlsx
# dashboard/
# data/
# data_manifest.csv
# data_manifest_instructions.md
# process_manifest.js
# process_raw_data.js
# processed/
# score/
# sources/
# undp-diagram.png

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False   list_of_countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              20         25
# Foundations            9         12
# Government            12         15
# Infrastructure        46         48
# People                38         46
# Regulation             6          7
# Strategy               1          1

# %% [markdown]
# ### Foundations

# %%
bnames = names[(names.check=='Government')&(~names.Filename.isna())]#&(names.Index==False)]

# %%
bnames.head(25)
# Out:
#                                             Indicator       check  \
# 53                         Online-Service-Index (OSI)  Government
# 54                              E-Participation index  Government
# 55  Use of public services online (% of services o...  Government
# 56  What is the % change of government digitizing ...  Government
# 57          Security incidents (# of relevant issues)  Government
# 58              ICT investment as a percentage of GDP  Government
# 59                            R&D spending (% of GDP)  Government
# 60  Evidence of digital strategies in/across Minst...  Government
# 62             Evidence of focus on vulnerable groups  Government
# 65  % of digital skills certifications / training ...  Government
# 66              % of government encrypted web traffic  Government
# 67                 % of country encrypted web traffic  Government
#
#                            Data Source  Index  \
# 53                                DESA   True
# 54                                DESA   True
# 55  Boston Consulting Group/SalesForce  False
# 56                          World Bank  TRUE
# 57                        SPECOPS/CSIS  False
# 58                                OECD  False
# 59                          World Bank  False
# 60                          World Bank  False
# 62                          World Bank  False
# 65                            Coursera  False
# 66                          Cloudflare  False
# 67                          Cloudflare  False
#
#                                 Filename
# 53                    e_government_index
# 54                    e_government_index
# 55            digital_public_service_use
# 56                         Egov_strategy
# 57                         cyber_attacks
# 58                        ICT_Investment
# 59                     RD_Percentage_GDP
# 60                         Egov_strategy
# 62                         Egov_strategy
# 65                   digital_skill_level
# 66                 gov_encrypted_traffic
# 67  %_countries_gov_encrypted_webtraffic

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['e_government_index', 'digital_public_service_use',
#        'Egov_strategy', 'cyber_attacks', 'ICT_Investment',
#        'RD_Percentage_GDP', 'digital_skill_level',
#        'gov_encrypted_traffic', '%_countries_gov_encrypted_webtraffic'],
#       dtype=object)

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %% [markdown]
# ### 1. Digital payments penetration

# %%
indicators[0]
# Out:
# 'Online-Service-Index (OSI)'

# %%
# load data
indicator = indicators[0]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Online-Service-Index (OSI)
# e_government_index

# %%
df.head()
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151

# %%
# all data from 2020
df['Survey Year'].value_counts()
# Out:
# 2020    193
# Name: Survey Year, dtype: int64

# %%
# score looks like the one to use
df.describe()
# Out:
#        Survey Year  E-Government Rank  E-Government Index  \
# count        193.0         193.000000          193.000000
# mean        2020.0          97.000000            0.598767
# std            0.0          55.858452            0.214869
# min         2020.0           1.000000            0.087500
# 25%         2020.0          49.000000            0.432000
# 50%         2020.0          97.000000            0.612900
# 75%         2020.0         145.000000            0.779800
# max         2020.0         193.000000            0.975800
#
#        E-Participation Index  Online Service Index  Human Capital Index  \
# count             193.000000            193.000000           193.000000
# mean                0.567723              0.561961             0.687992
# std                 0.259592              0.249874             0.194440
# min                 0.000000              0.000000             0.000000
# 25%                 0.357100              0.352900             0.559900
# 50%                 0.571400              0.576500             0.739500
# 75%                 0.797600              0.764700             0.841400
# max                 1.000000              1.000000             1.000000
#
#        Telecommunication Infrastructure Index
# count                              193.000000
# mean                                 0.546354
# std                                  0.259358
# min                                  0.000000
# 25%                                  0.349600
# 50%                                  0.566900
# 75%                                  0.772300
# max                                  1.000000

# %%
# df.Indicator.unique()

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Online Service Index'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
# output scores to csv
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].to_csv('../indicator_scores/government_{}_scores.csv'.format(bf), index=False)

# %%
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                          Country Name                   Indicator  data_col  \
# 0                               Iraq   Online-Service-Index (OSI)    0.3353
# 1                            Ireland   Online-Service-Index (OSI)    0.7706
# 2                             Israel   Online-Service-Index (OSI)    0.7471
# 3                              Italy   Online-Service-Index (OSI)    0.8294
# 4                            Jamaica   Online-Service-Index (OSI)    0.3882
# 5                              Japan   Online-Service-Index (OSI)    0.9059
# 6                             Jordan   Online-Service-Index (OSI)    0.3588
# 7                         Kazakhstan   Online-Service-Index (OSI)    0.9235
# 8                              Kenya   Online-Service-Index (OSI)    0.6765
# 9                           Kiribati   Online-Service-Index (OSI)    0.4941
# 10                            Kuwait   Online-Service-Index (OSI)    0.8412
# 11                        Kyrgyzstan   Online-Service-Index (OSI)    0.6471
# 12  Lao People's Democratic Republic   Online-Service-Index (OSI)    0.1941
# 13                            Latvia   Online-Service-Index (OSI)    0.5824
# 14                           Lebanon   Online-Service-Index (OSI)    0.4176
#
#     new_rank_score  higher_is_better
# 0           2.6765              True
# 1           4.8530              True
# 2           4.7355              True
# 3           5.1470              True
# 4           2.9410              True
# 5           5.5295              True
# 6           2.7940              True
# 7           5.6175              True
# 8           4.3825              True
# 9           3.4705              True
# 10          5.2060              True
# 11          4.2355              True
# 12          1.9705              True
# 13          3.9120              True
# 14          3.0880              True

# %% [markdown]
# ## 2. E-Participation index

# %%
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# E-Participation index
# e_government_index

# %%
df.head()
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151

# %%
df['Survey Year'].unique()
# Out:
# array([2020])

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['E-Participation Index'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))


# output scores to csv
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].to_csv('../indicator_scores/government_{}_scores.csv'.format(bf), index=False)

# %% [markdown]
# ## 3. Use of public services online (% of services online, penetration, frequency of use)

# %%
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Use of public services online (% of services online, penetration, frequency of use)
# digital_public_service_use

# %%
# drop first row
df = df.iloc[1: , :]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 1 to 32
# Data columns (total 2 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Net perception that needs are being met by digital services  32 non-null     object
#  1   Unnamed: 1                                                   32 non-null     object
# dtypes: object(2)
# memory usage: 644.0+ bytes

# %%
df.head()
# Out:
#   Net perception that needs are being met by digital services Unnamed: 1
# 1                                           Estonia                  67%
# 2                                               UAE                  61%
# 3                                      Saudi Arabia                  59%
# 4                                          Singapore                 54%
# 5                                             China                  53%

# %%
# clean data to remove % and convert to float
df['Unnamed: 1'] = df['Unnamed: 1'].str.replace('%','')

df['Unnamed: 1'] = df['Unnamed: 1'].astype(float)

# %%
# create the standard columns
df['higher_is_better'] = True
df['Indicator'] =  indicator
df['Country Name'] = df['Net perception that needs are being met by digital services']
# df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
df['data_col'] = df['Unnamed: 1']

# %%
# convert 1-100 %  into 1-6
min_rank = df['data_col'].min()
max_rank = df['data_col'].max()
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

df.sort_values(by='new_rank_score', ascending=False)

# prepare output
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]

# output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(bf), index=False)

# %%
df.describe()
# Out:
#        data_col  new_rank_score
# count  32.00000       32.000000
# mean   33.81250        4.092672
# std    20.85501        1.198564
# min   -20.00000        1.000000
# 25%    21.00000        3.356322
# 50%    39.00000        4.390805
# 75%    49.50000        4.994253
# max    67.00000        6.000000

# %% [markdown]
# ## 4. What is the % change of government digitizing public services?

# %%
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# What is the % change of government digitizing public services?
# Egov_strategy

# %%
df.head()
# Out:
#      198 DG Systems & Services Unnamed: 2 Country Data  \
# 0  Group                     #      GTI-4        Level
# 1      C                     1      -0.12          LIC
# 2      A                     2       0.26         UMIC
# 3      C                     3      -0.15         LMIC
# 4      C                     4      -1.32          HIC
#
#                                   Digital Government UN e-Gov Dev Index  \
# 0                                       e-Government            eGov'20
# 1                      https://mcit.gov.af/node/6938                169
# 2                              https://e-albania.al/                 59
# 3  https://www.mpttn.gov.dz/ar/content/%D8%A7%D9%...                120
# 4                               http://www.govern.ad                 80
#
#               DG Institution DG Strategy Whole of Government GovTech  ...  \
# 0                 DG Org URL       DG St                 WoG      GT  ...
# 1        http://mcit.gov.af/           2                   0       0  ...
# 2       http://akshi.gov.al/           3                   1       1  ...
# 3  https://www.mpttn.gov.dz/           2                   0       0  ...
# 4      http://www.govern.ad/           3                   0       0  ...
#
#   Comparison of weights OECD DG 2019  \
# 0                   GTE        Score
# 1                 0.442            -
# 2                 0.748            -
# 3                 0.281            -
# 4                 0.336            -
#
#   GTMI > Correlation of indicators (without standardization)  \
# 0                                               Code
# 1                                                AFG
# 2                                                ALB
# 3                                                DZA
# 4                                                ADO
#
#   GTI > Factor analysis (without standardization) GTMI Raw Scores >   \
# 0                                            Code               Code
# 1                                             AFG                AFG
# 2                                             ALB                ALB
# 3                                             DZA                DZA
# 4                                             ADO                ADO
#
#   GTMI Standardized Z-Scores>   \
# 0                         Code
# 1                          AFG
# 2                          ALB
# 3                          DZA
# 4                          ADO
#
#   GTC > Correlation analysis with Standardized Scores  \
# 0                                               Code
# 1                                                AFG
# 2                                                ALB
# 3                                                DZA
# 4                                                ADO
#
#   GTF > Factor analysis with Standardized Scores data_country data_year
# 0                                           Code        GTI-4     GTI-4
# 1                                            AFG        -0.12     -0.12
# 2                                            ALB         0.26      0.26
# 3                                            DZA        -0.15     -0.15
# 4                                            ADO        -1.32     -1.32
#
# [5 rows x 123 columns]

# %%
df['GTMI > Correlation of indicators (without standardization)'].unique()
# Out:
# array(['Code', 'AFG', 'ALB', 'DZA', 'ADO', 'AGO', 'ATG', 'ARG', 'ARM',
#        'AUS', 'AUT', 'AZE', 'BHS', 'BHR', 'BGD', 'BRB', 'BLR', 'BEL',
#        'BLZ', 'BEN', 'BTN', 'BOL', 'BIH', 'BWA', 'BRA', 'BRN', 'BGR',
#        'BFA', 'BDI', 'KHM', 'CMR', 'CAN', 'CPV', 'CAF', 'TCD', 'CHL',
#        'CHN', 'COL', 'COM', 'COG', 'ZAR', 'CRI', 'CIV', 'HRV', 'CUB',
#        'CYP', 'CZE', 'DNK', 'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'SLV',
#        'GNQ', 'ERI', 'EST', 'ETH', 'FJI', 'FIN', 'FRA', 'GAB', 'GMB',
#        'GEO', 'DEU', 'GHA', 'GRC', 'GRD', 'GTM', 'GIN', 'GNB', 'GUY',
#        'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN', 'IRN', 'IRQ',
#        'IRL', 'ISR', 'ITA', 'JAM', 'JPN', 'JOR', 'KAZ', 'KEN', 'KIR',
#        'PRK', 'KOR', 'KSV', 'KWT', 'KGZ', 'LAO', 'LVA', 'LBN', 'LSO',
#        'LBR', 'LBY', 'LIE', 'LTU', 'LUX', 'MAC', 'MKD', 'MDG', 'MWI',
#        'MYS', 'MDV', 'MLI', 'MLT', 'MHL', 'MRT', 'MUS', 'MEX', 'FSM',
#        'MDA', 'MCO', 'MNG', 'MNE', 'MAR', 'MOZ', 'MMR', 'NAM', 'NRU',
#        'NPL', 'NLD', 'NZL', 'NIC', 'NER', 'NGA', 'NOR', 'OMN', 'PAK',
#        'PLW', 'PAN', 'PNG', 'PRY', 'PER', 'PHL', 'POL', 'PRT', 'QAT',
#        'ROM', 'RUS', 'RWA', 'KNA', 'LCA', 'VCT', 'WSM', 'SMR', 'STP',
#        'SAU', 'SEN', 'SRB', 'SYC', 'SLE', 'SGP', 'SVK', 'SVN', 'SLB',
#        'SOM', 'ZAF', 'SSD', 'ESP', 'LKA', 'SDN', 'SUR', 'SWZ', 'SWE',
#        'CHE', 'SYR', 'TWN', 'TJK', 'TZA', 'THA', 'TMP', 'TGO', 'TON',
#        'TTO', 'TUN', 'TUR', 'TKM', 'TUV', 'UGA', 'UKR', 'ARE', 'GBR',
#        'USA', 'URY', 'UZB', 'VUT', 'VEN', 'VNM', 'WBG', 'YEM', 'ZMB',
#        'ZWE', nan], dtype=object)

# %%
df[['GovTech Index','data_country','data_year']].head()
# Out:
#   GovTech Index data_country data_year
# 0           GT0        GTI-4     GTI-4
# 1          0.46        -0.12     -0.12
# 2          0.76         0.26      0.26
# 3          0.36        -0.15     -0.15
# 4          0.39        -1.32     -1.32

# %%
df.columns.tolist()
# Out:
# ['198',
#  'DG Systems & Services',
#  'Unnamed: 2',
#  'Country Data',
#  'Digital Government',
#  'UN e-Gov Dev Index',
#  'DG Institution',
#  'DG Strategy',
#  'Whole of Government',
#  'GovTech',
#  'GovTech Products and Services',
#  'Finance Ministry web site, Public Finance data, and FMIS links',
#  'Financial Management Information System',
#  'Treasury Single Account',
#  'Tax Administration',
#  'Customs Administration',
#  'e-Filing',
#  'e-Payment',
#  'Digital Signature',
#  'Public Employment',
#  'HRMIS',
#  'Payroll System',
#  'e-Procurement',
#  'Public Debt',
#  'Public Investment Management Systems',
#  'Aid Mgmt Systems',
#  'Other Categories',
#  'Data Governance Maturity',
#  'Data Governance Institution, Policy & Regulations',
#  'Government Cloud, Enterprise Architecture and Interoperability Platform',
#  ' National CERT or CSIRT',
#  'National website for citizen participation',
#  'National website for citizen feedback / GRM',
#  'Government responsiveness',
#  'Legal System Type',
#  'Data Protection & Privacy Laws',
#  'Data Protection Agency',
#  'Right to Information Law',
#  'WDR Survey Results',
#  'WJP Rule of Law Index',
#  'Freedom in the World (2020)',
#  'Freedom on the Net (2019)',
#  'Is there an Open Government initiative?',
#  'Is there an Open Data portal?',
#  'Disruptive Technologies',
#  'PS Digital Skills & Innovation Strategy',
#  'Digital Skills & Innovation',
#  'PS Digital Skills & Innovation Institution',
#  'Open Source Policies adopted by the governments',
#  'ID4D',
#  'Government Effectiveness',
#  'Control of Corruption',
#  'CPI',
#  'GTMI > Expert opinion for weights',
#  'Core Gov Systems',
#  'Public Services',
#  'Citizen Engage',
#  'GovTech Enablers',
#  'I-1',
#  'I-2',
#  'I-3',
#  'I-4',
#  'I-5',
#  'I-6',
#  'I-7',
#  'I-8',
#  'I-9',
#  'I-10',
#  'I-11',
#  'I-12',
#  'I-13',
#  'I-14',
#  'I-15',
#  'I-16',
#  'I-17',
#  'I-18',
#  'I-19',
#  'I-20',
#  'I-21',
#  'I-22',
#  'I-23',
#  'I-24',
#  'I-25',
#  'I-26',
#  'I-27',
#  'I-28',
#  'I-29',
#  'I-30',
#  'I-31',
#  'I-32',
#  'I-33',
#  'I-34',
#  'I-35',
#  'I-36',
#  'I-37',
#  'I-38',
#  'I-39',
#  'I-40',
#  'I-41',
#  'I-42',
#  'I-43',
#  'I-44',
#  'I-45',
#  'I-46',
#  'I-47',
#  'I-48',
#  'GovTech Index',
#  'Comparison with UN',
#  'No weight',
#  'Comparison with weights',
#  'Standardized',
#  'Comparison with Indicators',
#  'No Weights',
#  'Comparison of weights',
#  'OECD DG 2019',
#  'GTMI > Correlation of indicators (without standardization)',
#  'GTI > Factor analysis (without standardization)',
#  'GTMI Raw Scores > ',
#  'GTMI Standardized Z-Scores> ',
#  'GTC > Correlation analysis with Standardized Scores',
#  'GTF > Factor analysis with Standardized Scores',
#  'data_country',
#  'data_year']

# %%
df[['data_country', 'data_year']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_country  0 non-null      float64
#  1   data_year     0 non-null      float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
# dcol = 'Percentage of total trade in services'
# indicol = 'Category Label'
# cname = 'Economy Label'

# # filter most recent year
# df = df[(df.Year==2019)&(df['Flow Label']=='Exports')]

# # create standard columns
# df['higher_is_better'] = True
# df['Indicator'] =  df[indicol]+' '+ df['Flow Label']
# df['Country Name'] = df[cname]
# # df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
# df['data_col'] = df[dcol]


# # convert 1-100 %  into 1-6
# df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=0,old_max=100))

# df.sort_values(by='new_rank_score', ascending=False)

# # prepare output
# df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]

# # output scores
# df.to_csv('../indicator_scores/{}_scores.csv'.format(bf+'_exports'), index=False)

# %% [markdown]
# ## 5. Security incidents (# of relevant issues)

# %%
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Security incidents (# of relevant issues)
# cyber_attacks

# %%
df['Country Characteristics'].unique()
# Out:
# array(['Region', 'SAS', 'ECS', 'MEA', 'SSF', 'LCN', 'EAS', 'NAC'],
#       dtype=object)

# %%
df.head()
# Out:
#           Country  Number of Significant Cyberattacks (2006-2020)  data_rank
# 0   United States                                             156       20.0
# 1  United Kingdom                                              47       19.0
# 2           India                                              23       18.0
# 3         Germany                                              21       17.0
# 4     South Korea                                              18       16.0

# %%
# create a rank from the number of attacks fields
df['data_rank'] = df['Number of Significant Cyberattacks (2006-2020)'].rank(method='max')

# %%
df.data_rank.max()
# Out:
# 20.0

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['data_rank'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# need to invert since higher rank is not better
df['new_rank_score'] = (6-df['new_rank_score'])+1

# output scores to csv
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].to_csv('../indicator_scores/government_{}_scores.csv'.format(bf), index=False)

# %%
df
# Out:
#       Country Name  Number of Significant Cyberattacks (2006-2020)  data_rank  \
# 0    United States                                             156       20.0
# 1   United Kingdom                                              47       19.0
# 2            India                                              23       18.0
# 3          Germany                                              21       17.0
# 4      South Korea                                              18       16.0
# 5        Australia                                              16       15.0
# 6          Ukraine                                              16       15.0
# 7            China                                              15       13.0
# 8             Iran                                              15       13.0
# 9     Saudi Arabia                                              15       13.0
# 10           Japan                                              13       10.0
# 11          Canada                                              12        9.0
# 12          France                                              11        8.0
# 13          Israel                                              11        8.0
# 14        Pakistan                                               9        6.0
# 15          Russia                                               8        5.0
# 16       Hong Kong                                               7        4.0
# 17         Vietnam                                               6        3.0
# 18          Turkey                                               6        3.0
# 19     North Korea                                               5        1.0
#
#     higher_is_better                                  Indicator  data_col  \
# 0               True  Security incidents (# of relevant issues)      20.0
# 1               True  Security incidents (# of relevant issues)      19.0
# 2               True  Security incidents (# of relevant issues)      18.0
# 3               True  Security incidents (# of relevant issues)      17.0
# 4               True  Security incidents (# of relevant issues)      16.0
# 5               True  Security incidents (# of relevant issues)      15.0
# 6               True  Security incidents (# of relevant issues)      15.0
# 7               True  Security incidents (# of relevant issues)      13.0
# 8               True  Security incidents (# of relevant issues)      13.0
# 9               True  Security incidents (# of relevant issues)      13.0
# 10              True  Security incidents (# of relevant issues)      10.0
# 11              True  Security incidents (# of relevant issues)       9.0
# 12              True  Security incidents (# of relevant issues)       8.0
# 13              True  Security incidents (# of relevant issues)       8.0
# 14              True  Security incidents (# of relevant issues)       6.0
# 15              True  Security incidents (# of relevant issues)       5.0
# 16              True  Security incidents (# of relevant issues)       4.0
# 17              True  Security incidents (# of relevant issues)       3.0
# 18              True  Security incidents (# of relevant issues)       3.0
# 19              True  Security incidents (# of relevant issues)       1.0
#
#     new_rank_score
# 0         1.000000
# 1         1.263158
# 2         1.526316
# 3         1.789474
# 4         2.052632
# 5         2.315789
# 6         2.315789
# 7         2.842105
# 8         2.842105
# 9         2.842105
# 10        3.631579
# 11        3.894737
# 12        4.157895
# 13        4.157895
# 14        4.684211
# 15        4.947368
# 16        5.210526
# 17        5.473684
# 18        5.473684
# 19        6.000000

# %% [markdown]
# ## 6. ICT investment as a percentage of GDP

# %%
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# ICT investment as a percentage of GDP
# ICT_Investment

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    450 non-null    object
#  1   INDICATOR   450 non-null    object
#  2   SUBJECT     450 non-null    object
#  3   MEASURE     450 non-null    object
#  4   FREQUENCY   450 non-null    object
#  5   TIME        450 non-null    int64
#  6   Value       450 non-null    float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.2+ KB

# %%
df.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME      Value  Flag Codes
# 0      AUS  ICTINVST     TOT      PC         A  1985  12.465454         NaN
# 1      AUS  ICTINVST     TOT      PC         A  1986  13.939533         NaN
# 2      AUS  ICTINVST     TOT      PC         A  1987  14.142429         NaN
# 3      AUS  ICTINVST     TOT      PC         A  1988  14.289993         NaN
# 4      AUS  ICTINVST     TOT      PC         A  1989  15.348707         NaN

# %%
df.SUBJECT.unique()
# Out:
# array(['TOT'], dtype=object)

# %%
df.TIME.max()
# Out:
# 2010

# %%
df.Value.describe()
# Out:
# count    450.000000
# mean      16.074272
# std        5.636379
# min        2.798417
# 25%       12.410442
# 50%       14.840726
# 75%       19.419433
# max       32.601105
# Name: Value, dtype: float64

# %%
dcol = 'Value'
indicol = indicator
cname = 'LOCATION'

# filter most recent year
df = df[(df.TIME==2010)]

# create standard columns
df['higher_is_better'] = True
df['Indicator'] =  indicator
df['Country Code'] = df[cname]
# # df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
df['data_col'] = df[dcol]

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# df.sort_values(by='new_rank_score', ascending=False)

# # prepare output
df = df[['Country Code', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]

# # output scores
df.to_csv('../indicator_scores/government{}_scores.csv'.format(bf), index=False)

# %%
df
# Out:
#     Country Code                              Indicator   data_col  \
# 72           CAN  ICT investment as a percentage of GDP  17.018367
# 121          FIN  ICT investment as a percentage of GDP  15.519828
# 172          DEU  ICT investment as a percentage of GDP  12.690394
# 198          IRL  ICT investment as a percentage of GDP  12.412805
# 224          ITA  ICT investment as a percentage of GDP  11.026056
# 274          KOR  ICT investment as a percentage of GDP  10.716026
# 323          NZL  ICT investment as a percentage of GDP  21.238183
# 349          ESP  ICT investment as a percentage of GDP  13.763415
# 400          CHE  ICT investment as a percentage of GDP  18.506691
# 449          USA  ICT investment as a percentage of GDP  32.137836
#
#      new_rank_score  higher_is_better
# 72         2.471010              True
# 121        2.121241              True
# 172        1.460831              True
# 198        1.396040              True
# 224        1.072363              True
# 274        1.000000              True
# 323        3.455945              True
# 349        1.711282              True
# 400        2.818396              True
# 449        6.000000              True

# %% [markdown]
# ## 7. R&D spending (% of GDP)

# %%
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# R&D spending (% of GDP)
# RD_Percentage_GDP
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-101-2b1396f3969f> in <module>
#       4 print(bf)
#       5
# ----> 6 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     704                 encoding=ioargs.encoding,
#     705                 errors=errors,
# --> 706                 newline="",
#     707             )
#     708         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/RD_Percentage_GDP.csv'

# %%
df.head()
# Out:
#   Legal Enablers to ID                          Unnamed: 1  \
# 0                    #  Economic Environment (0-30 points)
# 1                    1                                  16
# 2                    2                                  17
# 3                    3                                  19
# 4                    4                                   8
#
#   Country Characteristics              Legal System Type  \
# 0            Country Code              Legal System Type
# 1                     AFG  civil + customary + religious
# 2                     ALB                          civil
# 3                     DZA              civil + religious
# 4                     AND                          civil
#
#                Foundational Civil Identification Law  \
# 0                                     Key Act / Bill
# 1  Law for Registration of Population Records, Ar...
# 2    Law on ID Cards No. 8952, as amended, Arts. 1-3
# 3  Décret No. 67/126 du 21/07/1967 Portant Instit...
# 4                                                  -
#
#      Data Protection Laws & Privacy Bills Freedom in the World (2018)  \
# 0                          Key Act / Bill                      Status
# 1                                    None                          NF
# 2  Act on the Protection of Personal Data                          PF
# 3                                    None                          NF
# 4  Law on the protection of personal data                           F
#
#   Freedom on the Net (2017) Freedom in the Press (2017)  \
# 0                   Status         Press Freedom Status
# 1                       NaN                          PF
# 2                       NaN                          PF
# 3                       NaN                          NF
# 4                       NaN                           F
#
#                          data_country                           data_year
# 0  Economic Environment (0-30 points)  Economic Environment (0-30 points)
# 1                                  16                                  16
# 2                                  17                                  17
# 3                                  19                                  19
# 4                                   8                                   8

# %%
# min_rank = 1
# max_rank = df['Country Name'].nunique()

# # transform 1-24 rank into 1-6
# df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# # need to invert score since higher rank is not better 
# # df['new_rank_score'] = (6-df['new_rank_score'])+1

# %%
# # prepare output
# df.sort_values(by='new_rank_score', ascending=False)

# # prepare output
# df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]

# # output scores
# df.to_csv('../indicator_scores/{}_scores.csv'.format(bf), index=False)

# %% [markdown]
# ## 8. Evidence of digital strategies in/across Minstries

# %%
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Evidence of digital strategies in/across Minstries
# Egov_strategy

# %%
df.head()
# Out:
#      198 DG Systems & Services Unnamed: 2 Country Data  \
# 0  Group                     #      GTI-4        Level
# 1      C                     1      -0.12          LIC
# 2      A                     2       0.26         UMIC
# 3      C                     3      -0.15         LMIC
# 4      C                     4      -1.32          HIC
#
#                                   Digital Government UN e-Gov Dev Index  \
# 0                                       e-Government            eGov'20
# 1                      https://mcit.gov.af/node/6938                169
# 2                              https://e-albania.al/                 59
# 3  https://www.mpttn.gov.dz/ar/content/%D8%A7%D9%...                120
# 4                               http://www.govern.ad                 80
#
#               DG Institution DG Strategy Whole of Government GovTech  ...  \
# 0                 DG Org URL       DG St                 WoG      GT  ...
# 1        http://mcit.gov.af/           2                   0       0  ...
# 2       http://akshi.gov.al/           3                   1       1  ...
# 3  https://www.mpttn.gov.dz/           2                   0       0  ...
# 4      http://www.govern.ad/           3                   0       0  ...
#
#   Comparison of weights OECD DG 2019  \
# 0                   GTE        Score
# 1                 0.442            -
# 2                 0.748            -
# 3                 0.281            -
# 4                 0.336            -
#
#   GTMI > Correlation of indicators (without standardization)  \
# 0                                               Code
# 1                                                AFG
# 2                                                ALB
# 3                                                DZA
# 4                                                ADO
#
#   GTI > Factor analysis (without standardization) GTMI Raw Scores >   \
# 0                                            Code               Code
# 1                                             AFG                AFG
# 2                                             ALB                ALB
# 3                                             DZA                DZA
# 4                                             ADO                ADO
#
#   GTMI Standardized Z-Scores>   \
# 0                         Code
# 1                          AFG
# 2                          ALB
# 3                          DZA
# 4                          ADO
#
#   GTC > Correlation analysis with Standardized Scores  \
# 0                                               Code
# 1                                                AFG
# 2                                                ALB
# 3                                                DZA
# 4                                                ADO
#
#   GTF > Factor analysis with Standardized Scores data_country data_year
# 0                                           Code        GTI-4     GTI-4
# 1                                            AFG        -0.12     -0.12
# 2                                            ALB         0.26      0.26
# 3                                            DZA        -0.15     -0.15
# 4                                            ADO        -1.32     -1.32
#
# [5 rows x 123 columns]

# %%
# # filter on relevant years
# df = df[(df['Time']==2017)&(df['Information and communication technologies']=='ICT-intensive')]

# # convert rank into 1-6 - in order to get most recent data 
# df['data_col'] = df['Value'] 

# # going to assume index is between 1-100 but not 100% sure
# min_rank = 0 #df['data_col'].min()
# max_rank = 100 #df['data_col'].max()

# # transform 1-147 rank into 1-6
# df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# # need to invert score since higher rank is not better 
# # df['new_rank_score'] = (6-df['new_rank_score'])+1

# # df_rank[['Country ISO3', 'Country Name','Indicator','data_col','new_rank_score']].head()

# df.rename(columns={'Country':'Country Name'}, inplace=True)
# df['Indicator'] = indicator
# df['higher_is_better'] = True

# df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].head(15)


# # output scores to csv
# df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].to_csv('../indicator_scores/{}_scores.csv'.format(bf), index=False)

# %% [markdown]
# ## 9. Evidence of focus on vulnerable groups

# %%
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Evidence of focus on vulnerable groups
# Egov_strategy

# %%
df.head()
# Out:
#      198 DG Systems & Services Unnamed: 2 Country Data  \
# 0  Group                     #      GTI-4        Level
# 1      C                     1      -0.12          LIC
# 2      A                     2       0.26         UMIC
# 3      C                     3      -0.15         LMIC
# 4      C                     4      -1.32          HIC
#
#                                   Digital Government UN e-Gov Dev Index  \
# 0                                       e-Government            eGov'20
# 1                      https://mcit.gov.af/node/6938                169
# 2                              https://e-albania.al/                 59
# 3  https://www.mpttn.gov.dz/ar/content/%D8%A7%D9%...                120
# 4                               http://www.govern.ad                 80
#
#               DG Institution DG Strategy Whole of Government GovTech  ...  \
# 0                 DG Org URL       DG St                 WoG      GT  ...
# 1        http://mcit.gov.af/           2                   0       0  ...
# 2       http://akshi.gov.al/           3                   1       1  ...
# 3  https://www.mpttn.gov.dz/           2                   0       0  ...
# 4      http://www.govern.ad/           3                   0       0  ...
#
#   Comparison of weights OECD DG 2019  \
# 0                   GTE        Score
# 1                 0.442            -
# 2                 0.748            -
# 3                 0.281            -
# 4                 0.336            -
#
#   GTMI > Correlation of indicators (without standardization)  \
# 0                                               Code
# 1                                                AFG
# 2                                                ALB
# 3                                                DZA
# 4                                                ADO
#
#   GTI > Factor analysis (without standardization) GTMI Raw Scores >   \
# 0                                            Code               Code
# 1                                             AFG                AFG
# 2                                             ALB                ALB
# 3                                             DZA                DZA
# 4                                             ADO                ADO
#
#   GTMI Standardized Z-Scores>   \
# 0                         Code
# 1                          AFG
# 2                          ALB
# 3                          DZA
# 4                          ADO
#
#   GTC > Correlation analysis with Standardized Scores  \
# 0                                               Code
# 1                                                AFG
# 2                                                ALB
# 3                                                DZA
# 4                                                ADO
#
#   GTF > Factor analysis with Standardized Scores data_country data_year
# 0                                           Code        GTI-4     GTI-4
# 1                                            AFG        -0.12     -0.12
# 2                                            ALB         0.26      0.26
# 3                                            DZA        -0.15     -0.15
# 4                                            ADO        -1.32     -1.32
#
# [5 rows x 123 columns]

# %% [markdown]
# ## 10. % of digital skills certifications / training courses completed

# %%
indicator = indicators[9]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of digital skills certifications / training courses completed
# digital_skill_level

# %%
df
# Out:
#      Global Rank                           Region Country and Region  \
# 0              1                           Europe        Switzerland
# 1              2                           Europe         Luxembourg
# 2              3                           Europe            Austria
# 3              4                     Asia Pacific              Japan
# 4              5                           Europe            Germany
# ..           ...                              ...                ...
# 103          104                     Asia Pacific         Uzbekistan
# 104          105               Sub-Saharan Africa       Sierra Leone
# 105          106  Latin America and the Caribbean           Paraguay
# 106          107  Latin America and the Caribbean             Guyana
# 107          108               Sub-Saharan Africa            Somalia
#
#     Technology Data Science
# 0          84%          96%
# 1          62%          85%
# 2          88%          95%
# 3         100%          88%
# 4          89%          94%
# ..         ...          ...
# 103         6%           9%
# 104         2%           4%
# 105         7%          11%
# 106         8%           2%
# 107         1%           1%
#
# [108 rows x 5 columns]

# %%
dcol = 'Global Rank'
indicol = indicator
cname = 'Country and Region'

# filter most recent year
# df = df[(df.TIME==2010)]

# create standard columns
df['higher_is_better'] = True
df['Indicator'] =  indicator
df['Country Name'] = df[cname]
# # df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
df['data_col'] = df[dcol]

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# # need to invert score since higher rank is not better 
df['new_rank_score'] = (6-df['new_rank_score'])+1

df.sort_values(by='new_rank_score', ascending=False)

# # prepare output
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]

# # output scores
df.to_csv('../indicator_scores/government{}_scores.csv'.format(bf), index=False)

# %%
df
# Out:
#      Country Name                                          Indicator  \
# 0     Switzerland  % of digital skills certifications / training ...
# 1      Luxembourg  % of digital skills certifications / training ...
# 2         Austria  % of digital skills certifications / training ...
# 3           Japan  % of digital skills certifications / training ...
# 4         Germany  % of digital skills certifications / training ...
# ..            ...                                                ...
# 103    Uzbekistan  % of digital skills certifications / training ...
# 104  Sierra Leone  % of digital skills certifications / training ...
# 105      Paraguay  % of digital skills certifications / training ...
# 106        Guyana  % of digital skills certifications / training ...
# 107       Somalia  % of digital skills certifications / training ...
#
#      data_col  new_rank_score  higher_is_better
# 0           1        6.000000              True
# 1           2        5.953271              True
# 2           3        5.906542              True
# 3           4        5.859813              True
# 4           5        5.813084              True
# ..        ...             ...               ...
# 103       104        1.186916              True
# 104       105        1.140187              True
# 105       106        1.093458              True
# 106       107        1.046729              True
# 107       108        1.000000              True
#
# [108 rows x 5 columns]

# %% [markdown]
# ## 11. % of government encrypted web traffic

# %%
indicator = indicators[10]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of government encrypted web traffic
# gov_encrypted_traffic
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (7,12,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.columns
# Out:
# Index(['0', '1', '2', '3', '7', '29', '31', '53', '66', '82', '132', '164',
#        '1390', '1421927414', '59.166.0.0', '149.171.126.6', 'udp', 'CON',
#        '0.001055', 'dns', '500473.9375', '621800.9375', '0.017', '0.013',
#        'Unnamed: 24'],
#       dtype='object')

# %%
df.head()
# Out:
#    0  1  2  3  7  29  31    53   66  82  ...  149.171.126.6  udp  CON  \
# 0  0  2  4  3  4  29  31  1024  132  76  ...  149.171.126.9  udp  CON
# 1  0  1  2  2  8  29  31    53   73  89  ...  149.171.126.7  udp  CON
# 2  0  1  2  1  9  29  31    53   66  82  ...  149.171.126.5  udp  CON
# 3  0  1  2  1  9  29  31    53   73  89  ...  149.171.126.0  udp  CON
# 4  0  2  4  3  4  29  31   111  142  78  ...  149.171.126.9  udp  CON
#
#    0.001055  dns   500473.9375   621800.9375   0.017      0.013 Unnamed: 24
# 0  0.036133    -   87676.08594   50480.17188   7.005   7.564333         NaN
# 1  0.001119  dns  521894.53130  636282.37500   0.017   0.013000         NaN
# 2  0.001209  dns  436724.56250  542597.18750   0.043   0.014000         NaN
# 3  0.001169  dns  499572.25000  609067.56250   0.005   0.003000         NaN
# 4  0.078339    -   43503.23438   23896.14258  21.003  24.315000         NaN
#
# [5 rows x 25 columns]

# %%
bnames
# Out:
#                                             Indicator       check  \
# 53                         Online-Service-Index (OSI)  Government
# 54                              E-Participation index  Government
# 55  Use of public services online (% of services o...  Government
# 56  What is the % change of government digitizing ...  Government
# 57          Security incidents (# of relevant issues)  Government
# 58              ICT investment as a percentage of GDP  Government
# 59                            R&D spending (% of GDP)  Government
# 60  Evidence of digital strategies in/across Minst...  Government
# 62             Evidence of focus on vulnerable groups  Government
# 65  % of digital skills certifications / training ...  Government
# 66              % of government encrypted web traffic  Government
# 67                 % of country encrypted web traffic  Government
#
#                            Data Source  Index  \
# 53                                DESA   True
# 54                                DESA   True
# 55  Boston Consulting Group/SalesForce  False
# 56                          World Bank  TRUE
# 57                        SPECOPS/CSIS  False
# 58                                OECD  False
# 59                          World Bank  False
# 60                          World Bank  False
# 62                          World Bank  False
# 65                            Coursera  False
# 66                          Cloudflare  False
# 67                          Cloudflare  False
#
#                                 Filename
# 53                    e_government_index
# 54                    e_government_index
# 55            digital_public_service_use
# 56                         Egov_strategy
# 57                         cyber_attacks
# 58                        ICT_Investment
# 59                     RD_Percentage_GDP
# 60                         Egov_strategy
# 62                         Egov_strategy
# 65                   digital_skill_level
# 66                 gov_encrypted_traffic
# 67  %_countries_gov_encrypted_webtraffic

# %% [markdown]
# ## 12. % of country encrypted web traffic

# %%
indicator = indicators[11]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of country encrypted web traffic
# %_countries_gov_encrypted_webtraffic
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-119-549290ccdddc> in <module>
#       4 print(bf)
#       5
# ----> 6 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /anaconda3/envs/deepenv/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     704                 encoding=ioargs.encoding,
#     705                 errors=errors,
# --> 706                 newline="",
#     707             )
#     708         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/%_countries_gov_encrypted_webtraffic.csv'

# %% [markdown]
# ### Score Aggregating

# %%
import os

# %%
# get list of files in scores folder
scores = os.listdir('../indicator_scores/')
scores = [s for s in scores if s.startswith('government')]

# %%
scores
# Out:
# ['government_cyber_attacks_scores.csv',
#  'government_digital_public_service_use_scores.csv',
#  'government_e_government_index_scores.csv',
#  'governmentdigital_skill_level_scores.csv',
#  'governmentICT_Investment_scores.csv']

# %%
# create a dataframe that concatenates all these file into one table
df = pd.concat([pd.read_csv('../indicator_scores/{}'.format(s)) for s in scores])

# %%
df
# Out:
#       Country Name                                  Indicator   data_col  \
# 0    United States  Security incidents (# of relevant issues)  20.000000
# 1   United Kingdom  Security incidents (# of relevant issues)  19.000000
# 2            India  Security incidents (# of relevant issues)  18.000000
# 3          Germany  Security incidents (# of relevant issues)  17.000000
# 4      South Korea  Security incidents (# of relevant issues)  16.000000
# ..             ...                                        ...        ...
# 5              NaN      ICT investment as a percentage of GDP  10.716026
# 6              NaN      ICT investment as a percentage of GDP  21.238183
# 7              NaN      ICT investment as a percentage of GDP  13.763415
# 8              NaN      ICT investment as a percentage of GDP  18.506691
# 9              NaN      ICT investment as a percentage of GDP  32.137836
#
#     new_rank_score  higher_is_better Country Code
# 0         1.000000              True          NaN
# 1         1.263158              True          NaN
# 2         1.526316              True          NaN
# 3         1.789474              True          NaN
# 4         2.052632              True          NaN
# ..             ...               ...          ...
# 5         1.000000              True          KOR
# 6         3.455945              True          NZL
# 7         1.711282              True          ESP
# 8         2.818396              True          CHE
# 9         6.000000              True          USA
#
# [363 rows x 6 columns]

# %%
# Data cleaning
df['new_rank_score'] = df['new_rank_score'].fillna(0)
df.sort_values(by=['Country Name'], ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 363 entries, 0 to 362
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country Name      353 non-null    object
#  1   Indicator         363 non-null    object
#  2   data_col          363 non-null    float64
#  3   new_rank_score    363 non-null    float64
#  4   higher_is_better  363 non-null    bool
#  5   Country Code      10 non-null     object
# dtypes: bool(1), float64(2), object(3)
# memory usage: 14.7+ KB

# %%
df.head(15)
# Out:
#             Country Name                                          Indicator  \
# 0            Afghanistan                              E-Participation index
# 1               Albania                               E-Participation index
# 2                Algeria  % of digital skills certifications / training ...
# 3               Algeria                               E-Participation index
# 4               Andorra                               E-Participation index
# 5                Angola                               E-Participation index
# 6   Antigua and Barbuda                               E-Participation index
# 7              Argentina  % of digital skills certifications / training ...
# 8             Argentina   Use of public services online (% of services o...
# 9             Argentina                               E-Participation index
# 10               Armenia  % of digital skills certifications / training ...
# 11              Armenia                               E-Participation index
# 12             Australia  % of digital skills certifications / training ...
# 13             Australia          Security incidents (# of relevant issues)
# 14             Australia  Use of public services online (% of services o...
#
#     data_col  new_rank_score  higher_is_better Country Code
# 0     0.4643        3.321500              True          NaN
# 1     0.8452        5.226000              True          NaN
# 2    95.0000        1.607477              True          NaN
# 3     0.1548        1.774000              True          NaN
# 4     0.5119        3.559500              True          NaN
# 5     0.4524        3.262000              True          NaN
# 6     0.4881        3.440500              True          NaN
# 7    82.0000        2.214953              True          NaN
# 8    15.0000        3.011494              True          NaN
# 9     0.8571        5.285500              True          NaN
# 10   57.0000        3.383178              True          NaN
# 11    0.7500        4.750000              True          NaN
# 12   44.0000        3.990654              True          NaN
# 13   15.0000        2.315789              True          NaN
# 14   40.0000        4.448276              True          NaN

# %%
df.describe()
# Out:
#          data_col  new_rank_score
# count  363.000000      363.000000
# mean    20.547108        3.696272
# std     30.134795        1.386564
# min    -20.000000        1.000000
# 25%      0.517850        2.621257
# 50%      0.952400        3.710280
# 75%     34.500000        4.873752
# max    108.000000        6.000000

# %%
# checking country names
# sorted(df['Country Name'].unique().tolist())

# %%
# remove trailing whitespaces from country name
df['Country Name'] = df['Country Name'].str.strip()

# %%
df.head()
# Out:
#   Country Name                                          Indicator  data_col  \
# 0  Afghanistan                              E-Participation index    0.4643
# 1      Albania                              E-Participation index    0.8452
# 2      Algeria  % of digital skills certifications / training ...   95.0000
# 3      Algeria                              E-Participation index    0.1548
# 4      Andorra                              E-Participation index    0.5119
#
#    new_rank_score  higher_is_better Country Code
# 0        3.321500              True          NaN
# 1        5.226000              True          NaN
# 2        1.607477              True          NaN
# 3        1.774000              True          NaN
# 4        3.559500              True          NaN

# %%
# checking country names
sorted(df['Country Name'].unique().tolist())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-7e691ba93d02> in <module>
#       1 # checking country names
# ----> 2 sorted(df['Country Name'].unique().tolist())
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
# average indicator scores per country
agg_df = df.groupby(['Country Name']).agg({'new_rank_score':'mean','data_col':'count'})

# %%
agg_df.columns = ['agg_score', 'count_source' ]

# %%
max_number_sources = agg_df.describe()['count_source']['max']

# %%
agg_df['agg_score_wt'] = agg_df['agg_score']*(agg_df['count_source']/max_number_sources)

# %%
agg_df.sort_values(by='agg_score', ascending=False, inplace=True)

# %%
agg_df.head(25)
# Out:
#                       agg_score  count_source  agg_score_wt
# Country Name
# Norway                   6.0000             1        6.0000
# Denmark                  5.8620             1        5.8620
# Finland                  5.6975             1        5.6975
# Sweden                   5.6540             1        5.6540
# Netherlands              5.4505             1        5.4505
# New Zealand              5.3365             1        5.3365
# United States            5.2200             1        5.2200
# Estonia                  5.1410             1        5.1410
# Korea, Rep.              5.1320             1        5.1320
# Canada                   5.0765             1        5.0765
# Australia                4.9685             1        4.9685
# Czech Republic           4.7825             1        4.7825
# Belgium                  4.6575             1        4.6575
# Germany                  4.5600             1        4.5600
# Poland                   4.5170             1        4.5170
# Latvia                   4.4680             1        4.4680
# Luxembourg               4.3280             1        4.3280
# Kenya                    4.3175             1        4.3175
# Switzerland              4.3115             1        4.3115
# Lithuania                4.0325             1        4.0325
# France                   4.0310             1        4.0310
# Austria                  3.9945             1        3.9945
# United Arab Emirates     3.9580             1        3.9580
# Slovakia                 3.9470             1        3.9470
# Israel                   3.9245             1        3.9245

# %%
agg_df.to_csv('../pillar_scores/foundation_scores_v0.csv')
