# %%
import pandas as pd
import numpy as np
import os 
import re

# %%
### Score Aggregating by Subpillars

# %%
# get list of files in scores folder
scores = os.listdir('../subpillar_score/')
scores

df = pd.concat([pd.read_csv('../subpillar_score/{}'.format(s)) for s in scores])

# %%
#Drop all the 0 value in source
df = df[df['count_source'] != 0]

# %%
df['Country Name'] = df['Country Name'].str.strip()
df['Country Name'] = df['Country Name'].str.strip('**')
df['Country Name'] = df['Country Name'].str.strip('*')
df['Country Name'] = df['Country Name'].str.strip('*')
df['Country Name'] = df['Country Name'].replace('-',np.nan)
df['Country Name'] = df['Country Name'].replace('0.03',np.nan)
df = df.dropna()

# %%
# Normalize country names as much as possible

df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bahamas.*$)', 'Bahamas (the)')
df['Country Name'] = df['Country Name'].replace('Bahrain (Kingdom of)','Bahrain')
df['Country Name'] = df['Country Name'].replace('Bolivia','Bolivia (Plurinational State of)')
df['Country Name'] = df['Country Name'].replace('Bolivia, Plurinational State of','Bolivia (Plurinational State of)')
df['Country Name'] = df['Country Name'].replace('Brunei','Brunei Darussalam')
df['Country Name'] = df['Country Name'].replace('Bulgaria (Rep.)','Bulgaria')
df['Country Name'] = df['Country Name'].replace('Central African Republic','Central African Republic (the)')
df['Country Name'] = df['Country Name'].replace('Central African Rep.','Central African Republic (the)')
df['Country Name'] = df['Country Name'].replace("China (People's Rep.)",'China')
df['Country Name'] = df['Country Name'].replace("Comoros",'Comoros (the)')
df['Country Name'] = df['Country Name'].replace("Congo",'Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo (Brazzaville)",'Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo (Rep. of the)",'Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo (Democratic Republic of the)",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo, Dem. Rep.",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo, The Democratic Republic of the",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("DR Congo",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Democratic Republic of Congo",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Democratic Republic of the Congo",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Dem. Rep. of the Congo",'Democratic Republic of the Congo (the)')



df['Country Name'] = df['Country Name'].replace("Cote d'Ivoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Côte d’Ivoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Cote dIvoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].str.replace(r"(^.*Côte d'Ivoire.*$)", "Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Cōte d'Ivoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Ivory Coast","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Dem. People's Rep. of Korea","Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].replace("Democratic People's Republic of Korea","Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].replace("Korea, Dem. People's Rep.","Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].replace("North Korea","Democratic People's Republic of Korea (the)")

df['Country Name'] = df['Country Name'].str.replace(r'(^.*Czech.*$)', 'Czechia')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Dominican Re.*$)', 'Dominican Republic (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hong Kong.*$)', 'China, Hong Kong Special Administrative Region')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hongkong.*$)', 'China, Hong Kong Special Administrative Region')
df['Country Name'] = df['Country Name'].replace("Eswatini (Kingdom of)",'Eswatini')
df['Country Name'] = df['Country Name'].replace("Swaziland",'Eswatini')
df['Country Name'] = df['Country Name'].replace("Faröe Islands",'Faroe Islands')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Gambia.*$)', 'Gambia (the)')
df['Country Name'] = df['Country Name'].replace("Georgia (Country)",'Georgia')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Iran.*$)', 'Iran (Islamic Republic of)')
df['Country Name'] = df['Country Name'].replace("Korea",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea (Rep. of)",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea (Rep.)",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea (Republic of)",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Korea, Rep.*$)', 'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea, South",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("South Korea",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Republic of Korea",'Republic of Korea (the)')

df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kyrgyz.*$)', 'Kyrgyzstan')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lao.*$)', "Lao People's Democratic Republic (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macao.*$)', "China, Macao Special Administrative Region")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macau.*$)', "China, Macao Special Administrative Region")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Micronesia.*$)', "Micronesia (Federated States of)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Moldova.*$)', "Republic of Moldova (the)")
df['Country Name'] = df['Country Name'].replace("Morroco",'Morocco')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Nepal.*$)', "Nepal")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
df['Country Name'] = df['Country Name'].replace("Niger",'Niger (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macedonia.*$)', "North Macedonia")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Palestin.*$)', "State of Palestine (the)")
df['Country Name'] = df['Country Name'].replace("West Bank and Gaza",'State of Palestine (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Panama.*$)', "Panama")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Philippines.*$)', "Philippines (the)")
df['Country Name'] = df['Country Name'].replace("Republic of the Congo",'Congo (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Myanmar.*$)', "Myanmar")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Puerto Rico.*$)', "Puerto Rico")
df['Country Name'] = df['Country Name'].replace("Russia",'Russian Federation (the)')
df['Country Name'] = df['Country Name'].replace("Russian Federation",'Russian Federation (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Slovak.*$)', "Slovakia")
df['Country Name'] = df['Country Name'].str.replace(r'\bSudan\b', 'Sudan (the)')
df['Country Name'] = df['Country Name'].str.replace(r'\bSudan (the)\b', 'Sudan (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*South Sudan.*$)', "South Sudan")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Syria.*$)', "Syrian Arab Republic (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*São Tomé.*$)', "Sao Tome and Principe")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taiwan.*$)', "Taiwan")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taipei.*$)', "Taiwan")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Tanzania.*$)', "United Republic of Tanzania (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Netherlands.*$)', "Netherlands (the)")

df['Country Name'] = df['Country Name'].replace("UAE",'United Arab Emirates (the)')
df['Country Name'] = df['Country Name'].replace("U.A.E",'United Arab Emirates (the)')
df['Country Name'] = df['Country Name'].replace("United Arab Emirates",'United Arab Emirates (the)')
df['Country Name'] = df['Country Name'].replace('United Kingdom','United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace('UK','United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace("Great Britain",'United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace("United Kingdom of Great Britain and Northern Ireland",'United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace('Vietnam','Viet Nam')
df['Country Name'] = df['Country Name'].replace('United States','United States of America (the)')
df['Country Name'] = df['Country Name'].replace('USA','United States of America (the)')
df['Country Name'] = df['Country Name'].replace('United States of America','United States of America (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Virgin Islands.*$)', "United States Virgin Islands")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vatican.*$)', "Vatican")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Venezuela.*$)', "Venezuela (Bolivarian Republic of)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Yemen.*$)', "Yemen")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Arab world.*$)', "Arab World")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*World.*$)', "World")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kitts and Nevis.*$)', "Saint Kitts and Nevis")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lucia.*$)', "Saint Lucia")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Martin (French Part).*$)', "Saint Martin (French Part)")
df['Country Name'] = df['Country Name'].replace('Sint Maarten','Saint Martin')
df['Country Name'] = df['Country Name'].replace('St. Martin (French part)','Saint Martin (French Part)')
df['Country Name'] = df['Country Name'].replace('Sint Maarten (Dutch part)','Saint Martin (Dutch Part)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vincent and the Grenadines.*$)', "Saint Vincent and the Grenadines")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Verde.*$)', "Cabo Verde")
df['Country Name'] = df['Country Name'].replace('Congo, Democratic Republic','Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace('Congo, Rep.','Congo (the)')
df['Country Name'] = df['Country Name'].replace('Congo (Rep.)','Congo (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Egypt.*$)', "Egypt")

df['Country Name'] = df['Country Name'].str.replace(r'(^.*Korea, D.*$)', "Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Tobago.*$)', "Trinidad and Tobago")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Timor-Leste.*$)', "Timor-Leste")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Emirates.*$)', "United Arab Emirates (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Papua.*$)', "Papua New Guinea")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bissau.*$)', "Guinea-Bissau")
df['Country Name'] = df['Country Name'].replace('Eq. Guinea','Equatorial Guinea')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Burma.*$)', "Myanmar")
df['Country Name'] = df['Country Name'].replace('C.A. Republic','Central African Republic (the)')
df['Country Name'] = df['Country Name'].replace('Ant.& Barb.','Antigua and Barbuda')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bosnia.*$)', "Bosnia and Herzegovina")
df['Country Name'] = df['Country Name'].replace('Domin. Rep.','Dominican Republic (the)')
df['Country Name'] = df['Country Name'].replace('Dominica (Commonwealth of)','Dominica')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*European Union.*$)', "European Union")
df['Country Name'] = df['Country Name'].replace('R. of Congo','Congo (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Principe.*$)', "Sao Tome and Principe")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Solomon.*$)', "Solomon Islands")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vincent.*$)', "Saint Vincent and the Grenadines")
df['Country Name'] = df['Country Name'].replace('Curacao','Curaçao')
df['Country Name'] = df['Country Name'].replace('Reunion','Réunion')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kosovo.*$)', "Kosovo (UNSCR 1244)")
# Out:
# <ipython-input-6-13bd33f99da3>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bahamas.*$)', 'Bahamas (the)')
# <ipython-input-6-13bd33f99da3>:29: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r"(^.*Côte d'Ivoire.*$)", "Côte d'Ivoire")
# <ipython-input-6-13bd33f99da3>:37: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Czech.*$)', 'Czechia')
# <ipython-input-6-13bd33f99da3>:38: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Dominican Re.*$)', 'Dominican Republic (the)')
# <ipython-input-6-13bd33f99da3>:39: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hong Kong.*$)', 'China, Hong Kong Special Administrative Region')
# <ipython-input-6-13bd33f99da3>:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hongkong.*$)', 'China, Hong Kong Special Administrative Region')
# <ipython-input-6-13bd33f99da3>:44: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Gambia.*$)', 'Gambia (the)')
# <ipython-input-6-13bd33f99da3>:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Iran.*$)', 'Iran (Islamic Republic of)')
# <ipython-input-6-13bd33f99da3>:51: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Korea, Rep.*$)', 'Republic of Korea (the)')
# <ipython-input-6-13bd33f99da3>:56: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kyrgyz.*$)', 'Kyrgyzstan')
# <ipython-input-6-13bd33f99da3>:57: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lao.*$)', "Lao People's Democratic Republic (the)")
# <ipython-input-6-13bd33f99da3>:58: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macao.*$)', "China, Macao Special Administrative Region")
# <ipython-input-6-13bd33f99da3>:59: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macau.*$)', "China, Macao Special Administrative Region")
# <ipython-input-6-13bd33f99da3>:60: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Micronesia.*$)', "Micronesia (Federated States of)")
# <ipython-input-6-13bd33f99da3>:61: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Moldova.*$)', "Republic of Moldova (the)")
# <ipython-input-6-13bd33f99da3>:63: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Nepal.*$)', "Nepal")
# <ipython-input-6-13bd33f99da3>:64: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
# <ipython-input-6-13bd33f99da3>:66: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macedonia.*$)', "North Macedonia")
# <ipython-input-6-13bd33f99da3>:67: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
# <ipython-input-6-13bd33f99da3>:68: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Palestin.*$)', "State of Palestine (the)")
# <ipython-input-6-13bd33f99da3>:70: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Panama.*$)', "Panama")
# <ipython-input-6-13bd33f99da3>:71: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Philippines.*$)', "Philippines (the)")
# <ipython-input-6-13bd33f99da3>:73: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Myanmar.*$)', "Myanmar")
# <ipython-input-6-13bd33f99da3>:74: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Puerto Rico.*$)', "Puerto Rico")
# <ipython-input-6-13bd33f99da3>:77: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Slovak.*$)', "Slovakia")
# <ipython-input-6-13bd33f99da3>:78: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'\bSudan\b', 'Sudan (the)')
# <ipython-input-6-13bd33f99da3>:79: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'\bSudan (the)\b', 'Sudan (the)')
# <ipython-input-6-13bd33f99da3>:80: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*South Sudan.*$)', "South Sudan")
# <ipython-input-6-13bd33f99da3>:81: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Syria.*$)', "Syrian Arab Republic (the)")
# <ipython-input-6-13bd33f99da3>:82: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*São Tomé.*$)', "Sao Tome and Principe")
# <ipython-input-6-13bd33f99da3>:83: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taiwan.*$)', "Taiwan")
# <ipython-input-6-13bd33f99da3>:84: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taipei.*$)', "Taiwan")
# <ipython-input-6-13bd33f99da3>:85: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Tanzania.*$)', "United Republic of Tanzania (the)")
# <ipython-input-6-13bd33f99da3>:86: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Netherlands.*$)', "Netherlands (the)")
# <ipython-input-6-13bd33f99da3>:99: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Virgin Islands.*$)', "United States Virgin Islands")
# <ipython-input-6-13bd33f99da3>:100: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vatican.*$)', "Vatican")
# <ipython-input-6-13bd33f99da3>:101: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Venezuela.*$)', "Venezuela (Bolivarian Republic of)")
# <ipython-input-6-13bd33f99da3>:102: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Yemen.*$)', "Yemen")
# <ipython-input-6-13bd33f99da3>:103: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Arab world.*$)', "Arab World")
# <ipython-input-6-13bd33f99da3>:104: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*World.*$)', "World")
# <ipython-input-6-13bd33f99da3>:105: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kitts and Nevis.*$)', "Saint Kitts and Nevis")
# <ipython-input-6-13bd33f99da3>:106: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lucia.*$)', "Saint Lucia")
# <ipython-input-6-13bd33f99da3>:107: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Martin (French Part).*$)', "Saint Martin (French Part)")
# <ipython-input-6-13bd33f99da3>:111: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vincent and the Grenadines.*$)', "Saint Vincent and the Grenadines")
# <ipython-input-6-13bd33f99da3>:112: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Verde.*$)', "Cabo Verde")
# <ipython-input-6-13bd33f99da3>:116: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Egypt.*$)', "Egypt")
# <ipython-input-6-13bd33f99da3>:118: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Korea, D.*$)', "Democratic People's Republic of Korea (the)")
# <ipython-input-6-13bd33f99da3>:119: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Tobago.*$)', "Trinidad and Tobago")
# <ipython-input-6-13bd33f99da3>:120: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Timor-Leste.*$)', "Timor-Leste")
# <ipython-input-6-13bd33f99da3>:121: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Emirates.*$)', "United Arab Emirates (the)")
# <ipython-input-6-13bd33f99da3>:122: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Papua.*$)', "Papua New Guinea")
# <ipython-input-6-13bd33f99da3>:123: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bissau.*$)', "Guinea-Bissau")
# <ipython-input-6-13bd33f99da3>:125: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Burma.*$)', "Myanmar")
# <ipython-input-6-13bd33f99da3>:128: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bosnia.*$)', "Bosnia and Herzegovina")
# <ipython-input-6-13bd33f99da3>:131: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*European Union.*$)', "European Union")
# <ipython-input-6-13bd33f99da3>:133: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Principe.*$)', "Sao Tome and Principe")
# <ipython-input-6-13bd33f99da3>:134: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Solomon.*$)', "Solomon Islands")
# <ipython-input-6-13bd33f99da3>:135: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vincent.*$)', "Saint Vincent and the Grenadines")
# <ipython-input-6-13bd33f99da3>:138: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kosovo.*$)', "Kosovo (UNSCR 1244)")

# %%
#to_drop = ['Africa','Africa Eastern and Southern','Africa Western and Central']
#df = df[~df['Country Name'].isin(to_drop)]

# %%
sorted(df['Country Name'].unique().tolist())
# Out:
# ['Afghanistan',
#  'Africa',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas (the)',
#  'Bahrain',
#  'Bangladesh',
#  'Bangladesh Chittagong',
#  'Bangladesh Dhaka',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belgium Estonia',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia (Plurinational State of)',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brazil Rio de Janeiro',
#  'Brazil São Paulo',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic (the)',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'China Beijing',
#  'China Shanghai',
#  'China, Hong Kong Special Administrative Region',
#  'China, Macao Special Administrative Region',
#  'Colombia',
#  'Comoros (the)',
#  'Congo (the)',
#  'Cook Islands',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czechia',
#  "Côte d'Ivoire",
#  "Democratic People's Republic of Korea (the)",
#  'Democratic Republic of the Congo (the)',
#  'Denmark',
#  'Developing',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic (the)',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'East Asia & Pacific (excluding high income)',
#  'East and South Asia',
#  'Eastern Europe and Central Asia',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Euro area',
#  'Europe',
#  'Europe & Central Asia',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Europe & Central Asia (excluding high income)',
#  'European Union',
#  'Falkland Islands',
#  'Faroe Islands',
#  'Fiji',
#  'Finland',
#  'Fragile and conflict affected situations',
#  'France',
#  'French Guiana',
#  'French Polynesia',
#  'Gabon',
#  'Gambia (the)',
#  'Georgia',
#  'Germany',
#  'Germany France',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'High income: OECD',
#  'High-income Countries',
#  'Honduras',
#  'Hungary',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA blend',
#  'IDA only',
#  'IDA total',
#  'Iceland',
#  'India',
#  'India Delhi',
#  'India Mumbai',
#  'Indonesia',
#  'Indonesia Jakarta',
#  'Indonesia Surabaya',
#  'Iran (Islamic Republic of)',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Japan Osaka',
#  'Japan Tokyo',
#  'Jersey',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo (UNSCR 1244)',
#  'Kuwait',
#  'Kyrgyzstan',
#  "Lao People's Democratic Republic (the)",
#  'Late-demographic dividend',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean (excluding high income)',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Latin America and the Caribbean',
#  'Latvia',
#  'Least developed countries: UN classification',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Low & middle income',
#  'Low income',
#  'Low-income Countries',
#  'Lower middle income',
#  'Lower-middle-income Countries',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Martinique',
#  'Mauritania',
#  'Mauritius',
#  'Mayotte',
#  'Mexico',
#  'Mexico Mexico City',
#  'Mexico Monterrey',
#  'Micronesia (Federated States of)',
#  'Middle East & North Africa',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Middle East & North Africa (excluding high income)',
#  'Middle East and North Africa',
#  'Middle income',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands (the)',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger (the)',
#  'Nigeria',
#  'Nigeria Kano',
#  'Nigeria Lagos',
#  'Niue',
#  'North America',
#  'North Cyprus',
#  'North Macedonia',
#  'Northern Ireland',
#  'Northern Mariana Islands',
#  'Norway',
#  'OECD members',
#  'Oceania',
#  'Oman',
#  'Other small states',
#  'Pacific island small states',
#  'Pakistan',
#  'Pakistan Karachi',
#  'Pakistan Lahore',
#  'Palau',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines (the)',
#  'Poland',
#  'Portugal',
#  'Post-demographic dividend',
#  'Pre-demographic dividend',
#  'Puerto Rico',
#  'Qatar',
#  'Republic of Korea (the)',
#  'Republic of Moldova (the)',
#  'Romania',
#  'Russian Federation (the)',
#  'Russian Federation Moscow',
#  'Russian Federation Saint Petersburg',
#  'Rwanda',
#  'Réunion',
#  'Saint Helena',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Martin',
#  'Saint Martin (Dutch Part)',
#  'Saint Martin (French Part)',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Small Island Developing States',
#  'Small states',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Asia',
#  'South Asia (IDA & IBRD)',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'State of Palestine (the)',
#  'Sub-Saharan Africa',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sudan (the)',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Republic (the)',
#  'Taiwan',
#  'Tajikistan',
#  'Thailand',
#  'Timor-Leste',
#  'Togo',
#  'Tokelau',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates (the)',
#  'United Kingdom of Great Britain and Northern Ireland (the)',
#  'United Republic of Tanzania (the)',
#  'United States Los Angeles',
#  'United States New York City',
#  'United States Virgin Islands',
#  'United States of America (the)',
#  'Upper middle income',
#  'Upper-middle-income Countries',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vatican',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam',
#  'Wallis and Futuna',
#  'Western Sahara',
#  'World',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
df.head(15)
# Out:
#       Pillar            Sub-Pillar                      Country Name  \
# 0   Business  Financing Incentives                           Albania
# 1   Business  Financing Incentives                           Algeria
# 2   Business  Financing Incentives                            Angola
# 3   Business  Financing Incentives                         Argentina
# 4   Business  Financing Incentives                           Armenia
# 5   Business  Financing Incentives                         Australia
# 6   Business  Financing Incentives                           Austria
# 7   Business  Financing Incentives                        Azerbaijan
# 8   Business  Financing Incentives                           Bahrain
# 9   Business  Financing Incentives                        Bangladesh
# 10  Business  Financing Incentives                          Barbados
# 11  Business  Financing Incentives                           Belgium
# 13  Business  Financing Incentives                             Benin
# 15  Business  Financing Incentives  Bolivia (Plurinational State of)
# 16  Business  Financing Incentives            Bosnia and Herzegovina
#
#     agg_score  count_source  agg_score_wt
# 0    2.675049             1      0.297228
# 1    3.066379             1      0.340709
# 2    1.586939             1      0.176327
# 3    2.104625             1      0.233847
# 4    2.922058             1      0.324673
# 5    3.111601             1      0.345733
# 6    3.254124             1      0.361569
# 7    3.592510             1      0.399168
# 8    3.675231             1      0.408359
# 9    2.266366             1      0.251818
# 10   1.848639             1      0.205404
# 11   3.336294             1      0.370699
# 13   1.958136             1      0.217571
# 15   2.324981             1      0.258331
# 16   2.114815             1      0.234979

# %%
#df.to_csv('../country_scores/List.csv',index = False)

# %%
# Produce full list of pillars and sub-pillars
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')
full_list = names[['check','Sub-Pillar']]
full_list = full_list.drop_duplicates('Sub-Pillar').dropna().reset_index()
full_list = full_list[['check','Sub-Pillar']]
full_list.rename(columns={'check':'Pillar'}, inplace=True)
full_list
# Out:
#             Pillar                     Sub-Pillar
# 0   Infrastructure        Connectivity Technology
# 1   Infrastructure           Innovation Ecosystem
# 2       Government        Digital Public Services
# 3       Government        Funding and procurement
# 4       Government    Leadership and coordination
# 5       Government                     Monitoring
# 6       Government                   Capabilities
# 7       Regulation  Data standards and protection
# 8       Regulation              Ethical Standards
# 9       Regulation                  Cybersecurity
# 10        Business            Technology Adoption
# 11        Business           Financing Incentives
# 12        Business            Startup Environment
# 13        Business             Impact commitments
# 14          People        Digital Literacy Skills
# 15          People            Usage and ownership
# 16          People                        Culture
# 17          People              Digital Wellbeing
# 18        Strategy                       Ambition
# 19     Foundations               Digital Payments
# 20     Foundations         Digital Legal Identity
# 21     Foundations                  Data Exchange

# %%
# Master data to be used

# %%
# List of countries
country = df[['Country Name']]
# Combine list of country with full list of pillars so that even those without data in those pillars still have them
# Use cross join to do this
result = country.merge(full_list,how = "cross")
result
#Perform a left join with df
combined = result.merge(df,how="left",on = ['Country Name', 'Pillar','Sub-Pillar'])

combined.to_csv('../country_scores/All.csv',index = False)

# %%
### Average Scores by Pillars and Subpillars

# %%
df = pd.read_csv('../country_scores/All.csv')
df.rename(columns = {'agg_score': 'Score'}, inplace = True)
df = df[['Country Name','Pillar','Sub-Pillar','Score','count_source']]
df
# Out:
#                          Country Name          Pillar  \
# 0                             Albania  Infrastructure
# 1                             Albania  Infrastructure
# 2                             Albania      Government
# 3                             Albania      Government
# 4                             Albania      Government
# ...                               ...             ...
# 77016  Central African Republic (the)          People
# 77017  Central African Republic (the)        Strategy
# 77018  Central African Republic (the)     Foundations
# 77019  Central African Republic (the)     Foundations
# 77020  Central African Republic (the)     Foundations
#
#                         Sub-Pillar     Score  count_source
# 0          Connectivity Technology  4.036250          22.0
# 1             Innovation Ecosystem  1.591438           5.0
# 2          Digital Public Services  5.207568           2.0
# 3          Funding and procurement       NaN           NaN
# 4      Leadership and coordination       NaN           NaN
# ...                            ...       ...           ...
# 77016            Digital Wellbeing       NaN           NaN
# 77017                     Ambition  2.911170           1.0
# 77018             Digital Payments  1.384943           7.0
# 77019       Digital Legal Identity  1.864267           2.0
# 77020                Data Exchange       NaN           NaN
#
# [77021 rows x 5 columns]

# %%
# When normalizing country names, some sub-pillars will be duplicated, to resolve this, the method is to multiply
# the agg_score of the duplicate sub-pillars with count_source and then divided them by the total number of source to get the average
df['total_agg'] = df['Score']*df['count_source']
df
# Out:
#                          Country Name          Pillar  \
# 0                             Albania  Infrastructure
# 1                             Albania  Infrastructure
# 2                             Albania      Government
# 3                             Albania      Government
# 4                             Albania      Government
# ...                               ...             ...
# 77016  Central African Republic (the)          People
# 77017  Central African Republic (the)        Strategy
# 77018  Central African Republic (the)     Foundations
# 77019  Central African Republic (the)     Foundations
# 77020  Central African Republic (the)     Foundations
#
#                         Sub-Pillar     Score  count_source  total_agg
# 0          Connectivity Technology  4.036250          22.0  88.797489
# 1             Innovation Ecosystem  1.591438           5.0   7.957188
# 2          Digital Public Services  5.207568           2.0  10.415136
# 3          Funding and procurement       NaN           NaN        NaN
# 4      Leadership and coordination       NaN           NaN        NaN
# ...                            ...       ...           ...        ...
# 77016            Digital Wellbeing       NaN           NaN        NaN
# 77017                     Ambition  2.911170           1.0   2.911170
# 77018             Digital Payments  1.384943           7.0   9.694600
# 77019       Digital Legal Identity  1.864267           2.0   3.728533
# 77020                Data Exchange       NaN           NaN        NaN
#
# [77021 rows x 6 columns]

# %%
# Eliminate all duplicate Subpillar entries by aveerage them all
df = df.groupby(['Country Name','Pillar','Sub-Pillar']).agg({'total_agg':'sum','count_source':'sum'}).reset_index()
df['final_score'] = df['total_agg']/df['count_source']
df.rename(columns = {'final_score': 'Score'}, inplace = True)

df
# Out:
#      Country Name       Pillar                     Sub-Pillar   total_agg  \
# 0     Afghanistan     Business           Financing Incentives    0.000000
# 1     Afghanistan     Business             Impact commitments    0.000000
# 2     Afghanistan     Business            Startup Environment  119.588789
# 3     Afghanistan     Business            Technology Adoption   25.946060
# 4     Afghanistan  Foundations                  Data Exchange   22.400000
# ...           ...          ...                            ...         ...
# 7079     Zimbabwe       People            Usage and ownership  295.482642
# 7080     Zimbabwe   Regulation                  Cybersecurity   52.726400
# 7081     Zimbabwe   Regulation  Data standards and protection    0.000000
# 7082     Zimbabwe   Regulation              Ethical Standards   47.137600
# 7083     Zimbabwe     Strategy                       Ambition   62.866080
#
#       count_source     Score
# 0              0.0       NaN
# 1              0.0       NaN
# 2             28.0  4.271028
# 3             14.0  1.853290
# 4             14.0  1.600000
# ...            ...       ...
# 7079         128.0  2.308458
# 7080          16.0  3.295400
# 7081           0.0       NaN
# 7082          16.0  2.946100
# 7083          16.0  3.929130
#
# [7084 rows x 6 columns]

# %%
#Calculate the average pillar score of each country
pillar_score = df.groupby(['Country Name','Pillar']).agg({'Score':'mean'}).reset_index()
pillar_score.head(15)
# Out:
#                    Country Name          Pillar     Score
# 0                   Afghanistan        Business  3.062159
# 1                   Afghanistan     Foundations  2.491856
# 2                   Afghanistan      Government  3.185869
# 3                   Afghanistan  Infrastructure  1.862039
# 4                   Afghanistan          People  2.144179
# 5                   Afghanistan      Regulation  2.796400
# 6                   Afghanistan        Strategy  3.689610
# 7                        Africa        Business       NaN
# 8                        Africa     Foundations       NaN
# 9                        Africa      Government       NaN
# 10                       Africa  Infrastructure  1.058410
# 11                       Africa          People       NaN
# 12                       Africa      Regulation       NaN
# 13                       Africa        Strategy       NaN
# 14  Africa Eastern and Southern        Business  2.887244

# %%
#calculate the total average of sub-pillar score for each country
total_score =  df.groupby(['Country Name']).agg({'Score':'mean'}).reset_index()
total_score = total_score[['Country Name','Score']]
total_score.head(15)
# Out:
#                    Country Name     Score
# 0                   Afghanistan  2.540897
# 1                        Africa  1.058410
# 2   Africa Eastern and Southern  3.032456
# 3    Africa Western and Central  3.500116
# 4                       Albania  3.574024
# 5                       Algeria  3.068331
# 6                American Samoa  1.813058
# 7                       Andorra  2.452368
# 8                        Angola  2.661373
# 9                      Anguilla  3.994000
# 10          Antigua and Barbuda  2.736984
# 11                    Argentina  3.518330
# 12                      Armenia  3.419391
# 13                        Aruba  4.586628
# 14                    Australia  4.308516

# %%
product = pd.merge(total_score, pillar_score, how="outer", on=["Country Name",'Score'])
product
product.to_csv('../country_scores/Product.csv',index = False)

# %%
product_total = pd.concat([product,df], axis = 0).drop_duplicates().reset_index(drop=True)
#product_total['Score'] = product_total['Score'].replace(np.nan,0)
product_total.sort_values(by=['Pillar'], inplace=True)

product_total = product_total[['Country Name','Score','Pillar','Sub-Pillar']]
product_total
# Out:
#              Country Name     Score    Pillar            Sub-Pillar
# 8027          Saint Lucia       NaN  Business    Impact commitments
# 2747  Antigua and Barbuda       NaN  Business    Impact commitments
# 2748  Antigua and Barbuda  3.523609  Business   Startup Environment
# 2749  Antigua and Barbuda       NaN  Business   Technology Adoption
# 2768            Argentina  2.104625  Business  Financing Incentives
# ...                   ...       ...       ...                   ...
# 327        Western Sahara  1.110030       NaN                   NaN
# 328                 World  2.730184       NaN                   NaN
# 329                 Yemen  2.275230       NaN                   NaN
# 330                Zambia  2.829309       NaN                   NaN
# 331              Zimbabwe  2.783682       NaN                   NaN
#
# [9610 rows x 4 columns]

# %%
product_total.to_csv('../country_scores/Total_Scores_V2.csv',index = False)

# %%
country_list = ['Curaçao','Guinea-Bissau','Samoa','Solomon Islands','Uzbekistan']
dashboard = product_total[product_total['Sub-Pillar'].notna()]
dashboard = dashboard [['Country Name','Pillar','Sub-Pillar','Score']]
dashboard = dashboard[dashboard['Country Name'].isin(country_list)]
dashboard.to_csv('../country_scores/Dashboard.csv',index = False)

# %%
### Score Aggregating by Individual Indicators

# %%
# get list of files in scores folder
scores = os.listdir('../indicator_scores/')
scores
df = pd.concat([pd.read_csv('../indicator_scores/{}'.format(s)) for s in scores])    
df = df[['Sub-Pillar','Indicator','Country Name','Year','data_col','new_rank_score','higher_is_better']]
df
# Out:
#               Sub-Pillar                                 Indicator  \
# 0    Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 1    Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 2    Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 3    Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 4    Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# ..                   ...                                       ...
# 200             Ambition                                 SDG Index
# 201             Ambition                                 SDG Index
# 202             Ambition                                 SDG Index
# 203             Ambition                                 SDG Index
# 204             Ambition                                 SDG Index
#
#                       Country Name    Year  data_col  new_rank_score  \
# 0                          Germany  2018.0      18.2         1.90818
# 1                            Japan  2018.0      20.3         2.01297
# 2                    United States  2018.0      18.0         1.89820
# 3                   United Kingdom  2018.0      19.8         1.98802
# 4                        Australia  2018.0      16.1         1.80339
# ..                             ...     ...       ...             ...
# 200             Sub-Saharan Africa  2019.0      51.9         3.58981
# 201           Low-income Countries  2019.0      51.0         3.54490
# 202  Lower-middle-income Countries  2019.0      60.1         3.99899
# 203  Upper-middle-income Countries  2019.0      70.8         4.53292
# 204          High-income Countries  2019.0      78.1         4.89719
#
#      higher_is_better
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# ..                ...
# 200              True
# 201              True
# 202              True
# 203              True
# 204              True
#
# [13300 rows x 7 columns]

# %%
df['Country Name'] = df['Country Name'].str.strip()
df['Country Name'] = df['Country Name'].str.strip('**')
df['Country Name'] = df['Country Name'].str.strip('*')
df['Country Name'] = df['Country Name'].str.strip('*')
df = df.dropna()

# %%
# Normalize country names as much as possible

df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bahamas.*$)', 'Bahamas (the)')
df['Country Name'] = df['Country Name'].replace('Bahrain (Kingdom of)','Bahrain')
df['Country Name'] = df['Country Name'].replace('Bolivia','Bolivia (Plurinational State of)')
df['Country Name'] = df['Country Name'].replace('Bolivia, Plurinational State of','Bolivia (Plurinational State of)')
df['Country Name'] = df['Country Name'].replace('Brunei','Brunei Darussalam')
df['Country Name'] = df['Country Name'].replace('Bulgaria (Rep.)','Bulgaria')
df['Country Name'] = df['Country Name'].replace('Central African Republic','Central African Republic (the)')
df['Country Name'] = df['Country Name'].replace('Central African Rep.','Central African Republic (the)')
df['Country Name'] = df['Country Name'].replace("China (People's Rep.)",'China')
df['Country Name'] = df['Country Name'].replace("Comoros",'Comoros (the)')
df['Country Name'] = df['Country Name'].replace("Congo",'Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo (Brazzaville)",'Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo (Rep. of the)",'Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo (Democratic Republic of the)",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo, Dem. Rep.",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo, The Democratic Republic of the",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("DR Congo",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Democratic Republic of Congo",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Democratic Republic of the Congo",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Dem. Rep. of the Congo",'Democratic Republic of the Congo (the)')



df['Country Name'] = df['Country Name'].replace("Cote d'Ivoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Côte d’Ivoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Cote dIvoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Cōte d'Ivoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Ivory Coast","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Dem. People's Rep. of Korea","Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].replace("Democratic People's Republic of Korea","Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].replace("Korea, Dem. People's Rep.","Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].replace("North Korea","Democratic People's Republic of Korea (the)")
# Out:
# <ipython-input-27-f1a9d28c7d4c>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bahamas.*$)', 'Bahamas (the)')
# <ipython-input-27-f1a9d28c7d4c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bahamas.*$)', 'Bahamas (the)')
# <ipython-input-27-f1a9d28c7d4c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Bahrain (Kingdom of)','Bahrain')
# <ipython-input-27-f1a9d28c7d4c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Bolivia','Bolivia (Plurinational State of)')
# <ipython-input-27-f1a9d28c7d4c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Bolivia, Plurinational State of','Bolivia (Plurinational State of)')
# <ipython-input-27-f1a9d28c7d4c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Brunei','Brunei Darussalam')
# <ipython-input-27-f1a9d28c7d4c>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Bulgaria (Rep.)','Bulgaria')
# <ipython-input-27-f1a9d28c7d4c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Central African Republic','Central African Republic (the)')
# <ipython-input-27-f1a9d28c7d4c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Central African Rep.','Central African Republic (the)')
# <ipython-input-27-f1a9d28c7d4c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("China (People's Rep.)",'China')
# <ipython-input-27-f1a9d28c7d4c>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Comoros",'Comoros (the)')
# <ipython-input-27-f1a9d28c7d4c>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo",'Congo (the)')
# <ipython-input-27-f1a9d28c7d4c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo (Brazzaville)",'Congo (the)')
# <ipython-input-27-f1a9d28c7d4c>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo (Rep. of the)",'Congo (the)')
# <ipython-input-27-f1a9d28c7d4c>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo (Democratic Republic of the)",'Democratic Republic of the Congo (the)')
# <ipython-input-27-f1a9d28c7d4c>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo, Dem. Rep.",'Democratic Republic of the Congo (the)')
# <ipython-input-27-f1a9d28c7d4c>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo, The Democratic Republic of the",'Democratic Republic of the Congo (the)')
# <ipython-input-27-f1a9d28c7d4c>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("DR Congo",'Democratic Republic of the Congo (the)')
# <ipython-input-27-f1a9d28c7d4c>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Democratic Republic of Congo",'Democratic Republic of the Congo (the)')
# <ipython-input-27-f1a9d28c7d4c>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Democratic Republic of the Congo",'Democratic Republic of the Congo (the)')
# <ipython-input-27-f1a9d28c7d4c>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Dem. Rep. of the Congo",'Democratic Republic of the Congo (the)')
# <ipython-input-27-f1a9d28c7d4c>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Cote d'Ivoire","Côte d'Ivoire")
# <ipython-input-27-f1a9d28c7d4c>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Côte d’Ivoire","Côte d'Ivoire")
# <ipython-input-27-f1a9d28c7d4c>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Cote dIvoire","Côte d'Ivoire")
# <ipython-input-27-f1a9d28c7d4c>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Cōte d'Ivoire","Côte d'Ivoire")
# <ipython-input-27-f1a9d28c7d4c>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Ivory Coast","Côte d'Ivoire")
# <ipython-input-27-f1a9d28c7d4c>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Dem. People's Rep. of Korea","Democratic People's Republic of Korea (the)")
# <ipython-input-27-f1a9d28c7d4c>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Democratic People's Republic of Korea","Democratic People's Republic of Korea (the)")
# <ipython-input-27-f1a9d28c7d4c>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea, Dem. People's Rep.","Democratic People's Republic of Korea (the)")
# <ipython-input-27-f1a9d28c7d4c>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("North Korea","Democratic People's Republic of Korea (the)")

# %%
# Continue

df['Country Name'] = df['Country Name'].str.replace(r'(^.*Czech.*$)', 'Czechia')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Dominican Re.*$)', 'Dominican Republic (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hong Kong.*$)', 'China, Hong Kong Special Administrative Region')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hongkong.*$)', 'China, Hong Kong Special Administrative Region')
df['Country Name'] = df['Country Name'].replace("Eswatini (Kingdom of)",'Eswatini')
df['Country Name'] = df['Country Name'].replace("Swaziland",'Eswatini')
df['Country Name'] = df['Country Name'].replace("Faröe Islands",'Faroe Islands')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Gambia.*$)', 'Gambia (the)')
df['Country Name'] = df['Country Name'].replace("Georgia (Country)",'Georgia')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Iran.*$)', 'Iran (Islamic Republic of)')
df['Country Name'] = df['Country Name'].replace("Korea",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea (Rep. of)",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea (Rep.)",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea (Republic of)",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Korea, Rep.*$)', 'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea, South",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("South Korea",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Republic of Korea",'Republic of Korea (the)')
# Out:
# <ipython-input-28-d20d6b135740>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Czech.*$)', 'Czechia')
# <ipython-input-28-d20d6b135740>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Czech.*$)', 'Czechia')
# <ipython-input-28-d20d6b135740>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Dominican Re.*$)', 'Dominican Republic (the)')
# <ipython-input-28-d20d6b135740>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Dominican Re.*$)', 'Dominican Republic (the)')
# <ipython-input-28-d20d6b135740>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hong Kong.*$)', 'China, Hong Kong Special Administrative Region')
# <ipython-input-28-d20d6b135740>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hong Kong.*$)', 'China, Hong Kong Special Administrative Region')
# <ipython-input-28-d20d6b135740>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hongkong.*$)', 'China, Hong Kong Special Administrative Region')
# <ipython-input-28-d20d6b135740>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hongkong.*$)', 'China, Hong Kong Special Administrative Region')
# <ipython-input-28-d20d6b135740>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Eswatini (Kingdom of)",'Eswatini')
# <ipython-input-28-d20d6b135740>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Swaziland",'Eswatini')
# <ipython-input-28-d20d6b135740>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Faröe Islands",'Faroe Islands')
# <ipython-input-28-d20d6b135740>:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Gambia.*$)', 'Gambia (the)')
# <ipython-input-28-d20d6b135740>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Gambia.*$)', 'Gambia (the)')
# <ipython-input-28-d20d6b135740>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Georgia (Country)",'Georgia')
# <ipython-input-28-d20d6b135740>:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Iran.*$)', 'Iran (Islamic Republic of)')
# <ipython-input-28-d20d6b135740>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Iran.*$)', 'Iran (Islamic Republic of)')
# <ipython-input-28-d20d6b135740>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea",'Republic of Korea (the)')
# <ipython-input-28-d20d6b135740>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea (Rep. of)",'Republic of Korea (the)')
# <ipython-input-28-d20d6b135740>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea (Rep.)",'Republic of Korea (the)')
# <ipython-input-28-d20d6b135740>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea (Republic of)",'Republic of Korea (the)')
# <ipython-input-28-d20d6b135740>:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Korea, Rep.*$)', 'Republic of Korea (the)')
# <ipython-input-28-d20d6b135740>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Korea, Rep.*$)', 'Republic of Korea (the)')
# <ipython-input-28-d20d6b135740>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea, South",'Republic of Korea (the)')
# <ipython-input-28-d20d6b135740>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("South Korea",'Republic of Korea (the)')
# <ipython-input-28-d20d6b135740>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Republic of Korea",'Republic of Korea (the)')

# %%
# Continue
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kyrgyz.*$)', 'Kyrgyzstan')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lao.*$)', "Lao People's Democratic Republic (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macao.*$)', "China, Macao Special Administrative Region")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macau.*$)', "China, Macao Special Administrative Region")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Micronesia.*$)', "Micronesia (Federated States of)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Moldova.*$)', "Republic of Moldova (the)")
df['Country Name'] = df['Country Name'].replace("Morroco",'Morocco')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Nepal.*$)', "Nepal")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
df['Country Name'] = df['Country Name'].replace("Niger",'Niger (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macedonia.*$)', "North Macedonia")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Palestin.*$)', "State of Palestine (the)")
df['Country Name'] = df['Country Name'].replace("West Bank and Gaza",'State of Palestine (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Panama.*$)', "Panama")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Philippines.*$)', "Philippines (the)")
df['Country Name'] = df['Country Name'].replace("Republic of the Congo",'Congo (the)')
df['Country Name'] = df['Country Name'].replace("Korea, DPR","Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Myanmar.*$)', "Myanmar")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Puerto Rico.*$)', "Puerto Rico")
df['Country Name'] = df['Country Name'].replace("Russia",'Russian Federation (the)')
df['Country Name'] = df['Country Name'].replace("Russian Federation",'Russian Federation (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Slovak.*$)', "Slovakia")
df['Country Name'] = df['Country Name'].str.replace(r'\bSudan\b', 'Sudan (the)')
df['Country Name'] = df['Country Name'].str.replace(r'\bSudan (the)\b', 'Sudan (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*South Sudan.*$)', "South Sudan")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Syria.*$)', "Syrian Arab Republic (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*São Tomé.*$)', "Sao Tome and Principe")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taiwan.*$)', "Taiwan")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taipei.*$)', "Taiwan")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Tanzania.*$)', "United Republic of Tanzania (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Netherlands.*$)', "Netherlands (the)")
# Out:
# <ipython-input-29-21cb731b7228>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kyrgyz.*$)', 'Kyrgyzstan')
# <ipython-input-29-21cb731b7228>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kyrgyz.*$)', 'Kyrgyzstan')
# <ipython-input-29-21cb731b7228>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lao.*$)', "Lao People's Democratic Republic (the)")
# <ipython-input-29-21cb731b7228>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lao.*$)', "Lao People's Democratic Republic (the)")
# <ipython-input-29-21cb731b7228>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macao.*$)', "China, Macao Special Administrative Region")
# <ipython-input-29-21cb731b7228>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macao.*$)', "China, Macao Special Administrative Region")
# <ipython-input-29-21cb731b7228>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macau.*$)', "China, Macao Special Administrative Region")
# <ipython-input-29-21cb731b7228>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macau.*$)', "China, Macao Special Administrative Region")
# <ipython-input-29-21cb731b7228>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Micronesia.*$)', "Micronesia (Federated States of)")
# <ipython-input-29-21cb731b7228>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Micronesia.*$)', "Micronesia (Federated States of)")
# <ipython-input-29-21cb731b7228>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Moldova.*$)', "Republic of Moldova (the)")
# <ipython-input-29-21cb731b7228>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Moldova.*$)', "Republic of Moldova (the)")
# <ipython-input-29-21cb731b7228>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Morroco",'Morocco')
# <ipython-input-29-21cb731b7228>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Nepal.*$)', "Nepal")
# <ipython-input-29-21cb731b7228>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Nepal.*$)', "Nepal")
# <ipython-input-29-21cb731b7228>:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
# <ipython-input-29-21cb731b7228>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
# <ipython-input-29-21cb731b7228>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Niger",'Niger (the)')
# <ipython-input-29-21cb731b7228>:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macedonia.*$)', "North Macedonia")
# <ipython-input-29-21cb731b7228>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macedonia.*$)', "North Macedonia")
# <ipython-input-29-21cb731b7228>:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
# <ipython-input-29-21cb731b7228>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
# <ipython-input-29-21cb731b7228>:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Palestin.*$)', "State of Palestine (the)")
# <ipython-input-29-21cb731b7228>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Palestin.*$)', "State of Palestine (the)")
# <ipython-input-29-21cb731b7228>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("West Bank and Gaza",'State of Palestine (the)')
# <ipython-input-29-21cb731b7228>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Panama.*$)', "Panama")
# <ipython-input-29-21cb731b7228>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Panama.*$)', "Panama")
# <ipython-input-29-21cb731b7228>:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Philippines.*$)', "Philippines (the)")
# <ipython-input-29-21cb731b7228>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Philippines.*$)', "Philippines (the)")
# <ipython-input-29-21cb731b7228>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Republic of the Congo",'Congo (the)')
# <ipython-input-29-21cb731b7228>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea, DPR","Democratic People's Republic of Korea (the)")
# <ipython-input-29-21cb731b7228>:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Myanmar.*$)', "Myanmar")
# <ipython-input-29-21cb731b7228>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Myanmar.*$)', "Myanmar")
# <ipython-input-29-21cb731b7228>:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Puerto Rico.*$)', "Puerto Rico")
# <ipython-input-29-21cb731b7228>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Puerto Rico.*$)', "Puerto Rico")
# <ipython-input-29-21cb731b7228>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Russia",'Russian Federation (the)')
# <ipython-input-29-21cb731b7228>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Russian Federation",'Russian Federation (the)')
# <ipython-input-29-21cb731b7228>:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Slovak.*$)', "Slovakia")
# <ipython-input-29-21cb731b7228>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Slovak.*$)', "Slovakia")
# <ipython-input-29-21cb731b7228>:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'\bSudan\b', 'Sudan (the)')
# <ipython-input-29-21cb731b7228>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'\bSudan\b', 'Sudan (the)')
# <ipython-input-29-21cb731b7228>:26: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'\bSudan (the)\b', 'Sudan (the)')
# <ipython-input-29-21cb731b7228>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'\bSudan (the)\b', 'Sudan (the)')
# <ipython-input-29-21cb731b7228>:27: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*South Sudan.*$)', "South Sudan")
# <ipython-input-29-21cb731b7228>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*South Sudan.*$)', "South Sudan")
# <ipython-input-29-21cb731b7228>:28: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Syria.*$)', "Syrian Arab Republic (the)")
# <ipython-input-29-21cb731b7228>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Syria.*$)', "Syrian Arab Republic (the)")
# <ipython-input-29-21cb731b7228>:29: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*São Tomé.*$)', "Sao Tome and Principe")
# <ipython-input-29-21cb731b7228>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*São Tomé.*$)', "Sao Tome and Principe")
# <ipython-input-29-21cb731b7228>:30: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taiwan.*$)', "Taiwan")
# <ipython-input-29-21cb731b7228>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taiwan.*$)', "Taiwan")
# <ipython-input-29-21cb731b7228>:31: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taipei.*$)', "Taiwan")
# <ipython-input-29-21cb731b7228>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taipei.*$)', "Taiwan")
# <ipython-input-29-21cb731b7228>:32: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Tanzania.*$)', "United Republic of Tanzania (the)")
# <ipython-input-29-21cb731b7228>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Tanzania.*$)', "United Republic of Tanzania (the)")
# <ipython-input-29-21cb731b7228>:33: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Netherlands.*$)', "Netherlands (the)")
# <ipython-input-29-21cb731b7228>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Netherlands.*$)', "Netherlands (the)")

# %%
# Continue
df['Country Name'] = df['Country Name'].replace("UAE",'United Arab Emirates (the)')
df['Country Name'] = df['Country Name'].replace("U.A.E",'United Arab Emirates (the)')
df['Country Name'] = df['Country Name'].replace("United Arab Emirates",'United Arab Emirates (the)')
df['Country Name'] = df['Country Name'].replace('United Kingdom','United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace('UK','United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace("Great Britain",'United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace("United Kingdom of Great Britain and Northern Ireland",'United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace('Vietnam','Viet Nam')
df['Country Name'] = df['Country Name'].replace('United States','United States of America (the)')
df['Country Name'] = df['Country Name'].replace('USA','United States of America (the)')
df['Country Name'] = df['Country Name'].replace('United States of America','United States of America (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Virgin Islands.*$)', "United States Virgin Islands")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vatican.*$)', "Vatican")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Venezuela.*$)', "Venezuela (Bolivarian Republic of)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Yemen.*$)', "Yemen")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Arab world.*$)', "Arab World")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*World.*$)', "World")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kitts and Nevis.*$)', "Saint Kitts and Nevis")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lucia.*$)', "Saint Lucia")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Martin (French part).*$)', "Saint Martin (French Part)")
df['Country Name'] = df['Country Name'].replace('Sint Maarten','Saint Martin')
df['Country Name'] = df['Country Name'].replace('St. Martin (French part)','Saint Martin (French Part)')
df['Country Name'] = df['Country Name'].replace('Sint Maarten (Dutch part)','Saint Martin (Dutch Part)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vincent and the Grenadines.*$)', "Saint Vincent and the Grenadines")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Verde.*$)', "Cabo Verde")
df['Country Name'] = df['Country Name'].replace('Congo, Democratic Republic','Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace('Congo, Rep.','Congo (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Egypt.*$)', "Egypt")
df['Country Name'] = df['Country Name'].replace('Curacao','Curaçao')
df['Country Name'] = df['Country Name'].replace('Reunion','Réunion')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kosovo.*$)', "Kosovo (UNSCR 1244)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bissau.*$)', "Guinea-Bissau")
# Out:
# <ipython-input-30-05c1cfd9efbc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("UAE",'United Arab Emirates (the)')
# <ipython-input-30-05c1cfd9efbc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("U.A.E",'United Arab Emirates (the)')
# <ipython-input-30-05c1cfd9efbc>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("United Arab Emirates",'United Arab Emirates (the)')
# <ipython-input-30-05c1cfd9efbc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('United Kingdom','United Kingdom of Great Britain and Northern Ireland (the)')
# <ipython-input-30-05c1cfd9efbc>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('UK','United Kingdom of Great Britain and Northern Ireland (the)')
# <ipython-input-30-05c1cfd9efbc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Great Britain",'United Kingdom of Great Britain and Northern Ireland (the)')
# <ipython-input-30-05c1cfd9efbc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("United Kingdom of Great Britain and Northern Ireland",'United Kingdom of Great Britain and Northern Ireland (the)')
# <ipython-input-30-05c1cfd9efbc>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Vietnam','Viet Nam')
# <ipython-input-30-05c1cfd9efbc>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('United States','United States of America (the)')
# <ipython-input-30-05c1cfd9efbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('USA','United States of America (the)')
# <ipython-input-30-05c1cfd9efbc>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('United States of America','United States of America (the)')
# <ipython-input-30-05c1cfd9efbc>:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Virgin Islands.*$)', "United States Virgin Islands")
# <ipython-input-30-05c1cfd9efbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Virgin Islands.*$)', "United States Virgin Islands")
# <ipython-input-30-05c1cfd9efbc>:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vatican.*$)', "Vatican")
# <ipython-input-30-05c1cfd9efbc>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vatican.*$)', "Vatican")
# <ipython-input-30-05c1cfd9efbc>:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Venezuela.*$)', "Venezuela (Bolivarian Republic of)")
# <ipython-input-30-05c1cfd9efbc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Venezuela.*$)', "Venezuela (Bolivarian Republic of)")
# <ipython-input-30-05c1cfd9efbc>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Yemen.*$)', "Yemen")
# <ipython-input-30-05c1cfd9efbc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Yemen.*$)', "Yemen")
# <ipython-input-30-05c1cfd9efbc>:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Arab world.*$)', "Arab World")
# <ipython-input-30-05c1cfd9efbc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Arab world.*$)', "Arab World")
# <ipython-input-30-05c1cfd9efbc>:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*World.*$)', "World")
# <ipython-input-30-05c1cfd9efbc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*World.*$)', "World")
# <ipython-input-30-05c1cfd9efbc>:19: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kitts and Nevis.*$)', "Saint Kitts and Nevis")
# <ipython-input-30-05c1cfd9efbc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kitts and Nevis.*$)', "Saint Kitts and Nevis")
# <ipython-input-30-05c1cfd9efbc>:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lucia.*$)', "Saint Lucia")
# <ipython-input-30-05c1cfd9efbc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lucia.*$)', "Saint Lucia")
# <ipython-input-30-05c1cfd9efbc>:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Martin (French part).*$)', "Saint Martin (French Part)")
# <ipython-input-30-05c1cfd9efbc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Martin (French part).*$)', "Saint Martin (French Part)")
# <ipython-input-30-05c1cfd9efbc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Sint Maarten','Saint Martin')
# <ipython-input-30-05c1cfd9efbc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('St. Martin (French part)','Saint Martin (French Part)')
# <ipython-input-30-05c1cfd9efbc>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Sint Maarten (Dutch part)','Saint Martin (Dutch Part)')
# <ipython-input-30-05c1cfd9efbc>:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vincent and the Grenadines.*$)', "Saint Vincent and the Grenadines")
# <ipython-input-30-05c1cfd9efbc>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vincent and the Grenadines.*$)', "Saint Vincent and the Grenadines")
# <ipython-input-30-05c1cfd9efbc>:26: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Verde.*$)', "Cabo Verde")
# <ipython-input-30-05c1cfd9efbc>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Verde.*$)', "Cabo Verde")
# <ipython-input-30-05c1cfd9efbc>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Congo, Democratic Republic','Democratic Republic of the Congo (the)')
# <ipython-input-30-05c1cfd9efbc>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Congo, Rep.','Congo (the)')
# <ipython-input-30-05c1cfd9efbc>:29: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Egypt.*$)', "Egypt")
# <ipython-input-30-05c1cfd9efbc>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Egypt.*$)', "Egypt")
# <ipython-input-30-05c1cfd9efbc>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Curacao','Curaçao')
# <ipython-input-30-05c1cfd9efbc>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Reunion','Réunion')
# <ipython-input-30-05c1cfd9efbc>:32: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kosovo.*$)', "Kosovo (UNSCR 1244)")
# <ipython-input-30-05c1cfd9efbc>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kosovo.*$)', "Kosovo (UNSCR 1244)")
# <ipython-input-30-05c1cfd9efbc>:33: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bissau.*$)', "Guinea-Bissau")
# <ipython-input-30-05c1cfd9efbc>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bissau.*$)', "Guinea-Bissau")

# %%
country_list = sorted(df['Country Name'].unique().tolist())
country_list
# Out:
# ['Afghanistan',
#  'Africa',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Ant.& Barb.',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas (the)',
#  'Bahrain',
#  'Bangladesh',
#  'Bangladesh Chittagong',
#  'Bangladesh Dhaka',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belgium Estonia',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia (Plurinational State of)',
#  'Bosnia & Herz.',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brazil Rio de Janeiro',
#  'Brazil São Paulo',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burma',
#  'Burundi',
#  'C.A. Republic',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic (the)',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'China Beijing',
#  'China Shanghai',
#  'China, Hong Kong Special Administrative Region',
#  'China, Macao Special Administrative Region',
#  'Colombia',
#  'Comoros (the)',
#  'Congo (the)',
#  'Cook Islands',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czechia',
#  "Côte d'Ivoire",
#  "Democratic People's Republic of Korea (the)",
#  'Democratic Republic of the Congo (the)',
#  'Denmark',
#  'Developing',
#  'Djibouti',
#  'Domin. Rep.',
#  'Dominica',
#  'Dominican Republic (the)',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'East Asia & Pacific (excluding high income)',
#  'East and South Asia',
#  'Eastern Europe and Central Asia',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Eq. Guinea',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Euro area',
#  'Europe',
#  'Europe & Central Asia',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Europe & Central Asia (excluding high income)',
#  'European Union',
#  'European Union (28 countries)',
#  'Falkland Islands',
#  'Faroe Islands',
#  'Fiji',
#  'Finland',
#  'Fragile and conflict affected situations',
#  'France',
#  'French Guiana',
#  'French Polynesia',
#  'Gabon',
#  'Gambia (the)',
#  'Georgia',
#  'Germany',
#  'Germany France',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'High income: OECD',
#  'High-income Countries',
#  'Honduras',
#  'Hungary',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA blend',
#  'IDA only',
#  'IDA total',
#  'Iceland',
#  'India',
#  'India Delhi',
#  'India Mumbai',
#  'Indonesia',
#  'Indonesia Jakarta',
#  'Indonesia Surabaya',
#  'Iran (Islamic Republic of)',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Japan Osaka',
#  'Japan Tokyo',
#  'Jersey',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo (UNSCR 1244)',
#  'Kuwait',
#  'Kyrgyzstan',
#  "Lao People's Democratic Republic (the)",
#  'Late-demographic dividend',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean (excluding high income)',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Latin America and the Caribbean',
#  'Latvia',
#  'Least developed countries: UN classification',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Low & middle income',
#  'Low income',
#  'Low-income Countries',
#  'Lower middle income',
#  'Lower-middle-income Countries',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Martinique',
#  'Mauritania',
#  'Mauritius',
#  'Mayotte',
#  'Mexico',
#  'Mexico Mexico City',
#  'Mexico Monterrey',
#  'Micronesia (Federated States of)',
#  'Middle East & North Africa',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Middle East & North Africa (excluding high income)',
#  'Middle East and North Africa',
#  'Middle income',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands (the)',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger (the)',
#  'Nigeria',
#  'Nigeria Kano',
#  'Nigeria Lagos',
#  'Niue',
#  'North America',
#  'North Cyprus',
#  'North Macedonia',
#  'Northern Ireland',
#  'Northern Mariana Islands',
#  'Norway',
#  'OECD members',
#  'Oceania',
#  'Oman',
#  'Other small states',
#  'Pacific island small states',
#  'Pakistan',
#  'Pakistan Karachi',
#  'Pakistan Lahore',
#  'Palau',
#  'Panama',
#  'Papua N.G.',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines (the)',
#  'Poland',
#  'Portugal',
#  'Post-demographic dividend',
#  'Pre-demographic dividend',
#  'Puerto Rico',
#  'Qatar',
#  'R. of Congo',
#  'Republic of Korea (the)',
#  'Republic of Moldova (the)',
#  'Romania',
#  'Russian Federation (the)',
#  'Russian Federation Moscow',
#  'Russian Federation Saint Petersburg',
#  'Rwanda',
#  'Réunion',
#  'S.T.&Principe',
#  'Saint Helena',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Martin',
#  'Saint Martin (Dutch Part)',
#  'Saint Martin (French Part)',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Small Island Developing States',
#  'Small states',
#  'Solomon Isl.',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Asia',
#  'South Asia (IDA & IBRD)',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'St. Vincent & ...',
#  'State of Palestine (the)',
#  'Sub-Saharan Africa',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sudan (the)',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Republic (the)',
#  'Taiwan',
#  'Tajikistan',
#  'Thailand',
#  'Timor-Leste',
#  'Togo',
#  'Tokelau',
#  'Tonga',
#  'Tr.&Tobago',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'UA Emirates',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates (the)',
#  'United Kingdom of Great Britain and Northern Ireland (the)',
#  'United Republic of Tanzania (the)',
#  'United States Los Angeles',
#  'United States New York City',
#  'United States Virgin Islands',
#  'United States of America (the)',
#  'Upper middle income',
#  'Upper-middle-income Countries',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vatican',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam',
#  'Wallis and Futuna',
#  'Western Sahara',
#  'World',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
df.insert(0,'Pillar','')
df.loc[(df['Sub-Pillar'] == 'Connectivity Technology') | (df['Sub-Pillar'] == 'Innovation Ecosystem'), 'Pillar'] = 'Infrastructure'
df.loc[(df['Sub-Pillar'] == 'Financing Incentives') | (df['Sub-Pillar'] == 'Technology Adoption') | (df['Sub-Pillar'] == 'Startup Environment'), 'Pillar'] = 'Business'
df.loc[(df['Sub-Pillar'] == 'Data Exchange') | (df['Sub-Pillar'] == 'Digital Legal Identity') | (df['Sub-Pillar'] == 'Digital Payments'), 'Pillar'] = 'Foundations'
df.loc[(df['Sub-Pillar'] == 'Capabilities') | (df['Sub-Pillar'] == 'Digital Public Services') | (df['Sub-Pillar'] == 'Funding and procurement') | (df['Sub-Pillar'] == 'Leadership and coordination'), 'Pillar'] = 'Government'
df.loc[(df['Sub-Pillar'] == 'Culture') | (df['Sub-Pillar'] == 'Digital Literacy Skills') | (df['Sub-Pillar'] == 'Digital Wellbeing')| (df['Sub-Pillar'] == 'Usage and ownership'), 'Pillar'] = 'People'
df.loc[(df['Sub-Pillar'] == 'Cybersecurity') | (df['Sub-Pillar'] == 'Ethical Standards'), 'Pillar'] = 'Regulation'
df.loc[(df['Sub-Pillar'] == 'Ambition'), 'Pillar'] = 'Strategy'

df
# Out:
# D:\Apps\Anaconda\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#        Pillar           Sub-Pillar                                 Indicator  \
# 0    Business  Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 1    Business  Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 2    Business  Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 3    Business  Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 4    Business  Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# ..        ...                  ...                                       ...
# 200  Strategy             Ambition                                 SDG Index
# 201  Strategy             Ambition                                 SDG Index
# 202  Strategy             Ambition                                 SDG Index
# 203  Strategy             Ambition                                 SDG Index
# 204  Strategy             Ambition                                 SDG Index
#
#                                           Country Name    Year  data_col  \
# 0                                              Germany  2018.0      18.2
# 1                                                Japan  2018.0      20.3
# 2                       United States of America (the)  2018.0      18.0
# 3    United Kingdom of Great Britain and Northern I...  2018.0      19.8
# 4                                            Australia  2018.0      16.1
# ..                                                 ...     ...       ...
# 200                                 Sub-Saharan Africa  2019.0      51.9
# 201                               Low-income Countries  2019.0      51.0
# 202                      Lower-middle-income Countries  2019.0      60.1
# 203                      Upper-middle-income Countries  2019.0      70.8
# 204                              High-income Countries  2019.0      78.1
#
#      new_rank_score  higher_is_better
# 0           1.90818              True
# 1           2.01297              True
# 2           1.89820              True
# 3           1.98802              True
# 4           1.80339              True
# ..              ...               ...
# 200         3.58981              True
# 201         3.54490              True
# 202         3.99899              True
# 203         4.53292              True
# 204         4.89719              True
#
# [12018 rows x 8 columns]

# %%
# For all country
df = df[['Country Name','Year','Pillar','Sub-Pillar','Indicator','data_col','new_rank_score','higher_is_better']]
df.to_excel('../country_scores/All_Indicator.xlsx',index = False)
df.to_csv('../../dashboard/Scores.csv',index = False)

# %%
uzb = df[(df['Country Name'] == 'Uzbekistan')]
uzb
uzb.to_csv('../country_scores/Uzbekistan_Indicator.csv',index = False)

arm = df[(df['Country Name'] == 'Armenia')]
arm
arm.to_csv('../country_scores/Armenia_Indicator.csv',index = False)

# %%
pol = df[(df['Country Name'] == 'Poland')]
pol

pol.to_csv('../country_scores/Poland_Indicator.csv',index = False)

# %%
#country_list = ['Curaçao','Guinea-Bissau','Samoa','Solomon Islands','Uzbekistan']
#dashboard = df[(df['Country Name'] == country_list)]
#dashboard

#dashboard.to_csv('../country_scores/Dashboard.csv',index = False)
