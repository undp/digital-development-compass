# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False           Countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              16         25
# Foundations            8         13
# Government             9         15
# Infrastructure        39         48
# People                34         47
# Regulation             5          7
# Strategy               1          1

# %% [markdown]
# ### Foundations

# %%
bnames = names[(names.check=='Foundations')&(~names.Filename.isna())]#&(names.Index==False)]

# %%
bnames.head(25)
# Out:
#                                              Indicator        check  \
# 148                       Digital payments penetration  Foundations
# 149  % of population with digital finance account -...  Foundations
# 150  % of population with digital finance account -...  Foundations
# 154                      % of population with ID (all)  Foundations
# 155                   % of population with ID (female)  Foundations
# 157                    can ID be used for transactions  Foundations
# 158                            Is personal data siloed  Foundations
# 159                                    Open data index  Foundations
#
#                    Data Source  Index                               Filename
# 148        Portulans Institute  TRUE            digital_payments_penetration
# 149                 World Bank  False  population_digital_financial_services
# 150                 World Bank  False  population_digital_financial_services
# 154                World Bank   False                               id4d_nid
# 155                World Bank   False                               id4d_nid
# 157                World Bank   False                          id4d_services
# 158                 World Bank  False                          Egov_strategy
# 159  Open Knowledge Foundation   True                          open_data_idx

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['digital_payments_penetration',
#        'population_digital_financial_services', 'id4d_nid',
#        'id4d_services', 'Egov_strategy', 'open_data_idx'], dtype=object)

# %%
# ls digital-readiness-assessment-main/processed/

# %%
##ict_goods and services not in process data

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %% [markdown]
# ### 1. Digital payments penetration

# %%
indicators[0]
# Out:
# 'Digital payments penetration'

# %%
# load data
indicator = indicators[0]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Digital payments penetration
# digital_payments_penetration

# %%
df.head()
# Out:
#    RANK COUNTRY/ECONOMY  VALUE   SCORE
# 0   1.0          Norway   0.85  100.00
# 1   2.0         Denmark   0.83   97.24
# 2   3.0         Finland   0.80   93.95
# 3   4.0          Sweden   0.80   93.08
# 4   5.0     Netherlands   0.76   89.01

# %%
# score looks like the one to use
df.describe()
# Out:
#              RANK       VALUE       SCORE
# count  122.000000  122.000000  122.000000
# mean    61.500000    0.315738   36.076967
# std     35.362409    0.209012   24.867406
# min      1.000000    0.010000    0.000000
# 25%     31.250000    0.150000   16.235000
# 50%     61.500000    0.270000   30.870000
# 75%     91.750000    0.440000   51.110000
# max    122.000000    0.850000  100.000000

# %%
# df.Indicator.unique()

# %%
# create standard columns
df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['SCORE'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-100 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df
# Out:
#      RANK Country Name  VALUE   SCORE  higher_is_better  \
# 0     1.0       Norway   0.85  100.00              True
# 1     2.0      Denmark   0.83   97.24              True
# 2     3.0      Finland   0.80   93.95              True
# 3     4.0       Sweden   0.80   93.08              True
# 4     5.0  Netherlands   0.76   89.01              True
# ..    ...          ...    ...     ...               ...
# 129   NaN      Jamaica    NaN     NaN              True
# 130   NaN   Madagascar    NaN     NaN              True
# 131   NaN         Oman    NaN     NaN              True
# 132   NaN        Qatar    NaN     NaN              True
# 133   NaN        Yemen    NaN     NaN              True
#
#                         Indicator  data_col  new_rank_score
# 0    Digital payments penetration    100.00          6.0000
# 1    Digital payments penetration     97.24          5.8620
# 2    Digital payments penetration     93.95          5.6975
# 3    Digital payments penetration     93.08          5.6540
# 4    Digital payments penetration     89.01          5.4505
# ..                            ...       ...             ...
# 129  Digital payments penetration       NaN             NaN
# 130  Digital payments penetration       NaN             NaN
# 131  Digital payments penetration       NaN             NaN
# 132  Digital payments penetration       NaN             NaN
# 133  Digital payments penetration       NaN             NaN
#
# [134 rows x 8 columns]

# %%
# output scores to csv
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %%
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#       Country Name                     Indicator  data_col  new_rank_score  \
# 0           Norway  Digital payments penetration    100.00          6.0000
# 1          Denmark  Digital payments penetration     97.24          5.8620
# 2          Finland  Digital payments penetration     93.95          5.6975
# 3           Sweden  Digital payments penetration     93.08          5.6540
# 4      Netherlands  Digital payments penetration     89.01          5.4505
# 5      New Zealand  Digital payments penetration     86.73          5.3365
# 6    United States  Digital payments penetration     84.40          5.2200
# 7          Estonia  Digital payments penetration     82.82          5.1410
# 8      Korea, Rep.  Digital payments penetration     82.64          5.1320
# 9           Canada  Digital payments penetration     81.53          5.0765
# 10       Australia  Digital payments penetration     79.37          4.9685
# 11  Czech Republic  Digital payments penetration     75.65          4.7825
# 12         Belgium  Digital payments penetration     73.15          4.6575
# 13         Germany  Digital payments penetration     71.20          4.5600
# 14          Poland  Digital payments penetration     70.34          4.5170
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True

# %% [markdown]
# ## 2. % of population with digital finance account - registered

# %%
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population with digital finance account - registered
# population_digital_financial_services

# %%
df.head(15)
# Out:
#     Year  ISO          Country Name  \
# 0   2011  AFG           Afghanistan
# 1   2014  AFG           Afghanistan
# 2   2017  AFG           Afghanistan
# 3   2011  AGO                Angola
# 4   2014  AGO                Angola
# 5   2011  ALB               Albania
# 6   2014  ALB               Albania
# 7   2017  ALB               Albania
# 8   2011  ARB            Arab world
# 9   2014  ARB            Arab world
# 10  2017  ARB            Arab world
# 11  2011  ARE  United Arab Emirates
# 12  2014  ARE  United Arab Emirates
# 13  2017  ARE  United Arab Emirates
# 14  2011  ARG             Argentina
#
#                                                Region         Income Group  \
# 0                                          South Asia           Low income
# 1                                          South Asia           Low income
# 2                                          South Asia           Low income
# 3          Sub-Saharan Africa (excluding high income)  Lower middle income
# 4          Sub-Saharan Africa (excluding high income)  Lower middle income
# 5       Europe & Central Asia (excluding high income)  Upper middle income
# 6       Europe & Central Asia (excluding high income)  Upper middle income
# 7       Europe & Central Asia (excluding high income)  Upper middle income
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11                                        High income          High income
# 12                                        High income          High income
# 13                                        High income          High income
# 14  Latin America & Caribbean (excluding high income)  Upper middle income
#
#    Account (% age 15+) Account, male (% age 15+)  \
# 0                   9%                       15%
# 1                  10%                       16%
# 2                  15%                       23%
# 3                  39%                       39%
# 4                  29%                       36%
# 5                  28%                       34%
# 6                  38%                       43%
# 7                  40%                       42%
# 8                  22%                       30%
# 9                  30%                       38%
# 10                 37%                       48%
# 11                 60%                       69%
# 12                 84%                       90%
# 13                 88%                       93%
# 14                 33%                       35%
#
#    Account, in labor force (% age 15+)   \
# 0                                   15%
# 1                                   15%
# 2                                   25%
# 3                                   46%
# 4                                   36%
# 5                                   36%
# 6                                   44%
# 7                                   53%
# 8                                   33%
# 9                                   42%
# 10                                  51%
# 11                                  80%
# 12                                  91%
# 13                                  93%
# 14                                  37%
#
#    Account, out of labor force (% age 15+)  Account, female (% age 15+)  ...  \
# 0                                        2%                          3%  ...
# 1                                        4%                          4%  ...
# 2                                        4%                          7%  ...
# 3                                       31%                         39%  ...
# 4                                       12%                         22%  ...
# 5                                       15%                         23%  ...
# 6                                       29%                         34%  ...
# 7                                       27%                         38%  ...
# 8                                       11%                         14%  ...
# 9                                       18%                         22%  ...
# 10                                      24%                         26%  ...
# 11                                      24%                         47%  ...
# 12                                      49%                         68%  ...
# 13                                      57%                         76%  ...
# 14                                      28%                         32%  ...
#
#    Mobile money account, female (% age 15+)   \
# 0                                        NaN
# 1                                         0%
# 2                                         1%
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                         2%
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       10%
# 13                                       18%
# 14                                       NaN
#
#    Mobile money account, young adults  (% age 15-24)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  6%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                10%
# 13                                                10%
# 14                                                NaN
#
#    Mobile money account, older adults (% age 25+)   \
# 0                                              NaN
# 1                                               0%
# 2                                               1%
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                               1%
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             12%
# 13                                             22%
# 14                                             NaN
#
#    Mobile money account, primary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  1%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                 9%
# 14                                                NaN
#
#    Mobile money account, secondary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  2%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                12%
# 13                                                22%
# 14                                                NaN
#
#    Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  0%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                16%
# 14                                                NaN
#
#    Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                 NaN
# 1                                                  1%
# 2                                                  1%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                15%
# 13                                                25%
# 14                                                NaN
#
#    Mobile money account, rural  (% age 15+)  data_country data_year
# 0                                        NaN          NaN       NaN
# 1                                         0%          NaN       NaN
# 2                                         1%          NaN       NaN
# 3                                        NaN          NaN       NaN
# 4                                        NaN          NaN       NaN
# 5                                        NaN          NaN       NaN
# 6                                        NaN          NaN       NaN
# 7                                         2%          NaN       NaN
# 8                                        NaN          NaN       NaN
# 9                                        NaN          NaN       NaN
# 10                                       NaN          NaN       NaN
# 11                                       NaN          NaN       NaN
# 12                                       16%          NaN       NaN
# 13                                       14%          NaN       NaN
# 14                                       NaN          NaN       NaN
#
# [15 rows x 783 columns]

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Account (% age 15+)'] = df['Account (% age 15+)'].str.replace('%','')
df['Account (% age 15+)'] = df['Account (% age 15+)'].astype(float)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Account (% age 15+)'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]
df
# Out:
#              Country Name                                          Indicator  \
# 2             Afghanistan  % of population with digital finance account -...
# 7                 Albania  % of population with digital finance account -...
# 10             Arab world  % of population with digital finance account -...
# 13   United Arab Emirates  % of population with digital finance account -...
# 16              Argentina  % of population with digital finance account -...
# ..                    ...                                                ...
# 479                 World  % of population with digital finance account -...
# 482                Kosovo  % of population with digital finance account -...
# 487          South Africa  % of population with digital finance account -...
# 490                Zambia  % of population with digital finance account -...
# 493              Zimbabwe  % of population with digital finance account -...
#
#      data_col  new_rank_score  higher_is_better
# 2        15.0        1.329670              True
# 7        40.0        2.703297              True
# 10       37.0        2.538462              True
# 13       88.0        5.340659              True
# 16       49.0        3.197802              True
# ..        ...             ...               ...
# 479      69.0        4.296703              True
# 482      52.0        3.362637              True
# 487      69.0        4.296703              True
# 490      46.0        3.032967              True
# 493      55.0        3.527473              True
#
# [166 rows x 5 columns]

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 3. % of population with digital finance account - active (90 days)

# %%
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population with digital finance account - active (90 days)
# population_digital_financial_services

# %%
df.head()
# Out:
#    Year  ISO Country Name                                      Region  \
# 0  2011  AFG  Afghanistan                                  South Asia
# 1  2014  AFG  Afghanistan                                  South Asia
# 2  2017  AFG  Afghanistan                                  South Asia
# 3  2011  AGO       Angola  Sub-Saharan Africa (excluding high income)
# 4  2014  AGO       Angola  Sub-Saharan Africa (excluding high income)
#
#           Income Group Account (% age 15+) Account, male (% age 15+)  \
# 0           Low income                  9%                       15%
# 1           Low income                 10%                       16%
# 2           Low income                 15%                       23%
# 3  Lower middle income                 39%                       39%
# 4  Lower middle income                 29%                       36%
#
#   Account, in labor force (% age 15+)   \
# 0                                  15%
# 1                                  15%
# 2                                  25%
# 3                                  46%
# 4                                  36%
#
#   Account, out of labor force (% age 15+)  Account, female (% age 15+)  ...  \
# 0                                       2%                          3%  ...
# 1                                       4%                          4%  ...
# 2                                       4%                          7%  ...
# 3                                      31%                         39%  ...
# 4                                      12%                         22%  ...
#
#   Mobile money account, female (% age 15+)   \
# 0                                       NaN
# 1                                        0%
# 2                                        1%
# 3                                       NaN
# 4                                       NaN
#
#   Mobile money account, young adults  (% age 15-24)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 0%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, older adults (% age 25+)   \
# 0                                             NaN
# 1                                              0%
# 2                                              1%
# 3                                             NaN
# 4                                             NaN
#
#   Mobile money account, primary education or less (% age 15+)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 0%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, secondary education or less (% age 15+)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 2%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 0%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                NaN
# 1                                                 1%
# 2                                                 1%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, rural  (% age 15+)  data_country data_year
# 0                                       NaN          NaN       NaN
# 1                                        0%          NaN       NaN
# 2                                        1%          NaN       NaN
# 3                                       NaN          NaN       NaN
# 4                                       NaN          NaN       NaN
#
# [5 rows x 783 columns]

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Made or received digital payments in the past year (% age 15+)'] = df['Made or received digital payments in the past year (% age 15+)'].str.replace('%','')
df['Made or received digital payments in the past year (% age 15+)'] = df['Made or received digital payments in the past year (% age 15+)'].astype(float)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Made or received digital payments in the past year (% age 15+)'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]
df
# Out:
#              Country Name                                          Indicator  \
# 2             Afghanistan  % of population with digital finance account -...
# 7                 Albania  % of population with digital finance account -...
# 10             Arab world  % of population with digital finance account -...
# 13   United Arab Emirates  % of population with digital finance account -...
# 16              Argentina  % of population with digital finance account -...
# ..                    ...                                                ...
# 479                 World  % of population with digital finance account -...
# 482                Kosovo  % of population with digital finance account -...
# 487          South Africa  % of population with digital finance account -...
# 490                Zambia  % of population with digital finance account -...
# 493              Zimbabwe  % of population with digital finance account -...
#
#      data_col  new_rank_score  higher_is_better
# 2        11.0        1.217391              True
# 7        29.0        2.195652              True
# 10       26.0        2.032609              True
# 13       84.0        5.184783              True
# 16       40.0        2.793478              True
# ..        ...             ...               ...
# 479      52.0        3.445652              True
# 482      39.0        2.739130              True
# 487      60.0        3.880435              True
# 490      39.0        2.739130              True
# 493      53.0        3.500000              True
#
# [166 rows x 5 columns]

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator))

# %% [markdown]
# ## 4. % of population with ID (Total)

# %%
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf), skiprows=[1,2,3,4,5,6])
# Out:
# % of population with ID (all)
# id4d_nid
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-47-6ee7e41d00c9> in <module>
#       4 print(bf)
#       5
# ----> 6 df = pd.read_csv('../../processed/{}.csv'.format(bf), skiprows=[2,3,4,5,6])
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2059     def read(self, nrows=None):
#    2060         try:
# -> 2061             data = self._reader.read(nrows)
#    2062         except StopIteration:
#    2063             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 26 fields in line 8, saw 43

# %%
df.head(15)
# Out:
#                                                                                                                              id  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548   5,349,909
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565            1,685
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303          28,727
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                  NaN
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020   6,134,411
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939              NaN
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760          23,908
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969            4,046
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0                  NaN
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0                  NaN
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494         95,085
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277             NaN
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                  NaN
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948  22,851,336
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850                401
#
#                                                                                                                         Economy  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548   5,144,700
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565            5,451
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303          27,576
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                  NaN
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020   6,157,438
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939              NaN
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760          28,874
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969            4,831
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0                  NaN
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0                  NaN
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494         76,527
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277             NaN
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                  NaN
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948  21,950,829
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850                416
#
#                                                                                                                      Country Code  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548          49.0
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565               72.0
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303              49.0
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                    NaN
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020          50.0
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939                NaN
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760              49.0
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969               54.0
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0                    NaN
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0                    NaN
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494             44.0
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277               NaN
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                    NaN
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948          49.0
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850                 49.0
#
#                                                                                                                         Region  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548  1,486,880
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565               0
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303      4,680,827
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0              42,117
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020  5,067,551
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939          22,404
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760              0
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969               0
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0           3,029,780
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0           1,032,598
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494     1,919,255
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277        120,633
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0              65,877
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948  8,414,271
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850                 0
#
#                                                                                                                      Income  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548       8
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565            0
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303          17
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0               63
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020      35
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939           30
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760           0
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969            0
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0               16
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0               14
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494         27
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277          40
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                4
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948       8
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850              0
#
#                                                                                                                           OECD  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548          0
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565               0
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303            NaN
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                 NaN
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020        NaN
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939             NaN
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760            NaN
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969             NaN
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0           1,609,169
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0             523,874
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494       808,087
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277            NaN
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0              41,790
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948        NaN
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850               NaN
#
#                                                                                                                     Lending category  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548        1,486,880
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565                     0
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303                  NaN
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                       NaN
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020              NaN
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939                   NaN
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760                  NaN
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969                   NaN
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0                 1,422,069
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0                   508,717
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494           1,111,166
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277                  NaN
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                    24,088
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948              NaN
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850                     NaN
#
#                                                                                                                      Other  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548  100.0
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565         0.0
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303        NaN
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0             NaN
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020    NaN
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939         NaN
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760        NaN
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969         NaN
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0            47.0
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0            49.0
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494      58.0
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277        NaN
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0            37.0
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948    NaN
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850           NaN
#
#                                                                                                                      GCC adjusted  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548          42.3
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565               98.6
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303              99.6
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                  100.0
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020          25.0
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939               90.0
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760              99.5
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969               98.7
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0                  100.0
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0                  100.0
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494             93.6
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277              75.0
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                   90.0
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948          20.2
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850                 98.7
#
#                                                                                                                     Inclusion Criteria  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548               42.7
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565                    99.4
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303                   99.6
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                           –
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020               24.8
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939                       –
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760                   99.6
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969                    98.9
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0                           –
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0                           –
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494                  93.4
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277                      –
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                           –
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948               20.3
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850                      98.8
#
#                                                                                                                      ...  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548  ...
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565       ...
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303      ...
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0           ...
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020  ...
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939       ...
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760      ...
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969       ...
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0           ...
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0           ...
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494     ...
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277      ...
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0           ...
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948  ...
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850         ...
#
#                                                                                                                      UPA Total  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548  7,296,096
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565       2,188,099
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303            NaN
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                 NaN
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020        NaN
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939             NaN
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760            NaN
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969             NaN
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0           8,269,334
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0           3,307,645
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494     2,613,303
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277            NaN
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0             549,804
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948        NaN
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850               NaN
#
#                                                                                                                         UPA Male  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548   36,373,176
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565         2,934,363
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303       42,008,054
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                80,209
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020   30,774,205
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939           103,050
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760       44,688,864
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969         2,934,152
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0            24,772,247
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0             8,751,820
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494       9,923,914
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277          399,285
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0             1,566,993
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948  166,368,149
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850             286,388
#
#                                                                                                                      UPA Female  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548  18,191,591
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565          540,349
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303      14,075,724
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0               13,580
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020  16,389,360
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939           29,388
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760      11,751,904
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969          689,894
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0            5,624,607
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0            1,318,229
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494      2,695,225
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277          97,109
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                    0
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948  56,110,211
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850             65,411
#
#                                                                                                                     % of UPA that is Female  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548               9,336,665
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565                      280,793
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303                   7,181,719
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                            6,971
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020               8,157,462
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939                       14,745
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760                   5,977,086
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969                      367,840
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0                        2,884,647
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0                          676,854
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494                  1,440,683
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277                      49,717
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                                0
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948              28,671,689
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850                         33,408
#
#                                                                                                                       UPB Total  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548   8,854,905
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565          259,561
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303       6,894,010
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                6,609
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020   8,231,869
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939           14,644
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760       5,774,773
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969          322,065
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0            2,739,917
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0              641,377
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494      1,254,544
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277          47,392
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                    0
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948  27,438,536
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850             32,004
#
#                                                                                                                     UPB in % of Population above Cut-off  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548                           18,181,585
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565                                 2,394,014
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303                               27,932,330
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                                        66,629
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020                           14,384,845
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939                                    73,662
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760                               32,936,960
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969                                 2,244,258
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0                                    19,147,640
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0                                     7,433,591
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494                               7,228,689
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277                                  302,176
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                                     1,566,993
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948                          110,257,938
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850                                     220,977
#
#                                                                                                                        UPB Male  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548   9,398,623
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565        1,199,481
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303      14,033,462
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0               34,060
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020   6,937,053
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939           34,732
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760      15,898,099
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969        1,012,449
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0            9,456,278
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0            3,617,222
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494      3,504,218
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277         145,810
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0              993,102
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948  55,189,006
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850            103,644
#
#                                                                                                                     UPB Female   \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548   8,782,976
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565        1,194,510
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303      13,898,865
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0               32,569
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020   7,447,820
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939           38,932
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760      17,038,900
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969        1,231,792
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0            9,691,403
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0            3,816,362
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494      3,724,469
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277         156,371
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0              573,892
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948  55,068,922
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850            117,324
#
#                                                                                                                     % of UPB that is Female  \
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548                     NaN
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565                          NaN
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303                         NaN
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0                              NaN
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020                     NaN
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939                          NaN
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760                         NaN
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969                          NaN
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0                              NaN
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0                              NaN
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494                        NaN
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277                         NaN
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0                              NaN
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948                     NaN
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850                            NaN
#
#                                                                                                                     BR Total
# 1  Afghanistan         AFG SAS LIC NaN  IDA  HIPC NaN INCLUDE 11,983,428 33 5,349,909 6,631,580 55.0  18 10,496,548      NaN
# 2  Albania             ALB ECS UMC NaN  IBRD NaN  NaN INCLUDE 7,565      0  1,685     5,451     72.0  16 7,565           NaN
# 3  Algeria             DZA MEA UMC NaN  IBRD NaN  NaN INCLUDE 4,737,130  11 NaN       NaN       NaN   18 56,303          NaN
# 4  Andorra             AND ECS HIC NaN  ..   NaN  NaN EXCLUDE 42,117     53 NaN       NaN       NaN   18 0               NaN
# 5  Angola              AGO SSF LMC NaN  IBRD NaN  NaN INCLUDE 17,359,571 56 NaN       NaN       NaN   18 12,292,020      NaN
# 6  Antigua and Barbuda ATG LCN HIC NaN  IBRD NaN  NaN INCLUDE 25,343     25 NaN       NaN       NaN   18 2,939           NaN
# 7  Argentina           ARG LCN UMC NaN  IBRD NaN  NaN INCLUDE 58,760     0  NaN       NaN       NaN   16 58,760          NaN
# 8  Armenia             ARM ECS LMC NaN  IBRD NaN  NaN INCLUDE 8,969      0  NaN       NaN       NaN   18 8,969           NaN
# 9  Australia           AUS EAS HIC OECD ..   NaN  NaN EXCLUDE 3,029,780  12 NaN       NaN       NaN   18 0               NaN
# 10 Austria             AUT ECS HIC OECD ..   EMU  NaN EXCLUDE 1,032,598  12 NaN       NaN       NaN   16 0               NaN
# 11 Azerbaijan          AZE ECS UMC NaN  IBRD NaN  NaN INCLUDE 2,091,749  21 903,172   1,187,693 57.0  18 172,494         NaN
# 12 Bahamas, The        BHS LCN HIC NaN  ..   NaN  NaN INCLUDE 144,910    36 NaN       NaN       NaN   18 24,277          NaN
# 13 Bahrain             BHR MEA HIC NaN  ..   NaN  NaN INCLUDE 65,877     4  NaN       NaN       NaN   0  0               NaN
# 14 Bangladesh          BGD SAS LMC NaN  IDA  NaN  NaN INCLUDE 53,190,219 32 NaN       NaN       NaN   18 44,775,948      NaN
# 15 Barbados            BRB LCN HIC NaN  ..   NaN  NaN INCLUDE 850        0  NaN       NaN       NaN   18 850             NaN
#
# [15 rows x 26 columns]

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
# Subtract the unregister proportion column by 100 and absolute the value
df['data_col'] = df['UP in % of Country Population'].sub(100).abs()
df ['Year'] = 2018
df['Country Name'] = df.iloc[:,1]


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]
df

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %%
## 5. % of population with ID (Female)

# %%
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['% of UP that is Female'] = df['% of UP that is Female'].replace('n/a',np.nan)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
# Subtract the unregister proportion column by 100 and absolute the value
df['data_col'] = df['% of UP that is Female'].sub(100).abs()
df ['Year'] = 2018
df['Country Name'] = df.iloc[:,1]


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]
df

# %%
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 6. can ID be used for transactions

# %%
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(20)

# %%
df['Digitized ID system']= df['Digitized ID system'].replace('-',np.nan)
df['Digitized ID system']= df['Digitized ID system'].astype(float)

# %%
df.head(15)

# %%
# create standard columns
df.rename(columns={'Economy':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Year'] = 2018
df['Indicator'] = indicator
df['data_col'] = df['Digitized ID system']
df.rename(columns={'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']]
df

# %%
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 7. Is personal data siloed

# %%
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Must limit the database to the first 206 rows, the remaining rows do not contain any useful information
df = df.iloc[0:205,:]

# Drop the superfluous rows by dropping na
df = df[df['#'].notna()]

# Must convert data in the DPL column into float
df['DPL'] = df['DPL'].astype(float, errors = 'ignore')

# %%
df.head(104)

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,205]
df['Country Name'] = df['Economy']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']]
df.head(15)

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 8. Open data index

# %%
bnames

# %%
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['score'] 
df['Country Name'] = df['name']
df['Year'] = 2016

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']]
df.head(15)

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ### Score Aggregating

# %%
import os

# %%
# get list of files in scores folder
scores = os.listdir('../indicator_scores/')
scores = [s for s in scores if s.startswith('foundations')]

# %%
scores

# %%
# create a dataframe that concatenates all these file into one table
df = pd.concat([pd.read_csv('../indicator_scores/{}'.format(s)) for s in scores])

# %%
df

# %%
# Data cleaning
df['new_rank_score'] = df['new_rank_score'].fillna(0)
df.sort_values(by=['Country Name'], ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.info()

# %%
df.head(15)

# %%
df.describe()

# %%
# checking country names
sorted(df['Country Name'].unique().tolist())

# %%
# remove trailing whitespaces from country name
df['Country Name'] = df['Country Name'].str.strip()

# %%
# checking country names
sorted(df['Country Name'].unique().tolist())

# %%
# average indicator scores per country
agg_df = df.groupby(['Country Name']).agg({'new_rank_score':'mean','data_col':'count'})

# %%
agg_df.columns = ['agg_score', 'count_source' ]

# %%
max_number_sources = agg_df.describe()['count_source']['max']

# %%
agg_df['agg_score_wt'] = agg_df['agg_score']*(agg_df['count_source']/max_number_sources)

# %%
agg_df.sort_values(by='agg_score', ascending=False, inplace=True)

# %%
agg_df.head(25)

# %%
agg_df.to_csv('../pillar_scores/foundation_scores_v0.csv')
