# %%
import pandas as pd
import numpy as np

# %%
### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Data Link','Index','Filename','Sub-Pillar']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#                                  Data Source  \
# 0  UN Statistics Division: List of Countries
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4   World Bank: World Development Indicators
#
#                            Data Link  Index            Filename  \
# 0             https://unstats.un.org  False           Countries
# 1                   https://gadm.org  False                 NaN
# 2                                NaN  False                 NaN
# 3                                NaN  False                 NaN
# 4  https://datacatalog.worldbank.org  False  population_density
#
#                 Sub-Pillar
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4  Connectivity Technology

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              18         27
# Foundations           13         22
# Government            10         15
# Infrastructure        47         58
# People                35         49
# Regulation             5          8
# Strategy               1          1

# %%
### Regulation

# %%
bnames = names[(names.check=='Regulation')&(~names.Filename.isna())]#&(names.Index==False)]
bnames.head(25)
# Out:
#                                             Indicator       check  \
# 78                               data protection laws  Regulation
# 79       Global Tables of Data Privacy Laws and Bills  Regulation
# 80  Data Protection and Privacy Legislation Worldwide  Regulation
# 84                   # key internet controls employed  Regulation
# 85                                  Rule of Law Index  Regulation
#
#                                           Data Source  \
# 78  UNCTAD: Data Protection and Privacy Legislatio...
# 79  UNCTAD: Data Protection and Privacy Legislatio...
# 80  UNCTAD: Data Protection and Privacy Legislatio...
# 84                  Freedom House: Freedom on the Net
# 85           World Justice Project: Rule of Law Index
#
#                                             Data Link  Index  \
# 78  https://unctad.org/page/data-protection-and-pr...  False
# 79  https://unctad.org/page/data-protection-and-pr...  False
# 80  https://unctad.org/page/data-protection-and-pr...  False
# 84        https://freedomhouse.org/report/freedom-net  False
# 85  https://worldjusticeproject.org/our-work/resea...  False
#
#                                  Filename                     Sub-Pillar
# 78       data_protect_privacy_legislation  Data standards and protection
# 79       data_protect_privacy_legislation  Data standards and protection
# 80       data_protect_privacy_legislation  Data standards and protection
# 84  number_key_internet_controls_employed                  Cybersecurity
# 85                                    rli              Ethical Standards

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()
subpillars = bnames['Sub-Pillar'].unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['data_protect_privacy_legislation',
#        'number_key_internet_controls_employed', 'rli'], dtype=object)

# %%
#list all subpillars

# %%
subpillars
# Out:
# array(['Data standards and protection', 'Cybersecurity',
#        'Ethical Standards'], dtype=object)

# %%
# formula for converting scale 0-100
def convert_rank(old_value, old_min=0, old_max=100, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %%
# formula for converting scale 0-1
def convert_rank_b(old_value, old_min=0, old_max=1, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %%
### 1. data protection laws

# %%
indicators[0]
subpillars[0]

# load data
indicator = indicators[0]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillar = subpillars[0]
print(subpillar)
# Out:
# data protection laws
# data_protect_privacy_legislation
# Data standards and protection

# %%
df.head(15)
# Out:
#                 Country               Type  \
# 0               Albania        Legislation
# 1               Algeria        Legislation
# 2               Andorra        Legislation
# 3                Angola        Legislation
# 4                Angola        Legislation
# 5   Antigua and Barbuda        Legislation
# 6             Argentina        Legislation
# 7               Armenia        Legislation
# 8             Australia        Legislation
# 9               Austria        Legislation
# 10              Austria        Legislation
# 11           Azerbaijan        Legislation
# 12              Bahamas        Legislation
# 13              Bahrain        Legislation
# 14             Barbados  Draft Legislation
#
#                Title of Legislation/Draft Legislation  \
# 0   Law No. 9887 on the Protection of Personal Dat...
# 1   Loi n° 18-07 du 10 juin 2018 relative à la pro...
# 2   Qualified law 15/2003 on personal data protect...
# 3   Lei No. 22/11 da Protecção de Dados Pessoais d...
# 4   Regulamento das Tecnologias e dos Serviços da ...
# 5               Data Protection Act 2013 (in English)
# 6   Ley 25.326 de Protección de los Datos Personal...
# 7   Law of the Republic of Armenia on the Protecti...
# 8                       Privacy Act 1988 (in English)
# 9   The General Data Protection Regulation (Regula...
# 10                 Datenschutzgesetz 2000 (in German)
# 11         Law on Personal Data 2010 (in Azerbaijani)
# 12  Data Protection (Privacy of Personal Informati...
# 13  Law on the Protection of Personal Data (in ara...
# 14  Bill - Data Protection passed in Senate and Ho...
#
#                                         Links to laws  data_country  data_year
# 0   https://www.idp.al/wp-content/uploads/2019/10/...           NaN        NaN
# 1      https://www.joradp.dz/Jo2000/2018/034/FP10.pdf           NaN        NaN
# 2   https://www.afapdp.org/wp-content/uploads/2018...           NaN        NaN
# 3   https://media2.mofo.com/documents/Law_22_11_Da...           NaN        NaN
# 4   https://www.inacom.gov.ao/fotos/frontend_6/edi...           NaN        NaN
# 5   http://laws.gov.ag/wp-content/uploads/2019/02/...           NaN        NaN
# 6   http://servicios.infoleg.gob.ar/infolegInterne...           NaN        NaN
# 7   http://www.foi.am/u_files/file/Personaldatapro...           NaN        NaN
# 8        http://www.comlaw.gov.au/Details/C2015C00089           NaN        NaN
# 9   https://eur-lex.europa.eu/legal-content/EN/TXT...           NaN        NaN
# 10  https://www.ris.bka.gv.at/GeltendeFassung.wxe?...           NaN        NaN
# 11              http://www.e-qanun.az/framework/19675           NaN        NaN
# 12  http://laws.bahamas.gov.bs/cms/images/LEGISLAT...           NaN        NaN
# 13  http://www.legalaffairs.gov.bh/AdvancedSearchD...           NaN        NaN
# 14  https://www.barbadosparliament.com/uploads/bil...           NaN        NaN

# %%
# Not numerical data

# %%
### 2. Global Tables of Data Privacy Laws and Bills

# %%
indicators[1]

# load data
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# Global Tables of Data Privacy Laws and Bills
# data_protect_privacy_legislation
# Data standards and protection

# %%
df.head(15)
# Out:
#                 Country               Type  \
# 0               Albania        Legislation
# 1               Algeria        Legislation
# 2               Andorra        Legislation
# 3                Angola        Legislation
# 4                Angola        Legislation
# 5   Antigua and Barbuda        Legislation
# 6             Argentina        Legislation
# 7               Armenia        Legislation
# 8             Australia        Legislation
# 9               Austria        Legislation
# 10              Austria        Legislation
# 11           Azerbaijan        Legislation
# 12              Bahamas        Legislation
# 13              Bahrain        Legislation
# 14             Barbados  Draft Legislation
#
#                Title of Legislation/Draft Legislation  \
# 0   Law No. 9887 on the Protection of Personal Dat...
# 1   Loi n° 18-07 du 10 juin 2018 relative à la pro...
# 2   Qualified law 15/2003 on personal data protect...
# 3   Lei No. 22/11 da Protecção de Dados Pessoais d...
# 4   Regulamento das Tecnologias e dos Serviços da ...
# 5               Data Protection Act 2013 (in English)
# 6   Ley 25.326 de Protección de los Datos Personal...
# 7   Law of the Republic of Armenia on the Protecti...
# 8                       Privacy Act 1988 (in English)
# 9   The General Data Protection Regulation (Regula...
# 10                 Datenschutzgesetz 2000 (in German)
# 11         Law on Personal Data 2010 (in Azerbaijani)
# 12  Data Protection (Privacy of Personal Informati...
# 13  Law on the Protection of Personal Data (in ara...
# 14  Bill - Data Protection passed in Senate and Ho...
#
#                                         Links to laws  data_country  data_year
# 0   https://www.idp.al/wp-content/uploads/2019/10/...           NaN        NaN
# 1      https://www.joradp.dz/Jo2000/2018/034/FP10.pdf           NaN        NaN
# 2   https://www.afapdp.org/wp-content/uploads/2018...           NaN        NaN
# 3   https://media2.mofo.com/documents/Law_22_11_Da...           NaN        NaN
# 4   https://www.inacom.gov.ao/fotos/frontend_6/edi...           NaN        NaN
# 5   http://laws.gov.ag/wp-content/uploads/2019/02/...           NaN        NaN
# 6   http://servicios.infoleg.gob.ar/infolegInterne...           NaN        NaN
# 7   http://www.foi.am/u_files/file/Personaldatapro...           NaN        NaN
# 8        http://www.comlaw.gov.au/Details/C2015C00089           NaN        NaN
# 9   https://eur-lex.europa.eu/legal-content/EN/TXT...           NaN        NaN
# 10  https://www.ris.bka.gv.at/GeltendeFassung.wxe?...           NaN        NaN
# 11              http://www.e-qanun.az/framework/19675           NaN        NaN
# 12  http://laws.bahamas.gov.bs/cms/images/LEGISLAT...           NaN        NaN
# 13  http://www.legalaffairs.gov.bh/AdvancedSearchD...           NaN        NaN
# 14  https://www.barbadosparliament.com/uploads/bil...           NaN        NaN

# %%
### 3. Global Tables of Data Privacy Laws and Bills

# %%
indicators[2]

# load data
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Data Protection and Privacy Legislation Worldwide
# data_protect_privacy_legislation

# %%
df.head(15)
# Out:
#                 Country               Type  \
# 0               Albania        Legislation
# 1               Algeria        Legislation
# 2               Andorra        Legislation
# 3                Angola        Legislation
# 4                Angola        Legislation
# 5   Antigua and Barbuda        Legislation
# 6             Argentina        Legislation
# 7               Armenia        Legislation
# 8             Australia        Legislation
# 9               Austria        Legislation
# 10              Austria        Legislation
# 11           Azerbaijan        Legislation
# 12              Bahamas        Legislation
# 13              Bahrain        Legislation
# 14             Barbados  Draft Legislation
#
#                Title of Legislation/Draft Legislation  \
# 0   Law No. 9887 on the Protection of Personal Dat...
# 1   Loi n° 18-07 du 10 juin 2018 relative à la pro...
# 2   Qualified law 15/2003 on personal data protect...
# 3   Lei No. 22/11 da Protecção de Dados Pessoais d...
# 4   Regulamento das Tecnologias e dos Serviços da ...
# 5               Data Protection Act 2013 (in English)
# 6   Ley 25.326 de Protección de los Datos Personal...
# 7   Law of the Republic of Armenia on the Protecti...
# 8                       Privacy Act 1988 (in English)
# 9   The General Data Protection Regulation (Regula...
# 10                 Datenschutzgesetz 2000 (in German)
# 11         Law on Personal Data 2010 (in Azerbaijani)
# 12  Data Protection (Privacy of Personal Informati...
# 13  Law on the Protection of Personal Data (in ara...
# 14  Bill - Data Protection passed in Senate and Ho...
#
#                                         Links to laws  data_country  data_year
# 0   https://www.idp.al/wp-content/uploads/2019/10/...           NaN        NaN
# 1      https://www.joradp.dz/Jo2000/2018/034/FP10.pdf           NaN        NaN
# 2   https://www.afapdp.org/wp-content/uploads/2018...           NaN        NaN
# 3   https://media2.mofo.com/documents/Law_22_11_Da...           NaN        NaN
# 4   https://www.inacom.gov.ao/fotos/frontend_6/edi...           NaN        NaN
# 5   http://laws.gov.ag/wp-content/uploads/2019/02/...           NaN        NaN
# 6   http://servicios.infoleg.gob.ar/infolegInterne...           NaN        NaN
# 7   http://www.foi.am/u_files/file/Personaldatapro...           NaN        NaN
# 8        http://www.comlaw.gov.au/Details/C2015C00089           NaN        NaN
# 9   https://eur-lex.europa.eu/legal-content/EN/TXT...           NaN        NaN
# 10  https://www.ris.bka.gv.at/GeltendeFassung.wxe?...           NaN        NaN
# 11              http://www.e-qanun.az/framework/19675           NaN        NaN
# 12  http://laws.bahamas.gov.bs/cms/images/LEGISLAT...           NaN        NaN
# 13  http://www.legalaffairs.gov.bh/AdvancedSearchD...           NaN        NaN
# 14  https://www.barbadosparliament.com/uploads/bil...           NaN        NaN

# %%
### 4. # key internet controls employed

# %%
indicators[3]

# load data
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
df = df.iloc[0:70,:]

subpillars[1]
subpillar = subpillars[1]
print(subpillar)
# Out:
# # key internet controls employed
# number_key_internet_controls_employed
# Cybersecurity

# %%
df
# Out:
#        COUNTRY  # Key Internet Controls employed  \
# 0       Angola                               2.0
# 1    Argentina                               1.0
# 2      Armenia                               6.0
# 3    Australia                               1.0
# 4   Azerbaijan                               8.0
# ..         ...                               ...
# 65  Uzbekistan                               9.0
# 66   Venezuela                               6.0
# 67     Vietnam                               5.0
# 68      Zambia                               4.0
# 69    Zimbabwe                               4.0
#
#    Social media or communications platforms blocked  \
# 0                                               NaN
# 1                                               NaN
# 2                                                 X
# 3                                               NaN
# 4                                                 X
# ..                                              ...
# 65                                                X
# 66                                                X
# 67                                              NaN
# 68                                                *
# 69                                              NaN
#
#    Political, social, or religious content blocked  \
# 0                                              NaN
# 1                                              NaN
# 2                                                X
# 3                                              NaN
# 4                                                X
# ..                                             ...
# 65                                               X
# 66                                               X
# 67                                               X
# 68                                             NaN
# 69                                             NaN
#
#    ICT networks deliberately disrupted  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                    X
# ..                                 ...
# 65                                   X
# 66                                 NaN
# 67                                 NaN
# 68                                 NaN
# 69                                   X
#
#    Progovernment commentators manipualte online discussions  \
# 0                                                 NaN
# 1                                                   X
# 2                                                   X
# 3                                                 NaN
# 4                                                   X
# ..                                                ...
# 65                                                  X
# 66                                                  X
# 67                                                  X
# 68                                                  X
# 69                                                  X
#
#    New law or directive increasing censorship or punisment passed  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                   X
# 3                                                   X
# 4                                                   X
# ..                                                ...
# 65                                                  X
# 66                                                NaN
# 67                                                  *
# 68                                                  X
# 69                                                NaN
#
#    New law or directive increasing surveillance or restricting anonymity passed  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 65                                                  X
# 66                                                NaN
# 67                                                NaN
# 68                                                  X
# 69                                                NaN
#
#    Blogger or ICT user arrested, imprisoned, or in prolonged detention for political or social content  \
# 0                                                   X
# 1                                                 NaN
# 2                                                   X
# 3                                                 NaN
# 4                                                   X
# ..                                                ...
# 65                                                  X
# 66                                                  X
# 67                                                  X
# 68                                                  X
# 69                                                  X
#
#    Blogger or ICT user physically attacked or killed (including in custody)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                   X
# ..                                                ...
# 65                                                  X
# 66                                                  X
# 67                                                  X
# 68                                                NaN
# 69                                                  X
#
#    Technical attacks against government critics or human rights organizations  \
# 0                                                   X
# 1                                                 NaN
# 2                                                   X
# 3                                                 NaN
# 4                                                   X
# ..                                                ...
# 65                                                  X
# 66                                                  X
# 67                                                  X
# 68                                                NaN
# 69                                                NaN
#
#     FOTN 2021 score FOTN 2021 Status  Unnamed: 13  data_country  data_year
# 0              62.0      Partly Free          NaN           NaN        NaN
# 1              71.0             Free          NaN           NaN        NaN
# 2              71.0             Free          NaN           NaN        NaN
# 3              75.0             Free          NaN           NaN        NaN
# 4              35.0         Not Free          NaN           NaN        NaN
# ..              ...              ...          ...           ...        ...
# 65             28.0         Not Free          NaN           NaN        NaN
# 66             28.0         Not Free          NaN           NaN        NaN
# 67             22.0         Not Free          NaN           NaN        NaN
# 68             59.0      Partly Free          NaN           NaN        NaN
# 69             46.0      Partly Free          NaN           NaN        NaN
#
# [70 rows x 16 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2020
df['Indicator'] = indicator
df['data_col'] = df['FOTN 2021 score']
df['Country Name'] = df['COUNTRY']
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=0,old_max=100))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df.head(15)
# Out:
#    Country Name  Year                         Indicator  data_col  \
# 0        Angola  2020  # key internet controls employed      62.0
# 1     Argentina  2020  # key internet controls employed      71.0
# 2       Armenia  2020  # key internet controls employed      71.0
# 3     Australia  2020  # key internet controls employed      75.0
# 4    Azerbaijan  2020  # key internet controls employed      35.0
# 5       Bahrain  2020  # key internet controls employed      30.0
# 6    Bangladesh  2020  # key internet controls employed      40.0
# 7       Belarus  2020  # key internet controls employed      31.0
# 8        Brazil  2020  # key internet controls employed      64.0
# 9      Cambodia  2020  # key internet controls employed      43.0
# 10       Canada  2020  # key internet controls employed      87.0
# 11        China  2020  # key internet controls employed      10.0
# 12     Colombia  2020  # key internet controls employed      65.0
# 13   Costa Rica  2020  # key internet controls employed      87.0
# 14         Cuba  2020  # key internet controls employed      21.0
#
#     new_rank_score  higher_is_better     Sub-Pillar
# 0             4.10              True  Cybersecurity
# 1             4.55              True  Cybersecurity
# 2             4.55              True  Cybersecurity
# 3             4.75              True  Cybersecurity
# 4             2.75              True  Cybersecurity
# 5             2.50              True  Cybersecurity
# 6             3.00              True  Cybersecurity
# 7             2.55              True  Cybersecurity
# 8             4.20              True  Cybersecurity
# 9             3.15              True  Cybersecurity
# 10            5.35              True  Cybersecurity
# 11            1.50              True  Cybersecurity
# 12            4.25              True  Cybersecurity
# 13            5.35              True  Cybersecurity
# 14            2.05              True  Cybersecurity

# %%
df.to_csv('../indicator_scores/regulation_{}_scores.csv'.format(indicator), index=False)

# %%
### 5. Rule of Law Index

# %%
indicators[4]

# load data
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[2]
subpillar = subpillars[2]
print(subpillar)
# Out:
# Rule of Law Index
# rli
# Ethical Standards

# %%
df.head(15)
# Out:
#                 Country Country Code                         Region  \
# 0           Afghanistan          AFG                     South Asia
# 1               Albania          ALB  Eastern Europe & Central Asia
# 2               Algeria          DZA     Middle East & North Africa
# 3                Angola          AGO             Sub-Saharan Africa
# 4   Antigua and Barbuda          ATG      Latin America & Caribbean
# 5             Argentina          ARG      Latin America & Caribbean
# 6             Australia          AUS            East Asia & Pacific
# 7               Austria          AUT      EU + EFTA + North America
# 8           The Bahamas          BHS      Latin America & Caribbean
# 9            Bangladesh          BGD                     South Asia
# 10             Barbados          BRB      Latin America & Caribbean
# 11              Belarus          BLR  Eastern Europe & Central Asia
# 12              Belgium          BEL      EU + EFTA + North America
# 13               Belize          BLZ      Latin America & Caribbean
# 14                Benin          BEN             Sub-Saharan Africa
#
#     Income Group  WJP Rule of Law Index: Overall Score  \
# 0            Low                                  0.36
# 1   Upper middle                                  0.50
# 2   Upper middle                                  0.49
# 3   Lower middle                                  0.43
# 4           High                                  0.63
# 5   Upper middle                                  0.58
# 6           High                                  0.80
# 7           High                                  0.82
# 8           High                                  0.61
# 9   Lower middle                                  0.41
# 10          High                                  0.65
# 11  Upper middle                                  0.51
# 12          High                                  0.79
# 13  Upper middle                                  0.48
# 14           Low                                  0.50
#
#     Factor 1: Constraints on Government Powers  \
# 0                                         0.44
# 1                                         0.45
# 2                                         0.48
# 3                                         0.42
# 4                                         0.62
# 5                                         0.61
# 6                                         0.82
# 7                                         0.85
# 8                                         0.61
# 9                                         0.40
# 10                                        0.63
# 11                                        0.36
# 12                                        0.83
# 13                                        0.44
# 14                                        0.53
#
#     1.1 Government powers are effectively limited by the legislature  \
# 0                                                0.59
# 1                                                0.48
# 2                                                0.51
# 3                                                0.52
# 4                                                0.61
# 5                                                0.65
# 6                                                0.86
# 7                                                0.84
# 8                                                0.57
# 9                                                0.54
# 10                                               0.70
# 11                                               0.27
# 12                                               0.83
# 13                                               0.50
# 14                                               0.54
#
#     1.2 Government powers are effectively limited by the judiciary  \
# 0                                                0.35
# 1                                                0.30
# 2                                                0.43
# 3                                                0.40
# 4                                                0.71
# 5                                                0.46
# 6                                                0.84
# 7                                                0.84
# 8                                                0.62
# 9                                                0.48
# 10                                               0.71
# 11                                               0.28
# 12                                               0.78
# 13                                               0.51
# 14                                               0.45
#
#     1.3 Government powers are effectively limited by independent auditing and review  \
# 0                                                0.45
# 1                                                0.55
# 2                                                0.60
# 3                                                0.37
# 4                                                0.59
# 5                                                0.70
# 6                                                0.77
# 7                                                0.78
# 8                                                0.52
# 9                                                0.37
# 10                                               0.43
# 11                                               0.50
# 12                                               0.90
# 13                                               0.26
# 14                                               0.42
#
#     1.4 Government officials are sanctioned for misconduct  ...  \
# 0                                                0.32       ...
# 1                                                0.39       ...
# 2                                                0.50       ...
# 3                                                0.34       ...
# 4                                                0.46       ...
# 5                                                0.39       ...
# 6                                                0.77       ...
# 7                                                0.83       ...
# 8                                                0.44       ...
# 9                                                0.37       ...
# 10                                               0.42       ...
# 11                                               0.54       ...
# 12                                               0.75       ...
# 13                                               0.24       ...
# 14                                               0.49       ...
#
#     Factor 8: Criminal Justice  \
# 0                         0.31
# 1                         0.43
# 2                         0.43
# 3                         0.36
# 4                         0.56
# 5                         0.44
# 6                         0.73
# 7                         0.80
# 8                         0.61
# 9                         0.33
# 10                        0.57
# 11                        0.47
# 12                        0.71
# 13                        0.36
# 14                        0.43
#
#     8.1 Criminal investigation system is effective  \
# 0                                             0.31
# 1                                             0.43
# 2                                             0.29
# 3                                             0.36
# 4                                             0.50
# 5                                             0.27
# 6                                             0.66
# 7                                             0.65
# 8                                             0.50
# 9                                             0.41
# 10                                            0.51
# 11                                            0.53
# 12                                            0.58
# 13                                            0.33
# 14                                            0.37
#
#     8.2 Criminal adjudication system is timely and effective  \
# 0                                                0.41
# 1                                                0.41
# 2                                                0.44
# 3                                                0.38
# 4                                                0.56
# 5                                                0.41
# 6                                                0.71
# 7                                                0.81
# 8                                                0.55
# 9                                                0.45
# 10                                               0.43
# 11                                               0.60
# 12                                               0.67
# 13                                               0.35
# 14                                               0.38
#
#     8.3 Correctional system is effective in reducing criminal behavior  \
# 0                                                0.32
# 1                                                0.41
# 2                                                0.47
# 3                                                0.25
# 4                                                0.52
# 5                                                0.35
# 6                                                0.62
# 7                                                0.81
# 8                                                0.46
# 9                                                0.35
# 10                                               0.56
# 11                                               0.43
# 12                                               0.54
# 13                                               0.20
# 14                                               0.31
#
#     8.4 Criminal system is impartial  \
# 0                               0.21
# 1                               0.55
# 2                               0.62
# 3                               0.37
# 4                               0.49
# 5                               0.54
# 6                               0.58
# 7                               0.70
# 8                               0.59
# 9                               0.23
# 10                              0.43
# 11                              0.61
# 12                              0.68
# 13                              0.38
# 14                              0.73
#
#     8.5 Criminal system is free of corruption  \
# 0                                        0.26
# 1                                        0.33
# 2                                        0.44
# 3                                        0.49
# 4                                        0.68
# 5                                        0.48
# 6                                        0.85
# 7                                        0.88
# 8                                        0.78
# 9                                        0.35
# 10                                       0.77
# 11                                       0.56
# 12                                       0.83
# 13                                       0.48
# 14                                       0.42
#
#     8.6 Criminal system is free of improper government influence  \
# 0                                                0.30
# 1                                                0.33
# 2                                                0.24
# 3                                                0.34
# 4                                                0.57
# 5                                                0.43
# 6                                                0.92
# 7                                                0.92
# 8                                                0.86
# 9                                                0.26
# 10                                               0.76
# 11                                               0.13
# 12                                               0.86
# 13                                               0.41
# 14                                               0.32
#
#     8.7. Due process of the law and rights of the accused  data_country  \
# 0                                                0.33               NaN
# 1                                                0.53               NaN
# 2                                                0.54               NaN
# 3                                                0.33               NaN
# 4                                                0.60               NaN
# 5                                                0.57               NaN
# 6                                                0.77               NaN
# 7                                                0.83               NaN
# 8                                                0.56               NaN
# 9                                                0.28               NaN
# 10                                               0.57               NaN
# 11                                               0.43               NaN
# 12                                               0.79               NaN
# 13                                               0.38               NaN
# 14                                               0.49               NaN
#
#     data_year
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
#
# [15 rows x 59 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2020
df['Indicator'] = indicator
df['data_col'] = df['WJP Rule of Law Index: Overall Score']
df['Country Name'] = df['Country']
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank_b(row,old_min=0,old_max=1))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#             Country Name  Year          Indicator  data_col  new_rank_score  \
# 0            Afghanistan  2020  Rule of Law Index      0.36            2.80
# 1                Albania  2020  Rule of Law Index      0.50            3.50
# 2                Algeria  2020  Rule of Law Index      0.49            3.45
# 3                 Angola  2020  Rule of Law Index      0.43            3.15
# 4    Antigua and Barbuda  2020  Rule of Law Index      0.63            4.15
# ..                   ...   ...                ...       ...             ...
# 123           Uzbekistan  2020  Rule of Law Index      0.47            3.35
# 124        Venezuela, RB  2020  Rule of Law Index      0.27            2.35
# 125              Vietnam  2020  Rule of Law Index      0.49            3.45
# 126               Zambia  2020  Rule of Law Index      0.45            3.25
# 127             Zimbabwe  2020  Rule of Law Index      0.39            2.95
#
#      higher_is_better         Sub-Pillar
# 0                True  Ethical Standards
# 1                True  Ethical Standards
# 2                True  Ethical Standards
# 3                True  Ethical Standards
# 4                True  Ethical Standards
# ..                ...                ...
# 123              True  Ethical Standards
# 124              True  Ethical Standards
# 125              True  Ethical Standards
# 126              True  Ethical Standards
# 127              True  Ethical Standards
#
# [128 rows x 7 columns]

# %%
df.to_csv('../indicator_scores/regulation_{}_scores.csv'.format(indicator), index=False)

# %%
### Score Aggregating

# %%
import os

# %%
# get list of files in scores folder
scores = os.listdir('../indicator_scores/')
scores = [s for s in scores if s.startswith('regulation')]

# %%
scores
# Out:
# ['regulation_# key internet controls employed_scores.csv',
#  'regulation_Rule of Law Index_scores.csv']

# %%
# create a dataframe that concatenates all these file into one table
df = pd.concat([pd.read_csv('../indicator_scores/{}'.format(s)) for s in scores])

# %%
df
# Out:
#       Country Name  Year                         Indicator  data_col  \
# 0           Angola  2020  # key internet controls employed     62.00
# 1        Argentina  2020  # key internet controls employed     71.00
# 2          Armenia  2020  # key internet controls employed     71.00
# 3        Australia  2020  # key internet controls employed     75.00
# 4       Azerbaijan  2020  # key internet controls employed     35.00
# ..             ...   ...                               ...       ...
# 123     Uzbekistan  2020                 Rule of Law Index      0.47
# 124  Venezuela, RB  2020                 Rule of Law Index      0.27
# 125        Vietnam  2020                 Rule of Law Index      0.49
# 126         Zambia  2020                 Rule of Law Index      0.45
# 127       Zimbabwe  2020                 Rule of Law Index      0.39
#
#      new_rank_score  higher_is_better         Sub-Pillar
# 0              4.10              True      Cybersecurity
# 1              4.55              True      Cybersecurity
# 2              4.55              True      Cybersecurity
# 3              4.75              True      Cybersecurity
# 4              2.75              True      Cybersecurity
# ..              ...               ...                ...
# 123            3.35              True  Ethical Standards
# 124            2.35              True  Ethical Standards
# 125            3.45              True  Ethical Standards
# 126            3.25              True  Ethical Standards
# 127            2.95              True  Ethical Standards
#
# [198 rows x 7 columns]

# %%
# Data cleaning
df['new_rank_score'] = df['new_rank_score'].fillna(0)
df.sort_values(by=['Country Name'], ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# remove trailing whitespaces from country name
df['Country Name'] = df['Country Name'].str.strip()
df['Country Name'] = df['Country Name'].str.strip('**')
df['Country Name'] = df['Country Name'].str.strip('*')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country Name      198 non-null    object
#  1   Year              198 non-null    int64
#  2   Indicator         198 non-null    object
#  3   data_col          198 non-null    float64
#  4   new_rank_score    198 non-null    float64
#  5   higher_is_better  198 non-null    bool
#  6   Sub-Pillar        198 non-null    object
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 9.6+ KB

# %%
df.head(15)
# Out:
#            Country Name  Year                         Indicator  data_col  \
# 0           Afghanistan  2020                 Rule of Law Index      0.36
# 1               Albania  2020                 Rule of Law Index      0.50
# 2               Algeria  2020                 Rule of Law Index      0.49
# 3                Angola  2020                 Rule of Law Index      0.43
# 4                Angola  2020  # key internet controls employed     62.00
# 5   Antigua and Barbuda  2020                 Rule of Law Index      0.63
# 6             Argentina  2020  # key internet controls employed     71.00
# 7             Argentina  2020                 Rule of Law Index      0.58
# 8               Armenia  2020  # key internet controls employed     71.00
# 9             Australia  2020  # key internet controls employed     75.00
# 10            Australia  2020                 Rule of Law Index      0.80
# 11              Austria  2020                 Rule of Law Index      0.82
# 12           Azerbaijan  2020  # key internet controls employed     35.00
# 13              Bahrain  2020  # key internet controls employed     30.00
# 14           Bangladesh  2020                 Rule of Law Index      0.41
#
#     new_rank_score  higher_is_better         Sub-Pillar
# 0             2.80              True  Ethical Standards
# 1             3.50              True  Ethical Standards
# 2             3.45              True  Ethical Standards
# 3             3.15              True  Ethical Standards
# 4             4.10              True      Cybersecurity
# 5             4.15              True  Ethical Standards
# 6             4.55              True      Cybersecurity
# 7             3.90              True  Ethical Standards
# 8             4.55              True      Cybersecurity
# 9             4.75              True      Cybersecurity
# 10            5.00              True  Ethical Standards
# 11            5.10              True  Ethical Standards
# 12            2.75              True      Cybersecurity
# 13            2.50              True      Cybersecurity
# 14            3.05              True  Ethical Standards

# %%
df.describe()
# Out:
#          Year    data_col  new_rank_score
# count   198.0  198.000000      198.000000
# mean   2020.0   19.016465        3.732323
# std       0.0   27.883384        0.831420
# min    2020.0    0.270000        1.500000
# 25%    2020.0    0.500000        3.250000
# 50%    2020.0    0.650000        3.600000
# 75%    2020.0   37.500000        4.250000
# max    2020.0   96.000000        5.800000

# %%
# remove trailing whitespaces from country name
df['Country Name'] = df['Country Name'].str.strip()

# %%
# average indicator scores per country
agg_df = df.groupby(['Country Name']).agg({'new_rank_score':'mean','data_col':'count'})

# %%
agg_df.columns = ['agg_score', 'count_source' ]

# %%
max_number_sources = agg_df.describe()['count_source']['max']

# %%
agg_df['agg_score_wt'] = agg_df['agg_score']*(agg_df['count_source']/max_number_sources)

# %%
agg_df.sort_values(by='agg_score', ascending=False, inplace=True)

# %%
agg_df.head(25)
# Out:
#                       agg_score  count_source  agg_score_wt
# Country Name
# Iceland                   5.800             1         2.900
# Denmark                   5.500             1         2.750
# Norway                    5.450             1         2.725
# Estonia                   5.375             2         5.375
# Finland                   5.350             1         2.675
# Sweden                    5.300             1         2.650
# Canada                    5.200             2         5.200
# Netherlands               5.200             1         2.600
# New Zealand               5.150             1         2.575
# Austria                   5.100             1         2.550
# Germany                   5.075             2         5.075
# Taiwan                    5.000             1         2.500
# Belgium                   4.950             1         2.475
# United Kingdom            4.925             2         4.925
# Australia                 4.875             2         4.875
# Costa Rica                4.875             2         4.875
# Japan                     4.850             2         4.850
# Hong Kong SAR, China      4.800             1         2.400
# France                    4.775             2         4.775
# United States             4.675             2         4.675
# Spain                     4.650             1         2.325
# Republic of Korea         4.650             1         2.325
# Czech Republic            4.650             1         2.325
# Italy                     4.550             2         4.550
# Armenia                   4.550             1         2.275

# %%
agg_df.to_csv('../pillar_scores/regulation_scores_v0.csv')

# %%
### Score Aggregating by Subpillars

# %%
df.insert(0,'Pillar','Regulation')
df
# Out:
#          Pillar Country Name  Year                         Indicator  \
# 0    Regulation  Afghanistan  2020                 Rule of Law Index
# 1    Regulation      Albania  2020                 Rule of Law Index
# 2    Regulation      Algeria  2020                 Rule of Law Index
# 3    Regulation       Angola  2020                 Rule of Law Index
# 4    Regulation       Angola  2020  # key internet controls employed
# ..          ...          ...   ...                               ...
# 193  Regulation      Vietnam  2020                 Rule of Law Index
# 194  Regulation       Zambia  2020                 Rule of Law Index
# 195  Regulation       Zambia  2020  # key internet controls employed
# 196  Regulation     Zimbabwe  2020  # key internet controls employed
# 197  Regulation     Zimbabwe  2020                 Rule of Law Index
#
#      data_col  new_rank_score  higher_is_better         Sub-Pillar
# 0        0.36            2.80              True  Ethical Standards
# 1        0.50            3.50              True  Ethical Standards
# 2        0.49            3.45              True  Ethical Standards
# 3        0.43            3.15              True  Ethical Standards
# 4       62.00            4.10              True      Cybersecurity
# ..        ...             ...               ...                ...
# 193      0.49            3.45              True  Ethical Standards
# 194      0.45            3.25              True  Ethical Standards
# 195     59.00            3.95              True      Cybersecurity
# 196     46.00            3.30              True      Cybersecurity
# 197      0.39            2.95              True  Ethical Standards
#
# [198 rows x 8 columns]

# %%
sub_df = df.groupby(['Pillar','Sub-Pillar','Country Name']).agg({'new_rank_score':'mean','data_col':'count'})

# %%
sub_df.columns = ['agg_score', 'count_source' ]

# %%
max_number_sources = sub_df.describe()['count_source']['max']

# %%
sub_df['agg_score_wt'] = sub_df['agg_score']*(sub_df['count_source']/max_number_sources)

# %%
sub_df.to_csv('../subpillar_score/regulation_scores_subpillar_v0.csv')

# %% [markdown]
# ### Sources Generation

# %%
#Get all countries from Countries.xlsx
countries = pd.read_excel('../../data/Countries.xlsx')
col_names = ['Country or Area']
countries = countries[col_names]
countries.rename(columns = {'Country or Area': 'Country Name'}, inplace = True)

# %%
#Get all indicators from names dataframe retrieve at the begining of the script
bnames=bnames[['check','Sub-Pillar','Indicator','Data Source','Data Link']]
bnames.rename(columns = {'check': 'Pillar'}, inplace = True)

# %%
#Do a nice cross join so that we have combination of all countries vs all indicators
sources = countries.merge(bnames, how='cross')
sources
# Out:
#                    Country Name      Pillar                     Sub-Pillar  \
# 0                       Algeria  Regulation  Data standards and protection
# 1                       Algeria  Regulation  Data standards and protection
# 2                       Algeria  Regulation  Data standards and protection
# 3                       Algeria  Regulation                  Cybersecurity
# 4                       Algeria  Regulation              Ethical Standards
# ...                         ...         ...                            ...
# 1240  Wallis and Futuna Islands  Regulation  Data standards and protection
# 1241  Wallis and Futuna Islands  Regulation  Data standards and protection
# 1242  Wallis and Futuna Islands  Regulation  Data standards and protection
# 1243  Wallis and Futuna Islands  Regulation                  Cybersecurity
# 1244  Wallis and Futuna Islands  Regulation              Ethical Standards
#
#                                               Indicator  \
# 0                                  data protection laws
# 1          Global Tables of Data Privacy Laws and Bills
# 2     Data Protection and Privacy Legislation Worldwide
# 3                      # key internet controls employed
# 4                                     Rule of Law Index
# ...                                                 ...
# 1240                               data protection laws
# 1241       Global Tables of Data Privacy Laws and Bills
# 1242  Data Protection and Privacy Legislation Worldwide
# 1243                   # key internet controls employed
# 1244                                  Rule of Law Index
#
#                                             Data Source  \
# 0     UNCTAD: Data Protection and Privacy Legislatio...
# 1     UNCTAD: Data Protection and Privacy Legislatio...
# 2     UNCTAD: Data Protection and Privacy Legislatio...
# 3                     Freedom House: Freedom on the Net
# 4              World Justice Project: Rule of Law Index
# ...                                                 ...
# 1240  UNCTAD: Data Protection and Privacy Legislatio...
# 1241  UNCTAD: Data Protection and Privacy Legislatio...
# 1242  UNCTAD: Data Protection and Privacy Legislatio...
# 1243                  Freedom House: Freedom on the Net
# 1244           World Justice Project: Rule of Law Index
#
#                                               Data Link
# 0     https://unctad.org/page/data-protection-and-pr...
# 1     https://unctad.org/page/data-protection-and-pr...
# 2     https://unctad.org/page/data-protection-and-pr...
# 3           https://freedomhouse.org/report/freedom-net
# 4     https://worldjusticeproject.org/our-work/resea...
# ...                                                 ...
# 1240  https://unctad.org/page/data-protection-and-pr...
# 1241  https://unctad.org/page/data-protection-and-pr...
# 1242  https://unctad.org/page/data-protection-and-pr...
# 1243        https://freedomhouse.org/report/freedom-net
# 1244  https://worldjusticeproject.org/our-work/resea...
#
# [1245 rows x 6 columns]

# %%
#Make copy of a scores dataframe and add the column available, with value of 1 (string)
#denoting all the country/indicator combinations that have value
dfsources = df[['Country Name','Pillar','Sub-Pillar','Indicator']].copy()
dfsources['Available'] = '1'

# %%
#Merge (left join) sources (all country indicator combinations)
#with those in copied scores dataframe
#resulting in a sources dataframe with values of 1 in Available column where there is a value for country/indicator
#and there is a NaN where there's not. 
#subsequently replace NaN with 0 (string)
sources = sources.merge(dfsources, how='left', on=['Country Name','Pillar','Sub-Pillar','Indicator'])
sources['Available'] = sources['Available'].fillna('0')
sources
# Out:
#                    Country Name      Pillar                     Sub-Pillar  \
# 0                       Algeria  Regulation  Data standards and protection
# 1                       Algeria  Regulation  Data standards and protection
# 2                       Algeria  Regulation  Data standards and protection
# 3                       Algeria  Regulation                  Cybersecurity
# 4                       Algeria  Regulation              Ethical Standards
# ...                         ...         ...                            ...
# 1240  Wallis and Futuna Islands  Regulation  Data standards and protection
# 1241  Wallis and Futuna Islands  Regulation  Data standards and protection
# 1242  Wallis and Futuna Islands  Regulation  Data standards and protection
# 1243  Wallis and Futuna Islands  Regulation                  Cybersecurity
# 1244  Wallis and Futuna Islands  Regulation              Ethical Standards
#
#                                               Indicator  \
# 0                                  data protection laws
# 1          Global Tables of Data Privacy Laws and Bills
# 2     Data Protection and Privacy Legislation Worldwide
# 3                      # key internet controls employed
# 4                                     Rule of Law Index
# ...                                                 ...
# 1240                               data protection laws
# 1241       Global Tables of Data Privacy Laws and Bills
# 1242  Data Protection and Privacy Legislation Worldwide
# 1243                   # key internet controls employed
# 1244                                  Rule of Law Index
#
#                                             Data Source  \
# 0     UNCTAD: Data Protection and Privacy Legislatio...
# 1     UNCTAD: Data Protection and Privacy Legislatio...
# 2     UNCTAD: Data Protection and Privacy Legislatio...
# 3                     Freedom House: Freedom on the Net
# 4              World Justice Project: Rule of Law Index
# ...                                                 ...
# 1240  UNCTAD: Data Protection and Privacy Legislatio...
# 1241  UNCTAD: Data Protection and Privacy Legislatio...
# 1242  UNCTAD: Data Protection and Privacy Legislatio...
# 1243                  Freedom House: Freedom on the Net
# 1244           World Justice Project: Rule of Law Index
#
#                                               Data Link Available
# 0     https://unctad.org/page/data-protection-and-pr...         0
# 1     https://unctad.org/page/data-protection-and-pr...         0
# 2     https://unctad.org/page/data-protection-and-pr...         0
# 3           https://freedomhouse.org/report/freedom-net         0
# 4     https://worldjusticeproject.org/our-work/resea...         1
# ...                                                 ...       ...
# 1240  https://unctad.org/page/data-protection-and-pr...         0
# 1241  https://unctad.org/page/data-protection-and-pr...         0
# 1242  https://unctad.org/page/data-protection-and-pr...         0
# 1243        https://freedomhouse.org/report/freedom-net         0
# 1244  https://worldjusticeproject.org/our-work/resea...         0
#
# [1245 rows x 7 columns]

# %%
#If sources.csv exists, get the contents, remove everyhing from this pillar, append prepared sources, save csv.
#if sources.csv does not exist, create new file from sources.
from os.path import exists

if exists('../../dashboard/Sources.csv') :
    CurrentSources = pd.read_csv('../../dashboard/Sources.csv', dtype=str)
    CurrentSources = CurrentSources[['Country Name','Pillar','Sub-Pillar','Indicator','Data Source','Data Link','Available']]
    CurrentSources.loc[CurrentSources['Pillar'] != 'Regulation']
    CurrentSources = CurrentSources.append(sources)
else :
    CurrentSources = sources
CurrentSources
# Out:
#                    Country Name      Pillar                     Sub-Pillar  \
# 0                       Algeria    Strategy                       Ambition
# 1                         Egypt    Strategy                       Ambition
# 2                         Libya    Strategy                       Ambition
# 3                       Morocco    Strategy                       Ambition
# 4                         Sudan    Strategy                       Ambition
# ...                         ...         ...                            ...
# 1240  Wallis and Futuna Islands  Regulation  Data standards and protection
# 1241  Wallis and Futuna Islands  Regulation  Data standards and protection
# 1242  Wallis and Futuna Islands  Regulation  Data standards and protection
# 1243  Wallis and Futuna Islands  Regulation                  Cybersecurity
# 1244  Wallis and Futuna Islands  Regulation              Ethical Standards
#
#                                               Indicator  \
# 0                                             SDG Index
# 1                                             SDG Index
# 2                                             SDG Index
# 3                                             SDG Index
# 4                                             SDG Index
# ...                                                 ...
# 1240                               data protection laws
# 1241       Global Tables of Data Privacy Laws and Bills
# 1242  Data Protection and Privacy Legislation Worldwide
# 1243                   # key internet controls employed
# 1244                                  Rule of Law Index
#
#                                             Data Source  \
# 0                        Sustainable Development Report
# 1                        Sustainable Development Report
# 2                        Sustainable Development Report
# 3                        Sustainable Development Report
# 4                        Sustainable Development Report
# ...                                                 ...
# 1240  UNCTAD: Data Protection and Privacy Legislatio...
# 1241  UNCTAD: Data Protection and Privacy Legislatio...
# 1242  UNCTAD: Data Protection and Privacy Legislatio...
# 1243                  Freedom House: Freedom on the Net
# 1244           World Justice Project: Rule of Law Index
#
#                                               Data Link Available
# 0                              https://www.sdgindex.org         1
# 1                              https://www.sdgindex.org         0
# 2                              https://www.sdgindex.org         1
# 3                              https://www.sdgindex.org         1
# 4                              https://www.sdgindex.org         1
# ...                                                 ...       ...
# 1240  https://unctad.org/page/data-protection-and-pr...         0
# 1241  https://unctad.org/page/data-protection-and-pr...         0
# 1242  https://unctad.org/page/data-protection-and-pr...         0
# 1243        https://freedomhouse.org/report/freedom-net         0
# 1244  https://worldjusticeproject.org/our-work/resea...         0
#
# [405892 rows x 7 columns]

# %%
CurrentSources.to_csv('../../dashboard/Sources.csv', index=False)
