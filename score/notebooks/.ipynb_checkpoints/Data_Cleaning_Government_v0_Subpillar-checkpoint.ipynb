# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Data Link','Index','Filename','Sub-Pillar']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#                                  Data Source  \
# 0  UN Statistics Division: List of Countries
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4   World Bank: World Development Indicators
#
#                            Data Link  Index            Filename  \
# 0             https://unstats.un.org  False           Countries
# 1                   https://gadm.org  False                 NaN
# 2                                NaN  False                 NaN
# 3                                NaN  False                 NaN
# 4  https://datacatalog.worldbank.org  False  population_density
#
#                 Sub-Pillar
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4  Connectivity Technology

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              18         27
# Foundations           14         22
# Government            10         15
# Infrastructure        47         58
# People                35         49
# Regulation             5          8
# Strategy               1          1

# %% [markdown]
# ### Government

# %%
bnames = names[(names.check=='Government')&(~names.Filename.isna())]#&(names.Index==False)]

# %%
bnames.head(25)
# Out:
#                                             Indicator       check  \
# 63                         Online-Service-Index (OSI)  Government
# 64                              E-Participation index  Government
# 65  Use of public services online (% of services o...  Government
# 66          Security incidents (# of relevant issues)  Government
# 67  What is the % change of government digitizing ...  Government
# 68                            R&D spending (% of GDP)  Government
# 69              ICT investment as a percentage of GDP  Government
# 71  Evidence of digital strategies in/across Minst...  Government
# 72             Evidence of focus on vulnerable groups  Government
# 75  % of digital skills certifications / training ...  Government
#
#                                           Data Source  \
# 63                            UN: E-Government Survey
# 64                            UN: E-Government Survey
# 65  Boston Consulting Group/Salesforce: The Global...
# 66                                            SPECOPS
# 67                        World Bank: GovTech Dataset
# 68           World Bank: World Development Indicators
# 69                        OECD: Going Digital Toolkit
# 71                        World Bank: GovTech Dataset
# 72                        World Bank: GovTech Dataset
# 75                    Coursera: Global Skills Reports
#
#                                          Data Link  Index  \
# 63      https://publicadministration.un.org/egovkb   True
# 64      https://publicadministration.un.org/egovkb   True
# 65                      https://www.salesforce.com  False
# 66                         https://specopssoft.com  False
# 67               https://datacatalog.worldbank.org  TRUE
# 68               https://datacatalog.worldbank.org  False
# 69                           https://data.oecd.org  False
# 71               https://datacatalog.worldbank.org  False
# 72               https://datacatalog.worldbank.org  False
# 75  https://www.coursera.org/skills-reports/global  False
#
#                       Filename                   Sub-Pillar
# 63          e_government_index      Digital Public Services
# 64          e_government_index      Digital Public Services
# 65  digital_public_service_use      Digital Public Services
# 66               cyber_attacks      Digital Public Services
# 67               Egov_strategy      Digital Public Services
# 68           RD_Percentage_GDP      Funding and procurement
# 69              ICT_Investment      Funding and procurement
# 71               Egov_strategy      Funding and procurement
# 72               Egov_strategy  Leadership and coordination
# 75         digital_skill_level                 Capabilities

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()
subpillars = bnames['Sub-Pillar'].unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['e_government_index', 'digital_public_service_use',
#        'cyber_attacks', 'Egov_strategy', 'RD_Percentage_GDP',
#        'ICT_Investment', 'digital_skill_level'], dtype=object)

# %%
subpillars
# Out:
# array(['Digital Public Services', 'Funding and procurement',
#        'Leadership and coordination', 'Capabilities'], dtype=object)

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %% [markdown]
# ### 1. Online-Service-Index (OSI)

# %%
indicators[0]
# Out:
# 'Online-Service-Index (OSI)'

# %%
# load data
indicator = indicators[0]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Online-Service-Index (OSI)
# e_government_index

# %%
subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# Digital Public Services

# %%
df.head()
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151

# %%
# all data from 2020
df['Survey Year'].value_counts()
# Out:
# 2020    193
# Name: Survey Year, dtype: int64

# %%
# score looks like the one to use
df.describe()
# Out:
#        Survey Year  E-Government Rank  E-Government Index  \
# count        193.0         193.000000          193.000000
# mean        2020.0          97.000000            0.598767
# std            0.0          55.858452            0.214869
# min         2020.0           1.000000            0.087500
# 25%         2020.0          49.000000            0.432000
# 50%         2020.0          97.000000            0.612900
# 75%         2020.0         145.000000            0.779800
# max         2020.0         193.000000            0.975800
#
#        E-Participation Index  Online Service Index  Human Capital Index  \
# count             193.000000            193.000000           193.000000
# mean                0.567723              0.561961             0.687992
# std                 0.259592              0.249874             0.194440
# min                 0.000000              0.000000             0.000000
# 25%                 0.357100              0.352900             0.559900
# 50%                 0.571400              0.576500             0.739500
# 75%                 0.797600              0.764700             0.841400
# max                 1.000000              1.000000             1.000000
#
#        Telecommunication Infrastructure Index
# count                              193.000000
# mean                                 0.546354
# std                                  0.259358
# min                                  0.000000
# 25%                                  0.349600
# 50%                                  0.566900
# 75%                                  0.772300
# max                                  1.000000

# %%
# df.Indicator.unique()

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Online Service Index'] 
df['Year'] = df['Survey Year']
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#     Country Name  Year                   Indicator  data_col  new_rank_score  \
# 0          Iraq   2020  Online-Service-Index (OSI)    0.3353          2.6765
# 1       Ireland   2020  Online-Service-Index (OSI)    0.7706          4.8530
# 2        Israel   2020  Online-Service-Index (OSI)    0.7471          4.7355
# 3         Italy   2020  Online-Service-Index (OSI)    0.8294          5.1470
# 4       Jamaica   2020  Online-Service-Index (OSI)    0.3882          2.9410
# ..           ...   ...                         ...       ...             ...
# 188     Senegal   2020  Online-Service-Index (OSI)    0.4941          3.4705
# 189       Serbia  2020  Online-Service-Index (OSI)    0.7941          4.9705
# 190  Seychelles   2020  Online-Service-Index (OSI)    0.6176          4.0880
# 191   Singapore   2020  Online-Service-Index (OSI)    0.9647          5.8235
# 192    Slovakia   2020  Online-Service-Index (OSI)    0.7176          4.5880
#
#      higher_is_better               Sub-Pillar
# 0                True  Digital Public Services
# 1                True  Digital Public Services
# 2                True  Digital Public Services
# 3                True  Digital Public Services
# 4                True  Digital Public Services
# ..                ...                      ...
# 188              True  Digital Public Services
# 189              True  Digital Public Services
# 190              True  Digital Public Services
# 191              True  Digital Public Services
# 192              True  Digital Public Services
#
# [193 rows x 7 columns]

# %%
# output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator))

# %% [markdown]
# ## 2. E-Participation index

# %%
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# E-Participation index
# e_government_index

# %%
df.head()
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151

# %%
subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# Digital Public Services

# %%
df['Survey Year'].unique()
# Out:
# array([2020], dtype=int64)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,4]
df['Year'] = df['Survey Year']
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#     Country Name  Year              Indicator  data_col  new_rank_score  \
# 0          Iraq   2020  E-Participation index    0.3095          2.5475
# 1       Ireland   2020  E-Participation index    0.8571          5.2855
# 2        Israel   2020  E-Participation index    0.7143          4.5715
# 3         Italy   2020  E-Participation index    0.8214          5.1070
# 4       Jamaica   2020  E-Participation index    0.3690          2.8450
# ..           ...   ...                    ...       ...             ...
# 188     Senegal   2020  E-Participation index    0.4405          3.2025
# 189       Serbia  2020  E-Participation index    0.8214          5.1070
# 190  Seychelles   2020  E-Participation index    0.5714          3.8570
# 191   Singapore   2020  E-Participation index    0.9762          5.8810
# 192    Slovakia   2020  E-Participation index    0.7024          4.5120
#
#      higher_is_better               Sub-Pillar
# 0                True  Digital Public Services
# 1                True  Digital Public Services
# 2                True  Digital Public Services
# 3                True  Digital Public Services
# 4                True  Digital Public Services
# ..                ...                      ...
# 188              True  Digital Public Services
# 189              True  Digital Public Services
# 190              True  Digital Public Services
# 191              True  Digital Public Services
# 192              True  Digital Public Services
#
# [193 rows x 7 columns]

# %%
# output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator))

# %% [markdown]
# ## 3. Use of public services online (% of services online, penetration, frequency of use)

# %%
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Use of public services online (% of services online, penetration, frequency of use)
# digital_public_service_use

# %%
# drop first row
df = df.iloc[1: , :]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 1 to 31
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             31 non-null     object
#  1   Net Perception (%)  31 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 628.0+ bytes

# %%
df.head(15)
# Out:
#            Country  Net Perception (%)
# 1             UAE                   61
# 2    Saudi Arabia                   59
# 3        Singapore                  54
# 4           China                   53
# 5     New Zealand                   52
# 6     Netherlands                   51
# 7           Qatar                   51
# 8          Canada                   40
# 9          Denmark                  48
# 10          India                   45
# 11         France                   43
# 12              UK                  42
# 13          Sweden                  41
# 14       Australia                  40
# 15  United States                   39

# %%
subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# Digital Public Services

# %%
# create the standard columns
df['higher_is_better'] = True
df['Indicator'] =  indicator
df['Country Name'] = df['Country']
# df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
df['data_col'] = df['Net Perception (%)']
df['Year'] = 2020
df['Sub-Pillar'] = subpillar

# %%
# convert 1-100 %  into 1-6
min_rank = df['data_col'].min()
max_rank = df['data_col'].max()
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

df.sort_values(by='new_rank_score', ascending=False)

# prepare output
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]

# output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %%
df.head(15)
# Out:
#       Country Name  Year                                          Indicator  \
# 1             UAE   2020  Use of public services online (% of services o...
# 2    Saudi Arabia   2020  Use of public services online (% of services o...
# 3        Singapore  2020  Use of public services online (% of services o...
# 4           China   2020  Use of public services online (% of services o...
# 5     New Zealand   2020  Use of public services online (% of services o...
# 6     Netherlands   2020  Use of public services online (% of services o...
# 7           Qatar   2020  Use of public services online (% of services o...
# 8          Canada   2020  Use of public services online (% of services o...
# 9          Denmark  2020  Use of public services online (% of services o...
# 10          India   2020  Use of public services online (% of services o...
# 11         France   2020  Use of public services online (% of services o...
# 12              UK  2020  Use of public services online (% of services o...
# 13          Sweden  2020  Use of public services online (% of services o...
# 14       Australia  2020  Use of public services online (% of services o...
# 15  United States   2020  Use of public services online (% of services o...
#
#     data_col  new_rank_score  higher_is_better               Sub-Pillar
# 1         61        6.000000              True  Digital Public Services
# 2         59        5.876543              True  Digital Public Services
# 3         54        5.567901              True  Digital Public Services
# 4         53        5.506173              True  Digital Public Services
# 5         52        5.444444              True  Digital Public Services
# 6         51        5.382716              True  Digital Public Services
# 7         51        5.382716              True  Digital Public Services
# 8         40        4.703704              True  Digital Public Services
# 9         48        5.197531              True  Digital Public Services
# 10        45        5.012346              True  Digital Public Services
# 11        43        4.888889              True  Digital Public Services
# 12        42        4.827160              True  Digital Public Services
# 13        41        4.765432              True  Digital Public Services
# 14        40        4.703704              True  Digital Public Services
# 15        39        4.641975              True  Digital Public Services

# %% [markdown]
# ## 4. Security incidents (# of relevant issues)

# %%
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Security incidents (# of relevant issues)
# cyber_attacks

# %%
df.head()
# Out:
#           Country  Number of Significant Cyberattacks (2006-2020)
# 0   United States                                             156
# 1  United Kingdom                                              47
# 2           India                                              23
# 3         Germany                                              21
# 4     South Korea                                              18

# %%
# create a rank from the number of attacks fields
df['data_rank'] = df['Number of Significant Cyberattacks (2006-2020)'].rank(method='max')

# %%
subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# Digital Public Services

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['data_rank']
df['Year'] = 2020
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# need to invert since higher rank is not better
df['new_rank_score'] = (6-df['new_rank_score'])+1

# # prepare output
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]

df.head(15)
# Out:
#       Country Name  Year                                  Indicator  data_col  \
# 0    United States  2020  Security incidents (# of relevant issues)      20.0
# 1   United Kingdom  2020  Security incidents (# of relevant issues)      19.0
# 2            India  2020  Security incidents (# of relevant issues)      18.0
# 3          Germany  2020  Security incidents (# of relevant issues)      17.0
# 4      South Korea  2020  Security incidents (# of relevant issues)      16.0
# 5        Australia  2020  Security incidents (# of relevant issues)      15.0
# 6          Ukraine  2020  Security incidents (# of relevant issues)      15.0
# 7            China  2020  Security incidents (# of relevant issues)      13.0
# 8             Iran  2020  Security incidents (# of relevant issues)      13.0
# 9     Saudi Arabia  2020  Security incidents (# of relevant issues)      13.0
# 10           Japan  2020  Security incidents (# of relevant issues)      10.0
# 11          Canada  2020  Security incidents (# of relevant issues)       9.0
# 12          France  2020  Security incidents (# of relevant issues)       8.0
# 13          Israel  2020  Security incidents (# of relevant issues)       8.0
# 14        Pakistan  2020  Security incidents (# of relevant issues)       6.0
#
#     new_rank_score  higher_is_better               Sub-Pillar
# 0         1.000000              True  Digital Public Services
# 1         1.263158              True  Digital Public Services
# 2         1.526316              True  Digital Public Services
# 3         1.789474              True  Digital Public Services
# 4         2.052632              True  Digital Public Services
# 5         2.315789              True  Digital Public Services
# 6         2.315789              True  Digital Public Services
# 7         2.842105              True  Digital Public Services
# 8         2.842105              True  Digital Public Services
# 9         2.842105              True  Digital Public Services
# 10        3.631579              True  Digital Public Services
# 11        3.894737              True  Digital Public Services
# 12        4.157895              True  Digital Public Services
# 13        4.157895              True  Digital Public Services
# 14        4.684211              True  Digital Public Services

# %%
# # output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 5. What is the % change of government digitizing public services?

# %%
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# What is the % change of government digitizing public services?
# Egov_strategy

# %%
df.head()
# Out:
#    # Flag Code  Cnum      Economy Level Population      GNI   GNIPC  \
# 0  1  NaN  AFG   4.0  Afghanistan   LIC     38,928   20,726     540
# 1  2  NaN  ALB   8.0      Albania  UMIC      2,878   14,949   5,240
# 2  3  NaN  DZA  12.0      Algeria  LMIC     43,851  170,722   3,970
# 3  4  NaN  ADO  20.0      Andorra   HIC         77    3,154  40,886
# 4  5  NaN  AGO  24.0       Angola  LMIC     32,866   97,005   3,050
#
#                                         e-Government  ... NGTI-1 NGTI-2  \
# 0                      https://mcit.gov.af/node/6938  ...   0.69   0.52
# 1                              https://e-albania.al/  ...   0.81   0.78
# 2  https://www.mpttn.gov.dz/ar/content/%D8%A7%D9%...  ...   0.73   0.46
# 3                               http://www.govern.ad  ...   0.63   0.60
# 4                          http://www.governo.gov.ao  ...   0.68   0.69
#
#   NGTI-3 NGTI-4 GTI-1 GTI-2  GTI-3  GTI-4 data_country data_year
# 0   0.31   0.62 -0.09 -0.34   0.02  -0.12          NaN       NaN
# 1   0.60   0.77  0.29  0.62   0.74   0.26          NaN       NaN
# 2   0.02   0.60  0.06 -0.56  -0.68  -0.15          NaN       NaN
# 3   0.05   0.13 -0.28 -0.06  -0.62  -1.32          NaN       NaN
# 4   0.21   0.61 -0.12  0.27  -0.23  -0.13          NaN       NaN
#
# [5 rows x 332 columns]

# %%
# Must limit the database to the first 206 rows, the remaining rows do not contain any useful information
df = df.iloc[0:205,:]

# Drop the superfluous rows by dropping na
df = df[pd.to_numeric(df['#'], errors='coerce').notnull()]
df['#'] = df[df['#'].notna()]

# Must convert data in the DPL column into float
df['CGSI'] = df['CGSI'].replace('-',np.nan)
df['CGSI'] = df['CGSI'].astype(float, errors = 'ignore')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/1838411011.py in <module>
#       4 # Drop the superfluous rows by dropping na
#       5 df = df[pd.to_numeric(df['#'], errors='coerce').notnull()]
# ----> 6 df['#'] = df[df['#'].notna()]
#       7
#       8 # Must convert data in the DPL column into float
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3727             len_cols = 1 if is_scalar(cols) else len(cols)
#    3728             if len_cols != len(value.columns):
# -> 3729                 raise ValueError("Columns must be same length as key")
#    3730
#    3731             # align right-hand-side columns if self.columns
#
# ValueError: Columns must be same length as key

# %%
subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# Digital Public Services

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['CGSI']
df['Country Name'] = df['Economy']
df['Year'] = 2020
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df.head(15)
# Out:
#            Country Name  Year  \
# 0           Afghanistan  2020
# 1               Albania  2020
# 2               Algeria  2020
# 3               Andorra  2020
# 4                Angola  2020
# 5   Antigua and Barbuda  2020
# 6             Argentina  2020
# 7               Armenia  2020
# 8             Australia  2020
# 9               Austria  2020
# 11           Azerbaijan  2020
# 12              Bahamas  2020
# 13              Bahrain  2020
# 14           Bangladesh  2020
# 15             Barbados  2020
#
#                                             Indicator  data_col  \
# 0   What is the % change of government digitizing ...      0.69
# 1   What is the % change of government digitizing ...      0.79
# 2   What is the % change of government digitizing ...      0.71
# 3   What is the % change of government digitizing ...      0.58
# 4   What is the % change of government digitizing ...      0.67
# 5   What is the % change of government digitizing ...      0.68
# 6   What is the % change of government digitizing ...      0.81
# 7   What is the % change of government digitizing ...      0.73
# 8   What is the % change of government digitizing ...      0.89
# 9   What is the % change of government digitizing ...       NaN
# 11  What is the % change of government digitizing ...      0.76
# 12  What is the % change of government digitizing ...      0.72
# 13  What is the % change of government digitizing ...      0.59
# 14  What is the % change of government digitizing ...      0.81
# 15  What is the % change of government digitizing ...      0.75
#
#     new_rank_score  higher_is_better               Sub-Pillar
# 0         4.520408              True  Digital Public Services
# 1         5.030612              True  Digital Public Services
# 2         4.622449              True  Digital Public Services
# 3         3.959184              True  Digital Public Services
# 4         4.418367              True  Digital Public Services
# 5         4.469388              True  Digital Public Services
# 6         5.132653              True  Digital Public Services
# 7         4.724490              True  Digital Public Services
# 8         5.540816              True  Digital Public Services
# 9              NaN              True  Digital Public Services
# 11        4.877551              True  Digital Public Services
# 12        4.673469              True  Digital Public Services
# 13        4.010204              True  Digital Public Services
# 14        5.132653              True  Digital Public Services
# 15        4.826531              True  Digital Public Services

# %%
# output scores
df.to_csv('../indicator_scores/government_percent change of government digitalizing_scores.csv'.format(indicator), index=False)

# %%
## 6. R&D spending (% of GDP)

# %%
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# R&D spending (% of GDP)
# RD_Percentage_GDP

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   1960            0 non-null      float64
#  1   1961            0 non-null      float64
#  2   1962            0 non-null      float64
#  3   1963            0 non-null      float64
#  4   1964            0 non-null      float64
#  5   1965            0 non-null      float64
#  6   1966            0 non-null      float64
#  7   1967            0 non-null      float64
#  8   1968            0 non-null      float64
#  9   1969            0 non-null      float64
#  10  1970            0 non-null      float64
#  11  1971            0 non-null      float64
#  12  1972            0 non-null      float64
#  13  1973            0 non-null      float64
#  14  1974            0 non-null      float64
#  15  1975            0 non-null      float64
#  16  1976            0 non-null      float64
#  17  1977            0 non-null      float64
#  18  1978            0 non-null      float64
#  19  1979            0 non-null      float64
#  20  1980            0 non-null      float64
#  21  1981            0 non-null      float64
#  22  1982            0 non-null      float64
#  23  1983            0 non-null      float64
#  24  1984            0 non-null      float64
#  25  1985            0 non-null      float64
#  26  1986            0 non-null      float64
#  27  1987            0 non-null      float64
#  28  1988            0 non-null      float64
#  29  1989            0 non-null      float64
#  30  1990            0 non-null      float64
#  31  1991            0 non-null      float64
#  32  1992            0 non-null      float64
#  33  1993            0 non-null      float64
#  34  1994            0 non-null      float64
#  35  1995            0 non-null      float64
#  36  1996            70 non-null     float64
#  37  1997            87 non-null     float64
#  38  1998            82 non-null     float64
#  39  1999            85 non-null     float64
#  40  2000            98 non-null     float64
#  41  2001            108 non-null    float64
#  42  2002            120 non-null    float64
#  43  2003            120 non-null    float64
#  44  2004            121 non-null    float64
#  45  2005            119 non-null    float64
#  46  2006            111 non-null    float64
#  47  2007            129 non-null    float64
#  48  2008            123 non-null    float64
#  49  2009            124 non-null    float64
#  50  2010            123 non-null    float64
#  51  2011            119 non-null    float64
#  52  2012            113 non-null    float64
#  53  2013            122 non-null    float64
#  54  2014            116 non-null    float64
#  55  2015            129 non-null    float64
#  56  2016            116 non-null    float64
#  57  2017            121 non-null    float64
#  58  2018            108 non-null    float64
#  59  2019            2 non-null      float64
#  60  2020            0 non-null      float64
#  61  Country Name    266 non-null    object
#  62  Country Code    266 non-null    object
#  63  Indicator Name  266 non-null    object
#  64  Indicator Code  266 non-null    object
#  65  data_country    0 non-null      float64
#  66  data_year       0 non-null      float64
# dtypes: float64(63), object(4)
# memory usage: 139.4+ KB

# %%
df.head()
# Out:
#    1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  2017  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#    2018  2019  2020                 Country Name  Country Code  \
# 0   NaN   NaN   NaN                        Aruba           ABW
# 1   NaN   NaN   NaN  Africa Eastern and Southern           AFE
# 2   NaN   NaN   NaN                  Afghanistan           AFG
# 3   NaN   NaN   NaN   Africa Western and Central           AFW
# 4   NaN   NaN   NaN                       Angola           AGO
#
#                                     Indicator Name     Indicator Code  \
# 0  Research and development expenditure (% of GDP)  GB.XPD.RSDV.GD.ZS
# 1  Research and development expenditure (% of GDP)  GB.XPD.RSDV.GD.ZS
# 2  Research and development expenditure (% of GDP)  GB.XPD.RSDV.GD.ZS
# 3  Research and development expenditure (% of GDP)  GB.XPD.RSDV.GD.ZS
# 4  Research and development expenditure (% of GDP)  GB.XPD.RSDV.GD.ZS
#
#    data_country  data_year
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
#
# [5 rows x 67 columns]

# %%
# create standard columns
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2018'] 
df['Sub-Pillar'] = subpillar
df['Year'] = 2018

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#                     Country Name  Year                Indicator  data_col  \
# 0                          Aruba  2018  R&D spending (% of GDP)       NaN
# 1    Africa Eastern and Southern  2018  R&D spending (% of GDP)       NaN
# 2                    Afghanistan  2018  R&D spending (% of GDP)       NaN
# 3     Africa Western and Central  2018  R&D spending (% of GDP)       NaN
# 4                         Angola  2018  R&D spending (% of GDP)       NaN
# ..                           ...   ...                      ...       ...
# 261                       Kosovo  2018  R&D spending (% of GDP)       NaN
# 262                  Yemen, Rep.  2018  R&D spending (% of GDP)       NaN
# 263                 South Africa  2018  R&D spending (% of GDP)       NaN
# 264                       Zambia  2018  R&D spending (% of GDP)       NaN
# 265                     Zimbabwe  2018  R&D spending (% of GDP)       NaN
#
#      new_rank_score  higher_is_better               Sub-Pillar
# 0               NaN              True  Digital Public Services
# 1               NaN              True  Digital Public Services
# 2               NaN              True  Digital Public Services
# 3               NaN              True  Digital Public Services
# 4               NaN              True  Digital Public Services
# ..              ...               ...                      ...
# 261             NaN              True  Digital Public Services
# 262             NaN              True  Digital Public Services
# 263             NaN              True  Digital Public Services
# 264             NaN              True  Digital Public Services
# 265             NaN              True  Digital Public Services
#
# [266 rows x 7 columns]

# %%
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 7. ICT investment as a percentage of GDP

# %%
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# ICT investment as a percentage of GDP
# ICT_Investment

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    450 non-null    object
#  1   INDICATOR   450 non-null    object
#  2   SUBJECT     450 non-null    object
#  3   MEASURE     450 non-null    object
#  4   FREQUENCY   450 non-null    object
#  5   TIME        450 non-null    int64
#  6   Value       450 non-null    float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.2+ KB

# %%
df.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME      Value  Flag Codes
# 0      AUS  ICTINVST     TOT      PC         A  1985  12.465454         NaN
# 1      AUS  ICTINVST     TOT      PC         A  1986  13.939533         NaN
# 2      AUS  ICTINVST     TOT      PC         A  1987  14.142429         NaN
# 3      AUS  ICTINVST     TOT      PC         A  1988  14.289993         NaN
# 4      AUS  ICTINVST     TOT      PC         A  1989  15.348707         NaN

# %%
df.SUBJECT.unique()
# Out:
# array(['TOT'], dtype=object)

# %%
df.TIME.max()
# Out:
# 2010

# %%
df.Value.describe()
# Out:
# count    450.000000
# mean      16.074272
# std        5.636379
# min        2.798417
# 25%       12.410442
# 50%       14.840726
# 75%       19.419433
# max       32.601105
# Name: Value, dtype: float64

# %%
subpillars[1]
subpillar = subpillars[1]
print(subpillar)
# Out:
# Funding and procurement

# %%
dcol = 'Value'
indicol = indicator
cname = 'LOCATION'

# filter most recent year
df = df[(df.TIME==2010)]

# create standard columns
df['higher_is_better'] = True
df['Indicator'] =  indicator
df['Country Name'] = df[cname]
# # df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
df['data_col'] = df[dcol]
df['Sub-Pillar'] = subpillar
df['Year'] = 2010

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# df.sort_values(by='new_rank_score', ascending=False)

# # prepare output
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]

# # output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %%
df
# Out:
#     Country Name  Year                              Indicator   data_col  \
# 72           CAN  2010  ICT investment as a percentage of GDP  17.018367
# 121          FIN  2010  ICT investment as a percentage of GDP  15.519828
# 172          DEU  2010  ICT investment as a percentage of GDP  12.690394
# 198          IRL  2010  ICT investment as a percentage of GDP  12.412805
# 224          ITA  2010  ICT investment as a percentage of GDP  11.026056
# 274          KOR  2010  ICT investment as a percentage of GDP  10.716026
# 323          NZL  2010  ICT investment as a percentage of GDP  21.238183
# 349          ESP  2010  ICT investment as a percentage of GDP  13.763415
# 400          CHE  2010  ICT investment as a percentage of GDP  18.506691
# 449          USA  2010  ICT investment as a percentage of GDP  32.137836
#
#      new_rank_score  higher_is_better               Sub-Pillar
# 72         2.471010              True  Funding and procurement
# 121        2.121241              True  Funding and procurement
# 172        1.460831              True  Funding and procurement
# 198        1.396040              True  Funding and procurement
# 224        1.072363              True  Funding and procurement
# 274        1.000000              True  Funding and procurement
# 323        3.455945              True  Funding and procurement
# 349        1.711282              True  Funding and procurement
# 400        2.818396              True  Funding and procurement
# 449        6.000000              True  Funding and procurement

# %% [markdown]
# ## 8. Evidence of digital strategies in/across Ministries

# %%
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Evidence of digital strategies in/across Minstries
# Egov_strategy

# %%
df.head()
# Out:
#    # Flag Code  Cnum      Economy Level Population      GNI   GNIPC  \
# 0  1  NaN  AFG   4.0  Afghanistan   LIC     38,928   20,726     540
# 1  2  NaN  ALB   8.0      Albania  UMIC      2,878   14,949   5,240
# 2  3  NaN  DZA  12.0      Algeria  LMIC     43,851  170,722   3,970
# 3  4  NaN  ADO  20.0      Andorra   HIC         77    3,154  40,886
# 4  5  NaN  AGO  24.0       Angola  LMIC     32,866   97,005   3,050
#
#                                         e-Government  ... NGTI-1 NGTI-2  \
# 0                      https://mcit.gov.af/node/6938  ...   0.69   0.52
# 1                              https://e-albania.al/  ...   0.81   0.78
# 2  https://www.mpttn.gov.dz/ar/content/%D8%A7%D9%...  ...   0.73   0.46
# 3                               http://www.govern.ad  ...   0.63   0.60
# 4                          http://www.governo.gov.ao  ...   0.68   0.69
#
#   NGTI-3 NGTI-4 GTI-1 GTI-2  GTI-3  GTI-4 data_country data_year
# 0   0.31   0.62 -0.09 -0.34   0.02  -0.12          NaN       NaN
# 1   0.60   0.77  0.29  0.62   0.74   0.26          NaN       NaN
# 2   0.02   0.60  0.06 -0.56  -0.68  -0.15          NaN       NaN
# 3   0.05   0.13 -0.28 -0.06  -0.62  -1.32          NaN       NaN
# 4   0.21   0.61 -0.12  0.27  -0.23  -0.13          NaN       NaN
#
# [5 rows x 332 columns]

# %%
# Must limit the database to the first 206 rows, the remaining rows do not contain any useful information
df = df.iloc[0:205,:]

# Drop the superfluous rows by dropping na
df = df[pd.to_numeric(df['#'], errors='coerce').notnull()]
df['#'] = df[df['#'].notna()]

# Must convert data in the DPL column into float
df['DG St'] = df['DG St'].replace('-',np.nan)
df['DG St'] = df['DG St'].astype(float, errors = 'ignore')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/3384079989.py in <module>
#       4 # Drop the superfluous rows by dropping na
#       5 df = df[pd.to_numeric(df['#'], errors='coerce').notnull()]
# ----> 6 df['#'] = df[df['#'].notna()]
#       7
#       8 # Must convert data in the DPL column into float
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3727             len_cols = 1 if is_scalar(cols) else len(cols)
#    3728             if len_cols != len(value.columns):
# -> 3729                 raise ValueError("Columns must be same length as key")
#    3730
#    3731             # align right-hand-side columns if self.columns
#
# ValueError: Columns must be same length as key

# %%
subpillars[1]
subpillar = subpillars[1]
print(subpillar)
# Out:
# Funding and procurement

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['DG St']
df['Country Name'] = df['Economy']
df['Year'] = 2020
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

max_rank
# Out:
# '3'

# %%
# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/2029776328.py in <module>
#       1 # transform 0-1 rank into 1-6
# ----> 2 df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1097                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1098                 # "Callable[[Any], Any]"
# -> 1099                 mapped = lib.map_infer(
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/2029776328.py in <lambda>(row)
#       1 # transform 0-1 rank into 1-6
# ----> 2 df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
#
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/1178772952.py in convert_rank(old_value, old_min, old_max, new_min, new_max)
#       2 def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
#       3     """ Convert old scale values scale into new scale values"""
# ----> 4     old_range = old_max - old_min
#       5     new_range = new_max - new_min
#       6     new_value = (((old_value-old_min)*new_range)/old_range)+new_min
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df.head(15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/2153135651.py in <module>
# ----> 1 df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
#       2 df.head(15)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['new_rank_score'] not in index"

# %%
# # output scores
df.to_csv('../indicator_scores/government_Evidence of digital strategies_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 9. Evidence of focus on vulnerable groups

# %%
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

df = df.iloc[1:,:]
# Out:
# Evidence of focus on vulnerable groups
# Egov_strategy

# %%
df.head()
# Out:
#    # Flag Code  Cnum              Economy Level Population      GNI   GNIPC  \
# 1  2  NaN  ALB   8.0              Albania  UMIC      2,878   14,949   5,240
# 2  3  NaN  DZA  12.0              Algeria  LMIC     43,851  170,722   3,970
# 3  4  NaN  ADO  20.0              Andorra   HIC         77    3,154  40,886
# 4  5  NaN  AGO  24.0               Angola  LMIC     32,866   97,005   3,050
# 5  6  NaN  ATG  28.0  Antigua and Barbuda   HIC         98    1,618  16,660
#
#                                         e-Government  ... NGTI-1 NGTI-2  \
# 1                              https://e-albania.al/  ...   0.81   0.78
# 2  https://www.mpttn.gov.dz/ar/content/%D8%A7%D9%...  ...   0.73   0.46
# 3                               http://www.govern.ad  ...   0.63   0.60
# 4                          http://www.governo.gov.ao  ...   0.68   0.69
# 5                               http://www.ab.gov.ag  ...   0.72   0.55
#
#   NGTI-3 NGTI-4 GTI-1 GTI-2  GTI-3  GTI-4 data_country data_year
# 1   0.60   0.77  0.29  0.62   0.74   0.26          NaN       NaN
# 2   0.02   0.60  0.06 -0.56  -0.68  -0.15          NaN       NaN
# 3   0.05   0.13 -0.28 -0.06  -0.62  -1.32          NaN       NaN
# 4   0.21   0.61 -0.12  0.27  -0.23  -0.13          NaN       NaN
# 5   0.05   0.42  0.00 -0.23  -0.62  -0.59          NaN       NaN
#
# [5 rows x 332 columns]

# %%
# Must limit the database to the first 206 rows, the remaining rows do not contain any useful information
df = df.iloc[0:205,:]

# Drop the superfluous rows by dropping na
df = df[pd.to_numeric(df['#'], errors='coerce').notnull()]
df['#'] = df[df['#'].notna()]

# Must convert data in the DPL column into float
df['WoG'] = df['WoG'].replace('-',np.nan)
df['WoG'] = df['WoG'].astype(float, errors = 'ignore')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/3782096941.py in <module>
#       4 # Drop the superfluous rows by dropping na
#       5 df = df[pd.to_numeric(df['#'], errors='coerce').notnull()]
# ----> 6 df['#'] = df[df['#'].notna()]
#       7
#       8 # Must convert data in the DPL column into float
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3727             len_cols = 1 if is_scalar(cols) else len(cols)
#    3728             if len_cols != len(value.columns):
# -> 3729                 raise ValueError("Columns must be same length as key")
#    3730
#    3731             # align right-hand-side columns if self.columns
#
# ValueError: Columns must be same length as key

# %%
df['WoG'].describe
# Out:
# <bound method NDFrame.describe of 1       0.03
# 2      -0.03
# 3      -0.03
# 4       0.03
# 5      -0.03
#        ...
# 200     0.03
# 201    -0.03
# 202    -0.03
# 203    -0.03
# 204    -0.03
# Name: WoG, Length: 197, dtype: object>

# %%
subpillars[2]
subpillar = subpillars[2]
print(subpillar)
# Out:
# Leadership and coordination

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['WoG']
df['Country Name'] = df['Economy']
df['Year'] = 2020
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

max_rank
# Out:
# '0.09'

# %%
# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/2029776328.py in <module>
#       1 # transform 0-1 rank into 1-6
# ----> 2 df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1097                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1098                 # "Callable[[Any], Any]"
# -> 1099                 mapped = lib.map_infer(
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/2029776328.py in <lambda>(row)
#       1 # transform 0-1 rank into 1-6
# ----> 2 df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
#
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/1178772952.py in convert_rank(old_value, old_min, old_max, new_min, new_max)
#       2 def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
#       3     """ Convert old scale values scale into new scale values"""
# ----> 4     old_range = old_max - old_min
#       5     new_range = new_max - new_min
#       6     new_value = (((old_value-old_min)*new_range)/old_range)+new_min
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\OKRSTU~1\AppData\Local\Temp/ipykernel_3112/450344425.py in <module>
# ----> 1 df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
#       2 df
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['new_rank_score'] not in index"

# %%
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 10. % of digital skills certifications / training courses completed

# %%
indicator = indicators[9]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of digital skills certifications / training courses completed
# digital_skill_level

# %%
df
# Out:
#      Global Rank                           Region Country and Region  Year  \
# 0              1                           Europe        Switzerland  2020
# 1              2                           Europe         Luxembourg  2020
# 2              3                           Europe            Austria  2020
# 3              4                     Asia Pacific              Japan  2020
# 4              5                           Europe            Germany  2020
# ..           ...                              ...                ...   ...
# 103          104                     Asia Pacific         Uzbekistan  2020
# 104          105               Sub-Saharan Africa       Sierra Leone  2020
# 105          106  Latin America and the Caribbean           Paraguay  2020
# 106          107  Latin America and the Caribbean             Guyana  2020
# 107          108               Sub-Saharan Africa            Somalia  2020
#
#     Technology Data Science
# 0          84%          96%
# 1          62%          85%
# 2          88%          95%
# 3         100%          88%
# 4          89%          94%
# ..         ...          ...
# 103         6%           9%
# 104         2%           4%
# 105         7%          11%
# 106         8%           2%
# 107         1%           1%
#
# [108 rows x 6 columns]

# %%
subpillars[3]
subpillar = subpillars[3]
print(subpillar)
# Out:
# Capabilities

# %%
dcol = 'Global Rank'
indicol = indicator
cname = 'Country and Region'

# filter most recent year
# df = df[(df.TIME==2010)]

# create standard columns
df['higher_is_better'] = True
df['Indicator'] =  indicator
df['Country Name'] = df[cname]
# # df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
df['data_col'] = df[dcol]
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# # need to invert score since higher rank is not better 
df['new_rank_score'] = (6-df['new_rank_score'])+1

df.sort_values(by='new_rank_score', ascending=False)

# # prepare output
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]

# # output scores
df.to_csv('../indicator_scores/government_ percentage digital skills certifications_scores.csv'.format(indicator), index=False)

# %%
df
# Out:
#      Country Name  Year                                          Indicator  \
# 0     Switzerland  2020  % of digital skills certifications / training ...
# 1      Luxembourg  2020  % of digital skills certifications / training ...
# 2         Austria  2020  % of digital skills certifications / training ...
# 3           Japan  2020  % of digital skills certifications / training ...
# 4         Germany  2020  % of digital skills certifications / training ...
# ..            ...   ...                                                ...
# 103    Uzbekistan  2020  % of digital skills certifications / training ...
# 104  Sierra Leone  2020  % of digital skills certifications / training ...
# 105      Paraguay  2020  % of digital skills certifications / training ...
# 106        Guyana  2020  % of digital skills certifications / training ...
# 107       Somalia  2020  % of digital skills certifications / training ...
#
#      data_col  new_rank_score  higher_is_better    Sub-Pillar
# 0           1        6.000000              True  Capabilities
# 1           2        5.953271              True  Capabilities
# 2           3        5.906542              True  Capabilities
# 3           4        5.859813              True  Capabilities
# 4           5        5.813084              True  Capabilities
# ..        ...             ...               ...           ...
# 103       104        1.186916              True  Capabilities
# 104       105        1.140187              True  Capabilities
# 105       106        1.093458              True  Capabilities
# 106       107        1.046729              True  Capabilities
# 107       108        1.000000              True  Capabilities
#
# [108 rows x 7 columns]

# %% [markdown]
# ### Score Aggregating

# %%
import os

# %%
# get list of files in scores folder
scores = os.listdir('../indicator_scores/')
scores = [s for s in scores if s.startswith('government')]

# %%
scores
# Out:
# ['government_ percentage digital skills certifications_scores.csv',
#  'government_E-Participation index_scores.csv',
#  'government_Evidence of digital strategies_scores.csv',
#  'government_Evidence of focus on vulnerable groups_scores.csv',
#  'government_ICT investment as a percentage of GDP_scores.csv',
#  'government_Online-Service-Index (OSI)_scores.csv',
#  'government_percent change of government digitalizing_scores.csv',
#  'government_R&D spending (% of GDP)_scores.csv',
#  'government_Security incidents (# of relevant issues)_scores.csv',
#  'government_Use of public services online (% of services online, penetration, frequency of use)_scores.csv']

# %%
# create a dataframe that concatenates all these file into one table
df = pd.concat([pd.read_csv('../indicator_scores/{}'.format(s)) for s in scores])

# %%
df
# Out:
#    Country Name  Year                                          Indicator  \
# 0   Switzerland  2020  % of digital skills certifications / training ...
# 1    Luxembourg  2020  % of digital skills certifications / training ...
# 2       Austria  2020  % of digital skills certifications / training ...
# 3         Japan  2020  % of digital skills certifications / training ...
# 4       Germany  2020  % of digital skills certifications / training ...
# ..          ...   ...                                                ...
# 26     Germany   2020  Use of public services online (% of services o...
# 27   Argentina   2020  Use of public services online (% of services o...
# 28     Morocco   2020  Use of public services online (% of services o...
# 29  Switzerland  2020  Use of public services online (% of services o...
# 30       Japan   2020  Use of public services online (% of services o...
#
#     data_col  new_rank_score  higher_is_better               Sub-Pillar  \
# 0        1.0        6.000000              True             Capabilities
# 1        2.0        5.953271              True             Capabilities
# 2        3.0        5.906542              True             Capabilities
# 3        4.0        5.859813              True             Capabilities
# 4        5.0        5.813084              True             Capabilities
# ..       ...             ...               ...                      ...
# 26      17.0        3.283951              True  Digital Public Services
# 27      15.0        3.160494              True  Digital Public Services
# 28      -2.0        2.111111              True  Digital Public Services
# 29     -18.0        1.123457              True  Digital Public Services
# 30     -20.0        1.000000              True  Digital Public Services
#
#     Unnamed: 0   #  Flag  ... NGTI-1  NGTI-2 NGTI-3 NGTI-4 GTI-1 GTI-2 GTI-3  \
# 0          NaN NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 1          NaN NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 2          NaN NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 3          NaN NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 4          NaN NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# ..         ...  ..   ...  ...    ...     ...    ...    ...   ...   ...   ...
# 26         NaN NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 27         NaN NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 28         NaN NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 29         NaN NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 30         NaN NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
#
#    GTI-4  data_country data_year
# 0    NaN           NaN       NaN
# 1    NaN           NaN       NaN
# 2    NaN           NaN       NaN
# 3    NaN           NaN       NaN
# 4    NaN           NaN       NaN
# ..   ...           ...       ...
# 26   NaN           NaN       NaN
# 27   NaN           NaN       NaN
# 28   NaN           NaN       NaN
# 29   NaN           NaN       NaN
# 30   NaN           NaN       NaN
#
# [1414 rows x 340 columns]

# %%
# Data cleaning
df['new_rank_score'] = df['new_rank_score'].fillna(0)
df.sort_values(by=['Country Name'], ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1414 entries, 0 to 1413
# Columns: 340 entries, Country Name to data_year
# dtypes: bool(1), float64(119), int64(1), object(219)
# memory usage: 3.7+ MB

# %%
df.head(15)
# Out:
#                    Country Name  Year  \
# 0                   Afghanistan  2020
# 1                   Afghanistan  2018
# 2                   Afghanistan  2020
# 3                   Afghanistan  2020
# 4                   Afghanistan  2020
# 5   Africa Eastern and Southern  2018
# 6    Africa Western and Central  2018
# 7                       Albania  2018
# 8                       Albania  2020
# 9                       Albania  2020
# 10                      Albania  2020
# 11                     Albania   2020
# 12                     Albania   2020
# 13                      Algeria  2020
# 14                      Algeria  2020
#
#                                             Indicator  data_col  \
# 0   What is the % change of government digitizing ...    0.6900
# 1                             R&D spending (% of GDP)       NaN
# 2                               E-Participation index    0.4643
# 3   Evidence of digital strategies in/across Minst...    2.0000
# 4                          Online-Service-Index (OSI)    0.4118
# 5                             R&D spending (% of GDP)       NaN
# 6                             R&D spending (% of GDP)       NaN
# 7                             R&D spending (% of GDP)       NaN
# 8   Evidence of digital strategies in/across Minst...    3.0000
# 9   What is the % change of government digitizing ...    0.7900
# 10             Evidence of focus on vulnerable groups    0.0300
# 11                              E-Participation index    0.8452
# 12                         Online-Service-Index (OSI)    0.8412
# 13  Evidence of digital strategies in/across Minst...    2.0000
# 14  % of digital skills certifications / training ...   95.0000
#
#     new_rank_score  higher_is_better                   Sub-Pillar  Unnamed: 0  \
# 0         4.520408              True      Digital Public Services         NaN
# 1         0.000000              True      Digital Public Services         NaN
# 2         3.321500              True      Digital Public Services        29.0
# 3         0.000000              True      Funding and procurement         NaN
# 4         3.059000              True      Digital Public Services        29.0
# 5         0.000000              True      Digital Public Services         NaN
# 6         0.000000              True      Digital Public Services         NaN
# 7         0.000000              True      Digital Public Services         NaN
# 8         0.000000              True      Funding and procurement         NaN
# 9         5.030612              True      Digital Public Services         NaN
# 10        0.000000              True  Leadership and coordination         NaN
# 11        5.226000              True      Digital Public Services        36.0
# 12        5.206000              True      Digital Public Services        36.0
# 13        0.000000              True      Funding and procurement         NaN
# 14        1.607477              True                 Capabilities         NaN
#
#       #  Flag  ... NGTI-1  NGTI-2 NGTI-3 NGTI-4 GTI-1 GTI-2 GTI-3 GTI-4  \
# 0   NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 3   1.0   NaN  ...   0.69    0.52   0.31   0.62 -0.09 -0.34  0.02 -0.12
# 4   NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 5   NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 6   NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 7   NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 8   2.0   NaN  ...   0.81    0.78   0.60   0.77  0.29  0.62  0.74  0.26
# 9   NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 10  2.0   NaN  ...   0.81    0.78   0.60   0.77  0.29  0.62  0.74  0.26
# 11  NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 12  NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
# 13  3.0   NaN  ...   0.73    0.46   0.02   0.60  0.06 -0.56 -0.68 -0.15
# 14  NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN
#
#     data_country data_year
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# 5            NaN       NaN
# 6            NaN       NaN
# 7            NaN       NaN
# 8            NaN       NaN
# 9            NaN       NaN
# 10           NaN       NaN
# 11           NaN       NaN
# 12           NaN       NaN
# 13           NaN       NaN
# 14           NaN       NaN
#
# [15 rows x 340 columns]

# %%
df.describe()
# Out:
#               Year     data_col  new_rank_score  Unnamed: 0           #  Flag  \
# count  1414.000000  1249.000000     1414.000000  386.000000  395.000000   0.0
# mean   2019.553041     6.573519        2.249773   96.000000   99.749367   NaN
# std       1.122857    18.441544        2.128344   55.785861   57.086011   NaN
# min    2010.000000   -20.000000        0.000000    0.000000    1.000000   NaN
# 25%    2020.000000     0.273800        0.000000   48.000000   50.500000   NaN
# 50%    2020.000000     0.723500        2.126724   96.000000  100.000000   NaN
# 75%    2020.000000     2.000000        4.329439  144.000000  149.000000   NaN
# max    2020.000000   108.000000        6.000000  192.000000  198.000000   NaN
#
#              Cnum        eSrv    ePart'20       DG St  ...      NGTI-1  \
# count  395.000000  395.000000  395.000000  395.000000  ...  381.000000
# mean   434.313924    0.003241    0.000304    2.318987  ...    0.717822
# std    253.830808    0.053952    0.059944    1.019863  ...    0.200766
# min      4.000000   -0.080000   -0.130000    0.000000  ...    0.000000
# 25%    213.000000   -0.020000   -0.050000    2.000000  ...    0.660000
# 50%    430.000000    0.050000    0.000000    3.000000  ...    0.760000
# 75%    659.000000    0.050000    0.050000    3.000000  ...    0.850000
# max    926.000000    0.050000    0.100000    3.000000  ...    1.000000
#
#            NGTI-2      NGTI-3      NGTI-4       GTI-1       GTI-2       GTI-3  \
# count  381.000000  381.000000  381.000000  381.000000  381.000000  381.000000
# mean     0.612021    0.303491    0.661207    0.000446    0.002835    0.004462
# std      0.215494    0.293886    0.252401    0.653818    0.779548    0.726303
# min      0.000000    0.000000    0.000000   -2.340000   -2.210000   -0.750000
# 25%      0.470000    0.050000    0.510000   -0.200000   -0.500000   -0.620000
# 50%      0.610000    0.180000    0.700000    0.130000    0.010000   -0.310000
# 75%      0.760000    0.550000    0.880000    0.430000    0.540000    0.600000
# max      1.000000    1.000000    1.000000    0.920000    1.400000    1.720000
#
#             GTI-4  data_country  data_year
# count  381.000000           0.0        0.0
# mean    -0.003885           NaN        NaN
# std      0.626705           NaN        NaN
# min     -1.650000           NaN        NaN
# 25%     -0.380000           NaN        NaN
# 50%      0.080000           NaN        NaN
# 75%      0.530000           NaN        NaN
# max      0.840000           NaN        NaN
#
# [8 rows x 120 columns]

# %%
# checking country names
# sorted(df['Country Name'].unique().tolist())

# %%
# remove trailing whitespaces from country name
df['Country Name'] = df['Country Name'].str.strip()
df['Country Name'] = df['Country Name'].str.strip('**')
df['Country Name'] = df['Country Name'].str.strip('*')

# %%
df.head()
# Out:
#   Country Name  Year                                          Indicator  \
# 0  Afghanistan  2020  What is the % change of government digitizing ...
# 1  Afghanistan  2018                            R&D spending (% of GDP)
# 2  Afghanistan  2020                              E-Participation index
# 3  Afghanistan  2020  Evidence of digital strategies in/across Minst...
# 4  Afghanistan  2020                         Online-Service-Index (OSI)
#
#    data_col  new_rank_score  higher_is_better               Sub-Pillar  \
# 0    0.6900        4.520408              True  Digital Public Services
# 1       NaN        0.000000              True  Digital Public Services
# 2    0.4643        3.321500              True  Digital Public Services
# 3    2.0000        0.000000              True  Funding and procurement
# 4    0.4118        3.059000              True  Digital Public Services
#
#    Unnamed: 0    #  Flag  ... NGTI-1  NGTI-2 NGTI-3 NGTI-4 GTI-1 GTI-2 GTI-3  \
# 0         NaN  NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 1         NaN  NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 2        29.0  NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
# 3         NaN  1.0   NaN  ...   0.69    0.52   0.31   0.62 -0.09 -0.34  0.02
# 4        29.0  NaN   NaN  ...    NaN     NaN    NaN    NaN   NaN   NaN   NaN
#
#   GTI-4  data_country data_year
# 0   NaN           NaN       NaN
# 1   NaN           NaN       NaN
# 2   NaN           NaN       NaN
# 3 -0.12           NaN       NaN
# 4   NaN           NaN       NaN
#
# [5 rows x 340 columns]

# %%
# checking country names
# sorted(df['Country Name'].unique().tolist())

# %%
# average indicator scores per country
agg_df = df.groupby(['Country Name']).agg({'new_rank_score':'mean','data_col':'count'})

# %%
agg_df.columns = ['agg_score', 'count_source' ]

# %%
max_number_sources = agg_df.describe()['count_source']['max']

# %%
agg_df['agg_score_wt'] = agg_df['agg_score']*(agg_df['count_source']/max_number_sources)

# %%
agg_df.sort_values(by='agg_score', ascending=False, inplace=True)

# %%
agg_df.head(25)
# Out:
#                                                     agg_score  count_source  \
# Country Name
# UAE                                                  6.000000             1
# USA                                                  6.000000             1
# North Korea                                          6.000000             1
# United Kingdom of Great Britain and Northern Ir...   5.837500             2
# Hong Kong                                            5.091244             2
# Republic of Korea                                    5.034268             3
# Taiwan                                               4.878505             1
# UK                                                   4.827160             1
# Russia                                               4.794672             2
# Republic of Moldova                                  4.787000             2
# Viet Nam                                             4.388250             2
# Slovakia                                             4.316822             3
# Georgia (Country)                                    4.077750             2
# Denmark                                              4.031602             8
# Sweden                                               3.879095             8
# Netherlands                                          3.857930             8
# United Republic of Tanzania                          3.781000             2
# France                                               3.770469             9
# Finland                                              3.769037             7
# North America                                        3.761989             1
# Norway                                               3.675559             8
# Post-demographic dividend                            3.651215             1
# Iran (Islamic Republic of)                           3.631250             2
# Israel                                               3.627705             8
# High income                                          3.613066             1
#
#                                                     agg_score_wt
# Country Name
# UAE                                                     0.666667
# USA                                                     0.666667
# North Korea                                             0.666667
# United Kingdom of Great Britain and Northern Ir...      1.297222
# Hong Kong                                               1.131388
# Republic of Korea                                       1.678089
# Taiwan                                                  0.542056
# UK                                                      0.536351
# Russia                                                  1.065483
# Republic of Moldova                                     1.063778
# Viet Nam                                                0.975167
# Slovakia                                                1.438941
# Georgia (Country)                                       0.906167
# Denmark                                                 3.583646
# Sweden                                                  3.448085
# Netherlands                                             3.429271
# United Republic of Tanzania                             0.840222
# France                                                  3.770469
# Finland                                                 2.931473
# North America                                           0.417999
# Norway                                                  3.267164
# Post-demographic dividend                               0.405691
# Iran (Islamic Republic of)                              0.806944
# Israel                                                  3.224626
# High income                                             0.401452

# %%
agg_df.to_csv('../pillar_scores/government_scores_v0.csv')

# %%
### Score Aggregating by Subpillars

# %%
df.insert(0,'Pillar','Government')
df

# %%
sub_df = df.groupby(['Pillar','Sub-Pillar','Country Name']).agg({'new_rank_score':'mean','data_col':'count'})

# %%
sub_df.columns = ['agg_score', 'count_source' ]

# %%
max_number_sources = sub_df.describe()['count_source']['max']

# %%
sub_df['agg_score_wt'] = sub_df['agg_score']*(sub_df['count_source']/max_number_sources)

# %%
sub_df.to_csv('../subpillar_score/government_scores_subpillar_v0.csv')

# %% [markdown]
# ### Sources Generation

# %%
#Get all countries from Countries.xlsx
countries = pd.read_excel('../../data/Countries.xlsx')
col_names = ['Country or Area']
countries = countries[col_names]
countries.rename(columns = {'Country or Area': 'Country Name'}, inplace = True)

# %%
#Get all indicators from names dataframe retrieve at the begining of the script
bnames=bnames[['check','Sub-Pillar','Indicator','Data Source','Data Link']]
bnames.rename(columns = {'check': 'Pillar'}, inplace = True)

# %%
#Do a nice cross join so that we have combination of all countries vs all indicators
sources = countries.merge(bnames, how='cross')
sources
# Out:
#                    Country Name      Pillar                   Sub-Pillar  \
# 0                       Algeria  Government      Digital Public Services
# 1                       Algeria  Government      Digital Public Services
# 2                       Algeria  Government      Digital Public Services
# 3                       Algeria  Government      Digital Public Services
# 4                       Algeria  Government      Digital Public Services
# ...                         ...         ...                          ...
# 2485  Wallis and Futuna Islands  Government      Funding and procurement
# 2486  Wallis and Futuna Islands  Government      Funding and procurement
# 2487  Wallis and Futuna Islands  Government      Funding and procurement
# 2488  Wallis and Futuna Islands  Government  Leadership and coordination
# 2489  Wallis and Futuna Islands  Government                 Capabilities
#
#                                               Indicator  \
# 0                            Online-Service-Index (OSI)
# 1                                 E-Participation index
# 2     Use of public services online (% of services o...
# 3             Security incidents (# of relevant issues)
# 4     What is the % change of government digitizing ...
# ...                                                 ...
# 2485                            R&D spending (% of GDP)
# 2486              ICT investment as a percentage of GDP
# 2487  Evidence of digital strategies in/across Minst...
# 2488             Evidence of focus on vulnerable groups
# 2489  % of digital skills certifications / training ...
#
#                                             Data Source  \
# 0                               UN: E-Government Survey
# 1                               UN: E-Government Survey
# 2     Boston Consulting Group/Salesforce: The Global...
# 3                                               SPECOPS
# 4                           World Bank: GovTech Dataset
# ...                                                 ...
# 2485           World Bank: World Development Indicators
# 2486                        OECD: Going Digital Toolkit
# 2487                        World Bank: GovTech Dataset
# 2488                        World Bank: GovTech Dataset
# 2489                    Coursera: Global Skills Reports
#
#                                            Data Link
# 0         https://publicadministration.un.org/egovkb
# 1         https://publicadministration.un.org/egovkb
# 2                         https://www.salesforce.com
# 3                            https://specopssoft.com
# 4                  https://datacatalog.worldbank.org
# ...                                              ...
# 2485               https://datacatalog.worldbank.org
# 2486                           https://data.oecd.org
# 2487               https://datacatalog.worldbank.org
# 2488               https://datacatalog.worldbank.org
# 2489  https://www.coursera.org/skills-reports/global
#
# [2490 rows x 6 columns]

# %%
#Make copy of a scores dataframe and add the column available, with value of 1 (string)
#denoting all the country/indicator combinations that have value
dfsources = df[['Country Name','Pillar','Sub-Pillar','Indicator']].copy()
dfsources['Available'] = '1'

# %%
#If sources.csv exists, get the contents, remove everyhing from this pillar, append prepared sources, save csv.
#if sources.csv does not exist, create new file from sources.
from os.path import exists

if exists('../../dashboard/Sources.csv') :
    CurrentSources = pd.read_csv('../../dashboard/Sources.csv', dtype=str)
    CurrentSources = CurrentSources[['Country Name','Pillar','Sub-Pillar','Indicator','Data Source','Data Link','Available']]
    CurrentSources.loc[CurrentSources['Pillar'] != 'Government']
    CurrentSources = CurrentSources.append(sources)
else :
    CurrentSources = sources
CurrentSources
# Out:
#                    Country Name      Pillar                   Sub-Pillar  \
# 0                       Algeria    Strategy                     Ambition
# 1                         Egypt    Strategy                     Ambition
# 2                         Libya    Strategy                     Ambition
# 3                       Morocco    Strategy                     Ambition
# 4                         Sudan    Strategy                     Ambition
# ...                         ...         ...                          ...
# 2485  Wallis and Futuna Islands  Government      Funding and procurement
# 2486  Wallis and Futuna Islands  Government      Funding and procurement
# 2487  Wallis and Futuna Islands  Government      Funding and procurement
# 2488  Wallis and Futuna Islands  Government  Leadership and coordination
# 2489  Wallis and Futuna Islands  Government                 Capabilities
#
#                                               Indicator  \
# 0                                             SDG Index
# 1                                             SDG Index
# 2                                             SDG Index
# 3                                             SDG Index
# 4                                             SDG Index
# ...                                                 ...
# 2485                            R&D spending (% of GDP)
# 2486              ICT investment as a percentage of GDP
# 2487  Evidence of digital strategies in/across Minst...
# 2488             Evidence of focus on vulnerable groups
# 2489  % of digital skills certifications / training ...
#
#                                    Data Source  \
# 0               Sustainable Development Report
# 1               Sustainable Development Report
# 2               Sustainable Development Report
# 3               Sustainable Development Report
# 4               Sustainable Development Report
# ...                                        ...
# 2485  World Bank: World Development Indicators
# 2486               OECD: Going Digital Toolkit
# 2487               World Bank: GovTech Dataset
# 2488               World Bank: GovTech Dataset
# 2489           Coursera: Global Skills Reports
#
#                                            Data Link Available
# 0                           https://www.sdgindex.org         1
# 1                           https://www.sdgindex.org         0
# 2                           https://www.sdgindex.org         1
# 3                           https://www.sdgindex.org         1
# 4                           https://www.sdgindex.org         1
# ...                                              ...       ...
# 2485               https://datacatalog.worldbank.org       NaN
# 2486                           https://data.oecd.org       NaN
# 2487               https://datacatalog.worldbank.org       NaN
# 2488               https://datacatalog.worldbank.org       NaN
# 2489  https://www.coursera.org/skills-reports/global       NaN
#
# [34862 rows x 7 columns]

# %%
CurrentSources.to_csv('../../dashboard/Sources.csv', index=False)
