# %%
import pandas as pd
import numpy as np

# %%
### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False           Countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              20         25
# Foundations            9         12
# Government            11         15
# Infrastructure        45         48
# People                38         46
# Regulation             6          7
# Strategy               1          1

# %%
### People

# %%
bnames = names[(names.check=='People')&(~names.Filename.isna())]#&(names.Index==False)]
bnames
# Out:
#                                              Indicator   check  \
# 99                           Human Capital Index (HCI)  People
# 100               % of population using internet (all)  People
# 101            % of population using internet (female)  People
# 102              % of population using internet (male)  People
# 103                      SDG 4.4 Digital literacy data  People
# 104                UNDP Human Development Index (HDI)   People
# 105                Facebook Social Connectedness Index  People
# 106  Share of individuals using the Internet to int...  People
# 107  Level of satisfaction for online public servic...  People
# 108  Number of mobile apps available in national la...  People
# 109  Device Addiction (time of use on internet / on...  People
# 110                           Gross National Wellbeing  People
# 112         % of internet users who own cryptocurrency  People
# 115  Percentage of individuals not buying online du...  People
# 116  Percentage of individuals not buying online du...  People
# 117        E-waste generated, kilograms per inhabitant  People
# 118                        Automation-led unemployment  People
# 122                                      Cyberbullying  People
# 126  Global Wellbeing Initiative (World Happiness I...  People
# 127                            Financial Inclusiveness  People
# 128  E-commerce activity (% of individuals buying o...  People
# 129  E-commerce activity (Types of goods and servic...  People
# 130                               Top Visited websites  People
# 131                               Top YouTube Searches  People
# 132                                Top Google searches  People
# 133                                     Internet Usage  People
# 134  Households with a computer and with Internet a...  People
# 135                     % of population using Facebook  People
# 136                    Gender gap for social media use  People
# 137   % of population using digital financial services  People
# 138                Mobile Broadband Pricing (pre-paid)  People
# 139         Tax as % of total cost of mobile ownership  People
# 140                    % of population with a SIM card  People
# 141                  % of population with a smartphone  People
# 142                       Gender gap in internet usage  People
# 143                         Gender gap in mobile usage  People
# 144                          Mobile Device Penetration  People
# 145                 Mobile Device Penetration (female)  People
#
#                                            Data Source  Index  \
# 99                                                DESA   True
# 100                                         World Bank  False
# 101                                                ITU  False
# 102                                                ITU  False
# 103                                             UNESCO  False
# 104                                               UNDP   True
# 105                                           Facebook   True
# 106                                               OECD  False
# 107                 Boston Consulting Group/SalesForce  False
# 108                     GSMA Mobile Connectivity Index  False
# 109  Statista/DataReportal; Hootsuite; We Are Social\n  False
# 110                                Portulans Institute  TRUE
# 112                                           Statista  False
# 115                                               OECD  False
# 116                                               OECD  False
# 117                                         UNU UNITAR   True
# 118                          McKinsey Global Institute  False
# 122                                              IPSOS  False
# 126                             World Happiness Report  TRUE
# 127                                         World Bank  TRUE
# 128                                Portulans Institute  False
# 129                   Statista/Salesforce Research\n\n  False
# 130                                      Data Reportal  False
# 131                                      Data Reportal  False
# 132                                      Data Reportal  False
# 133                                         World Bank  False
# 134                                         World Bank  False
# 135                            World Population Review  False
# 136                     GSMA Mobile Connectivity Index  False
# 137                                         World Bank  False
# 138                   Alliance for Affordable Internet  False
# 139                     GSMA Mobile Connectivity Index  False
# 140                                         World Bank  False
# 141                                    Statista/Newzoo  False
# 142                                                ITU  False
# 143                     GSMA Mobile Connectivity Index  False
# 144                     GSMA Mobile Connectivity Index  False
# 145                     GSMA Mobile Connectivity Index  False
#
#                                       Filename
# 99                          e_government_index
# 100                  population_using_internet
# 101                  gender_gap_internet_usage
# 102                  gender_gap_internet_usage
# 103              SDG 4.4_Digital_literacy_data
# 104                      undp_human_developmnt
# 105                    fb_social_connectedness
# 106    population_interacting_public_officials
# 107                 digital_public_service_use
# 108                  apps_in_national_language
# 109                          time_spent_online
# 110                            happiness_score
# 112                    cryptocurrency_adoption
# 115  not_buying_online_concern_about_returning
# 116   not_buying_online_concern_about_security
# 117                      ewaste_per_inhabitant
# 118                automation_led_unemployment
# 122                         cyberbullying_rate
# 126               global_wellbeing_initiative
# 127                   financial_inclusiveness
# 128    individuals buying online and frequency
# 129                        e-commerce_activity
# 130                                  top_sites
# 131                           youtube_searches
# 132                              google_trends
# 133                              intenet_usage
# 134                  household_internet_access
# 135                                   FB_users
# 136                                gender_gaps
# 137      population_digital_financial_services
# 138                   mobile_broadband_pricing
# 139               tax_percent_mobile_ownership
# 140                percent_mobile_subscription
# 141                population_with_smartphones
# 142                  gender_gap_internet_usage
# 143                                gender_gaps
# 144                           mobile_ownership
# 145                                gender_gaps

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['e_government_index', 'population_using_internet',
#        'gender_gap_internet_usage', 'SDG 4.4_Digital_literacy_data',
#        'undp_human_developmnt', 'fb_social_connectedness',
#        'population_interacting_public_officials',
#        'digital_public_service_use', 'apps_in_national_language',
#        'time_spent_online', ' happiness_score', 'cryptocurrency_adoption',
#        'not_buying_online_concern_about_returning',
#        'not_buying_online_concern_about_security',
#        'ewaste_per_inhabitant', 'automation_led_unemployment',
#        'cyberbullying_rate', 'global_wellbeing_initiative ',
#        'financial_inclusiveness ',
#        'individuals buying online and frequency', 'e-commerce_activity',
#        'top_sites', 'youtube_searches', 'google_trends', 'intenet_usage',
#        'household_internet_access', 'FB_users', 'gender_gaps',
#        'population_digital_financial_services',
#        'mobile_broadband_pricing', 'tax_percent_mobile_ownership',
#        'percent_mobile_subscription', 'population_with_smartphones',
#        'mobile_ownership'], dtype=object)

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %%
### 1. Human Capital Index (HCI)

# %%
indicators[0]

# load data
indicator = indicators[0]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Human Capital Index (HCI)
# e_government_index

# %%
df.head(10)
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
# 5         2020       Japan                  14              0.8989
# 6         2020      Jordan                 117              0.5309
# 7         2020  Kazakhstan                  29              0.8375
# 8         2020       Kenya                 116              0.5326
# 9         2020    Kiribati                 145              0.4320
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
# 5                 0.9881                0.9059               0.8684
# 6                 0.3333                0.3588               0.6800
# 7                 0.8810                0.9235               0.8866
# 8                 0.5952                0.6765               0.5812
# 9                 0.5595                0.4941               0.6778
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151
# 5                                  0.9223
# 6                                  0.5540
# 7                                  0.7024
# 8                                  0.3402
# 9                                  0.1241

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Human Capital Index'] 
df['Year'] = df['Survey Year']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                          Country Name  Year                  Indicator  \
# 0                               Iraq   2020  Human Capital Index (HCI)
# 1                            Ireland   2020  Human Capital Index (HCI)
# 2                             Israel   2020  Human Capital Index (HCI)
# 3                              Italy   2020  Human Capital Index (HCI)
# 4                            Jamaica   2020  Human Capital Index (HCI)
# 5                              Japan   2020  Human Capital Index (HCI)
# 6                             Jordan   2020  Human Capital Index (HCI)
# 7                         Kazakhstan   2020  Human Capital Index (HCI)
# 8                              Kenya   2020  Human Capital Index (HCI)
# 9                           Kiribati   2020  Human Capital Index (HCI)
# 10                            Kuwait   2020  Human Capital Index (HCI)
# 11                        Kyrgyzstan   2020  Human Capital Index (HCI)
# 12  Lao People's Democratic Republic   2020  Human Capital Index (HCI)
# 13                            Latvia   2020  Human Capital Index (HCI)
# 14                           Lebanon   2020  Human Capital Index (HCI)
#
#     data_col  new_rank_score  higher_is_better
# 0     0.4358          3.1790              True
# 1     0.9494          5.7470              True
# 2     0.8924          5.4620              True
# 3     0.8466          5.2330              True
# 4     0.7142          4.5710              True
# 5     0.8684          5.3420              True
# 6     0.6800          4.4000              True
# 7     0.8866          5.4330              True
# 8     0.5812          3.9060              True
# 9     0.6778          4.3890              True
# 10    0.7470          4.7350              True
# 11    0.7873          4.9365              True
# 12    0.5539          3.7695              True
# 13    0.9172          5.5860              True
# 14    0.6567          4.2835              True

# %%
### 2. % of population using internet (all)

# %%
indicators[1]

# load data
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population using internet (all)
# population_using_internet
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-72afceee5c73> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/population_using_internet.csv'

# %%
### 3. % of population using internet (female)

# %%
indicators[2]

# load data
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)
# Need to move the top row down one

# %%
### 4. % of population using internet (male)

# %%
indicators[3]

# load data
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)
# Need to move the top row down one

# %%
### 5. SDG 4.4 Digital literacy data

# %%
indicators[4]

# load data
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
### 6. UNDP Human Development Index (HDI)

# %%
indicators[5]

# load data
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)
# Need to move the top row down

# %%
### 7. Facebook Social Connectedness Index

# %%
indicators[6]

# load data
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(25)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['scaled_sci'] 
df['Country Name'] = df['fr_loc']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].head(30)

# Need to find a way to convert ISO codes to full country names

# %%
### 8. Share of individuals using the Internet to interact with officials

# %%
indicators[7]

# load data
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year
df = df[(df.Time==2019)]
df = df[(df.Indicator=='Individuals using the Internet for visiting or interacting with public authorities websites - last 12 m (%)')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Year'] = df['Time']
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# Need to find a way to convert ISO codes to full country names

# %%
### 9. Level of satisfaction for online public service

# %%
indicators[8]

# load data
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Net Perception'] 
df['Year'] = 2020
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# Need to replace the % mark

# %%
### 10. Number of mobile apps available in national language

# %%
indicators[9]

# load data
indicator = indicators[9]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year and global value
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Number of apps in national language'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 11. Device Addiction (time of use on internet)

# %%
indicators[10]

# load data
indicator = indicators[10]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# Need to move the row further down

# %%
# filter most recent year and global value
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Number of apps in national language'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
### 12. Gross National Wellbeing

# %%
indicators[11]

# load data
indicator = indicators[11]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# happiness_score is missing has been fixed

# %%
### 13. % of internet users who own cryptocurrency

# %%
indicators[12]

# load data
indicator = indicators[12]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# Need to move the top row down

# %%
### 14. Percentage of individuals not buying online due to concerns about returning products

# %%
indicators[13]

# load data
indicator = indicators[13]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year and global value
df = df[(df.Time==2019)]
df = df[(df.Scope =='All individuals (aged 16-74)')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = False
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Year'] = df['Time']
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 15. Percentage of individuals not buying online due to payment security concerns

# %%
indicators[14]

# load data
indicator = indicators[14]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Percentage of individuals not buying online due to payment security concerns
# not_buying_online_concern_about_security

# %%
df.head(15)
# Out:
#                                             Indicator  Country  \
# 0   Individuals who did not buy online for payment...  Austria
# 1   Individuals who did not buy online for payment...  Austria
# 2   Individuals who did not buy online for payment...  Austria
# 3   Individuals who did not buy online for payment...  Austria
# 4   Individuals who did not buy online for payment...  Austria
# 5   Individuals who did not buy online for payment...  Austria
# 6   Individuals who did not buy online for payment...  Austria
# 7   Individuals who did not buy online for payment...  Austria
# 8   Individuals who did not buy online for payment...  Austria
# 9   Individuals who did not buy online for payment...  Austria
# 10  Individuals who did not buy online for payment...  Austria
# 11  Individuals who did not buy online for payment...  Austria
# 12  Individuals who did not buy online for payment...  Belgium
# 13  Individuals who did not buy online for payment...  Belgium
# 14  Individuals who did not buy online for payment...  Belgium
#
#                                              Variable  \
# 0   Individuals who, in the last 12 months, haven'...
# 1   Individuals who, in the last 12 months, haven'...
# 2   Individuals who, in the last 12 months, haven'...
# 3   Individuals who, in the last 12 months, haven'...
# 4   Individuals who, in the last 12 months, haven'...
# 5   Individuals who, in the last 12 months, haven'...
# 6   Individuals who, in the last 12 months, haven'...
# 7   Individuals who, in the last 12 months, haven'...
# 8   Individuals who, in the last 12 months, haven'...
# 9   Individuals who, in the last 12 months, haven'...
# 10  Individuals who, in the last 12 months, haven'...
# 11  Individuals who, in the last 12 months, haven'...
# 12  Individuals who, in the last 12 months, haven'...
# 13  Individuals who, in the last 12 months, haven'...
# 14  Individuals who, in the last 12 months, haven'...
#
#                                                  Unit  \
# 0   Percentage of individuals who ordered goods or...
# 1   Percentage of individuals who ordered goods or...
# 2   Percentage of individuals who ordered goods or...
# 3   Percentage of individuals who ordered goods or...
# 4   Percentage of individuals who ordered goods or...
# 5   Percentage of individuals who ordered goods or...
# 6   Percentage of individuals who ordered goods or...
# 7   Percentage of individuals who ordered goods or...
# 8   Percentage of individuals who ordered goods or...
# 9   Percentage of individuals who ordered goods or...
# 10  Percentage of individuals who ordered goods or...
# 11  Percentage of individuals who ordered goods or...
# 12  Percentage of individuals who ordered goods or...
# 13  Percentage of individuals who ordered goods or...
# 14  Percentage of individuals who ordered goods or...
#
#                            Scope  Time     Value  Flags
# 0   All individuals (aged 16-74)  2009  38.80930    NaN
# 1   All individuals (aged 16-74)  2015  34.89850    NaN
# 2   All individuals (aged 16-74)  2017  33.04743    NaN
# 3   All individuals (aged 16-74)  2019  31.19888    NaN
# 4         Individuals aged 16-24  2009  38.34010    NaN
# 5         Individuals aged 16-24  2015  34.96870    NaN
# 6         Individuals aged 16-24  2017  16.65675    NaN
# 7         Individuals aged 16-24  2019  12.88121    NaN
# 8         Individuals aged 55-74  2009  40.57610    NaN
# 9         Individuals aged 55-74  2015  42.60200    NaN
# 10        Individuals aged 55-74  2017  35.10980    NaN
# 11        Individuals aged 55-74  2019  39.53044    NaN
# 12  All individuals (aged 16-74)  2009  35.44600    NaN
# 13  All individuals (aged 16-74)  2015  23.41350    NaN
# 14  All individuals (aged 16-74)  2017  15.29681    NaN

# %%
# filter most recent year and global value
df = df[(df.Time==2019)]
df = df[(df.Scope =='All individuals (aged 16-74)')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = False
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Year'] = df['Time']
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#                       Country Name  Year  \
# 3                          Austria  2019
# 15                         Belgium  2019
# 27                  Czech Republic  2019
# 39                         Denmark  2019
# 51                         Estonia  2019
# 84   European Union (28 countries)  2019
# 96                         Finland  2019
# 108                         France  2019
# 120                        Germany  2019
# 132                         Greece  2019
# 144                        Hungary  2019
# 155                        Iceland  2019
# 164                        Ireland  2019
# 176                          Italy  2019
# 188                         Latvia  2019
# 200                      Lithuania  2019
# 212                     Luxembourg  2019
# 224                    Netherlands  2019
# 236                         Norway  2019
# 247                         Poland  2019
#
#                                              Indicator   data_col  \
# 3    Percentage of individuals not buying online du...  31.198880
# 15   Percentage of individuals not buying online du...  18.129610
# 27   Percentage of individuals not buying online du...   9.814267
# 39   Percentage of individuals not buying online du...  18.770550
# 51   Percentage of individuals not buying online du...   4.357608
# 84   Percentage of individuals not buying online du...  24.308600
# 96   Percentage of individuals not buying online du...  64.427210
# 108  Percentage of individuals not buying online du...  40.843490
# 120  Percentage of individuals not buying online du...  25.121840
# 132  Percentage of individuals not buying online du...  23.223810
# 144  Percentage of individuals not buying online du...  42.285470
# 155  Percentage of individuals not buying online du...  25.921260
# 164  Percentage of individuals not buying online du...  16.830400
# 176  Percentage of individuals not buying online du...   8.159797
# 188  Percentage of individuals not buying online du...  11.267850
# 200  Percentage of individuals not buying online du...  13.799410
# 212  Percentage of individuals not buying online du...  12.390420
# 224  Percentage of individuals not buying online du...  29.817950
# 236  Percentage of individuals not buying online du...  35.544350
# 247  Percentage of individuals not buying online du...   6.025776
#
#      new_rank_score  higher_is_better
# 3          3.765819             False
# 15         4.853663             False
# 27         5.545805             False
# 39         4.800313             False
# 51         6.000000             False
# 84         4.339344             False
# 96         1.000000             False
# 108        2.963033             False
# 120        4.271652             False
# 132        4.429638             False
# 144        2.843007             False
# 155        4.205111             False
# 164        4.961805             False
# 176        5.683518             False
# 188        5.424814             False
# 200        5.214095             False
# 212        5.331375             False
# 224        3.880763             False
# 236        3.404116             False
# 247        5.861147             False

# %%
### 16. E-waste generated, kilograms per inhabitant

# %%
indicators[15]

# load data
indicator = indicators[15]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# E-waste generated, kilograms per inhabitant
# ewaste_per_inhabitant

# %%
df.head(15)
# Out:
#    iso3c region_id          country_name income_id           gdp  \
# 0    ABW       LCN                 Aruba       HIC  35563.312500
# 1    AFG       SAS           Afghanistan       LIC   2057.062256
# 2    AGO       SSF                Angola       LMC   8036.690430
# 3    ALB       ECS               Albania       UMC  13724.058594
# 4    AND       ECS               Andorra       HIC  43711.800781
# 5    ARE       MEA  United Arab Emirates       HIC  67119.132812
# 6    ARG       LCN             Argentina       HIC  23550.099609
# 7    ARM       ECS               Armenia       UMC  11019.838867
# 8    ASM       EAS        American Samoa       UMC  11113.442383
# 9    ATG       LCN   Antigua and Barbuda       HIC  17965.501953
# 10   AUS       EAS             Australia       HIC  47784.179688
# 11   AUT       ECS               Austria       HIC  56029.613281
# 12   AZE       ECS            Azerbaijan       UMC  14853.910156
# 13   BDI       SSF               Burundi       LIC    839.778503
# 14   BEL       ECS               Belgium       HIC  51914.914062
#
#     composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                    51.80                       6.70
# 3                                    51.40                       4.50
# 4                                    31.20                       8.20
# 5                                    39.00                       4.00
# 6                                    38.74                       3.16
# 7                                    57.00                       3.20
# 8                                    19.70                       3.40
# 9                                    46.00                       7.00
# 10                                   48.44                       3.81
# 11                                   31.40                       7.00
# 12                                   45.19                       5.28
# 13                                   81.00                       2.90
# 14                                   14.18                       3.10
#
#     composition_metal_percent  composition_other_percent  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                        4.40                      11.50
# 3                        4.80                      15.21
# 4                        2.60                      11.60
# 5                        3.00                      10.00
# 6                        1.84                      15.36
# 7                        3.40                      17.40
# 8                        7.90                      25.60
# 9                        7.00                      12.00
# 10                      19.38                       3.46
# 11                       4.40                      18.50
# 12                       3.49                      13.73
# 13                       2.10                       3.20
# 14                       1.91                      40.14
#
#     composition_paper_cardboard_percent  ...  \
# 0                                   NaN  ...
# 1                                   NaN  ...
# 2                                 11.90  ...
# 3                                  9.90  ...
# 4                                 35.10  ...
# 5                                 25.00  ...
# 6                                 13.96  ...
# 7                                  6.70  ...
# 8                                 26.40  ...
# 9                                 15.00  ...
# 10                                17.30  ...
# 11                                19.70  ...
# 12                                10.93  ...
# 13                                 7.30  ...
# 14                                18.38  ...
#
#     waste_treatment_controlled_landfill_percent  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                          8.90
# 7                                           NaN
# 8                                           NaN
# 9                                         98.68
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
#
#     waste_treatment_incineration_percent  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                  52.10
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                  9.77
# 11                                 37.90
# 12                                   NaN
# 13                                   NaN
# 14                                 43.39
#
#     waste_treatment_landfill_unspecified_percent  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                           9.00
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                         48.87
# 11                                          2.98
# 12                                           NaN
# 13                                           NaN
# 14                                          0.91
#
#     waste_treatment_open_dump_percent waste_treatment_other_percent  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# 5                                62.0                           NaN
# 6                                22.6                           NaN
# 7                               100.0                           NaN
# 8                                 NaN                           NaN
# 9                                 NaN                           NaN
# 10                                NaN                           NaN
# 11                                NaN                           NaN
# 12                              100.0                           NaN
# 13                                NaN                           NaN
# 14                                NaN                           NaN
#
#    waste_treatment_recycling_percent  \
# 0                             11.000
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                             20.000
# 6                              6.000
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                            42.100
# 11                            25.660
# 12                               NaN
# 13                               NaN
# 14                            34.303
#
#    waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                62.5
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    waste_treatment_unaccounted_for_percent  \
# 0                                    89.00
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                    47.90
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                     1.14
# 10                                     NaN
# 11                                    2.22
# 12                                     NaN
# 13                                     NaN
# 14                                    2.26
#
#    waste_treatment_waterways_marine_percent  where_where_is_this_data_measured
# 0                                       NaN                                NaN
# 1                                       NaN                              Other
# 2                                       NaN                                NaN
# 3                                       NaN                Some disposal sites
# 4                                       NaN                                NaN
# 5                                       NaN                                NaN
# 6                                       NaN                              Other
# 7                                       NaN                              Other
# 8                                       NaN                                NaN
# 9                                       0.1                      Disposal Site
# 10                                      NaN                                NaN
# 11                                      NaN                                NaN
# 12                                      NaN                            Various
# 13                                      NaN                                NaN
# 14                                      NaN                                NaN
#
# [15 rows x 51 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
# Use special_waste_e_waste_tons_year times one thousand and divde by total population
df['data_col'] = df['special_waste_e_waste_tons_year']*1000/df['population_population_number_of_people'] 
df['Year'] = 2021
df['Country Name'] = df['country_name']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#             Country Name  Year                                    Indicator  \
# 0                  Aruba  2021  E-waste generated, kilograms per inhabitant
# 1            Afghanistan  2021  E-waste generated, kilograms per inhabitant
# 2                 Angola  2021  E-waste generated, kilograms per inhabitant
# 3                Albania  2021  E-waste generated, kilograms per inhabitant
# 4                Andorra  2021  E-waste generated, kilograms per inhabitant
# 5   United Arab Emirates  2021  E-waste generated, kilograms per inhabitant
# 6              Argentina  2021  E-waste generated, kilograms per inhabitant
# 7                Armenia  2021  E-waste generated, kilograms per inhabitant
# 8         American Samoa  2021  E-waste generated, kilograms per inhabitant
# 9    Antigua and Barbuda  2021  E-waste generated, kilograms per inhabitant
# 10             Australia  2021  E-waste generated, kilograms per inhabitant
# 11               Austria  2021  E-waste generated, kilograms per inhabitant
# 12            Azerbaijan  2021  E-waste generated, kilograms per inhabitant
# 13               Burundi  2021  E-waste generated, kilograms per inhabitant
# 14               Belgium  2021  E-waste generated, kilograms per inhabitant
# 15                 Benin  2021  E-waste generated, kilograms per inhabitant
# 16          Burkina Faso  2021  E-waste generated, kilograms per inhabitant
# 17            Bangladesh  2021  E-waste generated, kilograms per inhabitant
# 18              Bulgaria  2021  E-waste generated, kilograms per inhabitant
# 19               Bahrain  2021  E-waste generated, kilograms per inhabitant
#
#      data_col  new_rank_score  higher_is_better
# 0         NaN             NaN              True
# 1    0.577100        1.040883              True
# 2    3.665901        1.261006              True
# 3    7.007240        1.499126              True
# 4         NaN             NaN              True
# 5   13.714713        1.977133              True
# 6    6.786638        1.483405              True
# 7    4.817254        1.343057              True
# 8         NaN             NaN              True
# 9   11.366337        1.809777              True
# 10  24.128456        2.719267              True
# 11  18.719471        2.333797              True
# 12   6.528943        1.465040              True
# 13   0.741667        1.052611              True
# 14  52.557655        4.745269              True
# 15   1.485033        1.105587              True
# 16   0.607378        1.043041              True
# 17   0.911852        1.064739              True
# 18   7.656187        1.545373              True
# 19  14.033404        1.999845              True

# %%
### 17. Automation-led unemployment

# %%
indicators[16]

# load data
indicator = indicators[16]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Automation-led unemployment
# automation_led_unemployment

# %%
df.head(15)
# Out:
#         Country  No. of employees potentially automable (millions)  \
# 0         Japan                                              35.60
# 1      Thailand                                              21.00
# 2       Senegal                                               2.20
# 3      Colombia                                               9.30
# 4          Peru                                               6.90
# 5        Taiwan                                               5.20
# 6         Kenya                                               7.40
# 7   South Korea                                              12.50
# 8        Sweden                                               2.10
# 9    Costa Rica                                               1.10
# 10        Qatar                                               0.54
# 11    Indonesia                                              52.60
# 12        India                                             235.10
# 13       Mexico                                              25.50
# 14     Malaysia                                               6.30
#
#     Total employees (millions)  Potential Rate of Automation (%)
# 0                        63.90                             55.71
# 1                        38.40                             54.69
# 2                         4.07                             54.00
# 3                        17.50                             53.14
# 4                        13.00                             53.08
# 5                         9.80                             53.06
# 6                        14.20                             52.11
# 7                        24.00                             52.08
# 8                         4.04                             52.00
# 9                         2.12                             52.00
# 10                        1.04                             52.00
# 11                      101.50                             51.82
# 12                      454.20                             51.76
# 13                       49.30                             51.72
# 14                       12.20                             51.64

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Potential Rate of Automation (%)'] 
df['Year'] = 2018
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#    Country Name  Year                    Indicator  data_col  new_rank_score  \
# 0         Japan  2018  Automation-led unemployment     55.71        6.000000
# 1      Thailand  2018  Automation-led unemployment     54.69        5.656797
# 2       Senegal  2018  Automation-led unemployment     54.00        5.424630
# 3      Colombia  2018  Automation-led unemployment     53.14        5.135262
# 4          Peru  2018  Automation-led unemployment     53.08        5.115074
# 5        Taiwan  2018  Automation-led unemployment     53.06        5.108345
# 6         Kenya  2018  Automation-led unemployment     52.11        4.788694
# 7   South Korea  2018  Automation-led unemployment     52.08        4.778600
# 8        Sweden  2018  Automation-led unemployment     52.00        4.751682
# 9    Costa Rica  2018  Automation-led unemployment     52.00        4.751682
# 10        Qatar  2018  Automation-led unemployment     52.00        4.751682
# 11    Indonesia  2018  Automation-led unemployment     51.82        4.691117
# 12        India  2018  Automation-led unemployment     51.76        4.670929
# 13       Mexico  2018  Automation-led unemployment     51.72        4.657470
# 14     Malaysia  2018  Automation-led unemployment     51.64        4.630552
# 15        China  2018  Automation-led unemployment     51.17        4.472409
# 16        Ghana  2018  Automation-led unemployment     50.79        4.344549
# 17     Tanzania  2018  Automation-led unemployment     50.50        4.246972
# 18      Morroco  2018  Automation-led unemployment     50.45        4.230148
# 19        Italy  2018  Automation-led unemployment     50.43        4.223419
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19              True

# %%
### 18. Cyberbullying

# %%
indicators[17]

# load data
indicator = indicators[17]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Cyberbullying
# cyberbullying_rate

# %%
df.head(15)

# Need to move the top row down further
# Out:
#    Rates of Cyberbullying (Source: IPSOS) Unnamed: 1
# 0                                 Country       2011
# 1                                   India         32
# 2                                  Brazil         20
# 3                           United States         15
# 4                                 Belgium         12
# 5                            South Africa         10
# 6                                Malaysia         --
# 7                                  Sweden         14
# 8                                  Canada         18
# 9                                  Turkey          5
# 10                           Saudi Arabia         18
# 11                              Australia         13
# 12                                 Mexico          8
# 13                          Great Britain         11
# 14                                  China         11

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Potential Rate of Automation (%)'] 
df['Year'] = 2018
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank
# Out:
#   File "<ipython-input-62-0b09e91c7e25>", line 13
#     df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank
#                                                                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
### 19. Global Wellbeing Initiative

# %%
indicators[18]

# load data
indicator = indicators[18]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Strange the global_wellbeing_initiative is clearly in the data manifest and the link works well 
# but it has not been moved to the processed folder
# Out:
# Global Wellbeing Initiative (World Happiness Index)
# global_wellbeing_initiative
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-69-aa63dc7f3d28> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#      10
#      11 # Strange the global_wellbeing_initiative is clearly in the data manifest but it has not been moved to the processed folder
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/global_wellbeing_initiative .csv'

# %%
### 20. Financial Inclusiveness

# %%
indicators[19]

# load data
indicator = indicators[19]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)


df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Strange the global_wellbeing_initiative is clearly in the data manifest and the link works well 
# but it has not been moved to the processed folder
# Out:
# Financial Inclusiveness
# financial_inclusiveness
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-72-3d1976bc798c> in <module>
#       8
#       9
# ---> 10 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#      11 # Strange the global_wellbeing_initiative is clearly in the data manifest and the link works well but it has not been moved to the processed folder
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/financial_inclusiveness .csv'

# %%
### 21. E-commerce activity (% of individuals buying online and frequency)
