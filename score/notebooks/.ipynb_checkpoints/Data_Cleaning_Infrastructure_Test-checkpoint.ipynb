# %%
import pandas as pd
import numpy as np

# %%
### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False           Countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              20         25
# Foundations            9         12
# Government            10         15
# Infrastructure        40         48
# People                39         47
# Regulation             6          7
# Strategy               1          1

# %%
### Infrastructure

# %%
bnames = names[(names.check=='Infrastructure')&(~names.Filename.isna())]#&(names.Index==False)]
bnames.head(25)
# Out:
#                                             Indicator           check  \
# 4                                  Population Density  Infrastructure
# 5                                   Broadband Density  Infrastructure
# 6    % of population covered by internet connectivity  Infrastructure
# 7   % of population covered by mobile 2G+ data con...  Infrastructure
# 8   % of population covered by mobile 3G+ data con...  Infrastructure
# 9   % of population covered by mobile 4G+ data con...  Infrastructure
# 10  % of population covered by mobile 5G+ data con...  Infrastructure
# 11                               Mobile Coverage Maps  Infrastructure
# 12                                Electricity Density  Infrastructure
# 13             % of population covered by electricity  Infrastructure
# 14                         Electricity supply quality  Infrastructure
# 15           Electricity Environmental Sustainability  Infrastructure
# 17                           Cellphone Signal Density  Infrastructure
# 18       Telecommunication Infrastructure Index (TII)  Infrastructure
# 19                    GSMA Mobile Connectivity Index   Infrastructure
# 20             Spectrum Allocated to Mobile Providers  Infrastructure
# 23                Internet Exchange Points (IXPs) map  Infrastructure
# 26               ISP internet download speed average   Infrastructure
# 28  Mobile dowload speed at the slowest hour of th...  Infrastructure
# 29                     Mobile download speed average   Infrastructure
# 30   Individuals using the Internet (% of population)  Infrastructure
# 31     Mobile cellular subscriptions (per 100 people)  Infrastructure
# 32           Average fixed broadband download speeds   Infrastructure
# 35                                    Postal Coverage  Infrastructure
# 36  Logistics Performance Index (LPI) - Infrastruc...  Infrastructure
#
#                                           Data Source  Index  \
# 4                                          World Bank  False
# 5                                                 ITU  False
# 6                                                 ITU  False
# 7                      GSMA Mobile Connectivity Index  False
# 8                      GSMA Mobile Connectivity Index  False
# 9                      GSMA Mobile Connectivity Index  False
# 10                     GSMA Mobile Connectivity Index  False
# 11                                                ITU  False
# 12                                        Energy Data  False
# 13                                        World Bank   False
# 14  International Energy Agency / Global Competiti...  False
# 15  The Sustainable Development Report/ Cambridge ...  False
# 17                     GSMA Mobile Connectivity Index  False
# 18                                               DESA   True
# 19                     GSMA Mobile Connectivity Index   True
# 20                     GSMA Mobile Connectivity Index  False
# 23                              Packet Clearing House  False
# 26                     Ookla's Speedtest Intelligence  False
# 28                     GSMA Mobile Connectivity Index  False
# 29                     Ookla's Speedtest Intelligence  False
# 30                                                ITU  False
# 31                                                ITU  False
# 32                     Ookla's Speedtest Intelligence  False
# 35                             Universal Postal Union  False
# 36                                         World Bank   True
#
#                                Filename
# 4                    population_density
# 5                          ITU_database
# 6                          ITU_database
# 7         countries_mobile_connectivity
# 8         countries_mobile_connectivity
# 9         countries_mobile_connectivity
# 10        countries_mobile_connectivity
# 11                         ITU_database
# 12                 electricity_yearbook
# 13      population_electricity_coverage
# 14                 elect_supply_quality
# 15                 sustainability_index
# 17                       mobile_density
# 18                   e_government_index
# 19        countries_mobile_connectivity
# 20  spectrum_allocated_mobile_providers
# 23                        countries_ixp
# 26                       internet_speed
# 28                       mobile_latency
# 29                         mobile_speed
# 30                         ITU_database
# 31                         ITU_database
# 32                 fixed_bdbd_spd_dl_ul
# 35                      postal_coverage
# 36          logistics_performance_index

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['population_density', 'ITU_database',
#        'countries_mobile_connectivity', 'electricity_yearbook',
#        'population_electricity_coverage', 'elect_supply_quality',
#        'sustainability_index', 'mobile_density', 'e_government_index',
#        'spectrum_allocated_mobile_providers', 'countries_ixp',
#        'internet_speed', 'mobile_latency', 'mobile_speed',
#        'fixed_bdbd_spd_dl_ul', 'postal_coverage',
#        'logistics_performance_index', 'schools_w_internet',
#        'national_cybersecurity_index',
#        'dice_export_global_cybersecurity_index',
#        'software_developer_ecosystem_size',
#        'digital_platform_economy_index', 'migration_skill',
#        'migration_industry', 'migration_country',
#        'global_fintech_ranking', 'tech_hubs', 'banking_sector_size',
#        'angel_investment', 'startup_eco_size',
#        'international_co_inventions'], dtype=object)

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %%
### 2. Broadband Density

# %%
indicators[1]

# load data
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Broadband Density
# ITU_database

# %%
### 3. % of population covered by internet connectivity

# %%
indicators[2]

# load data
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by internet connectivity
# ITU_database

# %%
### 4. % of population covered by mobile 2G

# %%
indicators[3]
# Out:
# '% of population covered by mobile 2G+ data connectivity'

# %%
# load data
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 2G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 2G+ data con...     90.00
# 11  % of population covered by mobile 2G+ data con...     90.00
# 17  % of population covered by mobile 2G+ data con...     99.86
# 23  % of population covered by mobile 2G+ data con...    100.00
# 29  % of population covered by mobile 2G+ data con...     98.00
# 35  % of population covered by mobile 2G+ data con...    100.00
# 41  % of population covered by mobile 2G+ data con...     99.40
# 47  % of population covered by mobile 2G+ data con...     99.00
# 53  % of population covered by mobile 2G+ data con...    100.00
# 59  % of population covered by mobile 2G+ data con...     53.65
# 65  % of population covered by mobile 2G+ data con...    100.00
# 71  % of population covered by mobile 2G+ data con...     98.00
# 77  % of population covered by mobile 2G+ data con...     97.90
# 83  % of population covered by mobile 2G+ data con...     99.60
# 89  % of population covered by mobile 2G+ data con...    100.00
#
#     new_rank_score  higher_is_better
# 5         4.921251              True
# 11        4.921251              True
# 17        5.984898              True
# 23        6.000000              True
# 29        5.784250              True
# 35        6.000000              True
# 41        5.935275              True
# 47        5.892125              True
# 53        6.000000              True
# 59        1.000000              True
# 65        6.000000              True
# 71        5.784250              True
# 77        5.773463              True
# 83        5.956850              True
# 89        6.000000              True

# %%
### 5. % of population covered by mobile 3G

# %%
indicators[4]

# load data
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 3G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['3G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 3G+ data con...      58.7
# 11  % of population covered by mobile 3G+ data con...      71.0
# 17  % of population covered by mobile 3G+ data con...      97.0
# 23  % of population covered by mobile 3G+ data con...     100.0
# 29  % of population covered by mobile 3G+ data con...      95.0
# 35  % of population covered by mobile 3G+ data con...      99.0
# 41  % of population covered by mobile 3G+ data con...      99.5
# 47  % of population covered by mobile 3G+ data con...      99.0
# 53  % of population covered by mobile 3G+ data con...      95.0
# 59  % of population covered by mobile 3G+ data con...      40.0
# 65  % of population covered by mobile 3G+ data con...     100.0
# 71  % of population covered by mobile 3G+ data con...      89.0
# 77  % of population covered by mobile 3G+ data con...      65.0
# 83  % of population covered by mobile 3G+ data con...      95.0
# 89  % of population covered by mobile 3G+ data con...     100.0
#
#     new_rank_score  higher_is_better
# 5         3.282895              True
# 11        4.092105              True
# 17        5.802632              True
# 23        6.000000              True
# 29        5.671053              True
# 35        5.934211              True
# 41        5.967105              True
# 47        5.934211              True
# 53        5.671053              True
# 59        2.052632              True
# 65        6.000000              True
# 71        5.276316              True
# 77        3.697368              True
# 83        5.671053              True
# 89        6.000000              True

# %%
### 6. % of population covered by mobile 4G

# %%
indicators[5]

# load data
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 4G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['4G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 4G+ data con...     15.00
# 11  % of population covered by mobile 4G+ data con...     50.00
# 17  % of population covered by mobile 4G+ data con...     96.00
# 23  % of population covered by mobile 4G+ data con...     99.00
# 29  % of population covered by mobile 4G+ data con...     89.77
# 35  % of population covered by mobile 4G+ data con...     95.00
# 41  % of population covered by mobile 4G+ data con...     99.20
# 47  % of population covered by mobile 4G+ data con...     99.00
# 53  % of population covered by mobile 4G+ data con...     90.00
# 59  % of population covered by mobile 4G+ data con...     25.00
# 65  % of population covered by mobile 4G+ data con...    100.00
# 71  % of population covered by mobile 4G+ data con...     45.00
# 77  % of population covered by mobile 4G+ data con...      8.64
# 83  % of population covered by mobile 4G+ data con...     80.00
# 89  % of population covered by mobile 4G+ data con...    100.00
#
#     new_rank_score  higher_is_better
# 5           1.7500              True
# 11          3.5000              True
# 17          5.8000              True
# 23          5.9500              True
# 29          5.4885              True
# 35          5.7500              True
# 41          5.9600              True
# 47          5.9500              True
# 53          5.5000              True
# 59          2.2500              True
# 65          6.0000              True
# 71          3.2500              True
# 77          1.4320              True
# 83          5.0000              True
# 89          6.0000              True

# %%
### 7. % of population covered by mobile 5G

# %%
indicators[6]

# load data
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 5G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['5G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 5G+ data con...       0.0
# 11  % of population covered by mobile 5G+ data con...       0.0
# 17  % of population covered by mobile 5G+ data con...       0.0
# 23  % of population covered by mobile 5G+ data con...     100.0
# 29  % of population covered by mobile 5G+ data con...       0.0
# 35  % of population covered by mobile 5G+ data con...       0.0
# 41  % of population covered by mobile 5G+ data con...     100.0
# 47  % of population covered by mobile 5G+ data con...     100.0
# 53  % of population covered by mobile 5G+ data con...       0.0
# 59  % of population covered by mobile 5G+ data con...       0.0
# 65  % of population covered by mobile 5G+ data con...       0.0
# 71  % of population covered by mobile 5G+ data con...       0.0
# 77  % of population covered by mobile 5G+ data con...       0.0
# 83  % of population covered by mobile 5G+ data con...       0.0
# 89  % of population covered by mobile 5G+ data con...       0.0
#
#     new_rank_score  higher_is_better
# 5              1.0              True
# 11             1.0              True
# 17             1.0              True
# 23             6.0              True
# 29             1.0              True
# 35             1.0              True
# 41             6.0              True
# 47             6.0              True
# 53             1.0              True
# 59             1.0              True
# 65             1.0              True
# 71             1.0              True
# 77             1.0              True
# 83             1.0              True
# 89             1.0              True

# %%
### 8. Mobile Coverage Maps

# %%
indicators[7]

# load data
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Mobile Coverage Maps
# ITU_database

# %%
df.head(15)
# Out:
#                    Country  Region  ISO  \
# 0                   Angola  Africa  AGO
# 1                    Benin  Africa  BEN
# 2                 Botswana  Africa  BWA
# 3             Burkina Faso  Africa  BFA
# 4                  Burundi  Africa  BDI
# 5               Cabo Verde  Africa  CPV
# 6                 Cameroon  Africa  CMR
# 7     Central African Rep.  Africa  CAF
# 8                     Chad  Africa  TCD
# 9      Congo (Rep. of the)  Africa  COG
# 10           Côte d'Ivoire  Africa  CIV
# 11  Dem. Rep. of the Congo  Africa  COD
# 12       Equatorial Guinea  Africa  GNQ
# 13                 Eritrea  Africa  ERI
# 14                Eswatini  Africa  SWZ
#
#                                        Indicator name    Year  Value  \
# 0   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 10  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 11  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 12  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 13  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 14  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2019'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Apps\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2019'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-dd69d55656f8> in <module>
#       3 df['higher_is_better'] = True
#       4 df['Indicator'] = indicator
# ----> 5 df['data_col'] = df['2019']
#       6
#       7 min_rank = df['data_col'].min()
#
# D:\Apps\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# D:\Apps\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '2019'

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-c80880f0320d> in <module>
# ----> 1 df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
#
# D:\Apps\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# D:\Apps\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# D:\Apps\Anaconda\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['new_rank_score', 'Country Name', 'data_col'] not in index"

# %%
### 9. Electricity Density

# %%
indicators[8]

# load data
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electricity Density
# electricity_yearbook

# %%
df.head(10)
# Out:
#       1990     1991     1992     1993     1994     1995     1996     1997  \
# 0  11894.0  12173.0  12284.0  12574.0  12881.0  13327.0  13754.0  14045.0
# 1   7712.0   7900.0   7975.0   8160.0   8389.0   8646.0   8889.0   9014.0
# 2   6089.0   6236.0   6277.0   6414.0   6578.0   6760.0   6944.0   6985.0
# 3   2386.0   2468.0   2510.0   2583.0   2637.0   2754.0   2863.0   2961.0
# 4   2900.0   2937.0   2926.0   2931.0   2976.0   3071.0   3164.0   3199.0
# 5   2595.0   2640.0   2624.0   2626.0   2667.0   2744.0   2846.0   2857.0
# 6     71.0     72.0     72.0     71.0     72.0     74.0     76.0     79.0
# 7     63.0     61.0     59.0     59.0     59.0     61.0     64.0     65.0
# 8    421.0    456.0    464.0    473.0    477.0    494.0    513.0    505.0
# 9    550.0    540.0    537.0    526.0    529.0    537.0    555.0    552.0
#
#       1998     1999  ...     2013     2014     2015     2016     2017  \
# 0  14414.0  14823.0  ...  23424.0  23910.0  24317.0  24918.0  25592.0
# 1   9244.0   9451.0  ...  10902.0  10875.0  10914.0  10967.0  11069.0
# 2   7142.0   7272.0  ...   7897.0   7876.0   7867.0   7848.0   7898.0
# 3   3026.0   3170.0  ...   8524.0   8880.0   9142.0   9550.0  10000.0
# 4   3280.0   3327.0  ...   3813.0   3744.0   3802.0   3839.0   3886.0
# 5   2923.0   2955.0  ...   3269.0   3191.0   3234.0   3253.0   3275.0
# 6     83.0     85.0  ...     83.0     73.0     71.0     86.0     87.0
# 7     65.0     65.0  ...     87.0     86.0     84.0     83.0     87.0
# 8    511.0    526.0  ...    572.0    564.0    568.0    553.0    551.0
# 9    556.0    556.0  ...    639.0    628.0    647.0    648.0    653.0
#
#       Unnamed: 28  2016 - 2017 (%)   2000 - 2017 (%/year)     data_country  \
# 0           World               2.7                    3.0           World
# 1            OECD               0.9                    0.7            OECD
# 2              G7               0.6                    0.3              G7
# 3           BRICS               4.7                    6.6           BRICS
# 4          Europe               1.2                    0.7          Europe
# 5  European Union               0.7                    0.4  European Union
# 6         Belgium               0.5                    0.2         Belgium
# 7      Czech Rep.               4.5                    1.0      Czech Rep.
# 8          France              -0.4                    0.1          France
# 9         Germany               0.6                    0.7         Germany
#
#         data_year
# 0           World
# 1            OECD
# 2              G7
# 3           BRICS
# 4          Europe
# 5  European Union
# 6         Belgium
# 7      Czech Rep.
# 8          France
# 9         Germany
#
# [10 rows x 33 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2017'] 
df['Country'] = df['Unnamed: 28']
df['Year'] = 2017

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#            Country  Year            Indicator  data_col  new_rank_score  \
# 0            World  2017  Electricity Density   25592.0        6.000000
# 1             OECD  2017  Electricity Density   11069.0        3.159482
# 2               G7  2017  Electricity Density    7898.0        2.539274
# 3            BRICS  2017  Electricity Density   10000.0        2.950399
# 4           Europe  2017  Electricity Density    3886.0        1.754577
# 5   European Union  2017  Electricity Density    3275.0        1.635073
# 6          Belgium  2017  Electricity Density      87.0        1.011540
# 7       Czech Rep.  2017  Electricity Density      87.0        1.011540
# 8           France  2017  Electricity Density     551.0        1.102292
# 9          Germany  2017  Electricity Density     653.0        1.122242
# 10           Italy  2017  Electricity Density     295.0        1.052222
# 11     Netherlands  2017  Electricity Density     117.0        1.017407
# 12          Poland  2017  Electricity Density     171.0        1.027969
# 13        Portugal  2017  Electricity Density      60.0        1.006259
# 14         Romania  2017  Electricity Density      64.0        1.007041
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True

# %%
### 10. % of population covered by electricity

# %%
indicators[9]

# load data
indicator = indicators[9]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by electricity
# population_electricity_coverage

# %%
### 11. % of population covered by electricity

# %%
indicators[10]

# load data
indicator = indicators[10]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electricity supply quality
# elect_supply_quality

# %%
df.head(10)
# Out:
#          Unnamed: 0                                                AGO  \
# 0         Attribute                                             Angola
# 1             VALUE                                                NaN
# 2              RANK                                                136
# 3             SCORE                                        38.11248593
# 4  DATE DESCRIPTION                                       2019 edition
# 5            SOURCE  World Economic Forum, [i]Global Competitivenes...
# 6       SOURCE DATE                                                NaN
# 7              NOTE  See Appendix A of the Global Competitiveness R...
# 8             VALUE                                                NaN
# 9              RANK                                                136
#
#                                                  ALB  \
# 0                                            Albania
# 1                                                NaN
# 2                                                 81
# 3                                        57.61416881
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 88
#
#                                                  ARE  \
# 0                               United Arab Emirates
# 1                                                NaN
# 2                                                 25
# 3                                        75.00738794
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                  3
#
#                                                  ARG  \
# 0                                          Argentina
# 1                                                NaN
# 2                                                 83
# 3                                        57.20132859
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                109
#
#                                                  ARM  \
# 0                                            Armenia
# 1                                                NaN
# 2                                                 69
# 3                                        61.27687643
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 62
#
#                                                  AUS  \
# 0                                          Australia
# 1                                                NaN
# 2                                                 16
# 3                                        78.74662637
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 22
#
#                                                  AUT  \
# 0                                            Austria
# 1                                                NaN
# 2                                                 21
# 3                                        76.60913087
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 20
#
#                                                  AZE  \
# 0                                         Azerbaijan
# 1                                                NaN
# 2                                                 58
# 3                                        62.71789348
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 64
#
#                                                  BDI  ...  \
# 0                                            Burundi  ...
# 1                                                NaN  ...
# 2                                                135  ...
# 3                                        40.25234131  ...
# 4                                       2019 edition  ...
# 5  World Economic Forum, [i]Global Competitivenes...  ...
# 6                                                NaN  ...
# 7  See Appendix A of the Global Competitiveness R...  ...
# 8                                                NaN  ...
# 9                                                134  ...
#
#                                           GCREURASIA  \
# 0                                            Eurasia
# 1                                                NaN
# 2                                                NaN
# 3                                        59.37969533
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                               GCREAP  \
# 0                              East Asia and Pacific
# 1                                                NaN
# 2                                                NaN
# 3                                        69.86862667
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                             GCRSASIA  \
# 0                                         South Asia
# 1                                                NaN
# 2                                                NaN
# 3                                        54.70460508
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  LIC  \
# 0                                         Low-income
# 1                                                NaN
# 2                                                NaN
# 3                                         43.7445505
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  LMC  \
# 0                                Lower-middle-income
# 1                                                NaN
# 2                                                NaN
# 3                                        51.94942309
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  UMC  \
# 0                                Upper-middle-income
# 1                                                NaN
# 2                                                NaN
# 3                                         59.7912297
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  HIC  \
# 0                                        High-income
# 1                                                NaN
# 2                                                NaN
# 3                                        72.78080961
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  AVG      data_country  \
# 0                                     Sample average         Attribute
# 1                                                NaN             VALUE
# 2                                                  0              RANK
# 3                                         60.6396938             SCORE
# 4                                       2019 edition  DATE DESCRIPTION
# 5  World Economic Forum, [i]Global Competitivenes...            SOURCE
# 6                                                NaN       SOURCE DATE
# 7  See Appendix A of the Global Competitiveness R...              NOTE
# 8                                                NaN             VALUE
# 9                                                  0              RANK
#
#           data_year
# 0         Attribute
# 1             VALUE
# 2              RANK
# 3             SCORE
# 4  DATE DESCRIPTION
# 5            SOURCE
# 6       SOURCE DATE
# 7              NOTE
# 8             VALUE
# 9              RANK
#
# [10 rows x 156 columns]

# %%
# The data needs to be transposed as countries are now in columns, not rows, which could present problems for later.

# %%
### 12. Electricity Environmental Sustainability

# %%
indicators[11]

# load data
indicator = indicators[11]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electricity Environmental Sustainability
# sustainability_index

# %%
df.head(15)
# Out:
#    Country Code ISO3               Country  2021 SDG Index Score  \
# 0                AFG           Afghanistan                  53.9
# 1                AGO                Angola                  50.3
# 2                ALB               Albania                  71.0
# 3                AND               Andorra                   NaN
# 4                ARE  United Arab Emirates                  70.2
# 5                ARG             Argentina                  72.8
# 6                ARM               Armenia                  71.8
# 7                ATG   Antigua and Barbuda                   NaN
# 8                AUS             Australia                  75.6
# 9                AUT               Austria                  82.1
# 10               AZE            Azerbaijan                  72.4
# 11               BDI               Burundi                  51.8
# 12               BEL               Belgium                  82.2
# 13               BEN                 Benin                  49.9
# 14               BFA          Burkina Faso                  53.5
#
#     2021 SDG Index Rank  Percentage missing values  Spillover Score (0-100)  \
# 0                 137.0                        9.3                     99.3
# 1                 154.0                        0.0                     97.0
# 2                  64.0                        3.3                     94.3
# 3                   NaN                       51.2                      NaN
# 4                  71.0                       11.0                     38.8
# 5                  52.0                        1.1                     94.5
# 6                  58.0                        3.5                     96.7
# 7                   NaN                       30.8                      NaN
# 8                  35.0                        1.1                     63.9
# 9                   6.0                        3.5                     59.5
# 10                 55.0                        7.0                     97.6
# 11                147.0                        7.0                     99.8
# 12                  5.0                        4.4                     62.0
# 13                155.0                        4.4                     98.8
# 14                139.0                        1.2                     99.4
#
#     Regional Score (0-100) Regions used for the SDR  Population in 2020   \
# 0                     71.4      E. Europe & C. Asia          38,928,341
# 1                     51.9                   Africa          32,866,268
# 2                     71.4      E. Europe & C. Asia           2,877,800
# 3                     71.4      E. Europe & C. Asia              77,265
# 4                     67.1                     MENA           9,890,400
# 5                     68.6                      LAC          45,195,777
# 6                     71.4      E. Europe & C. Asia           2,963,234
# 7                     68.6                      LAC              97,928
# 8                     77.2                     OECD          25,499,881
# 9                     77.2                     OECD           9,006,400
# 10                    71.4      E. Europe & C. Asia          10,139,175
# 11                    51.9                   Africa          11,890,781
# 12                    77.2                     OECD          11,589,616
# 13                    51.9                   Africa          12,123,198
# 14                    51.9                   Africa          20,903,278
#
#    Goal 1 Dash  ... Goal 10 Regional Score Goal 11 Regional Score  \
# 0         grey  ...              72.362762              76.443228
# 1          red  ...              37.334205              52.728915
# 2       yellow  ...              72.362762              76.443228
# 3         grey  ...                    NaN                    NaN
# 4        green  ...              66.178091              58.928271
# 5       yellow  ...              27.901676              77.087594
# 6       yellow  ...              72.362762              76.443228
# 7         grey  ...                    NaN                    NaN
# 8       yellow  ...              74.475203              88.911367
# 9        green  ...              74.475203              88.911367
# 10       green  ...              72.362762              76.443228
# 11         red  ...              37.334205              52.728915
# 12       green  ...              74.475203              88.911367
# 13         red  ...              37.334205              52.728915
# 14         red  ...              37.334205              52.728915
#
#    Goal 12 Regional Score Goal 13 Regional Score Goal 14 Regional Score  \
# 0               77.629345              83.041913              58.865821
# 1               88.024702              96.266527              68.010492
# 2               77.629345              83.041913              58.865821
# 3                     NaN                    NaN                    NaN
# 4               76.842146              71.475510              62.776615
# 5               76.727283              85.373283              62.781114
# 6               77.629345              83.041913              58.865821
# 7                     NaN                    NaN                    NaN
# 8               58.055279              64.112721              63.360546
# 9               58.055279              64.112721              63.360546
# 10              77.629345              83.041913              58.865821
# 11              88.024702              96.266527              68.010492
# 12              58.055279              64.112721              63.360546
# 13              88.024702              96.266527              68.010492
# 14              88.024702              96.266527              68.010492
#
#    Goal 15 Regional Score Goal 16 Regional Score Goal 17 Regional Score  \
# 0               69.499564              72.403938              63.386460
# 1               66.835003              56.050983              51.652955
# 2               69.499564              72.403938              63.386460
# 3                     NaN                    NaN                    NaN
# 4               57.356212              69.093831              56.231255
# 5               60.904217              60.888934              64.295156
# 6               69.499564              72.403938              63.386460
# 7                     NaN                    NaN                    NaN
# 8               74.102776              82.316815              65.773824
# 9               74.102776              82.316815              65.773824
# 10              69.499564              72.403938              63.386460
# 11              66.835003              56.050983              51.652955
# 12              74.102776              82.316815              65.773824
# 13              66.835003              56.050983              51.652955
# 14              66.835003              56.050983              51.652955
#
#    data_country data_year
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10          NaN       NaN
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14          NaN       NaN
#
# [15 rows x 651 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2021 SDG Index Score'] 
df['Country Name'] = df['Country']
df['Year'] = 2021

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year                                 Indicator  \
# 0            Afghanistan  2021  Electricity Environmental Sustainability
# 1                 Angola  2021  Electricity Environmental Sustainability
# 2                Albania  2021  Electricity Environmental Sustainability
# 3                Andorra  2021  Electricity Environmental Sustainability
# 4   United Arab Emirates  2021  Electricity Environmental Sustainability
# 5              Argentina  2021  Electricity Environmental Sustainability
# 6                Armenia  2021  Electricity Environmental Sustainability
# 7    Antigua and Barbuda  2021  Electricity Environmental Sustainability
# 8              Australia  2021  Electricity Environmental Sustainability
# 9                Austria  2021  Electricity Environmental Sustainability
# 10            Azerbaijan  2021  Electricity Environmental Sustainability
# 11               Burundi  2021  Electricity Environmental Sustainability
# 12               Belgium  2021  Electricity Environmental Sustainability
# 13                 Benin  2021  Electricity Environmental Sustainability
# 14          Burkina Faso  2021  Electricity Environmental Sustainability
#
#     data_col  new_rank_score  higher_is_better
# 0       53.9        2.638655              True
# 1       50.3        2.260504              True
# 2       71.0        4.434874              True
# 3        NaN             NaN              True
# 4       70.2        4.350840              True
# 5       72.8        4.623950              True
# 6       71.8        4.518908              True
# 7        NaN             NaN              True
# 8       75.6        4.918067              True
# 9       82.1        5.600840              True
# 10      72.4        4.581933              True
# 11      51.8        2.418067              True
# 12      82.2        5.611345              True
# 13      49.9        2.218487              True
# 14      53.5        2.596639              True

# %%
### 13. Cellphone Signal Density

# %%
indicators[12]

# load data
indicator = indicators[12]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Cellphone Signal Density
# mobile_density

# %%
df.head(10)
#No country names in the data file
# Out:
#    Unnamed: 0 ISO Code      Country              Region  Year  \
# 0           1      AFG  Afghanistan          South Asia  2014
# 1           2      AFG  Afghanistan          South Asia  2015
# 2           3      AFG  Afghanistan          South Asia  2016
# 3           4      AFG  Afghanistan          South Asia  2017
# 4           5      AFG  Afghanistan          South Asia  2018
# 5           6      AFG  Afghanistan          South Asia  2019
# 6           7      AGO       Angola  Sub-Saharan Africa  2014
# 7           8      AGO       Angola  Sub-Saharan Africa  2015
# 8           9      AGO       Angola  Sub-Saharan Africa  2016
# 9          10      AGO       Angola  Sub-Saharan Africa  2017
#
#    Network coverage
# 0         28.919998
# 1         31.799999
# 2         33.040001
# 3         36.340000
# 4         30.931999
# 5         38.480000
# 6         51.445770
# 7         53.906952
# 8         61.174950
# 9         60.800003

# %%
### 14. Telecommunication Infrastructure Index (TII)

# %%
indicators[13]

# load data
indicator = indicators[13]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Telecommunication Infrastructure Index (TII)
# e_government_index

# %%
df.head(10)
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
# 5         2020       Japan                  14              0.8989
# 6         2020      Jordan                 117              0.5309
# 7         2020  Kazakhstan                  29              0.8375
# 8         2020       Kenya                 116              0.5326
# 9         2020    Kiribati                 145              0.4320
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
# 5                 0.9881                0.9059               0.8684
# 6                 0.3333                0.3588               0.6800
# 7                 0.8810                0.9235               0.8866
# 8                 0.5952                0.6765               0.5812
# 9                 0.5595                0.4941               0.6778
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151
# 5                                  0.9223
# 6                                  0.5540
# 7                                  0.7024
# 8                                  0.3402
# 9                                  0.1241

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Telecommunication Infrastructure Index'] 
df['Year'] = df['Survey Year']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

df.rename(columns={'Country Name':'Country'}, inplace=True)

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                               Country  Year  \
# 0                               Iraq   2020
# 1                            Ireland   2020
# 2                             Israel   2020
# 3                              Italy   2020
# 4                            Jamaica   2020
# 5                              Japan   2020
# 6                             Jordan   2020
# 7                         Kazakhstan   2020
# 8                              Kenya   2020
# 9                           Kiribati   2020
# 10                            Kuwait   2020
# 11                        Kyrgyzstan   2020
# 12  Lao People's Democratic Republic   2020
# 13                            Latvia   2020
# 14                           Lebanon   2020
#
#                                        Indicator  data_col  new_rank_score  \
# 0   Telecommunication Infrastructure Index (TII)    0.5370          3.6850
# 1   Telecommunication Infrastructure Index (TII)    0.8100          5.0500
# 2   Telecommunication Infrastructure Index (TII)    0.8689          5.3445
# 3   Telecommunication Infrastructure Index (TII)    0.7932          4.9660
# 4   Telecommunication Infrastructure Index (TII)    0.5151          3.5755
# 5   Telecommunication Infrastructure Index (TII)    0.9223          5.6115
# 6   Telecommunication Infrastructure Index (TII)    0.5540          3.7700
# 7   Telecommunication Infrastructure Index (TII)    0.7024          4.5120
# 8   Telecommunication Infrastructure Index (TII)    0.3402          2.7010
# 9   Telecommunication Infrastructure Index (TII)    0.1241          1.6205
# 10  Telecommunication Infrastructure Index (TII)    0.7858          4.9290
# 11  Telecommunication Infrastructure Index (TII)    0.5902          3.9510
# 12  Telecommunication Infrastructure Index (TII)    0.2383          2.1915
# 13  Telecommunication Infrastructure Index (TII)    0.8399          5.1995
# 14  Telecommunication Infrastructure Index (TII)    0.4123          3.0615
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True

# %%
### 15. GSMA Mobile Connectivity Index

# %%
indicators[14]

# load data
indicator = indicators[14]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# GSMA Mobile Connectivity Index
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Index'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year                        Indicator  data_col  \
# 5            Afghanistan  2019  GSMA Mobile Connectivity Index      28.94
# 11                Angola  2019  GSMA Mobile Connectivity Index      43.53
# 17               Albania  2019  GSMA Mobile Connectivity Index      67.89
# 23  United Arab Emirates  2019  GSMA Mobile Connectivity Index      78.23
# 29             Argentina  2019  GSMA Mobile Connectivity Index      67.16
# 35               Armenia  2019  GSMA Mobile Connectivity Index      56.24
# 41             Australia  2019  GSMA Mobile Connectivity Index      90.51
# 47               Austria  2019  GSMA Mobile Connectivity Index      84.21
# 53            Azerbaijan  2019  GSMA Mobile Connectivity Index      58.28
# 59               Burundi  2019  GSMA Mobile Connectivity Index      26.16
# 65               Belgium  2019  GSMA Mobile Connectivity Index      82.56
# 71                 Benin  2019  GSMA Mobile Connectivity Index      39.07
# 77          Burkina Faso  2019  GSMA Mobile Connectivity Index      32.44
# 83            Bangladesh  2019  GSMA Mobile Connectivity Index      46.47
# 89              Bulgaria  2019  GSMA Mobile Connectivity Index      70.37
#
#     new_rank_score  higher_is_better
# 5         2.041533              True
# 11        2.979555              True
# 17        4.545712              True
# 23        5.210492              True
# 29        4.498778              True
# 35        3.796708              True
# 41        6.000000              True
# 47        5.594959              True
# 53        3.927864              True
# 59        1.862801              True
# 65        5.488877              True
# 71        2.692812              True
# 77        2.266555              True
# 83        3.168574              True
# 89        4.705156              True

# %%
### 16. Spectrum Allocated to Mobile Providers

# %%
indicators[15]

# load data
indicator = indicators[15]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Spectrum Allocated to Mobile Providers
# spectrum_allocated_mobile_providers

# %%
df.head(15)
# Out:
#    ISO Code      Country                 Region  Year       Cluster  Index  \
# 0       AFG  Afghanistan             South Asia  2014    Discoverer  22.12
# 1       AFG  Afghanistan             South Asia  2015    Discoverer  22.99
# 2       AFG  Afghanistan             South Asia  2016    Discoverer  23.71
# 3       AFG  Afghanistan             South Asia  2017    Discoverer  25.82
# 4       AFG  Afghanistan             South Asia  2018    Discoverer  28.39
# 5       AFG  Afghanistan             South Asia  2019    Discoverer  28.94
# 6       AGO       Angola     Sub-Saharan Africa  2014    Discoverer  32.78
# 7       AGO       Angola     Sub-Saharan Africa  2015      Emerging  37.18
# 8       AGO       Angola     Sub-Saharan Africa  2016      Emerging  39.85
# 9       AGO       Angola     Sub-Saharan Africa  2017      Emerging  42.89
# 10      AGO       Angola     Sub-Saharan Africa  2018      Emerging  42.46
# 11      AGO       Angola     Sub-Saharan Africa  2019      Emerging  43.53
# 12      ALB      Albania  Europe & Central Asia  2014  Transitioner  53.74
# 13      ALB      Albania  Europe & Central Asia  2015  Transitioner  57.42
# 14      ALB      Albania  Europe & Central Asia  2016  Transitioner  60.24
#
#     Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0            21.74          31.79               24.40                 14.19
# 1            22.82          30.81               25.28                 15.71
# 2            26.92          26.75               26.07                 16.83
# 3            33.54          27.22               28.56                 17.04
# 4            30.91          42.64               29.24                 16.87
# 5            32.34          41.53               29.72                 17.58
# 6            25.99          35.99               44.33                 27.85
# 7            33.09          42.01               45.41                 30.27
# 8            37.80          44.74               46.47                 32.11
# 9            48.60          47.94               46.32                 31.36
# 10           47.61          46.28               47.61                 30.98
# 11           48.18          47.65               48.13                 32.50
# 12           41.32          55.95               74.94                 48.13
# 13           52.09          54.60               75.56                 50.57
# 14           57.44          54.45               75.97                 55.41
#
#     ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0   ...                            0.00            39.55               18.11
# 1   ...                            0.00            39.57               24.27
# 2   ...                            0.00            39.58               30.43
# 3   ...                            0.00            39.47               30.50
# 4   ...                            0.00            39.39               30.56
# 5   ...                            0.00            39.41               41.18
# 6   ...                           51.65             0.00               29.92
# 7   ...                           57.00             0.31               32.35
# 8   ...                           63.73             0.00               34.78
# 9   ...                           53.97             0.00               37.88
# 10  ...                           63.34             0.00               40.97
# 11  ...                           57.71             0.77               48.82
# 12  ...                           68.42            53.41               44.88
# 13  ...                           68.42            57.45               52.15
# 14  ...                           67.39            58.70               59.42
#
#     Mobile Social Media Penetration  Apps developed per person  \
# 0                              3.28                      20.98
# 1                              4.36                      22.93
# 2                              6.73                      30.31
# 3                              7.78                      31.62
# 4                              8.54                      36.54
# 5                              9.39                      39.36
# 6                              3.99                      22.74
# 7                              5.26                      22.12
# 8                              6.27                      27.46
# 9                              4.26                      31.94
# 10                             5.39                      35.36
# 11                             6.82                      41.20
# 12                            39.75                      66.65
# 13                            40.61                      65.99
# 14                            48.07                      69.64
#
#     Number of apps in national language  Accessibility of top ranked apps  \
# 0                                  2.44                              4.37
# 1                                  2.79                              8.03
# 2                                  2.85                              5.90
# 3                                  2.91                              6.15
# 4                                  2.96                              8.66
# 5                                  3.00                              5.72
# 6                                 53.33                             49.09
# 7                                 55.08                             58.33
# 8                                 56.52                             61.73
# 9                                 57.06                             55.09
# 10                                57.13                             47.25
# 11                                57.98                             46.19
# 12                                60.33                             56.55
# 13                                63.29                             57.56
# 14                                65.57                             65.80
#
#     Cybersecurity Index  data_country  data_year
# 0                 26.50           NaN        NaN
# 1                 25.83           NaN        NaN
# 2                 25.17           NaN        NaN
# 3                 24.50           NaN        NaN
# 4                 17.70           NaN        NaN
# 5                 17.70           NaN        NaN
# 6                  8.80           NaN        NaN
# 7                  8.47           NaN        NaN
# 8                  8.13           NaN        NaN
# 9                  7.80           NaN        NaN
# 10                 9.70           NaN        NaN
# 11                 9.70           NaN        NaN
# 12                20.60           NaN        NaN
# 13                24.20           NaN        NaN
# 14                27.80           NaN        NaN
#
# [15 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Spectrum'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year                               Indicator  \
# 5            Afghanistan  2019  Spectrum Allocated to Mobile Providers
# 11                Angola  2019  Spectrum Allocated to Mobile Providers
# 17               Albania  2019  Spectrum Allocated to Mobile Providers
# 23  United Arab Emirates  2019  Spectrum Allocated to Mobile Providers
# 29             Argentina  2019  Spectrum Allocated to Mobile Providers
# 35               Armenia  2019  Spectrum Allocated to Mobile Providers
# 41             Australia  2019  Spectrum Allocated to Mobile Providers
# 47               Austria  2019  Spectrum Allocated to Mobile Providers
# 53            Azerbaijan  2019  Spectrum Allocated to Mobile Providers
# 59               Burundi  2019  Spectrum Allocated to Mobile Providers
# 65               Belgium  2019  Spectrum Allocated to Mobile Providers
# 71                 Benin  2019  Spectrum Allocated to Mobile Providers
# 77          Burkina Faso  2019  Spectrum Allocated to Mobile Providers
# 83            Bangladesh  2019  Spectrum Allocated to Mobile Providers
# 89              Bulgaria  2019  Spectrum Allocated to Mobile Providers
#
#     data_col  new_rank_score  higher_is_better
# 5      17.62        1.577685              True
# 11     48.22        3.261224              True
# 17     52.85        3.515955              True
# 23     82.44        5.143926              True
# 29     63.38        4.095290              True
# 35     21.43        1.787302              True
# 41     75.45        4.759353              True
# 47     73.33        4.642716              True
# 53     15.36        1.453345              True
# 59     16.29        1.504511              True
# 65     58.62        3.833407              True
# 71     61.31        3.981404              True
# 77     23.82        1.918794              True
# 83     19.97        1.706976              True
# 89     27.49        2.120709              True

# %%
### 17. Internet Exchange Points (IXPs)

# %%
indicators[16]

# load data
indicator = indicators[16]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Internet Exchange Points (IXPs) map
# countries_ixp

# %%
df['Country Name'] = df['Country']
df.head(15)
# Out:
#            Region      Country                    City  \
# 0    Asia-Pacific  Afghanistan                   Kabul
# 1          Europe      Albania                  Tirana
# 2             NaN      Albania                  Tirana
# 3          Africa      Algeria                 Algiers
# 4             NaN       Angola                  Luanda
# 5             NaN       Angola                  Luanda
# 6             NaN       Angola                  Luanda
# 7   Latin America    Argentina            Bahía Blanca
# 8             NaN    Argentina               Bariloche
# 9             NaN    Argentina            Buenos Aires
# 10            NaN    Argentina            Buenos Aires
# 11            NaN    Argentina            Buenos Aires
# 12            NaN    Argentina            Buenos Aires
# 13            NaN    Argentina            Buenos Aires
# 14            NaN    Argentina  Concepcion del Uruguay
#
#                                      IXP Name  Participants   Peak    Avg  \
# 0   National Internet Exchange of Afghanistan            20   6.4G  2.19G
# 1          Albanian Neutral Internet eXchange            16  2.42G    35M
# 2                                  Albania IX             0    NaN    NaN
# 3                   Algeria Internet Exchange             0    NaN    NaN
# 4                    Angola Internet Exchange            21   1.6G    NaN
# 5        Ponto de Intercambio Internet Angola             0    NaN    NaN
# 6                                     ANGONIX            21    16G    NaN
# 7                     CABASE IXP Bahía Blanca            15   713M    NaN
# 8                        CABASE IXP Bariloche             8    NaN    NaN
# 9                     CABASE IXP Buenos Aires           125  9.19G    NaN
# 10                                   Cubecorp             0    NaN    NaN
# 11                   CABASE IXP Ruteo Central             0    NaN    NaN
# 12      CABASE IXP Oeste de Gran Buenos Aires             7    NaN    NaN
# 13                      NAP CABASE La Matanza             0    NaN    NaN
# 14          CABASE IXP Concepcion del Uruguay             4    NaN    NaN
#
#    IPv6  Prefixes Established  URL Country Name
# 0   NaN       NaN      18-Jul  NaN  Afghanistan
# 1   NaN       NaN        2018  NaN      Albania
# 2   NaN       NaN        2011  NaN      Albania
# 3   NaN       NaN         NaN  NaN      Algeria
# 4   NaN     512.0   17-Mar-06  NaN       Angola
# 5   NaN       NaN         NaN  NaN       Angola
# 6   NaN    5495.0    9-Mar-15  NaN       Angola
# 7   NaN       NaN   27-Apr-13  NaN    Argentina
# 8   NaN       NaN   15-Sep-14  NaN    Argentina
# 9   NaN   17224.0    1-Apr-98  NaN    Argentina
# 10  NaN       NaN         NaN  NaN    Argentina
# 11  NaN       NaN         NaN  NaN    Argentina
# 12  NaN       NaN    5-Jul-16  NaN    Argentina
# 13  NaN       NaN         NaN  NaN    Argentina
# 14  NaN       NaN         NaN  NaN    Argentina

# %%
agg_df = df.groupby('Country Name').agg({'Country':'count'})
agg_df
# Out:
#               Country
# Country Name
# Afghanistan         1
# Albania             2
# Algeria             1
# Angola              3
# Argentina          33
# ...               ...
# Uzbekistan          3
# Vanuatu             1
# Viet Nam            3
# Zambia              1
# Zimbabwe            2
#
# [165 rows x 1 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

agg_df['higher_is_better'] = True
agg_df['Indicator'] = indicator
agg_df['data_col'] = agg_df['Country'] 
agg_df['Year'] = 2019

min_rank = agg_df['data_col'].min()
max_rank = agg_df['data_col'].max()

# transform 0-1 rank into 1-6
agg_df['new_rank_score'] = agg_df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
agg_df[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(150)
# Out:
#               Year                            Indicator  data_col  \
# Country Name
# Afghanistan   2019  Internet Exchange Points (IXPs) map         1
# Albania       2019  Internet Exchange Points (IXPs) map         2
# Algeria       2019  Internet Exchange Points (IXPs) map         1
# Angola        2019  Internet Exchange Points (IXPs) map         3
# Argentina     2019  Internet Exchange Points (IXPs) map        33
# ...            ...                                  ...       ...
# Syria         2019  Internet Exchange Points (IXPs) map         1
# Taiwan        2019  Internet Exchange Points (IXPs) map         7
# Tajikistan    2019  Internet Exchange Points (IXPs) map         1
# Tanzania      2019  Internet Exchange Points (IXPs) map         5
# Thailand      2019  Internet Exchange Points (IXPs) map        13
#
#               new_rank_score  higher_is_better
# Country Name
# Afghanistan         1.000000              True
# Albania             1.023148              True
# Algeria             1.000000              True
# Angola              1.046296              True
# Argentina           1.740741              True
# ...                      ...               ...
# Syria               1.000000              True
# Taiwan              1.138889              True
# Tajikistan          1.000000              True
# Tanzania            1.092593              True
# Thailand            1.277778              True
#
# [150 rows x 5 columns]

# %%
### 18. ISP internet download speed averag

# %%
indicators[17]

# load data
indicator = indicators[17]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# ISP internet download speed average
# internet_speed

# %%
df.head(15)
# Out:
#     Ranking  Year               Country  Download speed (Mbps)
# 0         1  2021                Monaco                 256.70
# 1         2  2021             Singapore                 256.03
# 2         3  2021       Hong Kong (SAR)                 248.59
# 3         4  2021              Thailand                 216.16
# 4         5  2021               Romania                 215.30
# 5         6  2021           Switzerland                 214.82
# 6         7  2021           South Korea                 212.83
# 7         8  2021                 Chile                 209.45
# 8         9  2021               Denmark                 208.50
# 9        10  2021         Liechtenstein                 207.44
# 10       11  2021                France                 199.68
# 11       12  2021               Hungary                 199.47
# 12       13  2021               Moldova                 196.46
# 13       14  2021         United States                 195.55
# 14       15  2021  United Arab Emirates                 190.96

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Download speed (Mbps)'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year                             Indicator  \
# 0                 Monaco  2021  ISP internet download speed average
# 1              Singapore  2021  ISP internet download speed average
# 2        Hong Kong (SAR)  2021  ISP internet download speed average
# 3               Thailand  2021  ISP internet download speed average
# 4                Romania  2021  ISP internet download speed average
# 5            Switzerland  2021  ISP internet download speed average
# 6            South Korea  2021  ISP internet download speed average
# 7                  Chile  2021  ISP internet download speed average
# 8                Denmark  2021  ISP internet download speed average
# 9          Liechtenstein  2021  ISP internet download speed average
# 10                France  2021  ISP internet download speed average
# 11               Hungary  2021  ISP internet download speed average
# 12               Moldova  2021  ISP internet download speed average
# 13         United States  2021  ISP internet download speed average
# 14  United Arab Emirates  2021  ISP internet download speed average
#
#     data_col  new_rank_score  higher_is_better
# 0     256.70        6.000000              True
# 1     256.03        5.986711              True
# 2     248.59        5.839145              True
# 3     216.16        5.195922              True
# 4     215.30        5.178865              True
# 5     214.82        5.169344              True
# 6     212.83        5.129874              True
# 7     209.45        5.062835              True
# 8     208.50        5.043992              True
# 9     207.44        5.022968              True
# 10    199.68        4.869055              True
# 11    199.47        4.864890              True
# 12    196.46        4.805189              True
# 13    195.55        4.787140              True
# 14    190.96        4.696101              True

# %%
### 19. Mobile dowload speed at the slowest hour

# %%
indicators[18]

# load data
indicator = indicators[18]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Waiting for internet_speed to be added to the processed folder
# Out:
# Mobile dowload speed at the slowest hour of the day
# mobile_latency

# %%
df.head(15)
# Out:
#     Unnamed: 0 ISO Code      Country                 Region  Year  \
# 0            1      AFG  Afghanistan             South Asia  2014
# 1            2      AFG  Afghanistan             South Asia  2015
# 2            3      AFG  Afghanistan             South Asia  2016
# 3            4      AFG  Afghanistan             South Asia  2017
# 4            5      AFG  Afghanistan             South Asia  2018
# 5            6      AFG  Afghanistan             South Asia  2019
# 6            7      AGO       Angola     Sub-Saharan Africa  2014
# 7            8      AGO       Angola     Sub-Saharan Africa  2015
# 8            9      AGO       Angola     Sub-Saharan Africa  2016
# 9           10      AGO       Angola     Sub-Saharan Africa  2017
# 10          11      AGO       Angola     Sub-Saharan Africa  2018
# 11          12      AGO       Angola     Sub-Saharan Africa  2019
# 12          13      ALB      Albania  Europe & Central Asia  2014
# 13          14      ALB      Albania  Europe & Central Asia  2015
# 14          15      ALB      Albania  Europe & Central Asia  2016
#
#     Mobile latencies
# 0           0.000000
# 1           0.000000
# 2          11.842106
# 3          56.234993
# 4          49.762146
# 5          42.627621
# 6           0.000000
# 7          36.975155
# 8          50.958073
# 9          66.052635
# 10         74.417152
# 11         66.285637
# 12         34.736843
# 13         57.339764
# 14         73.420052

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Mobile latencies'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))


# invert since to lower rank is better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator   data_col  \
# 5   Mobile dowload speed at the slowest hour of th...  42.627621
# 11  Mobile dowload speed at the slowest hour of th...  66.285637
# 17  Mobile dowload speed at the slowest hour of th...  84.636459
# 23  Mobile dowload speed at the slowest hour of th...  84.951675
# 29  Mobile dowload speed at the slowest hour of th...  80.727203
# 35  Mobile dowload speed at the slowest hour of th...  88.437950
# 41  Mobile dowload speed at the slowest hour of th...  86.069145
# 47  Mobile dowload speed at the slowest hour of th...  85.845047
# 53  Mobile dowload speed at the slowest hour of th...  85.687500
# 59  Mobile dowload speed at the slowest hour of th...  51.736294
# 65  Mobile dowload speed at the slowest hour of th...  82.730255
# 71  Mobile dowload speed at the slowest hour of th...  68.678703
# 77  Mobile dowload speed at the slowest hour of th...  54.469799
# 83  Mobile dowload speed at the slowest hour of th...  74.701111
# 89  Mobile dowload speed at the slowest hour of th...  83.992538
#
#     new_rank_score  higher_is_better
# 5         3.618652              True
# 11        2.297022              True
# 17        1.271872              True
# 23        1.254263              True
# 29        1.490258              True
# 35        1.059505              True
# 41        1.191836              True
# 47        1.204355              True
# 53        1.213157              True
# 59        3.109806              True
# 65        1.378360              True
# 71        2.163335              True
# 77        2.957101              True
# 83        1.826900              True
# 89        1.307844              True

# %%
### 20. Mobile download speed average

# %%
indicators[19]

# load data
indicator = indicators[19]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Mobile download speed average
# mobile_speed

# %%
df.head(15)
# Out:
#      #  Year               Country    Mbps
# 0    1  2021  United Arab Emirates  190.03
# 1    2  2021           South Korea  189.20
# 2    3  2021                 Qatar  170.77
# 3    4  2021                 China  157.72
# 4    5  2021                Cyprus  154.13
# 5    6  2021                Norway  152.53
# 6    7  2021          Saudi Arabia  151.13
# 7    8  2021                Kuwait  140.16
# 8    9  2021             Australia  122.27
# 9   10  2021              Bulgaria  120.44
# 10  11  2021            Luxembourg  110.72
# 11  12  2021           Switzerland  109.65
# 12  13  2021           Netherlands  100.65
# 13  14  2021         United States   91.01
# 14  15  2021                Sweden   90.57

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Mbps'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year                       Indicator  data_col  \
# 0   United Arab Emirates  2021  Mobile download speed average     190.03
# 1            South Korea  2021  Mobile download speed average     189.20
# 2                  Qatar  2021  Mobile download speed average     170.77
# 3                  China  2021  Mobile download speed average     157.72
# 4                 Cyprus  2021  Mobile download speed average     154.13
# 5                 Norway  2021  Mobile download speed average     152.53
# 6           Saudi Arabia  2021  Mobile download speed average     151.13
# 7                 Kuwait  2021  Mobile download speed average     140.16
# 8              Australia  2021  Mobile download speed average     122.27
# 9               Bulgaria  2021  Mobile download speed average     120.44
# 10            Luxembourg  2021  Mobile download speed average     110.72
# 11           Switzerland  2021  Mobile download speed average     109.65
# 12           Netherlands  2021  Mobile download speed average     100.65
# 13         United States  2021  Mobile download speed average      91.01
# 14                Sweden  2021  Mobile download speed average      90.57
#
#     new_rank_score  higher_is_better
# 0         6.000000              True
# 1         5.977362              True
# 2         5.474689              True
# 3         5.118754              True
# 4         5.020838              True
# 5         4.977198              True
# 6         4.939014              True
# 7         4.639810              True
# 8         4.151866              True
# 9         4.101953              True
# 10        3.836843              True
# 11        3.807659              True
# 12        3.562186              True
# 13        3.299258              True
# 14        3.287257              True

# %%
### 21. Individuals using the Internet (% of population)

# %%
indicators[20]

# load data
indicator = indicators[20]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Individuals using the Internet (% of population)
# ITU_database

# %%
df.head(15)
# Out:
#                    Country  Region  ISO  \
# 0                   Angola  Africa  AGO
# 1                    Benin  Africa  BEN
# 2                 Botswana  Africa  BWA
# 3             Burkina Faso  Africa  BFA
# 4                  Burundi  Africa  BDI
# 5               Cabo Verde  Africa  CPV
# 6                 Cameroon  Africa  CMR
# 7     Central African Rep.  Africa  CAF
# 8                     Chad  Africa  TCD
# 9      Congo (Rep. of the)  Africa  COG
# 10           Côte d'Ivoire  Africa  CIV
# 11  Dem. Rep. of the Congo  Africa  COD
# 12       Equatorial Guinea  Africa  GNQ
# 13                 Eritrea  Africa  ERI
# 14                Eswatini  Africa  SWZ
#
#                                        Indicator name    Year  Value  \
# 0   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 10  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 11  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 12  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 13  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 14  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
df = df[(df['Indicator name'] == 'Individuals using the Internet, total (%)')]
df = df[(df.Year==2019)]
df.head(15)
# Out:
#                     Country       Region  ISO  \
# 47607            Cabo Verde       Africa  CPV
# 47608  Central African Rep.       Africa  CAF
# 47609   Congo (Rep. of the)       Africa  COG
# 47610         Côte d'Ivoire       Africa  CIV
# 47611     Equatorial Guinea       Africa  GNQ
# 47612               Eritrea       Africa  ERI
# 47613              Eswatini       Africa  SWZ
# 47614                 Kenya       Africa  KEN
# 47615               Lesotho       Africa  LSO
# 47616            Madagascar       Africa  MDG
# 47617             Mauritius       Africa  MUS
# 47618                 Niger       Africa  NER
# 47619           South Sudan       Africa  SSD
# 47620                Uganda       Africa  UGA
# 47621               Bahrain  Arab States  BHR
#
#                                   Indicator name    Year      Value  \
# 47607  Individuals using the Internet, total (%)  2019.0  61.943398
# 47608  Individuals using the Internet, total (%)  2019.0        NaN
# 47609  Individuals using the Internet, total (%)  2019.0        NaN
# 47610  Individuals using the Internet, total (%)  2019.0  36.288955
# 47611  Individuals using the Internet, total (%)  2019.0        NaN
# 47612  Individuals using the Internet, total (%)  2019.0        NaN
# 47613  Individuals using the Internet, total (%)  2019.0        NaN
# 47614  Individuals using the Internet, total (%)  2019.0  22.565119
# 47615  Individuals using the Internet, total (%)  2019.0  42.301734
# 47616  Individuals using the Internet, total (%)  2019.0        NaN
# 47617  Individuals using the Internet, total (%)  2019.0  61.729955
# 47618  Individuals using the Internet, total (%)  2019.0        NaN
# 47619  Individuals using the Internet, total (%)  2019.0        NaN
# 47620  Individuals using the Internet, total (%)  2019.0        NaN
# 47621  Individuals using the Internet, total (%)  2019.0  99.701493
#
#        data_country  data_year
# 47607           NaN        NaN
# 47608           NaN        NaN
# 47609           NaN        NaN
# 47610           NaN        NaN
# 47611           NaN        NaN
# 47612           NaN        NaN
# 47613           NaN        NaN
# 47614           NaN        NaN
# 47615           NaN        NaN
# 47616           NaN        NaN
# 47617           NaN        NaN
# 47618           NaN        NaN
# 47619           NaN        NaN
# 47620           NaN        NaN
# 47621           NaN        NaN

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df.rename(columns = {'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(150)
# Out:
#                            Country Name    Year  \
# 47607                        Cabo Verde  2019.0
# 47608              Central African Rep.  2019.0
# 47609               Congo (Rep. of the)  2019.0
# 47610                     Côte d'Ivoire  2019.0
# 47611                 Equatorial Guinea  2019.0
# ...                                 ...     ...
# 47739  Saint Vincent and the Grenadines  2019.0
# 47740               Trinidad and Tobago  2019.0
# 47741                     United States  2019.0
# 47742                           Uruguay  2019.0
# 47743                         Venezuela  2019.0
#
#                                               Indicator   data_col  \
# 47607  Individuals using the Internet (% of population)  61.943398
# 47608  Individuals using the Internet (% of population)        NaN
# 47609  Individuals using the Internet (% of population)        NaN
# 47610  Individuals using the Internet (% of population)  36.288955
# 47611  Individuals using the Internet (% of population)        NaN
# ...                                                 ...        ...
# 47739  Individuals using the Internet (% of population)        NaN
# 47740  Individuals using the Internet (% of population)        NaN
# 47741  Individuals using the Internet (% of population)  89.430285
# 47742  Individuals using the Internet (% of population)  83.351534
# 47743  Individuals using the Internet (% of population)        NaN
#
#        new_rank_score  higher_is_better
# 47607        3.715247              True
# 47608             NaN              True
# 47609             NaN              True
# 47610        2.162890              True
# 47611             NaN              True
# ...               ...               ...
# 47739             NaN              True
# 47740             NaN              True
# 47741        5.378486              True
# 47742        5.010659              True
# 47743             NaN              True
#
# [137 rows x 6 columns]

# %%
### 22. Mobile-cellular subscriptions per 100 inhabitants

# %%
indicators[21]

# load data
indicator = indicators[21]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Mobile cellular subscriptions (per 100 people)
# ITU_database

# %%
df = df[(df['Indicator name'] == 'Individuals using the Internet, total (%)')]
df = df[(df.Year==2020)]
df.head(15)
# Out:
#                     Country          Region  ISO  \
# 47744             Mauritius          Africa  MUS
# 47745                Uganda          Africa  UGA
# 47746               Bahrain     Arab States  BHR
# 47747                 Egypt     Arab States  EGY
# 47748                  Iraq     Arab States  IRQ
# 47749                Kuwait     Arab States  KWT
# 47750               Morocco     Arab States  MAR
# 47751                  Oman     Arab States  OMN
# 47752                 Qatar     Arab States  QAT
# 47753          Saudi Arabia     Arab States  SAU
# 47754  United Arab Emirates     Arab States  ARE
# 47755              Cambodia  Asia & Pacific  KHM
# 47756                 China  Asia & Pacific  CHN
# 47757      Hong Kong, China  Asia & Pacific  HKG
# 47758             Indonesia  Asia & Pacific  IDN
#
#                                   Indicator name    Year       Value  \
# 47744  Individuals using the Internet, total (%)  2020.0   64.884904
# 47745  Individuals using the Internet, total (%)  2020.0         NaN
# 47746  Individuals using the Internet, total (%)  2020.0   99.539512
# 47747  Individuals using the Internet, total (%)  2020.0   71.914200
# 47748  Individuals using the Internet, total (%)  2020.0         NaN
# 47749  Individuals using the Internet, total (%)  2020.0   98.599995
# 47750  Individuals using the Internet, total (%)  2020.0   84.120363
# 47751  Individuals using the Internet, total (%)  2020.0   95.232293
# 47752  Individuals using the Internet, total (%)  2020.0   99.652794
# 47753  Individuals using the Internet, total (%)  2020.0   97.862332
# 47754  Individuals using the Internet, total (%)  2020.0  100.000000
# 47755  Individuals using the Internet, total (%)  2020.0   78.800000
# 47756  Individuals using the Internet, total (%)  2020.0   70.642143
# 47757  Individuals using the Internet, total (%)  2020.0   92.413136
# 47758  Individuals using the Internet, total (%)  2020.0   53.726494
#
#        data_country  data_year
# 47744           NaN        NaN
# 47745           NaN        NaN
# 47746           NaN        NaN
# 47747           NaN        NaN
# 47748           NaN        NaN
# 47749           NaN        NaN
# 47750           NaN        NaN
# 47751           NaN        NaN
# 47752           NaN        NaN
# 47753           NaN        NaN
# 47754           NaN        NaN
# 47755           NaN        NaN
# 47756           NaN        NaN
# 47757           NaN        NaN
# 47758           NaN        NaN

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df.rename(columns = {'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(150)
# Out:
#                            Country Name    Year  \
# 47744                         Mauritius  2020.0
# 47745                            Uganda  2020.0
# 47746                           Bahrain  2020.0
# 47747                             Egypt  2020.0
# 47748                              Iraq  2020.0
# ...                                 ...     ...
# 47805  Bolivia (Plurinational State of)  2020.0
# 47806                        Costa Rica  2020.0
# 47807                            Mexico  2020.0
# 47808                          Paraguay  2020.0
# 47809                              Peru  2020.0
#
#                                             Indicator   data_col  \
# 47744  Mobile cellular subscriptions (per 100 people)  64.884904
# 47745  Mobile cellular subscriptions (per 100 people)        NaN
# 47746  Mobile cellular subscriptions (per 100 people)  99.539512
# 47747  Mobile cellular subscriptions (per 100 people)  71.914200
# 47748  Mobile cellular subscriptions (per 100 people)        NaN
# ...                                               ...        ...
# 47805  Mobile cellular subscriptions (per 100 people)  55.139051
# 47806  Mobile cellular subscriptions (per 100 people)  80.530186
# 47807  Mobile cellular subscriptions (per 100 people)  71.970000
# 47808  Mobile cellular subscriptions (per 100 people)  74.515240
# 47809  Mobile cellular subscriptions (per 100 people)  65.251799
#
#        new_rank_score  higher_is_better
# 47744        3.298839              True
# 47745             NaN              True
# 47746        5.964578              True
# 47747        3.839554              True
# 47748             NaN              True
# ...               ...               ...
# 47805        2.549158              True
# 47806        4.502322              True
# 47807        3.843846              True
# 47808        4.039634              True
# 47809        3.327061              True
#
# [66 rows x 6 columns]

# %%
### 23. Average fixed broadband download speeds

# %%
indicators[22]

# load data
indicator = indicators[22]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Average fixed broadband download speeds
# fixed_bdbd_spd_dl_ul

# %%
df.head(15)
# Out:
#           country  broadband  mobile     pop2021
# 0       Singapore     226.60   60.52    5896.686
# 1       Hong Kong     210.73   50.96    7552.810
# 2         Romania     193.47   40.35   19127.774
# 3     Switzerland     178.81   64.10    8715.494
# 4        Thailand     175.22   34.38   69950.850
# 5          France     173.05   49.82   65426.179
# 6         Denmark     162.08   63.86    5813.298
# 7          Monaco     162.06     NaN      39.511
# 8         Hungary     161.51   44.52    9634.164
# 9   United States     161.14   47.13  332915.073
# 10          Spain     157.22   39.03   46745.216
# 11  Liechtenstein     156.94     NaN      38.250
# 12         Sweden     156.34   53.13   10160.169
# 13    South Korea     155.39  121.00   51305.186
# 14          Macau     154.57   53.30     658.394

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df['broadband'] 
df.rename(columns = {'country':'Country'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#           Country  Year                                 Indicator  data_col  \
# 0       Singapore  2021  Average fixed broadband download speeds     226.60
# 1       Hong Kong  2021  Average fixed broadband download speeds     210.73
# 2         Romania  2021  Average fixed broadband download speeds     193.47
# 3     Switzerland  2021  Average fixed broadband download speeds     178.81
# 4        Thailand  2021  Average fixed broadband download speeds     175.22
# 5          France  2021  Average fixed broadband download speeds     173.05
# 6         Denmark  2021  Average fixed broadband download speeds     162.08
# 7          Monaco  2021  Average fixed broadband download speeds     162.06
# 8         Hungary  2021  Average fixed broadband download speeds     161.51
# 9   United States  2021  Average fixed broadband download speeds     161.14
# 10          Spain  2021  Average fixed broadband download speeds     157.22
# 11  Liechtenstein  2021  Average fixed broadband download speeds     156.94
# 12         Sweden  2021  Average fixed broadband download speeds     156.34
# 13    South Korea  2021  Average fixed broadband download speeds     155.39
# 14          Macau  2021  Average fixed broadband download speeds     154.57
#
#     new_rank_score  higher_is_better
# 0         6.000000              True
# 1         5.644489              True
# 2         5.257841              True
# 3         4.929435              True
# 4         4.849014              True
# 5         4.800403              True
# 6         4.554659              True
# 7         4.554211              True
# 8         4.541891              True
# 9         4.533602              True
# 10        4.445789              True
# 11        4.439516              True
# 12        4.426075              True
# 13        4.404794              True
# 14        4.386425              True

# %%
### 24. Postal Coverage

# %%
indicators[23]

# load data
indicator = indicators[23]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Postal Coverage
# postal_coverage

# %%
df.head(15)
# Out:
#     2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  93.0   NaN   NaN
# 1    NaN   NaN   NaN   NaN   NaN  17.0   NaN   NaN   NaN   NaN   NaN
# 2    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   0.0   NaN   NaN
# 3    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  70.0   NaN
# 4    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  74.0   NaN
# 5    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  10.0   NaN
# 7    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  15.0
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   8.9
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  55.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  99.6   NaN   NaN
# 12   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   8.3   NaN   NaN
# 13   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   0.0   NaN   NaN
#
#    Country ISO3 Country Name  Indicator Id  \
# 0           ABW        Aruba         24707
# 1           ABW        Aruba         24708
# 2           ABW        Aruba         24710
# 3           AFG  Afghanistan         24707
# 4           AFG  Afghanistan         24708
# 5           AFG  Afghanistan         24709
# 6           AFG  Afghanistan         24710
# 7           AGO       Angola         24707
# 8           AGO       Angola         24708
# 9           AGO       Angola         24709
# 10          AGO       Angola         24710
# 11          ALB      Albania         24707
# 12          ALB      Albania         24708
# 13          ALB      Albania         24709
# 14          ALB      Albania         24710
#
#                                             Indicator Subindicator Type  \
# 0   Percent of Population Having Mail Delivered at...             Value
# 1   Percent of Income Linked to Parcels and Logist...             Value
# 2   Percent of the Population Without Postal Services             Value
# 3   Percent of Population Having Mail Delivered at...             Value
# 4   Percent of Income Linked to Parcels and Logist...             Value
# 5                            Postal Reliability Index     Index (0-100)
# 6   Percent of the Population Without Postal Services             Value
# 7   Percent of Population Having Mail Delivered at...             Value
# 8   Percent of Income Linked to Parcels and Logist...             Value
# 9                            Postal Reliability Index     Index (0-100)
# 10  Percent of the Population Without Postal Services             Value
# 11  Percent of Population Having Mail Delivered at...             Value
# 12  Percent of Income Linked to Parcels and Logist...             Value
# 13                           Postal Reliability Index     Index (0-100)
# 14  Percent of the Population Without Postal Services             Value
#
#     2013-14
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5      17.9
# 6       NaN
# 7       NaN
# 8       NaN
# 9      15.3
# 10      NaN
# 11      NaN
# 12      NaN
# 13     79.6
# 14      NaN

# %%
#Choose 'Percent of Population Having Mail Delivered at Home' as the data column
df = df[(df.Indicator=='Percent of Population Having Mail Delivered at Home')]
df.head(15)

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2015
df['Indicator'] = indicator
df['data_col'] = df['2015'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year        Indicator  data_col  new_rank_score  \
# 0                  Aruba  2015  Postal Coverage       NaN             NaN
# 3            Afghanistan  2015  Postal Coverage       NaN             NaN
# 7                 Angola  2015  Postal Coverage      15.0            1.75
# 11               Albania  2015  Postal Coverage       NaN             NaN
# 15  United Arab Emirates  2015  Postal Coverage       NaN             NaN
# 19             Argentina  2015  Postal Coverage      93.0            5.65
# 23               Armenia  2015  Postal Coverage      93.0            5.65
# 27   Antigua and Barbuda  2015  Postal Coverage      80.0            5.00
# 30             Australia  2015  Postal Coverage       NaN             NaN
# 33               Austria  2015  Postal Coverage      99.0            5.95
# 38               Burundi  2015  Postal Coverage       NaN             NaN
# 42               Belgium  2015  Postal Coverage       NaN             NaN
# 45                 Benin  2015  Postal Coverage       6.0            1.30
# 49          Burkina Faso  2015  Postal Coverage       0.0            1.00
# 53            Bangladesh  2015  Postal Coverage       NaN             NaN
#
#     higher_is_better
# 0               True
# 3               True
# 7               True
# 11              True
# 15              True
# 19              True
# 23              True
# 27              True
# 30              True
# 33              True
# 38              True
# 42              True
# 45              True
# 49              True
# 53              True

# %%
### 25. Logistics Performance Index (LPI)

# %%
indicators[24]

# load data
indicator = indicators[24]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Logistics Performance Index (LPI) - Infrastructure Rating
# logistics_performance_index

# %%
df.head(15)
# Out:
#                  Country Code  score  lower bound  upper bound  rank  \
# 0                Germany  DEU   4.39            1            1     3
# 1                 Sweden  SWE   4.28            2           12     7
# 2                Belgium  BEL   4.41            2           12     1
# 3                Austria  AUT   4.25            2           14    12
# 4                  Japan  JPN   4.25            2           10    10
# 5            Netherlands  NLD   4.25            2           11    11
# 6              Singapore  SGP   4.32            2           15     6
# 7                Denmark  DNK   4.41            2           17     2
# 8         United Kingdom  GBR   4.33            3           11     5
# 9                Finland  FIN   4.28            1           21     8
# 10  United Arab Emirates  ARE   4.38            2           15     4
# 11  Hong Kong SAR, China  HKG   4.14            7           17    15
# 12           Switzerland  CHE   4.24            7           17    13
# 13         United States  USA   4.08           12           17    19
# 14           New Zealand  NZL   4.26            2           23     9
#
#     % of highest performer  data_country  data_year
# 0                   100.00           NaN        NaN
# 1                    95.36           NaN        NaN
# 2                    94.93           NaN        NaN
# 3                    94.52           NaN        NaN
# 4                    94.51           NaN        NaN
# 5                    94.31           NaN        NaN
# 6                    93.59           NaN        NaN
# 7                    93.45           NaN        NaN
# 8                    93.30           NaN        NaN
# 9                    92.74           NaN        NaN
# 10                   92.35           NaN        NaN
# 11                   91.21           NaN        NaN
# 12                   90.63           NaN        NaN
# 13                   90.12           NaN        NaN
# 14                   89.82           NaN        NaN

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2018
df['Indicator'] = indicator
df['data_col'] = df['score']
df.rename(columns={'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year  \
# 0                Germany  2018
# 1                 Sweden  2018
# 2                Belgium  2018
# 3                Austria  2018
# 4                  Japan  2018
# 5            Netherlands  2018
# 6              Singapore  2018
# 7                Denmark  2018
# 8         United Kingdom  2018
# 9                Finland  2018
# 10  United Arab Emirates  2018
# 11  Hong Kong SAR, China  2018
# 12           Switzerland  2018
# 13         United States  2018
# 14           New Zealand  2018
#
#                                             Indicator  data_col  \
# 0   Logistics Performance Index (LPI) - Infrastruc...      4.39
# 1   Logistics Performance Index (LPI) - Infrastruc...      4.28
# 2   Logistics Performance Index (LPI) - Infrastruc...      4.41
# 3   Logistics Performance Index (LPI) - Infrastruc...      4.25
# 4   Logistics Performance Index (LPI) - Infrastruc...      4.25
# 5   Logistics Performance Index (LPI) - Infrastruc...      4.25
# 6   Logistics Performance Index (LPI) - Infrastruc...      4.32
# 7   Logistics Performance Index (LPI) - Infrastruc...      4.41
# 8   Logistics Performance Index (LPI) - Infrastruc...      4.33
# 9   Logistics Performance Index (LPI) - Infrastruc...      4.28
# 10  Logistics Performance Index (LPI) - Infrastruc...      4.38
# 11  Logistics Performance Index (LPI) - Infrastruc...      4.14
# 12  Logistics Performance Index (LPI) - Infrastruc...      4.24
# 13  Logistics Performance Index (LPI) - Infrastruc...      4.08
# 14  Logistics Performance Index (LPI) - Infrastruc...      4.26
#
#     new_rank_score  higher_is_better
# 0         5.957806              True
# 1         5.725738              True
# 2         6.000000              True
# 3         5.662447              True
# 4         5.662447              True
# 5         5.662447              True
# 6         5.810127              True
# 7         6.000000              True
# 8         5.831224              True
# 9         5.725738              True
# 10        5.936709              True
# 11        5.430380              True
# 12        5.641350              True
# 13        5.303797              True
# 14        5.683544              True

# %%
### 26.Schools with Internet proportion

# %%
indicators[25]

# load data
indicator = indicators[25]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Schools with Internet proportion
# schools_w_internet

# %%
df.head(15)
# Out:
#    Instructional computers and rooms, and access All public schools  \
# 0                                            NaN                NaN
# 1                                            NaN                NaN
# 2                                            NaN                NaN
# 3                                            NaN                NaN
# 4                                              1                  2
# 5                                 Computers for                 NaN
# 6                                  instructional                NaN
# 7                                       purposes                NaN
# 8                                         Number                NaN
# 9                                 (in thousands)                NaN
# 10                  1995\4\ ....................              5,621
# 11             2000 ............................              8,776
# 12              2005 ...........................             12,672
# 13              2008 ...........................             15,434
# 14                               Average number                 NaN
#
#     Unnamed: 2 Instructional level\1\ Size of school enrollment  \
# 0          NaN                    NaN                       NaN
# 1          NaN             Elementary             Less than 300
# 2          NaN                    NaN                      Less
# 3          NaN                    NaN                  than 300
# 4          NaN                      3                         5
# 5          NaN                    NaN                       NaN
# 6          NaN                    NaN                       NaN
# 7          NaN                    NaN                       NaN
# 8          NaN                    NaN                       NaN
# 9          NaN                    NaN                       NaN
# 10         NaN                  3,453                       850
# 11         NaN                  5,296                     1,135
# 12         NaN                  7,701                     1,566
# 13         NaN                  9,711                     1,746
# 14         NaN                    NaN                       NaN
#
#    Community type\2\  \
# 0                NaN
# 1               City
# 2                NaN
# 3               City
# 4                  8
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10             1,497
# 11             2,537
# 12             3,132
# 13             3,611
# 14               NaN
#
#    Percent of students eligible for free or reduced-price lunch\3\  \
# 0                                                 NaN
# 1                                Less than 35 percent
# 2                                                 NaN
# 3                                                 NaN
# 4                                                  12
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                              2,905
# 11                                              4,394
# 12                                              5,352
# 13                                              6,195
# 14                                                NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
### 32.National cyber security index

# %%
indicators[31]

# load data
indicator = indicators[31]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df['National Cyber Security Index'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 33. Global Cybersecurity Index (GCI)

# %%
indicators[32]

# load data
indicator = indicators[32]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)
#The Data is practically unusable, find a new one

# %%
### 34. Software Developer Ecosystem size

# %%
indicators[33]

# load data
indicator = indicators[33]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2018
df['Indicator'] = indicator
df['data_col'] = df['GitHub Accounts']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

#There is a small error in the column name this has been addressed, waiting for files to be updated

# %%
### 35. Digital Work Ecosystem size

# %%
indicators[34]

# load data
indicator = indicators[34]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = False
df['Year'] = 2020
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,[0]].astype(float)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# invert since to lower rank is better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Two problems: 1. cannot use the name of the column, have to use iloc, 2. cannot use the index column
# because the number format is not standard, have to use the rank column

# %%
### 36. Country, Industry, Skill Migration Data (Skill)

# %%
indicators[35]

# load data
indicator = indicators[35]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['Country'] = df.iloc[:,[1]]

df_sum = df.groupby('Country')[['net_per_10K_2019']].sum()
df_sum

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 37. Country, Industry, Skill Migration Data (Industry)

# %%
indicators[36]

# load data
indicator = indicators[36]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['Country'] = df.iloc[:,[1]]

df_sum = df.groupby('Country')[['net_per_10K_2019']].sum()
df_sum

# %%
## create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 38. Country, Industry, Skill Migration Data (Nation)

# %%
indicators[37]

# load data
indicator = indicators[37]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['Country'] = df.iloc[:,[1]]

df_sum = df.groupby('Country')[['net_per_10K_2019']].sum()
df_sum

# %%
## create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 39. Digital Finance Ecosystem size

# %%
indicators[38]

# load data
indicator = indicators[38]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,[2]]
df['Country Name'] = df.iloc[:,[1]]

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# Have to shorten the column names to see if this works

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 40. Tech hubs & spaces size

# %%
indicators[39]

# load data
indicator = indicators[39]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

#There are two problems:
#1. The column names need some overhaul (moving the second column to the top and make it the column names)
#2. This is a list of cities, not countries, may present probkems later.

# %%
### 41. Banking Ecosystem size

# %%
indicators[40]

# load data
indicator = indicators[40]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2017
df['Indicator'] = indicator
df['data_col'] = df['Bank assets, percent of GDP, 2017']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but will have to remove number from the Country column, leaving only characters.

# %%
### 42. Angel Ecosystem size

# %%
indicators[41]

# load data
indicator = indicators[41]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2019
df['Indicator'] = indicator
df['data_col'] = df['Business angel investments (in million Euros)']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but there are only EU countries

# %%
### 43. Startup Ecosystem size

# %%
indicators[42]

# load data
indicator = indicators[42]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# This is a list of cities, not countries, wonder if it will work

# %%
### 44. Venture Ecosystem size

# Similar to the previous one

# %%
### 45. International Co-Inventions

# %%
indicators[44]

# load data
indicator = indicators[44]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year and global value
df = df[(df.Time==2017)]
df = df[(df.Country!='World')]
df

# %%
# Create summarization
df_sum = df.groupby('Country')[['Value']].sum()
df_sum

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2017
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum.iloc[:,[0]]

min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but the data is too general with many missing countries
