# %%
import pandas as pd
import numpy as np

# %%
### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False           Countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              20         25
# Foundations            9         12
# Government            11         15
# Infrastructure        45         48
# People                38         46
# Regulation             6          7
# Strategy               1          1

# %%
### Infrastructure

# %%
bnames = names[(names.check=='Infrastructure')&(~names.Filename.isna())]#&(names.Index==False)]
bnames.head(25)
# Out:
#                                             Indicator           check  \
# 4                                  Population Density  Infrastructure
# 5                                   Broadband Density  Infrastructure
# 6    % of population covered by internet connectivity  Infrastructure
# 7   % of population covered by mobile 2G+ data con...  Infrastructure
# 8   % of population covered by mobile 3G+ data con...  Infrastructure
# 9   % of population covered by mobile 4G+ data con...  Infrastructure
# 10  % of population covered by mobile 5G+ data con...  Infrastructure
# 11                               Mobile Coverage Maps  Infrastructure
# 12                                Electricity Density  Infrastructure
# 13             % of population covered by electricity  Infrastructure
# 14                         Electricity supply quality  Infrastructure
# 15           Electricity Environmental Sustainability  Infrastructure
# 16                  Electrical Distribution Grid Maps  Infrastructure
# 17                           Cellphone Signal Density  Infrastructure
# 18       Telecommunication Infrastructure Index (TII)  Infrastructure
# 19                    GSMA Mobile Connectivity Index   Infrastructure
# 20             Spectrum Allocated to Mobile Providers  Infrastructure
# 23                Internet Exchange Points (IXPs) map  Infrastructure
# 24                                 ISP Speeds - Fixed  Infrastructure
# 25                                ISP Speeds - Mobile  Infrastructure
# 26               ISP internet download speed average   Infrastructure
# 28  Mobile dowload speed at the slowest hour of th...  Infrastructure
# 29                     Mobile download speed average   Infrastructure
# 30   Individuals using the Internet (% of population)  Infrastructure
# 31     Mobile cellular subscriptions (per 100 people)  Infrastructure
#
#                                           Data Source  Index  \
# 4                                          World Bank  False
# 5                                          World Bank  False
# 6                                          World Bank  False
# 7                      GSMA Mobile Connectivity Index  False
# 8                      GSMA Mobile Connectivity Index  False
# 9                      GSMA Mobile Connectivity Index  False
# 10                     GSMA Mobile Connectivity Index  False
# 11                     GSMA Mobile Connectivity Index  False
# 12                                        Energy Data  False
# 13                                        World Bank   False
# 14  International Energy Agency / Global Competiti...  False
# 15  The Sustainable Development Report/ Cambridge ...  False
# 16                                           Facebook  False
# 17                     GSMA Mobile Connectivity Index  False
# 18                                               DESA   True
# 19                     GSMA Mobile Connectivity Index   True
# 20                     GSMA Mobile Connectivity Index  False
# 23                              Packet Clearing House  False
# 24                 Ookla's Speedtest Intelligence/AWS  False
# 25                 Ookla's Speedtest Intelligence/AWS  False
# 26                     Ookla's Speedtest Intelligence  False
# 28                     GSMA Mobile Connectivity Index  False
# 29                     Ookla's Speedtest Intelligence  False
# 30                                                ITU  False
# 31                                         World Bank  False
#
#                                Filename
# 4                    population_density
# 5               fixed_broadband_density
# 6            population_access_internet
# 7         countries_mobile_connectivity
# 8         countries_mobile_connectivity
# 9         countries_mobile_connectivity
# 10        countries_mobile_connectivity
# 11                      mobile_coverage
# 12                 electricity_yearbook
# 13      population_electricity_coverage
# 14                 elect_supply_quality
# 15                 sustainability_index
# 16                  elect_dist_grid_map
# 17                       mobile_density
# 18                   e_government_index
# 19        countries_mobile_connectivity
# 20  spectrum_allocated_mobile_providers
# 23                        countries_ixp
# 24    speedtest-global-performance.yaml
# 25    speedtest-global-performance.yaml
# 26                       internet_speed
# 28                       mobile_latency
# 29                         mobile_speed
# 30            individual_internet_usage
# 31                      mobile_cell_sub

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['population_density', 'fixed_broadband_density',
#        'population_access_internet', 'countries_mobile_connectivity',
#        'mobile_coverage', 'electricity_yearbook',
#        'population_electricity_coverage', 'elect_supply_quality',
#        'sustainability_index', 'elect_dist_grid_map', 'mobile_density',
#        'e_government_index', 'spectrum_allocated_mobile_providers',
#        'countries_ixp', 'speedtest-global-performance.yaml',
#        'internet_speed', 'mobile_latency', 'mobile_speed',
#        'individual_internet_usage', 'mobile_cell_sub',
#        'fixed_bdbd_spd_dl_ul',
#        'fixed_broadband_speed_download_upload_latency', 'postal_coverage',
#        'World Bank The Logistics Performance Index 2007 to 2018.xlsx',
#        'schools_w_internet', 'national_cybersecurity_index',
#        'dice_export_global_cybersecurity_index',
#        'software_developer_ecosystem_size',
#        'digital_platform_economy_index', 'migration_skill',
#        'migration_industry', 'migration_country',
#        'global_fintech_ranking', 'tech_hubs', 'banking_sector_size',
#        'angel_investment', 'startup_eco_size',
#        'international_co_inventions'], dtype=object)

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %%
### 2. Broadband Density

# %%
indicators[1]

# load data
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Broadband Density
# fixed_broadband_density
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-72afceee5c73> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/fixed_broadband_density.csv'

# %%
### 3. % of population covered by internet connectivity

# %%
indicators[2]

# load data
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by internet connectivity
# population_access_internet
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-91c83eedb488> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/population_access_internet.csv'

# %%
### 4. % of population covered by mobile 2G

# %%
indicators[3]
# Out:
# '% of population covered by mobile 2G+ data connectivity'

# %%
# load data
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 2G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 2G+ data con...     90.00
# 11  % of population covered by mobile 2G+ data con...     90.00
# 17  % of population covered by mobile 2G+ data con...     99.86
# 23  % of population covered by mobile 2G+ data con...    100.00
# 29  % of population covered by mobile 2G+ data con...     98.00
# 35  % of population covered by mobile 2G+ data con...    100.00
# 41  % of population covered by mobile 2G+ data con...     99.40
# 47  % of population covered by mobile 2G+ data con...     99.00
# 53  % of population covered by mobile 2G+ data con...    100.00
# 59  % of population covered by mobile 2G+ data con...     53.65
# 65  % of population covered by mobile 2G+ data con...    100.00
# 71  % of population covered by mobile 2G+ data con...     98.00
# 77  % of population covered by mobile 2G+ data con...     97.90
# 83  % of population covered by mobile 2G+ data con...     99.60
# 89  % of population covered by mobile 2G+ data con...    100.00
#
#     new_rank_score  higher_is_better
# 5         4.921251              True
# 11        4.921251              True
# 17        5.984898              True
# 23        6.000000              True
# 29        5.784250              True
# 35        6.000000              True
# 41        5.935275              True
# 47        5.892125              True
# 53        6.000000              True
# 59        1.000000              True
# 65        6.000000              True
# 71        5.784250              True
# 77        5.773463              True
# 83        5.956850              True
# 89        6.000000              True

# %%
### 5. % of population covered by mobile 3G

# %%
indicators[4]

# load data
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 3G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['3G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 3G+ data con...      58.7
# 11  % of population covered by mobile 3G+ data con...      71.0
# 17  % of population covered by mobile 3G+ data con...      97.0
# 23  % of population covered by mobile 3G+ data con...     100.0
# 29  % of population covered by mobile 3G+ data con...      95.0
# 35  % of population covered by mobile 3G+ data con...      99.0
# 41  % of population covered by mobile 3G+ data con...      99.5
# 47  % of population covered by mobile 3G+ data con...      99.0
# 53  % of population covered by mobile 3G+ data con...      95.0
# 59  % of population covered by mobile 3G+ data con...      40.0
# 65  % of population covered by mobile 3G+ data con...     100.0
# 71  % of population covered by mobile 3G+ data con...      89.0
# 77  % of population covered by mobile 3G+ data con...      65.0
# 83  % of population covered by mobile 3G+ data con...      95.0
# 89  % of population covered by mobile 3G+ data con...     100.0
#
#     new_rank_score  higher_is_better
# 5         3.282895              True
# 11        4.092105              True
# 17        5.802632              True
# 23        6.000000              True
# 29        5.671053              True
# 35        5.934211              True
# 41        5.967105              True
# 47        5.934211              True
# 53        5.671053              True
# 59        2.052632              True
# 65        6.000000              True
# 71        5.276316              True
# 77        3.697368              True
# 83        5.671053              True
# 89        6.000000              True

# %%
### 6. % of population covered by mobile 4G

# %%
indicators[5]

# load data
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 4G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['4G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 4G+ data con...     15.00
# 11  % of population covered by mobile 4G+ data con...     50.00
# 17  % of population covered by mobile 4G+ data con...     96.00
# 23  % of population covered by mobile 4G+ data con...     99.00
# 29  % of population covered by mobile 4G+ data con...     89.77
# 35  % of population covered by mobile 4G+ data con...     95.00
# 41  % of population covered by mobile 4G+ data con...     99.20
# 47  % of population covered by mobile 4G+ data con...     99.00
# 53  % of population covered by mobile 4G+ data con...     90.00
# 59  % of population covered by mobile 4G+ data con...     25.00
# 65  % of population covered by mobile 4G+ data con...    100.00
# 71  % of population covered by mobile 4G+ data con...     45.00
# 77  % of population covered by mobile 4G+ data con...      8.64
# 83  % of population covered by mobile 4G+ data con...     80.00
# 89  % of population covered by mobile 4G+ data con...    100.00
#
#     new_rank_score  higher_is_better
# 5           1.7500              True
# 11          3.5000              True
# 17          5.8000              True
# 23          5.9500              True
# 29          5.4885              True
# 35          5.7500              True
# 41          5.9600              True
# 47          5.9500              True
# 53          5.5000              True
# 59          2.2500              True
# 65          6.0000              True
# 71          3.2500              True
# 77          1.4320              True
# 83          5.0000              True
# 89          6.0000              True

# %%
### 7. % of population covered by mobile 5G

# %%
indicators[6]

# load data
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 5G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['5G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 5G+ data con...       0.0
# 11  % of population covered by mobile 5G+ data con...       0.0
# 17  % of population covered by mobile 5G+ data con...       0.0
# 23  % of population covered by mobile 5G+ data con...     100.0
# 29  % of population covered by mobile 5G+ data con...       0.0
# 35  % of population covered by mobile 5G+ data con...       0.0
# 41  % of population covered by mobile 5G+ data con...     100.0
# 47  % of population covered by mobile 5G+ data con...     100.0
# 53  % of population covered by mobile 5G+ data con...       0.0
# 59  % of population covered by mobile 5G+ data con...       0.0
# 65  % of population covered by mobile 5G+ data con...       0.0
# 71  % of population covered by mobile 5G+ data con...       0.0
# 77  % of population covered by mobile 5G+ data con...       0.0
# 83  % of population covered by mobile 5G+ data con...       0.0
# 89  % of population covered by mobile 5G+ data con...       0.0
#
#     new_rank_score  higher_is_better
# 5              1.0              True
# 11             1.0              True
# 17             1.0              True
# 23             6.0              True
# 29             1.0              True
# 35             1.0              True
# 41             6.0              True
# 47             6.0              True
# 53             1.0              True
# 59             1.0              True
# 65             1.0              True
# 71             1.0              True
# 77             1.0              True
# 83             1.0              True
# 89             1.0              True

# %%
### 8. Mobile Coverage Maps

# %%
indicators[7]

# load data
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Mobile Coverage Maps
# mobile_coverage
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-6773d3a00b35> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/mobile_coverage.csv'

# %%
### 9. Electricity Density

# %%
indicators[8]

# load data
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electricity Density
# electricity_yearbook

# %%
df.head(10)
# Out:
#       1990     1991     1992     1993     1994     1995     1996     1997  \
# 0  11894.0  12173.0  12284.0  12574.0  12881.0  13327.0  13754.0  14045.0
# 1   7712.0   7900.0   7975.0   8160.0   8389.0   8646.0   8889.0   9014.0
# 2   6089.0   6236.0   6277.0   6414.0   6578.0   6760.0   6944.0   6985.0
# 3   2386.0   2468.0   2510.0   2583.0   2637.0   2754.0   2863.0   2961.0
# 4   2900.0   2937.0   2926.0   2931.0   2976.0   3071.0   3164.0   3199.0
# 5   2595.0   2640.0   2624.0   2626.0   2667.0   2744.0   2846.0   2857.0
# 6     71.0     72.0     72.0     71.0     72.0     74.0     76.0     79.0
# 7     63.0     61.0     59.0     59.0     59.0     61.0     64.0     65.0
# 8    421.0    456.0    464.0    473.0    477.0    494.0    513.0    505.0
# 9    550.0    540.0    537.0    526.0    529.0    537.0    555.0    552.0
#
#       1998     1999  ...     2013     2014     2015     2016     2017  \
# 0  14414.0  14823.0  ...  23424.0  23910.0  24317.0  24918.0  25592.0
# 1   9244.0   9451.0  ...  10902.0  10875.0  10914.0  10967.0  11069.0
# 2   7142.0   7272.0  ...   7897.0   7876.0   7867.0   7848.0   7898.0
# 3   3026.0   3170.0  ...   8524.0   8880.0   9142.0   9550.0  10000.0
# 4   3280.0   3327.0  ...   3813.0   3744.0   3802.0   3839.0   3886.0
# 5   2923.0   2955.0  ...   3269.0   3191.0   3234.0   3253.0   3275.0
# 6     83.0     85.0  ...     83.0     73.0     71.0     86.0     87.0
# 7     65.0     65.0  ...     87.0     86.0     84.0     83.0     87.0
# 8    511.0    526.0  ...    572.0    564.0    568.0    553.0    551.0
# 9    556.0    556.0  ...    639.0    628.0    647.0    648.0    653.0
#
#       Unnamed: 28  2016 - 2017 (%)   2000 - 2017 (%/year)     data_country  \
# 0           World               2.7                    3.0           World
# 1            OECD               0.9                    0.7            OECD
# 2              G7               0.6                    0.3              G7
# 3           BRICS               4.7                    6.6           BRICS
# 4          Europe               1.2                    0.7          Europe
# 5  European Union               0.7                    0.4  European Union
# 6         Belgium               0.5                    0.2         Belgium
# 7      Czech Rep.               4.5                    1.0      Czech Rep.
# 8          France              -0.4                    0.1          France
# 9         Germany               0.6                    0.7         Germany
#
#         data_year
# 0           World
# 1            OECD
# 2              G7
# 3           BRICS
# 4          Europe
# 5  European Union
# 6         Belgium
# 7      Czech Rep.
# 8          France
# 9         Germany
#
# [10 rows x 33 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2017'] 
df['Country'] = df['Unnamed: 28']
df['Year'] = 2017

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#            Country  Year            Indicator  data_col  new_rank_score  \
# 0            World  2017  Electricity Density   25592.0        6.000000
# 1             OECD  2017  Electricity Density   11069.0        3.159482
# 2               G7  2017  Electricity Density    7898.0        2.539274
# 3            BRICS  2017  Electricity Density   10000.0        2.950399
# 4           Europe  2017  Electricity Density    3886.0        1.754577
# 5   European Union  2017  Electricity Density    3275.0        1.635073
# 6          Belgium  2017  Electricity Density      87.0        1.011540
# 7       Czech Rep.  2017  Electricity Density      87.0        1.011540
# 8           France  2017  Electricity Density     551.0        1.102292
# 9          Germany  2017  Electricity Density     653.0        1.122242
# 10           Italy  2017  Electricity Density     295.0        1.052222
# 11     Netherlands  2017  Electricity Density     117.0        1.017407
# 12          Poland  2017  Electricity Density     171.0        1.027969
# 13        Portugal  2017  Electricity Density      60.0        1.006259
# 14         Romania  2017  Electricity Density      64.0        1.007041
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True

# %%
### 10. % of population covered by electricity

# %%
indicators[9]

# load data
indicator = indicators[9]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by electricity
# population_electricity_coverage
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-65-98704f74efaf> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/population_electricity_coverage.csv'

# %%
### 11. % of population covered by electricity

# %%
indicators[10]

# load data
indicator = indicators[10]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electricity supply quality
# elect_supply_quality

# %%
df.head(10)
# Out:
#          Unnamed: 0                                                AGO  \
# 0         Attribute                                             Angola
# 1             VALUE                                                NaN
# 2              RANK                                                136
# 3             SCORE                                        38.11248593
# 4  DATE DESCRIPTION                                       2019 edition
# 5            SOURCE  World Economic Forum, [i]Global Competitivenes...
# 6       SOURCE DATE                                                NaN
# 7              NOTE  See Appendix A of the Global Competitiveness R...
# 8             VALUE                                                NaN
# 9              RANK                                                136
#
#                                                  ALB  \
# 0                                            Albania
# 1                                                NaN
# 2                                                 81
# 3                                        57.61416881
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 88
#
#                                                  ARE  \
# 0                               United Arab Emirates
# 1                                                NaN
# 2                                                 25
# 3                                        75.00738794
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                  3
#
#                                                  ARG  \
# 0                                          Argentina
# 1                                                NaN
# 2                                                 83
# 3                                        57.20132859
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                109
#
#                                                  ARM  \
# 0                                            Armenia
# 1                                                NaN
# 2                                                 69
# 3                                        61.27687643
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 62
#
#                                                  AUS  \
# 0                                          Australia
# 1                                                NaN
# 2                                                 16
# 3                                        78.74662637
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 22
#
#                                                  AUT  \
# 0                                            Austria
# 1                                                NaN
# 2                                                 21
# 3                                        76.60913087
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 20
#
#                                                  AZE  \
# 0                                         Azerbaijan
# 1                                                NaN
# 2                                                 58
# 3                                        62.71789348
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 64
#
#                                                  BDI  ...  \
# 0                                            Burundi  ...
# 1                                                NaN  ...
# 2                                                135  ...
# 3                                        40.25234131  ...
# 4                                       2019 edition  ...
# 5  World Economic Forum, [i]Global Competitivenes...  ...
# 6                                                NaN  ...
# 7  See Appendix A of the Global Competitiveness R...  ...
# 8                                                NaN  ...
# 9                                                134  ...
#
#                                           GCREURASIA  \
# 0                                            Eurasia
# 1                                                NaN
# 2                                                NaN
# 3                                        59.37969533
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                               GCREAP  \
# 0                              East Asia and Pacific
# 1                                                NaN
# 2                                                NaN
# 3                                        69.86862667
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                             GCRSASIA  \
# 0                                         South Asia
# 1                                                NaN
# 2                                                NaN
# 3                                        54.70460508
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  LIC  \
# 0                                         Low-income
# 1                                                NaN
# 2                                                NaN
# 3                                         43.7445505
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  LMC  \
# 0                                Lower-middle-income
# 1                                                NaN
# 2                                                NaN
# 3                                        51.94942309
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  UMC  \
# 0                                Upper-middle-income
# 1                                                NaN
# 2                                                NaN
# 3                                         59.7912297
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  HIC  \
# 0                                        High-income
# 1                                                NaN
# 2                                                NaN
# 3                                        72.78080961
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  AVG      data_country  \
# 0                                     Sample average         Attribute
# 1                                                NaN             VALUE
# 2                                                  0              RANK
# 3                                         60.6396938             SCORE
# 4                                       2019 edition  DATE DESCRIPTION
# 5  World Economic Forum, [i]Global Competitivenes...            SOURCE
# 6                                                NaN       SOURCE DATE
# 7  See Appendix A of the Global Competitiveness R...              NOTE
# 8                                                NaN             VALUE
# 9                                                  0              RANK
#
#           data_year
# 0         Attribute
# 1             VALUE
# 2              RANK
# 3             SCORE
# 4  DATE DESCRIPTION
# 5            SOURCE
# 6       SOURCE DATE
# 7              NOTE
# 8             VALUE
# 9              RANK
#
# [10 rows x 156 columns]

# %%
# The data needs to be transposed as countries are now in columns, not rows, which could present problems for later.

# %%
### 12. Electricity Environmental Sustainability

# %%
indicators[11]

# load data
indicator = indicators[11]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electricity Environmental Sustainability
# sustainability_index
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-71-d5d213f2e19c> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/sustainability_index.csv'

# %%
### 13. Electrical Distribution Grid Maps

# %%
indicators[12]

# load data
indicator = indicators[12]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electrical Distribution Grid Maps
# elect_dist_grid_map

# %%
df.head(10)
#No country names in the data file
# Out:
#         lat       lon  Electrical Distribution Grid
# 0  6.550017 -8.475952                             1
# 1  6.604587 -8.475952                             1
# 2  6.539103 -8.475952                             1
# 3  6.593674 -8.475952                             1
# 4  6.560932 -8.442993                             1
# 5  6.593674 -8.442993                             1
# 6  6.550017 -8.442993                             1
# 7  6.550017 -8.453979                             1
# 8  6.604587 -8.453979                             1
# 9  6.593674 -8.453979                             1

# %%
### 14. Cellphone Signal Density

# %%
indicators[13]

# load data
indicator = indicators[13]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Cellphone Signal Density
# mobile_density

# %%
df.head(10)
# Out:
#    Unnamed: 0 ISO Code      Country              Region  Year  \
# 0           1      AFG  Afghanistan          South Asia  2014
# 1           2      AFG  Afghanistan          South Asia  2015
# 2           3      AFG  Afghanistan          South Asia  2016
# 3           4      AFG  Afghanistan          South Asia  2017
# 4           5      AFG  Afghanistan          South Asia  2018
# 5           6      AFG  Afghanistan          South Asia  2019
# 6           7      AGO       Angola  Sub-Saharan Africa  2014
# 7           8      AGO       Angola  Sub-Saharan Africa  2015
# 8           9      AGO       Angola  Sub-Saharan Africa  2016
# 9          10      AGO       Angola  Sub-Saharan Africa  2017
#
#    Network coverage
# 0         28.919998
# 1         31.799999
# 2         33.040001
# 3         36.340000
# 4         30.931999
# 5         38.480000
# 6         51.445770
# 7         53.906952
# 8         61.174950
# 9         60.800003

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Network coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year                 Indicator   data_col  \
# 5            Afghanistan  2019  Cellphone Signal Density  38.480000
# 11                Angola  2019  Cellphone Signal Density  57.400002
# 17               Albania  2019  Cellphone Signal Density  87.186005
# 23  United Arab Emirates  2019  Cellphone Signal Density  99.599998
# 29             Argentina  2019  Cellphone Signal Density  83.708000
# 35               Armenia  2019  Cellphone Signal Density  87.599998
# 41             Australia  2019  Cellphone Signal Density  99.419998
# 47               Austria  2019  Cellphone Signal Density  99.099998
# 53            Azerbaijan  2019  Cellphone Signal Density  84.000000
# 59               Burundi  2019  Cellphone Signal Density  31.365000
# 65               Belgium  2019  Cellphone Signal Density  90.000000
# 71                 Benin  2019  Cellphone Signal Density  63.399998
# 77          Burkina Faso  2019  Cellphone Signal Density  39.245998
# 83            Bangladesh  2019  Cellphone Signal Density  79.959999
# 89              Bulgaria  2019  Cellphone Signal Density  90.000000
#
#     new_rank_score  higher_is_better
# 5         2.117926              True
# 11        3.311828              True
# 17        5.191403              True
# 23        5.974759              True
# 29        4.971932              True
# 35        5.217527              True
# 41        5.963400              True
# 47        5.943208              True
# 53        4.990358              True
# 59        1.668951              True
# 65        5.368974              True
# 71        3.690444              True
# 77        2.166263              True
# 83        4.735423              True
# 89        5.368974              True

# %%
### 15. Telecommunication Infrastructure Index (TII)

# %%
indicators[14]

# load data
indicator = indicators[14]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Telecommunication Infrastructure Index (TII)
# e_government_index

# %%
df.head(10)
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
# 5         2020       Japan                  14              0.8989
# 6         2020      Jordan                 117              0.5309
# 7         2020  Kazakhstan                  29              0.8375
# 8         2020       Kenya                 116              0.5326
# 9         2020    Kiribati                 145              0.4320
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
# 5                 0.9881                0.9059               0.8684
# 6                 0.3333                0.3588               0.6800
# 7                 0.8810                0.9235               0.8866
# 8                 0.5952                0.6765               0.5812
# 9                 0.5595                0.4941               0.6778
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151
# 5                                  0.9223
# 6                                  0.5540
# 7                                  0.7024
# 8                                  0.3402
# 9                                  0.1241

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Telecommunication Infrastructure Index'] 
df['Year'] = df['Survey Year']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

df.rename(columns={'Country Name':'Country'}, inplace=True)

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                               Country  Year  \
# 0                               Iraq   2020
# 1                            Ireland   2020
# 2                             Israel   2020
# 3                              Italy   2020
# 4                            Jamaica   2020
# 5                              Japan   2020
# 6                             Jordan   2020
# 7                         Kazakhstan   2020
# 8                              Kenya   2020
# 9                           Kiribati   2020
# 10                            Kuwait   2020
# 11                        Kyrgyzstan   2020
# 12  Lao People's Democratic Republic   2020
# 13                            Latvia   2020
# 14                           Lebanon   2020
#
#                                        Indicator  data_col  new_rank_score  \
# 0   Telecommunication Infrastructure Index (TII)    0.5370          3.6850
# 1   Telecommunication Infrastructure Index (TII)    0.8100          5.0500
# 2   Telecommunication Infrastructure Index (TII)    0.8689          5.3445
# 3   Telecommunication Infrastructure Index (TII)    0.7932          4.9660
# 4   Telecommunication Infrastructure Index (TII)    0.5151          3.5755
# 5   Telecommunication Infrastructure Index (TII)    0.9223          5.6115
# 6   Telecommunication Infrastructure Index (TII)    0.5540          3.7700
# 7   Telecommunication Infrastructure Index (TII)    0.7024          4.5120
# 8   Telecommunication Infrastructure Index (TII)    0.3402          2.7010
# 9   Telecommunication Infrastructure Index (TII)    0.1241          1.6205
# 10  Telecommunication Infrastructure Index (TII)    0.7858          4.9290
# 11  Telecommunication Infrastructure Index (TII)    0.5902          3.9510
# 12  Telecommunication Infrastructure Index (TII)    0.2383          2.1915
# 13  Telecommunication Infrastructure Index (TII)    0.8399          5.1995
# 14  Telecommunication Infrastructure Index (TII)    0.4123          3.0615
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True

# %%
### 16. GSMA Mobile Connectivity Index

# %%
indicators[15]

# load data
indicator = indicators[15]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# GSMA Mobile Connectivity Index
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Index'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year                        Indicator  data_col  \
# 5            Afghanistan  2019  GSMA Mobile Connectivity Index      28.94
# 11                Angola  2019  GSMA Mobile Connectivity Index      43.53
# 17               Albania  2019  GSMA Mobile Connectivity Index      67.89
# 23  United Arab Emirates  2019  GSMA Mobile Connectivity Index      78.23
# 29             Argentina  2019  GSMA Mobile Connectivity Index      67.16
# 35               Armenia  2019  GSMA Mobile Connectivity Index      56.24
# 41             Australia  2019  GSMA Mobile Connectivity Index      90.51
# 47               Austria  2019  GSMA Mobile Connectivity Index      84.21
# 53            Azerbaijan  2019  GSMA Mobile Connectivity Index      58.28
# 59               Burundi  2019  GSMA Mobile Connectivity Index      26.16
# 65               Belgium  2019  GSMA Mobile Connectivity Index      82.56
# 71                 Benin  2019  GSMA Mobile Connectivity Index      39.07
# 77          Burkina Faso  2019  GSMA Mobile Connectivity Index      32.44
# 83            Bangladesh  2019  GSMA Mobile Connectivity Index      46.47
# 89              Bulgaria  2019  GSMA Mobile Connectivity Index      70.37
#
#     new_rank_score  higher_is_better
# 5         2.041533              True
# 11        2.979555              True
# 17        4.545712              True
# 23        5.210492              True
# 29        4.498778              True
# 35        3.796708              True
# 41        6.000000              True
# 47        5.594959              True
# 53        3.927864              True
# 59        1.862801              True
# 65        5.488877              True
# 71        2.692812              True
# 77        2.266555              True
# 83        3.168574              True
# 89        4.705156              True

# %%
### 17. Spectrum Allocated to Mobile Providers

# %%
indicators[16]

# load data
indicator = indicators[16]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Spectrum Allocated to Mobile Providers
# spectrum_allocated_mobile_providers

# %%
df.head(15)
# Out:
#    ISO Code      Country                 Region  Year       Cluster  Index  \
# 0       AFG  Afghanistan             South Asia  2014    Discoverer  22.12
# 1       AFG  Afghanistan             South Asia  2015    Discoverer  22.99
# 2       AFG  Afghanistan             South Asia  2016    Discoverer  23.71
# 3       AFG  Afghanistan             South Asia  2017    Discoverer  25.82
# 4       AFG  Afghanistan             South Asia  2018    Discoverer  28.39
# 5       AFG  Afghanistan             South Asia  2019    Discoverer  28.94
# 6       AGO       Angola     Sub-Saharan Africa  2014    Discoverer  32.78
# 7       AGO       Angola     Sub-Saharan Africa  2015      Emerging  37.18
# 8       AGO       Angola     Sub-Saharan Africa  2016      Emerging  39.85
# 9       AGO       Angola     Sub-Saharan Africa  2017      Emerging  42.89
# 10      AGO       Angola     Sub-Saharan Africa  2018      Emerging  42.46
# 11      AGO       Angola     Sub-Saharan Africa  2019      Emerging  43.53
# 12      ALB      Albania  Europe & Central Asia  2014  Transitioner  53.74
# 13      ALB      Albania  Europe & Central Asia  2015  Transitioner  57.42
# 14      ALB      Albania  Europe & Central Asia  2016  Transitioner  60.24
#
#     Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0            21.74          31.79               24.40                 14.19
# 1            22.82          30.81               25.28                 15.71
# 2            26.92          26.75               26.07                 16.83
# 3            33.54          27.22               28.56                 17.04
# 4            30.91          42.64               29.24                 16.87
# 5            32.34          41.53               29.72                 17.58
# 6            25.99          35.99               44.33                 27.85
# 7            33.09          42.01               45.41                 30.27
# 8            37.80          44.74               46.47                 32.11
# 9            48.60          47.94               46.32                 31.36
# 10           47.61          46.28               47.61                 30.98
# 11           48.18          47.65               48.13                 32.50
# 12           41.32          55.95               74.94                 48.13
# 13           52.09          54.60               75.56                 50.57
# 14           57.44          54.45               75.97                 55.41
#
#     ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0   ...                            0.00            39.55               18.11
# 1   ...                            0.00            39.57               24.27
# 2   ...                            0.00            39.58               30.43
# 3   ...                            0.00            39.47               30.50
# 4   ...                            0.00            39.39               30.56
# 5   ...                            0.00            39.41               41.18
# 6   ...                           51.65             0.00               29.92
# 7   ...                           57.00             0.31               32.35
# 8   ...                           63.73             0.00               34.78
# 9   ...                           53.97             0.00               37.88
# 10  ...                           63.34             0.00               40.97
# 11  ...                           57.71             0.77               48.82
# 12  ...                           68.42            53.41               44.88
# 13  ...                           68.42            57.45               52.15
# 14  ...                           67.39            58.70               59.42
#
#     Mobile Social Media Penetration  Apps developed per person  \
# 0                              3.28                      20.98
# 1                              4.36                      22.93
# 2                              6.73                      30.31
# 3                              7.78                      31.62
# 4                              8.54                      36.54
# 5                              9.39                      39.36
# 6                              3.99                      22.74
# 7                              5.26                      22.12
# 8                              6.27                      27.46
# 9                              4.26                      31.94
# 10                             5.39                      35.36
# 11                             6.82                      41.20
# 12                            39.75                      66.65
# 13                            40.61                      65.99
# 14                            48.07                      69.64
#
#     Number of apps in national language  Accessibility of top ranked apps  \
# 0                                  2.44                              4.37
# 1                                  2.79                              8.03
# 2                                  2.85                              5.90
# 3                                  2.91                              6.15
# 4                                  2.96                              8.66
# 5                                  3.00                              5.72
# 6                                 53.33                             49.09
# 7                                 55.08                             58.33
# 8                                 56.52                             61.73
# 9                                 57.06                             55.09
# 10                                57.13                             47.25
# 11                                57.98                             46.19
# 12                                60.33                             56.55
# 13                                63.29                             57.56
# 14                                65.57                             65.80
#
#     Cybersecurity Index  data_country  data_year
# 0                 26.50           NaN        NaN
# 1                 25.83           NaN        NaN
# 2                 25.17           NaN        NaN
# 3                 24.50           NaN        NaN
# 4                 17.70           NaN        NaN
# 5                 17.70           NaN        NaN
# 6                  8.80           NaN        NaN
# 7                  8.47           NaN        NaN
# 8                  8.13           NaN        NaN
# 9                  7.80           NaN        NaN
# 10                 9.70           NaN        NaN
# 11                 9.70           NaN        NaN
# 12                20.60           NaN        NaN
# 13                24.20           NaN        NaN
# 14                27.80           NaN        NaN
#
# [15 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Spectrum'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year                               Indicator  \
# 5            Afghanistan  2019  Spectrum Allocated to Mobile Providers
# 11                Angola  2019  Spectrum Allocated to Mobile Providers
# 17               Albania  2019  Spectrum Allocated to Mobile Providers
# 23  United Arab Emirates  2019  Spectrum Allocated to Mobile Providers
# 29             Argentina  2019  Spectrum Allocated to Mobile Providers
# 35               Armenia  2019  Spectrum Allocated to Mobile Providers
# 41             Australia  2019  Spectrum Allocated to Mobile Providers
# 47               Austria  2019  Spectrum Allocated to Mobile Providers
# 53            Azerbaijan  2019  Spectrum Allocated to Mobile Providers
# 59               Burundi  2019  Spectrum Allocated to Mobile Providers
# 65               Belgium  2019  Spectrum Allocated to Mobile Providers
# 71                 Benin  2019  Spectrum Allocated to Mobile Providers
# 77          Burkina Faso  2019  Spectrum Allocated to Mobile Providers
# 83            Bangladesh  2019  Spectrum Allocated to Mobile Providers
# 89              Bulgaria  2019  Spectrum Allocated to Mobile Providers
#
#     data_col  new_rank_score  higher_is_better
# 5      17.62        1.577685              True
# 11     48.22        3.261224              True
# 17     52.85        3.515955              True
# 23     82.44        5.143926              True
# 29     63.38        4.095290              True
# 35     21.43        1.787302              True
# 41     75.45        4.759353              True
# 47     73.33        4.642716              True
# 53     15.36        1.453345              True
# 59     16.29        1.504511              True
# 65     58.62        3.833407              True
# 71     61.31        3.981404              True
# 77     23.82        1.918794              True
# 83     19.97        1.706976              True
# 89     27.49        2.120709              True

# %%
### 18. Internet Exchange Points (IXPs)

# %%
indicators[17]

# load data
indicator = indicators[17]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Internet Exchange Points (IXPs) map
# countries_ixp

# %%
df.head(15)
# Out:
#            Region      Country                    City  \
# 0    Asia-Pacific  Afghanistan                   Kabul
# 1          Europe      Albania                  Tirana
# 2             NaN      Albania                  Tirana
# 3          Africa      Algeria                 Algiers
# 4             NaN       Angola                  Luanda
# 5             NaN       Angola                  Luanda
# 6             NaN       Angola                  Luanda
# 7   Latin America    Argentina            Bahía Blanca
# 8             NaN    Argentina               Bariloche
# 9             NaN    Argentina            Buenos Aires
# 10            NaN    Argentina            Buenos Aires
# 11            NaN    Argentina            Buenos Aires
# 12            NaN    Argentina            Buenos Aires
# 13            NaN    Argentina            Buenos Aires
# 14            NaN    Argentina  Concepcion del Uruguay
#
#                                      IXP Name  Participants   Peak    Avg  \
# 0   National Internet Exchange of Afghanistan            20   6.4G  2.19G
# 1          Albanian Neutral Internet eXchange            16  2.42G    35M
# 2                                  Albania IX             0    NaN    NaN
# 3                   Algeria Internet Exchange             0    NaN    NaN
# 4                    Angola Internet Exchange            21   1.6G    NaN
# 5        Ponto de Intercambio Internet Angola             0    NaN    NaN
# 6                                     ANGONIX            21    16G    NaN
# 7                     CABASE IXP Bahía Blanca            15   713M    NaN
# 8                        CABASE IXP Bariloche             8    NaN    NaN
# 9                     CABASE IXP Buenos Aires           125  9.19G    NaN
# 10                                   Cubecorp             0    NaN    NaN
# 11                   CABASE IXP Ruteo Central             0    NaN    NaN
# 12      CABASE IXP Oeste de Gran Buenos Aires             7    NaN    NaN
# 13                      NAP CABASE La Matanza             0    NaN    NaN
# 14          CABASE IXP Concepcion del Uruguay             4    NaN    NaN
#
#    IPv6  Prefixes Established  URL
# 0   NaN       NaN      Jul-18  NaN
# 1   NaN       NaN        2018  NaN
# 2   NaN       NaN        2011  NaN
# 3   NaN       NaN         NaN  NaN
# 4   NaN     512.0   17-Mar-06  NaN
# 5   NaN       NaN         NaN  NaN
# 6   NaN    5495.0    9-Mar-15  NaN
# 7   NaN       NaN   27-Apr-13  NaN
# 8   NaN       NaN   15-Sep-14  NaN
# 9   NaN   17224.0    1-Apr-98  NaN
# 10  NaN       NaN         NaN  NaN
# 11  NaN       NaN         NaN  NaN
# 12  NaN       NaN    5-Jul-16  NaN
# 13  NaN       NaN         NaN  NaN
# 14  NaN       NaN         NaN  NaN

# %%
agg_df = df.groupby('Country')['Country'].count()
agg_df
# Out:
# Country
# Afghanistan     1
# Albania         2
# Algeria         1
# Angola          3
# Argentina      33
#                ..
# Uzbekistan      3
# Vanuatu         1
# Viet Nam        3
# Zambia          1
# Zimbabwe        2
# Name: Country, Length: 165, dtype: int64

# %%
count = df['Country'].value_counts()

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Spectrum'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Apps\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Spectrum'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-6174dbc9f51e> in <module>
#       6 df['higher_is_better'] = True
#       7 df['Indicator'] = indicator
# ----> 8 df['data_col'] = df['Spectrum']
#       9
#      10 min_rank = df['data_col'].min()
#
# D:\Apps\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# D:\Apps\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Spectrum'

# %%
### 19. ISP Speeds - Fixed

# %%
indicators[18]

# load data
indicator = indicators[18]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Convert yaml to csv
# Out:
# ISP Speeds - Fixed
# speedtest-global-performance.yaml
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-101-c2ca5b0ed723> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#      10
#      11 # Convert yaml to csv
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/speedtest-global-performance.yaml.csv'

# %%
df.head(15)
# Out:
#            Region      Country                    City  \
# 0    Asia-Pacific  Afghanistan                   Kabul
# 1          Europe      Albania                  Tirana
# 2             NaN      Albania                  Tirana
# 3          Africa      Algeria                 Algiers
# 4             NaN       Angola                  Luanda
# 5             NaN       Angola                  Luanda
# 6             NaN       Angola                  Luanda
# 7   Latin America    Argentina            Bahía Blanca
# 8             NaN    Argentina               Bariloche
# 9             NaN    Argentina            Buenos Aires
# 10            NaN    Argentina            Buenos Aires
# 11            NaN    Argentina            Buenos Aires
# 12            NaN    Argentina            Buenos Aires
# 13            NaN    Argentina            Buenos Aires
# 14            NaN    Argentina  Concepcion del Uruguay
#
#                                      IXP Name  Participants   Peak    Avg  \
# 0   National Internet Exchange of Afghanistan            20   6.4G  2.19G
# 1          Albanian Neutral Internet eXchange            16  2.42G    35M
# 2                                  Albania IX             0    NaN    NaN
# 3                   Algeria Internet Exchange             0    NaN    NaN
# 4                    Angola Internet Exchange            21   1.6G    NaN
# 5        Ponto de Intercambio Internet Angola             0    NaN    NaN
# 6                                     ANGONIX            21    16G    NaN
# 7                     CABASE IXP Bahía Blanca            15   713M    NaN
# 8                        CABASE IXP Bariloche             8    NaN    NaN
# 9                     CABASE IXP Buenos Aires           125  9.19G    NaN
# 10                                   Cubecorp             0    NaN    NaN
# 11                   CABASE IXP Ruteo Central             0    NaN    NaN
# 12      CABASE IXP Oeste de Gran Buenos Aires             7    NaN    NaN
# 13                      NAP CABASE La Matanza             0    NaN    NaN
# 14          CABASE IXP Concepcion del Uruguay             4    NaN    NaN
#
#    IPv6  Prefixes Established  URL  higher_is_better  \
# 0   NaN       NaN      Jul-18  NaN              True
# 1   NaN       NaN        2018  NaN              True
# 2   NaN       NaN        2011  NaN              True
# 3   NaN       NaN         NaN  NaN              True
# 4   NaN     512.0   17-Mar-06  NaN              True
# 5   NaN       NaN         NaN  NaN              True
# 6   NaN    5495.0    9-Mar-15  NaN              True
# 7   NaN       NaN   27-Apr-13  NaN              True
# 8   NaN       NaN   15-Sep-14  NaN              True
# 9   NaN   17224.0    1-Apr-98  NaN              True
# 10  NaN       NaN         NaN  NaN              True
# 11  NaN       NaN         NaN  NaN              True
# 12  NaN       NaN    5-Jul-16  NaN              True
# 13  NaN       NaN         NaN  NaN              True
# 14  NaN       NaN         NaN  NaN              True
#
#                               Indicator
# 0   Internet Exchange Points (IXPs) map
# 1   Internet Exchange Points (IXPs) map
# 2   Internet Exchange Points (IXPs) map
# 3   Internet Exchange Points (IXPs) map
# 4   Internet Exchange Points (IXPs) map
# 5   Internet Exchange Points (IXPs) map
# 6   Internet Exchange Points (IXPs) map
# 7   Internet Exchange Points (IXPs) map
# 8   Internet Exchange Points (IXPs) map
# 9   Internet Exchange Points (IXPs) map
# 10  Internet Exchange Points (IXPs) map
# 11  Internet Exchange Points (IXPs) map
# 12  Internet Exchange Points (IXPs) map
# 13  Internet Exchange Points (IXPs) map
# 14  Internet Exchange Points (IXPs) map

# %%
### 20. SP Speeds - Mobile

# %%
# May also have to convert yaml to csv

# %%
### 21. ISP internet download speed average

# %%
indicators[20]

# load data
indicator = indicators[20]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Waiting for internet_speed to be added to the processed folder
# Out:
# ISP internet download speed average
# internet_speed

# %%
df.head(15)
# Out:
#     Ranking  Year               Country  Download speed (Mbps)
# 0         1  2021                Monaco                 256.70
# 1         2  2021             Singapore                 256.03
# 2         3  2021       Hong Kong (SAR)                 248.59
# 3         4  2021              Thailand                 216.16
# 4         5  2021               Romania                 215.30
# 5         6  2021           Switzerland                 214.82
# 6         7  2021           South Korea                 212.83
# 7         8  2021                 Chile                 209.45
# 8         9  2021               Denmark                 208.50
# 9        10  2021         Liechtenstein                 207.44
# 10       11  2021                France                 199.68
# 11       12  2021               Hungary                 199.47
# 12       13  2021               Moldova                 196.46
# 13       14  2021         United States                 195.55
# 14       15  2021  United Arab Emirates                 190.96

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Download speed (Mbps)'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year                             Indicator  \
# 0                 Monaco  2021  ISP internet download speed average
# 1              Singapore  2021  ISP internet download speed average
# 2        Hong Kong (SAR)  2021  ISP internet download speed average
# 3               Thailand  2021  ISP internet download speed average
# 4                Romania  2021  ISP internet download speed average
# 5            Switzerland  2021  ISP internet download speed average
# 6            South Korea  2021  ISP internet download speed average
# 7                  Chile  2021  ISP internet download speed average
# 8                Denmark  2021  ISP internet download speed average
# 9          Liechtenstein  2021  ISP internet download speed average
# 10                France  2021  ISP internet download speed average
# 11               Hungary  2021  ISP internet download speed average
# 12               Moldova  2021  ISP internet download speed average
# 13         United States  2021  ISP internet download speed average
# 14  United Arab Emirates  2021  ISP internet download speed average
#
#     data_col  new_rank_score  higher_is_better
# 0     256.70        6.000000              True
# 1     256.03        5.986711              True
# 2     248.59        5.839145              True
# 3     216.16        5.195922              True
# 4     215.30        5.178865              True
# 5     214.82        5.169344              True
# 6     212.83        5.129874              True
# 7     209.45        5.062835              True
# 8     208.50        5.043992              True
# 9     207.44        5.022968              True
# 10    199.68        4.869055              True
# 11    199.47        4.864890              True
# 12    196.46        4.805189              True
# 13    195.55        4.787140              True
# 14    190.96        4.696101              True

# %%
### 22. Mobile dowload speed at the slowest hour

# %%
indicators[21]

# load data
indicator = indicators[21]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Waiting for internet_speed to be added to the processed folder
# Out:
# Mobile dowload speed at the slowest hour of the day
# mobile_latency

# %%
df.head(15)
# Out:
#     Unnamed: 0 ISO Code      Country                 Region  Year  \
# 0            1      AFG  Afghanistan             South Asia  2014
# 1            2      AFG  Afghanistan             South Asia  2015
# 2            3      AFG  Afghanistan             South Asia  2016
# 3            4      AFG  Afghanistan             South Asia  2017
# 4            5      AFG  Afghanistan             South Asia  2018
# 5            6      AFG  Afghanistan             South Asia  2019
# 6            7      AGO       Angola     Sub-Saharan Africa  2014
# 7            8      AGO       Angola     Sub-Saharan Africa  2015
# 8            9      AGO       Angola     Sub-Saharan Africa  2016
# 9           10      AGO       Angola     Sub-Saharan Africa  2017
# 10          11      AGO       Angola     Sub-Saharan Africa  2018
# 11          12      AGO       Angola     Sub-Saharan Africa  2019
# 12          13      ALB      Albania  Europe & Central Asia  2014
# 13          14      ALB      Albania  Europe & Central Asia  2015
# 14          15      ALB      Albania  Europe & Central Asia  2016
#
#     Mobile latencies
# 0           0.000000
# 1           0.000000
# 2          11.842106
# 3          56.234993
# 4          49.762146
# 5          42.627621
# 6           0.000000
# 7          36.975155
# 8          50.958073
# 9          66.052635
# 10         74.417152
# 11         66.285637
# 12         34.736843
# 13         57.339764
# 14         73.420052

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Mobile latencies'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator   data_col  \
# 5   Mobile dowload speed at the slowest hour of th...  42.627621
# 11  Mobile dowload speed at the slowest hour of th...  66.285637
# 17  Mobile dowload speed at the slowest hour of th...  84.636459
# 23  Mobile dowload speed at the slowest hour of th...  84.951675
# 29  Mobile dowload speed at the slowest hour of th...  80.727203
# 35  Mobile dowload speed at the slowest hour of th...  88.437950
# 41  Mobile dowload speed at the slowest hour of th...  86.069145
# 47  Mobile dowload speed at the slowest hour of th...  85.845047
# 53  Mobile dowload speed at the slowest hour of th...  85.687500
# 59  Mobile dowload speed at the slowest hour of th...  51.736294
# 65  Mobile dowload speed at the slowest hour of th...  82.730255
# 71  Mobile dowload speed at the slowest hour of th...  68.678703
# 77  Mobile dowload speed at the slowest hour of th...  54.469799
# 83  Mobile dowload speed at the slowest hour of th...  74.701111
# 89  Mobile dowload speed at the slowest hour of th...  83.992538
#
#     new_rank_score  higher_is_better
# 5         3.381348              True
# 11        4.702978              True
# 17        5.728128              True
# 23        5.745737              True
# 29        5.509742              True
# 35        5.940495              True
# 41        5.808164              True
# 47        5.795645              True
# 53        5.786843              True
# 59        3.890194              True
# 65        5.621640              True
# 71        4.836665              True
# 77        4.042899              True
# 83        5.173100              True
# 89        5.692156              True

# %%
### 23. Mobile download speed average

# %%
indicators[22]

# load data
indicator = indicators[22]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Mobile download speed average
# mobile_speed

# %%
df.head(15)
# Out:
#      #  Year               Country    Mbps
# 0    1  2021  United Arab Emirates  190.03
# 1    2  2021           South Korea  189.20
# 2    3  2021                 Qatar  170.77
# 3    4  2021                 China  157.72
# 4    5  2021                Cyprus  154.13
# 5    6  2021                Norway  152.53
# 6    7  2021          Saudi Arabia  151.13
# 7    8  2021                Kuwait  140.16
# 8    9  2021             Australia  122.27
# 9   10  2021              Bulgaria  120.44
# 10  11  2021            Luxembourg  110.72
# 11  12  2021           Switzerland  109.65
# 12  13  2021           Netherlands  100.65
# 13  14  2021         United States   91.01
# 14  15  2021                Sweden   90.57

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Mbps'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year                       Indicator  data_col  \
# 0   United Arab Emirates  2021  Mobile download speed average     190.03
# 1            South Korea  2021  Mobile download speed average     189.20
# 2                  Qatar  2021  Mobile download speed average     170.77
# 3                  China  2021  Mobile download speed average     157.72
# 4                 Cyprus  2021  Mobile download speed average     154.13
# 5                 Norway  2021  Mobile download speed average     152.53
# 6           Saudi Arabia  2021  Mobile download speed average     151.13
# 7                 Kuwait  2021  Mobile download speed average     140.16
# 8              Australia  2021  Mobile download speed average     122.27
# 9               Bulgaria  2021  Mobile download speed average     120.44
# 10            Luxembourg  2021  Mobile download speed average     110.72
# 11           Switzerland  2021  Mobile download speed average     109.65
# 12           Netherlands  2021  Mobile download speed average     100.65
# 13         United States  2021  Mobile download speed average      91.01
# 14                Sweden  2021  Mobile download speed average      90.57
#
#     new_rank_score  higher_is_better
# 0         6.000000              True
# 1         5.977362              True
# 2         5.474689              True
# 3         5.118754              True
# 4         5.020838              True
# 5         4.977198              True
# 6         4.939014              True
# 7         4.639810              True
# 8         4.151866              True
# 9         4.101953              True
# 10        3.836843              True
# 11        3.807659              True
# 12        3.562186              True
# 13        3.299258              True
# 14        3.287257              True

# %%
### 24. Individuals using the Internet (% of population)

# %%
indicators[23]

# load data
indicator = indicators[23]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Individuals using the Internet (% of population)
# individual_internet_usage

# %%
df.head(15)
# Out:
#               ShortName                                          2000_note  \
# 0           Afghanistan                                                NaN
# 1               Albania                                                NaN
# 2               Algeria                                                NaN
# 3               Andorra                                                NaN
# 4                Angola                                                NaN
# 5              Anguilla                                                NaN
# 6   Antigua and Barbuda                                                NaN
# 7             Argentina                                                NaN
# 8               Armenia                                                NaN
# 9                 Aruba                                                NaN
# 10            Ascension                                                NaN
# 11            Australia                                                NaN
# 12              Austria  Regular users of the Internet, Population age ...
# 13           Azerbaijan                                                NaN
# 14              Bahamas  Estimated based on 3 times the number of subsc...
#
#                                           2000_source 2000_value  \
# 0                                                 NaN        NaN
# 1                        Albanian Telecom Enterprise.       0.11
# 2                                                 NaN       0.49
# 3        Servei de Telecomunicacions d'Andorra (STA).      10.54
# 4                                                 NaN       0.11
# 5                                                 NaN      22.41
# 6   Cable and Wireless (W.I.) Ltd. (C&W). A.P.U.A....       6.48
# 7                                              SECOM.       7.04
# 8                                                 NaN       1.30
# 9      Servicio di Telecomunicacion di Aruba (SETAR).      15.44
# 10                       Cable & Wireless plc. (C&W).      34.94
# 11  ABS Household Use of Information Technology Su...      46.76
# 12                          Austria Internet Monitor.      33.73
# 13                                                NaN       0.15
# 14                                      ITU estimate.       8.00
#
#                                             2001_note  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                       Data refer to 31st December.
# 11                                                NaN
# 12  Regular users of the Internet, Population age ...
# 13                                                NaN
# 14  Estimated based on 3 times the number of subsc...
#
#                      2001_source 2001_value  \
# 0                  ITU estimate.       0.00
# 1   Albanian Telecom Enterprise.       0.33
# 2                            NaN       0.65
# 3                            NaN        NaN
# 4                            NaN       0.14
# 5                            NaN      25.88
# 6                  ITU estimate.       8.90
# 7                         SECOM.       9.78
# 8                            NaN       1.63
# 9                  ITU estimate.      17.10
# 10  Cable & Wireless plc. (C&W).      38.17
# 11                 ITU estimate.      52.69
# 12     Austria Internet Monitor.      39.19
# 13                           NaN       0.31
# 14                 ITU estimate.      11.80
#
#                                             2002_note  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  Population age 16-74 using Internet in the las...
# 13                                                NaN
# 14  Estimated based on 3 times the number of subsc...
#
#                                           2002_source 2002_value  ...  \
# 0                         Ministry of Communications.       0.00  ...
# 1                        Albanian Telecom Enterprise.       0.39  ...
# 2                                                 NaN       1.59  ...
# 3        Servei de Telecomunicacions d'Andorra (STA).      11.26  ...
# 4                                                 NaN       0.27  ...
# 5                                                 NaN      24.80  ...
# 6   Cable and Wireless (W.I.) Ltd. (C&W). A.P.U.A....      12.50  ...
# 7                                              SECOM.      10.88  ...
# 8                                                 NaN       1.96  ...
# 9                                       ITU estimate.      18.80  ...
# 10                                                NaN        NaN  ...
# 11                                                NaN        NaN  ...
# 12                                          Eurostat.      36.56  ...
# 13                                                NaN       5.00  ...
# 14                                      ITU estimate.      18.00  ...
#
#                                           2018_source 2018_value 2019_note  \
# 0                                                 NaN        NaN       NaN
# 1                                                 NaN        NaN       NaN
# 2   Ministry of Post, Telecommunications, Technolo...      49.04       NaN
# 3             Servei d'studis - Ministeri de Finances        NaN       NaN
# 4                                                 NaN        NaN       NaN
# 5                                                 NaN        NaN       NaN
# 6                                                 NaN        NaN       NaN
# 7                                                 NaN        NaN       NaN
# 8   The Statistical Committee of the Republic of A...      68.25       NaN
# 9                                                 NaN        NaN       NaN
# 10                                                NaN        NaN       NaN
# 11                    Australian Bureau of Statistics        NaN       NaN
# 12                                  Statistik Austria      87.48       NaN
# 13  State Statistical Committee of the Republic of...      79.80       NaN
# 14                                                NaN        NaN       NaN
#
#                          2019_source 2019_value  2020_note 2020_source  \
# 0                                NaN        NaN        NaN         NaN
# 1   INSTAT (Institute of Statistics)      68.55        NaN         NaN
# 2                                NaN        NaN        NaN         NaN
# 3                                NaN        NaN        NaN         NaN
# 4                                NaN        NaN        NaN         NaN
# 5                                NaN        NaN        NaN         NaN
# 6                                NaN        NaN        NaN         NaN
# 7                                NaN        NaN        NaN         NaN
# 8        Statistical Committee of RA      66.54        NaN         NaN
# 9                                NaN        NaN        NaN         NaN
# 10                               NaN        NaN        NaN         NaN
# 11                               NaN        NaN        NaN         NaN
# 12                 Statistik Austria      87.75        NaN         NaN
# 13       State Statistical Committee      81.10        NaN         NaN
# 14                               NaN        NaN        NaN         NaN
#
#    2020_value  data_country data_year
# 0         NaN           NaN       NaN
# 1         NaN           NaN       NaN
# 2         NaN           NaN       NaN
# 3         NaN           NaN       NaN
# 4         NaN           NaN       NaN
# 5         NaN           NaN       NaN
# 6         NaN           NaN       NaN
# 7         NaN           NaN       NaN
# 8         NaN           NaN       NaN
# 9         NaN           NaN       NaN
# 10        NaN           NaN       NaN
# 11        NaN           NaN       NaN
# 12        NaN           NaN       NaN
# 13        NaN           NaN       NaN
# 14        NaN           NaN       NaN
#
# [15 rows x 66 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2017
df['Indicator'] = indicator
df['data_col'] = df['2017_value'] 
df.rename(columns = {'ShortName':'Country'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
#2019 data is missing too much, switching to 2017
# Out:
#                 Country  Year  \
# 0           Afghanistan  2017
# 1               Albania  2017
# 2               Algeria  2017
# 3               Andorra  2017
# 4                Angola  2017
# 5              Anguilla  2017
# 6   Antigua and Barbuda  2017
# 7             Argentina  2017
# 8               Armenia  2017
# 9                 Aruba  2017
# 10            Ascension  2017
# 11            Australia  2017
# 12              Austria  2017
# 13           Azerbaijan  2017
# 14              Bahamas  2017
#
#                                            Indicator  data_col  \
# 0   Individuals using the Internet (% of population)     11.45
# 1   Individuals using the Internet (% of population)     71.85
# 2   Individuals using the Internet (% of population)     47.69
# 3   Individuals using the Internet (% of population)     91.57
# 4   Individuals using the Internet (% of population)     14.34
# 5   Individuals using the Internet (% of population)       NaN
# 6   Individuals using the Internet (% of population)       NaN
# 7   Individuals using the Internet (% of population)     74.29
# 8   Individuals using the Internet (% of population)     64.74
# 9   Individuals using the Internet (% of population)     97.17
# 10  Individuals using the Internet (% of population)       NaN
# 11  Individuals using the Internet (% of population)     86.55
# 12  Individuals using the Internet (% of population)     87.94
# 13  Individuals using the Internet (% of population)     79.00
# 14  Individuals using the Internet (% of population)     85.00
#
#     new_rank_score  higher_is_better
# 0         1.516083              True
# 1         4.590187              True
# 2         3.360546              True
# 3         5.593852              True
# 4         1.663172              True
# 5              NaN              True
# 6              NaN              True
# 7         4.714373              True
# 8         4.228318              True
# 9         5.878868              True
# 10             NaN              True
# 11        5.338355              True
# 12        5.409100              True
# 13        4.954092              True
# 14        5.259467              True

# %%
### 25. Mobile cellular subscriptions (per 100 people)

# %%
indicators[24]

# load data
indicator = indicators[24]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

#Waiting for mobile_cell_sub to be added to processed folder
# Out:
# Mobile cellular subscriptions (per 100 people)
# mobile_cell_sub
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-126-d66169a8cbf8> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#      10
#      11 #Waiting for mobile_cell_sub to be added to processed folder
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/mobile_cell_sub.csv'

# %%
### 26. Average fixed broadband download speeds

# %%
indicators[25]

# load data
indicator = indicators[25]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Average fixed broadband download speeds
# fixed_bdbd_spd_dl_ul

# %%
df.head(15)
# Out:
#           country  broadband  mobile     pop2021
# 0       Singapore     226.60   60.52    5896.686
# 1       Hong Kong     210.73   50.96    7552.810
# 2         Romania     193.47   40.35   19127.774
# 3     Switzerland     178.81   64.10    8715.494
# 4        Thailand     175.22   34.38   69950.850
# 5          France     173.05   49.82   65426.179
# 6         Denmark     162.08   63.86    5813.298
# 7          Monaco     162.06     NaN      39.511
# 8         Hungary     161.51   44.52    9634.164
# 9   United States     161.14   47.13  332915.073
# 10          Spain     157.22   39.03   46745.216
# 11  Liechtenstein     156.94     NaN      38.250
# 12         Sweden     156.34   53.13   10160.169
# 13    South Korea     155.39  121.00   51305.186
# 14          Macau     154.57   53.30     658.394

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df['broadband'] 
df.rename(columns = {'country':'Country'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#           Country  Year                                 Indicator  data_col  \
# 0       Singapore  2021  Average fixed broadband download speeds     226.60
# 1       Hong Kong  2021  Average fixed broadband download speeds     210.73
# 2         Romania  2021  Average fixed broadband download speeds     193.47
# 3     Switzerland  2021  Average fixed broadband download speeds     178.81
# 4        Thailand  2021  Average fixed broadband download speeds     175.22
# 5          France  2021  Average fixed broadband download speeds     173.05
# 6         Denmark  2021  Average fixed broadband download speeds     162.08
# 7          Monaco  2021  Average fixed broadband download speeds     162.06
# 8         Hungary  2021  Average fixed broadband download speeds     161.51
# 9   United States  2021  Average fixed broadband download speeds     161.14
# 10          Spain  2021  Average fixed broadband download speeds     157.22
# 11  Liechtenstein  2021  Average fixed broadband download speeds     156.94
# 12         Sweden  2021  Average fixed broadband download speeds     156.34
# 13    South Korea  2021  Average fixed broadband download speeds     155.39
# 14          Macau  2021  Average fixed broadband download speeds     154.57
#
#     new_rank_score  higher_is_better
# 0         6.000000              True
# 1         5.644489              True
# 2         5.257841              True
# 3         4.929435              True
# 4         4.849014              True
# 5         4.800403              True
# 6         4.554659              True
# 7         4.554211              True
# 8         4.541891              True
# 9         4.533602              True
# 10        4.445789              True
# 11        4.439516              True
# 12        4.426075              True
# 13        4.404794              True
# 14        4.386425              True

# %%
### 27. Average fixed broadband upload speeds
# Must convert yaml to csv

# %%
### 28. Average fixed broadband latency
# Must convert yaml to csv

# %%
### 29. Postal Coverage

# %%
indicators[28]

# load data
indicator = indicators[28]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Postal Coverage
# postal_coverage

# %%
df.head(15)
# Out:
#     2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  93.0   NaN   NaN
# 1    NaN   NaN   NaN   NaN   NaN  17.0   NaN   NaN   NaN   NaN   NaN
# 2    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   0.0   NaN   NaN
# 3    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  70.0   NaN
# 4    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  74.0   NaN
# 5    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  10.0   NaN
# 7    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  15.0
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   8.9
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  55.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  99.6   NaN   NaN
# 12   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   8.3   NaN   NaN
# 13   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   0.0   NaN   NaN
#
#    Country ISO3 Country Name  Indicator Id  \
# 0           ABW        Aruba         24707
# 1           ABW        Aruba         24708
# 2           ABW        Aruba         24710
# 3           AFG  Afghanistan         24707
# 4           AFG  Afghanistan         24708
# 5           AFG  Afghanistan         24709
# 6           AFG  Afghanistan         24710
# 7           AGO       Angola         24707
# 8           AGO       Angola         24708
# 9           AGO       Angola         24709
# 10          AGO       Angola         24710
# 11          ALB      Albania         24707
# 12          ALB      Albania         24708
# 13          ALB      Albania         24709
# 14          ALB      Albania         24710
#
#                                             Indicator Subindicator Type  \
# 0   Percent of Population Having Mail Delivered at...             Value
# 1   Percent of Income Linked to Parcels and Logist...             Value
# 2   Percent of the Population Without Postal Services             Value
# 3   Percent of Population Having Mail Delivered at...             Value
# 4   Percent of Income Linked to Parcels and Logist...             Value
# 5                            Postal Reliability Index     Index (0-100)
# 6   Percent of the Population Without Postal Services             Value
# 7   Percent of Population Having Mail Delivered at...             Value
# 8   Percent of Income Linked to Parcels and Logist...             Value
# 9                            Postal Reliability Index     Index (0-100)
# 10  Percent of the Population Without Postal Services             Value
# 11  Percent of Population Having Mail Delivered at...             Value
# 12  Percent of Income Linked to Parcels and Logist...             Value
# 13                           Postal Reliability Index     Index (0-100)
# 14  Percent of the Population Without Postal Services             Value
#
#     2013-14
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5      17.9
# 6       NaN
# 7       NaN
# 8       NaN
# 9      15.3
# 10      NaN
# 11      NaN
# 12      NaN
# 13     79.6
# 14      NaN

# %%
#Choose 'Percent of Population Having Mail Delivered at Home' as the data column
df = df[(df.Indicator=='Percent of Population Having Mail Delivered at Home')]
df.head(15)

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2015
df['Indicator'] = indicator
df['data_col'] = df['2015'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year        Indicator  data_col  new_rank_score  \
# 0                  Aruba  2015  Postal Coverage       NaN             NaN
# 3            Afghanistan  2015  Postal Coverage       NaN             NaN
# 7                 Angola  2015  Postal Coverage      15.0            1.75
# 11               Albania  2015  Postal Coverage       NaN             NaN
# 15  United Arab Emirates  2015  Postal Coverage       NaN             NaN
# 19             Argentina  2015  Postal Coverage      93.0            5.65
# 23               Armenia  2015  Postal Coverage      93.0            5.65
# 27   Antigua and Barbuda  2015  Postal Coverage      80.0            5.00
# 30             Australia  2015  Postal Coverage       NaN             NaN
# 33               Austria  2015  Postal Coverage      99.0            5.95
# 38               Burundi  2015  Postal Coverage       NaN             NaN
# 42               Belgium  2015  Postal Coverage       NaN             NaN
# 45                 Benin  2015  Postal Coverage       6.0            1.30
# 49          Burkina Faso  2015  Postal Coverage       0.0            1.00
# 53            Bangladesh  2015  Postal Coverage       NaN             NaN
#
#     higher_is_better
# 0               True
# 3               True
# 7               True
# 11              True
# 15              True
# 19              True
# 23              True
# 27              True
# 30              True
# 33              True
# 38              True
# 42              True
# 45              True
# 49              True
# 53              True

# %%
### 30. Logistics Performance Index (LPI)

# %%
indicators[29]

# load data
indicator = indicators[29]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Logistics Performance Index (LPI) - Infrastructure Rating
# World Bank The Logistics Performance Index 2007 to 2018.xlsx
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-140-27db7754b360> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/World Bank The Logistics Performance Index 2007 to 2018.xlsx.csv'

# %%
### 31.Schools with Internet proportion

# %%
indicators[30]

# load data
indicator = indicators[30]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Schools with Internet proportion
# schools_w_internet
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-142-43e1c6606bb0> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/schools_w_internet.csv'

# %%
### 32.National cyber security index

# %%
indicators[31]

# load data
indicator = indicators[31]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# National cyber security index
# national_cybersecurity_index

# %%
df.head(15)
# Out:
#     Rank         Country  National Cyber Security Index  Difference  \
# 0    1.0          Greece                          96.10       32.35
# 1    2.0  Czech Republic                          92.21       23.25
# 2    3.0         Estonia                          90.91       15.05
# 3    4.0        Portugal                          89.61       21.76
# 4    5.0       Lithuania                          88.31       20.01
# 5    6.0           Spain                          88.31       15.70
# 6    7.0          Poland                          87.01       21.66
# 7    8.0         Belgium                          85.71       11.32
# 8    9.0         Finland                          85.71        6.23
# 9   10.0          France                          84.42        6.63
# 10  11.0         Croatia                          83.12       18.95
# 11  12.0        Slovakia                          83.12       17.43
# 12  13.0     Netherlands                          81.82       -1.32
# 13  14.0         Denmark                          81.82       -2.82
# 14  15.0         Germany                          80.52       -0.17
#
#     Unnamed: 4
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df['National Cyber Security Index'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#            Country  Year                      Indicator  data_col  \
# 0           Greece  2021  National cyber security index     96.10
# 1   Czech Republic  2021  National cyber security index     92.21
# 2          Estonia  2021  National cyber security index     90.91
# 3         Portugal  2021  National cyber security index     89.61
# 4        Lithuania  2021  National cyber security index     88.31
# 5            Spain  2021  National cyber security index     88.31
# 6           Poland  2021  National cyber security index     87.01
# 7          Belgium  2021  National cyber security index     85.71
# 8          Finland  2021  National cyber security index     85.71
# 9           France  2021  National cyber security index     84.42
# 10         Croatia  2021  National cyber security index     83.12
# 11        Slovakia  2021  National cyber security index     83.12
# 12     Netherlands  2021  National cyber security index     81.82
# 13         Denmark  2021  National cyber security index     81.82
# 14         Germany  2021  National cyber security index     80.52
#
#     new_rank_score  higher_is_better
# 0         6.000000              True
# 1         5.794831              True
# 2         5.726266              True
# 3         5.657700              True
# 4         5.589135              True
# 5         5.589135              True
# 6         5.520570              True
# 7         5.452004              True
# 8         5.452004              True
# 9         5.383966              True
# 10        5.315401              True
# 11        5.315401              True
# 12        5.246835              True
# 13        5.246835              True
# 14        5.178270              True

# %%
### 33. Global Cybersecurity Index (GCI)

# %%
indicators[32]

# load data
indicator = indicators[32]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Global Cybersecurity Index (GCI)
# dice_export_global_cybersecurity_index

# %%
df.head(15)
#The Data is practically unusable, find a new one
# Out:
#     Unnamed: 0  data_country  data_year
# 0          1.0           1.0        1.0
# 1          2.0           2.0        2.0
# 2          2.0           2.0        2.0
# 3          3.0           3.0        3.0
# 4          4.0           4.0        4.0
# 5          4.0           4.0        4.0
# 6          4.0           4.0        4.0
# 7          5.0           5.0        5.0
# 8          5.0           5.0        5.0
# 9          5.0           5.0        5.0
# 10         6.0           6.0        6.0
# 11         7.0           7.0        7.0
# 12         8.0           8.0        8.0
# 13         9.0           9.0        9.0
# 14        10.0          10.0       10.0

# %%
### 34. Software Developer Ecosystem size

# %%
indicators[33]

# load data
indicator = indicators[33]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Software Developer Ecosystem size
# software_developer_ecosystem_size

# %%
df.head(15)
# Out:
#            Country GitHub Accounts
# 0    United States         651,017
# 1            China         183,805
# 2            India         168,328
# 3   United Kingdom         109,460
# 4          Germany          94,359
# 5           Brazil          80,903
# 6           Canada          77,318
# 7           France          66,367
# 8           Russia          58,767
# 9        Australia          41,790
# 10           Japan          39,263
# 11           Spain          38,020
# 12     Netherlands          35,782
# 13         Ukraine          33,032
# 14          Poland          30,928

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2018
df['Indicator'] = indicator
df['data_col'] = df['GitHub Accounts']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

#There is a small error in the column name this has been addressed, waiting for files to be updated
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-e5ff39e2dc36> in <module>
#      11
#      12 # transform 0-1 rank into 1-6
# ---> 13 df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
#      14
#      15 #There is a small error in the column name this has been addressed, waiting for files to be updated
#
# D:\Apps\Anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-154-e5ff39e2dc36> in <lambda>(row)
#      11
#      12 # transform 0-1 rank into 1-6
# ---> 13 df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
#      14
#      15 #There is a small error in the column name this has been addressed, waiting for files to be updated
#
# <ipython-input-30-020bafb9c04d> in convert_rank(old_value, old_min, old_max, new_min, new_max)
#       2 def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
#       3     """ Convert old scale values scale into new scale values"""
# ----> 4     old_range = old_max - old_min
#       5     new_range = new_max - new_min
#       6     new_value = (((old_value-old_min)*new_range)/old_range)+new_min
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
### 35. Digital Work Ecosystem size

# %%
indicators[34]

# load data
indicator = indicators[34]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Digital Work Ecosystem size
# digital_platform_economy_index

# %%
df.head(15)
# Out:
#    Rank          Country DPE 2020    GDP per capita 2017  Unnamed: 4
# 0      1   United States       85,0                54225         NaN
# 1      2  United Kingdom       82,7                39753         NaN
# 2      3     Netherlands       82,4                48473         NaN
# 3      4          Canada       78,2                44018         NaN
# 4      5          Sweden       76,8                46949         NaN
# 5      6     Switzerland       76,3                57410         NaN
# 6      7          Norway       74,4                64800         NaN
# 7      8         Denmark       71,1                46683         NaN
# 8      9       Australia       69,3                44649         NaN
# 9     10       Finland         68,9                40586         NaN
# 10    11         Ireland       66,0                67335         NaN
# 11    12      Luxembourg       65,6                94278         NaN
# 12    13     New Zealand       65,3                36086         NaN
# 13    14  Germany France       64,4                45229         NaN
# 14    15             NaN       63,6                38606         NaN

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = False
df['Year'] = 2020
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,[0]].astype(float)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# invert since to lower rank is better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Two problems: 1. cannot use the name of the column, have to use iloc, 2. cannot use the index column
# because the number format is not standard, have to use the rank column
# Out:
#            Country  Year                    Indicator  data_col  \
# 0    United States  2020  Digital Work Ecosystem size       1.0
# 1   United Kingdom  2020  Digital Work Ecosystem size       2.0
# 2      Netherlands  2020  Digital Work Ecosystem size       3.0
# 3           Canada  2020  Digital Work Ecosystem size       4.0
# 4           Sweden  2020  Digital Work Ecosystem size       5.0
# 5      Switzerland  2020  Digital Work Ecosystem size       6.0
# 6           Norway  2020  Digital Work Ecosystem size       7.0
# 7          Denmark  2020  Digital Work Ecosystem size       8.0
# 8        Australia  2020  Digital Work Ecosystem size       9.0
# 9        Finland    2020  Digital Work Ecosystem size      10.0
# 10         Ireland  2020  Digital Work Ecosystem size      11.0
# 11      Luxembourg  2020  Digital Work Ecosystem size      12.0
# 12     New Zealand  2020  Digital Work Ecosystem size      13.0
# 13  Germany France  2020  Digital Work Ecosystem size      14.0
# 14             NaN  2020  Digital Work Ecosystem size      15.0
#
#     new_rank_score  higher_is_better
# 0         6.000000             False
# 1         5.956522             False
# 2         5.913043             False
# 3         5.869565             False
# 4         5.826087             False
# 5         5.782609             False
# 6         5.739130             False
# 7         5.695652             False
# 8         5.652174             False
# 9         5.608696             False
# 10        5.565217             False
# 11        5.521739             False
# 12        5.478261             False
# 13        5.434783             False
# 14        5.391304             False

# %%
### 36. Country, Industry, Skill Migration Data (Skill)

# %%
indicators[35]

# load data
indicator = indicators[35]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Country, Industry, Skill Migration Data (Skill)
# migration_skill

# %%
df.head(15)
# Out:
#    country_code country_name   wb_income   wb_region  skill_group_id  \
# 0            af  Afghanistan  Low income  South Asia          2549.0
# 1            af  Afghanistan  Low income  South Asia          2608.0
# 2            af  Afghanistan  Low income  South Asia          3806.0
# 3            af  Afghanistan  Low income  South Asia         50321.0
# 4            af  Afghanistan  Low income  South Asia          1606.0
# 5            af  Afghanistan  Low income  South Asia          3139.0
# 6            af  Afghanistan  Low income  South Asia          1315.0
# 7            af  Afghanistan  Low income  South Asia          1017.0
# 8            af  Afghanistan  Low income  South Asia          2130.0
# 9            af  Afghanistan  Low income  South Asia          2265.0
# 10           af  Afghanistan  Low income  South Asia          1989.0
# 11           af  Afghanistan  Low income  South Asia         17168.0
# 12           af  Afghanistan  Low income  South Asia          1871.0
# 13           af  Afghanistan  Low income  South Asia          3980.0
# 14           af  Afghanistan  Low income  South Asia          2917.0
#
#            skill_group_category                        skill_group_name  \
# 0                   Tech Skills                  Information Management
# 1               Business Skills                  Operational Efficiency
# 2   Specialized Industry Skills                       National Security
# 3                   Tech Skills                        Software Testing
# 4   Specialized Industry Skills                                    Navy
# 5        Disruptive Tech Skills                       Materials Science
# 6   Specialized Industry Skills                            Criminal Law
# 7                   Soft Skills                         Problem Solving
# 8                   Tech Skills  Software Development Life Cycle (SDLC)
# 9   Specialized Industry Skills                           Cybersecurity
# 10                  Tech Skills                     Enterprise Software
# 11  Specialized Industry Skills                       Water Engineering
# 12  Specialized Industry Skills                               Air Force
# 13  Specialized Industry Skills                           Documentation
# 14  Specialized Industry Skills                           Public Safety
#
#     net_per_10K_2015  net_per_10K_2016  net_per_10K_2017  net_per_10K_2018  \
# 0            -791.59           -705.88           -550.04           -680.92
# 1           -1610.25           -933.55           -776.06           -532.22
# 2           -1731.45           -769.68           -756.59           -600.44
# 3            -957.50           -828.54           -964.73           -406.50
# 4           -1510.71           -841.17           -842.32           -581.71
# 5           -1085.03          -1045.71           -783.03           -473.42
# 6            -687.80           -294.93           -769.01           -415.34
# 7            -906.42           -210.44           -480.92           -126.62
# 8           -1096.96           -566.70           -478.30           -324.99
# 9           -1046.26           -796.25           -796.72           -517.62
# 10           -989.69           -778.24           -328.94           -350.93
# 11           -639.43           -851.40           -486.67           -377.28
# 12          -1488.62           -839.32           -777.83           -480.36
# 13          -1115.58           -955.82          -1025.11           -722.36
# 14          -1191.25           -789.13           -743.97           -465.34
#
#     net_per_10K_2019  Unnamed: 12  data_country  data_year
# 0           -1208.79          NaN           NaN        NaN
# 1            -790.09          NaN           NaN        NaN
# 2            -767.64          NaN           NaN        NaN
# 3            -739.51          NaN           NaN        NaN
# 4            -718.64          NaN           NaN        NaN
# 5            -717.73          NaN           NaN        NaN
# 6            -698.84          NaN           NaN        NaN
# 7            -696.16          NaN           NaN        NaN
# 8            -692.24          NaN           NaN        NaN
# 9            -640.96          NaN           NaN        NaN
# 10           -625.19          NaN           NaN        NaN
# 11           -560.86          NaN           NaN        NaN
# 12           -553.91          NaN           NaN        NaN
# 13           -534.90          NaN           NaN        NaN
# 14           -531.68          NaN           NaN        NaN

# %%
df['Country'] = df.iloc[:,[1]]

df_sum = df.groupby('Country')[['net_per_10K_2019']].sum()
df_sum
# Out:
#                     net_per_10K_2019
# Country
# Afghanistan                 -1369.00
# Albania                     -2188.08
# Algeria                     -3243.78
# Angola                        544.66
# Argentina                   -4122.87
# ...                              ...
# Vietnam                     -2645.19
# West Bank and Gaza           -748.05
# Yemen, Rep.                   160.41
# Zambia                        494.78
# Zimbabwe                    -1701.37
#
# [137 rows x 1 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#               Year                                          Indicator  \
# Country
# Afghanistan   2019  Country, Industry, Skill Migration Data (Indus...
# Albania       2019  Country, Industry, Skill Migration Data (Indus...
# Algeria       2019  Country, Industry, Skill Migration Data (Indus...
# Angola        2019  Country, Industry, Skill Migration Data (Indus...
# Argentina     2019  Country, Industry, Skill Migration Data (Indus...
# Armenia       2019  Country, Industry, Skill Migration Data (Indus...
# Australia     2019  Country, Industry, Skill Migration Data (Indus...
# Austria       2019  Country, Industry, Skill Migration Data (Indus...
# Azerbaijan    2019  Country, Industry, Skill Migration Data (Indus...
# Bahamas, The  2019  Country, Industry, Skill Migration Data (Indus...
# Bahrain       2019  Country, Industry, Skill Migration Data (Indus...
# Bangladesh    2019  Country, Industry, Skill Migration Data (Indus...
# Belarus       2019  Country, Industry, Skill Migration Data (Indus...
# Belgium       2019  Country, Industry, Skill Migration Data (Indus...
# Benin         2019  Country, Industry, Skill Migration Data (Indus...
#
#               data_col  new_rank_score  higher_is_better
# Country
# Afghanistan   -1369.00        4.082767              True
# Albania       -2188.08        4.016637              True
# Algeria       -3243.78        3.931403              True
# Angola          544.66        4.237269              True
# Argentina     -4122.87        3.860429              True
# Armenia        -308.22        4.168411              True
# Australia     13732.49        5.302010              True
# Austria        7143.28        4.770019              True
# Azerbaijan    -1030.96        4.110059              True
# Bahamas, The   -202.83        4.176919              True
# Bahrain        -416.68        4.159654              True
# Bangladesh    -2270.37        4.009993              True
# Belarus        -431.20        4.158482              True
# Belgium        3728.64        4.494333              True
# Benin          -129.29        4.182857              True

# %%
### 37. Country, Industry, Skill Migration Data (Industry)
# Out:
# Country, Industry, Skill Migration Data (Industry)
# migration_industry

# %%
indicators[36]

# load data
indicator = indicators[36]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)
# Out:
#    country_code          country_name    wb_income  \
# 0            ae  United Arab Emirates  High income
# 1            ae  United Arab Emirates  High income
# 2            ae  United Arab Emirates  High income
# 3            ae  United Arab Emirates  High income
# 4            ae  United Arab Emirates  High income
# 5            ae  United Arab Emirates  High income
# 6            ae  United Arab Emirates  High income
# 7            ae  United Arab Emirates  High income
# 8            ae  United Arab Emirates  High income
# 9            ae  United Arab Emirates  High income
# 10           ae  United Arab Emirates  High income
# 11           ae  United Arab Emirates  High income
# 12           ae  United Arab Emirates  High income
# 13           ae  United Arab Emirates  High income
# 14           ae  United Arab Emirates  High income
#
#                      wb_region isic_section_index  \
# 0   Middle East & North Africa                  C
# 1   Middle East & North Africa                  J
# 2   Middle East & North Africa                  J
# 3   Middle East & North Africa                  J
# 4   Middle East & North Africa                  J
# 5   Middle East & North Africa                  J
# 6   Middle East & North Africa                  M
# 7   Middle East & North Africa                  M
# 8   Middle East & North Africa                  M
# 9   Middle East & North Africa                  M
# 10  Middle East & North Africa                  Q
# 11  Middle East & North Africa                  Q
# 12  Middle East & North Africa                  C
# 13  Middle East & North Africa                  Q
# 14  Middle East & North Africa                  G
#
#                                     isic_section_name  industry_id  \
# 0                                       Manufacturing            1
# 1                       Information and communication            3
# 2                       Information and communication            4
# 3                       Information and communication            5
# 4                       Information and communication            6
# 5                       Information and communication            8
# 6    Professional scientific and technical activities            9
# 7    Professional scientific and technical activities           10
# 8    Professional scientific and technical activities           11
# 9    Professional scientific and technical activities           12
# 10            Human health and social work activities           13
# 11            Human health and social work activities           14
# 12                                      Manufacturing           15
# 13            Human health and social work activities           17
# 14  Wholesale and retail trade; repair of motor ve...           18
#
#              industry_name  net_per_10K_2015  net_per_10K_2016  \
# 0          Defense & Space            378.74            127.94
# 1        Computer Hardware            100.97            358.14
# 2        Computer Software           1079.36            848.15
# 3      Computer Networking            401.46            447.39
# 4                 Internet           1840.33           1368.42
# 5       Telecommunications            676.91            676.11
# 6             Law Practice            694.50            529.50
# 7           Legal Services            661.10            665.65
# 8    Management Consulting            982.85            694.25
# 9            Biotechnology           1230.17            846.28
# 10        Medical Practice            674.12            449.37
# 11  Hospital & Health Care            784.47            663.06
# 12         Pharmaceuticals            893.55            714.75
# 13          Medical Device            885.00           1034.07
# 14               Cosmetics            928.04            689.92
#
#     net_per_10K_2017  net_per_10K_2018  net_per_10K_2019  Unnamed: 13  \
# 0               8.20             68.51             49.55          NaN
# 1             112.98            149.57            182.22          NaN
# 2             596.48            409.18            407.41          NaN
# 3             163.99            236.69            188.07          NaN
# 4             877.71            852.39            519.40          NaN
# 5             365.96            283.59            281.91          NaN
# 6             362.83            356.56            147.83          NaN
# 7             462.30            475.62            255.21          NaN
# 8             520.28            574.60            406.03          NaN
# 9             500.77            205.78            513.23          NaN
# 10            368.32            266.66            136.06          NaN
# 11            475.39            373.26            268.67          NaN
# 12            473.60            515.47            396.71          NaN
# 13            543.44            415.49            183.75          NaN
# 14            428.23            278.95            157.01          NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
df['Country'] = df.iloc[:,[1]]

df_sum = df.groupby('Country')[['net_per_10K_2019']].sum()
df_sum
# Out:
#                     net_per_10K_2019
# Country
# Afghanistan                 -1369.00
# Albania                     -2188.08
# Algeria                     -3243.78
# Angola                        544.66
# Argentina                   -4122.87
# ...                              ...
# Vietnam                     -2645.19
# West Bank and Gaza           -748.05
# Yemen, Rep.                   160.41
# Zambia                        494.78
# Zimbabwe                    -1701.37
#
# [137 rows x 1 columns]

# %%
## create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#               Year                                          Indicator  \
# Country
# Afghanistan   2019  Country, Industry, Skill Migration Data (Indus...
# Albania       2019  Country, Industry, Skill Migration Data (Indus...
# Algeria       2019  Country, Industry, Skill Migration Data (Indus...
# Angola        2019  Country, Industry, Skill Migration Data (Indus...
# Argentina     2019  Country, Industry, Skill Migration Data (Indus...
# Armenia       2019  Country, Industry, Skill Migration Data (Indus...
# Australia     2019  Country, Industry, Skill Migration Data (Indus...
# Austria       2019  Country, Industry, Skill Migration Data (Indus...
# Azerbaijan    2019  Country, Industry, Skill Migration Data (Indus...
# Bahamas, The  2019  Country, Industry, Skill Migration Data (Indus...
# Bahrain       2019  Country, Industry, Skill Migration Data (Indus...
# Bangladesh    2019  Country, Industry, Skill Migration Data (Indus...
# Belarus       2019  Country, Industry, Skill Migration Data (Indus...
# Belgium       2019  Country, Industry, Skill Migration Data (Indus...
# Benin         2019  Country, Industry, Skill Migration Data (Indus...
#
#               data_col  new_rank_score  higher_is_better
# Country
# Afghanistan   -1369.00        4.082767              True
# Albania       -2188.08        4.016637              True
# Algeria       -3243.78        3.931403              True
# Angola          544.66        4.237269              True
# Argentina     -4122.87        3.860429              True
# Armenia        -308.22        4.168411              True
# Australia     13732.49        5.302010              True
# Austria        7143.28        4.770019              True
# Azerbaijan    -1030.96        4.110059              True
# Bahamas, The   -202.83        4.176919              True
# Bahrain        -416.68        4.159654              True
# Bangladesh    -2270.37        4.009993              True
# Belarus        -431.20        4.158482              True
# Belgium        3728.64        4.494333              True
# Benin          -129.29        4.182857              True

# %%
### 38. Country, Industry, Skill Migration Data (Nation)

# %%
indicators[37]

# load data
indicator = indicators[37]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Country, Industry, Skill Migration Data (Country)
# migration_country

# %%
df.head(15)
# Out:
#    base_country_code     base_country_name   base_lat  base_long  \
# 0                 ae  United Arab Emirates  23.424076  53.847818
# 1                 ae  United Arab Emirates  23.424076  53.847818
# 2                 ae  United Arab Emirates  23.424076  53.847818
# 3                 ae  United Arab Emirates  23.424076  53.847818
# 4                 ae  United Arab Emirates  23.424076  53.847818
# 5                 ae  United Arab Emirates  23.424076  53.847818
# 6                 ae  United Arab Emirates  23.424076  53.847818
# 7                 ae  United Arab Emirates  23.424076  53.847818
# 8                 ae  United Arab Emirates  23.424076  53.847818
# 9                 ae  United Arab Emirates  23.424076  53.847818
# 10                ae  United Arab Emirates  23.424076  53.847818
# 11                ae  United Arab Emirates  23.424076  53.847818
# 12                ae  United Arab Emirates  23.424076  53.847818
# 13                ae  United Arab Emirates  23.424076  53.847818
# 14                ae  United Arab Emirates  23.424076  53.847818
#
#    base_country_wb_income      base_country_wb_region target_country_code  \
# 0             High Income  Middle East & North Africa                  af
# 1             High Income  Middle East & North Africa                  dz
# 2             High Income  Middle East & North Africa                  ao
# 3             High Income  Middle East & North Africa                  ar
# 4             High Income  Middle East & North Africa                  am
# 5             High Income  Middle East & North Africa                  au
# 6             High Income  Middle East & North Africa                  at
# 7             High Income  Middle East & North Africa                  az
# 8             High Income  Middle East & North Africa                  bh
# 9             High Income  Middle East & North Africa                  bd
# 10            High Income  Middle East & North Africa                  by
# 11            High Income  Middle East & North Africa                  be
# 12            High Income  Middle East & North Africa                  br
# 13            High Income  Middle East & North Africa                  bg
# 14            High Income  Middle East & North Africa                  cm
#
#    target_country_name  target_lat  target_long target_country_wb_income  \
# 0          Afghanistan   33.939110    67.709953               Low Income
# 1              Algeria   28.033886     1.659626      Upper Middle Income
# 2               Angola  -11.202692    17.873887      Lower Middle Income
# 3            Argentina  -38.416097   -63.616672              High Income
# 4              Armenia   40.069099    45.038189      Upper Middle Income
# 5            Australia  -25.274398   133.775136              High Income
# 6              Austria   47.516231    14.550072              High Income
# 7           Azerbaijan   40.143105    47.576927      Upper Middle Income
# 8              Bahrain   25.930414    50.637772              High Income
# 9           Bangladesh   23.684994    90.356331      Lower Middle Income
# 10             Belarus   53.709807    27.953389      Upper Middle Income
# 11             Belgium   50.503887     4.469936              High Income
# 12              Brazil  -14.235004   -51.925280      Upper Middle Income
# 13            Bulgaria   42.733883    25.485830      Upper Middle Income
# 14            Cameroon    7.369722    12.354722      Lower Middle Income
#
#       target_country_wb_region  net_per_10K_2015  net_per_10K_2016  \
# 0                   South Asia              0.19              0.16
# 1   Middle East & North Africa              0.19              0.25
# 2           Sub-Saharan Africa             -0.01              0.04
# 3    Latin America & Caribbean              0.16              0.18
# 4        Europe & Central Asia              0.10              0.05
# 5          East Asia & Pacific             -1.06             -3.31
# 6        Europe & Central Asia              0.11             -0.08
# 7        Europe & Central Asia              0.24              0.25
# 8   Middle East & North Africa              0.90              0.89
# 9                   South Asia             -0.21             -0.21
# 10       Europe & Central Asia              0.12              0.12
# 11       Europe & Central Asia              0.51              0.22
# 12   Latin America & Caribbean              0.81              0.78
# 13       Europe & Central Asia              0.17              0.09
# 14          Sub-Saharan Africa              0.20              0.13
#
#     net_per_10K_2017  net_per_10K_2018  net_per_10K_2019  Unnamed: 17  \
# 0               0.11             -0.05             -0.02          NaN
# 1               0.57              0.55              0.78          NaN
# 2               0.11             -0.02             -0.06          NaN
# 3               0.04              0.01              0.23          NaN
# 4               0.03             -0.01              0.02          NaN
# 5              -4.01             -4.58             -4.09          NaN
# 6              -0.07             -0.05             -0.16          NaN
# 7               0.10              0.05              0.04          NaN
# 8               0.38             -0.07              0.15          NaN
# 9              -0.26             -0.18             -0.04          NaN
# 10              0.11              0.12              0.10          NaN
# 11             -0.01             -0.09             -0.06          NaN
# 12              0.63              0.90              0.99          NaN
# 13             -0.07             -0.02             -0.04          NaN
# 14              0.20              0.29              0.29          NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
df['Country'] = df.iloc[:,[1]]

df_sum = df.groupby('Country')[['net_per_10K_2019']].sum()
df_sum
# Out:
#                     net_per_10K_2019
# Country
# Afghanistan                    23.01
# Albania                       -16.58
# Algeria                       -23.47
# Angola                         19.07
# Argentina                      -8.77
# ...                              ...
# Vietnam                        -7.94
# West Bank and Gaza            -15.59
# Yemen, Rep.                     2.89
# Zambia                         27.05
# Zimbabwe                      -23.98
#
# [140 rows x 1 columns]

# %%
## create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#               Year                                          Indicator  \
# Country
# Afghanistan   2019  Country, Industry, Skill Migration Data (Country)
# Albania       2019  Country, Industry, Skill Migration Data (Country)
# Algeria       2019  Country, Industry, Skill Migration Data (Country)
# Angola        2019  Country, Industry, Skill Migration Data (Country)
# Argentina     2019  Country, Industry, Skill Migration Data (Country)
# Armenia       2019  Country, Industry, Skill Migration Data (Country)
# Australia     2019  Country, Industry, Skill Migration Data (Country)
# Austria       2019  Country, Industry, Skill Migration Data (Country)
# Azerbaijan    2019  Country, Industry, Skill Migration Data (Country)
# Bahamas, The  2019  Country, Industry, Skill Migration Data (Country)
# Bahrain       2019  Country, Industry, Skill Migration Data (Country)
# Bangladesh    2019  Country, Industry, Skill Migration Data (Country)
# Belarus       2019  Country, Industry, Skill Migration Data (Country)
# Belgium       2019  Country, Industry, Skill Migration Data (Country)
# Benin         2019  Country, Industry, Skill Migration Data (Country)
#
#               data_col  new_rank_score  higher_is_better
# Country
# Afghanistan      23.01        3.194208              True
# Albania         -16.58        2.634379              True
# Algeria         -23.47        2.536950              True
# Angola           19.07        3.138494              True
# Argentina        -8.77        2.744817              True
# Armenia         -12.46        2.692638              True
# Australia        42.52        3.470092              True
# Austria          26.61        3.245114              True
# Azerbaijan      -10.29        2.723324              True
# Bahamas, The     -8.82        2.744110              True
# Bahrain          18.38        3.128737              True
# Bangladesh      -11.75        2.702678              True
# Belarus         -26.04        2.500608              True
# Belgium          12.56        3.046438              True
# Benin           -38.71        2.321446              True

# %%
### 39. Digital Finance Ecosystem size

# %%
indicators[38]

# load data
indicator = indicators[38]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Digital Finance Ecosystem size
# global_fintech_ranking

# %%
df.head(15)
# Out:
#                            Global Fintech
# Rank Country           Total Score (2021)
# 1    United States                 31.789
# 2    United Kingdom                23.262
# 3    Singapore                     19.176
# 4    Lithuania                     17.343
# 5    Switzerland                   16.018
# 6    The Netherlands               14.464
# 7    Sweden                        14.272
# 8    Australia                     13.555
# 9    Canada                        13.322
# 10   Estonia                       13.303
# 11   Germany                       12.787
# 12   Israel                        12.771
# 13   Spain                         12.372
# 14   Finland                        12.11

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,[2]]

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# Have to shorten the column names to see if this works
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-181-b056fd23cb73> in <module>
#      11
#      12 # transform 0-1 rank into 1-6
# ---> 13 df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
#      14
#      15 # Have to shorten the column names to see if this works
#
# D:\Apps\Anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-181-b056fd23cb73> in <lambda>(row)
#      11
#      12 # transform 0-1 rank into 1-6
# ---> 13 df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
#      14
#      15 # Have to shorten the column names to see if this works
#
# <ipython-input-30-020bafb9c04d> in convert_rank(old_value, old_min, old_max, new_min, new_max)
#       4     old_range = old_max - old_min
#       5     new_range = new_max - new_min
# ----> 6     new_value = (((old_value-old_min)*new_range)/old_range)+new_min
#       7     return new_value
#
# ZeroDivisionError: division by zero

# %%
### 40. Tech hubs & spaces size

# %%
indicators[39]

# load data
indicator = indicators[39]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Tech hubs & spaces size
# tech_hubs

# %%
df.head(15)

#There are two problems:
#1. The column names need some overhaul (moving the second column to the top and make it the column names)
#2. This is a list of cities, not countries, may present probkems later.
# Out:
#    Unnamed: 0 Overall Research  innovation Innovation economy  \
# 0     Ranking   Score                Score              Score
# 1           1     100                91.59                100
# 2           2   88.44                  100              67.63
# 3           4   85.57                98.49              67.91
# 4          15   84.75                82.99              90.92
# 5          11   84.68                85.96              86.49
# 6           3   80.69                88.49              63.63
# 7           9   77.61                 81.8              69.47
# 8           6   76.88                 85.1              63.46
# 9          12   76.72                87.96              63.74
# 10         13   76.58                87.13               64.2
# 11         20   76.43                 87.8              66.78
# 12          7   75.64                 82.3              62.87
# 13          5   75.11                80.43              62.76
# 14          8   74.36                 77.8              63.66
#
#    Innovation  ecosystem
# 0                  Score
# 1                    100
# 2                  94.26
# 3                  87.73
# 4                  76.37
# 5                  77.96
# 6                  88.09
# 7                  80.04
# 8                  81.18
# 9                   77.9
# 10                 77.81
# 11                  74.2
# 12                 81.01
# 13                 81.39
# 14                 80.86

# %%
### 41. Banking Ecosystem size

# %%
indicators[40]

# load data
indicator = indicators[40]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Banking Ecosystem size
# banking_sector_size

# %%
df.head(15)
# Out:
#            Country  Bank assets, percent of GDP, 2017
# 0     1. Hong Kong                             256.63
# 1         2. China                             174.54
# 2       3. Denmark                             172.28
# 3   4. New Zealand                             157.73
# 4         5. Japan                             157.51
# 5       6. Lebanon                             157.18
# 6     7. Singapore                             151.67
# 7         8. Qatar                             149.95
# 8   9. South Korea                             141.52
# 9    10. Australia                             140.47
# 10    11. Thailand                             138.96
# 11     12. Vietnam                             137.43
# 12      13. Sweden                             135.27
# 13      14. Norway                             134.37
# 14    15. Malaysia                             131.91

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2017
df['Indicator'] = indicator
df['data_col'] = df['Bank assets, percent of GDP, 2017']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but will have to remove number from the Country column, leaving only characters.
# Out:
#            Country  Year               Indicator  data_col  new_rank_score  \
# 0     1. Hong Kong  2017  Banking Ecosystem size    256.63        6.000000
# 1         2. China  2017  Banking Ecosystem size    174.54        4.380612
# 2       3. Denmark  2017  Banking Ecosystem size    172.28        4.336029
# 3   4. New Zealand  2017  Banking Ecosystem size    157.73        4.049002
# 4         5. Japan  2017  Banking Ecosystem size    157.51        4.044662
# 5       6. Lebanon  2017  Banking Ecosystem size    157.18        4.038152
# 6     7. Singapore  2017  Banking Ecosystem size    151.67        3.929456
# 7         8. Qatar  2017  Banking Ecosystem size    149.95        3.895526
# 8   9. South Korea  2017  Banking Ecosystem size    141.52        3.729227
# 9    10. Australia  2017  Banking Ecosystem size    140.47        3.708514
# 10    11. Thailand  2017  Banking Ecosystem size    138.96        3.678726
# 11     12. Vietnam  2017  Banking Ecosystem size    137.43        3.648544
# 12      13. Sweden  2017  Banking Ecosystem size    135.27        3.605934
# 13      14. Norway  2017  Banking Ecosystem size    134.37        3.588180
# 14    15. Malaysia  2017  Banking Ecosystem size    131.91        3.539651
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True

# %%
### 42. Angel Ecosystem size

# %%
indicators[41]

# load data
indicator = indicators[41]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Angel Ecosystem size
# angel_investment

# %%
df.head(15)

# Will have to move the second line to first line and delete the title
# Out:
#    Business angel investments on the visible market in Europe in 2019, by country  \
# 0   Value of business angel investments via angel ...
# 1                                      United Kingdom
# 2                                             Germany
# 3                                               Spain
# 4                                             Finland
# 5                                              Sweden
# 6                                              France
# 7                                             Denmark
# 8                                         Switzerland
# 9                                               Italy
# 10                                             Russia
# 11                                             Turkey
# 12                                            Austria
# 13                                        Netherlands
# 14                                            Belgium
#
#     Unnamed: 1
# 0          NaN
# 1       153.08
# 2        81.77
# 3        78.66
# 4        54.00
# 5        44.08
# 6        43.00
# 7        33.34
# 8        32.60
# 9        28.20
# 10       26.08
# 11       21.26
# 12       20.11
# 13       19.38
# 14       17.09

# %%
### 43. Startup Ecosystem size

# %%
indicators[42]

# load data
indicator = indicators[42]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Startup Ecosystem size
# startup_eco_size

# %%
df.head(15)

# This is a list of cities, not countries, wonder if it will work
# Out:
#                 Location Ranking (2019)
# 0         Silicon Valley              1
# 1          New York City        2 (tie)
# 2                 London        2 (tie)
# 3                Beijing              4
# 4                 Boston              5
# 5   Tel Aviv - Jerusalem        6 (tie)
# 6            Los Angeles        6 (tie)
# 7               Shanghai              8
# 8                Seattle              9
# 9              Stockholm             10
# 10         Washington DC             11
# 11             Amsterdam             12
# 12                 Paris             13
# 13               Chicago             14
# 14                 Tokyo             15

# %%
### 44. Venture Ecosystem size

# Similar to the previous one

# %%
### 45. International Co-Inventions

# %%
indicators[44]

# load data
indicator = indicators[44]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# International Co-Inventions
# international_co_inventions

# %%
df.head(15)
# Out:
#    KINDPATENT                   Patent office KINDCOOP  \
# 0       EPO_A  Patent applications to the EPO  FOR_APP
# 1       EPO_A  Patent applications to the EPO  FOR_APP
# 2       EPO_A  Patent applications to the EPO  FOR_APP
# 3       EPO_A  Patent applications to the EPO  FOR_APP
# 4       EPO_A  Patent applications to the EPO  FOR_APP
# 5       EPO_A  Patent applications to the EPO  FOR_APP
# 6       EPO_A  Patent applications to the EPO  FOR_APP
# 7       EPO_A  Patent applications to the EPO  FOR_APP
# 8       EPO_A  Patent applications to the EPO  FOR_APP
# 9       EPO_A  Patent applications to the EPO  FOR_APP
# 10      EPO_A  Patent applications to the EPO  FOR_APP
# 11      EPO_A  Patent applications to the EPO  FOR_APP
# 12      EPO_A  Patent applications to the EPO  FOR_APP
# 13      EPO_A  Patent applications to the EPO  FOR_APP
# 14      EPO_A  Patent applications to the EPO  FOR_APP
#
#    Type of International Cooperation in Patenting LOCATION    Country PARTNER  \
# 0        Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 1        Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 2        Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 3        Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 4        Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 5        Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 6        Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 7        Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 8        Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 9        Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 10       Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 11       Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 12       Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 13       Foreign ownership of domestic inventions      AUS  Australia   TOTAL
# 14       Foreign ownership of domestic inventions      AUS  Australia   TOTAL
#
#    Partner Country  KINDDATE Reference Date  ...  Time  Unit Code    Unit  \
# 0    Total Patents  PRIORITY  Priority date  ...  1999        NBR  Number
# 1    Total Patents  PRIORITY  Priority date  ...  2000        NBR  Number
# 2    Total Patents  PRIORITY  Priority date  ...  2001        NBR  Number
# 3    Total Patents  PRIORITY  Priority date  ...  2002        NBR  Number
# 4    Total Patents  PRIORITY  Priority date  ...  2003        NBR  Number
# 5    Total Patents  PRIORITY  Priority date  ...  2004        NBR  Number
# 6    Total Patents  PRIORITY  Priority date  ...  2005        NBR  Number
# 7    Total Patents  PRIORITY  Priority date  ...  2006        NBR  Number
# 8    Total Patents  PRIORITY  Priority date  ...  2007        NBR  Number
# 9    Total Patents  PRIORITY  Priority date  ...  2008        NBR  Number
# 10   Total Patents  PRIORITY  Priority date  ...  2009        NBR  Number
# 11   Total Patents  PRIORITY  Priority date  ...  2010        NBR  Number
# 12   Total Patents  PRIORITY  Priority date  ...  2011        NBR  Number
# 13   Total Patents  PRIORITY  Priority date  ...  2012        NBR  Number
# 14   Total Patents  PRIORITY  Priority date  ...  2013        NBR  Number
#
#    PowerCode Code  PowerCode Reference Period Code  Reference Period   Value  \
# 0               0      Units                   NaN               NaN  1082.0
# 1               0      Units                   NaN               NaN  1159.0
# 2               0      Units                   NaN               NaN  1119.0
# 3               0      Units                   NaN               NaN  1193.0
# 4               0      Units                   NaN               NaN  1238.0
# 5               0      Units                   NaN               NaN  1336.0
# 6               0      Units                   NaN               NaN  1332.0
# 7               0      Units                   NaN               NaN  1219.0
# 8               0      Units                   NaN               NaN  1131.0
# 9               0      Units                   NaN               NaN  1110.0
# 10              0      Units                   NaN               NaN  1126.0
# 11              0      Units                   NaN               NaN  1035.0
# 12              0      Units                   NaN               NaN  1087.0
# 13              0      Units                   NaN               NaN  1072.0
# 14              0      Units                   NaN               NaN  1006.0
#
#     Flag Codes  Flags
# 0          NaN    NaN
# 1          NaN    NaN
# 2          NaN    NaN
# 3          NaN    NaN
# 4          NaN    NaN
# 5          NaN    NaN
# 6          NaN    NaN
# 7          NaN    NaN
# 8          NaN    NaN
# 9          NaN    NaN
# 10         NaN    NaN
# 11         NaN    NaN
# 12         NaN    NaN
# 13         NaN    NaN
# 14         NaN    NaN
#
# [15 rows x 21 columns]

# %%
# filter most recent year and global value
df = df[(df.Time==2017)]
df = df[(df.Country!='World')]
df
# Out:
#       KINDPATENT                     Patent office  KINDCOOP  \
# 36         EPO_A    Patent applications to the EPO   FOR_APP
# 73         EPO_A    Patent applications to the EPO   FOR_APP
# 110        EPO_A    Patent applications to the EPO   FOR_APP
# 147        EPO_A    Patent applications to the EPO   FOR_APP
# 184        EPO_A    Patent applications to the EPO   FOR_APP
# ...          ...                               ...       ...
# 27024    USPTO_A  Patent applications to the USPTO  CO_INV_S
# 27062    USPTO_A  Patent applications to the USPTO  CO_INV_S
# 27081    USPTO_A  Patent applications to the USPTO  CO_INV_S
# 27100    USPTO_A  Patent applications to the USPTO  CO_INV_S
# 27119    USPTO_A  Patent applications to the USPTO  CO_INV_S
#
#       Type of International Cooperation in Patenting LOCATION  \
# 36          Foreign ownership of domestic inventions      AUS
# 73          Foreign ownership of domestic inventions      AUS
# 110         Foreign ownership of domestic inventions      AUS
# 147         Foreign ownership of domestic inventions      AUS
# 184         Foreign ownership of domestic inventions      AUS
# ...                                              ...      ...
# 27024       % of patents with foreign co-inventor(s)      USA
# 27062       % of patents with foreign co-inventor(s)     EU27
# 27081       % of patents with foreign co-inventor(s)     EU27
# 27100       % of patents with foreign co-inventor(s)     EU27
# 27119       % of patents with foreign co-inventor(s)     EU27
#
#                              Country PARTNER                 Partner Country  \
# 36                         Australia   TOTAL                   Total Patents
# 73                         Australia     WRD  Total co-operation with abroad
# 110                        Australia     JPN                           Japan
# 147                        Australia     USA                   United States
# 184                        Australia    EU27             European Union (27)
# ...                              ...     ...                             ...
# 27024                  United States    EU27             European Union (27)
# 27062  European Union (27 countries)     WRD  Total co-operation with abroad
# 27081  European Union (27 countries)     JPN                           Japan
# 27100  European Union (27 countries)     USA                   United States
# 27119  European Union (27 countries)    EU27             European Union (27)
#
#           KINDDATE    Reference Date  ...  Time  Unit Code        Unit  \
# 36     APPLICATION  Application date  ...  2017        NBR      Number
# 73     APPLICATION  Application date  ...  2017        NBR      Number
# 110    APPLICATION  Application date  ...  2017        NBR      Number
# 147    APPLICATION  Application date  ...  2017        NBR      Number
# 184    APPLICATION  Application date  ...  2017        NBR      Number
# ...            ...               ...  ...   ...        ...         ...
# 27024  APPLICATION  Application date  ...  2017         PC  Percentage
# 27062  APPLICATION  Application date  ...  2017         PC  Percentage
# 27081  APPLICATION  Application date  ...  2017         PC  Percentage
# 27100  APPLICATION  Application date  ...  2017         PC  Percentage
# 27119  APPLICATION  Application date  ...  2017         PC  Percentage
#
#       PowerCode Code  PowerCode Reference Period Code  Reference Period  \
# 36                 0      Units                   NaN               NaN
# 73                 0      Units                   NaN               NaN
# 110                0      Units                   NaN               NaN
# 147                0      Units                   NaN               NaN
# 184                0      Units                   NaN               NaN
# ...              ...        ...                   ...               ...
# 27024              0      Units                   NaN               NaN
# 27062              0      Units                   NaN               NaN
# 27081              0      Units                   NaN               NaN
# 27100              0      Units                   NaN               NaN
# 27119              0      Units                   NaN               NaN
#
#            Value  Flag Codes  Flags
# 36     1077.0000         NaN    NaN
# 73      277.0000         NaN    NaN
# 110      11.0000         NaN    NaN
# 147     137.0000         NaN    NaN
# 184      62.0000         NaN    NaN
# ...          ...         ...    ...
# 27024     3.6198         NaN    NaN
# 27062    20.9912         NaN    NaN
# 27081     0.7465         NaN    NaN
# 27100    13.4261         NaN    NaN
# 27119     6.8753         NaN    NaN
#
# [828 rows x 21 columns]

# %%
# Create summarization
df_sum = df.groupby('Country')[['Value']].sum()
df_sum
# Out:
#                                       Value
# Country
# Australia                      3.116507e+04
# Canada                         8.628640e+04
# European Union (27 countries)  7.976543e+05
# European Union (28 countries)  0.000000e+00
# Japan                          5.457706e+05
# Netherlands                    7.438852e+04
# United States                  1.224357e+06

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2017
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum.iloc[:,[0]]

min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but the data is too general with many missing countries
# Out:
#                                Year                    Indicator  \
# Country
# Australia                      2017  International Co-Inventions
# Canada                         2017  International Co-Inventions
# European Union (27 countries)  2017  International Co-Inventions
# European Union (28 countries)  2017  International Co-Inventions
# Japan                          2017  International Co-Inventions
# Netherlands                    2017  International Co-Inventions
# United States                  2017  International Co-Inventions
#
#                                    data_col  new_rank_score  higher_is_better
# Country
# Australia                      3.116507e+04        1.127271              True
# Canada                         8.628640e+04        1.352374              True
# European Union (27 countries)  7.976543e+05        4.257441              True
# European Union (28 countries)  0.000000e+00        1.000000              True
# Japan                          5.457706e+05        3.228805              True
# Netherlands                    7.438852e+04        1.303786              True
# United States                  1.224357e+06        6.000000              True
