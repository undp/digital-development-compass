# %%
import pandas as pd
import numpy as np

# %%
### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False           Countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              20         25
# Foundations            9         12
# Government            11         15
# Infrastructure        45         48
# People                38         46
# Regulation             6          7
# Strategy               1          1

# %%
### Infrastructure

# %%
bnames = names[(names.check=='Infrastructure')&(~names.Filename.isna())]#&(names.Index==False)]
bnames.head(25)
# Out:
#                                             Indicator           check  \
# 4                                  Population Density  Infrastructure
# 5                                   Broadband Density  Infrastructure
# 6    % of population covered by internet connectivity  Infrastructure
# 7   % of population covered by mobile 2G+ data con...  Infrastructure
# 8   % of population covered by mobile 3G+ data con...  Infrastructure
# 9   % of population covered by mobile 4G+ data con...  Infrastructure
# 10  % of population covered by mobile 5G+ data con...  Infrastructure
# 11                               Mobile Coverage Maps  Infrastructure
# 12                                Electricity Density  Infrastructure
# 13             % of population covered by electricity  Infrastructure
# 14                         Electricity supply quality  Infrastructure
# 15           Electricity Environmental Sustainability  Infrastructure
# 16                  Electrical Distribution Grid Maps  Infrastructure
# 17                           Cellphone Signal Density  Infrastructure
# 18       Telecommunication Infrastructure Index (TII)  Infrastructure
# 19                    GSMA Mobile Connectivity Index   Infrastructure
# 20             Spectrum Allocated to Mobile Providers  Infrastructure
# 23                Internet Exchange Points (IXPs) map  Infrastructure
# 24                                 ISP Speeds - Fixed  Infrastructure
# 25                                ISP Speeds - Mobile  Infrastructure
# 26               ISP internet download speed average   Infrastructure
# 28  Mobile dowload speed at the slowest hour of th...  Infrastructure
# 29                     Mobile download speed average   Infrastructure
# 30   Individuals using the Internet (% of population)  Infrastructure
# 31     Mobile cellular subscriptions (per 100 people)  Infrastructure
#
#                                           Data Source  Index  \
# 4                                          World Bank  False
# 5                                          World Bank  False
# 6                                          World Bank  False
# 7                      GSMA Mobile Connectivity Index  False
# 8                      GSMA Mobile Connectivity Index  False
# 9                      GSMA Mobile Connectivity Index  False
# 10                     GSMA Mobile Connectivity Index  False
# 11                     GSMA Mobile Connectivity Index  False
# 12                                        Energy Data  False
# 13                                        World Bank   False
# 14  International Energy Agency / Global Competiti...  False
# 15  The Sustainable Development Report/ Cambridge ...  False
# 16                                           Facebook  False
# 17                     GSMA Mobile Connectivity Index  False
# 18                                               DESA   True
# 19                     GSMA Mobile Connectivity Index   True
# 20                     GSMA Mobile Connectivity Index  False
# 23                              Packet Clearing House  False
# 24                 Ookla's Speedtest Intelligence/AWS  False
# 25                 Ookla's Speedtest Intelligence/AWS  False
# 26                     Ookla's Speedtest Intelligence  False
# 28                     GSMA Mobile Connectivity Index  False
# 29                     Ookla's Speedtest Intelligence  False
# 30                                                ITU  False
# 31                                         World Bank  False
#
#                                Filename
# 4                    population_density
# 5               fixed_broadband_density
# 6            population_access_internet
# 7         countries_mobile_connectivity
# 8         countries_mobile_connectivity
# 9         countries_mobile_connectivity
# 10        countries_mobile_connectivity
# 11                      mobile_coverage
# 12                 electricity_yearbook
# 13      population_electricity_coverage
# 14                 elect_supply_quality
# 15                 sustainability_index
# 16                  elect_dist_grid_map
# 17                       mobile_density
# 18                   e_government_index
# 19        countries_mobile_connectivity
# 20  spectrum_allocated_mobile_providers
# 23                        countries_ixp
# 24    speedtest-global-performance.yaml
# 25    speedtest-global-performance.yaml
# 26                       internet_speed
# 28                       mobile_latency
# 29                         mobile_speed
# 30            individual_internet_usage
# 31                      mobile_cell_sub

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['population_density', 'fixed_broadband_density',
#        'population_access_internet', 'countries_mobile_connectivity',
#        'mobile_coverage', 'electricity_yearbook',
#        'population_electricity_coverage', 'elect_supply_quality',
#        'sustainability_index', 'elect_dist_grid_map', 'mobile_density',
#        'e_government_index', 'spectrum_allocated_mobile_providers',
#        'countries_ixp', 'speedtest-global-performance.yaml',
#        'internet_speed', 'mobile_latency', 'mobile_speed',
#        'individual_internet_usage', 'mobile_cell_sub',
#        'fixed_bdbd_spd_dl_ul',
#        'fixed_broadband_speed_download_upload_latency', 'postal_coverage',
#        'World Bank The Logistics Performance Index 2007 to 2018.xlsx',
#        'schools_w_internet', 'national_cybersecurity_index',
#        'dice_export_global_cybersecurity_index',
#        'software_developer_ecosystem_size',
#        'digital_platform_economy_index', 'migration_skill',
#        'migration_industry', 'migration_country',
#        'global_fintech_ranking', 'tech_hubs', 'banking_sector_size',
#        'angel_investment', 'startup_eco_size',
#        'international_co_inventions'], dtype=object)

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %%
### 2. Broadband Density

# %%
indicators[1]

# load data
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Broadband Density
# fixed_broadband_density
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-72afceee5c73> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/fixed_broadband_density.csv'

# %%
### 3. % of population covered by internet connectivity

# %%
indicators[2]

# load data
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by internet connectivity
# population_access_internet
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-91c83eedb488> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/population_access_internet.csv'

# %%
### 4. % of population covered by mobile 2G

# %%
indicators[3]

# %%
# load data
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 5. % of population covered by mobile 3G

# %%
indicators[4]

# load data
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['3G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 6. % of population covered by mobile 4G

# %%
indicators[5]

# load data
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['4G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 7. % of population covered by mobile 5G

# %%
indicators[6]

# load data
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['5G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 8. Mobile Coverage Maps

# %%
indicators[7]

# load data
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Mobile Coverage Maps
# mobile_coverage

# %%
df.head(15)
# Out:
#     1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  \
# 0    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 1    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 2    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 3    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 4    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 5    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 6    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 7    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 10   0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 11   0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 12   0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 13   0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# 14   0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
#
#           2015        2016        2017        2018        2019  2020  \
# 0   135.133840         NaN         NaN         NaN         NaN   NaN
# 1    67.993504   64.963156   64.881587   72.931734   78.463447   NaN
# 2    57.271068   61.054638   65.929134   59.120848   59.356020   NaN
# 3    86.707693   86.325387   84.672561   94.218808   97.841583   NaN
# 4    49.793223   45.076290   44.686107   43.130519   46.598638   NaN
# 5   117.659218  116.744444  125.710352   94.176998   91.293015   NaN
# 6    91.443514   98.492826  104.332411  107.282549  113.957377   NaN
# 7   105.734882  103.190799  101.030747   99.486473  105.181707   NaN
# 8   193.703484  212.638986  208.978600  208.504833  200.632074   NaN
# 9   143.566834  146.453828  140.877124  132.093151  125.842106   NaN
# 10  118.421714  116.975467  118.464231  121.259018  122.348753   NaN
# 11         NaN         NaN         NaN         NaN         NaN   NaN
# 12  188.102516  190.421784  192.819567         NaN         NaN   NaN
# 13  107.677835  109.431295  108.441782  111.012255  110.620882   NaN
# 14  155.215471  126.661470  123.119296  123.535268  119.775297   NaN
#
#                    Country Name  Country Code  \
# 0                         Aruba           ABW
# 1   Africa Eastern and Southern           AFE
# 2                   Afghanistan           AFG
# 3    Africa Western and Central           AFW
# 4                        Angola           AGO
# 5                       Albania           ALB
# 6                       Andorra           AND
# 7                    Arab World           ARB
# 8          United Arab Emirates           ARE
# 9                     Argentina           ARG
# 10                      Armenia           ARM
# 11               American Samoa           ASM
# 12          Antigua and Barbuda           ATG
# 13                    Australia           AUS
# 14                      Austria           AUT
#
#                                     Indicator Name  Indicator Code
# 0   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 1   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 2   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 3   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 4   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 5   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 6   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 7   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 8   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 9   Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 10  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 11  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 12  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 13  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
# 14  Mobile cellular subscriptions (per 100 people)  IT.CEL.SETS.P2
#
# [15 rows x 65 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2019'] 
df['Year'] = 2019

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                    Country Name  Year             Indicator    data_col  \
# 0                         Aruba  2019  Mobile Coverage Maps         NaN
# 1   Africa Eastern and Southern  2019  Mobile Coverage Maps   78.463447
# 2                   Afghanistan  2019  Mobile Coverage Maps   59.356020
# 3    Africa Western and Central  2019  Mobile Coverage Maps   97.841583
# 4                        Angola  2019  Mobile Coverage Maps   46.598638
# 5                       Albania  2019  Mobile Coverage Maps   91.293015
# 6                       Andorra  2019  Mobile Coverage Maps  113.957377
# 7                    Arab World  2019  Mobile Coverage Maps  105.181707
# 8          United Arab Emirates  2019  Mobile Coverage Maps  200.632074
# 9                     Argentina  2019  Mobile Coverage Maps  125.842106
# 10                      Armenia  2019  Mobile Coverage Maps  122.348753
# 11               American Samoa  2019  Mobile Coverage Maps         NaN
# 12          Antigua and Barbuda  2019  Mobile Coverage Maps         NaN
# 13                    Australia  2019  Mobile Coverage Maps  110.620882
# 14                      Austria  2019  Mobile Coverage Maps  119.775297
#
#     new_rank_score  higher_is_better
# 0              NaN              True
# 1         2.087315              True
# 2         1.731426              True
# 3         2.448246              True
# 4         1.493811              True
# 5         2.326275              True
# 6         2.748414              True
# 7         2.584961              True
# 8         4.362790              True
# 9         2.969775              True
# 10        2.904709              True
# 11             NaN              True
# 12             NaN              True
# 13        2.686269              True
# 14        2.856777              True

# %%
### 9. Electricity Density

# %%
indicators[8]

# load data
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2017'] 
df['Country'] = df['Unnamed: 28']
df['Year'] = 2017

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 10. % of population covered by electricity

# %%
indicators[9]

# load data
indicator = indicators[9]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by electricity
# population_electricity_coverage
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-98704f74efaf> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/population_electricity_coverage.csv'

# %%
### 11. % of population covered by electricity

# %%
indicators[10]

# load data
indicator = indicators[10]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electricity supply quality
# elect_supply_quality

# %%
df.head(10)
# Out:
#          Unnamed: 0                                                AGO  \
# 0         Attribute                                             Angola
# 1             VALUE                                                NaN
# 2              RANK                                                136
# 3             SCORE                                        38.11248593
# 4  DATE DESCRIPTION                                       2019 edition
# 5            SOURCE  World Economic Forum, [i]Global Competitivenes...
# 6       SOURCE DATE                                                NaN
# 7              NOTE  See Appendix A of the Global Competitiveness R...
# 8             VALUE                                                NaN
# 9              RANK                                                136
#
#                                                  ALB  \
# 0                                            Albania
# 1                                                NaN
# 2                                                 81
# 3                                        57.61416881
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 88
#
#                                                  ARE  \
# 0                               United Arab Emirates
# 1                                                NaN
# 2                                                 25
# 3                                        75.00738794
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                  3
#
#                                                  ARG  \
# 0                                          Argentina
# 1                                                NaN
# 2                                                 83
# 3                                        57.20132859
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                109
#
#                                                  ARM  \
# 0                                            Armenia
# 1                                                NaN
# 2                                                 69
# 3                                        61.27687643
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 62
#
#                                                  AUS  \
# 0                                          Australia
# 1                                                NaN
# 2                                                 16
# 3                                        78.74662637
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 22
#
#                                                  AUT  \
# 0                                            Austria
# 1                                                NaN
# 2                                                 21
# 3                                        76.60913087
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 20
#
#                                                  AZE  \
# 0                                         Azerbaijan
# 1                                                NaN
# 2                                                 58
# 3                                        62.71789348
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                 64
#
#                                                  BDI  ...  \
# 0                                            Burundi  ...
# 1                                                NaN  ...
# 2                                                135  ...
# 3                                        40.25234131  ...
# 4                                       2019 edition  ...
# 5  World Economic Forum, [i]Global Competitivenes...  ...
# 6                                                NaN  ...
# 7  See Appendix A of the Global Competitiveness R...  ...
# 8                                                NaN  ...
# 9                                                134  ...
#
#                                           GCREURASIA  \
# 0                                            Eurasia
# 1                                                NaN
# 2                                                NaN
# 3                                        59.37969533
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                               GCREAP  \
# 0                              East Asia and Pacific
# 1                                                NaN
# 2                                                NaN
# 3                                        69.86862667
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                             GCRSASIA  \
# 0                                         South Asia
# 1                                                NaN
# 2                                                NaN
# 3                                        54.70460508
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  LIC  \
# 0                                         Low-income
# 1                                                NaN
# 2                                                NaN
# 3                                         43.7445505
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  LMC  \
# 0                                Lower-middle-income
# 1                                                NaN
# 2                                                NaN
# 3                                        51.94942309
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  UMC  \
# 0                                Upper-middle-income
# 1                                                NaN
# 2                                                NaN
# 3                                         59.7912297
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  HIC  \
# 0                                        High-income
# 1                                                NaN
# 2                                                NaN
# 3                                        72.78080961
# 4                                       2019 edition
# 5  World Economic Forum, [i]Global Competitivenes...
# 6                                                NaN
# 7  See Appendix A of the Global Competitiveness R...
# 8                                                NaN
# 9                                                NaN
#
#                                                  AVG      data_country  \
# 0                                     Sample average         Attribute
# 1                                                NaN             VALUE
# 2                                                  0              RANK
# 3                                         60.6396938             SCORE
# 4                                       2019 edition  DATE DESCRIPTION
# 5  World Economic Forum, [i]Global Competitivenes...            SOURCE
# 6                                                NaN       SOURCE DATE
# 7  See Appendix A of the Global Competitiveness R...              NOTE
# 8                                                NaN             VALUE
# 9                                                  0              RANK
#
#           data_year
# 0         Attribute
# 1             VALUE
# 2              RANK
# 3             SCORE
# 4  DATE DESCRIPTION
# 5            SOURCE
# 6       SOURCE DATE
# 7              NOTE
# 8             VALUE
# 9              RANK
#
# [10 rows x 156 columns]

# %%
# The data needs to be transposed as countries are now in columns, not rows, which could present problems for later.

# %%
### 12. Electricity Environmental Sustainability

# %%
indicators[11]

# load data
indicator = indicators[11]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electricity Environmental Sustainability
# sustainability_index

# %%
df.head(15)
# Out:
#    Country Code ISO3               Country  2021 SDG Index Score  \
# 0                AFG           Afghanistan                  53.9
# 1                AGO                Angola                  50.3
# 2                ALB               Albania                  71.0
# 3                AND               Andorra                   NaN
# 4                ARE  United Arab Emirates                  70.2
# 5                ARG             Argentina                  72.8
# 6                ARM               Armenia                  71.8
# 7                ATG   Antigua and Barbuda                   NaN
# 8                AUS             Australia                  75.6
# 9                AUT               Austria                  82.1
# 10               AZE            Azerbaijan                  72.4
# 11               BDI               Burundi                  51.8
# 12               BEL               Belgium                  82.2
# 13               BEN                 Benin                  49.9
# 14               BFA          Burkina Faso                  53.5
#
#     2021 SDG Index Rank  Percentage missing values  Spillover Score (0-100)  \
# 0                 137.0                        9.3                     99.3
# 1                 154.0                        0.0                     97.0
# 2                  64.0                        3.3                     94.3
# 3                   NaN                       51.2                      NaN
# 4                  71.0                       11.0                     38.8
# 5                  52.0                        1.1                     94.5
# 6                  58.0                        3.5                     96.7
# 7                   NaN                       30.8                      NaN
# 8                  35.0                        1.1                     63.9
# 9                   6.0                        3.5                     59.5
# 10                 55.0                        7.0                     97.6
# 11                147.0                        7.0                     99.8
# 12                  5.0                        4.4                     62.0
# 13                155.0                        4.4                     98.8
# 14                139.0                        1.2                     99.4
#
#     Regional Score (0-100) Regions used for the SDR  Population in 2020   \
# 0                     71.4      E. Europe & C. Asia          38,928,341
# 1                     51.9                   Africa          32,866,268
# 2                     71.4      E. Europe & C. Asia           2,877,800
# 3                     71.4      E. Europe & C. Asia              77,265
# 4                     67.1                     MENA           9,890,400
# 5                     68.6                      LAC          45,195,777
# 6                     71.4      E. Europe & C. Asia           2,963,234
# 7                     68.6                      LAC              97,928
# 8                     77.2                     OECD          25,499,881
# 9                     77.2                     OECD           9,006,400
# 10                    71.4      E. Europe & C. Asia          10,139,175
# 11                    51.9                   Africa          11,890,781
# 12                    77.2                     OECD          11,589,616
# 13                    51.9                   Africa          12,123,198
# 14                    51.9                   Africa          20,903,278
#
#    Goal 1 Dash  ... Goal 10 Regional Score Goal 11 Regional Score  \
# 0         grey  ...              72.362762              76.443228
# 1          red  ...              37.334205              52.728915
# 2       yellow  ...              72.362762              76.443228
# 3         grey  ...                    NaN                    NaN
# 4        green  ...              66.178091              58.928271
# 5       yellow  ...              27.901676              77.087594
# 6       yellow  ...              72.362762              76.443228
# 7         grey  ...                    NaN                    NaN
# 8       yellow  ...              74.475203              88.911367
# 9        green  ...              74.475203              88.911367
# 10       green  ...              72.362762              76.443228
# 11         red  ...              37.334205              52.728915
# 12       green  ...              74.475203              88.911367
# 13         red  ...              37.334205              52.728915
# 14         red  ...              37.334205              52.728915
#
#    Goal 12 Regional Score Goal 13 Regional Score Goal 14 Regional Score  \
# 0               77.629345              83.041913              58.865821
# 1               88.024702              96.266527              68.010492
# 2               77.629345              83.041913              58.865821
# 3                     NaN                    NaN                    NaN
# 4               76.842146              71.475510              62.776615
# 5               76.727283              85.373283              62.781114
# 6               77.629345              83.041913              58.865821
# 7                     NaN                    NaN                    NaN
# 8               58.055279              64.112721              63.360546
# 9               58.055279              64.112721              63.360546
# 10              77.629345              83.041913              58.865821
# 11              88.024702              96.266527              68.010492
# 12              58.055279              64.112721              63.360546
# 13              88.024702              96.266527              68.010492
# 14              88.024702              96.266527              68.010492
#
#    Goal 15 Regional Score Goal 16 Regional Score Goal 17 Regional Score  \
# 0               69.499564              72.403938              63.386460
# 1               66.835003              56.050983              51.652955
# 2               69.499564              72.403938              63.386460
# 3                     NaN                    NaN                    NaN
# 4               57.356212              69.093831              56.231255
# 5               60.904217              60.888934              64.295156
# 6               69.499564              72.403938              63.386460
# 7                     NaN                    NaN                    NaN
# 8               74.102776              82.316815              65.773824
# 9               74.102776              82.316815              65.773824
# 10              69.499564              72.403938              63.386460
# 11              66.835003              56.050983              51.652955
# 12              74.102776              82.316815              65.773824
# 13              66.835003              56.050983              51.652955
# 14              66.835003              56.050983              51.652955
#
#    data_country data_year
# 0           NaN       NaN
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10          NaN       NaN
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14          NaN       NaN
#
# [15 rows x 651 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2021 SDG Index Score'] 
df['Country Name'] = df['Country']
df['Year'] = 2021

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year                                 Indicator  \
# 0            Afghanistan  2021  Electricity Environmental Sustainability
# 1                 Angola  2021  Electricity Environmental Sustainability
# 2                Albania  2021  Electricity Environmental Sustainability
# 3                Andorra  2021  Electricity Environmental Sustainability
# 4   United Arab Emirates  2021  Electricity Environmental Sustainability
# 5              Argentina  2021  Electricity Environmental Sustainability
# 6                Armenia  2021  Electricity Environmental Sustainability
# 7    Antigua and Barbuda  2021  Electricity Environmental Sustainability
# 8              Australia  2021  Electricity Environmental Sustainability
# 9                Austria  2021  Electricity Environmental Sustainability
# 10            Azerbaijan  2021  Electricity Environmental Sustainability
# 11               Burundi  2021  Electricity Environmental Sustainability
# 12               Belgium  2021  Electricity Environmental Sustainability
# 13                 Benin  2021  Electricity Environmental Sustainability
# 14          Burkina Faso  2021  Electricity Environmental Sustainability
#
#     data_col  new_rank_score  higher_is_better
# 0       53.9        2.638655              True
# 1       50.3        2.260504              True
# 2       71.0        4.434874              True
# 3        NaN             NaN              True
# 4       70.2        4.350840              True
# 5       72.8        4.623950              True
# 6       71.8        4.518908              True
# 7        NaN             NaN              True
# 8       75.6        4.918067              True
# 9       82.1        5.600840              True
# 10      72.4        4.581933              True
# 11      51.8        2.418067              True
# 12      82.2        5.611345              True
# 13      49.9        2.218487              True
# 14      53.5        2.596639              True

# %%
### 13. Electrical Distribution Grid Maps

# %%
indicators[12]

# load data
indicator = indicators[12]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electrical Distribution Grid Maps
# elect_dist_grid_map

# %%
df.head(10)
#No country names in the data file
# Out:
#         lat       lon  Electrical Distribution Grid
# 0  6.550017 -8.475952                             1
# 1  6.604587 -8.475952                             1
# 2  6.539103 -8.475952                             1
# 3  6.593674 -8.475952                             1
# 4  6.560932 -8.442993                             1
# 5  6.593674 -8.442993                             1
# 6  6.550017 -8.442993                             1
# 7  6.550017 -8.453979                             1
# 8  6.604587 -8.453979                             1
# 9  6.593674 -8.453979                             1

# %%
### 14. Cellphone Signal Density

# %%
indicators[13]

# load data
indicator = indicators[13]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Network coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 15. Telecommunication Infrastructure Index (TII)

# %%
indicators[14]

# load data
indicator = indicators[14]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Telecommunication Infrastructure Index'] 
df['Year'] = df['Survey Year']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

df.rename(columns={'Country Name':'Country'}, inplace=True)

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 16. GSMA Mobile Connectivity Index

# %%
indicators[15]

# load data
indicator = indicators[15]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Index'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 17. Spectrum Allocated to Mobile Providers

# %%
indicators[16]

# load data
indicator = indicators[16]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Spectrum'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 18. Internet Exchange Points (IXPs)

# %%
indicators[17]

# load data
indicator = indicators[17]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
agg_df = df.groupby('Country')['Country'].count()
agg_df

# %%
count = df['Country'].value_counts()

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Spectrum'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
### 19. ISP Speeds - Fixed

# %%
indicators[18]

# load data
indicator = indicators[18]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Convert yaml to csv

# %%
df.head(15)

# %%
### 20. SP Speeds - Mobile

# %%
# May also have to convert yaml to csv

# %%
### 21. ISP internet download speed average

# %%
indicators[20]

# load data
indicator = indicators[20]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Waiting for internet_speed to be added to the processed folder

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Download speed (Mbps)'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 22. Mobile dowload speed at the slowest hour

# %%
indicators[21]

# load data
indicator = indicators[21]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Waiting for internet_speed to be added to the processed folder

# %%
df.head(15)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Mobile latencies'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 23. Mobile download speed average

# %%
indicators[22]

# load data
indicator = indicators[22]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Mbps'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 24. Individuals using the Internet (% of population)

# %%
indicators[23]

# load data
indicator = indicators[23]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2017
df['Indicator'] = indicator
df['data_col'] = df['2017_value'] 
df.rename(columns = {'ShortName':'Country'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
#2019 data is missing too much, switching to 2017

# %%
### 25. Mobile cellular subscriptions (per 100 people)

# %%
indicators[24]

# load data
indicator = indicators[24]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

#Waiting for mobile_cell_sub to be added to processed folder
# Out:
# Mobile cellular subscriptions (per 100 people)
# mobile_cell_sub
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-d66169a8cbf8> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#      10
#      11 #Waiting for mobile_cell_sub to be added to processed folder
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/mobile_cell_sub.csv'

# %%
### 26. Average fixed broadband download speeds

# %%
indicators[25]

# load data
indicator = indicators[25]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df['broadband'] 
df.rename(columns = {'country':'Country'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 27. Average fixed broadband upload speeds
# Must convert yaml to csv

# %%
### 28. Average fixed broadband latency
# Must convert yaml to csv

# %%
### 29. Postal Coverage

# %%
indicators[28]

# load data
indicator = indicators[28]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
#Choose 'Percent of Population Having Mail Delivered at Home' as the data column
df = df[(df.Indicator=='Percent of Population Having Mail Delivered at Home')]
df.head(15)

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2015
df['Indicator'] = indicator
df['data_col'] = df['2015'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 30. Logistics Performance Index (LPI)

# %%
indicators[29]

# load data
indicator = indicators[29]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
### 31.Schools with Internet proportion

# %%
indicators[30]

# load data
indicator = indicators[30]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
### 32.National cyber security index

# %%
indicators[31]

# load data
indicator = indicators[31]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df['National Cyber Security Index'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 33. Global Cybersecurity Index (GCI)

# %%
indicators[32]

# load data
indicator = indicators[32]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)
#The Data is practically unusable, find a new one

# %%
### 34. Software Developer Ecosystem size

# %%
indicators[33]

# load data
indicator = indicators[33]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2018
df['Indicator'] = indicator
df['data_col'] = df['GitHub Accounts']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

#There is a small error in the column name this has been addressed, waiting for files to be updated

# %%
### 35. Digital Work Ecosystem size

# %%
indicators[34]

# load data
indicator = indicators[34]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = False
df['Year'] = 2020
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,[0]].astype(float)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# invert since to lower rank is better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Two problems: 1. cannot use the name of the column, have to use iloc, 2. cannot use the index column
# because the number format is not standard, have to use the rank column

# %%
### 36. Country, Industry, Skill Migration Data (Skill)

# %%
indicators[35]

# load data
indicator = indicators[35]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['Country'] = df.iloc[:,[1]]

df_sum = df.groupby('Country')[['net_per_10K_2019']].sum()
df_sum

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 37. Country, Industry, Skill Migration Data (Industry)

# %%
indicators[36]

# load data
indicator = indicators[36]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['Country'] = df.iloc[:,[1]]

df_sum = df.groupby('Country')[['net_per_10K_2019']].sum()
df_sum

# %%
## create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 38. Country, Industry, Skill Migration Data (Nation)

# %%
indicators[37]

# load data
indicator = indicators[37]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['Country'] = df.iloc[:,[1]]

df_sum = df.groupby('Country')[['net_per_10K_2019']].sum()
df_sum

# %%
## create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 39. Digital Finance Ecosystem size

# %%
indicators[38]

# load data
indicator = indicators[38]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Digital Finance Ecosystem size
# global_fintech_ranking

# %%
df.head(15)
# Out:
#     Rank          Country   Total Score (2021)
# 0      1    United States               31.789
# 1      2   United Kingdom               23.262
# 2      3        Singapore               19.176
# 3      4        Lithuania               17.343
# 4      5      Switzerland               16.018
# 5      6  The Netherlands               14.464
# 6      7           Sweden               14.272
# 7      8        Australia               13.555
# 8      9           Canada               13.322
# 9     10          Estonia               13.303
# 10    11          Germany               12.787
# 11    12           Israel               12.771
# 12    13            Spain               12.372
# 13    14          Finland               12.110
# 14    15            India               12.024

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,[2]]
df['Country Name'] = df.iloc[:,[1]]

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# Have to shorten the column names to see if this works

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#         Country Name  Year                       Indicator  data_col  \
# 0     United States   2021  Digital Finance Ecosystem size    31.789
# 1    United Kingdom   2021  Digital Finance Ecosystem size    23.262
# 2         Singapore   2021  Digital Finance Ecosystem size    19.176
# 3         Lithuania   2021  Digital Finance Ecosystem size    17.343
# 4       Switzerland   2021  Digital Finance Ecosystem size    16.018
# 5   The Netherlands   2021  Digital Finance Ecosystem size    14.464
# 6            Sweden   2021  Digital Finance Ecosystem size    14.272
# 7         Australia   2021  Digital Finance Ecosystem size    13.555
# 8            Canada   2021  Digital Finance Ecosystem size    13.322
# 9           Estonia   2021  Digital Finance Ecosystem size    13.303
# 10          Germany   2021  Digital Finance Ecosystem size    12.787
# 11           Israel   2021  Digital Finance Ecosystem size    12.771
# 12            Spain   2021  Digital Finance Ecosystem size    12.372
# 13          Finland   2021  Digital Finance Ecosystem size    12.110
# 14            India   2021  Digital Finance Ecosystem size    12.024
#
#     new_rank_score  higher_is_better
# 0         6.000000              True
# 1         4.469010              True
# 2         3.735385              True
# 3         3.406277              True
# 4         3.168378              True
# 5         2.889364              True
# 6         2.854891              True
# 7         2.726156              True
# 8         2.684322              True
# 9         2.680911              True
# 10        2.588265              True
# 11        2.585392              True
# 12        2.513753              True
# 13        2.466712              True
# 14        2.451271              True

# %%
### 40. Tech hubs & spaces size

# %%
indicators[39]

# load data
indicator = indicators[39]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

#There are two problems:
#1. The column names need some overhaul (moving the second column to the top and make it the column names)
#2. This is a list of cities, not countries, may present probkems later.

# %%
### 41. Banking Ecosystem size

# %%
indicators[40]

# load data
indicator = indicators[40]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2017
df['Indicator'] = indicator
df['data_col'] = df['Bank assets, percent of GDP, 2017']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but will have to remove number from the Country column, leaving only characters.

# %%
### 42. Angel Ecosystem size

# %%
indicators[41]

# load data
indicator = indicators[41]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Angel Ecosystem size
# angel_investment

# %%
df.head(15)
# Out:
#            Country  Business angel investments (in million Euros)
# 0   United Kingdom                                         153.08
# 1          Germany                                          81.77
# 2            Spain                                          78.66
# 3          Finland                                          54.00
# 4           Sweden                                          44.08
# 5           France                                          43.00
# 6          Denmark                                          33.34
# 7      Switzerland                                          32.60
# 8            Italy                                          28.20
# 9           Russia                                          26.08
# 10          Turkey                                          21.26
# 11         Austria                                          20.11
# 12     Netherlands                                          19.38
# 13         Belgium                                          17.09
# 14         Ireland                                          16.80

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2019
df['Indicator'] = indicator
df['data_col'] = df['Business angel investments (in million Euros)']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but there are only EU countries
# Out:
#            Country  Year             Indicator  data_col  new_rank_score  \
# 0   United Kingdom  2019  Angel Ecosystem size    153.08        6.000000
# 1          Germany  2019  Angel Ecosystem size     81.77        3.666099
# 2            Spain  2019  Angel Ecosystem size     78.66        3.564312
# 3          Finland  2019  Angel Ecosystem size     54.00        2.757217
# 4           Sweden  2019  Angel Ecosystem size     44.08        2.432546
# 5           France  2019  Angel Ecosystem size     43.00        2.397198
# 6          Denmark  2019  Angel Ecosystem size     33.34        2.081037
# 7      Switzerland  2019  Angel Ecosystem size     32.60        2.056817
# 8            Italy  2019  Angel Ecosystem size     28.20        1.912810
# 9           Russia  2019  Angel Ecosystem size     26.08        1.843425
# 10          Turkey  2019  Angel Ecosystem size     21.26        1.685671
# 11         Austria  2019  Angel Ecosystem size     20.11        1.648033
# 12     Netherlands  2019  Angel Ecosystem size     19.38        1.624141
# 13         Belgium  2019  Angel Ecosystem size     17.09        1.549192
# 14         Ireland  2019  Angel Ecosystem size     16.80        1.539700
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True

# %%
### 43. Startup Ecosystem size

# %%
indicators[42]

# load data
indicator = indicators[42]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# This is a list of cities, not countries, wonder if it will work

# %%
### 44. Venture Ecosystem size

# Similar to the previous one

# %%
### 45. International Co-Inventions

# %%
indicators[44]

# load data
indicator = indicators[44]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year and global value
df = df[(df.Time==2017)]
df = df[(df.Country!='World')]
df

# %%
# Create summarization
df_sum = df.groupby('Country')[['Value']].sum()
df_sum

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2017
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum.iloc[:,[0]]

min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but the data is too general with many missing countries
