# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Data Link','Index','Filename','Sub-Pillar']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#                                  Data Source  \
# 0  UN Statistics Division: List of Countries
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4   World Bank: World Development Indicators
#
#                            Data Link  Index            Filename  \
# 0             https://unstats.un.org  False           Countries
# 1                   https://gadm.org  False                 NaN
# 2                                NaN  False                 NaN
# 3                                NaN  False                 NaN
# 4  https://datacatalog.worldbank.org  False  population_density
#
#                 Sub-Pillar
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4  Connectivity Technology

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              18         27
# Foundations           14         22
# Government            10         15
# Infrastructure        47         58
# People                35         49
# Regulation             5          8
# Strategy               1          1

# %% [markdown]
# ### Foundations

# %%
bnames = names[(names.check=='Foundations')&(~names.Filename.isna())]#&(names.Index==False)]

# %%
bnames.head(25)
# Out:
#                                              Indicator        check  \
# 163                       Digital payments penetration  Foundations
# 164       % of population with digital finance account  Foundations
# 165  Made or received digital payments in the past ...  Foundations
# 166  Made or received digital payments in the past ...  Foundations
# 169  Used a mobile phone or the internet to check a...  Foundations
# 170  Used a mobile phone or the internet to check a...  Foundations
# 171                 % Making online transactions - Men  Foundations
# 172               % Making online transactions - Women  Foundations
# 173  % of population with digital finance account -...  Foundations
# 178                      % of population with ID (all)  Foundations
# 179                   % of population with ID (female)  Foundations
# 181                    can ID be used for transactions  Foundations
# 182                            Is personal data siloed  Foundations
# 183                                    Open data index  Foundations
#
#                                            Data Source  \
# 163      Portulans Institute: Network Readiness Index
# 164                 World Bank: Global Findex database
# 165                 World Bank: Global Findex database
# 166                 World Bank: Global Findex database
# 169                 World Bank: Global Findex database
# 170                 World Bank: Global Findex database
# 171                 World Bank: Global Findex database
# 172                 World Bank: Global Findex database
# 173                 World Bank: Global Findex database
# 178  World Bank: Identification For Development (ID4D)
# 179  World Bank: Identification For Development (ID4D)
# 181  World Bank: Identification For Development (ID4D)
# 182                        World Bank: GovTech Dataset
# 183  Open Knowledge Foundation: Global Open Data Index
#
#                              Data Link  Index  \
# 163  https://networkreadinessindex.org  TRUE
# 164  https://datacatalog.worldbank.org  False
# 165  https://datacatalog.worldbank.org  False
# 166  https://datacatalog.worldbank.org  False
# 169  https://datacatalog.worldbank.org  False
# 170  https://datacatalog.worldbank.org  False
# 171  https://datacatalog.worldbank.org  False
# 172  https://datacatalog.worldbank.org  False
# 173  https://datacatalog.worldbank.org  False
# 178  https://datacatalog.worldbank.org  False
# 179  https://datacatalog.worldbank.org  False
# 181  https://datacatalog.worldbank.org  False
# 182  https://datacatalog.worldbank.org  TRUE
# 183             https://index.okfn.org   True
#
#                                   Filename              Sub-Pillar
# 163           digital_payments_penetration        Digital Payments
# 164  population_digital_financial_services        Digital Payments
# 165  population_digital_financial_services        Digital Payments
# 166  population_digital_financial_services        Digital Payments
# 169  population_digital_financial_services        Digital Payments
# 170  population_digital_financial_services        Digital Payments
# 171  population_digital_financial_services        Digital Payments
# 172  population_digital_financial_services        Digital Payments
# 173  population_digital_financial_services        Digital Payments
# 178                               id4d_nid  Digital Legal Identity
# 179                               id4d_nid  Digital Legal Identity
# 181                          id4d_services  Digital Legal Identity
# 182                          Egov_strategy  Digital Legal Identity
# 183                          open_data_idx           Data Exchange

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()
subpillars = bnames['Sub-Pillar'].unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['digital_payments_penetration',
#        'population_digital_financial_services', 'id4d_nid',
#        'id4d_services', 'Egov_strategy', 'open_data_idx'], dtype=object)

# %%
subpillars
# Out:
# array(['Digital Payments', 'Digital Legal Identity', 'Data Exchange'],
#       dtype=object)

# %%
# ls digital-readiness-assessment-main/processed/

# %%
##ict_goods and services not in process data

# %%
# formula for converting scale 0-100
def convert_rank(old_value, old_min=0, old_max=100, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %% [markdown]
# ### 1. Digital payments penetration

# %%
indicators[0]
subpillars[0]
# Out:
# 'Digital Payments'

# %%
# load data
indicator = indicators[0]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillar = subpillars[0]
print(subpillar)
# Out:
# Digital payments penetration
# digital_payments_penetration
# Digital Payments

# %%
df.head()
# Out:
#    RANK COUNTRY/ECONOMY  VALUE   SCORE
# 0   1.0          Norway   0.85  100.00
# 1   2.0         Denmark   0.83   97.24
# 2   3.0         Finland   0.80   93.95
# 3   4.0          Sweden   0.80   93.08
# 4   5.0     Netherlands   0.76   89.01

# %%
# score looks like the one to use
df.describe()
# Out:
#              RANK       VALUE       SCORE
# count  122.000000  122.000000  122.000000
# mean    61.500000    0.315738   36.076967
# std     35.362409    0.209012   24.867406
# min      1.000000    0.010000    0.000000
# 25%     31.250000    0.150000   16.235000
# 50%     61.500000    0.270000   30.870000
# 75%     91.750000    0.440000   51.110000
# max    122.000000    0.850000  100.000000

# %%
# df.Indicator.unique()

# %%
# create standard columns
df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['SCORE'] 
df['Sub-Pillar'] = subpillar
df['Year'] = 2017


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-100 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']].head(15)

# %%
# output scores to csv
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 2. % of population with digital finance account - registered

# %%
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# % of population with digital finance account
# population_digital_financial_services
# Digital Payments

# %%
df.head(15)
# Out:
#     Year  ISO          Country Name  \
# 0   2011  AFG           Afghanistan
# 1   2014  AFG           Afghanistan
# 2   2017  AFG           Afghanistan
# 3   2011  AGO                Angola
# 4   2014  AGO                Angola
# 5   2011  ALB               Albania
# 6   2014  ALB               Albania
# 7   2017  ALB               Albania
# 8   2011  ARB            Arab world
# 9   2014  ARB            Arab world
# 10  2017  ARB            Arab world
# 11  2011  ARE  United Arab Emirates
# 12  2014  ARE  United Arab Emirates
# 13  2017  ARE  United Arab Emirates
# 14  2011  ARG             Argentina
#
#                                                Region         Income Group  \
# 0                                          South Asia           Low income
# 1                                          South Asia           Low income
# 2                                          South Asia           Low income
# 3          Sub-Saharan Africa (excluding high income)  Lower middle income
# 4          Sub-Saharan Africa (excluding high income)  Lower middle income
# 5       Europe & Central Asia (excluding high income)  Upper middle income
# 6       Europe & Central Asia (excluding high income)  Upper middle income
# 7       Europe & Central Asia (excluding high income)  Upper middle income
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11                                        High income          High income
# 12                                        High income          High income
# 13                                        High income          High income
# 14  Latin America & Caribbean (excluding high income)  Upper middle income
#
#    Account (% age 15+) Account, male (% age 15+)  \
# 0                   9%                       15%
# 1                  10%                       16%
# 2                  15%                       23%
# 3                  39%                       39%
# 4                  29%                       36%
# 5                  28%                       34%
# 6                  38%                       43%
# 7                  40%                       42%
# 8                  22%                       30%
# 9                  30%                       38%
# 10                 37%                       48%
# 11                 60%                       69%
# 12                 84%                       90%
# 13                 88%                       93%
# 14                 33%                       35%
#
#    Account, in labor force (% age 15+)   \
# 0                                   15%
# 1                                   15%
# 2                                   25%
# 3                                   46%
# 4                                   36%
# 5                                   36%
# 6                                   44%
# 7                                   53%
# 8                                   33%
# 9                                   42%
# 10                                  51%
# 11                                  80%
# 12                                  91%
# 13                                  93%
# 14                                  37%
#
#    Account, out of labor force (% age 15+)  Account, female (% age 15+)  ...  \
# 0                                        2%                          3%  ...
# 1                                        4%                          4%  ...
# 2                                        4%                          7%  ...
# 3                                       31%                         39%  ...
# 4                                       12%                         22%  ...
# 5                                       15%                         23%  ...
# 6                                       29%                         34%  ...
# 7                                       27%                         38%  ...
# 8                                       11%                         14%  ...
# 9                                       18%                         22%  ...
# 10                                      24%                         26%  ...
# 11                                      24%                         47%  ...
# 12                                      49%                         68%  ...
# 13                                      57%                         76%  ...
# 14                                      28%                         32%  ...
#
#    Mobile money account, female (% age 15+)   \
# 0                                        NaN
# 1                                         0%
# 2                                         1%
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                         2%
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       10%
# 13                                       18%
# 14                                       NaN
#
#    Mobile money account, young adults  (% age 15-24)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  6%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                10%
# 13                                                10%
# 14                                                NaN
#
#    Mobile money account, older adults (% age 25+)   \
# 0                                              NaN
# 1                                               0%
# 2                                               1%
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                               1%
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             12%
# 13                                             22%
# 14                                             NaN
#
#    Mobile money account, primary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  1%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                 9%
# 14                                                NaN
#
#    Mobile money account, secondary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  2%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                12%
# 13                                                22%
# 14                                                NaN
#
#    Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  0%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                16%
# 14                                                NaN
#
#    Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                 NaN
# 1                                                  1%
# 2                                                  1%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                15%
# 13                                                25%
# 14                                                NaN
#
#    Mobile money account, rural  (% age 15+)  data_country data_year
# 0                                        NaN          NaN       NaN
# 1                                         0%          NaN       NaN
# 2                                         1%          NaN       NaN
# 3                                        NaN          NaN       NaN
# 4                                        NaN          NaN       NaN
# 5                                        NaN          NaN       NaN
# 6                                        NaN          NaN       NaN
# 7                                         2%          NaN       NaN
# 8                                        NaN          NaN       NaN
# 9                                        NaN          NaN       NaN
# 10                                       NaN          NaN       NaN
# 11                                       NaN          NaN       NaN
# 12                                       16%          NaN       NaN
# 13                                       14%          NaN       NaN
# 14                                       NaN          NaN       NaN
#
# [15 rows x 783 columns]

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Account (% age 15+)'] = df['Account (% age 15+)'].str.replace('%','')
df['Account (% age 15+)'] = df['Account (% age 15+)'].astype(float)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Account (% age 15+)'] 
df['Sub-Pillar'] = subpillar


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#              Country Name  Year                                     Indicator  \
# 2             Afghanistan  2017  % of population with digital finance account
# 7                 Albania  2017  % of population with digital finance account
# 10             Arab world  2017  % of population with digital finance account
# 13   United Arab Emirates  2017  % of population with digital finance account
# 16              Argentina  2017  % of population with digital finance account
# ..                    ...   ...                                           ...
# 479                 World  2017  % of population with digital finance account
# 482                Kosovo  2017  % of population with digital finance account
# 487          South Africa  2017  % of population with digital finance account
# 490                Zambia  2017  % of population with digital finance account
# 493              Zimbabwe  2017  % of population with digital finance account
#
#      data_col  new_rank_score  higher_is_better        Sub-Pillar
# 2        15.0        1.329670              True  Digital Payments
# 7        40.0        2.703297              True  Digital Payments
# 10       37.0        2.538462              True  Digital Payments
# 13       88.0        5.340659              True  Digital Payments
# 16       49.0        3.197802              True  Digital Payments
# ..        ...             ...               ...               ...
# 479      69.0        4.296703              True  Digital Payments
# 482      52.0        3.362637              True  Digital Payments
# 487      69.0        4.296703              True  Digital Payments
# 490      46.0        3.032967              True  Digital Payments
# 493      55.0        3.527473              True  Digital Payments
#
# [166 rows x 7 columns]

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %%
## 3. Made or received digital payments in the past year (% age 15+) - all

# %%
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# Made or received digital payments in the past year (% age 15+) - all
# population_digital_financial_services
# Digital Payments

# %%
df.head(15)
# Out:
#     Year  ISO          Country Name  \
# 0   2011  AFG           Afghanistan
# 1   2014  AFG           Afghanistan
# 2   2017  AFG           Afghanistan
# 3   2011  AGO                Angola
# 4   2014  AGO                Angola
# 5   2011  ALB               Albania
# 6   2014  ALB               Albania
# 7   2017  ALB               Albania
# 8   2011  ARB            Arab world
# 9   2014  ARB            Arab world
# 10  2017  ARB            Arab world
# 11  2011  ARE  United Arab Emirates
# 12  2014  ARE  United Arab Emirates
# 13  2017  ARE  United Arab Emirates
# 14  2011  ARG             Argentina
#
#                                                Region         Income Group  \
# 0                                          South Asia           Low income
# 1                                          South Asia           Low income
# 2                                          South Asia           Low income
# 3          Sub-Saharan Africa (excluding high income)  Lower middle income
# 4          Sub-Saharan Africa (excluding high income)  Lower middle income
# 5       Europe & Central Asia (excluding high income)  Upper middle income
# 6       Europe & Central Asia (excluding high income)  Upper middle income
# 7       Europe & Central Asia (excluding high income)  Upper middle income
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11                                        High income          High income
# 12                                        High income          High income
# 13                                        High income          High income
# 14  Latin America & Caribbean (excluding high income)  Upper middle income
#
#    Account (% age 15+) Account, male (% age 15+)  \
# 0                   9%                       15%
# 1                  10%                       16%
# 2                  15%                       23%
# 3                  39%                       39%
# 4                  29%                       36%
# 5                  28%                       34%
# 6                  38%                       43%
# 7                  40%                       42%
# 8                  22%                       30%
# 9                  30%                       38%
# 10                 37%                       48%
# 11                 60%                       69%
# 12                 84%                       90%
# 13                 88%                       93%
# 14                 33%                       35%
#
#    Account, in labor force (% age 15+)   \
# 0                                   15%
# 1                                   15%
# 2                                   25%
# 3                                   46%
# 4                                   36%
# 5                                   36%
# 6                                   44%
# 7                                   53%
# 8                                   33%
# 9                                   42%
# 10                                  51%
# 11                                  80%
# 12                                  91%
# 13                                  93%
# 14                                  37%
#
#    Account, out of labor force (% age 15+)  Account, female (% age 15+)  ...  \
# 0                                        2%                          3%  ...
# 1                                        4%                          4%  ...
# 2                                        4%                          7%  ...
# 3                                       31%                         39%  ...
# 4                                       12%                         22%  ...
# 5                                       15%                         23%  ...
# 6                                       29%                         34%  ...
# 7                                       27%                         38%  ...
# 8                                       11%                         14%  ...
# 9                                       18%                         22%  ...
# 10                                      24%                         26%  ...
# 11                                      24%                         47%  ...
# 12                                      49%                         68%  ...
# 13                                      57%                         76%  ...
# 14                                      28%                         32%  ...
#
#    Mobile money account, female (% age 15+)   \
# 0                                        NaN
# 1                                         0%
# 2                                         1%
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                         2%
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       10%
# 13                                       18%
# 14                                       NaN
#
#    Mobile money account, young adults  (% age 15-24)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  6%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                10%
# 13                                                10%
# 14                                                NaN
#
#    Mobile money account, older adults (% age 25+)   \
# 0                                              NaN
# 1                                               0%
# 2                                               1%
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                               1%
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             12%
# 13                                             22%
# 14                                             NaN
#
#    Mobile money account, primary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  1%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                 9%
# 14                                                NaN
#
#    Mobile money account, secondary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  2%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                12%
# 13                                                22%
# 14                                                NaN
#
#    Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  0%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                16%
# 14                                                NaN
#
#    Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                 NaN
# 1                                                  1%
# 2                                                  1%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                15%
# 13                                                25%
# 14                                                NaN
#
#    Mobile money account, rural  (% age 15+)  data_country data_year
# 0                                        NaN          NaN       NaN
# 1                                         0%          NaN       NaN
# 2                                         1%          NaN       NaN
# 3                                        NaN          NaN       NaN
# 4                                        NaN          NaN       NaN
# 5                                        NaN          NaN       NaN
# 6                                        NaN          NaN       NaN
# 7                                         2%          NaN       NaN
# 8                                        NaN          NaN       NaN
# 9                                        NaN          NaN       NaN
# 10                                       NaN          NaN       NaN
# 11                                       NaN          NaN       NaN
# 12                                       16%          NaN       NaN
# 13                                       14%          NaN       NaN
# 14                                       NaN          NaN       NaN
#
# [15 rows x 783 columns]

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Made or received digital payments in the past year (% age 15+)'] = df['Made or received digital payments in the past year (% age 15+)'].str.replace('%','')
df['Made or received digital payments in the past year (% age 15+)'] = df['Made or received digital payments in the past year (% age 15+)'].astype(float)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Made or received digital payments in the past year (% age 15+)'] 
df['Sub-Pillar'] = subpillar


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#              Country Name  Year  \
# 2             Afghanistan  2017
# 7                 Albania  2017
# 10             Arab world  2017
# 13   United Arab Emirates  2017
# 16              Argentina  2017
# ..                    ...   ...
# 479                 World  2017
# 482                Kosovo  2017
# 487          South Africa  2017
# 490                Zambia  2017
# 493              Zimbabwe  2017
#
#                                              Indicator  data_col  \
# 2    Made or received digital payments in the past ...      11.0
# 7    Made or received digital payments in the past ...      29.0
# 10   Made or received digital payments in the past ...      26.0
# 13   Made or received digital payments in the past ...      84.0
# 16   Made or received digital payments in the past ...      40.0
# ..                                                 ...       ...
# 479  Made or received digital payments in the past ...      52.0
# 482  Made or received digital payments in the past ...      39.0
# 487  Made or received digital payments in the past ...      60.0
# 490  Made or received digital payments in the past ...      39.0
# 493  Made or received digital payments in the past ...      53.0
#
#      new_rank_score  higher_is_better        Sub-Pillar
# 2          1.217391              True  Digital Payments
# 7          2.195652              True  Digital Payments
# 10         2.032609              True  Digital Payments
# 13         5.184783              True  Digital Payments
# 16         2.793478              True  Digital Payments
# ..              ...               ...               ...
# 479        3.445652              True  Digital Payments
# 482        2.739130              True  Digital Payments
# 487        3.880435              True  Digital Payments
# 490        2.739130              True  Digital Payments
# 493        3.500000              True  Digital Payments
#
# [166 rows x 7 columns]

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %%
## 4. Made or received digital payments in the past year (% age 15+) - female

# %%
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# Made or received digital payments in the past year (% age 15+) - female
# population_digital_financial_services
# Digital Payments

# %%
df.head(15)
# Out:
#     Year  ISO          Country Name  \
# 0   2011  AFG           Afghanistan
# 1   2014  AFG           Afghanistan
# 2   2017  AFG           Afghanistan
# 3   2011  AGO                Angola
# 4   2014  AGO                Angola
# 5   2011  ALB               Albania
# 6   2014  ALB               Albania
# 7   2017  ALB               Albania
# 8   2011  ARB            Arab world
# 9   2014  ARB            Arab world
# 10  2017  ARB            Arab world
# 11  2011  ARE  United Arab Emirates
# 12  2014  ARE  United Arab Emirates
# 13  2017  ARE  United Arab Emirates
# 14  2011  ARG             Argentina
#
#                                                Region         Income Group  \
# 0                                          South Asia           Low income
# 1                                          South Asia           Low income
# 2                                          South Asia           Low income
# 3          Sub-Saharan Africa (excluding high income)  Lower middle income
# 4          Sub-Saharan Africa (excluding high income)  Lower middle income
# 5       Europe & Central Asia (excluding high income)  Upper middle income
# 6       Europe & Central Asia (excluding high income)  Upper middle income
# 7       Europe & Central Asia (excluding high income)  Upper middle income
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11                                        High income          High income
# 12                                        High income          High income
# 13                                        High income          High income
# 14  Latin America & Caribbean (excluding high income)  Upper middle income
#
#    Account (% age 15+) Account, male (% age 15+)  \
# 0                   9%                       15%
# 1                  10%                       16%
# 2                  15%                       23%
# 3                  39%                       39%
# 4                  29%                       36%
# 5                  28%                       34%
# 6                  38%                       43%
# 7                  40%                       42%
# 8                  22%                       30%
# 9                  30%                       38%
# 10                 37%                       48%
# 11                 60%                       69%
# 12                 84%                       90%
# 13                 88%                       93%
# 14                 33%                       35%
#
#    Account, in labor force (% age 15+)   \
# 0                                   15%
# 1                                   15%
# 2                                   25%
# 3                                   46%
# 4                                   36%
# 5                                   36%
# 6                                   44%
# 7                                   53%
# 8                                   33%
# 9                                   42%
# 10                                  51%
# 11                                  80%
# 12                                  91%
# 13                                  93%
# 14                                  37%
#
#    Account, out of labor force (% age 15+)  Account, female (% age 15+)  ...  \
# 0                                        2%                          3%  ...
# 1                                        4%                          4%  ...
# 2                                        4%                          7%  ...
# 3                                       31%                         39%  ...
# 4                                       12%                         22%  ...
# 5                                       15%                         23%  ...
# 6                                       29%                         34%  ...
# 7                                       27%                         38%  ...
# 8                                       11%                         14%  ...
# 9                                       18%                         22%  ...
# 10                                      24%                         26%  ...
# 11                                      24%                         47%  ...
# 12                                      49%                         68%  ...
# 13                                      57%                         76%  ...
# 14                                      28%                         32%  ...
#
#    Mobile money account, female (% age 15+)   \
# 0                                        NaN
# 1                                         0%
# 2                                         1%
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                         2%
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       10%
# 13                                       18%
# 14                                       NaN
#
#    Mobile money account, young adults  (% age 15-24)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  6%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                10%
# 13                                                10%
# 14                                                NaN
#
#    Mobile money account, older adults (% age 25+)   \
# 0                                              NaN
# 1                                               0%
# 2                                               1%
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                               1%
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             12%
# 13                                             22%
# 14                                             NaN
#
#    Mobile money account, primary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  1%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                 9%
# 14                                                NaN
#
#    Mobile money account, secondary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  2%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                12%
# 13                                                22%
# 14                                                NaN
#
#    Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  0%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                16%
# 14                                                NaN
#
#    Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                 NaN
# 1                                                  1%
# 2                                                  1%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                15%
# 13                                                25%
# 14                                                NaN
#
#    Mobile money account, rural  (% age 15+)  data_country data_year
# 0                                        NaN          NaN       NaN
# 1                                         0%          NaN       NaN
# 2                                         1%          NaN       NaN
# 3                                        NaN          NaN       NaN
# 4                                        NaN          NaN       NaN
# 5                                        NaN          NaN       NaN
# 6                                        NaN          NaN       NaN
# 7                                         2%          NaN       NaN
# 8                                        NaN          NaN       NaN
# 9                                        NaN          NaN       NaN
# 10                                       NaN          NaN       NaN
# 11                                       NaN          NaN       NaN
# 12                                       16%          NaN       NaN
# 13                                       14%          NaN       NaN
# 14                                       NaN          NaN       NaN
#
# [15 rows x 783 columns]

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Made or received digital payments in the past year, female  (% age 15+)'] = df['Made or received digital payments in the past year, female  (% age 15+)'].str.replace('%','')
df['Made or received digital payments in the past year, female  (% age 15+)'] = df['Made or received digital payments in the past year, female  (% age 15+)'].astype(float)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Made or received digital payments in the past year, female  (% age 15+)'] 
df['Sub-Pillar'] = subpillar


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#              Country Name  Year  \
# 2             Afghanistan  2017
# 7                 Albania  2017
# 10             Arab world  2017
# 13   United Arab Emirates  2017
# 16              Argentina  2017
# ..                    ...   ...
# 479                 World  2017
# 482                Kosovo  2017
# 487          South Africa  2017
# 490                Zambia  2017
# 493              Zimbabwe  2017
#
#                                              Indicator  data_col  \
# 2    Made or received digital payments in the past ...       4.0
# 7    Made or received digital payments in the past ...      28.0
# 10   Made or received digital payments in the past ...      16.0
# 13   Made or received digital payments in the past ...      68.0
# 16   Made or received digital payments in the past ...      42.0
# ..                                                 ...       ...
# 479  Made or received digital payments in the past ...      49.0
# 482  Made or received digital payments in the past ...      29.0
# 487  Made or received digital payments in the past ...      61.0
# 490  Made or received digital payments in the past ...      35.0
# 493  Made or received digital payments in the past ...      49.0
#
#      new_rank_score  higher_is_better        Sub-Pillar
# 2          1.000000              True  Digital Payments
# 7          2.250000              True  Digital Payments
# 10         1.625000              True  Digital Payments
# 13         4.333333              True  Digital Payments
# 16         2.979167              True  Digital Payments
# ..              ...               ...               ...
# 479        3.343750              True  Digital Payments
# 482        2.302083              True  Digital Payments
# 487        3.968750              True  Digital Payments
# 490        2.614583              True  Digital Payments
# 493        3.343750              True  Digital Payments
#
# [166 rows x 7 columns]

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %%
## 5. Used a mobile phone or the internet to check account balance in the past year (% age 15+) - all

# %%
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# Used a mobile phone or the internet to check account balance in the past year (% age 15+) - all
# population_digital_financial_services
# Digital Payments

# %%
df.head(15)
# Out:
#     Year  ISO          Country Name  \
# 0   2011  AFG           Afghanistan
# 1   2014  AFG           Afghanistan
# 2   2017  AFG           Afghanistan
# 3   2011  AGO                Angola
# 4   2014  AGO                Angola
# 5   2011  ALB               Albania
# 6   2014  ALB               Albania
# 7   2017  ALB               Albania
# 8   2011  ARB            Arab world
# 9   2014  ARB            Arab world
# 10  2017  ARB            Arab world
# 11  2011  ARE  United Arab Emirates
# 12  2014  ARE  United Arab Emirates
# 13  2017  ARE  United Arab Emirates
# 14  2011  ARG             Argentina
#
#                                                Region         Income Group  \
# 0                                          South Asia           Low income
# 1                                          South Asia           Low income
# 2                                          South Asia           Low income
# 3          Sub-Saharan Africa (excluding high income)  Lower middle income
# 4          Sub-Saharan Africa (excluding high income)  Lower middle income
# 5       Europe & Central Asia (excluding high income)  Upper middle income
# 6       Europe & Central Asia (excluding high income)  Upper middle income
# 7       Europe & Central Asia (excluding high income)  Upper middle income
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11                                        High income          High income
# 12                                        High income          High income
# 13                                        High income          High income
# 14  Latin America & Caribbean (excluding high income)  Upper middle income
#
#    Account (% age 15+) Account, male (% age 15+)  \
# 0                   9%                       15%
# 1                  10%                       16%
# 2                  15%                       23%
# 3                  39%                       39%
# 4                  29%                       36%
# 5                  28%                       34%
# 6                  38%                       43%
# 7                  40%                       42%
# 8                  22%                       30%
# 9                  30%                       38%
# 10                 37%                       48%
# 11                 60%                       69%
# 12                 84%                       90%
# 13                 88%                       93%
# 14                 33%                       35%
#
#    Account, in labor force (% age 15+)   \
# 0                                   15%
# 1                                   15%
# 2                                   25%
# 3                                   46%
# 4                                   36%
# 5                                   36%
# 6                                   44%
# 7                                   53%
# 8                                   33%
# 9                                   42%
# 10                                  51%
# 11                                  80%
# 12                                  91%
# 13                                  93%
# 14                                  37%
#
#    Account, out of labor force (% age 15+)  Account, female (% age 15+)  ...  \
# 0                                        2%                          3%  ...
# 1                                        4%                          4%  ...
# 2                                        4%                          7%  ...
# 3                                       31%                         39%  ...
# 4                                       12%                         22%  ...
# 5                                       15%                         23%  ...
# 6                                       29%                         34%  ...
# 7                                       27%                         38%  ...
# 8                                       11%                         14%  ...
# 9                                       18%                         22%  ...
# 10                                      24%                         26%  ...
# 11                                      24%                         47%  ...
# 12                                      49%                         68%  ...
# 13                                      57%                         76%  ...
# 14                                      28%                         32%  ...
#
#    Mobile money account, female (% age 15+)   \
# 0                                        NaN
# 1                                         0%
# 2                                         1%
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                         2%
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       10%
# 13                                       18%
# 14                                       NaN
#
#    Mobile money account, young adults  (% age 15-24)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  6%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                10%
# 13                                                10%
# 14                                                NaN
#
#    Mobile money account, older adults (% age 25+)   \
# 0                                              NaN
# 1                                               0%
# 2                                               1%
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                               1%
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             12%
# 13                                             22%
# 14                                             NaN
#
#    Mobile money account, primary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  1%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                 9%
# 14                                                NaN
#
#    Mobile money account, secondary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  2%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                12%
# 13                                                22%
# 14                                                NaN
#
#    Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  0%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                16%
# 14                                                NaN
#
#    Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                 NaN
# 1                                                  1%
# 2                                                  1%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                15%
# 13                                                25%
# 14                                                NaN
#
#    Mobile money account, rural  (% age 15+)  data_country data_year
# 0                                        NaN          NaN       NaN
# 1                                         0%          NaN       NaN
# 2                                         1%          NaN       NaN
# 3                                        NaN          NaN       NaN
# 4                                        NaN          NaN       NaN
# 5                                        NaN          NaN       NaN
# 6                                        NaN          NaN       NaN
# 7                                         2%          NaN       NaN
# 8                                        NaN          NaN       NaN
# 9                                        NaN          NaN       NaN
# 10                                       NaN          NaN       NaN
# 11                                       NaN          NaN       NaN
# 12                                       16%          NaN       NaN
# 13                                       14%          NaN       NaN
# 14                                       NaN          NaN       NaN
#
# [15 rows x 783 columns]

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Used a mobile phone or the internet to access an account (% age 15+)   '] = df['Used a mobile phone or the internet to access an account (% age 15+)   '].str.replace('%','')
df['Used a mobile phone or the internet to access an account (% age 15+)   '] = df['Used a mobile phone or the internet to access an account (% age 15+)   '].astype(float)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Used a mobile phone or the internet to access an account (% age 15+)   '] 
df['Sub-Pillar'] = subpillar


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#              Country Name  Year  \
# 2             Afghanistan  2017
# 7                 Albania  2017
# 10             Arab world  2017
# 13   United Arab Emirates  2017
# 16              Argentina  2017
# ..                    ...   ...
# 479                 World  2017
# 482                Kosovo  2017
# 487          South Africa  2017
# 490                Zambia  2017
# 493              Zimbabwe  2017
#
#                                              Indicator  data_col  \
# 2    Used a mobile phone or the internet to check a...       1.0
# 7    Used a mobile phone or the internet to check a...       4.0
# 10   Used a mobile phone or the internet to check a...       6.0
# 13   Used a mobile phone or the internet to check a...      47.0
# 16   Used a mobile phone or the internet to check a...      10.0
# ..                                                 ...       ...
# 479  Used a mobile phone or the internet to check a...      25.0
# 482  Used a mobile phone or the internet to check a...       5.0
# 487  Used a mobile phone or the internet to check a...      21.0
# 490  Used a mobile phone or the internet to check a...      26.0
# 493  Used a mobile phone or the internet to check a...      46.0
#
#      new_rank_score  higher_is_better        Sub-Pillar
# 2          1.058824              True  Digital Payments
# 7          1.235294              True  Digital Payments
# 10         1.352941              True  Digital Payments
# 13         3.764706              True  Digital Payments
# 16         1.588235              True  Digital Payments
# ..              ...               ...               ...
# 479        2.470588              True  Digital Payments
# 482        1.294118              True  Digital Payments
# 487        2.235294              True  Digital Payments
# 490        2.529412              True  Digital Payments
# 493        3.705882              True  Digital Payments
#
# [166 rows x 7 columns]

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %%
## 6. % of population with digital finance account - active (90 days)

# %%
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# Used a mobile phone or the internet to check account balance in the past year (% age 15+) - female
# population_digital_financial_services
# Digital Payments

# %%
df.head(15)
# Out:
#     Year  ISO          Country Name  \
# 0   2011  AFG           Afghanistan
# 1   2014  AFG           Afghanistan
# 2   2017  AFG           Afghanistan
# 3   2011  AGO                Angola
# 4   2014  AGO                Angola
# 5   2011  ALB               Albania
# 6   2014  ALB               Albania
# 7   2017  ALB               Albania
# 8   2011  ARB            Arab world
# 9   2014  ARB            Arab world
# 10  2017  ARB            Arab world
# 11  2011  ARE  United Arab Emirates
# 12  2014  ARE  United Arab Emirates
# 13  2017  ARE  United Arab Emirates
# 14  2011  ARG             Argentina
#
#                                                Region         Income Group  \
# 0                                          South Asia           Low income
# 1                                          South Asia           Low income
# 2                                          South Asia           Low income
# 3          Sub-Saharan Africa (excluding high income)  Lower middle income
# 4          Sub-Saharan Africa (excluding high income)  Lower middle income
# 5       Europe & Central Asia (excluding high income)  Upper middle income
# 6       Europe & Central Asia (excluding high income)  Upper middle income
# 7       Europe & Central Asia (excluding high income)  Upper middle income
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11                                        High income          High income
# 12                                        High income          High income
# 13                                        High income          High income
# 14  Latin America & Caribbean (excluding high income)  Upper middle income
#
#    Account (% age 15+) Account, male (% age 15+)  \
# 0                   9%                       15%
# 1                  10%                       16%
# 2                  15%                       23%
# 3                  39%                       39%
# 4                  29%                       36%
# 5                  28%                       34%
# 6                  38%                       43%
# 7                  40%                       42%
# 8                  22%                       30%
# 9                  30%                       38%
# 10                 37%                       48%
# 11                 60%                       69%
# 12                 84%                       90%
# 13                 88%                       93%
# 14                 33%                       35%
#
#    Account, in labor force (% age 15+)   \
# 0                                   15%
# 1                                   15%
# 2                                   25%
# 3                                   46%
# 4                                   36%
# 5                                   36%
# 6                                   44%
# 7                                   53%
# 8                                   33%
# 9                                   42%
# 10                                  51%
# 11                                  80%
# 12                                  91%
# 13                                  93%
# 14                                  37%
#
#    Account, out of labor force (% age 15+)  Account, female (% age 15+)  ...  \
# 0                                        2%                          3%  ...
# 1                                        4%                          4%  ...
# 2                                        4%                          7%  ...
# 3                                       31%                         39%  ...
# 4                                       12%                         22%  ...
# 5                                       15%                         23%  ...
# 6                                       29%                         34%  ...
# 7                                       27%                         38%  ...
# 8                                       11%                         14%  ...
# 9                                       18%                         22%  ...
# 10                                      24%                         26%  ...
# 11                                      24%                         47%  ...
# 12                                      49%                         68%  ...
# 13                                      57%                         76%  ...
# 14                                      28%                         32%  ...
#
#    Mobile money account, female (% age 15+)   \
# 0                                        NaN
# 1                                         0%
# 2                                         1%
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                         2%
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       10%
# 13                                       18%
# 14                                       NaN
#
#    Mobile money account, young adults  (% age 15-24)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  6%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                10%
# 13                                                10%
# 14                                                NaN
#
#    Mobile money account, older adults (% age 25+)   \
# 0                                              NaN
# 1                                               0%
# 2                                               1%
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                               1%
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             12%
# 13                                             22%
# 14                                             NaN
#
#    Mobile money account, primary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  1%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                 9%
# 14                                                NaN
#
#    Mobile money account, secondary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  2%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                12%
# 13                                                22%
# 14                                                NaN
#
#    Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  0%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                16%
# 14                                                NaN
#
#    Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                 NaN
# 1                                                  1%
# 2                                                  1%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                15%
# 13                                                25%
# 14                                                NaN
#
#    Mobile money account, rural  (% age 15+)  data_country data_year
# 0                                        NaN          NaN       NaN
# 1                                         0%          NaN       NaN
# 2                                         1%          NaN       NaN
# 3                                        NaN          NaN       NaN
# 4                                        NaN          NaN       NaN
# 5                                        NaN          NaN       NaN
# 6                                        NaN          NaN       NaN
# 7                                         2%          NaN       NaN
# 8                                        NaN          NaN       NaN
# 9                                        NaN          NaN       NaN
# 10                                       NaN          NaN       NaN
# 11                                       NaN          NaN       NaN
# 12                                       16%          NaN       NaN
# 13                                       14%          NaN       NaN
# 14                                       NaN          NaN       NaN
#
# [15 rows x 783 columns]

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Used a mobile phone or the internet to access an account, female  (% age 15+)   '] = df['Used a mobile phone or the internet to access an account, female  (% age 15+)   '].str.replace('%','')
df['Used a mobile phone or the internet to access an account, female  (% age 15+)   '] = df['Used a mobile phone or the internet to access an account, female  (% age 15+)   '].astype(float)

# %%
#create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Used a mobile phone or the internet to access an account, female  (% age 15+)   '] 
df['Sub-Pillar'] = subpillar


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#              Country Name  Year  \
# 2             Afghanistan  2017
# 7                 Albania  2017
# 10             Arab world  2017
# 13   United Arab Emirates  2017
# 16              Argentina  2017
# ..                    ...   ...
# 479                 World  2017
# 482                Kosovo  2017
# 487          South Africa  2017
# 490                Zambia  2017
# 493              Zimbabwe  2017
#
#                                              Indicator  data_col  \
# 2    Used a mobile phone or the internet to check a...       1.0
# 7    Used a mobile phone or the internet to check a...       4.0
# 10   Used a mobile phone or the internet to check a...       3.0
# 13   Used a mobile phone or the internet to check a...      37.0
# 16   Used a mobile phone or the internet to check a...       8.0
# ..                                                 ...       ...
# 479  Used a mobile phone or the internet to check a...      23.0
# 482  Used a mobile phone or the internet to check a...       4.0
# 487  Used a mobile phone or the internet to check a...      18.0
# 490  Used a mobile phone or the internet to check a...      25.0
# 493  Used a mobile phone or the internet to check a...      43.0
#
#      new_rank_score  higher_is_better        Sub-Pillar
# 2          1.058824              True  Digital Payments
# 7          1.235294              True  Digital Payments
# 10         1.176471              True  Digital Payments
# 13         3.176471              True  Digital Payments
# 16         1.470588              True  Digital Payments
# ..              ...               ...               ...
# 479        2.352941              True  Digital Payments
# 482        1.235294              True  Digital Payments
# 487        2.058824              True  Digital Payments
# 490        2.470588              True  Digital Payments
# 493        3.529412              True  Digital Payments
#
# [166 rows x 7 columns]

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %%
## 7. % Making online transactions - Men

# %%
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# % Making online transactions - Men
# population_digital_financial_services
# Digital Payments

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Used the internet to pay bills or to buy something online in the past year, male (% age 15+)'] = df['Used the internet to pay bills or to buy something online in the past year, male (% age 15+)'].str.replace('%','')
df['Used the internet to pay bills or to buy something online in the past year, male (% age 15+)'] = df['Used the internet to pay bills or to buy something online in the past year, male (% age 15+)'].astype(float)

# %%
#create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Used the internet to pay bills or to buy something online in the past year, male (% age 15+)'] 
df['Sub-Pillar'] = subpillar


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#              Country Name  Year                           Indicator  data_col  \
# 2             Afghanistan  2017  % Making online transactions - Men       1.0
# 7                 Albania  2017  % Making online transactions - Men       9.0
# 10             Arab world  2017  % Making online transactions - Men      12.0
# 13   United Arab Emirates  2017  % Making online transactions - Men      62.0
# 16              Argentina  2017  % Making online transactions - Men      21.0
# ..                    ...   ...                                 ...       ...
# 479                 World  2017  % Making online transactions - Men      30.0
# 482                Kosovo  2017  % Making online transactions - Men      18.0
# 487          South Africa  2017  % Making online transactions - Men      17.0
# 490                Zambia  2017  % Making online transactions - Men      14.0
# 493              Zimbabwe  2017  % Making online transactions - Men      13.0
#
#      new_rank_score  higher_is_better        Sub-Pillar
# 2          1.000000              True  Digital Payments
# 7          1.439560              True  Digital Payments
# 10         1.604396              True  Digital Payments
# 13         4.351648              True  Digital Payments
# 16         2.098901              True  Digital Payments
# ..              ...               ...               ...
# 479        2.593407              True  Digital Payments
# 482        1.934066              True  Digital Payments
# 487        1.879121              True  Digital Payments
# 490        1.714286              True  Digital Payments
# 493        1.659341              True  Digital Payments
#
# [166 rows x 7 columns]

# %%
df.to_csv('../indicator_scores/foundations_Making online transactions - Men_scores.csv', index=False)

# %%
## 8. % Making online transactions - Women

# %%
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# % Making online transactions - Women
# population_digital_financial_services
# Digital Payments

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Used the internet to pay bills or to buy something online in the past year, female (% age 15+)'] = df['Used the internet to pay bills or to buy something online in the past year, female (% age 15+)'].str.replace('%','')
df['Used the internet to pay bills or to buy something online in the past year, female (% age 15+)'] = df['Used the internet to pay bills or to buy something online in the past year, female (% age 15+)'].astype(float)

# %%
#create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Used the internet to pay bills or to buy something online in the past year, female (% age 15+)'] 
df['Sub-Pillar'] = subpillar


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#              Country Name  Year                             Indicator  \
# 2             Afghanistan  2017  % Making online transactions - Women
# 7                 Albania  2017  % Making online transactions - Women
# 10             Arab world  2017  % Making online transactions - Women
# 13   United Arab Emirates  2017  % Making online transactions - Women
# 16              Argentina  2017  % Making online transactions - Women
# ..                    ...   ...                                   ...
# 479                 World  2017  % Making online transactions - Women
# 482                Kosovo  2017  % Making online transactions - Women
# 487          South Africa  2017  % Making online transactions - Women
# 490                Zambia  2017  % Making online transactions - Women
# 493              Zimbabwe  2017  % Making online transactions - Women
#
#      data_col  new_rank_score  higher_is_better        Sub-Pillar
# 2         0.0        1.000000              True  Digital Payments
# 7         6.0        1.337079              True  Digital Payments
# 10        6.0        1.337079              True  Digital Payments
# 13       54.0        4.033708              True  Digital Payments
# 16       16.0        1.898876              True  Digital Payments
# ..        ...             ...               ...               ...
# 479      28.0        2.573034              True  Digital Payments
# 482      12.0        1.674157              True  Digital Payments
# 487      12.0        1.674157              True  Digital Payments
# 490       9.0        1.505618              True  Digital Payments
# 493       6.0        1.337079              True  Digital Payments
#
# [166 rows x 7 columns]

# %%
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [raw]
# ## 9. % of population with digital finance account - registered

# %%
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[0]
subpillar = subpillars[0]
print(subpillar)
# Out:
# % of population with digital finance account - registered
# population_digital_financial_services
# Digital Payments

# %%
df.head()
# Out:
#    Year  ISO Country Name                                      Region  \
# 0  2011  AFG  Afghanistan                                  South Asia
# 1  2014  AFG  Afghanistan                                  South Asia
# 2  2017  AFG  Afghanistan                                  South Asia
# 3  2011  AGO       Angola  Sub-Saharan Africa (excluding high income)
# 4  2014  AGO       Angola  Sub-Saharan Africa (excluding high income)
#
#           Income Group Account (% age 15+) Account, male (% age 15+)  \
# 0           Low income                  9%                       15%
# 1           Low income                 10%                       16%
# 2           Low income                 15%                       23%
# 3  Lower middle income                 39%                       39%
# 4  Lower middle income                 29%                       36%
#
#   Account, in labor force (% age 15+)   \
# 0                                  15%
# 1                                  15%
# 2                                  25%
# 3                                  46%
# 4                                  36%
#
#   Account, out of labor force (% age 15+)  Account, female (% age 15+)  ...  \
# 0                                       2%                          3%  ...
# 1                                       4%                          4%  ...
# 2                                       4%                          7%  ...
# 3                                      31%                         39%  ...
# 4                                      12%                         22%  ...
#
#   Mobile money account, female (% age 15+)   \
# 0                                       NaN
# 1                                        0%
# 2                                        1%
# 3                                       NaN
# 4                                       NaN
#
#   Mobile money account, young adults  (% age 15-24)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 0%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, older adults (% age 25+)   \
# 0                                             NaN
# 1                                              0%
# 2                                              1%
# 3                                             NaN
# 4                                             NaN
#
#   Mobile money account, primary education or less (% age 15+)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 0%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, secondary education or less (% age 15+)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 2%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 0%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                NaN
# 1                                                 1%
# 2                                                 1%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, rural  (% age 15+)  data_country data_year
# 0                                       NaN          NaN       NaN
# 1                                        0%          NaN       NaN
# 2                                        1%          NaN       NaN
# 3                                       NaN          NaN       NaN
# 4                                       NaN          NaN       NaN
#
# [5 rows x 783 columns]

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Financial institution account (% age 15+) '] = df['Financial institution account (% age 15+) '].str.replace('%','')
df['Financial institution account (% age 15+) '] = df['Financial institution account (% age 15+) '].astype(float)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Financial institution account (% age 15+) '] 
df['Sub-Pillar'] = subpillar


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df
# Out:
#              Country Name  Year  \
# 2             Afghanistan  2017
# 7                 Albania  2017
# 10             Arab world  2017
# 13   United Arab Emirates  2017
# 16              Argentina  2017
# ..                    ...   ...
# 479                 World  2017
# 482                Kosovo  2017
# 487          South Africa  2017
# 490                Zambia  2017
# 493              Zimbabwe  2017
#
#                                              Indicator  data_col  \
# 2    % of population with digital finance account -...      15.0
# 7    % of population with digital finance account -...      39.0
# 10   % of population with digital finance account -...      37.0
# 13   % of population with digital finance account -...      87.0
# 16   % of population with digital finance account -...      48.0
# ..                                                 ...       ...
# 479  % of population with digital finance account -...      67.0
# 482  % of population with digital finance account -...      52.0
# 487  % of population with digital finance account -...      67.0
# 490  % of population with digital finance account -...      36.0
# 493  % of population with digital finance account -...      28.0
#
#      new_rank_score  higher_is_better        Sub-Pillar
# 2          1.329670              True  Digital Payments
# 7          2.648352              True  Digital Payments
# 10         2.538462              True  Digital Payments
# 13         5.285714              True  Digital Payments
# 16         3.142857              True  Digital Payments
# ..              ...               ...               ...
# 479        4.186813              True  Digital Payments
# 482        3.362637              True  Digital Payments
# 487        4.186813              True  Digital Payments
# 490        2.483516              True  Digital Payments
# 493        2.043956              True  Digital Payments
#
# [166 rows x 7 columns]

# %%
# output scores
df.to_csv('../indicator_scores/foundations_Financial institution account_scores.csv')

# %% [markdown]
# ## 10. % of population with ID (Total)

# %%
indicator = indicators[9]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))


subpillars[1]
subpillar = subpillars[1]
print(subpillar)
# Out:
# % of population with ID (all)
# id4d_nid
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-77-3593c9ab88f4> in <module>
#       4 print(bf)
#       5
# ----> 6 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#       7
#       8
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2059     def read(self, nrows=None):
#    2060         try:
# -> 2061             data = self._reader.read(nrows)
#    2062         except StopIteration:
#    2063             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 26 fields in line 8, saw 43

# %%
df.head(15)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
# Subtract the unregister proportion column by 100 and absolute the value
df['data_col'] = df['UP in % of Country Population'].sub(100).abs()
df ['Year'] = 2018
df['Country Name'] = df.iloc[:,1]
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 11. % of population with ID (Female)

# %%
indicator = indicators[10]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[1]
subpillar = subpillars[1]
print(subpillar)

# %%
df.head(15)

# %%
df['% of UP that is Female'] = df['% of UP that is Female'].replace('n/a',np.nan)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
# Subtract the unregister proportion column by 100 and absolute the value
df['data_col'] = df['% of UP that is Female'].sub(100).abs()
df ['Year'] = 2018
df['Country Name'] = df.iloc[:,1]
df['Sub-Pillar'] = subpillar


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df

# %%
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 12. can ID be used for transactions

# %%
indicator = indicators[11]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[1]
subpillar = subpillars[1]
print(subpillar)

# %%
df.head(20)

# %%
df['Digitized ID system']= df['Digitized ID system'].replace('-',np.nan)
df['Digitized ID system']= df['Digitized ID system'].astype(float)

# %%
df.head(15)

# %%
# create standard columns
df.rename(columns={'Economy':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Year'] = 2018
df['Indicator'] = indicator
df['data_col'] = df['Digitized ID system']
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df

# %%
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 13. Is personal data siloed

# %%
indicator = indicators[12]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Must limit the database to the first 206 rows, the remaining rows do not contain any useful information
df = df.iloc[0:205,:]

# Drop the superfluous rows by dropping na
df = df[df['#'].notna()]

# Must convert data in the DPL column into float
df['DPL'] = df['DPL'].astype(float, errors = 'ignore')

subpillars[1]
subpillar = subpillars[1]
print(subpillar)

# %%
df.head(104)

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,205]
df['Country Name'] = df['Economy']
df['Year'] = 2020
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df.head(15)

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 14. Open data index

# %%
bnames

# %%
indicator = indicators[13]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

subpillars[2]
subpillar = subpillars[2]
print(subpillar)

# %%
df.head(15)

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['score'] 
df['Country Name'] = df['name']
df['Year'] = 2016
df['Sub-Pillar'] = subpillar

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better','Sub-Pillar']]
df.head(15)

# %%
# output scores
df.to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ### Score Aggregating

# %%
import os

# %%
# get list of files in scores folder
scores = os.listdir('../indicator_scores/')
scores = [s for s in scores if s.startswith('foundations')]

# %%
scores

# %%
# create a dataframe that concatenates all these file into one table
df = pd.concat([pd.read_csv('../indicator_scores/{}'.format(s)) for s in scores])

# %%
df

# %%
# Data cleaning
df['new_rank_score'] = df['new_rank_score'].fillna(0)
df.sort_values(by=['Country Name'], ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.info()

# %%
df.head(15)

# %%
df.describe()

# %%
# checking country names
sorted(df['Country Name'].unique().tolist())

# %%
# remove trailing whitespaces from country name
df['Country Name'] = df['Country Name'].str.strip()
df['Country Name'] = df['Country Name'].str.strip('**')
df['Country Name'] = df['Country Name'].str.strip('*')

# %%
# checking country names
sorted(df['Country Name'].unique().tolist())

# %%
# average indicator scores per country
agg_df = df.groupby(['Country Name']).agg({'new_rank_score':'mean','data_col':'count'})

# %%
agg_df.columns = ['agg_score', 'count_source' ]

# %%
max_number_sources = agg_df.describe()['count_source']['max']

# %%
agg_df['agg_score_wt'] = agg_df['agg_score']*(agg_df['count_source']/max_number_sources)

# %%
agg_df.sort_values(by='agg_score', ascending=False, inplace=True)

# %%
agg_df.head(25)

# %%
agg_df.to_csv('../pillar_scores/foundation_scores_v0.csv')

# %%
### Score Aggregating by Subpillars

# %%
df.insert(0,'Pillar','Foundations')
df

# remove trailing whitespaces from country name
df['Country Name'] = df['Country Name'].str.strip()
df['Country Name'] = df['Country Name'].str.strip('**')
df['Country Name'] = df['Country Name'].str.strip('*')

# %%
sub_df = df.groupby(['Pillar','Sub-Pillar','Country Name']).agg({'new_rank_score':'mean','data_col':'count'})

# %%
sub_df.columns = ['agg_score', 'count_source' ]

# %%
max_number_sources = sub_df.describe()['count_source']['max']

# %%
sub_df['agg_score_wt'] = sub_df['agg_score']*(sub_df['count_source']/max_number_sources)

# %%
sub_df.to_csv('../subpillar_score/foundations_scores_subpillar_v0.csv')

# %% [markdown]
# ### Sources Generation

# %%
#Get all countries from Countries.xlsx
countries = pd.read_excel('../../data/Countries.xlsx')
col_names = ['Country or Area']
countries = countries[col_names]
countries.rename(columns = {'Country or Area': 'Country Name'}, inplace = True)

# %%
#Get all indicators from names dataframe retrieve at the begining of the script
bnames=bnames[['check','Sub-Pillar','Indicator','Data Source','Data Link']]
bnames.rename(columns = {'check': 'Pillar'}, inplace = True)

# %%
#Do a nice cross join so that we have combination of all countries vs all indicators
sources = countries.merge(bnames, how='cross')
sources

# %%
#Make copy of a scores dataframe and add the column available, with value of 1 (string)
#denoting all the country/indicator combinations that have value
dfsources = df[['Country Name','Pillar','Sub-Pillar','Indicator']].copy()
dfsources['Available'] = '1'

# %%
#Merge (left join) sources (all country indicator combinations)
#with those in copied scores dataframe
#resulting in a sources dataframe with values of 1 in Available column where there is a value for country/indicator
#and there is a NaN where there's not. 
#subsequently replace NaN with 0 (string)
sources = sources.merge(dfsources, how='left', on=['Country Name','Pillar','Sub-Pillar','Indicator'])
sources['Available'] = sources['Available'].fillna('0')
sources

# %%
#If sources.csv exists, get the contents, remove everyhing from this pillar, append prepared sources, save csv.
#if sources.csv does not exist, create new file from sources.
from os.path import exists

if exists('../../dashboard/Sources.csv') :
    CurrentSources = pd.read_csv('../../dashboard/Sources.csv', dtype=str)
    CurrentSources = CurrentSources[['Country Name','Pillar','Sub-Pillar','Indicator','Data Source','Data Link','Available']]
    CurrentSources.loc[CurrentSources['Pillar'] != 'Foundations']
    CurrentSources = CurrentSources.append(sources)
else :
    CurrentSources = sources
CurrentSources

# %%
CurrentSources.to_csv('../../dashboard/Sources.csv', index=False)
