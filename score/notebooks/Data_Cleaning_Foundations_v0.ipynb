# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False           Countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              20         25
# Foundations            8         12
# Government            10         15
# Infrastructure        38         48
# People                35         47
# Regulation             6          7
# Strategy               1          1

# %% [markdown]
# ### Foundations

# %%
bnames = names[(names.check=='Foundations')&(~names.Filename.isna())]#&(names.Index==False)]

# %%
bnames.head(25)
# Out:
#                                              Indicator        check  \
# 148                       Digital payments penetration  Foundations
# 149  % of population with digital finance account -...  Foundations
# 150  % of population with digital finance account -...  Foundations
# 154                            % of population with ID  Foundations
# 155                 % of services that can be accessed  Foundations
# 156                    can ID be used for transactions  Foundations
# 157                            Is personal data siloed  Foundations
# 158                                    Open data index  Foundations
#
#                    Data Source  Index                               Filename
# 148        Portulans Institute  TRUE            digital_payments_penetration
# 149                 World Bank  False  population_digital_financial_services
# 150                 World Bank  False  population_digital_financial_services
# 154                World Bank   False                               id4d_nid
# 155                World Bank   False                          id4d_services
# 156                World Bank   False                          id4d_services
# 157                 World Bank  False                          Egov_strategy
# 158  Open Knowledge Foundation   True                          open_data_idx

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['digital_payments_penetration',
#        'population_digital_financial_services', 'id4d_nid',
#        'id4d_services', 'Egov_strategy', 'open_data_idx'], dtype=object)

# %%
# ls digital-readiness-assessment-main/processed/

# %%
##ict_goods and services not in process data

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %% [markdown]
# ### 1. Digital payments penetration

# %%
indicators[0]
# Out:
# 'Digital payments penetration'

# %%
# load data
indicator = indicators[0]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Digital payments penetration
# digital_payments_penetration

# %%
df.head()
# Out:
#    RANK COUNTRY/ECONOMY  VALUE   SCORE
# 0   1.0          Norway   0.85  100.00
# 1   2.0         Denmark   0.83   97.24
# 2   3.0         Finland   0.80   93.95
# 3   4.0          Sweden   0.80   93.08
# 4   5.0     Netherlands   0.76   89.01

# %%
# score looks like the one to use
df.describe()
# Out:
#              RANK       VALUE       SCORE
# count  122.000000  122.000000  122.000000
# mean    61.500000    0.315738   36.076967
# std     35.362409    0.209012   24.867406
# min      1.000000    0.010000    0.000000
# 25%     31.250000    0.150000   16.235000
# 50%     61.500000    0.270000   30.870000
# 75%     91.750000    0.440000   51.110000
# max    122.000000    0.850000  100.000000

# %%
# df.Indicator.unique()

# %%
# create standard columns
df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['SCORE'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-100 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df
# Out:
#      RANK Country Name  VALUE   SCORE  higher_is_better  \
# 0     1.0       Norway   0.85  100.00              True
# 1     2.0      Denmark   0.83   97.24              True
# 2     3.0      Finland   0.80   93.95              True
# 3     4.0       Sweden   0.80   93.08              True
# 4     5.0  Netherlands   0.76   89.01              True
# ..    ...          ...    ...     ...               ...
# 129   NaN      Jamaica    NaN     NaN              True
# 130   NaN   Madagascar    NaN     NaN              True
# 131   NaN         Oman    NaN     NaN              True
# 132   NaN        Qatar    NaN     NaN              True
# 133   NaN        Yemen    NaN     NaN              True
#
#                         Indicator  data_col  new_rank_score
# 0    Digital payments penetration    100.00          6.0000
# 1    Digital payments penetration     97.24          5.8620
# 2    Digital payments penetration     93.95          5.6975
# 3    Digital payments penetration     93.08          5.6540
# 4    Digital payments penetration     89.01          5.4505
# ..                            ...       ...             ...
# 129  Digital payments penetration       NaN             NaN
# 130  Digital payments penetration       NaN             NaN
# 131  Digital payments penetration       NaN             NaN
# 132  Digital payments penetration       NaN             NaN
# 133  Digital payments penetration       NaN             NaN
#
# [134 rows x 8 columns]

# %%
# output scores to csv
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].to_csv('../indicator_scores/foundations_{}_scores.csv'.format(indicator), index=False)

# %%
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#            Country Name                Indicator  data_col  new_rank_score  \
# 0           Afghanistan  % of population with ID        67        3.857143
# 1               Albania  % of population with ID       100        6.000000
# 2               Algeria  % of population with ID        89        5.285714
# 3               Andorra  % of population with ID        47        2.558442
# 4                Angola  % of population with ID        44        2.363636
# 5   Antigua and Barbuda  % of population with ID        75        4.376623
# 6             Argentina  % of population with ID       100        6.000000
# 7               Armenia  % of population with ID       100        6.000000
# 8             Australia  % of population with ID        88        5.220779
# 9               Austria  % of population with ID        88        5.220779
# 10           Azerbaijan  % of population with ID        79        4.636364
# 11         Bahamas, The  % of population with ID        64        3.662338
# 12              Bahrain  % of population with ID        96        5.740260
# 13           Bangladesh  % of population with ID        68        3.922078
# 14             Barbados  % of population with ID       100        6.000000
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True

# %% [markdown]
# ## 2. % of population with digital finance account - registered

# %%
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population with digital finance account - registered
# population_digital_financial_services

# %%
df.head(15)
# Out:
#     Year  ISO          Country Name  \
# 0   2011  AFG           Afghanistan
# 1   2014  AFG           Afghanistan
# 2   2017  AFG           Afghanistan
# 3   2011  AGO                Angola
# 4   2014  AGO                Angola
# 5   2011  ALB               Albania
# 6   2014  ALB               Albania
# 7   2017  ALB               Albania
# 8   2011  ARB            Arab world
# 9   2014  ARB            Arab world
# 10  2017  ARB            Arab world
# 11  2011  ARE  United Arab Emirates
# 12  2014  ARE  United Arab Emirates
# 13  2017  ARE  United Arab Emirates
# 14  2011  ARG             Argentina
#
#                                                Region         Income Group  \
# 0                                          South Asia           Low income
# 1                                          South Asia           Low income
# 2                                          South Asia           Low income
# 3          Sub-Saharan Africa (excluding high income)  Lower middle income
# 4          Sub-Saharan Africa (excluding high income)  Lower middle income
# 5       Europe & Central Asia (excluding high income)  Upper middle income
# 6       Europe & Central Asia (excluding high income)  Upper middle income
# 7       Europe & Central Asia (excluding high income)  Upper middle income
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11                                        High income          High income
# 12                                        High income          High income
# 13                                        High income          High income
# 14  Latin America & Caribbean (excluding high income)  Upper middle income
#
#    Account (% age 15+) Account, male (% age 15+)  \
# 0                   9%                       15%
# 1                  10%                       16%
# 2                  15%                       23%
# 3                  39%                       39%
# 4                  29%                       36%
# 5                  28%                       34%
# 6                  38%                       43%
# 7                  40%                       42%
# 8                  22%                       30%
# 9                  30%                       38%
# 10                 37%                       48%
# 11                 60%                       69%
# 12                 84%                       90%
# 13                 88%                       93%
# 14                 33%                       35%
#
#    Account, in labor force (% age 15+)   \
# 0                                   15%
# 1                                   15%
# 2                                   25%
# 3                                   46%
# 4                                   36%
# 5                                   36%
# 6                                   44%
# 7                                   53%
# 8                                   33%
# 9                                   42%
# 10                                  51%
# 11                                  80%
# 12                                  91%
# 13                                  93%
# 14                                  37%
#
#    Account, out of labor force (% age 15+)  Account, female (% age 15+)  ...  \
# 0                                        2%                          3%  ...
# 1                                        4%                          4%  ...
# 2                                        4%                          7%  ...
# 3                                       31%                         39%  ...
# 4                                       12%                         22%  ...
# 5                                       15%                         23%  ...
# 6                                       29%                         34%  ...
# 7                                       27%                         38%  ...
# 8                                       11%                         14%  ...
# 9                                       18%                         22%  ...
# 10                                      24%                         26%  ...
# 11                                      24%                         47%  ...
# 12                                      49%                         68%  ...
# 13                                      57%                         76%  ...
# 14                                      28%                         32%  ...
#
#    Mobile money account, female (% age 15+)   \
# 0                                        NaN
# 1                                         0%
# 2                                         1%
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                         2%
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       10%
# 13                                       18%
# 14                                       NaN
#
#    Mobile money account, young adults  (% age 15-24)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  6%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                10%
# 13                                                10%
# 14                                                NaN
#
#    Mobile money account, older adults (% age 25+)   \
# 0                                              NaN
# 1                                               0%
# 2                                               1%
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                               1%
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             12%
# 13                                             22%
# 14                                             NaN
#
#    Mobile money account, primary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  1%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                 9%
# 14                                                NaN
#
#    Mobile money account, secondary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  2%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                12%
# 13                                                22%
# 14                                                NaN
#
#    Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  0%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                16%
# 14                                                NaN
#
#    Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                 NaN
# 1                                                  1%
# 2                                                  1%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                15%
# 13                                                25%
# 14                                                NaN
#
#    Mobile money account, rural  (% age 15+)  data_country data_year
# 0                                        NaN          NaN       NaN
# 1                                         0%          NaN       NaN
# 2                                         1%          NaN       NaN
# 3                                        NaN          NaN       NaN
# 4                                        NaN          NaN       NaN
# 5                                        NaN          NaN       NaN
# 6                                        NaN          NaN       NaN
# 7                                         2%          NaN       NaN
# 8                                        NaN          NaN       NaN
# 9                                        NaN          NaN       NaN
# 10                                       NaN          NaN       NaN
# 11                                       NaN          NaN       NaN
# 12                                       16%          NaN       NaN
# 13                                       14%          NaN       NaN
# 14                                       NaN          NaN       NaN
#
# [15 rows x 783 columns]

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Account (% age 15+)'] = df['Account (% age 15+)'].str.replace('%','')
df['Account (% age 15+)'] = df['Account (% age 15+)'].astype(float)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Account (% age 15+)'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]
df
# Out:
#              Country Name                                          Indicator  \
# 2             Afghanistan  % of population with digital finance account -...
# 7                 Albania  % of population with digital finance account -...
# 10             Arab world  % of population with digital finance account -...
# 13   United Arab Emirates  % of population with digital finance account -...
# 16              Argentina  % of population with digital finance account -...
# ..                    ...                                                ...
# 479                 World  % of population with digital finance account -...
# 482                Kosovo  % of population with digital finance account -...
# 487          South Africa  % of population with digital finance account -...
# 490                Zambia  % of population with digital finance account -...
# 493              Zimbabwe  % of population with digital finance account -...
#
#      data_col  new_rank_score  higher_is_better
# 2        15.0        1.329670              True
# 7        40.0        2.703297              True
# 10       37.0        2.538462              True
# 13       88.0        5.340659              True
# 16       49.0        3.197802              True
# ..        ...             ...               ...
# 479      69.0        4.296703              True
# 482      52.0        3.362637              True
# 487      69.0        4.296703              True
# 490      46.0        3.032967              True
# 493      55.0        3.527473              True
#
# [166 rows x 5 columns]

# %%
# output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 3. % of population with digital finance account - active (90 days)

# %%
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population with digital finance account - active (90 days)
# population_digital_financial_services

# %%
df.head()
# Out:
#    Year  ISO Country Name                                      Region  \
# 0  2011  AFG  Afghanistan                                  South Asia
# 1  2014  AFG  Afghanistan                                  South Asia
# 2  2017  AFG  Afghanistan                                  South Asia
# 3  2011  AGO       Angola  Sub-Saharan Africa (excluding high income)
# 4  2014  AGO       Angola  Sub-Saharan Africa (excluding high income)
#
#           Income Group Account (% age 15+) Account, male (% age 15+)  \
# 0           Low income                  9%                       15%
# 1           Low income                 10%                       16%
# 2           Low income                 15%                       23%
# 3  Lower middle income                 39%                       39%
# 4  Lower middle income                 29%                       36%
#
#   Account, in labor force (% age 15+)   \
# 0                                  15%
# 1                                  15%
# 2                                  25%
# 3                                  46%
# 4                                  36%
#
#   Account, out of labor force (% age 15+)  Account, female (% age 15+)  ...  \
# 0                                       2%                          3%  ...
# 1                                       4%                          4%  ...
# 2                                       4%                          7%  ...
# 3                                      31%                         39%  ...
# 4                                      12%                         22%  ...
#
#   Mobile money account, female (% age 15+)   \
# 0                                       NaN
# 1                                        0%
# 2                                        1%
# 3                                       NaN
# 4                                       NaN
#
#   Mobile money account, young adults  (% age 15-24)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 0%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, older adults (% age 25+)   \
# 0                                             NaN
# 1                                              0%
# 2                                              1%
# 3                                             NaN
# 4                                             NaN
#
#   Mobile money account, primary education or less (% age 15+)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 0%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, secondary education or less (% age 15+)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 2%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                NaN
# 1                                                 0%
# 2                                                 0%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                NaN
# 1                                                 1%
# 2                                                 1%
# 3                                                NaN
# 4                                                NaN
#
#   Mobile money account, rural  (% age 15+)  data_country data_year
# 0                                       NaN          NaN       NaN
# 1                                        0%          NaN       NaN
# 2                                        1%          NaN       NaN
# 3                                       NaN          NaN       NaN
# 4                                       NaN          NaN       NaN
#
# [5 rows x 783 columns]

# %%
df = df[(df.Year == 2017)]

# Must convert the data to float by removing the % sign
df['Made or received digital payments in the past year (% age 15+)'] = df['Made or received digital payments in the past year (% age 15+)'].str.replace('%','')
df['Made or received digital payments in the past year (% age 15+)'] = df['Made or received digital payments in the past year (% age 15+)'].astype(float)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Made or received digital payments in the past year (% age 15+)'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]
df
# Out:
#              Country Name                                          Indicator  \
# 2             Afghanistan  % of population with digital finance account -...
# 7                 Albania  % of population with digital finance account -...
# 10             Arab world  % of population with digital finance account -...
# 13   United Arab Emirates  % of population with digital finance account -...
# 16              Argentina  % of population with digital finance account -...
# ..                    ...                                                ...
# 479                 World  % of population with digital finance account -...
# 482                Kosovo  % of population with digital finance account -...
# 487          South Africa  % of population with digital finance account -...
# 490                Zambia  % of population with digital finance account -...
# 493              Zimbabwe  % of population with digital finance account -...
#
#      data_col  new_rank_score  higher_is_better
# 2        11.0        1.217391              True
# 7        29.0        2.195652              True
# 10       26.0        2.032609              True
# 13       84.0        5.184783              True
# 16       40.0        2.793478              True
# ..        ...             ...               ...
# 479      52.0        3.445652              True
# 482      39.0        2.739130              True
# 487      60.0        3.880435              True
# 490      39.0        2.739130              True
# 493      53.0        3.500000              True
#
# [166 rows x 5 columns]

# %%
# output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(bf))

# %% [markdown]
# ## 4. % of population with ID

# %%
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population with ID
# id4d_nid

# %%
df.head(15)
# Out:
#     id              Economy Country Code Region Income  OECD Lending category  \
# 0    1          Afghanistan          AFG    SAS    LIC   NaN              IDA
# 1    2              Albania          ALB    ECS    UMC   NaN             IBRD
# 2    3              Algeria          DZA    MEA    UMC   NaN             IBRD
# 3    4              Andorra          AND    ECS    HIC   NaN               ..
# 4    5               Angola          AGO    SSF    LMC   NaN             IBRD
# 5    6  Antigua and Barbuda          ATG    LCN    HIC   NaN             IBRD
# 6    7            Argentina          ARG    LCN    UMC   NaN             IBRD
# 7    8              Armenia          ARM    ECS    LMC   NaN             IBRD
# 8    9            Australia          AUS    EAS    HIC  OECD               ..
# 9   10              Austria          AUT    ECS    HIC  OECD               ..
# 10  11           Azerbaijan          AZE    ECS    UMC   NaN             IBRD
# 11  12         Bahamas, The          BHS    LCN    HIC   NaN               ..
# 12  13              Bahrain          BHR    MEA    HIC   NaN               ..
# 13  14           Bangladesh          BGD    SAS    LMC   NaN              IDA
# 14  15             Barbados          BRB    LCN    HIC   NaN               ..
#
#    Other  GCC adjusted Inclusion Criteria  ... Unnamed: 31  Unnamed: 32  \
# 0   HIPC           NaN            INCLUDE  ...       Voter   13,549,892
# 1    NaN           NaN            INCLUDE  ...      Direct    2,267,673
# 2    NaN           NaN            INCLUDE  ...       Voter          NaN
# 3    NaN           NaN            EXCLUDE  ...       Voter          NaN
# 4    NaN           NaN            INCLUDE  ...       Voter          NaN
# 5    NaN           NaN            INCLUDE  ...       Voter          NaN
# 6    NaN           NaN            INCLUDE  ...       Voter          NaN
# 7    NaN           NaN            INCLUDE  ...       Voter          NaN
# 8    NaN           NaN            EXCLUDE  ...       Voter    7,847,109
# 9    EMU           NaN            EXCLUDE  ...       Voter    3,093,348
# 10   NaN           NaN            INCLUDE  ...       Voter    2,696,131
# 11   NaN           NaN            INCLUDE  ...       Voter          NaN
# 12   NaN           NaN            INCLUDE  ...      Direct      951,312
# 13   NaN           NaN            INCLUDE  ...       Voter          NaN
# 14   NaN           NaN            INCLUDE  ...       Voter          NaN
#
#    Unnamed: 33  Unnamed: 34  Unnamed: 35  Unnamed: 36 Unnamed: 37  \
# 0    7,296,096   36,373,176   18,191,591    9,336,665   8,854,905
# 1    2,188,099    2,934,363      540,349      280,793     259,561
# 2          NaN   42,008,054   14,075,724    7,181,719   6,894,010
# 3          NaN       80,209       13,580        6,971       6,609
# 4          NaN   30,774,205   16,389,360    8,157,462   8,231,869
# 5          NaN      103,050       29,388       14,745      14,644
# 6          NaN   44,688,864   11,751,904    5,977,086   5,774,773
# 7          NaN    2,934,152      689,894      367,840     322,065
# 8    8,269,334   24,772,247    5,624,607    2,884,647   2,739,917
# 9    3,307,645    8,751,820    1,318,229      676,854     641,377
# 10   2,613,303    9,923,914    2,695,225    1,440,683   1,254,544
# 11         NaN      399,285       97,109       49,717      47,392
# 12     549,804    1,566,993            0            0           0
# 13         NaN  166,368,149   56,110,211   28,671,689  27,438,536
# 14         NaN      286,388       65,411       33,408      32,004
#
#     Unnamed: 38 Unnamed: 39  Unnamed: 40
# 0    18,181,585   9,398,623    8,782,976
# 1     2,394,014   1,199,481    1,194,510
# 2    27,932,330  14,033,462   13,898,865
# 3        66,629      34,060       32,569
# 4    14,384,845   6,937,053    7,447,820
# 5        73,662      34,732       38,932
# 6    32,936,960  15,898,099   17,038,900
# 7     2,244,258   1,012,449    1,231,792
# 8    19,147,640   9,456,278    9,691,403
# 9     7,433,591   3,617,222    3,816,362
# 10    7,228,689   3,504,218    3,724,469
# 11      302,176     145,810      156,371
# 12    1,566,993     993,102      573,892
# 13  110,257,938  55,189,006   55,068,922
# 14      220,977     103,644      117,324
#
# [15 rows x 41 columns]

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
# Subtract the unregister proportion column by 100 and absolute the value
df['data_col'] = df['UP in % of Country Population'].sub(100).abs()
df ['Year'] = 2018
df['Country Name'] = df.iloc[:,1]


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]
df
# Out:
#       Country Name                Indicator  data_col  new_rank_score  \
# 0      Afghanistan  % of population with ID        67        3.857143
# 1          Albania  % of population with ID       100        6.000000
# 2          Algeria  % of population with ID        89        5.285714
# 3          Andorra  % of population with ID        47        2.558442
# 4           Angola  % of population with ID        44        2.363636
# ..             ...                      ...       ...             ...
# 193  Venezuela, RB  % of population with ID        87        5.155844
# 194        Vietnam  % of population with ID        96        5.740260
# 195    Yemen, Rep.  % of population with ID        50        2.753247
# 196         Zambia  % of population with ID        44        2.363636
# 197       Zimbabwe  % of population with ID        58        3.272727
#
#      higher_is_better
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# ..                ...
# 193              True
# 194              True
# 195              True
# 196              True
# 197              True
#
# [198 rows x 5 columns]

# %%
# output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 5. % of services that can be accessed

# %%
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of services that can be accessed
# id4d_services

# %%
df.head(15)
# Out:
#       ID              Economy Region Income Code Inclusion Criteria  \
# 0    1.0          Afghanistan    SAS    LIC  AFG            INCLUDE
# 1    2.0              Albania    ECS    UMC  ALB            INCLUDE
# 2    3.0              Algeria    MEA    UMC  DZA            INCLUDE
# 3    4.0              Andorra    ECS    HIC  AND            EXCLUDE
# 4    5.0               Angola    SSF    LMC  AGO            INCLUDE
# 5    6.0  Antigua and Barbuda    LCN    HIC  ATG            INCLUDE
# 6    7.0            Argentina    LCN    UMC  ARG            INCLUDE
# 7    8.0              Armenia    ECS    LMC  ARM            INCLUDE
# 8    9.0            Australia    EAS    HIC  AUS            EXCLUDE
# 9   10.0              Austria    ECS    HIC  AUT            EXCLUDE
# 10  11.0           Azerbaijan    ECS    UMC  AZE            INCLUDE
# 11  12.0         Bahamas, The    LCN    HIC  BHS            INCLUDE
# 12  13.0              Bahrain    MEA    HIC  BHR            INCLUDE
# 13  14.0           Bangladesh    SAS    LMC  BGD            INCLUDE
# 14  15.0             Barbados    LCN    HIC  BRB            INCLUDE
#
#    National ID NID Issued at Birth Mandatory NID age Digitized ID system  ...  \
# 0            1                   1                 0                   1  ...
# 1            1                   0                16                   1  ...
# 2            1                   0                18                   1  ...
# 3            0                                     -                   -  ...
# 4            1                   0                10                   1  ...
# 5            0                                     -                   -  ...
# 6            1                   1                 0                   1  ...
# 7            1                   1                16                   1  ...
# 8            0                                     -                   -  ...
# 9            1                   0                 0                   1  ...
# 10           1                   0                16                   1  ...
# 11           1                   0                 0                   0  ...
# 12           1                   1                 0                   1  ...
# 13           1                   0                18                   1  ...
# 14           1                   0                16                   0  ...
#
#                                                   URL  \
# 0                     http://mcit.gov.af/en/page/7081
# 1                   http://www.punetebrendshme.gov.al
# 2                        http://www.interieur.gov.dz/
# 3                                                None
# 4   http://www.minjusdh.gov.ao/VerPrestadorServico...
# 5                                                None
# 6         http://www.nuevodni.gov.ar/inicio/index.php
# 7                            https://www.ekeng.am/hy/
# 8                                                None
# 9   https://www.help.gv.at/Portal.Node/hlpd/public...
# 10   http://www.mia.gov.az/index.php?/en/content/171/
# 11  http://www.bahamas.gov.bs/wps/portal/public/!u...
# 12  http://www.cio.gov.bh/CIO_ENG/SubDetailed.aspx...
# 13                             http://www.nidw.gov.bd
# 14  http://www.electoral.barbados.gov.bb/nationalr...
#
#                                  NID card/number name             NID cost  \
# 0                                      Tazkira / eNID  Afs 30-35 (US$ 0.5)
# 1              Letërnjoftimi / Albanian Identity Card             10 euros
# 2   Carte Nationale d'Identité Biométrique Electro...                 free
# 3                                                   -                    -
# 4            Bilhete de Identidade (National ID card)            15 kwanza
# 5                                                   -                    -
# 6   DNI (Documento Nacional de Identidad) / SIBIOS...                 free
# 7                National ID Card / National Passport                 free
# 8                                                   -                    -
# 9   Identitätsausweis / Personalausweis (Austrian ...             61.5 EUR
# 10  Azərbaycan Respublikası vətəndaşının şəxsiyyət...                 free
# 11                            Certificate of Identity                BS$25
# 12                              National ID Smartcard               varies
# 13                                   National ID Card                 free
# 14                                   National ID Card                 free
#
#                                     Primary CR entity  \
# 0                        Ministry of Interior Affairs
# 1   Vital Statistics Offices , Ministry of Interio...
# 2      Ministry of the Interior and Local Governments
# 3                               Civil Registry Office
# 4   Direcção Nacional dos Registos e do Notariado ...
# 5   Civil Registry, Ministry of Justice and Legal ...
# 6   Regional Civil Registries, Provincial Authorit...
# 7       Civil Registry Office, RA Ministry of Justice
# 8           Registrar-General, Departments of Justice
# 9                         Register Office, Baby-Point
# 10                       Civil registry office (ZAGS)
# 11                     Registrar General’s Department
# 12                                 Ministry of Health
# 13  Office of the Registrar-General, Local Governm...
# 14  Registration Department, Barbados Supreme Cour...
#
#                                     CR Gov Entity URL CR entity category  \
# 0   http://moi.gov.af/en/page/7180 , http://moi.go...                2.0
# 1                  http://www.punetebrendshme.gov.al/                5.0
# 2                         http://www.interieur.gov.dz                2.0
# 3                         http://www.registrecivil.ad                1.0
# 4                          http://www.minjusdh.gov.ao                1.0
# 5                     http://www.legalaffairs.gov.ag/                1.0
# 6   http://www.mininterior.gov.ar/renaper/renaper.php                6.0
# 7   http://www.moj.am/services/civil_registry/item...                1.0
# 8   http://www.australia.gov.au/topics/law-and-jus...                1.0
# 9   https://www.help.gv.at/Portal.Node/hlpd/public...                2.0
# 10                          http://www.justice.gov.az                1.0
# 11                      http://www.bahamas.gov.bs/rgd                1.0
# 12                              http://www.moh.gov.bh                3.0
# 13                               http://br.lgd.gov.bd                6.0
# 14               http://www.barbadoslawcourts.gov.bb/                1.0
#
#    Mandatory Birth Registration Period Birth Registration cost  data_country  \
# 0                                  6 m                    free           NaN
# 1                                 60 d                100 Leke           NaN
# 2                             5 - 60 d                    free           NaN
# 3                                 15 d                    free           NaN
# 4                                  5 d                    free           NaN
# 5                                 30 d                   EC 10           NaN
# 6                                 40 d                    free           NaN
# 7                                  1 y                    free           NaN
# 8                                  6 m                    free           NaN
# 9                                  1 m                    free           NaN
# 10                                 1 m                    free           NaN
# 11                                21 d                    free           NaN
# 12                                 7 d                  BD 0.5           NaN
# 13                                45 d                    free           NaN
# 14                                42 d                    free           NaN
#
#    data_year
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
#
# [15 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 1 to 198
# Data columns (total 23 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   1.0                                                     197 non-null    float64
#  1   Afghanistan                                             198 non-null    object
#  2   SAS                                                     198 non-null    object
#  3   LIC                                                     198 non-null    object
#  4   AFG                                                     198 non-null    object
#  5   INCLUDE                                                 198 non-null    object
#  6   1                                                       198 non-null    object
#  7   1                                                       197 non-null    object
#  8   0                                                       197 non-null    object
#  9   1                                                       197 non-null    object
#  10  1                                                       197 non-null    object
#  11  Ministry of Interior Affairs                            197 non-null    object
#  12  2.0                                                     197 non-null    float64
#  13  http://mcit.gov.af/en/page/7081                         197 non-null    object
#  14  Tazkira / eNID                                          194 non-null    object
#  15  Afs 30-35 (US$ 0.5)                                     195 non-null    object
#  16  Ministry of Interior Affairs                            196 non-null    object
#  17  http://moi.gov.af/en/page/7180 , http://moi.gov.af/fa   196 non-null    object
#  18  2.0                                                     196 non-null    float64
#  19  6 m                                                     196 non-null    object
#  20  free                                                    196 non-null    object
#  21  nan                                                     0 non-null      float64
#  22  nan                                                     0 non-null      float64
# dtypes: float64(5), object(18)
# memory usage: 35.7+ KB

# %%
df.head()
# Out:
# 0  1.0          Afghanistan  SAS  LIC  AFG  INCLUDE  1  1   0  1  ...  \
# 1  2.0              Albania  ECS  UMC  ALB  INCLUDE  1  0  16  1  ...
# 2  3.0              Algeria  MEA  UMC  DZA  INCLUDE  1  0  18  1  ...
# 3  4.0              Andorra  ECS  HIC  AND  EXCLUDE  0      -  -  ...
# 4  5.0               Angola  SSF  LMC  AGO  INCLUDE  1  0  10  1  ...
# 5  6.0  Antigua and Barbuda  LCN  HIC  ATG  INCLUDE  0      -  -  ...
#
# 0                    http://mcit.gov.af/en/page/7081  \
# 1                  http://www.punetebrendshme.gov.al
# 2                       http://www.interieur.gov.dz/
# 3                                               None
# 4  http://www.minjusdh.gov.ao/VerPrestadorServico...
# 5                                               None
#
# 0                                     Tazkira / eNID  Afs 30-35 (US$ 0.5)  \
# 1             Letërnjoftimi / Albanian Identity Card             10 euros
# 2  Carte Nationale d'Identité Biométrique Electro...                 free
# 3                                                  -                    -
# 4           Bilhete de Identidade (National ID card)            15 kwanza
# 5                                                  -                    -
#
# 0                       Ministry of Interior Affairs  \
# 1  Vital Statistics Offices , Ministry of Interio...
# 2     Ministry of the Interior and Local Governments
# 3                              Civil Registry Office
# 4  Direcção Nacional dos Registos e do Notariado ...
# 5  Civil Registry, Ministry of Justice and Legal ...
#
# 0 http://moi.gov.af/en/page/7180 , http://moi.gov.af/fa   2.0       6 m  \
# 1                 http://www.punetebrendshme.gov.al/      5.0      60 d
# 2                        http://www.interieur.gov.dz      2.0  5 - 60 d
# 3                        http://www.registrecivil.ad      1.0      15 d
# 4                         http://www.minjusdh.gov.ao      1.0       5 d
# 5                    http://www.legalaffairs.gov.ag/      1.0      30 d
#
# 0      free NaN NaN
# 1  100 Leke NaN NaN
# 2      free NaN NaN
# 3      free NaN NaN
# 4      free NaN NaN
# 5     EC 10 NaN NaN
#
# [5 rows x 23 columns]

# %%
# dcol = 'Percentage of total merchandise trade'
# indicol = 'IctProductCategory Label'
# cname = 'Economy Label'

# # filter most recent year and exports
# df = df[(df.Year==2019)&(df['Flow Label']=='Imports')]

# # create standard columns
# df['higher_is_better'] = True
# df['Indicator'] =  df[indicol]+' '+ df['Flow Label']
# df['Country Name'] = df[cname]
# # df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
# df['data_col'] = df[dcol]


# # convert 1-100 %  into 1-6
# df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=0,old_max=100))

# df.sort_values(by='new_rank_score', ascending=False)

# # prepare output
# df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]

# # output scores
# df.to_csv('../indicator_scores/{}_scores.csv'.format(bf+'_imports'), index=False)

# %% [markdown]
# ## 6. can ID be used for transactions

# %%
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# can ID be used for transactions
# id4d_services

# %%
df.head(20)
# Out:
#       ID              Economy Region Income Code Inclusion Criteria  \
# 0    1.0          Afghanistan    SAS    LIC  AFG            INCLUDE
# 1    2.0              Albania    ECS    UMC  ALB            INCLUDE
# 2    3.0              Algeria    MEA    UMC  DZA            INCLUDE
# 3    4.0              Andorra    ECS    HIC  AND            EXCLUDE
# 4    5.0               Angola    SSF    LMC  AGO            INCLUDE
# 5    6.0  Antigua and Barbuda    LCN    HIC  ATG            INCLUDE
# 6    7.0            Argentina    LCN    UMC  ARG            INCLUDE
# 7    8.0              Armenia    ECS    LMC  ARM            INCLUDE
# 8    9.0            Australia    EAS    HIC  AUS            EXCLUDE
# 9   10.0              Austria    ECS    HIC  AUT            EXCLUDE
# 10  11.0           Azerbaijan    ECS    UMC  AZE            INCLUDE
# 11  12.0         Bahamas, The    LCN    HIC  BHS            INCLUDE
# 12  13.0              Bahrain    MEA    HIC  BHR            INCLUDE
# 13  14.0           Bangladesh    SAS    LMC  BGD            INCLUDE
# 14  15.0             Barbados    LCN    HIC  BRB            INCLUDE
# 15  16.0              Belarus    ECS    UMC  BLR            INCLUDE
# 16  17.0              Belgium    ECS    HIC  BEL            EXCLUDE
# 17  18.0               Belize    LCN    UMC  BLZ            INCLUDE
# 18  19.0                Benin    SSF    LIC  BEN            INCLUDE
# 19  20.0               Bhutan    SAS    LMC  BTN            INCLUDE
#
#    National ID NID Issued at Birth Mandatory NID age Digitized ID system  ...  \
# 0            1                   1                 0                   1  ...
# 1            1                   0                16                   1  ...
# 2            1                   0                18                   1  ...
# 3            0                                     -                   -  ...
# 4            1                   0                10                   1  ...
# 5            0                                     -                   -  ...
# 6            1                   1                 0                   1  ...
# 7            1                   1                16                   1  ...
# 8            0                                     -                   -  ...
# 9            1                   0                 0                   1  ...
# 10           1                   0                16                   1  ...
# 11           1                   0                 0                   0  ...
# 12           1                   1                 0                   1  ...
# 13           1                   0                18                   1  ...
# 14           1                   0                16                   0  ...
# 15           1                   1                14                   0  ...
# 16           1                   0                12                   1  ...
# 17           0                 NaN                 -                   -  ...
# 18           1                   0                18                   0  ...
# 19           1                   0                15                   1  ...
#
#                                                   URL  \
# 0                     http://mcit.gov.af/en/page/7081
# 1                   http://www.punetebrendshme.gov.al
# 2                        http://www.interieur.gov.dz/
# 3                                                None
# 4   http://www.minjusdh.gov.ao/VerPrestadorServico...
# 5                                                None
# 6         http://www.nuevodni.gov.ar/inicio/index.php
# 7                            https://www.ekeng.am/hy/
# 8                                                None
# 9   https://www.help.gv.at/Portal.Node/hlpd/public...
# 10   http://www.mia.gov.az/index.php?/en/content/171/
# 11  http://www.bahamas.gov.bs/wps/portal/public/!u...
# 12  http://www.cio.gov.bh/CIO_ENG/SubDetailed.aspx...
# 13                             http://www.nidw.gov.bd
# 14  http://www.electoral.barbados.gov.bb/nationalr...
# 15          http://mvd.gov.by/ru/main.aspx?guid=12611
# 16                          https://eid.belgium.be/en
# 17                                               None
# 18                                    http://gouv.bj/
# 19  https://www.citizenservices.gov.bt/web/guest/i...
#
#                                  NID card/number name             NID cost  \
# 0                                      Tazkira / eNID  Afs 30-35 (US$ 0.5)
# 1              Letërnjoftimi / Albanian Identity Card             10 euros
# 2   Carte Nationale d'Identité Biométrique Electro...                 free
# 3                                                   -                    -
# 4            Bilhete de Identidade (National ID card)            15 kwanza
# 5                                                   -                    -
# 6   DNI (Documento Nacional de Identidad) / SIBIOS...                 free
# 7                National ID Card / National Passport                 free
# 8                                                   -                    -
# 9   Identitätsausweis / Personalausweis (Austrian ...             61.5 EUR
# 10  Azərbaycan Respublikası vətəndaşının şəxsiyyət...                 free
# 11                            Certificate of Identity                BS$25
# 12                              National ID Smartcard               varies
# 13                                   National ID Card                 free
# 14                                   National ID Card                 free
# 15                                  National Passport                 free
# 16  BelPIC / Identiteitskaart / Carte d’Identité /...               varies
# 17                                                  -                  NaN
# 18                                   National ID Card               2400 F
# 19                          Citizenship Identity Card              Nu. 100
#
#                                     Primary CR entity  \
# 0                        Ministry of Interior Affairs
# 1   Vital Statistics Offices , Ministry of Interio...
# 2      Ministry of the Interior and Local Governments
# 3                               Civil Registry Office
# 4   Direcção Nacional dos Registos e do Notariado ...
# 5   Civil Registry, Ministry of Justice and Legal ...
# 6   Regional Civil Registries, Provincial Authorit...
# 7       Civil Registry Office, RA Ministry of Justice
# 8           Registrar-General, Departments of Justice
# 9                         Register Office, Baby-Point
# 10                       Civil registry office (ZAGS)
# 11                     Registrar General’s Department
# 12                                 Ministry of Health
# 13  Office of the Registrar-General, Local Governm...
# 14  Registration Department, Barbados Supreme Cour...
# 15                               Ministry of Interior
# 16     Municipalities, Civil Registration Departments
# 17  General Registry of the Supreme Court, Vital S...
# 18  Ministry of Interior / Ministry of Justice / M...
# 19  Min of Home & Cultural Affairs, Dept of Civl R...
#
#                                     CR Gov Entity URL CR entity category  \
# 0   http://moi.gov.af/en/page/7180 , http://moi.go...                2.0
# 1                  http://www.punetebrendshme.gov.al/                5.0
# 2                         http://www.interieur.gov.dz                2.0
# 3                         http://www.registrecivil.ad                1.0
# 4                          http://www.minjusdh.gov.ao                1.0
# 5                     http://www.legalaffairs.gov.ag/                1.0
# 6   http://www.mininterior.gov.ar/renaper/renaper.php                6.0
# 7   http://www.moj.am/services/civil_registry/item...                1.0
# 8   http://www.australia.gov.au/topics/law-and-jus...                1.0
# 9   https://www.help.gv.at/Portal.Node/hlpd/public...                2.0
# 10                          http://www.justice.gov.az                1.0
# 11                      http://www.bahamas.gov.bs/rgd                1.0
# 12                              http://www.moh.gov.bh                3.0
# 13                               http://br.lgd.gov.bd                6.0
# 14               http://www.barbadoslawcourts.gov.bb/                1.0
# 15         http://mvd.gov.by/ru/main.aspx?guid=152273                2.0
# 16             http://www.brussels.be/artdet.cfm/4840                2.0
# 17  http://www.belizejudiciary.org/web/supreme-cou...                1.0
# 18                                 http://www.gouv.bj                6.0
# 19  https://www.citizenservices.gov.bt/web/guest/b...                2.0
#
#    Mandatory Birth Registration Period Birth Registration cost  data_country  \
# 0                                  6 m                    free           NaN
# 1                                 60 d                100 Leke           NaN
# 2                             5 - 60 d                    free           NaN
# 3                                 15 d                    free           NaN
# 4                                  5 d                    free           NaN
# 5                                 30 d                   EC 10           NaN
# 6                                 40 d                    free           NaN
# 7                                  1 y                    free           NaN
# 8                                  6 m                    free           NaN
# 9                                  1 m                    free           NaN
# 10                                 1 m                    free           NaN
# 11                                21 d                    free           NaN
# 12                                 7 d                  BD 0.5           NaN
# 13                                45 d                    free           NaN
# 14                                42 d                    free           NaN
# 15                                 2 m                    free           NaN
# 16                                15 d                    free           NaN
# 17                             42 days                       1           NaN
# 18                                10 d                    free           NaN
# 19                                30 d                    free           NaN
#
#    data_year
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
#
# [20 rows x 23 columns]

# %%
df['Digitized ID system']= df['Digitized ID system'].replace('-',np.nan)
df['Digitized ID system']= df['Digitized ID system'].astype(float)

# %%
df.head(15)
# Out:
#       ID              Economy Region Income Code Inclusion Criteria  \
# 0    1.0          Afghanistan    SAS    LIC  AFG            INCLUDE
# 1    2.0              Albania    ECS    UMC  ALB            INCLUDE
# 2    3.0              Algeria    MEA    UMC  DZA            INCLUDE
# 3    4.0              Andorra    ECS    HIC  AND            EXCLUDE
# 4    5.0               Angola    SSF    LMC  AGO            INCLUDE
# 5    6.0  Antigua and Barbuda    LCN    HIC  ATG            INCLUDE
# 6    7.0            Argentina    LCN    UMC  ARG            INCLUDE
# 7    8.0              Armenia    ECS    LMC  ARM            INCLUDE
# 8    9.0            Australia    EAS    HIC  AUS            EXCLUDE
# 9   10.0              Austria    ECS    HIC  AUT            EXCLUDE
# 10  11.0           Azerbaijan    ECS    UMC  AZE            INCLUDE
# 11  12.0         Bahamas, The    LCN    HIC  BHS            INCLUDE
# 12  13.0              Bahrain    MEA    HIC  BHR            INCLUDE
# 13  14.0           Bangladesh    SAS    LMC  BGD            INCLUDE
# 14  15.0             Barbados    LCN    HIC  BRB            INCLUDE
#
#    National ID NID Issued at Birth Mandatory NID age  Digitized ID system  \
# 0            1                   1                 0                  1.0
# 1            1                   0                16                  1.0
# 2            1                   0                18                  1.0
# 3            0                                     -                  NaN
# 4            1                   0                10                  1.0
# 5            0                                     -                  NaN
# 6            1                   1                 0                  1.0
# 7            1                   1                16                  1.0
# 8            0                                     -                  NaN
# 9            1                   0                 0                  1.0
# 10           1                   0                16                  1.0
# 11           1                   0                 0                  0.0
# 12           1                   1                 0                  1.0
# 13           1                   0                18                  1.0
# 14           1                   0                16                  0.0
#
#     ...                                                URL  \
# 0   ...                    http://mcit.gov.af/en/page/7081
# 1   ...                  http://www.punetebrendshme.gov.al
# 2   ...                       http://www.interieur.gov.dz/
# 3   ...                                               None
# 4   ...  http://www.minjusdh.gov.ao/VerPrestadorServico...
# 5   ...                                               None
# 6   ...        http://www.nuevodni.gov.ar/inicio/index.php
# 7   ...                           https://www.ekeng.am/hy/
# 8   ...                                               None
# 9   ...  https://www.help.gv.at/Portal.Node/hlpd/public...
# 10  ...   http://www.mia.gov.az/index.php?/en/content/171/
# 11  ...  http://www.bahamas.gov.bs/wps/portal/public/!u...
# 12  ...  http://www.cio.gov.bh/CIO_ENG/SubDetailed.aspx...
# 13  ...                             http://www.nidw.gov.bd
# 14  ...  http://www.electoral.barbados.gov.bb/nationalr...
#
#                                  NID card/number name             NID cost  \
# 0                                      Tazkira / eNID  Afs 30-35 (US$ 0.5)
# 1              Letërnjoftimi / Albanian Identity Card             10 euros
# 2   Carte Nationale d'Identité Biométrique Electro...                 free
# 3                                                   -                    -
# 4            Bilhete de Identidade (National ID card)            15 kwanza
# 5                                                   -                    -
# 6   DNI (Documento Nacional de Identidad) / SIBIOS...                 free
# 7                National ID Card / National Passport                 free
# 8                                                   -                    -
# 9   Identitätsausweis / Personalausweis (Austrian ...             61.5 EUR
# 10  Azərbaycan Respublikası vətəndaşının şəxsiyyət...                 free
# 11                            Certificate of Identity                BS$25
# 12                              National ID Smartcard               varies
# 13                                   National ID Card                 free
# 14                                   National ID Card                 free
#
#                                     Primary CR entity  \
# 0                        Ministry of Interior Affairs
# 1   Vital Statistics Offices , Ministry of Interio...
# 2      Ministry of the Interior and Local Governments
# 3                               Civil Registry Office
# 4   Direcção Nacional dos Registos e do Notariado ...
# 5   Civil Registry, Ministry of Justice and Legal ...
# 6   Regional Civil Registries, Provincial Authorit...
# 7       Civil Registry Office, RA Ministry of Justice
# 8           Registrar-General, Departments of Justice
# 9                         Register Office, Baby-Point
# 10                       Civil registry office (ZAGS)
# 11                     Registrar General’s Department
# 12                                 Ministry of Health
# 13  Office of the Registrar-General, Local Governm...
# 14  Registration Department, Barbados Supreme Cour...
#
#                                     CR Gov Entity URL CR entity category  \
# 0   http://moi.gov.af/en/page/7180 , http://moi.go...                2.0
# 1                  http://www.punetebrendshme.gov.al/                5.0
# 2                         http://www.interieur.gov.dz                2.0
# 3                         http://www.registrecivil.ad                1.0
# 4                          http://www.minjusdh.gov.ao                1.0
# 5                     http://www.legalaffairs.gov.ag/                1.0
# 6   http://www.mininterior.gov.ar/renaper/renaper.php                6.0
# 7   http://www.moj.am/services/civil_registry/item...                1.0
# 8   http://www.australia.gov.au/topics/law-and-jus...                1.0
# 9   https://www.help.gv.at/Portal.Node/hlpd/public...                2.0
# 10                          http://www.justice.gov.az                1.0
# 11                      http://www.bahamas.gov.bs/rgd                1.0
# 12                              http://www.moh.gov.bh                3.0
# 13                               http://br.lgd.gov.bd                6.0
# 14               http://www.barbadoslawcourts.gov.bb/                1.0
#
#    Mandatory Birth Registration Period Birth Registration cost  data_country  \
# 0                                  6 m                    free           NaN
# 1                                 60 d                100 Leke           NaN
# 2                             5 - 60 d                    free           NaN
# 3                                 15 d                    free           NaN
# 4                                  5 d                    free           NaN
# 5                                 30 d                   EC 10           NaN
# 6                                 40 d                    free           NaN
# 7                                  1 y                    free           NaN
# 8                                  6 m                    free           NaN
# 9                                  1 m                    free           NaN
# 10                                 1 m                    free           NaN
# 11                                21 d                    free           NaN
# 12                                 7 d                  BD 0.5           NaN
# 13                                45 d                    free           NaN
# 14                                42 d                    free           NaN
#
#    data_year
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
#
# [15 rows x 23 columns]

# %%
# create standard columns
df.rename(columns={'Economy':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Year'] = 2018
df['Indicator'] = indicator
df['data_col'] = df['Digitized ID system']
df.rename(columns={'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
df
# Out:
#            Country Name  Year                        Indicator  data_col  \
# 0           Afghanistan  2018  can ID be used for transactions       1.0
# 1               Albania  2018  can ID be used for transactions       1.0
# 2               Algeria  2018  can ID be used for transactions       1.0
# 3               Andorra  2018  can ID be used for transactions       NaN
# 4                Angola  2018  can ID be used for transactions       1.0
# 5   Antigua and Barbuda  2018  can ID be used for transactions       NaN
# 6             Argentina  2018  can ID be used for transactions       1.0
# 7               Armenia  2018  can ID be used for transactions       1.0
# 8             Australia  2018  can ID be used for transactions       NaN
# 9               Austria  2018  can ID be used for transactions       1.0
# 10           Azerbaijan  2018  can ID be used for transactions       1.0
# 11         Bahamas, The  2018  can ID be used for transactions       0.0
# 12              Bahrain  2018  can ID be used for transactions       1.0
# 13           Bangladesh  2018  can ID be used for transactions       1.0
# 14             Barbados  2018  can ID be used for transactions       0.0
#
#     new_rank_score  higher_is_better
# 0              6.0              True
# 1              6.0              True
# 2              6.0              True
# 3              NaN              True
# 4              6.0              True
# 5              NaN              True
# 6              6.0              True
# 7              6.0              True
# 8              NaN              True
# 9              6.0              True
# 10             6.0              True
# 11             1.0              True
# 12             6.0              True
# 13             6.0              True
# 14             1.0              True

# %%
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 7. Is personal data siloed

# %%
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Must limit the database to the first 206 rows, the remaining rows do not contain any useful information
df = df.iloc[0:205,:]

# Drop the superfluous rows by dropping na
df = df[df['#'].notna()]

# Must convert data in the DPL column into float
df['DPL'] = df['DPL'].astype(float, errors = 'ignore')
# Out:
# Is personal data siloed
# Egov_strategy

# %%
df.head(104)
# Out:
#        # Flag Code   Cnum        Economy Level Population      GNI    GNIPC  \
# 0      1  NaN  AFG    4.0    Afghanistan   LIC     38,928   20,726      540
# 1      2  NaN  ALB    8.0        Albania  UMIC      2,878   14,949    5,240
# 2      3  NaN  DZA   12.0        Algeria  LMIC     43,851  170,722    3,970
# 3      4  NaN  ADO   20.0        Andorra   HIC         77    3,154   40,886
# 4      5  NaN  AGO   24.0         Angola  LMIC     32,866   97,005    3,050
# ..   ...  ...  ...    ...            ...   ...        ...      ...      ...
# 102   98  NaN  LSO  426.0        Lesotho  LMIC      2,142    2,901    1,360
# 104   99  NaN  LBR  430.0        Liberia   LIC      5,058    2,852      580
# 105  100  NaN  LBY  434.0          Libya  UMIC      6,871   51,757    7,640
# 106  101  NaN  LIE  438.0  Liechtenstein   HIC         38    4,160  116,430
# 107  102  NaN  LTU  440.0      Lithuania   HIC      2,722   52,926   18,990
#
#                                           e-Government  ... NGTI-1 NGTI-2  \
# 0                        https://mcit.gov.af/node/6938  ...   0.69   0.52
# 1                                https://e-albania.al/  ...   0.81   0.78
# 2    https://www.mpttn.gov.dz/ar/content/%D8%A7%D9%...  ...   0.73   0.46
# 3                                 http://www.govern.ad  ...   0.63   0.60
# 4                            http://www.governo.gov.ao  ...   0.68   0.69
# ..                                                 ...  ...    ...    ...
# 102                                  http://www.gov.ls  ...    NaN    NaN
# 104                         http://www.emansion.gov.lr  ...   0.69   0.42
# 105                               http://www.pm.gov.ly  ...   0.26   0.31
# 106                                http://regierung.li  ...   0.30   0.48
# 107                                  http://www.lrv.lt  ...   0.85   0.77
#
#     NGTI-3 NGTI-4 GTI-1 GTI-2  GTI-3  GTI-4 data_country data_year
# 0     0.31   0.62 -0.09 -0.34   0.02  -0.12          NaN       NaN
# 1     0.60   0.77  0.29  0.62   0.74   0.26          NaN       NaN
# 2     0.02   0.60  0.06 -0.56  -0.68  -0.15          NaN       NaN
# 3     0.05   0.13 -0.28 -0.06  -0.62  -1.32          NaN       NaN
# 4     0.21   0.61 -0.12  0.27  -0.23  -0.13          NaN       NaN
# ..     ...    ...   ...   ...    ...    ...          ...       ...
# 102    NaN    NaN   NaN   NaN    NaN    NaN          NaN       NaN
# 104   0.13   0.50 -0.08 -0.69  -0.42  -0.39          NaN       NaN
# 105   0.01   0.50 -1.49 -1.09  -0.71  -0.42          NaN       NaN
# 106   0.07   0.87 -1.35 -0.49  -0.57   0.51          NaN       NaN
# 107   0.96   0.90  0.43  0.57   1.64   0.59          NaN       NaN
#
# [104 rows x 332 columns]

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,205]
df['Country Name'] = df['Economy']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(107)
# Out:
#          Country Name  Year                Indicator  data_col  \
# 0         Afghanistan  2020  Is personal data siloed     -0.04
# 1             Albania  2020  Is personal data siloed      0.02
# 2             Algeria  2020  Is personal data siloed     -0.04
# 3             Andorra  2020  Is personal data siloed      0.02
# 4              Angola  2020  Is personal data siloed      0.02
# ..                ...   ...                      ...       ...
# 106     Liechtenstein  2020  Is personal data siloed      0.02
# 107         Lithuania  2020  Is personal data siloed      0.02
# 108        Luxembourg  2020  Is personal data siloed      0.02
# 109  Macao SAR, China  2020  Is personal data siloed      0.02
# 110   North Macedonia  2020  Is personal data siloed      0.02
#
#      new_rank_score  higher_is_better
# 0               1.0              True
# 1               6.0              True
# 2               1.0              True
# 3               6.0              True
# 4               6.0              True
# ..              ...               ...
# 106             6.0              True
# 107             6.0              True
# 108             6.0              True
# 109             6.0              True
# 110             6.0              True
#
# [107 rows x 6 columns]

# %% [markdown]
# ## 8. Open data index

# %%
bnames
# Out:
#                                              Indicator        check  \
# 148                       Digital payments penetration  Foundations
# 149  % of population with digital finance account -...  Foundations
# 150  % of population with digital finance account -...  Foundations
# 154                            % of population with ID  Foundations
# 155                 % of services that can be accessed  Foundations
# 156                    can ID be used for transactions  Foundations
# 157                            Is personal data siloed  Foundations
# 158                                    Open data index  Foundations
#
#                    Data Source  Index                               Filename
# 148        Portulans Institute  TRUE            digital_payments_penetration
# 149                 World Bank  False  population_digital_financial_services
# 150                 World Bank  False  population_digital_financial_services
# 154                World Bank   False                               id4d_nid
# 155                World Bank   False                          id4d_services
# 156                World Bank   False                          id4d_services
# 157                 World Bank  False                          Egov_strategy
# 158  Open Knowledge Foundation   True                          open_data_idx

# %%
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Open data index
# open_data_idx

# %%
df.head(15)
# Out:
#      id    site              name              slug  region  continent  rank  \
# 0    tw  global            Taiwan            taiwan     NaN        NaN     1
# 1    au  global         Australia         australia     NaN        NaN     2
# 2    gb  global     Great Britain    united_kingdom     NaN        NaN     2
# 3    fr  global            France            france     NaN        NaN     4
# 4    fi  global           Finland           finland     NaN        NaN     5
# 5    ca  global            Canada            canada     NaN        NaN     5
# 6    no  global            Norway            norway     NaN        NaN     5
# 7    br  global            Brazil            brazil     NaN        NaN     8
# 8    nz  global       New Zealand       new_zealand     NaN        NaN     8
# 9   nir  global  Northern Ireland  northern_ireland     NaN        NaN    10
# 10   us  global     United States     United_states     NaN        NaN    11
# 11   dk  global           Denmark           denmark     NaN        NaN    11
# 12   mx  global            Mexico            mexico     NaN        NaN    11
# 13   co  global          Colombia          colombia     NaN        NaN    14
# 14   lv  global            Latvia            latvia     NaN        NaN    14
#
#     score
# 0      90
# 1      79
# 2      79
# 3      70
# 4      69
# 5      69
# 6      69
# 7      68
# 8      68
# 9      67
# 10     65
# 11     65
# 12     65
# 13     64
# 14     64

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['score'] 
df['Country Name'] = df['name']
df['Year'] = 2016

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#         Country Name  Year        Indicator  data_col  new_rank_score  \
# 0             Taiwan  2016  Open data index        90        6.000000
# 1          Australia  2016  Open data index        79        5.382022
# 2      Great Britain  2016  Open data index        79        5.382022
# 3             France  2016  Open data index        70        4.876404
# 4            Finland  2016  Open data index        69        4.820225
# 5             Canada  2016  Open data index        69        4.820225
# 6             Norway  2016  Open data index        69        4.820225
# 7             Brazil  2016  Open data index        68        4.764045
# 8        New Zealand  2016  Open data index        68        4.764045
# 9   Northern Ireland  2016  Open data index        67        4.707865
# 10     United States  2016  Open data index        65        4.595506
# 11           Denmark  2016  Open data index        65        4.595506
# 12            Mexico  2016  Open data index        65        4.595506
# 13          Colombia  2016  Open data index        64        4.539326
# 14            Latvia  2016  Open data index        64        4.539326
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True

# %% [markdown]
# ### Score Aggregating

# %%
import os

# %%
# get list of files in scores folder
scores = os.listdir('../indicator_scores/')
scores = [s for s in scores if s.startswith('foundations')]

# %%
scores
# Out:
# ['foundations_digital_payments_penetration_scores.csv']

# %%
# create a dataframe that concatenates all these file into one table
df = pd.concat([pd.read_csv('../indicator_scores/{}'.format(s)) for s in scores])

# %%
df
# Out:
#     Country Name                     Indicator  data_col  new_rank_score  \
# 0         Norway  Digital payments penetration    100.00          6.0000
# 1        Denmark  Digital payments penetration     97.24          5.8620
# 2        Finland  Digital payments penetration     93.95          5.6975
# 3         Sweden  Digital payments penetration     93.08          5.6540
# 4    Netherlands  Digital payments penetration     89.01          5.4505
# ..           ...                           ...       ...             ...
# 129      Jamaica  Digital payments penetration       NaN             NaN
# 130   Madagascar  Digital payments penetration       NaN             NaN
# 131         Oman  Digital payments penetration       NaN             NaN
# 132        Qatar  Digital payments penetration       NaN             NaN
# 133        Yemen  Digital payments penetration       NaN             NaN
#
#      higher_is_better
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# ..                ...
# 129              True
# 130              True
# 131              True
# 132              True
# 133              True
#
# [134 rows x 5 columns]

# %%
# Data cleaning
df['new_rank_score'] = df['new_rank_score'].fillna(0)
df.sort_values(by=['Country Name'], ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country Name      134 non-null    object
#  1   Indicator         134 non-null    object
#  2   data_col          122 non-null    float64
#  3   new_rank_score    134 non-null    float64
#  4   higher_is_better  134 non-null    bool
# dtypes: bool(1), float64(2), object(2)
# memory usage: 4.4+ KB

# %%
df.head(15)
# Out:
#               Country Name                     Indicator  data_col  \
# 0                  Albania  Digital payments penetration      8.62
# 1                  Algeria  Digital payments penetration      4.16
# 2                   Angola  Digital payments penetration       NaN
# 3                Argentina  Digital payments penetration     22.93
# 4                  Armenia  Digital payments penetration     17.52
# 5                Australia  Digital payments penetration     79.37
# 6                  Austria  Digital payments penetration     59.89
# 7               Azerbaijan  Digital payments penetration      6.93
# 8                  Bahrain  Digital payments penetration     40.00
# 9               Bangladesh  Digital payments penetration     14.08
# 10                 Belarus  Digital payments penetration     46.02
# 11                 Belgium  Digital payments penetration     73.15
# 12                   Benin  Digital payments penetration     30.59
# 13                 Bolivia  Digital payments penetration     12.41
# 14  Bosnia and Herzegovina  Digital payments penetration     10.71
#
#     new_rank_score  higher_is_better
# 0           1.4310              True
# 1           1.2080              True
# 2           0.0000              True
# 3           2.1465              True
# 4           1.8760              True
# 5           4.9685              True
# 6           3.9945              True
# 7           1.3465              True
# 8           3.0000              True
# 9           1.7040              True
# 10          3.3010              True
# 11          4.6575              True
# 12          2.5295              True
# 13          1.6205              True
# 14          1.5355              True

# %%
df.describe()
# Out:
#          data_col  new_rank_score
# count  122.000000      134.000000
# mean    36.076967        2.552757
# std     24.867406        1.432577
# min      0.000000        0.000000
# 25%     16.235000        1.627375
# 50%     30.870000        2.400250
# 75%     51.110000        3.507125
# max    100.000000        6.000000

# %%
# checking country names
sorted(df['Country Name'].unique().tolist())
# Out:
# ['Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo, Dem. Rep.',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  "Côte d'Ivoire",
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Honduras',
#  'Hong Kong (China)',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran, Islamic Rep.',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea, Rep.',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Lao PDR',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Malta',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'Spain',
#  'Sri Lanka',
#  'Sweden',
#  'Switzerland',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Venezuela',
#  'Viet Nam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
# remove trailing whitespaces from country name
df['Country Name'] = df['Country Name'].str.strip()

# %%
# checking country names
sorted(df['Country Name'].unique().tolist())
# Out:
# ['Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo, Dem. Rep.',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  "Côte d'Ivoire",
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Honduras',
#  'Hong Kong (China)',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran, Islamic Rep.',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea, Rep.',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Lao PDR',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Malta',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'Spain',
#  'Sri Lanka',
#  'Sweden',
#  'Switzerland',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Venezuela',
#  'Viet Nam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
# average indicator scores per country
agg_df = df.groupby(['Country Name']).agg({'new_rank_score':'mean','data_col':'count'})

# %%
agg_df.columns = ['agg_score', 'count_source' ]

# %%
max_number_sources = agg_df.describe()['count_source']['max']

# %%
agg_df['agg_score_wt'] = agg_df['agg_score']*(agg_df['count_source']/max_number_sources)

# %%
agg_df.sort_values(by='agg_score', ascending=False, inplace=True)

# %%
agg_df.head(25)
# Out:
#                       agg_score  count_source  agg_score_wt
# Country Name
# Norway                   6.0000             1        6.0000
# Denmark                  5.8620             1        5.8620
# Finland                  5.6975             1        5.6975
# Sweden                   5.6540             1        5.6540
# Netherlands              5.4505             1        5.4505
# New Zealand              5.3365             1        5.3365
# United States            5.2200             1        5.2200
# Estonia                  5.1410             1        5.1410
# Korea, Rep.              5.1320             1        5.1320
# Canada                   5.0765             1        5.0765
# Australia                4.9685             1        4.9685
# Czech Republic           4.7825             1        4.7825
# Belgium                  4.6575             1        4.6575
# Germany                  4.5600             1        4.5600
# Poland                   4.5170             1        4.5170
# Latvia                   4.4680             1        4.4680
# Luxembourg               4.3280             1        4.3280
# Kenya                    4.3175             1        4.3175
# Switzerland              4.3115             1        4.3115
# Lithuania                4.0325             1        4.0325
# France                   4.0310             1        4.0310
# Austria                  3.9945             1        3.9945
# United Arab Emirates     3.9580             1        3.9580
# Slovakia                 3.9470             1        3.9470
# Israel                   3.9245             1        3.9245

# %%
agg_df.to_csv('../pillar_scores/foundation_scores_v0.csv')
