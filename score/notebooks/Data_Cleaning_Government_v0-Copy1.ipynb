# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False           Countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              20         25
# Foundations            7         12
# Government             9         15
# Infrastructure        39         48
# People                35         47
# Regulation             6          7
# Strategy               1          1

# %% [markdown]
# ### Foundations

# %%
bnames = names[(names.check=='Government')&(~names.Filename.isna())]#&(names.Index==False)]

# %%
bnames.head(25)
# Out:
#                                             Indicator       check  \
# 53                         Online-Service-Index (OSI)  Government
# 54                              E-Participation index  Government
# 55  Use of public services online (% of services o...  Government
# 56  What is the % change of government digitizing ...  Government
# 57          Security incidents (# of relevant issues)  Government
# 58              ICT investment as a percentage of GDP  Government
# 60  Evidence of digital strategies in/across Minst...  Government
# 62             Evidence of focus on vulnerable groups  Government
# 65  % of digital skills certifications / training ...  Government
#
#                            Data Source  Index                    Filename
# 53                                DESA   True          e_government_index
# 54                                DESA   True          e_government_index
# 55  Boston Consulting Group/SalesForce  False  digital_public_service_use
# 56                          World Bank  TRUE                Egov_strategy
# 57                        SPECOPS/CSIS  False               cyber_attacks
# 58                                OECD  False              ICT_Investment
# 60                          World Bank  False               Egov_strategy
# 62                          World Bank  False               Egov_strategy
# 65                            Coursera  False         digital_skill_level

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['e_government_index', 'digital_public_service_use',
#        'Egov_strategy', 'cyber_attacks', 'ICT_Investment',
#        'digital_skill_level'], dtype=object)

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %% [markdown]
# ### 1. Online-Service-Index (OSI)

# %%
indicators[0]
# Out:
# 'Online-Service-Index (OSI)'

# %%
# load data
indicator = indicators[0]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Online-Service-Index (OSI)
# e_government_index

# %%
df.head()
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151

# %%
# all data from 2020
df['Survey Year'].value_counts()
# Out:
# 2020    193
# Name: Survey Year, dtype: int64

# %%
# score looks like the one to use
df.describe()
# Out:
#        Survey Year  E-Government Rank  E-Government Index  \
# count        193.0         193.000000          193.000000
# mean        2020.0          97.000000            0.598767
# std            0.0          55.858452            0.214869
# min         2020.0           1.000000            0.087500
# 25%         2020.0          49.000000            0.432000
# 50%         2020.0          97.000000            0.612900
# 75%         2020.0         145.000000            0.779800
# max         2020.0         193.000000            0.975800
#
#        E-Participation Index  Online Service Index  Human Capital Index  \
# count             193.000000            193.000000           193.000000
# mean                0.567723              0.561961             0.687992
# std                 0.259592              0.249874             0.194440
# min                 0.000000              0.000000             0.000000
# 25%                 0.357100              0.352900             0.559900
# 50%                 0.571400              0.576500             0.739500
# 75%                 0.797600              0.764700             0.841400
# max                 1.000000              1.000000             1.000000
#
#        Telecommunication Infrastructure Index
# count                              193.000000
# mean                                 0.546354
# std                                  0.259358
# min                                  0.000000
# 25%                                  0.349600
# 50%                                  0.566900
# 75%                                  0.772300
# max                                  1.000000

# %%
# df.Indicator.unique()

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Online Service Index'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
# output scores to csv
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %%
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                          Country Name                   Indicator  data_col  \
# 0                               Iraq   Online-Service-Index (OSI)    0.3353
# 1                            Ireland   Online-Service-Index (OSI)    0.7706
# 2                             Israel   Online-Service-Index (OSI)    0.7471
# 3                              Italy   Online-Service-Index (OSI)    0.8294
# 4                            Jamaica   Online-Service-Index (OSI)    0.3882
# 5                              Japan   Online-Service-Index (OSI)    0.9059
# 6                             Jordan   Online-Service-Index (OSI)    0.3588
# 7                         Kazakhstan   Online-Service-Index (OSI)    0.9235
# 8                              Kenya   Online-Service-Index (OSI)    0.6765
# 9                           Kiribati   Online-Service-Index (OSI)    0.4941
# 10                            Kuwait   Online-Service-Index (OSI)    0.8412
# 11                        Kyrgyzstan   Online-Service-Index (OSI)    0.6471
# 12  Lao People's Democratic Republic   Online-Service-Index (OSI)    0.1941
# 13                            Latvia   Online-Service-Index (OSI)    0.5824
# 14                           Lebanon   Online-Service-Index (OSI)    0.4176
#
#     new_rank_score  higher_is_better
# 0           2.6765              True
# 1           4.8530              True
# 2           4.7355              True
# 3           5.1470              True
# 4           2.9410              True
# 5           5.5295              True
# 6           2.7940              True
# 7           5.6175              True
# 8           4.3825              True
# 9           3.4705              True
# 10          5.2060              True
# 11          4.2355              True
# 12          1.9705              True
# 13          3.9120              True
# 14          3.0880              True

# %% [markdown]
# ## 2. E-Participation index

# %%
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# E-Participation index
# e_government_index

# %%
df.head()
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151

# %%
df['Survey Year'].unique()
# Out:
# array([2020], dtype=int64)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,4]


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))


# output scores to csv
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %%
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                          Country Name              Indicator  data_col  \
# 0                               Iraq   E-Participation index    0.3095
# 1                            Ireland   E-Participation index    0.8571
# 2                             Israel   E-Participation index    0.7143
# 3                              Italy   E-Participation index    0.8214
# 4                            Jamaica   E-Participation index    0.3690
# 5                              Japan   E-Participation index    0.9881
# 6                             Jordan   E-Participation index    0.3333
# 7                         Kazakhstan   E-Participation index    0.8810
# 8                              Kenya   E-Participation index    0.5952
# 9                           Kiribati   E-Participation index    0.5595
# 10                            Kuwait   E-Participation index    0.9048
# 11                        Kyrgyzstan   E-Participation index    0.7143
# 12  Lao People's Democratic Republic   E-Participation index    0.2143
# 13                            Latvia   E-Participation index    0.5833
# 14                           Lebanon   E-Participation index    0.3333
#
#     new_rank_score  higher_is_better
# 0           2.5475              True
# 1           5.2855              True
# 2           4.5715              True
# 3           5.1070              True
# 4           2.8450              True
# 5           5.9405              True
# 6           2.6665              True
# 7           5.4050              True
# 8           3.9760              True
# 9           3.7975              True
# 10          5.5240              True
# 11          4.5715              True
# 12          2.0715              True
# 13          3.9165              True
# 14          2.6665              True

# %% [markdown]
# ## 3. Use of public services online (% of services online, penetration, frequency of use)

# %%
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Use of public services online (% of services online, penetration, frequency of use)
# digital_public_service_use

# %%
# drop first row
df = df.iloc[1: , :]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 1 to 31
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             31 non-null     object
#  1   Net Perception (%)  31 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 628.0+ bytes

# %%
df.head(15)
# Out:
#            Country  Net Perception (%)
# 1             UAE                   61
# 2    Saudi Arabia                   59
# 3        Singapore                  54
# 4           China                   53
# 5     New Zealand                   52
# 6     Netherlands                   51
# 7           Qatar                   51
# 8          Canada                   40
# 9          Denmark                  48
# 10          India                   45
# 11         France                   43
# 12              UK                  42
# 13          Sweden                  41
# 14       Australia                  40
# 15  United States                   39

# %%
# create the standard columns
df['higher_is_better'] = True
df['Indicator'] =  indicator
df['Country Name'] = df['Country']
# df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
df['data_col'] = df['Net Perception (%)']

# %%
# convert 1-100 %  into 1-6
min_rank = df['data_col'].min()
max_rank = df['data_col'].max()
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

df.sort_values(by='new_rank_score', ascending=False)

# prepare output
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]

# output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %%
df.head(15)
# Out:
#       Country Name                                          Indicator  \
# 1             UAE   Use of public services online (% of services o...
# 2    Saudi Arabia   Use of public services online (% of services o...
# 3        Singapore  Use of public services online (% of services o...
# 4           China   Use of public services online (% of services o...
# 5     New Zealand   Use of public services online (% of services o...
# 6     Netherlands   Use of public services online (% of services o...
# 7           Qatar   Use of public services online (% of services o...
# 8          Canada   Use of public services online (% of services o...
# 9          Denmark  Use of public services online (% of services o...
# 10          India   Use of public services online (% of services o...
# 11         France   Use of public services online (% of services o...
# 12              UK  Use of public services online (% of services o...
# 13          Sweden  Use of public services online (% of services o...
# 14       Australia  Use of public services online (% of services o...
# 15  United States   Use of public services online (% of services o...
#
#     data_col  new_rank_score  higher_is_better
# 1         61        6.000000              True
# 2         59        5.876543              True
# 3         54        5.567901              True
# 4         53        5.506173              True
# 5         52        5.444444              True
# 6         51        5.382716              True
# 7         51        5.382716              True
# 8         40        4.703704              True
# 9         48        5.197531              True
# 10        45        5.012346              True
# 11        43        4.888889              True
# 12        42        4.827160              True
# 13        41        4.765432              True
# 14        40        4.703704              True
# 15        39        4.641975              True

# %% [markdown]
# ## 4. What is the % change of government digitizing public services?

# %%
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# What is the % change of government digitizing public services?
# Egov_strategy

# %%
df.head()
# Out:
#    # Flag Code  Cnum      Economy Level Population      GNI   GNIPC  \
# 0  1  NaN  AFG   4.0  Afghanistan   LIC     38,928   20,726     540
# 1  2  NaN  ALB   8.0      Albania  UMIC      2,878   14,949   5,240
# 2  3  NaN  DZA  12.0      Algeria  LMIC     43,851  170,722   3,970
# 3  4  NaN  ADO  20.0      Andorra   HIC         77    3,154  40,886
# 4  5  NaN  AGO  24.0       Angola  LMIC     32,866   97,005   3,050
#
#                                         e-Government  ... NGTI-1 NGTI-2  \
# 0                      https://mcit.gov.af/node/6938  ...   0.69   0.52
# 1                              https://e-albania.al/  ...   0.81   0.78
# 2  https://www.mpttn.gov.dz/ar/content/%D8%A7%D9%...  ...   0.73   0.46
# 3                               http://www.govern.ad  ...   0.63   0.60
# 4                          http://www.governo.gov.ao  ...   0.68   0.69
#
#   NGTI-3 NGTI-4 GTI-1 GTI-2  GTI-3  GTI-4 data_country data_year
# 0   0.31   0.62 -0.09 -0.34   0.02  -0.12          NaN       NaN
# 1   0.60   0.77  0.29  0.62   0.74   0.26          NaN       NaN
# 2   0.02   0.60  0.06 -0.56  -0.68  -0.15          NaN       NaN
# 3   0.05   0.13 -0.28 -0.06  -0.62  -1.32          NaN       NaN
# 4   0.21   0.61 -0.12  0.27  -0.23  -0.13          NaN       NaN
#
# [5 rows x 332 columns]

# %%
df.columns.tolist()
# Out:
# ['#',
#  'Flag',
#  'Code',
#  'Cnum',
#  'Economy',
#  'Level',
#  'Population',
#  'GNI',
#  'GNIPC',
#  'e-Government',
#  'eSrv',
#  'e-Services',
#  "eGov'20",
#  "EGDI'20",
#  "eOSI'20",
#  "eTII'20",
#  "eHCI'20",
#  "ePart'20",
#  "EGDI'18",
#  "eOSI'18",
#  "eOSI'16",
#  "eOSI'14",
#  'DG Org URL',
#  'DG Entity',
#  'DG Org',
#  'DG St',
#  'DG Strategy',
#  'DG Yr',
#  'WoG',
#  'Whole of Gov URL',
#  'GT',
#  'GovTech Institution',
#  'GovTech URL',
#  'Type',
#  'GT Org',
#  'GT since',
#  'GT focus',
#  'Other GT Links',
#  'e-Gov',
#  'e-ID',
#  'GSB',
#  'e-Serv',
#  'Innov',
#  'Priv',
#  'DTech',
#  'OSS',
#  'KSL',
#  'MoF URL',
#  'Org Name',
#  'PF',
#  'Budget Data URL',
#  'MIS',
#  'FMIS URL',
#  'FMIS / TS',
#  'FMIS Name',
#  'Tpl',
#  'Func',
#  'Status',
#  'Op Yr',
#  'Scope',
#  'ASW',
#  'ASW Solution',
#  'Arch',
#  'Treasury website',
#  'Tre Yr',
#  'TSA website',
#  'TSA Yr',
#  'TSA Type',
#  'TSA Scope',
#  'Duration',
#  'TSA Benefits',
#  'TSA Savings',
#  'Sav Yr',
#  'Tax Adm URL',
#  'Tax Yr',
#  'TMIS Abbr',
#  'TMIS Name',
#  'TMIS',
#  'TMIS Soln',
#  'Tax System URL',
#  'TMIS Yr',
#  'TMIS Sta',
#  'Tax Srv',
#  'Customs URL',
#  'Cust Yr',
#  'WCO Mem',
#  'HS Sta',
#  'Customs Abbr',
#  'Customs Name',
#  'CMIS',
#  'CMIS Soln',
#  'Customs Sys URL',
#  'CMIS Yr',
#  'Cust Sta',
#  'Cust Srv',
#  'e-Filing URL',
#  'eFil Yr',
#  'eFil Srv',
#  'ePayment',
#  'ePay Yr',
#  'ePay Srv',
#  'Digital Sign URL',
#  'Dsign Yr',
#  'Dsign Sta',
#  'Public Emp',
#  'PE Scope',
#  'Pub Emp URL',
#  'PE Yr',
#  'HRMIS Abbr',
#  'HRMIS System',
#  'HRM',
#  'HRMIS Soln',
#  'HRMIS URL',
#  'HRM Yr',
#  'HRM Sta',
#  'HRM Srv',
#  'Payroll Abbr',
#  'Payroll System',
#  'Payr',
#  'Payr Soln',
#  'Payroll URL',
#  'Payr Yr',
#  'Payr Sta',
#  'Payr Srv',
#  'eProc System',
#  'eProcurement',
#  'ePrc Yr',
#  'ePrc Sta',
#  'ePr Srv',
#  'Contr Monitoring',
#  'Debt Org / URL',
#  'DMS',
#  'DMS Soln',
#  'DMS Yr',
#  'DMS Sta',
#  'DM Inst',
#  'DM OpSt',
#  'PIM Unit URL',
#  'PIM Unit Name',
#  'WB PIR',
#  'WB PIR URL',
#  'PIMA',
#  'PIMS Abbr',
#  'PIMS Name',
#  'PIMS',
#  'PIMS Soln',
#  'PIMS URL',
#  'PIMS Yr',
#  'PIMS Sta',
#  'PIMS Fun',
#  'AMP',
#  'DAD',
#  'Other',
#  'Region',
#  'FCS',
#  'NRR',
#  'Select',
#  'Zone',
#  'OECD',
#  'APEC',
#  'LenCat',
#  'Grp',
#  'DGM',
#  'Pol&Reg',
#  'Inst',
#  'Infra',
#  'Inst Yr',
#  'DGov Inst Name',
#  'DGov Inst URL',
#  'Impl',
#  'Policy',
#  'Pol Yr',
#  'DG Policy URL',
#  'Regs',
#  'Reg Yr',
#  'DG Regs URL',
#  'GCL',
#  'GCL Yr',
#  'Gov Cloud Name',
#  'Gov Cloud URL',
#  'GEA',
#  'GEA Yr',
#  'GEA Name',
#  'GEA URL',
#  'GSB Yr',
#  'Interop Platform',
#  'Interop URL',
#  'Cyber',
#  'Cyb Yr',
#  'Cybersecurity Agency',
#  'Cybersecurity URL',
#  'Part',
#  'Participation URL',
#  'Petit',
#  'Publ',
#  'Anym',
#  'Resp',
#  'GRM',
#  'GRM URL',
#  'Serv',
#  'Acce',
#  'Perf',
#  'Perf URL',
#  'Legal System Type',
#  'Leg Sys',
#  'DPL',
#  'DP Act / Bill',
#  'Act/Bill URL',
#  'From',
#  'Latest',
#  'DPA',
#  'Data Protection Agency (DPA)',
#  'DPA URL',
#  'DPA Yr',
#  'RTI',
#  'Law URL',
#  'Law Yr',
#  'Cl Pol',
#  'Cl Man',
#  'Data Cl',
#  'RTIL',
#  'Reuse',
#  'Non-P',
#  'OpenP',
#  'Acct',
#  'Indiv',
#  'Elect',
#  'Std',
#  'Data Sh',
#  'DSP',
#  'RoL Score',
#  'OpenGov',
#  '3.1 Pub',
#  '3.2 RTI',
#  '3.3. Part',
#  '3.4 Cmp',
#  'PR Rating',
#  'CL Rating',
#  'PR Score',
#  'CL Score',
#  'FIW Score',
#  'Obstac',
#  'Limits',
#  'Violat',
#  'FOTN',
#  'OGI',
#  'Open Gov URL',
#  'ODP',
#  'Open Data URL',
#  'DT',
#  'DT Fo',
#  'DT Strategy',
#  'DT StrategyURL',
#  'DT Yr',
#  'DSI',
#  'Focus',
#  'DSI Strategy Name',
#  'DSI URL',
#  'DSI Yr',
#  'Prog',
#  'Use',
#  'DSI Prg Name',
#  'DSI Program URL',
#  'PSI',
#  'PSI Institution Name',
#  'PSI Inst URL',
#  'PSI Yr',
#  'OSS Policy URL',
#  'OSS Yr',
#  'OSS Gov',
#  'RD',
#  'A',
#  'P',
#  'M',
#  'OSS Loc',
#  'Nat ID',
#  'GE',
#  'GE est',
#  'GE rank',
#  'GE src',
#  'CoC',
#  'CoC est',
#  'CoC rank',
#  'CoC src',
#  'CPI',
#  'Who',
#  'GTMI',
#  'CGSI',
#  'PSDI',
#  'CEI',
#  'GTEI',
#  'FMIS',
#  'TSA',
#  'Tax',
#  'Cust',
#  'e-GP',
#  'Debt',
#  'eTII',
#  'eOSI',
#  'TaxS',
#  'CusS',
#  'DaG',
#  'DGSt',
#  'NatID',
#  'dSign',
#  'eHCI',
#  'DSSt',
#  'Unnamed: 307',
#  'GT0',
#  'Group',
#  'eGDI',
#  'GTE',
#  'GTC',
#  'GTF',
#  'GTCs',
#  'GTFs',
#  'GovTech',
#  'Chk',
#  'Comments',
#  'Score',
#  'Rank',
#  'GTI',
#  'NGTI-1',
#  'NGTI-2',
#  'NGTI-3',
#  'NGTI-4',
#  'GTI-1',
#  'GTI-2',
#  'GTI-3',
#  'GTI-4',
#  'data_country',
#  'data_year']

# %%
# Must limit the database to the first 206 rows, the remaining rows do not contain any useful information
df = df.iloc[0:205,:]

# Drop the superfluous rows by dropping na
df = df[pd.to_numeric(df['#'], errors='coerce').notnull()]
df['#'] = df[df['#'].notna()]

# Must convert data in the DPL column into float
df['CGSI'] = df['CGSI'].replace('-',np.nan)
df['CGSI'] = df['CGSI'].astype(float, errors = 'ignore')

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['CGSI']
df['Country Name'] = df['Economy']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']]
df.head(15)
# Out:
#            Country Name  Year  \
# 0           Afghanistan  2020
# 1               Albania  2020
# 2               Algeria  2020
# 3               Andorra  2020
# 4                Angola  2020
# 5   Antigua and Barbuda  2020
# 6             Argentina  2020
# 7               Armenia  2020
# 8             Australia  2020
# 9               Austria  2020
# 11           Azerbaijan  2020
# 12              Bahamas  2020
# 13              Bahrain  2020
# 14           Bangladesh  2020
# 15             Barbados  2020
#
#                                             Indicator  data_col  \
# 0   What is the % change of government digitizing ...      0.69
# 1   What is the % change of government digitizing ...      0.79
# 2   What is the % change of government digitizing ...      0.71
# 3   What is the % change of government digitizing ...      0.58
# 4   What is the % change of government digitizing ...      0.67
# 5   What is the % change of government digitizing ...      0.68
# 6   What is the % change of government digitizing ...      0.81
# 7   What is the % change of government digitizing ...      0.73
# 8   What is the % change of government digitizing ...      0.89
# 9   What is the % change of government digitizing ...       NaN
# 11  What is the % change of government digitizing ...      0.76
# 12  What is the % change of government digitizing ...      0.72
# 13  What is the % change of government digitizing ...      0.59
# 14  What is the % change of government digitizing ...      0.81
# 15  What is the % change of government digitizing ...      0.75
#
#     new_rank_score  higher_is_better
# 0         4.520408              True
# 1         5.030612              True
# 2         4.622449              True
# 3         3.959184              True
# 4         4.418367              True
# 5         4.469388              True
# 6         5.132653              True
# 7         4.724490              True
# 8         5.540816              True
# 9              NaN              True
# 11        4.877551              True
# 12        4.673469              True
# 13        4.010204              True
# 14        5.132653              True
# 15        4.826531              True

# %%
# output scores
df.to_csv('../indicator_scores/government_percent change of government digitalizing_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 5. Security incidents (# of relevant issues)

# %%
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Security incidents (# of relevant issues)
# cyber_attacks

# %%
df.head()
# Out:
#           Country  Number of Significant Cyberattacks (2006-2020)
# 0   United States                                             156
# 1  United Kingdom                                              47
# 2           India                                              23
# 3         Germany                                              21
# 4     South Korea                                              18

# %%
# create a rank from the number of attacks fields
df['data_rank'] = df['Number of Significant Cyberattacks (2006-2020)'].rank(method='max')

# %%
df.data_rank.max()
# Out:
# 20.0

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['data_rank'] 


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# need to invert since higher rank is not better
df['new_rank_score'] = (6-df['new_rank_score'])+1

# # prepare output
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]

df.head(15)
# Out:
#       Country Name                                  Indicator  data_col  \
# 0    United States  Security incidents (# of relevant issues)      20.0
# 1   United Kingdom  Security incidents (# of relevant issues)      19.0
# 2            India  Security incidents (# of relevant issues)      18.0
# 3          Germany  Security incidents (# of relevant issues)      17.0
# 4      South Korea  Security incidents (# of relevant issues)      16.0
# 5        Australia  Security incidents (# of relevant issues)      15.0
# 6          Ukraine  Security incidents (# of relevant issues)      15.0
# 7            China  Security incidents (# of relevant issues)      13.0
# 8             Iran  Security incidents (# of relevant issues)      13.0
# 9     Saudi Arabia  Security incidents (# of relevant issues)      13.0
# 10           Japan  Security incidents (# of relevant issues)      10.0
# 11          Canada  Security incidents (# of relevant issues)       9.0
# 12          France  Security incidents (# of relevant issues)       8.0
# 13          Israel  Security incidents (# of relevant issues)       8.0
# 14        Pakistan  Security incidents (# of relevant issues)       6.0
#
#     new_rank_score  higher_is_better
# 0         1.000000              True
# 1         1.263158              True
# 2         1.526316              True
# 3         1.789474              True
# 4         2.052632              True
# 5         2.315789              True
# 6         2.315789              True
# 7         2.842105              True
# 8         2.842105              True
# 9         2.842105              True
# 10        3.631579              True
# 11        3.894737              True
# 12        4.157895              True
# 13        4.157895              True
# 14        4.684211              True

# %%
# # output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 6. ICT investment as a percentage of GDP

# %%
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# ICT investment as a percentage of GDP
# ICT_Investment

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    450 non-null    object
#  1   INDICATOR   450 non-null    object
#  2   SUBJECT     450 non-null    object
#  3   MEASURE     450 non-null    object
#  4   FREQUENCY   450 non-null    object
#  5   TIME        450 non-null    int64
#  6   Value       450 non-null    float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.2+ KB

# %%
df.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME      Value  Flag Codes
# 0      AUS  ICTINVST     TOT      PC         A  1985  12.465454         NaN
# 1      AUS  ICTINVST     TOT      PC         A  1986  13.939533         NaN
# 2      AUS  ICTINVST     TOT      PC         A  1987  14.142429         NaN
# 3      AUS  ICTINVST     TOT      PC         A  1988  14.289993         NaN
# 4      AUS  ICTINVST     TOT      PC         A  1989  15.348707         NaN

# %%
df.SUBJECT.unique()
# Out:
# array(['TOT'], dtype=object)

# %%
df.TIME.max()
# Out:
# 2010

# %%
df.Value.describe()
# Out:
# count    450.000000
# mean      16.074272
# std        5.636379
# min        2.798417
# 25%       12.410442
# 50%       14.840726
# 75%       19.419433
# max       32.601105
# Name: Value, dtype: float64

# %%
dcol = 'Value'
indicol = indicator
cname = 'LOCATION'

# filter most recent year
df = df[(df.TIME==2010)]

# create standard columns
df['higher_is_better'] = True
df['Indicator'] =  indicator
df['Country Code'] = df[cname]
# # df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
df['data_col'] = df[dcol]

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# df.sort_values(by='new_rank_score', ascending=False)

# # prepare output
df = df[['Country Code', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]

# # output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %%
df
# Out:
#     Country Code                              Indicator   data_col  \
# 72           CAN  ICT investment as a percentage of GDP  17.018367
# 121          FIN  ICT investment as a percentage of GDP  15.519828
# 172          DEU  ICT investment as a percentage of GDP  12.690394
# 198          IRL  ICT investment as a percentage of GDP  12.412805
# 224          ITA  ICT investment as a percentage of GDP  11.026056
# 274          KOR  ICT investment as a percentage of GDP  10.716026
# 323          NZL  ICT investment as a percentage of GDP  21.238183
# 349          ESP  ICT investment as a percentage of GDP  13.763415
# 400          CHE  ICT investment as a percentage of GDP  18.506691
# 449          USA  ICT investment as a percentage of GDP  32.137836
#
#      new_rank_score  higher_is_better
# 72         2.471010              True
# 121        2.121241              True
# 172        1.460831              True
# 198        1.396040              True
# 224        1.072363              True
# 274        1.000000              True
# 323        3.455945              True
# 349        1.711282              True
# 400        2.818396              True
# 449        6.000000              True

# %% [markdown]
# ## 7. Evidence of digital strategies in/across Ministries

# %%
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Evidence of digital strategies in/across Minstries
# Egov_strategy

# %%
df.head()
# Out:
#    # Flag Code  Cnum      Economy Level Population      GNI   GNIPC  \
# 0  1  NaN  AFG   4.0  Afghanistan   LIC     38,928   20,726     540
# 1  2  NaN  ALB   8.0      Albania  UMIC      2,878   14,949   5,240
# 2  3  NaN  DZA  12.0      Algeria  LMIC     43,851  170,722   3,970
# 3  4  NaN  ADO  20.0      Andorra   HIC         77    3,154  40,886
# 4  5  NaN  AGO  24.0       Angola  LMIC     32,866   97,005   3,050
#
#                                         e-Government  ... NGTI-1 NGTI-2  \
# 0                      https://mcit.gov.af/node/6938  ...   0.69   0.52
# 1                              https://e-albania.al/  ...   0.81   0.78
# 2  https://www.mpttn.gov.dz/ar/content/%D8%A7%D9%...  ...   0.73   0.46
# 3                               http://www.govern.ad  ...   0.63   0.60
# 4                          http://www.governo.gov.ao  ...   0.68   0.69
#
#   NGTI-3 NGTI-4 GTI-1 GTI-2  GTI-3  GTI-4 data_country data_year
# 0   0.31   0.62 -0.09 -0.34   0.02  -0.12          NaN       NaN
# 1   0.60   0.77  0.29  0.62   0.74   0.26          NaN       NaN
# 2   0.02   0.60  0.06 -0.56  -0.68  -0.15          NaN       NaN
# 3   0.05   0.13 -0.28 -0.06  -0.62  -1.32          NaN       NaN
# 4   0.21   0.61 -0.12  0.27  -0.23  -0.13          NaN       NaN
#
# [5 rows x 332 columns]

# %%
# Must limit the database to the first 206 rows, the remaining rows do not contain any useful information
df = df.iloc[0:205,:]

# Drop the superfluous rows by dropping na
df = df[pd.to_numeric(df['#'], errors='coerce').notnull()]
df['#'] = df[df['#'].notna()]

# Must convert data in the DPL column into float
df['DG St'] = df['DG St'].replace('-',np.nan)
df['DG St'] = df['DG St'].astype(float, errors = 'ignore')

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['DG St']
df['Country Name'] = df['Economy']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

max_rank
# Out:
# 3.0

# %%
# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']]
df.head(15)
# Out:
#            Country Name  Year  \
# 0           Afghanistan  2020
# 1               Albania  2020
# 2               Algeria  2020
# 3               Andorra  2020
# 4                Angola  2020
# 5   Antigua and Barbuda  2020
# 6             Argentina  2020
# 7               Armenia  2020
# 8             Australia  2020
# 9               Austria  2020
# 11           Azerbaijan  2020
# 12              Bahamas  2020
# 13              Bahrain  2020
# 14           Bangladesh  2020
# 15             Barbados  2020
#
#                                             Indicator  data_col  \
# 0   Evidence of digital strategies in/across Minst...       2.0
# 1   Evidence of digital strategies in/across Minst...       3.0
# 2   Evidence of digital strategies in/across Minst...       2.0
# 3   Evidence of digital strategies in/across Minst...       3.0
# 4   Evidence of digital strategies in/across Minst...       2.0
# 5   Evidence of digital strategies in/across Minst...       1.0
# 6   Evidence of digital strategies in/across Minst...       3.0
# 7   Evidence of digital strategies in/across Minst...       1.0
# 8   Evidence of digital strategies in/across Minst...       3.0
# 9   Evidence of digital strategies in/across Minst...       3.0
# 11  Evidence of digital strategies in/across Minst...       3.0
# 12  Evidence of digital strategies in/across Minst...       1.0
# 13  Evidence of digital strategies in/across Minst...       2.0
# 14  Evidence of digital strategies in/across Minst...       3.0
# 15  Evidence of digital strategies in/across Minst...       2.0
#
#     new_rank_score  higher_is_better
# 0         4.333333              True
# 1         6.000000              True
# 2         4.333333              True
# 3         6.000000              True
# 4         4.333333              True
# 5         2.666667              True
# 6         6.000000              True
# 7         2.666667              True
# 8         6.000000              True
# 9         6.000000              True
# 11        6.000000              True
# 12        2.666667              True
# 13        4.333333              True
# 14        6.000000              True
# 15        4.333333              True

# %%
# # output scores
df.to_csv('../indicator_scores/government_Evidence of digital strategies_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 8. Evidence of focus on vulnerable groups

# %%
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

df = df.iloc[1:,:]
# Out:
# Evidence of focus on vulnerable groups
# Egov_strategy

# %%
df.head()
# Out:
#    # Flag Code  Cnum              Economy Level Population      GNI   GNIPC  \
# 1  2  NaN  ALB   8.0              Albania  UMIC      2,878   14,949   5,240
# 2  3  NaN  DZA  12.0              Algeria  LMIC     43,851  170,722   3,970
# 3  4  NaN  ADO  20.0              Andorra   HIC         77    3,154  40,886
# 4  5  NaN  AGO  24.0               Angola  LMIC     32,866   97,005   3,050
# 5  6  NaN  ATG  28.0  Antigua and Barbuda   HIC         98    1,618  16,660
#
#                                         e-Government  ... NGTI-1 NGTI-2  \
# 1                              https://e-albania.al/  ...   0.81   0.78
# 2  https://www.mpttn.gov.dz/ar/content/%D8%A7%D9%...  ...   0.73   0.46
# 3                               http://www.govern.ad  ...   0.63   0.60
# 4                          http://www.governo.gov.ao  ...   0.68   0.69
# 5                               http://www.ab.gov.ag  ...   0.72   0.55
#
#   NGTI-3 NGTI-4 GTI-1 GTI-2  GTI-3  GTI-4 data_country data_year
# 1   0.60   0.77  0.29  0.62   0.74   0.26          NaN       NaN
# 2   0.02   0.60  0.06 -0.56  -0.68  -0.15          NaN       NaN
# 3   0.05   0.13 -0.28 -0.06  -0.62  -1.32          NaN       NaN
# 4   0.21   0.61 -0.12  0.27  -0.23  -0.13          NaN       NaN
# 5   0.05   0.42  0.00 -0.23  -0.62  -0.59          NaN       NaN
#
# [5 rows x 332 columns]

# %%
# Must limit the database to the first 206 rows, the remaining rows do not contain any useful information
df = df.iloc[0:205,:]

# Drop the superfluous rows by dropping na
df = df[pd.to_numeric(df['#'], errors='coerce').notnull()]
df['#'] = df[df['#'].notna()]

# Must convert data in the DPL column into float
df['WoG'] = df['WoG'].replace('-',np.nan)
df['WoG'] = df['WoG'].astype(float, errors = 'ignore')

# %%
df['WoG'].describe
# Out:
# <bound method NDFrame.describe of 1      0.03
# 2     -0.03
# 3     -0.03
# 4      0.03
# 5     -0.03
#        ...
# 200    0.03
# 201   -0.03
# 202   -0.03
# 203   -0.03
# 204   -0.03
# Name: WoG, Length: 197, dtype: float64>

# %%
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['WoG']
df['Country Name'] = df['Economy']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

max_rank
# Out:
# 0.09

# %%
# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df = df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']]
df.head(15)
# Out:
#            Country Name  Year                               Indicator  \
# 1               Albania  2020  Evidence of focus on vulnerable groups
# 2               Algeria  2020  Evidence of focus on vulnerable groups
# 3               Andorra  2020  Evidence of focus on vulnerable groups
# 4                Angola  2020  Evidence of focus on vulnerable groups
# 5   Antigua and Barbuda  2020  Evidence of focus on vulnerable groups
# 6             Argentina  2020  Evidence of focus on vulnerable groups
# 7               Armenia  2020  Evidence of focus on vulnerable groups
# 8             Australia  2020  Evidence of focus on vulnerable groups
# 9               Austria  2020  Evidence of focus on vulnerable groups
# 11           Azerbaijan  2020  Evidence of focus on vulnerable groups
# 12              Bahamas  2020  Evidence of focus on vulnerable groups
# 13              Bahrain  2020  Evidence of focus on vulnerable groups
# 14           Bangladesh  2020  Evidence of focus on vulnerable groups
# 15             Barbados  2020  Evidence of focus on vulnerable groups
# 16              Belarus  2020  Evidence of focus on vulnerable groups
#
#     data_col  new_rank_score  higher_is_better
# 1       0.03             3.5              True
# 2      -0.03             1.0              True
# 3      -0.03             1.0              True
# 4       0.03             3.5              True
# 5      -0.03             1.0              True
# 6       0.03             3.5              True
# 7      -0.03             1.0              True
# 8       0.09             6.0              True
# 9       0.09             6.0              True
# 11     -0.03             1.0              True
# 12     -0.03             1.0              True
# 13      0.03             3.5              True
# 14      0.03             3.5              True
# 15     -0.03             1.0              True
# 16      0.03             3.5              True

# %%
# # output scores
df.to_csv('../indicator_scores/government_{}_scores.csv'.format(indicator), index=False)

# %% [markdown]
# ## 9. % of digital skills certifications / training courses completed

# %%
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of digital skills certifications / training courses completed
# digital_skill_level

# %%
df
# Out:
#      Global Rank                           Region Country and Region  Year  \
# 0              1                           Europe        Switzerland  2020
# 1              2                           Europe         Luxembourg  2020
# 2              3                           Europe            Austria  2020
# 3              4                     Asia Pacific              Japan  2020
# 4              5                           Europe            Germany  2020
# ..           ...                              ...                ...   ...
# 103          104                     Asia Pacific         Uzbekistan  2020
# 104          105               Sub-Saharan Africa       Sierra Leone  2020
# 105          106  Latin America and the Caribbean           Paraguay  2020
# 106          107  Latin America and the Caribbean             Guyana  2020
# 107          108               Sub-Saharan Africa            Somalia  2020
#
#     Technology Data Science
# 0          84%          96%
# 1          62%          85%
# 2          88%          95%
# 3         100%          88%
# 4          89%          94%
# ..         ...          ...
# 103         6%           9%
# 104         2%           4%
# 105         7%          11%
# 106         8%           2%
# 107         1%           1%
#
# [108 rows x 6 columns]

# %%
dcol = 'Global Rank'
indicol = indicator
cname = 'Country and Region'

# filter most recent year
# df = df[(df.TIME==2010)]

# create standard columns
df['higher_is_better'] = True
df['Indicator'] =  indicator
df['Country Name'] = df[cname]
# # df['2019 [YR2019]'] = df['2019 [YR2019]'].astype(float)
df['data_col'] = df[dcol]

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 1-20 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# # need to invert score since higher rank is not better 
df['new_rank_score'] = (6-df['new_rank_score'])+1

df.sort_values(by='new_rank_score', ascending=False)

# # prepare output
df = df[['Country Name', 'Indicator', 'data_col', 'new_rank_score','higher_is_better']]

# # output scores
df.to_csv('../indicator_scores/government_ percentage digital skills certifications_scores.csv'.format(indicator), index=False)

# %%
df
# Out:
#      Country Name                                          Indicator  \
# 0     Switzerland  % of digital skills certifications / training ...
# 1      Luxembourg  % of digital skills certifications / training ...
# 2         Austria  % of digital skills certifications / training ...
# 3           Japan  % of digital skills certifications / training ...
# 4         Germany  % of digital skills certifications / training ...
# ..            ...                                                ...
# 103    Uzbekistan  % of digital skills certifications / training ...
# 104  Sierra Leone  % of digital skills certifications / training ...
# 105      Paraguay  % of digital skills certifications / training ...
# 106        Guyana  % of digital skills certifications / training ...
# 107       Somalia  % of digital skills certifications / training ...
#
#      data_col  new_rank_score  higher_is_better
# 0           1        6.000000              True
# 1           2        5.953271              True
# 2           3        5.906542              True
# 3           4        5.859813              True
# 4           5        5.813084              True
# ..        ...             ...               ...
# 103       104        1.186916              True
# 104       105        1.140187              True
# 105       106        1.093458              True
# 106       107        1.046729              True
# 107       108        1.000000              True
#
# [108 rows x 5 columns]

# %% [markdown]
# ### Score Aggregating

# %%
import os

# %%
# get list of files in scores folder
scores = os.listdir('../indicator_scores/')
scores = [s for s in scores if s.startswith('government')]

# %%
scores
# Out:
# ['government_ percentage digital skills certifications_scores.csv',
#  'government_E-Participation index_scores.csv',
#  'government_Evidence of digital strategies_scores.csv',
#  'government_Evidence of focus on vulnerable groups_scores.csv',
#  'government_ICT investment as a percentage of GDP_scores.csv',
#  'government_Online-Service-Index (OSI)_scores.csv',
#  'government_percent change of government digitalizing_scores.csv',
#  'government_Security incidents (# of relevant issues)_scores.csv',
#  'government_Use of public services online (% of services online, penetration, frequency of use)_scores.csv']

# %%
# create a dataframe that concatenates all these file into one table
df = pd.concat([pd.read_csv('../indicator_scores/{}'.format(s)) for s in scores])

# %%
df
# Out:
#    Country Name                                          Indicator  data_col  \
# 0   Switzerland  % of digital skills certifications / training ...       1.0
# 1    Luxembourg  % of digital skills certifications / training ...       2.0
# 2       Austria  % of digital skills certifications / training ...       3.0
# 3         Japan  % of digital skills certifications / training ...       4.0
# 4       Germany  % of digital skills certifications / training ...       5.0
# ..          ...                                                ...       ...
# 26     Germany   Use of public services online (% of services o...      17.0
# 27   Argentina   Use of public services online (% of services o...      15.0
# 28     Morocco   Use of public services online (% of services o...      -2.0
# 29  Switzerland  Use of public services online (% of services o...     -18.0
# 30       Japan   Use of public services online (% of services o...     -20.0
#
#     new_rank_score  higher_is_better  Year Country Code
# 0         6.000000              True   NaN          NaN
# 1         5.953271              True   NaN          NaN
# 2         5.906542              True   NaN          NaN
# 3         5.859813              True   NaN          NaN
# 4         5.813084              True   NaN          NaN
# ..             ...               ...   ...          ...
# 26        3.283951              True   NaN          NaN
# 27        3.160494              True   NaN          NaN
# 28        2.111111              True   NaN          NaN
# 29        1.123457              True   NaN          NaN
# 30        1.000000              True   NaN          NaN
#
# [1148 rows x 7 columns]

# %%
# Data cleaning
df['new_rank_score'] = df['new_rank_score'].fillna(0)
df.sort_values(by=['Country Name'], ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country Name      1138 non-null   object
#  1   Indicator         1148 non-null   object
#  2   data_col          1141 non-null   float64
#  3   new_rank_score    1148 non-null   float64
#  4   higher_is_better  1148 non-null   bool
#  5   Year              593 non-null    float64
#  6   Country Code      10 non-null     object
# dtypes: bool(1), float64(3), object(3)
# memory usage: 55.1+ KB

# %%
df.head(15)
# Out:
#    Country Name                                          Indicator  data_col  \
# 0   Afghanistan                              E-Participation index    0.4643
# 1   Afghanistan  Evidence of digital strategies in/across Minst...    2.0000
# 2   Afghanistan                         Online-Service-Index (OSI)    0.4118
# 3   Afghanistan  What is the % change of government digitizing ...    0.6900
# 4       Albania  Evidence of digital strategies in/across Minst...    3.0000
# 5       Albania  What is the % change of government digitizing ...    0.7900
# 6       Albania             Evidence of focus on vulnerable groups    0.0300
# 7      Albania                               E-Participation index    0.8452
# 8      Albania                          Online-Service-Index (OSI)    0.8412
# 9       Algeria             Evidence of focus on vulnerable groups   -0.0300
# 10      Algeria  What is the % change of government digitizing ...    0.7100
# 11      Algeria  % of digital skills certifications / training ...   95.0000
# 12      Algeria  Evidence of digital strategies in/across Minst...    2.0000
# 13     Algeria                          Online-Service-Index (OSI)    0.2765
# 14     Algeria                               E-Participation index    0.1548
#
#     new_rank_score  higher_is_better    Year Country Code
# 0         3.321500              True     NaN          NaN
# 1         4.333333              True  2020.0          NaN
# 2         3.059000              True     NaN          NaN
# 3         4.520408              True  2020.0          NaN
# 4         6.000000              True  2020.0          NaN
# 5         5.030612              True  2020.0          NaN
# 6         3.500000              True  2020.0          NaN
# 7         5.226000              True     NaN          NaN
# 8         5.206000              True     NaN          NaN
# 9         1.000000              True  2020.0          NaN
# 10        4.622449              True  2020.0          NaN
# 11        1.607477              True     NaN          NaN
# 12        4.333333              True  2020.0          NaN
# 13        2.382500              True     NaN          NaN
# 14        1.774000              True     NaN          NaN

# %%
df.describe()
# Out:
#           data_col  new_rank_score    Year
# count  1141.000000     1148.000000   593.0
# mean      7.083916        3.793531  2020.0
# std      19.214432        1.664582     0.0
# min     -20.000000        0.000000  2020.0
# 25%       0.261900        2.607000  2020.0
# 50%       0.720000        4.088000  2020.0
# 75%       2.000000        5.183673  2020.0
# max     108.000000        6.000000  2020.0

# %%
# checking country names
# sorted(df['Country Name'].unique().tolist())

# %%
# remove trailing whitespaces from country name
df['Country Name'] = df['Country Name'].str.strip()

# %%
df.head()
# Out:
#   Country Name                                          Indicator  data_col  \
# 0  Afghanistan                              E-Participation index    0.4643
# 1  Afghanistan  Evidence of digital strategies in/across Minst...    2.0000
# 2  Afghanistan                         Online-Service-Index (OSI)    0.4118
# 3  Afghanistan  What is the % change of government digitizing ...    0.6900
# 4      Albania  Evidence of digital strategies in/across Minst...    3.0000
#
#    new_rank_score  higher_is_better    Year Country Code
# 0        3.321500              True     NaN          NaN
# 1        4.333333              True  2020.0          NaN
# 2        3.059000              True     NaN          NaN
# 3        4.520408              True  2020.0          NaN
# 4        6.000000              True  2020.0          NaN

# %%
# checking country names
# sorted(df['Country Name'].unique().tolist())

# %%
# average indicator scores per country
agg_df = df.groupby(['Country Name']).agg({'new_rank_score':'mean','data_col':'count'})

# %%
agg_df.columns = ['agg_score', 'count_source' ]

# %%
max_number_sources = agg_df.describe()['count_source']['max']

# %%
agg_df['agg_score_wt'] = agg_df['agg_score']*(agg_df['count_source']/max_number_sources)

# %%
agg_df.sort_values(by='agg_score', ascending=False, inplace=True)

# %%
agg_df.head(25)
# Out:
#                                                     agg_score  count_source  \
# Country Name
# North Korea                                          6.000000             1
# UAE                                                  6.000000             1
# Korea, Rep.                                          5.965986             3
# United Kingdom of Great Britain and Northern Ir...   5.837500             2
# Finland                                              5.766560             6
# Denmark                                              5.741112             7
# Estonia                                              5.679981             6
# Netherlands                                          5.668561             7
# United States of America                             5.552542             5
# Singapore                                            5.546862             7
# New Zealand                                          5.536375             7
# Sweden                                               5.526271             7
# Iceland                                              5.476063             5
# Norway                                               5.473337             7
# Slovenia                                             5.148776             5
# Hong Kong                                            5.091244             2
# Malta                                                5.083876             5
# Italy                                                5.081973             6
# Spain                                                5.077217             6
# Republic of Korea                                    5.034268             3
# United Arab Emirates                                 5.032558             6
# France                                               5.027638             8
# Australia                                            5.013495             8
# Vietnam                                              5.013085             5
# Luxembourg                                           5.012414             6
#
#                                                     agg_score_wt
# Country Name
# North Korea                                             0.750000
# UAE                                                     0.750000
# Korea, Rep.                                             2.237245
# United Kingdom of Great Britain and Northern Ir...      1.459375
# Finland                                                 4.324920
# Denmark                                                 5.023473
# Estonia                                                 4.259985
# Netherlands                                             4.959991
# United States of America                                3.470339
# Singapore                                               4.853504
# New Zealand                                             4.844328
# Sweden                                                  4.835487
# Iceland                                                 3.422540
# Norway                                                  4.789170
# Slovenia                                                3.217985
# Hong Kong                                               1.272811
# Malta                                                   3.177422
# Italy                                                   3.811480
# Spain                                                   3.807912
# Republic of Korea                                       1.887850
# United Arab Emirates                                    3.774418
# France                                                  5.027638
# Australia                                               5.013495
# Vietnam                                                 3.133178
# Luxembourg                                              3.759311

# %%
agg_df.to_csv('../pillar_scores/government_scores_v0.csv')
