# %%
import pandas as pd
import numpy as np

# %%
### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False           Countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              20         25
# Foundations            9         12
# Government            10         15
# Infrastructure        39         48
# People                39         47
# Regulation             6          7
# Strategy               1          1

# %%
### People

# %%
bnames = names[(names.check=='People')&(~names.Filename.isna())]#&(names.Index==False)]
bnames
# Out:
#                                              Indicator   check  \
# 99                           Human Capital Index (HCI)  People
# 100               % of population using internet (all)  People
# 101            % of population using internet (female)  People
# 102              % of population using internet (male)  People
# 103                      SDG 4.4 Digital literacy data  People
# 104                UNDP Human Development Index (HDI)   People
# 105                Facebook Social Connectedness Index  People
# 106  Share of individuals using the Internet to int...  People
# 107  Level of satisfaction for online public servic...  People
# 108  Number of mobile apps available in national la...  People
# 109  Device Addiction (time of use on internet / on...  People
# 110                           Gross National Wellbeing  People
# 112         % of internet users who own cryptocurrency  People
# 115  Percentage of individuals not buying online du...  People
# 116  Percentage of individuals not buying online du...  People
# 117        E-waste generated, kilograms per inhabitant  People
# 118                        Automation-led unemployment  People
# 122                                      Cyberbullying  People
# 126  Global Wellbeing Initiative (World Happiness I...  People
# 127                            Financial Inclusiveness  People
# 128  E-commerce activity (% of individuals buying o...  People
# 129  E-commerce activity (Types of goods and servic...  People
# 130                               Top Visited websites  People
# 131                               Top YouTube Searches  People
# 132                                Top Google searches  People
# 133                                     Internet Usage  People
# 134  Households with a computer and with Internet a...  People
# 135                     % of population using Facebook  People
# 136                    Gender gap for social media use  People
# 137   % of population using digital financial services  People
# 138                Mobile Broadband Pricing (pre-paid)  People
# 139         Tax as % of total cost of mobile ownership  People
# 140                    % of population with a SIM card  People
# 141                  % of population with a smartphone  People
# 142                       Gender gap in internet usage  People
# 143                         Gender gap in mobile usage  People
# 144                          Mobile Device Penetration  People
# 145                 Mobile Device Penetration (female)  People
# 146                              Crypto Adoption Index  People
#
#                                            Data Source  Index  \
# 99                                                DESA   True
# 100                                                ITU  False
# 101                                                ITU  False
# 102                                                ITU  False
# 103                                             UNESCO  False
# 104                                               UNDP   True
# 105                                           Facebook   True
# 106                                               OECD  False
# 107                 Boston Consulting Group/SalesForce  False
# 108                     GSMA Mobile Connectivity Index  False
# 109  Statista/DataReportal; Hootsuite; We Are Social\n  False
# 110                                Portulans Institute  TRUE
# 112                                           Statista  False
# 115                                               OECD  False
# 116                                               OECD  False
# 117                                         UNU UNITAR   True
# 118                          McKinsey Global Institute  False
# 122                                              IPSOS  False
# 126                             World Happiness Report  TRUE
# 127                                         World Bank  TRUE
# 128                                Portulans Institute  False
# 129                   Statista/Salesforce Research\n\n  False
# 130                                      Data Reportal  False
# 131                                      Data Reportal  False
# 132                                      Data Reportal  False
# 133                                                ITU  False
# 134                                                ITU  False
# 135                            World Population Review  False
# 136                     GSMA Mobile Connectivity Index  False
# 137                                         World Bank  False
# 138                                                ITU  False
# 139                     GSMA Mobile Connectivity Index  False
# 140                                                ITU  False
# 141                                    Statista/Newzoo  False
# 142                                                ITU  False
# 143                                                ITU  False
# 144                                                ITU  False
# 145                     GSMA Mobile Connectivity Index  False
# 146                                      Chainanalysis  TRUE
#
#                                              Filename
# 99                                 e_government_index
# 100                                      ITU_database
# 101                                      ITU_database
# 102                                      ITU_database
# 103                         SDG_digital_literacy_data
# 104                             undp_human_developmnt
# 105                           fb_social_connectedness
# 106           population_interacting_public_officials
# 107                        digital_public_service_use
# 108                         apps_in_national_language
# 109                                 time_spent_online
# 110                                   happiness_score
# 112                           cryptocurrency_adoption
# 115         not_buying_online_concern_about_returning
# 116          not_buying_online_concern_about_security
# 117                             ewaste_per_inhabitant
# 118                       automation_led_unemployment
# 122                                cyberbullying_rate
# 126                       global_wellbeing_initiative
# 127                           financial_inclusiveness
# 128               individuals_buying_online_frequency
# 129                               e-commerce_activity
# 130                                         top_sites
# 131                                  youtube_searches
# 132                                     google_trends
# 133                                      ITU_database
# 134                                      ITU_database
# 135                                          FB_users
# 136                                       gender_gaps
# 137             population_digital_financial_services
# 138                                      ITU_database
# 139                      tax_percent_mobile_ownership
# 140                                      ITU_database
# 141                       population_with_smartphones
# 142                                      ITU_database
# 143                                      ITU_database
# 144                                      ITU_database
# 145                                       gender_gaps
# 146  Chainalysis_2020_Geography_Cryptocurrency_Report

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['e_government_index', 'ITU_database', 'SDG_digital_literacy_data',
#        'undp_human_developmnt', 'fb_social_connectedness',
#        'population_interacting_public_officials',
#        'digital_public_service_use', 'apps_in_national_language',
#        'time_spent_online', 'happiness_score', 'cryptocurrency_adoption',
#        'not_buying_online_concern_about_returning',
#        'not_buying_online_concern_about_security',
#        'ewaste_per_inhabitant', 'automation_led_unemployment',
#        'cyberbullying_rate', 'global_wellbeing_initiative',
#        'financial_inclusiveness', 'individuals_buying_online_frequency',
#        'e-commerce_activity', 'top_sites', 'youtube_searches',
#        'google_trends', 'FB_users', 'gender_gaps',
#        'population_digital_financial_services',
#        'tax_percent_mobile_ownership', 'population_with_smartphones',
#        'Chainalysis_2020_Geography_Cryptocurrency_Report'], dtype=object)

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %%
### 1. Human Capital Index (HCI)

# %%
indicators[0]

# load data
indicator = indicators[0]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Human Capital Index (HCI)
# e_government_index

# %%
df.head(10)
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
# 5         2020       Japan                  14              0.8989
# 6         2020      Jordan                 117              0.5309
# 7         2020  Kazakhstan                  29              0.8375
# 8         2020       Kenya                 116              0.5326
# 9         2020    Kiribati                 145              0.4320
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
# 5                 0.9881                0.9059               0.8684
# 6                 0.3333                0.3588               0.6800
# 7                 0.8810                0.9235               0.8866
# 8                 0.5952                0.6765               0.5812
# 9                 0.5595                0.4941               0.6778
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151
# 5                                  0.9223
# 6                                  0.5540
# 7                                  0.7024
# 8                                  0.3402
# 9                                  0.1241

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Human Capital Index'] 
df['Year'] = df['Survey Year']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                          Country Name  Year                  Indicator  \
# 0                               Iraq   2020  Human Capital Index (HCI)
# 1                            Ireland   2020  Human Capital Index (HCI)
# 2                             Israel   2020  Human Capital Index (HCI)
# 3                              Italy   2020  Human Capital Index (HCI)
# 4                            Jamaica   2020  Human Capital Index (HCI)
# 5                              Japan   2020  Human Capital Index (HCI)
# 6                             Jordan   2020  Human Capital Index (HCI)
# 7                         Kazakhstan   2020  Human Capital Index (HCI)
# 8                              Kenya   2020  Human Capital Index (HCI)
# 9                           Kiribati   2020  Human Capital Index (HCI)
# 10                            Kuwait   2020  Human Capital Index (HCI)
# 11                        Kyrgyzstan   2020  Human Capital Index (HCI)
# 12  Lao People's Democratic Republic   2020  Human Capital Index (HCI)
# 13                            Latvia   2020  Human Capital Index (HCI)
# 14                           Lebanon   2020  Human Capital Index (HCI)
#
#     data_col  new_rank_score  higher_is_better
# 0     0.4358          3.1790              True
# 1     0.9494          5.7470              True
# 2     0.8924          5.4620              True
# 3     0.8466          5.2330              True
# 4     0.7142          4.5710              True
# 5     0.8684          5.3420              True
# 6     0.6800          4.4000              True
# 7     0.8866          5.4330              True
# 8     0.5812          3.9060              True
# 9     0.6778          4.3890              True
# 10    0.7470          4.7350              True
# 11    0.7873          4.9365              True
# 12    0.5539          3.7695              True
# 13    0.9172          5.5860              True
# 14    0.6567          4.2835              True

# %%
### 2. % of population using internet (all)

# %%
indicators[1]

# load data
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population using internet (all)
# ITU_database

# %%
df.head(150)
# Out:
#              Country  Region  ISO  \
# 0             Angola  Africa  AGO
# 1              Benin  Africa  BEN
# 2           Botswana  Africa  BWA
# 3       Burkina Faso  Africa  BFA
# 4            Burundi  Africa  BDI
# ..               ...     ...  ...
# 145  North Macedonia  Europe  MKD
# 146           Norway  Europe  NOR
# 147           Poland  Europe  POL
# 148         Portugal  Europe  PRT
# 149          Romania  Europe  ROU
#
#                                         Indicator name    Year  Value  \
# 0    Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1    Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2    Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3    Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4    Female mobile phone ownership as a % of total ...  2010.0    NaN
# ..                                                 ...     ...    ...
# 145  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 146  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 147  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 148  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 149  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#      data_country  data_year
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
# ..            ...        ...
# 145           NaN        NaN
# 146           NaN        NaN
# 147           NaN        NaN
# 148           NaN        NaN
# 149           NaN        NaN
#
# [150 rows x 8 columns]

# %%
df = df[(df.Year==2019)]
df = df[(df.iloc[:,3] =='Internet users: 25-74 years as a % of all 25-74 years')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Country Name'] = df['Country']


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(100)
# Out:
#          Country Name    Year                             Indicator  \
# 7750           Angola  2019.0  % of population using internet (all)
# 7751            Benin  2019.0  % of population using internet (all)
# 7752         Botswana  2019.0  % of population using internet (all)
# 7753     Burkina Faso  2019.0  % of population using internet (all)
# 7754          Burundi  2019.0  % of population using internet (all)
# ...               ...     ...                                   ...
# 7845            Samoa  2019.0  % of population using internet (all)
# 7846        Singapore  2019.0  % of population using internet (all)
# 7847  Solomon Islands  2019.0  % of population using internet (all)
# 7848        Sri Lanka  2019.0  % of population using internet (all)
# 7849         Thailand  2019.0  % of population using internet (all)
#
#        data_col  new_rank_score  higher_is_better
# 7750        NaN             NaN              True
# 7751        NaN             NaN              True
# 7752        NaN             NaN              True
# 7753        NaN             NaN              True
# 7754        NaN             NaN              True
# ...         ...             ...               ...
# 7845        NaN             NaN              True
# 7846        NaN             NaN              True
# 7847        NaN             NaN              True
# 7848        NaN             NaN              True
# 7849  63.749684        3.080025              True
#
# [100 rows x 6 columns]

# %%
### 3. % of population using internet (female)

# %%
indicators[2]

# load data
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population using internet (female)
# ITU_database

# %%
df.head(10)

# Must convert the string in the dataset to float
# Out:
#                 Country  Region  ISO  \
# 0                Angola  Africa  AGO
# 1                 Benin  Africa  BEN
# 2              Botswana  Africa  BWA
# 3          Burkina Faso  Africa  BFA
# 4               Burundi  Africa  BDI
# 5            Cabo Verde  Africa  CPV
# 6              Cameroon  Africa  CMR
# 7  Central African Rep.  Africa  CAF
# 8                  Chad  Africa  TCD
# 9   Congo (Rep. of the)  Africa  COG
#
#                                       Indicator name    Year  Value  \
# 0  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#    data_country  data_year
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# 5           NaN        NaN
# 6           NaN        NaN
# 7           NaN        NaN
# 8           NaN        NaN
# 9           NaN        NaN

# %%
df = df[(df.iloc[:,3] =='Female Internet users as a % of total female population')]
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value']
df['Country Name'] = df['Country']


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#                Country Name    Year                                Indicator  \
# 40307            Cabo Verde  2019.0  % of population using internet (female)
# 40308         Côte d'Ivoire  2019.0  % of population using internet (female)
# 40309                 Kenya  2019.0  % of population using internet (female)
# 40310               Lesotho  2019.0  % of population using internet (female)
# 40311             Mauritius  2019.0  % of population using internet (female)
# 40312               Bahrain  2019.0  % of population using internet (female)
# 40313                 Egypt  2019.0  % of population using internet (female)
# 40314                Kuwait  2019.0  % of population using internet (female)
# 40315               Morocco  2019.0  % of population using internet (female)
# 40316                  Oman  2019.0  % of population using internet (female)
# 40317             Palestine  2019.0  % of population using internet (female)
# 40318                 Qatar  2019.0  % of population using internet (female)
# 40319          Saudi Arabia  2019.0  % of population using internet (female)
# 40320               Tunisia  2019.0  % of population using internet (female)
# 40321  United Arab Emirates  2019.0  % of population using internet (female)
# 40322     Brunei Darussalam  2019.0  % of population using internet (female)
# 40323              Cambodia  2019.0  % of population using internet (female)
# 40324                 China  2019.0  % of population using internet (female)
# 40325      Hong Kong, China  2019.0  % of population using internet (female)
# 40326             Indonesia  2019.0  % of population using internet (female)
#
#         data_col  new_rank_score  higher_is_better
# 40307  60.965017        3.766390              True
# 40308  32.924445        2.151554              True
# 40309  20.125122        1.414451              True
# 40310  44.922768        2.842529              True
# 40311  60.130645        3.718339              True
# 40312  99.316403        5.975016              True
# 40313  52.986990        3.306941              True
# 40314  99.579959        5.990194              True
# 40315  70.167130        4.296332              True
# 40316  97.153466        5.850455              True
# 40317  68.934490        4.225345              True
# 40318  99.319498        5.975195              True
# 40319  94.566890        5.701496              True
# 40320  61.112559        3.774886              True
# 40321  99.501508        5.985676              True
# 40322  99.750226        6.000000              True
# 40323  77.783786        4.734970              True
# 40324  63.524052        3.913762              True
# 40325  90.472168        5.465684              True
# 40326  44.864022        2.839146              True

# %%
### 4. % of population using internet (male)

# %%
indicators[3]

# load data
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population using internet (male)
# ITU_database

# %%
df.head(10)
# Out:
#                 Country  Region  ISO  \
# 0                Angola  Africa  AGO
# 1                 Benin  Africa  BEN
# 2              Botswana  Africa  BWA
# 3          Burkina Faso  Africa  BFA
# 4               Burundi  Africa  BDI
# 5            Cabo Verde  Africa  CPV
# 6              Cameroon  Africa  CMR
# 7  Central African Rep.  Africa  CAF
# 8                  Chad  Africa  TCD
# 9   Congo (Rep. of the)  Africa  COG
#
#                                       Indicator name    Year  Value  \
# 0  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#    data_country  data_year
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# 5           NaN        NaN
# 6           NaN        NaN
# 7           NaN        NaN
# 8           NaN        NaN
# 9           NaN        NaN

# %%
df = df[(df.iloc[:,3] =='Male Internet users as a % of total male population')]
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value']
df['Country Name'] = df['Country']


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#                Country Name    Year                              Indicator  \
# 41078            Cabo Verde  2019.0  % of population using internet (male)
# 41079         Côte d'Ivoire  2019.0  % of population using internet (male)
# 41080                 Kenya  2019.0  % of population using internet (male)
# 41081               Lesotho  2019.0  % of population using internet (male)
# 41082             Mauritius  2019.0  % of population using internet (male)
# 41083               Bahrain  2019.0  % of population using internet (male)
# 41084                 Egypt  2019.0  % of population using internet (male)
# 41085                Kuwait  2019.0  % of population using internet (male)
# 41086               Morocco  2019.0  % of population using internet (male)
# 41087                  Oman  2019.0  % of population using internet (male)
# 41088             Palestine  2019.0  % of population using internet (male)
# 41089                 Qatar  2019.0  % of population using internet (male)
# 41090          Saudi Arabia  2019.0  % of population using internet (male)
# 41091               Tunisia  2019.0  % of population using internet (male)
# 41092  United Arab Emirates  2019.0  % of population using internet (male)
# 41093     Brunei Darussalam  2019.0  % of population using internet (male)
# 41094              Cambodia  2019.0  % of population using internet (male)
# 41095                 China  2019.0  % of population using internet (male)
# 41096      Hong Kong, China  2019.0  % of population using internet (male)
# 41097             Indonesia  2019.0  % of population using internet (male)
#
#         data_col  new_rank_score  higher_is_better
# 41078  62.921166        3.643039              True
# 41079  39.808871        2.173867              True
# 41080  25.071668        1.237071              True
# 41081  38.349985        2.081130              True
# 41082  63.393093        3.673038              True
# 41083  99.910314        5.994317              True
# 41084  61.541347        3.555329              True
# 41085  99.521506        5.969602              True
# 41086  78.636833        4.642032              True
# 41087  94.404849        5.644353              True
# 41088  72.262563        4.236841              True
# 41089  99.999712        6.000000              True
# 41090  96.531207        5.779519              True
# 41091  72.462033        4.249521              True
# 41092  99.030014        5.938359              True
# 41093  91.833183        5.480881              True
# 41094  78.788371        4.651665              True
# 41095  65.569645        3.811394              True
# 41096  93.150818        5.564638              True
# 41097  50.497113        2.853283              True

# %%
### 5. SDG 4.4 Digital literacy data

# %%
indicators[4]

# load data
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# The indicators are all jumbled, need to unclutter this
# Out:
# SDG 4.4 Digital literacy data
# SDG_digital_literacy_data

# %%
df.head(15)
# Out:
#                    SDG_IND                                          Indicator  \
# 0   ICTSKILLTRANSFERFILE_M  Proportion of youth and adults who have transf...
# 1   ICTSKILLTRANSFERFILE_M  Proportion of youth and adults who have transf...
# 2   ICTSKILLTRANSFERFILE_M  Proportion of youth and adults who have transf...
# 3   ICTSKILLTRANSFERFILE_M  Proportion of youth and adults who have transf...
# 4         ICTSKILLDUPLIC_M  Proportion of youth and adults who have used c...
# 5         ICTSKILLDUPLIC_M  Proportion of youth and adults who have used c...
# 6         ICTSKILLDUPLIC_M  Proportion of youth and adults who have used c...
# 7         ICTSKILLDUPLIC_M  Proportion of youth and adults who have used c...
# 8     ICTSKILLTRANSFERFILE  Proportion of youth and adults who have transf...
# 9     ICTSKILLTRANSFERFILE  Proportion of youth and adults who have transf...
# 10    ICTSKILLTRANSFERFILE  Proportion of youth and adults who have transf...
# 11    ICTSKILLTRANSFERFILE  Proportion of youth and adults who have transf...
# 12    ICTSKILLTRANSFERFILE  Proportion of youth and adults who have transf...
# 13       ICTSKILLFORMULA_M  Proportion of youth and adults who have used b...
# 14       ICTSKILLFORMULA_M  Proportion of youth and adults who have used b...
#
#    LOCATION Country  TIME  Time     Value  Flag Codes  Flags
# 0       BRA  Brazil  2014  2014  23.31007         NaN    NaN
# 1       BRA  Brazil  2016  2016  21.53173         NaN    NaN
# 2       BRA  Brazil  2017  2017  21.14880         NaN    NaN
# 3       BRA  Brazil  2018  2018  21.84886         NaN    NaN
# 4       BRA  Brazil  2014  2014  25.64427         NaN    NaN
# 5       BRA  Brazil  2016  2016  22.01463         NaN    NaN
# 6       BRA  Brazil  2017  2017  22.69577         NaN    NaN
# 7       BRA  Brazil  2018  2018  22.59234         NaN    NaN
# 8       TUR  Turkey  2014  2014  27.72807         NaN    NaN
# 9       TUR  Turkey  2015  2015  25.66142         NaN    NaN
# 10      TUR  Turkey  2016  2016  31.29833         NaN    NaN
# 11      TUR  Turkey  2017  2017  37.06352         NaN    NaN
# 12      TUR  Turkey  2019  2019  38.18440         NaN    NaN
# 13      EGY   Egypt  2014  2014   1.69992         NaN    NaN
# 14      EGY   Egypt  2015  2015   2.14629         NaN    NaN

# %%
df = df[(df.Time == 2019)]
df.head(15)
# Out:
#                     SDG_IND  \
# 12     ICTSKILLTRANSFERFILE
# 35         ICTSKILLSOFTWARE
# 75     ICTSKILLTRANSFERFILE
# 90         ICTSKILLPROGLANG
# 103        ICTSKILLSOFTWARE
# 121    ICTSKILLTRANSFERFILE
# 126    ICTSKILLTRANSFERFILE
# 133          ICTSKILLATTACH
# 143        ICTSKILLPROGLANG
# 152        ICTSKILLPROGLANG
# 170        ICTSKILLPROGLANG
# 174  ICTSKILLTRANSFERFILE_F
# 179      ICTSKILLPROGLANG_M
# 217         ICTSKILLFORMULA
# 234    ICTSKILLTRANSFERFILE
#
#                                              Indicator LOCATION  \
# 12   Proportion of youth and adults who have transf...      TUR
# 35   Proportion of youth and adults who have found,...      THA
# 75   Proportion of youth and adults who have transf...      PAK
# 90   Proportion of youth and adults who have wrote ...      PRT
# 103  Proportion of youth and adults who have found,...      FIN
# 121  Proportion of youth and adults who have transf...      FRA
# 126  Proportion of youth and adults who have transf...      ESP
# 133  Proportion of youth and adults who have sent e...      KAZ
# 143  Proportion of youth and adults who have wrote ...      KAZ
# 152  Proportion of youth and adults who have wrote ...      BEL
# 170  Proportion of youth and adults who have wrote ...      ROU
# 174  Proportion of youth and adults who have transf...      DEU
# 179  Proportion of youth and adults who have wrote ...      BIH
# 217  Proportion of youth and adults who have used b...      QAT
# 234  Proportion of youth and adults who have transf...      CZE
#
#                     Country  TIME  Time     Value  Flag Codes  Flags
# 12                   Turkey  2019  2019  38.18440         NaN    NaN
# 35                 Thailand  2019  2019   5.30000         NaN    NaN
# 75                 Pakistan  2019  2019   2.70000         NaN    NaN
# 90                 Portugal  2019  2019   8.20000         NaN    NaN
# 103                 Finland  2019  2019  63.10000         NaN    NaN
# 121                  France  2019  2019  54.60000         NaN    NaN
# 126                   Spain  2019  2019  54.67742         NaN    NaN
# 133              Kazakhstan  2019  2019  51.70000         NaN    NaN
# 143              Kazakhstan  2019  2019   6.30000         NaN    NaN
# 152                 Belgium  2019  2019   4.50000         NaN    NaN
# 170                 Romania  2019  2019   1.00000         NaN    NaN
# 174                 Germany  2019  2019  52.66343         NaN    NaN
# 179  Bosnia and Herzegovina  2019  2019   3.46017         NaN    NaN
# 217                   Qatar  2019  2019  24.93569         NaN    NaN
# 234                 Czechia  2019  2019  55.70000         NaN    NaN

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value']
df['Country Name'] = df['Country']
df['Year'] = df['Time']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(10)
# Out:
#     Country Name  Year                      Indicator  data_col  \
# 12        Turkey  2019  SDG 4.4 Digital literacy data  38.18440
# 35      Thailand  2019  SDG 4.4 Digital literacy data   5.30000
# 75      Pakistan  2019  SDG 4.4 Digital literacy data   2.70000
# 90      Portugal  2019  SDG 4.4 Digital literacy data   8.20000
# 103      Finland  2019  SDG 4.4 Digital literacy data  63.10000
# 121       France  2019  SDG 4.4 Digital literacy data  54.60000
# 126        Spain  2019  SDG 4.4 Digital literacy data  54.67742
# 133   Kazakhstan  2019  SDG 4.4 Digital literacy data  51.70000
# 143   Kazakhstan  2019  SDG 4.4 Digital literacy data   6.30000
# 152      Belgium  2019  SDG 4.4 Digital literacy data   4.50000
#
#      new_rank_score  higher_is_better
# 12         2.920344              True
# 35         1.257836              True
# 75         1.126390              True
# 90         1.404449              True
# 103        4.179980              True
# 121        3.750253              True
# 126        3.754167              True
# 133        3.603640              True
# 143        1.308392              True
# 152        1.217391              True

# %%
### 6. UNDP Human Development Index (HDI)

# %%
indicators[5]

# load data
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# UNDP Human Development Index (HDI)
# undp_human_developmnt

# %%
df.head(15)
# Out:
#     HDI rank                      Country  Value  Unnamed: 3      (years)  \
# 0        NaN                          NaN   2019         NaN         2019
# 1        NaN  VERY HIGH HUMAN DEVELOPMENT    NaN         NaN          NaN
# 2        1.0                       Norway  0.957         NaN     12.89775
# 3        2.0                      Ireland  0.955         NaN   12.6663305
# 4        2.0                  Switzerland  0.955         NaN  13.38081241
# 5        4.0       Hong Kong, China (SAR)  0.949         NaN     12.27996
# 6        4.0                      Iceland  0.949         NaN  12.77278684
# 7        6.0                      Germany  0.947         NaN     14.15168
# 8        7.0                       Sweden  0.945         NaN     12.54847
# 9        8.0                    Australia  0.944         NaN  12.72469119
# 10       8.0                  Netherlands  0.944         NaN      12.4148
# 11      10.0                      Denmark   0.94         NaN  12.61380326
# 12      11.0                      Finland  0.938         NaN     12.82413
# 13      11.0                    Singapore  0.938         NaN     11.62461
# 14      13.0               United Kingdom  0.932         NaN     13.24287
#
#    (2017 PPP $)  data_country  data_year
# 0          2019           NaN        NaN
# 1           NaN           NaN        NaN
# 2   66494.25217           NaN        NaN
# 3   68370.58737           NaN        NaN
# 4   69393.52076           NaN        NaN
# 5   62984.76553           NaN        NaN
# 6   54682.38057           NaN        NaN
# 7   55314.35355           NaN        NaN
# 8   54507.80504           NaN        NaN
# 9   48084.84207           NaN        NaN
# 10  57707.06867           NaN        NaN
# 11  58661.87084           NaN        NaN
# 12   48511.3978           NaN        NaN
# 13  88155.21431           NaN        NaN
# 14  46070.64481           NaN        NaN

# %%
# choose only the rows where column HDI rank is numeric

df = df.iloc[0:194,:]
df = df[pd.to_numeric(df['HDI rank'], errors='coerce').notnull()]

# %%
df.head(67)
# Out:
#     HDI rank                 Country  Value  Unnamed: 3      (years)  \
# 2        1.0                  Norway  0.957         NaN     12.89775
# 3        2.0                 Ireland  0.955         NaN   12.6663305
# 4        2.0             Switzerland  0.955         NaN  13.38081241
# 5        4.0  Hong Kong, China (SAR)  0.949         NaN     12.27996
# 6        4.0                 Iceland  0.949         NaN  12.77278684
# ..       ...                     ...    ...         ...          ...
# 64      62.0                Malaysia   0.81         NaN     10.37283
# 65      64.0                  Kuwait  0.806         NaN  7.275667996
# 66      64.0                  Serbia  0.806         NaN     11.19411
# 67      66.0               Mauritius  0.804         NaN         9.54
# 69      67.0              Seychelles  0.796         NaN     9.992045
#
#    (2017 PPP $)  data_country  data_year
# 2   66494.25217           NaN        NaN
# 3   68370.58737           NaN        NaN
# 4   69393.52076           NaN        NaN
# 5   62984.76553           NaN        NaN
# 6   54682.38057           NaN        NaN
# ..          ...           ...        ...
# 64  27534.09856           NaN        NaN
# 65  58590.08219           NaN        NaN
# 66  17191.66873           NaN        NaN
# 67  25266.21195           NaN        NaN
# 69  26903.24617           NaN        NaN
#
# [67 rows x 8 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = False
df['Indicator'] = indicator
df['data_col'] = df['HDI rank']
df['Country Name'] = df['Country']
df['Year'] = 2019


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#               Country Name  Year                            Indicator  \
# 2                   Norway  2019  UNDP Human Development Index (HDI)
# 3                  Ireland  2019  UNDP Human Development Index (HDI)
# 4              Switzerland  2019  UNDP Human Development Index (HDI)
# 5   Hong Kong, China (SAR)  2019  UNDP Human Development Index (HDI)
# 6                  Iceland  2019  UNDP Human Development Index (HDI)
# 7                  Germany  2019  UNDP Human Development Index (HDI)
# 8                   Sweden  2019  UNDP Human Development Index (HDI)
# 9                Australia  2019  UNDP Human Development Index (HDI)
# 10             Netherlands  2019  UNDP Human Development Index (HDI)
# 11                 Denmark  2019  UNDP Human Development Index (HDI)
# 12                 Finland  2019  UNDP Human Development Index (HDI)
# 13               Singapore  2019  UNDP Human Development Index (HDI)
# 14          United Kingdom  2019  UNDP Human Development Index (HDI)
# 15                 Belgium  2019  UNDP Human Development Index (HDI)
# 16             New Zealand  2019  UNDP Human Development Index (HDI)
# 17                  Canada  2019  UNDP Human Development Index (HDI)
# 18           United States  2019  UNDP Human Development Index (HDI)
# 19                 Austria  2019  UNDP Human Development Index (HDI)
# 20                  Israel  2019  UNDP Human Development Index (HDI)
# 21                   Japan  2019  UNDP Human Development Index (HDI)
#
#     data_col  new_rank_score  higher_is_better
# 2        1.0        6.000000             False
# 3        2.0        5.973404             False
# 4        2.0        5.973404             False
# 5        4.0        5.920213             False
# 6        4.0        5.920213             False
# 7        6.0        5.867021             False
# 8        7.0        5.840426             False
# 9        8.0        5.813830             False
# 10       8.0        5.813830             False
# 11      10.0        5.760638             False
# 12      11.0        5.734043             False
# 13      11.0        5.734043             False
# 14      13.0        5.680851             False
# 15      14.0        5.654255             False
# 16      14.0        5.654255             False
# 17      16.0        5.601064             False
# 18      17.0        5.574468             False
# 19      18.0        5.547872             False
# 20      19.0        5.521277             False
# 21      19.0        5.521277             False

# %%
### 7. Facebook Social Connectedness Index

# %%
indicators[6]

# load data
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Facebook Social Connectedness Index
# fb_social_connectedness

# %%
df.head(25)
# Out:
#     user_loc fr_loc  scaled_sci
# 0       1001     AE        8729
# 1       1001     AG       95256
# 2       1001     AL        3122
# 3       1001     AM        3470
# 4       1001     AO        2839
# 5       1001     AR        3729
# 6       1001     AT        6977
# 7       1001     AU       21136
# 8       1001     AW       27607
# 9       1001     AZ        1108
# 10      1001     BA        3183
# 11      1001     BB       44020
# 12      1001     BD        1244
# 13      1001     BE       10933
# 14      1001     BF        2159
# 15      1001     BG        4085
# 16      1001     BH       14541
# 17      1001     BI        3778
# 18      1001     BJ        3308
# 19      1001     BN        3155
# 20      1001     BO        2724
# 21      1001     BR        4593
# 22      1001     BS      128531
# 23      1001     BT        1375
# 24      1001     BW        5455

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['scaled_sci'] 
df['Country Name'] = df['fr_loc']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].head(30)

# Need to find a way to convert ISO codes to full country names
# Out:
#    Country Name                            Indicator  data_col  \
# 0            AE  Facebook Social Connectedness Index      8729
# 1            AG  Facebook Social Connectedness Index     95256
# 2            AL  Facebook Social Connectedness Index      3122
# 3            AM  Facebook Social Connectedness Index      3470
# 4            AO  Facebook Social Connectedness Index      2839
# 5            AR  Facebook Social Connectedness Index      3729
# 6            AT  Facebook Social Connectedness Index      6977
# 7            AU  Facebook Social Connectedness Index     21136
# 8            AW  Facebook Social Connectedness Index     27607
# 9            AZ  Facebook Social Connectedness Index      1108
# 10           BA  Facebook Social Connectedness Index      3183
# 11           BB  Facebook Social Connectedness Index     44020
# 12           BD  Facebook Social Connectedness Index      1244
# 13           BE  Facebook Social Connectedness Index     10933
# 14           BF  Facebook Social Connectedness Index      2159
# 15           BG  Facebook Social Connectedness Index      4085
# 16           BH  Facebook Social Connectedness Index     14541
# 17           BI  Facebook Social Connectedness Index      3778
# 18           BJ  Facebook Social Connectedness Index      3308
# 19           BN  Facebook Social Connectedness Index      3155
# 20           BO  Facebook Social Connectedness Index      2724
# 21           BR  Facebook Social Connectedness Index      4593
# 22           BS  Facebook Social Connectedness Index    128531
# 23           BT  Facebook Social Connectedness Index      1375
# 24           BW  Facebook Social Connectedness Index      5455
# 25           BY  Facebook Social Connectedness Index      3696
# 26           BZ  Facebook Social Connectedness Index     34999
# 27           CA  Facebook Social Connectedness Index     37534
# 28           CD  Facebook Social Connectedness Index      3730
# 29           CF  Facebook Social Connectedness Index     21593
#
#     new_rank_score  higher_is_better
# 0         1.000044              True
# 1         1.000476              True
# 2         1.000016              True
# 3         1.000017              True
# 4         1.000014              True
# 5         1.000019              True
# 6         1.000035              True
# 7         1.000106              True
# 8         1.000138              True
# 9         1.000006              True
# 10        1.000016              True
# 11        1.000220              True
# 12        1.000006              True
# 13        1.000055              True
# 14        1.000011              True
# 15        1.000020              True
# 16        1.000073              True
# 17        1.000019              True
# 18        1.000017              True
# 19        1.000016              True
# 20        1.000014              True
# 21        1.000023              True
# 22        1.000643              True
# 23        1.000007              True
# 24        1.000027              True
# 25        1.000018              True
# 26        1.000175              True
# 27        1.000188              True
# 28        1.000019              True
# 29        1.000108              True

# %%
### 8. Share of individuals using the Internet to interact with officials

# %%
indicators[7]

# load data
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Share of individuals using the Internet to interact with public authorities
# population_interacting_public_officials

# %%
df.head(15)
# Out:
#       Country                                          Indicator  \
# 0   Australia  Individuals using the Internet for downloading...
# 1   Australia  Individuals using the Internet for downloading...
# 2     Austria  Individuals using the Internet for visiting or...
# 3     Austria  Individuals using the Internet for visiting or...
# 4     Austria  Individuals using the Internet for visiting or...
# 5     Austria  Individuals using the Internet for visiting or...
# 6     Austria  Individuals using the Internet for visiting or...
# 7     Austria  Individuals using the Internet for visiting or...
# 8     Austria  Individuals using the Internet for visiting or...
# 9     Austria  Individuals using the Internet for visiting or...
# 10    Austria  Individuals using the Internet for visiting or...
# 11    Austria  Individuals using the Internet for visiting or...
# 12    Austria  Individuals using the Internet for visiting or...
# 13    Austria  Individuals using the Internet for visiting or...
# 14    Austria  Individuals using the Internet for visiting or...
#
#                       Breakdowns  Time        Unit PowerCode  \
# 0   All (individuals aged 16-74)  2010  Percentage     Units
# 1   All (individuals aged 16-74)  2012  Percentage     Units
# 2   All (individuals aged 16-74)  2005  Percentage     Units
# 3   All (individuals aged 16-74)  2006  Percentage     Units
# 4   All (individuals aged 16-74)  2007  Percentage     Units
# 5   All (individuals aged 16-74)  2008  Percentage     Units
# 6   All (individuals aged 16-74)  2009  Percentage     Units
# 7   All (individuals aged 16-74)  2010  Percentage     Units
# 8   All (individuals aged 16-74)  2011  Percentage     Units
# 9   All (individuals aged 16-74)  2012  Percentage     Units
# 10  All (individuals aged 16-74)  2013  Percentage     Units
# 11  All (individuals aged 16-74)  2014  Percentage     Units
# 12  All (individuals aged 16-74)  2015  Percentage     Units
# 13  All (individuals aged 16-74)  2016  Percentage     Units
# 14  All (individuals aged 16-74)  2017  Percentage     Units
#
#     Reference Period    Value                      Flags
# 0                NaN  38.1100  Difference in methodology
# 1                NaN  49.9600  Difference in methodology
# 2                NaN  29.1940                        NaN
# 3                NaN  32.9733                        NaN
# 4                NaN  27.4741                        NaN
# 5                NaN  51.2252                      Break
# 6                NaN  48.8515                        NaN
# 7                NaN  51.0458                        NaN
# 8                NaN  51.2893                        NaN
# 9                NaN  52.8274                        NaN
# 10               NaN  53.6259                        NaN
# 11               NaN  58.6330                        NaN
# 12               NaN  56.7484                        NaN
# 13               NaN  59.9848                        NaN
# 14               NaN  61.9779                        NaN

# %%
# filter most recent year
df = df[(df.Time==2019)]
df = df[(df.Indicator=='Individuals using the Internet for visiting or interacting with public authorities websites - last 12 m (%)')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Year'] = df['Time']
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#        Country Name  Year                                          Indicator  \
# 16          Austria  2019  Share of individuals using the Internet to int...
# 64          Belgium  2019  Share of individuals using the Internet to int...
# 109          Brazil  2019  Share of individuals using the Internet to int...
# 148        Colombia  2019  Share of individuals using the Internet to int...
# 169  Czech Republic  2019  Share of individuals using the Internet to int...
# 216         Denmark  2019  Share of individuals using the Internet to int...
# 262         Estonia  2019  Share of individuals using the Internet to int...
# 310         Finland  2019  Share of individuals using the Internet to int...
# 357          France  2019  Share of individuals using the Internet to int...
# 397         Germany  2019  Share of individuals using the Internet to int...
# 443          Greece  2019  Share of individuals using the Internet to int...
# 491         Hungary  2019  Share of individuals using the Internet to int...
# 537         Iceland  2019  Share of individuals using the Internet to int...
# 581         Ireland  2019  Share of individuals using the Internet to int...
# 622          Israel  2019  Share of individuals using the Internet to int...
# 637           Italy  2019  Share of individuals using the Internet to int...
# 700          Latvia  2019  Share of individuals using the Internet to int...
# 748       Lithuania  2019  Share of individuals using the Internet to int...
# 796      Luxembourg  2019  Share of individuals using the Internet to int...
# 844          Mexico  2019  Share of individuals using the Internet to int...
#
#       data_col  new_rank_score  higher_is_better
# 16   69.735500        4.715671              True
# 64   58.605000        4.063974              True
# 109  34.194129        2.634704              True
# 148   6.274581        1.000000              True
# 169  53.776600        3.781269              True
# 216  91.670900        6.000000              True
# 262  80.015600        5.317576              True
# 310  87.295400        5.743812              True
# 357  74.724200        5.007762              True
# 397  59.097700        4.092822              True
# 443  52.094000        3.682751              True
# 491  52.794300        3.723754              True
# 537  89.228900        5.857020              True
# 581  61.097800        4.209929              True
# 622  48.800000        3.489886              True
# 637  23.408100        2.003177              True
# 700  69.572300        4.706115              True
# 748  54.733300        3.837284              True
# 796  60.142000        4.153966              True
# 844  30.233392        2.402801              True

# %%
### 9. Level of satisfaction for online public service

# %%
indicators[8]

# load data
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Level of satisfaction for online public services (% of users, by type of interaction and service)
# digital_public_service_use

# %%
df.head(10)
# Out:
#          Country  Net Perception (%)
# 0       Estonia                   67
# 1           UAE                   61
# 2  Saudi Arabia                   59
# 3      Singapore                  54
# 4         China                   53
# 5   New Zealand                   52
# 6   Netherlands                   51
# 7         Qatar                   51
# 8        Canada                   40
# 9        Denmark                  48

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Net Perception (%)'] 
df['Year'] = 2020
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# Need to replace the % mark

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#       Country Name  Year                                          Indicator  \
# 0         Estonia   2020  Level of satisfaction for online public servic...
# 1             UAE   2020  Level of satisfaction for online public servic...
# 2    Saudi Arabia   2020  Level of satisfaction for online public servic...
# 3        Singapore  2020  Level of satisfaction for online public servic...
# 4           China   2020  Level of satisfaction for online public servic...
# 5     New Zealand   2020  Level of satisfaction for online public servic...
# 6     Netherlands   2020  Level of satisfaction for online public servic...
# 7           Qatar   2020  Level of satisfaction for online public servic...
# 8          Canada   2020  Level of satisfaction for online public servic...
# 9          Denmark  2020  Level of satisfaction for online public servic...
# 10          India   2020  Level of satisfaction for online public servic...
# 11         France   2020  Level of satisfaction for online public servic...
# 12              UK  2020  Level of satisfaction for online public servic...
# 13          Sweden  2020  Level of satisfaction for online public servic...
# 14       Australia  2020  Level of satisfaction for online public servic...
# 15  United States   2020  Level of satisfaction for online public servic...
# 16         Russia   2020  Level of satisfaction for online public servic...
# 17         Norway   2020  Level of satisfaction for online public servic...
# 18         Austria  2020  Level of satisfaction for online public servic...
# 19     Kazakhstan   2020  Level of satisfaction for online public servic...
#
#     data_col  new_rank_score  higher_is_better
# 0         67        6.000000              True
# 1         61        5.655172              True
# 2         59        5.540230              True
# 3         54        5.252874              True
# 4         53        5.195402              True
# 5         52        5.137931              True
# 6         51        5.080460              True
# 7         51        5.080460              True
# 8         40        4.448276              True
# 9         48        4.908046              True
# 10        45        4.735632              True
# 11        43        4.620690              True
# 12        42        4.563218              True
# 13        41        4.505747              True
# 14        40        4.448276              True
# 15        39        4.390805              True
# 16        39        4.390805              True
# 17        34        4.103448              True
# 18        33        4.045977              True
# 19        32        3.988506              True

# %%
### 10. Number of mobile apps available in national language

# %%
indicators[9]

# load data
indicator = indicators[9]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Number of mobile apps available in national language(s)
# apps_in_national_language

# %%
df.head(15)
# Out:
#     Unnamed: 0 ISO Code      Country                 Region  Year  \
# 0            1      AFG  Afghanistan             South Asia  2014
# 1            2      AFG  Afghanistan             South Asia  2015
# 2            3      AFG  Afghanistan             South Asia  2016
# 3            4      AFG  Afghanistan             South Asia  2017
# 4            5      AFG  Afghanistan             South Asia  2018
# 5            6      AFG  Afghanistan             South Asia  2019
# 6            7      AGO       Angola     Sub-Saharan Africa  2014
# 7            8      AGO       Angola     Sub-Saharan Africa  2015
# 8            9      AGO       Angola     Sub-Saharan Africa  2016
# 9           10      AGO       Angola     Sub-Saharan Africa  2017
# 10          11      AGO       Angola     Sub-Saharan Africa  2018
# 11          12      AGO       Angola     Sub-Saharan Africa  2019
# 12          13      ALB      Albania  Europe & Central Asia  2014
# 13          14      ALB      Albania  Europe & Central Asia  2015
# 14          15      ALB      Albania  Europe & Central Asia  2016
#
#     Number of apps in national language
# 0                              2.444741
# 1                              2.793221
# 2                              2.849881
# 3                              2.913741
# 4                              2.961247
# 5                              3.000000
# 6                             53.333237
# 7                             55.080910
# 8                             56.516411
# 9                             57.061077
# 10                            57.133656
# 11                            57.978500
# 12                            60.334080
# 13                            63.294495
# 14                            65.568138

# %%
# filter most recent year and global value
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Number of apps in national language'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#                Country Name  Year  \
# 5               Afghanistan  2019
# 11                   Angola  2019
# 17                  Albania  2019
# 23     United Arab Emirates  2019
# 29                Argentina  2019
# 35                  Armenia  2019
# 41                Australia  2019
# 47                  Austria  2019
# 53               Azerbaijan  2019
# 59                  Burundi  2019
# 65                  Belgium  2019
# 71                    Benin  2019
# 77             Burkina Faso  2019
# 83               Bangladesh  2019
# 89                 Bulgaria  2019
# 95                  Bahrain  2019
# 101                 Bahamas  2019
# 107  Bosnia and Herzegovina  2019
# 113                 Belarus  2019
# 119                  Belize  2019
#
#                                              Indicator    data_col  \
# 5    Number of mobile apps available in national la...    3.000000
# 11   Number of mobile apps available in national la...   57.978500
# 17   Number of mobile apps available in national la...   67.286446
# 23   Number of mobile apps available in national la...   78.453438
# 29   Number of mobile apps available in national la...   89.724289
# 35   Number of mobile apps available in national la...   12.541476
# 41   Number of mobile apps available in national la...  100.000000
# 47   Number of mobile apps available in national la...   89.197319
# 53   Number of mobile apps available in national la...   25.400829
# 59   Number of mobile apps available in national la...    6.738045
# 65   Number of mobile apps available in national la...   84.225563
# 71   Number of mobile apps available in national la...   29.478947
# 77   Number of mobile apps available in national la...   18.529623
# 83   Number of mobile apps available in national la...   50.598633
# 89   Number of mobile apps available in national la...   60.423946
# 95   Number of mobile apps available in national la...   78.453438
# 101  Number of mobile apps available in national la...  100.000000
# 107  Number of mobile apps available in national la...   63.071186
# 113  Number of mobile apps available in national la...   61.593445
# 119  Number of mobile apps available in national la...   70.000000
#
#      new_rank_score  higher_is_better
# 5          1.000000              True
# 11         3.833943              True
# 17         4.313734              True
# 23         4.889352              True
# 29         5.470324              True
# 35         1.491829              True
# 41         6.000000              True
# 47         5.443161              True
# 53         2.154682              True
# 59         1.192683              True
# 65         5.186885              True
# 71         2.364894              True
# 77         1.800496              True
# 83         3.453538              True
# 89         3.959997              True
# 95         4.889352              True
# 101        6.000000              True
# 107        4.096453              True
# 113        4.020281              True
# 119        4.453608              True

# %%
### 11. Device Addiction (time of use on internet)

# %%
indicators[10]

# load data
indicator = indicators[10]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Device Addiction (time of use on internet / on devices)
# time_spent_online

# %%
df.head(15)

# Need to move the row further down
# Out:
#          Country  \
# 0    Philippines
# 1         Brazil
# 2       Colombia
# 3   South Africa
# 4      Argentina
# 5       Malaysia
# 6         Mexico
# 7      Indonesia
# 8       Thailand
# 9         Taiwan
# 10     Singapore
# 11        Turkey
# 12        Russia
# 13  Saudi Arabia
# 14         Egypt
#
#     Average daily time spent using the internet by online users worldwide as of 3rd quarter 2020, by region (in hours.minutes)
# 0                                               10.56
# 1                                               10.08
# 2                                               10.07
# 3                                               10.06
# 4                                                9.39
# 5                                                9.17
# 6                                                9.01
# 7                                                8.52
# 8                                                8.44
# 9                                                8.08
# 10                                               8.07
# 11                                               7.57
# 12                                               7.52
# 13                                               7.45
# 14                                               7.36

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Average daily time spent using the internet by online users worldwide as of 3rd quarter 2020, by region (in hours.minutes)'] 
df['Country Name'] = df['Country']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#     Country Name  Year                                          Indicator  \
# 0    Philippines  2020  Device Addiction (time of use on internet / on...
# 1         Brazil  2020  Device Addiction (time of use on internet / on...
# 2       Colombia  2020  Device Addiction (time of use on internet / on...
# 3   South Africa  2020  Device Addiction (time of use on internet / on...
# 4      Argentina  2020  Device Addiction (time of use on internet / on...
# 5       Malaysia  2020  Device Addiction (time of use on internet / on...
# 6         Mexico  2020  Device Addiction (time of use on internet / on...
# 7      Indonesia  2020  Device Addiction (time of use on internet / on...
# 8       Thailand  2020  Device Addiction (time of use on internet / on...
# 9         Taiwan  2020  Device Addiction (time of use on internet / on...
# 10     Singapore  2020  Device Addiction (time of use on internet / on...
# 11        Turkey  2020  Device Addiction (time of use on internet / on...
# 12        Russia  2020  Device Addiction (time of use on internet / on...
# 13  Saudi Arabia  2020  Device Addiction (time of use on internet / on...
# 14         Egypt  2020  Device Addiction (time of use on internet / on...
# 15        Israel  2020  Device Addiction (time of use on internet / on...
# 16       Romania  2020  Device Addiction (time of use on internet / on...
# 17         U.A.E  2020  Device Addiction (time of use on internet / on...
# 18      Portugal  2020  Device Addiction (time of use on internet / on...
# 19     Hong Kong  2020  Device Addiction (time of use on internet / on...
#
#     data_col  new_rank_score  higher_is_better
# 0      10.56        6.000000              True
# 1      10.08        5.619651              True
# 2      10.07        5.611727              True
# 3      10.06        5.603803              True
# 4       9.39        5.072900              True
# 5       9.17        4.898574              True
# 6       9.01        4.771791              True
# 7       8.52        4.383518              True
# 8       8.44        4.320127              True
# 9       8.08        4.034865              True
# 10      8.07        4.026941              True
# 11      7.57        3.630745              True
# 12      7.52        3.591125              True
# 13      7.45        3.535658              True
# 14      7.36        3.464342              True
# 15      7.27        3.393027              True
# 16      7.26        3.385103              True
# 17      7.24        3.369255              True
# 18      7.20        3.337559              True
# 19      7.15        3.297940              True

# %%
### 12. Gross National Wellbeing

# %%
indicators[11]

# load data
indicator = indicators[11]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# happiness_score is missing looks like the problem is in a redundant space before it in the filename matching
# Out:
# Gross National Wellbeing
# happiness_score

# %%
df.head(15)
# Out:
#     RANK COUNTRY/ECONOMY  VALUE   SCORE
# 0    1.0         Finland   7.78  100.00
# 1    2.0     Switzerland   7.69   98.31
# 2    3.0         Denmark   7.69   98.28
# 3    4.0         Iceland   7.53   95.13
# 4    5.0          Norway   7.44   93.35
# 5    6.0     Netherlands   7.43   93.02
# 6    7.0      Luxembourg   7.40   92.60
# 7    8.0          Sweden   7.40   92.49
# 8    9.0         Ireland   7.25   89.67
# 9   10.0       Australia   7.23   89.26
# 10  11.0     New Zealand   7.21   88.69
# 11  12.0         Austria   7.20   88.50
# 12  13.0  United Kingdom   7.16   87.75
# 13  14.0          Canada   7.11   86.80
# 14  15.0         Germany   7.04   85.36

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['VALUE'] 
df['Country Name'] = df['COUNTRY/ECONOMY']
df['Year'] = 2019

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#       Country Name  Year                 Indicator  data_col  new_rank_score  \
# 0          Finland  2019  Gross National Wellbeing      7.78        6.000000
# 1      Switzerland  2019  Gross National Wellbeing      7.69        5.911591
# 2          Denmark  2019  Gross National Wellbeing      7.69        5.911591
# 3          Iceland  2019  Gross National Wellbeing      7.53        5.754420
# 4           Norway  2019  Gross National Wellbeing      7.44        5.666012
# 5      Netherlands  2019  Gross National Wellbeing      7.43        5.656189
# 6       Luxembourg  2019  Gross National Wellbeing      7.40        5.626719
# 7           Sweden  2019  Gross National Wellbeing      7.40        5.626719
# 8          Ireland  2019  Gross National Wellbeing      7.25        5.479371
# 9        Australia  2019  Gross National Wellbeing      7.23        5.459725
# 10     New Zealand  2019  Gross National Wellbeing      7.21        5.440079
# 11         Austria  2019  Gross National Wellbeing      7.20        5.430255
# 12  United Kingdom  2019  Gross National Wellbeing      7.16        5.390963
# 13          Canada  2019  Gross National Wellbeing      7.11        5.341847
# 14         Germany  2019  Gross National Wellbeing      7.04        5.273084
# 15  Czech Republic  2019  Gross National Wellbeing      7.03        5.263261
# 16      Costa Rica  2019  Gross National Wellbeing      7.00        5.233792
# 17   United States  2019  Gross National Wellbeing      6.94        5.174853
# 18          Israel  2019  Gross National Wellbeing      6.93        5.165029
# 19            Oman  2019  Gross National Wellbeing      6.85        5.086444
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19              True

# %%
### 13. % of internet users who own cryptocurrency

# %%
indicators[12]

# load data
indicator = indicators[12]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of internet users who own cryptocurrency
# cryptocurrency_adoption

# %%
df.head(15)
# Out:
#          Country  \
# 0        Nigeria
# 1        Vietnam
# 2    Philippines
# 3   South Africa
# 4       Thailand
# 5           Peru
# 6         Turkey
# 7       Colombia
# 8      Argentina
# 9      Indonesia
# 10        Brazil
# 11      Malaysia
# 12         Chile
# 13  Saudi Arabia
# 14   Switzerland
#
#     Share of respondents who indicated they either owned or used cryptocurrencies in 55 countries worldwide in 2020  \
# 0                                                31.9
# 1                                                21.1
# 2                                                19.8
# 3                                                17.8
# 4                                                17.6
# 5                                                16.1
# 6                                                16.1
# 7                                                15.3
# 8                                                14.4
# 9                                                13.0
# 10                                               12.5
# 11                                               12.3
# 12                                               11.7
# 13                                               11.4
# 14                                               11.1
#
#    Units
# 0   in %
# 1   in %
# 2   in %
# 3   in %
# 4   in %
# 5   in %
# 6   in %
# 7   in %
# 8   in %
# 9   in %
# 10  in %
# 11  in %
# 12  in %
# 13  in %
# 14  in %

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Share of respondents who indicated they either owned or used cryptocurrencies in 55 countries worldwide in 2020'] 
df['Country Name'] = df['Country']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#             Country Name  Year                                   Indicator  \
# 0                Nigeria  2020  % of internet users who own cryptocurrency
# 1                Vietnam  2020  % of internet users who own cryptocurrency
# 2            Philippines  2020  % of internet users who own cryptocurrency
# 3           South Africa  2020  % of internet users who own cryptocurrency
# 4               Thailand  2020  % of internet users who own cryptocurrency
# 5                   Peru  2020  % of internet users who own cryptocurrency
# 6                 Turkey  2020  % of internet users who own cryptocurrency
# 7               Colombia  2020  % of internet users who own cryptocurrency
# 8              Argentina  2020  % of internet users who own cryptocurrency
# 9              Indonesia  2020  % of internet users who own cryptocurrency
# 10                Brazil  2020  % of internet users who own cryptocurrency
# 11              Malaysia  2020  % of internet users who own cryptocurrency
# 12                 Chile  2020  % of internet users who own cryptocurrency
# 13          Saudi Arabia  2020  % of internet users who own cryptocurrency
# 14           Switzerland  2020  % of internet users who own cryptocurrency
# 15                Greece  2020  % of internet users who own cryptocurrency
# 16                 Kenya  2020  % of internet users who own cryptocurrency
# 17    Dominican Republic  2020  % of internet users who own cryptocurrency
# 18           Netherlands  2020  % of internet users who own cryptocurrency
# 19  United Arab Emirates  2020  % of internet users who own cryptocurrency
#
#     data_col  new_rank_score  higher_is_better
# 0       31.9        6.000000              True
# 1       21.1        4.085106              True
# 2       19.8        3.854610              True
# 3       17.8        3.500000              True
# 4       17.6        3.464539              True
# 5       16.1        3.198582              True
# 6       16.1        3.198582              True
# 7       15.3        3.056738              True
# 8       14.4        2.897163              True
# 9       13.0        2.648936              True
# 10      12.5        2.560284              True
# 11      12.3        2.524823              True
# 12      11.7        2.418440              True
# 13      11.4        2.365248              True
# 14      11.1        2.312057              True
# 15      11.1        2.312057              True
# 16      10.5        2.205674              True
# 17      10.3        2.170213              True
# 18      10.0        2.117021              True
# 19      10.0        2.117021              True

# %%
### 14. Percentage of individuals not buying online due to concerns about returning products

# %%
indicators[13]

# load data
indicator = indicators[13]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Percentage of individuals not buying online due to concerns about returning products
# not_buying_online_concern_about_returning

# %%
df.head(15)
# Out:
#                                             Indicator  Country  \
# 0   Individuals who did not buy online for payment...  Austria
# 1   Individuals who did not buy online for payment...  Austria
# 2   Individuals who did not buy online for payment...  Austria
# 3   Individuals who did not buy online for payment...  Austria
# 4   Individuals who did not buy online for payment...  Austria
# 5   Individuals who did not buy online for payment...  Austria
# 6   Individuals who did not buy online for payment...  Austria
# 7   Individuals who did not buy online for payment...  Austria
# 8   Individuals who did not buy online for payment...  Austria
# 9   Individuals who did not buy online for payment...  Austria
# 10  Individuals who did not buy online for payment...  Austria
# 11  Individuals who did not buy online for payment...  Austria
# 12  Individuals who did not buy online for payment...  Austria
# 13  Individuals who did not buy online for payment...  Austria
# 14  Individuals who did not buy online for payment...  Austria
#
#                                              Variable  \
# 0   Individuals who, in the last 12 months, haven'...
# 1   Individuals who, in the last 12 months, haven'...
# 2   Individuals who, in the last 12 months, haven'...
# 3   Individuals who, in the last 12 months, haven'...
# 4   Individuals who, in the last 12 months, haven'...
# 5   Individuals who, in the last 12 months, haven'...
# 6   Individuals who, in the last 12 months, haven'...
# 7   Individuals who, in the last 12 months, haven'...
# 8   Individuals who, in the last 12 months, haven'...
# 9   Individuals who, in the last 12 months, haven'...
# 10  Individuals who, in the last 12 months, haven'...
# 11  Individuals who, in the last 12 months, haven'...
# 12  Individuals who, in the last 12 months, haven'...
# 13  Individuals who, in the last 12 months, haven'...
# 14  Individuals who, in the last 12 months, haven'...
#
#                                                  Unit  \
# 0   Percentage of individuals who ordered goods or...
# 1   Percentage of individuals who ordered goods or...
# 2   Percentage of individuals who ordered goods or...
# 3   Percentage of individuals who ordered goods or...
# 4   Percentage of individuals who ordered goods or...
# 5   Percentage of individuals who ordered goods or...
# 6   Percentage of individuals who ordered goods or...
# 7   Percentage of individuals who ordered goods or...
# 8   Percentage of individuals who ordered goods or...
# 9   Percentage of individuals who ordered goods or...
# 10  Percentage of individuals who ordered goods or...
# 11  Percentage of individuals who ordered goods or...
# 12  Percentage of individuals who ordered goods or...
# 13  Percentage of individuals who ordered goods or...
# 14  Percentage of individuals who ordered goods or...
#
#                            Scope  Time      Value  Flags
# 0   All individuals (aged 16-74)  2005  10.358200    NaN
# 1   All individuals (aged 16-74)  2006  14.697300    NaN
# 2   All individuals (aged 16-74)  2009  25.081000    NaN
# 3   All individuals (aged 16-74)  2015  17.049300    NaN
# 4   All individuals (aged 16-74)  2017  15.114670    NaN
# 5   All individuals (aged 16-74)  2019  16.727490    NaN
# 6         Individuals aged 16-24  2005   7.911900    NaN
# 7         Individuals aged 16-24  2006  13.751800    NaN
# 8         Individuals aged 16-24  2009  24.068800    NaN
# 9         Individuals aged 16-24  2015  12.671000    NaN
# 10        Individuals aged 16-24  2017  12.306280    NaN
# 11        Individuals aged 16-24  2019   3.328083    NaN
# 12        Individuals aged 55-74  2005  15.146800    NaN
# 13        Individuals aged 55-74  2006  16.317800    NaN
# 14        Individuals aged 55-74  2009  24.404300    NaN

# %%
# filter most recent year and global value
df = df[(df.Time==2019)]
df = df[(df.Scope =='All individuals (aged 16-74)')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = False
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Year'] = df['Time']
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#                       Country Name  Year  \
# 5                          Austria  2019
# 22                         Belgium  2019
# 37                  Czech Republic  2019
# 51                         Denmark  2019
# 67                         Estonia  2019
# 121  European Union (28 countries)  2019
# 135                        Finland  2019
# 152                         France  2019
# 167                        Germany  2019
# 184                         Greece  2019
# 202                        Hungary  2019
# 219                        Iceland  2019
# 234                        Ireland  2019
# 252                          Italy  2019
# 270                         Latvia  2019
# 288                      Lithuania  2019
# 306                     Luxembourg  2019
# 324                    Netherlands  2019
# 342                         Norway  2019
# 359                         Poland  2019
#
#                                              Indicator   data_col  \
# 5    Percentage of individuals not buying online du...  16.727490
# 22   Percentage of individuals not buying online du...   9.164280
# 37   Percentage of individuals not buying online du...   8.857784
# 51   Percentage of individuals not buying online du...  13.273220
# 67   Percentage of individuals not buying online du...   3.968984
# 121  Percentage of individuals not buying online du...  17.256510
# 135  Percentage of individuals not buying online du...  46.960710
# 152  Percentage of individuals not buying online du...  14.236370
# 167  Percentage of individuals not buying online du...  16.450070
# 184  Percentage of individuals not buying online du...   9.599324
# 202  Percentage of individuals not buying online du...  37.607560
# 219  Percentage of individuals not buying online du...  26.551820
# 234  Percentage of individuals not buying online du...   3.234247
# 252  Percentage of individuals not buying online du...   9.380008
# 270  Percentage of individuals not buying online du...   8.105389
# 288  Percentage of individuals not buying online du...  22.905720
# 306  Percentage of individuals not buying online du...   6.451037
# 324  Percentage of individuals not buying online du...  23.332380
# 342  Percentage of individuals not buying online du...  18.048640
# 359  Percentage of individuals not buying online du...   5.992940
#
#      new_rank_score  higher_is_better
# 5          4.589811             False
# 22         5.380248             False
# 37         5.412280             False
# 51         4.950819             False
# 67         5.923212             False
# 121        4.534523             False
# 135        1.430114             False
# 152        4.850160             False
# 167        4.618804             False
# 184        5.334781             False
# 202        2.407619             False
# 219        3.563063             False
# 234        6.000000             False
# 252        5.357702             False
# 270        5.490913             False
# 288        3.944119             False
# 306        5.663811             False
# 324        3.899529             False
# 342        4.451737             False
# 359        5.711687             False

# %%
### 15. Percentage of individuals not buying online due to payment security concerns

# %%
indicators[14]

# load data
indicator = indicators[14]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Percentage of individuals not buying online due to payment security concerns
# not_buying_online_concern_about_security

# %%
df.head(15)
# Out:
#                                             Indicator  Country  \
# 0   Individuals who did not buy online for payment...  Austria
# 1   Individuals who did not buy online for payment...  Austria
# 2   Individuals who did not buy online for payment...  Austria
# 3   Individuals who did not buy online for payment...  Austria
# 4   Individuals who did not buy online for payment...  Austria
# 5   Individuals who did not buy online for payment...  Austria
# 6   Individuals who did not buy online for payment...  Austria
# 7   Individuals who did not buy online for payment...  Austria
# 8   Individuals who did not buy online for payment...  Austria
# 9   Individuals who did not buy online for payment...  Austria
# 10  Individuals who did not buy online for payment...  Austria
# 11  Individuals who did not buy online for payment...  Austria
# 12  Individuals who did not buy online for payment...  Belgium
# 13  Individuals who did not buy online for payment...  Belgium
# 14  Individuals who did not buy online for payment...  Belgium
#
#                                              Variable  \
# 0   Individuals who, in the last 12 months, haven'...
# 1   Individuals who, in the last 12 months, haven'...
# 2   Individuals who, in the last 12 months, haven'...
# 3   Individuals who, in the last 12 months, haven'...
# 4   Individuals who, in the last 12 months, haven'...
# 5   Individuals who, in the last 12 months, haven'...
# 6   Individuals who, in the last 12 months, haven'...
# 7   Individuals who, in the last 12 months, haven'...
# 8   Individuals who, in the last 12 months, haven'...
# 9   Individuals who, in the last 12 months, haven'...
# 10  Individuals who, in the last 12 months, haven'...
# 11  Individuals who, in the last 12 months, haven'...
# 12  Individuals who, in the last 12 months, haven'...
# 13  Individuals who, in the last 12 months, haven'...
# 14  Individuals who, in the last 12 months, haven'...
#
#                                                  Unit  \
# 0   Percentage of individuals who ordered goods or...
# 1   Percentage of individuals who ordered goods or...
# 2   Percentage of individuals who ordered goods or...
# 3   Percentage of individuals who ordered goods or...
# 4   Percentage of individuals who ordered goods or...
# 5   Percentage of individuals who ordered goods or...
# 6   Percentage of individuals who ordered goods or...
# 7   Percentage of individuals who ordered goods or...
# 8   Percentage of individuals who ordered goods or...
# 9   Percentage of individuals who ordered goods or...
# 10  Percentage of individuals who ordered goods or...
# 11  Percentage of individuals who ordered goods or...
# 12  Percentage of individuals who ordered goods or...
# 13  Percentage of individuals who ordered goods or...
# 14  Percentage of individuals who ordered goods or...
#
#                            Scope  Time     Value  Flags
# 0   All individuals (aged 16-74)  2009  38.80930    NaN
# 1   All individuals (aged 16-74)  2015  34.89850    NaN
# 2   All individuals (aged 16-74)  2017  33.04743    NaN
# 3   All individuals (aged 16-74)  2019  31.19888    NaN
# 4         Individuals aged 16-24  2009  38.34010    NaN
# 5         Individuals aged 16-24  2015  34.96870    NaN
# 6         Individuals aged 16-24  2017  16.65675    NaN
# 7         Individuals aged 16-24  2019  12.88121    NaN
# 8         Individuals aged 55-74  2009  40.57610    NaN
# 9         Individuals aged 55-74  2015  42.60200    NaN
# 10        Individuals aged 55-74  2017  35.10980    NaN
# 11        Individuals aged 55-74  2019  39.53044    NaN
# 12  All individuals (aged 16-74)  2009  35.44600    NaN
# 13  All individuals (aged 16-74)  2015  23.41350    NaN
# 14  All individuals (aged 16-74)  2017  15.29681    NaN

# %%
# filter most recent year and global value
df = df[(df.Time==2019)]
df = df[(df.Scope =='All individuals (aged 16-74)')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = False
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Year'] = df['Time']
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#                       Country Name  Year  \
# 3                          Austria  2019
# 15                         Belgium  2019
# 27                  Czech Republic  2019
# 39                         Denmark  2019
# 51                         Estonia  2019
# 84   European Union (28 countries)  2019
# 96                         Finland  2019
# 108                         France  2019
# 120                        Germany  2019
# 132                         Greece  2019
# 144                        Hungary  2019
# 155                        Iceland  2019
# 164                        Ireland  2019
# 176                          Italy  2019
# 188                         Latvia  2019
# 200                      Lithuania  2019
# 212                     Luxembourg  2019
# 224                    Netherlands  2019
# 236                         Norway  2019
# 247                         Poland  2019
#
#                                              Indicator   data_col  \
# 3    Percentage of individuals not buying online du...  31.198880
# 15   Percentage of individuals not buying online du...  18.129610
# 27   Percentage of individuals not buying online du...   9.814267
# 39   Percentage of individuals not buying online du...  18.770550
# 51   Percentage of individuals not buying online du...   4.357608
# 84   Percentage of individuals not buying online du...  24.308600
# 96   Percentage of individuals not buying online du...  64.427210
# 108  Percentage of individuals not buying online du...  40.843490
# 120  Percentage of individuals not buying online du...  25.121840
# 132  Percentage of individuals not buying online du...  23.223810
# 144  Percentage of individuals not buying online du...  42.285470
# 155  Percentage of individuals not buying online du...  25.921260
# 164  Percentage of individuals not buying online du...  16.830400
# 176  Percentage of individuals not buying online du...   8.159797
# 188  Percentage of individuals not buying online du...  11.267850
# 200  Percentage of individuals not buying online du...  13.799410
# 212  Percentage of individuals not buying online du...  12.390420
# 224  Percentage of individuals not buying online du...  29.817950
# 236  Percentage of individuals not buying online du...  35.544350
# 247  Percentage of individuals not buying online du...   6.025776
#
#      new_rank_score  higher_is_better
# 3          3.765819             False
# 15         4.853663             False
# 27         5.545805             False
# 39         4.800313             False
# 51         6.000000             False
# 84         4.339344             False
# 96         1.000000             False
# 108        2.963033             False
# 120        4.271652             False
# 132        4.429638             False
# 144        2.843007             False
# 155        4.205111             False
# 164        4.961805             False
# 176        5.683518             False
# 188        5.424814             False
# 200        5.214095             False
# 212        5.331375             False
# 224        3.880763             False
# 236        3.404116             False
# 247        5.861147             False

# %%
### 16. E-waste generated, kilograms per inhabitant

# %%
indicators[15]

# load data
indicator = indicators[15]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# E-waste generated, kilograms per inhabitant
# ewaste_per_inhabitant

# %%
df.head(15)
# Out:
#    iso3c region_id          country_name income_id           gdp  \
# 0    ABW       LCN                 Aruba       HIC  35563.312500
# 1    AFG       SAS           Afghanistan       LIC   2057.062256
# 2    AGO       SSF                Angola       LMC   8036.690430
# 3    ALB       ECS               Albania       UMC  13724.058594
# 4    AND       ECS               Andorra       HIC  43711.800781
# 5    ARE       MEA  United Arab Emirates       HIC  67119.132812
# 6    ARG       LCN             Argentina       HIC  23550.099609
# 7    ARM       ECS               Armenia       UMC  11019.838867
# 8    ASM       EAS        American Samoa       UMC  11113.442383
# 9    ATG       LCN   Antigua and Barbuda       HIC  17965.501953
# 10   AUS       EAS             Australia       HIC  47784.179688
# 11   AUT       ECS               Austria       HIC  56029.613281
# 12   AZE       ECS            Azerbaijan       UMC  14853.910156
# 13   BDI       SSF               Burundi       LIC    839.778503
# 14   BEL       ECS               Belgium       HIC  51914.914062
#
#     composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                    51.80                       6.70
# 3                                    51.40                       4.50
# 4                                    31.20                       8.20
# 5                                    39.00                       4.00
# 6                                    38.74                       3.16
# 7                                    57.00                       3.20
# 8                                    19.70                       3.40
# 9                                    46.00                       7.00
# 10                                   48.44                       3.81
# 11                                   31.40                       7.00
# 12                                   45.19                       5.28
# 13                                   81.00                       2.90
# 14                                   14.18                       3.10
#
#     composition_metal_percent  composition_other_percent  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                        4.40                      11.50
# 3                        4.80                      15.21
# 4                        2.60                      11.60
# 5                        3.00                      10.00
# 6                        1.84                      15.36
# 7                        3.40                      17.40
# 8                        7.90                      25.60
# 9                        7.00                      12.00
# 10                      19.38                       3.46
# 11                       4.40                      18.50
# 12                       3.49                      13.73
# 13                       2.10                       3.20
# 14                       1.91                      40.14
#
#     composition_paper_cardboard_percent  ...  \
# 0                                   NaN  ...
# 1                                   NaN  ...
# 2                                 11.90  ...
# 3                                  9.90  ...
# 4                                 35.10  ...
# 5                                 25.00  ...
# 6                                 13.96  ...
# 7                                  6.70  ...
# 8                                 26.40  ...
# 9                                 15.00  ...
# 10                                17.30  ...
# 11                                19.70  ...
# 12                                10.93  ...
# 13                                 7.30  ...
# 14                                18.38  ...
#
#     waste_treatment_controlled_landfill_percent  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                          8.90
# 7                                           NaN
# 8                                           NaN
# 9                                         98.68
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
#
#     waste_treatment_incineration_percent  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                  52.10
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                  9.77
# 11                                 37.90
# 12                                   NaN
# 13                                   NaN
# 14                                 43.39
#
#     waste_treatment_landfill_unspecified_percent  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                           9.00
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                         48.87
# 11                                          2.98
# 12                                           NaN
# 13                                           NaN
# 14                                          0.91
#
#     waste_treatment_open_dump_percent waste_treatment_other_percent  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# 5                                62.0                           NaN
# 6                                22.6                           NaN
# 7                               100.0                           NaN
# 8                                 NaN                           NaN
# 9                                 NaN                           NaN
# 10                                NaN                           NaN
# 11                                NaN                           NaN
# 12                              100.0                           NaN
# 13                                NaN                           NaN
# 14                                NaN                           NaN
#
#    waste_treatment_recycling_percent  \
# 0                             11.000
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                             20.000
# 6                              6.000
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                            42.100
# 11                            25.660
# 12                               NaN
# 13                               NaN
# 14                            34.303
#
#    waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                62.5
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    waste_treatment_unaccounted_for_percent  \
# 0                                    89.00
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                    47.90
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                     1.14
# 10                                     NaN
# 11                                    2.22
# 12                                     NaN
# 13                                     NaN
# 14                                    2.26
#
#    waste_treatment_waterways_marine_percent  where_where_is_this_data_measured
# 0                                       NaN                                NaN
# 1                                       NaN                              Other
# 2                                       NaN                                NaN
# 3                                       NaN                Some disposal sites
# 4                                       NaN                                NaN
# 5                                       NaN                                NaN
# 6                                       NaN                              Other
# 7                                       NaN                              Other
# 8                                       NaN                                NaN
# 9                                       0.1                      Disposal Site
# 10                                      NaN                                NaN
# 11                                      NaN                                NaN
# 12                                      NaN                            Various
# 13                                      NaN                                NaN
# 14                                      NaN                                NaN
#
# [15 rows x 51 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
# Use special_waste_e_waste_tons_year times one thousand and divde by total population
df['data_col'] = df['special_waste_e_waste_tons_year']*1000/df['population_population_number_of_people'] 
df['Year'] = 2021
df['Country Name'] = df['country_name']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#             Country Name  Year                                    Indicator  \
# 0                  Aruba  2021  E-waste generated, kilograms per inhabitant
# 1            Afghanistan  2021  E-waste generated, kilograms per inhabitant
# 2                 Angola  2021  E-waste generated, kilograms per inhabitant
# 3                Albania  2021  E-waste generated, kilograms per inhabitant
# 4                Andorra  2021  E-waste generated, kilograms per inhabitant
# 5   United Arab Emirates  2021  E-waste generated, kilograms per inhabitant
# 6              Argentina  2021  E-waste generated, kilograms per inhabitant
# 7                Armenia  2021  E-waste generated, kilograms per inhabitant
# 8         American Samoa  2021  E-waste generated, kilograms per inhabitant
# 9    Antigua and Barbuda  2021  E-waste generated, kilograms per inhabitant
# 10             Australia  2021  E-waste generated, kilograms per inhabitant
# 11               Austria  2021  E-waste generated, kilograms per inhabitant
# 12            Azerbaijan  2021  E-waste generated, kilograms per inhabitant
# 13               Burundi  2021  E-waste generated, kilograms per inhabitant
# 14               Belgium  2021  E-waste generated, kilograms per inhabitant
# 15                 Benin  2021  E-waste generated, kilograms per inhabitant
# 16          Burkina Faso  2021  E-waste generated, kilograms per inhabitant
# 17            Bangladesh  2021  E-waste generated, kilograms per inhabitant
# 18              Bulgaria  2021  E-waste generated, kilograms per inhabitant
# 19               Bahrain  2021  E-waste generated, kilograms per inhabitant
#
#      data_col  new_rank_score  higher_is_better
# 0         NaN             NaN              True
# 1    0.577100        1.040883              True
# 2    3.665901        1.261006              True
# 3    7.007240        1.499126              True
# 4         NaN             NaN              True
# 5   13.714713        1.977133              True
# 6    6.786638        1.483405              True
# 7    4.817254        1.343057              True
# 8         NaN             NaN              True
# 9   11.366337        1.809777              True
# 10  24.128456        2.719267              True
# 11  18.719471        2.333797              True
# 12   6.528943        1.465040              True
# 13   0.741667        1.052611              True
# 14  52.557655        4.745269              True
# 15   1.485033        1.105587              True
# 16   0.607378        1.043041              True
# 17   0.911852        1.064739              True
# 18   7.656187        1.545373              True
# 19  14.033404        1.999845              True

# %%
### 17. Automation-led unemployment

# %%
indicators[16]

# load data
indicator = indicators[16]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Automation-led unemployment
# automation_led_unemployment

# %%
df.head(15)
# Out:
#         Country  No. of employees potentially automable (millions)  \
# 0         Japan                                              35.60
# 1      Thailand                                              21.00
# 2       Senegal                                               2.20
# 3      Colombia                                               9.30
# 4          Peru                                               6.90
# 5        Taiwan                                               5.20
# 6         Kenya                                               7.40
# 7   South Korea                                              12.50
# 8        Sweden                                               2.10
# 9    Costa Rica                                               1.10
# 10        Qatar                                               0.54
# 11    Indonesia                                              52.60
# 12        India                                             235.10
# 13       Mexico                                              25.50
# 14     Malaysia                                               6.30
#
#     Total employees (millions)  Potential Rate of Automation (%)
# 0                        63.90                             55.71
# 1                        38.40                             54.69
# 2                         4.07                             54.00
# 3                        17.50                             53.14
# 4                        13.00                             53.08
# 5                         9.80                             53.06
# 6                        14.20                             52.11
# 7                        24.00                             52.08
# 8                         4.04                             52.00
# 9                         2.12                             52.00
# 10                        1.04                             52.00
# 11                      101.50                             51.82
# 12                      454.20                             51.76
# 13                       49.30                             51.72
# 14                       12.20                             51.64

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Potential Rate of Automation (%)'] 
df['Year'] = 2018
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#    Country Name  Year                    Indicator  data_col  new_rank_score  \
# 0         Japan  2018  Automation-led unemployment     55.71        6.000000
# 1      Thailand  2018  Automation-led unemployment     54.69        5.656797
# 2       Senegal  2018  Automation-led unemployment     54.00        5.424630
# 3      Colombia  2018  Automation-led unemployment     53.14        5.135262
# 4          Peru  2018  Automation-led unemployment     53.08        5.115074
# 5        Taiwan  2018  Automation-led unemployment     53.06        5.108345
# 6         Kenya  2018  Automation-led unemployment     52.11        4.788694
# 7   South Korea  2018  Automation-led unemployment     52.08        4.778600
# 8        Sweden  2018  Automation-led unemployment     52.00        4.751682
# 9    Costa Rica  2018  Automation-led unemployment     52.00        4.751682
# 10        Qatar  2018  Automation-led unemployment     52.00        4.751682
# 11    Indonesia  2018  Automation-led unemployment     51.82        4.691117
# 12        India  2018  Automation-led unemployment     51.76        4.670929
# 13       Mexico  2018  Automation-led unemployment     51.72        4.657470
# 14     Malaysia  2018  Automation-led unemployment     51.64        4.630552
# 15        China  2018  Automation-led unemployment     51.17        4.472409
# 16        Ghana  2018  Automation-led unemployment     50.79        4.344549
# 17     Tanzania  2018  Automation-led unemployment     50.50        4.246972
# 18      Morroco  2018  Automation-led unemployment     50.45        4.230148
# 19        Italy  2018  Automation-led unemployment     50.43        4.223419
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19              True

# %%
### 18. Cyberbullying

# %%
indicators[17]

# load data
indicator = indicators[17]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Cyberbullying
# cyberbullying_rate

# %%
df.head(15)

# Need to move the top row down further
# Out:
#    2011 2016  2018        Country
# 0    32   32    37          India
# 1    20   19    29         Brazil
# 2    15   34    26  United States
# 3    12   13    25        Belgium
# 4    10   25    26   South Africa
# 5    --   --    23       Malaysia
# 6    14   20    23         Sweden
# 7    18   17    20         Canada
# 8     5   14    20         Turkey
# 9    18   17    19   Saudi Arabia
# 10   13   20    19      Australia
# 11    8   20    18         Mexico
# 12   11   15    18  Great Britain
# 13   11   20    17          China
# 14   --   --    16         Serbia

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2018'] 
df['Year'] = 2018
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#      Country Name  Year      Indicator  data_col  new_rank_score  \
# 0           India  2018  Cyberbullying        37        1.000000
# 1          Brazil  2018  Cyberbullying        29        2.111111
# 2   United States  2018  Cyberbullying        26        2.527778
# 3         Belgium  2018  Cyberbullying        25        2.666667
# 4    South Africa  2018  Cyberbullying        26        2.527778
# 5        Malaysia  2018  Cyberbullying        23        2.944444
# 6          Sweden  2018  Cyberbullying        23        2.944444
# 7          Canada  2018  Cyberbullying        20        3.361111
# 8          Turkey  2018  Cyberbullying        20        3.361111
# 9    Saudi Arabia  2018  Cyberbullying        19        3.500000
# 10      Australia  2018  Cyberbullying        19        3.500000
# 11         Mexico  2018  Cyberbullying        18        3.638889
# 12  Great Britain  2018  Cyberbullying        18        3.638889
# 13          China  2018  Cyberbullying        17        3.777778
# 14         Serbia  2018  Cyberbullying        16        3.916667
# 15        Germany  2018  Cyberbullying        14        4.194444
# 16      Argentina  2018  Cyberbullying        14        4.194444
# 17           Peru  2018  Cyberbullying        14        4.194444
# 18    South Korea  2018  Cyberbullying        13        4.333333
# 19          Italy  2018  Cyberbullying        12        4.472222
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19              True

# %%
### 19. Global Wellbeing Initiative

# %%
indicators[18]

# load data
indicator = indicators[18]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Strange the global_wellbeing_initiative is clearly in the data manifest and the link works well 
# but it has not been moved to the processed folder
# Out:
# Global Wellbeing Initiative (World Happiness Index)
# global_wellbeing_initiative

# %%
### 20. Financial Inclusiveness

# %%
indicators[19]

# load data
indicator = indicators[19]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)


df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Strange the global_wellbeing_initiative is clearly in the data manifest and the link works well 
# but it has not been moved to the processed folder
# Out:
# Financial Inclusiveness
# financial_inclusiveness

# %%
df.head(15)
# Out:
#              Unnamed: 0 Account (% age 15+) Account, male (% age 15+)  \
# 0            Low income                  9%                       15%
# 1            Low income                 10%                       16%
# 2            Low income                 15%                       23%
# 3   Lower middle income                 39%                       39%
# 4   Lower middle income                 29%                       36%
# 5   Upper middle income                 28%                       34%
# 6   Upper middle income                 38%                       43%
# 7   Upper middle income                 40%                       42%
# 8                   NaN                 22%                       30%
# 9                   NaN                 30%                       38%
# 10                  NaN                 37%                       48%
# 11          High income                 60%                       69%
# 12          High income                 84%                       90%
# 13          High income                 88%                       93%
# 14  Upper middle income                 33%                       35%
#
#    Account, in labor force (% age 15+)   \
# 0                                   15%
# 1                                   15%
# 2                                   25%
# 3                                   46%
# 4                                   36%
# 5                                   36%
# 6                                   44%
# 7                                   53%
# 8                                   33%
# 9                                   42%
# 10                                  51%
# 11                                  80%
# 12                                  91%
# 13                                  93%
# 14                                  37%
#
#    Account, out of labor force (% age 15+)  Account, female (% age 15+)  \
# 0                                        2%                          3%
# 1                                        4%                          4%
# 2                                        4%                          7%
# 3                                       31%                         39%
# 4                                       12%                         22%
# 5                                       15%                         23%
# 6                                       29%                         34%
# 7                                       27%                         38%
# 8                                       11%                         14%
# 9                                       18%                         22%
# 10                                      24%                         26%
# 11                                      24%                         47%
# 12                                      49%                         68%
# 13                                      57%                         76%
# 14                                      28%                         32%
#
#    Account, young adults (% ages 15-24) Account, older adults (% ages 25+)  \
# 0                                    6%                                11%
# 1                                    7%                                12%
# 2                                   10%                                18%
# 3                                   30%                                45%
# 4                                   15%                                38%
# 5                                   26%                                29%
# 6                                   30%                                40%
# 7                                   32%                                43%
# 8                                   15%                                26%
# 9                                   21%                                34%
# 10                                  21%                                43%
# 11                                  26%                                73%
# 12                                  67%                                88%
# 13                                  60%                                91%
# 14                                  16%                                38%
#
#    Account, primary education or less (% ages 15+)   \
# 0                                                5%
# 1                                                5%
# 2                                                9%
# 3                                               35%
# 4                                               14%
# 5                                               15%
# 6                                               24%
# 7                                               27%
# 8                                               14%
# 9                                               21%
# 10                                              26%
# 11                                              43%
# 12                                              64%
# 13                                              71%
# 14                                              28%
#
#    Account, secondary education or more (% ages 15+)   ...  \
# 0                                                 30%  ...
# 1                                                 23%  ...
# 2                                                 31%  ...
# 3                                                 44%  ...
# 4                                                 70%  ...
# 5                                                 36%  ...
# 6                                                 56%  ...
# 7                                                 56%  ...
# 8                                                 31%  ...
# 9                                                 39%  ...
# 10                                                49%  ...
# 11                                                61%  ...
# 12                                                85%  ...
# 13                                                89%  ...
# 14                                                37%  ...
#
#    Mobile money account, female (% age 15+)   \
# 0                                        NaN
# 1                                         0%
# 2                                         1%
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                         2%
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       10%
# 13                                       18%
# 14                                       NaN
#
#    Mobile money account, young adults  (% age 15-24)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  6%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                10%
# 13                                                10%
# 14                                                NaN
#
#    Mobile money account, older adults (% age 25+)   \
# 0                                              NaN
# 1                                               0%
# 2                                               1%
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                               1%
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             12%
# 13                                             22%
# 14                                             NaN
#
#    Mobile money account, primary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  1%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                 9%
# 14                                                NaN
#
#    Mobile money account, secondary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  2%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                12%
# 13                                                22%
# 14                                                NaN
#
#    Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  0%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                16%
# 14                                                NaN
#
#    Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                 NaN
# 1                                                  1%
# 2                                                  1%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                15%
# 13                                                25%
# 14                                                NaN
#
#    Mobile money account, rural  (% age 15+)  data_country            data_year
# 0                                        NaN          NaN           Low income
# 1                                         0%          NaN           Low income
# 2                                         1%          NaN           Low income
# 3                                        NaN          NaN  Lower middle income
# 4                                        NaN          NaN  Lower middle income
# 5                                        NaN          NaN  Upper middle income
# 6                                        NaN          NaN  Upper middle income
# 7                                         2%          NaN  Upper middle income
# 8                                        NaN          NaN                  NaN
# 9                                        NaN          NaN                  NaN
# 10                                       NaN          NaN                  NaN
# 11                                       NaN          NaN          High income
# 12                                       16%          NaN          High income
# 13                                       14%          NaN          High income
# 14                                       NaN          NaN  Upper middle income
#
# [15 rows x 779 columns]

# %%
### 21. E-commerce activity (% of individuals buying online and frequency)

# %%
indicators[20]

# load data
indicator = indicators[20]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Added _ between spaces to see if this changes anything
# Out:
# E-commerce activity (% of individuals buying online and frequency)
# individuals_buying_online_frequency

# %%
df.head(15)

# Move the top row down further
# Out:
#     RANK COUNTRY/ECONOMY  VALUE (%)   SCORE  Year
# 0    1.0         Denmark      77.97  100.00  2017
# 1    2.0     Netherlands      75.72   97.11  2017
# 2    3.0          Norway      75.63   96.99  2017
# 3    4.0  United Kingdom      74.74   95.86  2017
# 4    5.0     Korea, Rep.      72.47   92.94  2017
# 5    6.0          Sweden      71.65   91.90  2017
# 6    7.0   United States      70.43   90.33  2017
# 7    8.0     New Zealand      69.11   88.63  2017
# 8    9.0          Canada      68.57   87.95  2017
# 9   10.0       Australia      67.69   86.81  2017
# 10  11.0         Germany      66.84   85.73  2017
# 11  12.0         Finland      60.76   77.92  2017
# 12  13.0         Ireland      59.49   76.29  2017
# 13  14.0         Belgium      57.27   73.44  2017
# 14  15.0     Switzerland      56.02   71.84  2017

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['VALUE (%)'] 
df['Country Name'] = df['COUNTRY/ECONOMY']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#       Country Name  Year                                          Indicator  \
# 0          Denmark  2017  E-commerce activity (% of individuals buying o...
# 1      Netherlands  2017  E-commerce activity (% of individuals buying o...
# 2           Norway  2017  E-commerce activity (% of individuals buying o...
# 3   United Kingdom  2017  E-commerce activity (% of individuals buying o...
# 4      Korea, Rep.  2017  E-commerce activity (% of individuals buying o...
# 5           Sweden  2017  E-commerce activity (% of individuals buying o...
# 6    United States  2017  E-commerce activity (% of individuals buying o...
# 7      New Zealand  2017  E-commerce activity (% of individuals buying o...
# 8           Canada  2017  E-commerce activity (% of individuals buying o...
# 9        Australia  2017  E-commerce activity (% of individuals buying o...
# 10         Germany  2017  E-commerce activity (% of individuals buying o...
# 11         Finland  2017  E-commerce activity (% of individuals buying o...
# 12         Ireland  2017  E-commerce activity (% of individuals buying o...
# 13         Belgium  2017  E-commerce activity (% of individuals buying o...
# 14     Switzerland  2017  E-commerce activity (% of individuals buying o...
# 15          France  2017  E-commerce activity (% of individuals buying o...
# 16           Italy  2017  E-commerce activity (% of individuals buying o...
# 17           Spain  2017  E-commerce activity (% of individuals buying o...
# 18  Czech Republic  2017  E-commerce activity (% of individuals buying o...
# 19      Luxembourg  2017  E-commerce activity (% of individuals buying o...
#
#     data_col  new_rank_score  higher_is_better
# 0      77.97        6.000000              True
# 1      75.72        5.855658              True
# 2      75.63        5.849885              True
# 3      74.74        5.792789              True
# 4      72.47        5.647164              True
# 5      71.65        5.594560              True
# 6      70.43        5.516295              True
# 7      69.11        5.431614              True
# 8      68.57        5.396972              True
# 9      67.69        5.340518              True
# 10     66.84        5.285989              True
# 11     60.76        4.895946              True
# 12     59.49        4.814473              True
# 13     57.27        4.672055              True
# 14     56.02        4.591866              True
# 15     55.51        4.559148              True
# 16     54.94        4.522581              True
# 17     54.18        4.473826              True
# 18     54.05        4.465486              True
# 19     51.12        4.277521              True

# %%
### 22. E-commerce activity (Types of goods and services purchased online)

# %%
indicators[21]

# load data
indicator = indicators[21]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Move the top row down further
# This is a list of categories, wonder if it will do
# Out:
# E-commerce activity (Types of goods and services purchased online)
# e-commerce_activity

# %%
df.head(15)
# Out:
#               Category  \
# 0       Luxury apparel
# 1       Active apparel
# 2      General apparel
# 3        All verticals
# 4    Health and beauty
# 5  Home and appliances
#
#    Average e-commerce spending per online shopper worldwide per visit as of 1st quarter 2021, by category (in U.S. dollars)
# 0                                               3.45
# 1                                               2.96
# 2                                               2.70
# 3                                               3.39
# 4                                               2.40
# 5                                               2.08

# %%
### 23. Top Visited websites

# %%
indicators[22]

# load data
indicator = indicators[22]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Top Visited websites
# top_sites

# %%
df.head(15)
# Out:
#      1     google.com
# 0    2    youtube.com
# 1    3   facebook.com
# 2    4      baidu.com
# 3    5  wikipedia.org
# 4    6      yahoo.com
# 5    7   google.co.in
# 6    8     reddit.com
# 7    9         qq.com
# 8   10     amazon.com
# 9   11     taobao.com
# 10  12    twitter.com
# 11  13      tmall.com
# 12  14   google.co.jp
# 13  15       live.com
# 14  16         vk.com

# %%
### 24. Top YouTube Searches

# %%
indicators[23]

# load data
indicator = indicators[23]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Top YouTube Searches
# youtube_searches

# %%
df.head(15)
# Out:
#      #                         Keyword Search Volume
# 0    1                             bts    16,723,304
# 1    2                       pewdiepie    16,495,659
# 2    3                            asmr    14,655,088
# 3    4                   billie eilish    13,801,247
# 4    5                      baby shark    12,110,100
# 5    6                   old town road    10,456,524
# 6    7                           music    10,232,134
# 7    8                         badabun    10,188,997
# 8    9                       blackpink     9,580,131
# 9   10                        fortnite     9,117,342
# 10  11                       minecraft     8,540,800
# 11  12           pewdiepie vs t series     8,252,156
# 12  13  peliculas completas en español     8,223,530
# 13  14                        senorita     8,203,240
# 14  15                   ariana grande     7,599,148

# %%
### 25. Top Google searches

# %%
indicators[24]

# load data
indicator = indicators[24]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Top Google searches
# google_trends

# %%
df.head(15)
# Out:
#     Unnamed: 0  data_country  data_year
# 0         13.6          13.6       13.6
# 1          4.1           4.1        4.1
# 2          4.1           4.1        4.1
# 3          4.1           4.1        4.1
# 4          2.2           2.2        2.2
# 5          2.2           2.2        2.2
# 6          1.8           1.8        1.8
# 7          1.5           1.5        1.5
# 8          1.5           1.5        1.5
# 9          1.2           1.2        1.2
# 10         1.2           1.2        1.2
# 11         1.2           1.2        1.2
# 12         1.0           1.0        1.0
# 13         1.0           1.0        1.0
# 14         1.0           1.0        1.0

# %%
### 26. Internet Usage

# %%
indicators[25]

# load data
indicator = indicators[25]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Internet Usage
# ITU_database

# %%
df.head(15)
# Out:
#                    Country  Region  ISO  \
# 0                   Angola  Africa  AGO
# 1                    Benin  Africa  BEN
# 2                 Botswana  Africa  BWA
# 3             Burkina Faso  Africa  BFA
# 4                  Burundi  Africa  BDI
# 5               Cabo Verde  Africa  CPV
# 6                 Cameroon  Africa  CMR
# 7     Central African Rep.  Africa  CAF
# 8                     Chad  Africa  TCD
# 9      Congo (Rep. of the)  Africa  COG
# 10           Côte d'Ivoire  Africa  CIV
# 11  Dem. Rep. of the Congo  Africa  COD
# 12       Equatorial Guinea  Africa  GNQ
# 13                 Eritrea  Africa  ERI
# 14                Eswatini  Africa  SWZ
#
#                                        Indicator name    Year  Value  \
# 0   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 10  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 11  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 12  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 13  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 14  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
df = df[(df['Indicator name'] == 'Individuals using the Internet, total (%)')]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Year'] = 2019
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','data_col','new_rank_score','higher_is_better']].head(150)
# Out:
#        Country Name  Year  data_col  new_rank_score  higher_is_better
# 45916        Angola  2019      2.80          1.1400              True
# 45917         Benin  2019      3.13          1.1565              True
# 45918      Botswana  2019      6.00          1.3000              True
# 45919  Burkina Faso  2019      2.40          1.1200              True
# 45920       Burundi  2019      1.00          1.0500              True
# ...             ...   ...       ...             ...               ...
# 46061        Norway  2019     93.39          5.6695              True
# 46062        Poland  2019     62.32          4.1160              True
# 46063      Portugal  2019     53.30          3.6650              True
# 46064       Romania  2019     39.93          2.9965              True
# 46065    San Marino  2019       NaN             NaN              True
#
# [150 rows x 5 columns]

# %%
### 27. Households with a computer and with Internet Access

# %%
indicators[26]

# load data
indicator = indicators[26]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Households with a computer and with Internet access
# ITU_database

# %%
df.head(15)
# Out:
#                    Country  Region  ISO  \
# 0                   Angola  Africa  AGO
# 1                    Benin  Africa  BEN
# 2                 Botswana  Africa  BWA
# 3             Burkina Faso  Africa  BFA
# 4                  Burundi  Africa  BDI
# 5               Cabo Verde  Africa  CPV
# 6                 Cameroon  Africa  CMR
# 7     Central African Rep.  Africa  CAF
# 8                     Chad  Africa  TCD
# 9      Congo (Rep. of the)  Africa  COG
# 10           Côte d'Ivoire  Africa  CIV
# 11  Dem. Rep. of the Congo  Africa  COD
# 12       Equatorial Guinea  Africa  GNQ
# 13                 Eritrea  Africa  ERI
# 14                Eswatini  Africa  SWZ
#
#                                        Indicator name    Year  Value  \
# 0   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 10  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 11  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 12  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 13  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 14  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
df = df[(df['Indicator name'] == 'Households with Internet access at home (%)')]
df = df[(df.Year == 2019)]
df
# Out:
#                    Country        Region  ISO  \
# 44796               Angola        Africa  AGO
# 44797                Benin        Africa  BEN
# 44798             Botswana        Africa  BWA
# 44799         Burkina Faso        Africa  BFA
# 44800              Burundi        Africa  BDI
# ...                    ...           ...  ...
# 44987             Suriname  The Americas  SUR
# 44988  Trinidad and Tobago  The Americas  TTO
# 44989        United States  The Americas  USA
# 44990              Uruguay  The Americas  URY
# 44991            Venezuela  The Americas  VEN
#
#                                     Indicator name    Year      Value  \
# 44796  Households with Internet access at home (%)  2018.0   6.711401
# 44797  Households with Internet access at home (%)  2018.0        NaN
# 44798  Households with Internet access at home (%)  2018.0        NaN
# 44799  Households with Internet access at home (%)  2018.0        NaN
# 44800  Households with Internet access at home (%)  2018.0        NaN
# ...                                            ...     ...        ...
# 44987  Households with Internet access at home (%)  2018.0  52.752486
# 44988  Households with Internet access at home (%)  2018.0        NaN
# 44989  Households with Internet access at home (%)  2018.0  85.349794
# 44990  Households with Internet access at home (%)  2018.0  68.412062
# 44991  Households with Internet access at home (%)  2018.0        NaN
#
#        data_country  data_year
# 44796           NaN        NaN
# 44797           NaN        NaN
# 44798           NaN        NaN
# 44799           NaN        NaN
# 44800           NaN        NaN
# ...             ...        ...
# 44987           NaN        NaN
# 44988           NaN        NaN
# 44989           NaN        NaN
# 44990           NaN        NaN
# 44991           NaN        NaN
#
# [196 rows x 8 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']]
# Out:
#               Country Name    Year  \
# 44796               Angola  2018.0
# 44797                Benin  2018.0
# 44798             Botswana  2018.0
# 44799         Burkina Faso  2018.0
# 44800              Burundi  2018.0
# ...                    ...     ...
# 44987             Suriname  2018.0
# 44988  Trinidad and Tobago  2018.0
# 44989        United States  2018.0
# 44990              Uruguay  2018.0
# 44991            Venezuela  2018.0
#
#                                                Indicator   data_col  \
# 44796  Households with a computer and with Internet a...   6.711401
# 44797  Households with a computer and with Internet a...        NaN
# 44798  Households with a computer and with Internet a...        NaN
# 44799  Households with a computer and with Internet a...        NaN
# 44800  Households with a computer and with Internet a...        NaN
# ...                                                  ...        ...
# 44987  Households with a computer and with Internet a...  52.752486
# 44988  Households with a computer and with Internet a...        NaN
# 44989  Households with a computer and with Internet a...  85.349794
# 44990  Households with a computer and with Internet a...  68.412062
# 44991  Households with a computer and with Internet a...        NaN
#
#        new_rank_score  higher_is_better
# 44796        1.004915              True
# 44797             NaN              True
# 44798             NaN              True
# 44799             NaN              True
# 44800             NaN              True
# ...               ...               ...
# 44987        3.470159              True
# 44988             NaN              True
# 44989        5.215563              True
# 44990        4.308642              True
# 44991             NaN              True
#
# [196 rows x 6 columns]

# %%
### 28. % of population using Facebook

# %%
indicators[27]

# load data
indicator = indicators[27]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population using Facebook
# FB_users

# %%
df.head(15)
# Out:
#            Country Facebook Users Population in Thousands (2021)  \
# 0            India    251,000,000                      1,393,409
# 1    United States    240,000,000                        332,915
# 2           Brazil    139,000,000                        213,993
# 3        Indonesia    136,960,000                        276,362
# 4           Mexico     78,000,000                        130,262
# 5      Philippines     71,760,000                        111,047
# 6          Vietnam     66,720,000                         98,169
# 7         Thailand     46,000,000                         69,951
# 8   United Kingdom     44,000,000                         68,207
# 9           Turkey     44,000,000                         85,043
# 10           Egypt     42,400,000                        104,258
# 11            Iran     40,000,000                         85,029
# 12        Pakistan     37,070,000                        225,200
# 13      Bangladesh     33,713,000                        166,303
# 14          France     33,000,000                         65,426
#
#     Percentage of Facebook Users
# 0                          18.01
# 1                          72.09
# 2                          64.96
# 3                          49.56
# 4                          59.88
# 5                          64.62
# 6                          67.96
# 7                          65.76
# 8                          64.51
# 9                          51.74
# 10                         40.67
# 11                         47.04
# 12                         16.46
# 13                         20.27
# 14                         50.44

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Percentage of Facebook Users'] 
df['Year'] = 2021
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#       Country Name  Year                       Indicator  data_col  \
# 0            India  2021  % of population using Facebook     18.01
# 1    United States  2021  % of population using Facebook     72.09
# 2           Brazil  2021  % of population using Facebook     64.96
# 3        Indonesia  2021  % of population using Facebook     49.56
# 4           Mexico  2021  % of population using Facebook     59.88
# 5      Philippines  2021  % of population using Facebook     64.62
# 6          Vietnam  2021  % of population using Facebook     67.96
# 7         Thailand  2021  % of population using Facebook     65.76
# 8   United Kingdom  2021  % of population using Facebook     64.51
# 9           Turkey  2021  % of population using Facebook     51.74
# 10           Egypt  2021  % of population using Facebook     40.67
# 11            Iran  2021  % of population using Facebook     47.04
# 12        Pakistan  2021  % of population using Facebook     16.46
# 13      Bangladesh  2021  % of population using Facebook     20.27
# 14          France  2021  % of population using Facebook     50.44
#
#     new_rank_score  higher_is_better
# 0         1.897091              True
# 1         4.590855              True
# 2         4.235704              True
# 3         3.468619              True
# 4         3.982666              True
# 5         4.218769              True
# 6         4.385136              True
# 7         4.275553              True
# 8         4.213289              True
# 9         3.577207              True
# 10        3.025802              True
# 11        3.343096              True
# 12        1.819884              True
# 13        2.009663              True
# 14        3.512453              True

# %%
### 29. Gender gap for social media use

# %%
indicators[28]

# load data
indicator = indicators[28]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Gender gap for social media use
# gender_gaps

# %%
df.head(15)
# Out:
#    ISO Code      Country                 Region  Year  \
# 0       AFG  Afghanistan             South Asia  2014
# 1       AFG  Afghanistan             South Asia  2015
# 2       AFG  Afghanistan             South Asia  2016
# 3       AFG  Afghanistan             South Asia  2017
# 4       AFG  Afghanistan             South Asia  2018
# 5       AFG  Afghanistan             South Asia  2019
# 6       AGO       Angola     Sub-Saharan Africa  2014
# 7       AGO       Angola     Sub-Saharan Africa  2015
# 8       AGO       Angola     Sub-Saharan Africa  2016
# 9       AGO       Angola     Sub-Saharan Africa  2017
# 10      AGO       Angola     Sub-Saharan Africa  2018
# 11      AGO       Angola     Sub-Saharan Africa  2019
# 12      ALB      Albania  Europe & Central Asia  2014
# 13      ALB      Albania  Europe & Central Asia  2015
# 14      ALB      Albania  Europe & Central Asia  2016
#
#     Gender parity in account ownership  Gender gap in social media use  \
# 0                            11.109999                        0.000000
# 1                            14.087173                        0.000000
# 2                            17.064350                        0.000000
# 3                            20.041523                        0.000000
# 4                            20.041523                        0.000000
# 5                            20.041523                        0.000000
# 6                            55.237572                       46.428570
# 7                            55.237572                       46.428570
# 8                            55.237572                       46.428570
# 9                            55.237572                       38.646553
# 10                           55.237572                       38.646553
# 11                           55.237572                       49.552494
# 12                           75.398972                       36.507938
# 13                           79.937897                       36.507938
# 14                           84.476822                       36.507938
#
#     Gender gap in mobile ownership
# 0                         0.000000
# 1                         0.000000
# 2                         0.000000
# 3                         0.000000
# 4                         0.000000
# 5                         0.000000
# 6                        51.645042
# 7                        57.001461
# 8                        63.725491
# 9                        53.966476
# 10                       63.339275
# 11                       57.712311
# 12                       68.421051
# 13                       68.421051
# 14                       67.391304

# %%
df = df[df.Year==2019]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Gender gap in social media use'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year                        Indicator    data_col  \
# 5            Afghanistan  2019  Gender gap for social media use    0.000000
# 11                Angola  2019  Gender gap for social media use   49.552494
# 17               Albania  2019  Gender gap for social media use   41.406120
# 23  United Arab Emirates  2019  Gender gap for social media use   13.890497
# 29             Argentina  2019  Gender gap for social media use  100.000000
# 35               Armenia  2019  Gender gap for social media use   88.382561
# 41             Australia  2019  Gender gap for social media use  100.000000
# 47               Austria  2019  Gender gap for social media use   93.794891
# 53            Azerbaijan  2019  Gender gap for social media use   82.578400
# 59               Burundi  2019  Gender gap for social media use   20.199215
# 65               Belgium  2019  Gender gap for social media use  100.000000
# 71                 Benin  2019  Gender gap for social media use   18.559984
# 77          Burkina Faso  2019  Gender gap for social media use    9.472891
# 83            Bangladesh  2019  Gender gap for social media use    7.507241
# 89              Bulgaria  2019  Gender gap for social media use  100.000000
#
#     new_rank_score  higher_is_better
# 5         1.000000              True
# 11        3.477625              True
# 17        3.070306              True
# 23        1.694525              True
# 29        6.000000              True
# 35        5.419128              True
# 41        6.000000              True
# 47        5.689745              True
# 53        5.128920              True
# 59        2.009961              True
# 65        6.000000              True
# 71        1.927999              True
# 77        1.473645              True
# 83        1.375362              True
# 89        6.000000              True

# %%
### 30. % of population using digital financial services

# %%
indicators[29]

# load data
indicator = indicators[29]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population using digital financial services
# population_digital_financial_services

# %%
df.head(15)

# May have to convert the data to csv file as the original file is missing many important columns
# Out:
#              Unnamed: 0 Account (% age 15+) Account, male (% age 15+)  \
# 0            Low income                  9%                       15%
# 1            Low income                 10%                       16%
# 2            Low income                 15%                       23%
# 3   Lower middle income                 39%                       39%
# 4   Lower middle income                 29%                       36%
# 5   Upper middle income                 28%                       34%
# 6   Upper middle income                 38%                       43%
# 7   Upper middle income                 40%                       42%
# 8                   NaN                 22%                       30%
# 9                   NaN                 30%                       38%
# 10                  NaN                 37%                       48%
# 11          High income                 60%                       69%
# 12          High income                 84%                       90%
# 13          High income                 88%                       93%
# 14  Upper middle income                 33%                       35%
#
#    Account, in labor force (% age 15+)   \
# 0                                   15%
# 1                                   15%
# 2                                   25%
# 3                                   46%
# 4                                   36%
# 5                                   36%
# 6                                   44%
# 7                                   53%
# 8                                   33%
# 9                                   42%
# 10                                  51%
# 11                                  80%
# 12                                  91%
# 13                                  93%
# 14                                  37%
#
#    Account, out of labor force (% age 15+)  Account, female (% age 15+)  \
# 0                                        2%                          3%
# 1                                        4%                          4%
# 2                                        4%                          7%
# 3                                       31%                         39%
# 4                                       12%                         22%
# 5                                       15%                         23%
# 6                                       29%                         34%
# 7                                       27%                         38%
# 8                                       11%                         14%
# 9                                       18%                         22%
# 10                                      24%                         26%
# 11                                      24%                         47%
# 12                                      49%                         68%
# 13                                      57%                         76%
# 14                                      28%                         32%
#
#    Account, young adults (% ages 15-24) Account, older adults (% ages 25+)  \
# 0                                    6%                                11%
# 1                                    7%                                12%
# 2                                   10%                                18%
# 3                                   30%                                45%
# 4                                   15%                                38%
# 5                                   26%                                29%
# 6                                   30%                                40%
# 7                                   32%                                43%
# 8                                   15%                                26%
# 9                                   21%                                34%
# 10                                  21%                                43%
# 11                                  26%                                73%
# 12                                  67%                                88%
# 13                                  60%                                91%
# 14                                  16%                                38%
#
#    Account, primary education or less (% ages 15+)   \
# 0                                                5%
# 1                                                5%
# 2                                                9%
# 3                                               35%
# 4                                               14%
# 5                                               15%
# 6                                               24%
# 7                                               27%
# 8                                               14%
# 9                                               21%
# 10                                              26%
# 11                                              43%
# 12                                              64%
# 13                                              71%
# 14                                              28%
#
#    Account, secondary education or more (% ages 15+)   ...  \
# 0                                                 30%  ...
# 1                                                 23%  ...
# 2                                                 31%  ...
# 3                                                 44%  ...
# 4                                                 70%  ...
# 5                                                 36%  ...
# 6                                                 56%  ...
# 7                                                 56%  ...
# 8                                                 31%  ...
# 9                                                 39%  ...
# 10                                                49%  ...
# 11                                                61%  ...
# 12                                                85%  ...
# 13                                                89%  ...
# 14                                                37%  ...
#
#    Mobile money account, female (% age 15+)   \
# 0                                        NaN
# 1                                         0%
# 2                                         1%
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                         2%
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       10%
# 13                                       18%
# 14                                       NaN
#
#    Mobile money account, young adults  (% age 15-24)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  6%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                10%
# 13                                                10%
# 14                                                NaN
#
#    Mobile money account, older adults (% age 25+)   \
# 0                                              NaN
# 1                                               0%
# 2                                               1%
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                               1%
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             12%
# 13                                             22%
# 14                                             NaN
#
#    Mobile money account, primary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  1%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                 9%
# 14                                                NaN
#
#    Mobile money account, secondary education or less (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  2%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                12%
# 13                                                22%
# 14                                                NaN
#
#    Mobile money account, income, poorest 40% (% age 15+)   \
# 0                                                 NaN
# 1                                                  0%
# 2                                                  0%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  0%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 7%
# 13                                                16%
# 14                                                NaN
#
#    Mobile money account, income, richest 60%  (% age 15+)   \
# 0                                                 NaN
# 1                                                  1%
# 2                                                  1%
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  4%
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                15%
# 13                                                25%
# 14                                                NaN
#
#    Mobile money account, rural  (% age 15+)          data_country  \
# 0                                        NaN           Low income
# 1                                         0%           Low income
# 2                                         1%           Low income
# 3                                        NaN  Lower middle income
# 4                                        NaN  Lower middle income
# 5                                        NaN  Upper middle income
# 6                                        NaN  Upper middle income
# 7                                         2%  Upper middle income
# 8                                        NaN                  NaN
# 9                                        NaN                  NaN
# 10                                       NaN                  NaN
# 11                                       NaN          High income
# 12                                       16%          High income
# 13                                       14%          High income
# 14                                       NaN  Upper middle income
#
#               data_year
# 0            Low income
# 1            Low income
# 2            Low income
# 3   Lower middle income
# 4   Lower middle income
# 5   Upper middle income
# 6   Upper middle income
# 7   Upper middle income
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11          High income
# 12          High income
# 13          High income
# 14  Upper middle income
#
# [15 rows x 779 columns]

# %%
### 31. Mobile Broadband Pricing (pre-paid)

# %%
indicators[30]

# load data
indicator = indicators[30]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# File not found despite its presence in the personal repo and the data manifest
# Out:
# Mobile Broadband Pricing (pre-paid)
# ITU_database

# %%
df.head(15)
# Out:
#                    Country  Region  ISO  \
# 0                   Angola  Africa  AGO
# 1                    Benin  Africa  BEN
# 2                 Botswana  Africa  BWA
# 3             Burkina Faso  Africa  BFA
# 4                  Burundi  Africa  BDI
# 5               Cabo Verde  Africa  CPV
# 6                 Cameroon  Africa  CMR
# 7     Central African Rep.  Africa  CAF
# 8                     Chad  Africa  TCD
# 9      Congo (Rep. of the)  Africa  COG
# 10           Côte d'Ivoire  Africa  CIV
# 11  Dem. Rep. of the Congo  Africa  COD
# 12       Equatorial Guinea  Africa  GNQ
# 13                 Eritrea  Africa  ERI
# 14                Eswatini  Africa  SWZ
#
#                                        Indicator name    Year  Value  \
# 0   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 10  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 11  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 12  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 13  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 14  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
df = df[df.Year==2019]
df = df[df['Indicator name'] == 'Mobile broadband basket as a % of GNI p.c.']
df
# Out:
#                                 Country        Region  ISO  \
# 17974                            Angola        Africa  AGO
# 17975                             Benin        Africa  BEN
# 17976                          Botswana        Africa  BWA
# 17977                      Burkina Faso        Africa  BFA
# 17978                           Burundi        Africa  BDI
# ...                                 ...           ...  ...
# 18161  Saint Vincent and the Grenadines  The Americas  VCT
# 18162                          Suriname  The Americas  SUR
# 18163               Trinidad and Tobago  The Americas  TTO
# 18164                     United States  The Americas  USA
# 18165                           Uruguay  The Americas  URY
#
#                                    Indicator name    Year  Value  \
# 17974  Mobile broadband basket as a % of GNI p.c.  2019.0   5.63
# 17975  Mobile broadband basket as a % of GNI p.c.  2019.0   6.21
# 17976  Mobile broadband basket as a % of GNI p.c.  2019.0   2.87
# 17977  Mobile broadband basket as a % of GNI p.c.  2019.0  19.63
# 17978  Mobile broadband basket as a % of GNI p.c.  2019.0  20.43
# ...                                           ...     ...    ...
# 18161  Mobile broadband basket as a % of GNI p.c.  2019.0   4.59
# 18162  Mobile broadband basket as a % of GNI p.c.  2019.0   1.93
# 18163  Mobile broadband basket as a % of GNI p.c.  2019.0   3.07
# 18164  Mobile broadband basket as a % of GNI p.c.  2019.0   0.42
# 18165  Mobile broadband basket as a % of GNI p.c.  2019.0   1.61
#
#        data_country  data_year
# 17974           NaN        NaN
# 17975           NaN        NaN
# 17976           NaN        NaN
# 17977           NaN        NaN
# 17978           NaN        NaN
# ...             ...        ...
# 18161           NaN        NaN
# 18162           NaN        NaN
# 18163           NaN        NaN
# 18164           NaN        NaN
# 18165           NaN        NaN
#
# [192 rows x 8 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country Name    Year                            Indicator  \
# 17974                  Angola  2019.0  Mobile Broadband Pricing (pre-paid)
# 17975                   Benin  2019.0  Mobile Broadband Pricing (pre-paid)
# 17976                Botswana  2019.0  Mobile Broadband Pricing (pre-paid)
# 17977            Burkina Faso  2019.0  Mobile Broadband Pricing (pre-paid)
# 17978                 Burundi  2019.0  Mobile Broadband Pricing (pre-paid)
# 17979              Cabo Verde  2019.0  Mobile Broadband Pricing (pre-paid)
# 17980                Cameroon  2019.0  Mobile Broadband Pricing (pre-paid)
# 17981    Central African Rep.  2019.0  Mobile Broadband Pricing (pre-paid)
# 17982                    Chad  2019.0  Mobile Broadband Pricing (pre-paid)
# 17983     Congo (Rep. of the)  2019.0  Mobile Broadband Pricing (pre-paid)
# 17984           Côte d'Ivoire  2019.0  Mobile Broadband Pricing (pre-paid)
# 17985  Dem. Rep. of the Congo  2019.0  Mobile Broadband Pricing (pre-paid)
# 17986       Equatorial Guinea  2019.0  Mobile Broadband Pricing (pre-paid)
# 17987                 Eritrea  2019.0  Mobile Broadband Pricing (pre-paid)
# 17988                Eswatini  2019.0  Mobile Broadband Pricing (pre-paid)
#
#        data_col  new_rank_score  higher_is_better
# 17974      5.63        5.553571              True
# 17975      6.21        5.506062              True
# 17976      2.87        5.779653              True
# 17977     19.63        4.406782              True
# 17978     20.43        4.341252              True
# 17979      3.16        5.755898              True
# 17980      4.67        5.632208              True
# 17981     26.99        3.803899              True
# 17982     32.23        3.374672              True
# 17983     13.17        4.935944              True
# 17984      5.36        5.575688              True
# 17985     61.22        1.000000              True
# 17986       NaN             NaN              True
# 17987       NaN             NaN              True
# 17988      5.41        5.571592              True

# %%
### 32. Tax as % of total cost of mobile ownership

# %%
indicators[31]

# load data
indicator = indicators[31]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Tax as % of total cost of mobile ownership
# tax_percent_mobile_ownership

# %%
df.head(15)
# Out:
#    ISO Code      Country                 Region  Year       Cluster  Index  \
# 0       AFG  Afghanistan             South Asia  2014    Discoverer  22.12
# 1       AFG  Afghanistan             South Asia  2015    Discoverer  22.99
# 2       AFG  Afghanistan             South Asia  2016    Discoverer  23.71
# 3       AFG  Afghanistan             South Asia  2017    Discoverer  25.82
# 4       AFG  Afghanistan             South Asia  2018    Discoverer  28.39
# 5       AFG  Afghanistan             South Asia  2019    Discoverer  28.94
# 6       AGO       Angola     Sub-Saharan Africa  2014    Discoverer  32.78
# 7       AGO       Angola     Sub-Saharan Africa  2015      Emerging  37.18
# 8       AGO       Angola     Sub-Saharan Africa  2016      Emerging  39.85
# 9       AGO       Angola     Sub-Saharan Africa  2017      Emerging  42.89
# 10      AGO       Angola     Sub-Saharan Africa  2018      Emerging  42.46
# 11      AGO       Angola     Sub-Saharan Africa  2019      Emerging  43.53
# 12      ALB      Albania  Europe & Central Asia  2014  Transitioner  53.74
# 13      ALB      Albania  Europe & Central Asia  2015  Transitioner  57.42
# 14      ALB      Albania  Europe & Central Asia  2016  Transitioner  60.24
#
#     Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0            21.74          31.79               24.40                 14.19
# 1            22.82          30.81               25.28                 15.71
# 2            26.92          26.75               26.07                 16.83
# 3            33.54          27.22               28.56                 17.04
# 4            30.91          42.64               29.24                 16.87
# 5            32.34          41.53               29.72                 17.58
# 6            25.99          35.99               44.33                 27.85
# 7            33.09          42.01               45.41                 30.27
# 8            37.80          44.74               46.47                 32.11
# 9            48.60          47.94               46.32                 31.36
# 10           47.61          46.28               47.61                 30.98
# 11           48.18          47.65               48.13                 32.50
# 12           41.32          55.95               74.94                 48.13
# 13           52.09          54.60               75.56                 50.57
# 14           57.44          54.45               75.97                 55.41
#
#     ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0   ...                            0.00            39.55               18.11
# 1   ...                            0.00            39.57               24.27
# 2   ...                            0.00            39.58               30.43
# 3   ...                            0.00            39.47               30.50
# 4   ...                            0.00            39.39               30.56
# 5   ...                            0.00            39.41               41.18
# 6   ...                           51.65             0.00               29.92
# 7   ...                           57.00             0.31               32.35
# 8   ...                           63.73             0.00               34.78
# 9   ...                           53.97             0.00               37.88
# 10  ...                           63.34             0.00               40.97
# 11  ...                           57.71             0.77               48.82
# 12  ...                           68.42            53.41               44.88
# 13  ...                           68.42            57.45               52.15
# 14  ...                           67.39            58.70               59.42
#
#     Mobile Social Media Penetration  Apps developed per person  \
# 0                              3.28                      20.98
# 1                              4.36                      22.93
# 2                              6.73                      30.31
# 3                              7.78                      31.62
# 4                              8.54                      36.54
# 5                              9.39                      39.36
# 6                              3.99                      22.74
# 7                              5.26                      22.12
# 8                              6.27                      27.46
# 9                              4.26                      31.94
# 10                             5.39                      35.36
# 11                             6.82                      41.20
# 12                            39.75                      66.65
# 13                            40.61                      65.99
# 14                            48.07                      69.64
#
#     Number of apps in national language  Accessibility of top ranked apps  \
# 0                                  2.44                              4.37
# 1                                  2.79                              8.03
# 2                                  2.85                              5.90
# 3                                  2.91                              6.15
# 4                                  2.96                              8.66
# 5                                  3.00                              5.72
# 6                                 53.33                             49.09
# 7                                 55.08                             58.33
# 8                                 56.52                             61.73
# 9                                 57.06                             55.09
# 10                                57.13                             47.25
# 11                                57.98                             46.19
# 12                                60.33                             56.55
# 13                                63.29                             57.56
# 14                                65.57                             65.80
#
#     Cybersecurity Index  data_country  data_year
# 0                 26.50           NaN        NaN
# 1                 25.83           NaN        NaN
# 2                 25.17           NaN        NaN
# 3                 24.50           NaN        NaN
# 4                 17.70           NaN        NaN
# 5                 17.70           NaN        NaN
# 6                  8.80           NaN        NaN
# 7                  8.47           NaN        NaN
# 8                  8.13           NaN        NaN
# 9                  7.80           NaN        NaN
# 10                 9.70           NaN        NaN
# 11                 9.70           NaN        NaN
# 12                20.60           NaN        NaN
# 13                24.20           NaN        NaN
# 14                27.80           NaN        NaN
#
# [15 rows x 66 columns]

# %%
df = df[df.Year==2019]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = False
df['Indicator'] = indicator
df['data_col'] = df['Tax as a % of TCMO'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year                                   Indicator  \
# 5            Afghanistan  2019  Tax as % of total cost of mobile ownership
# 11                Angola  2019  Tax as % of total cost of mobile ownership
# 17               Albania  2019  Tax as % of total cost of mobile ownership
# 23  United Arab Emirates  2019  Tax as % of total cost of mobile ownership
# 29             Argentina  2019  Tax as % of total cost of mobile ownership
# 35               Armenia  2019  Tax as % of total cost of mobile ownership
# 41             Australia  2019  Tax as % of total cost of mobile ownership
# 47               Austria  2019  Tax as % of total cost of mobile ownership
# 53            Azerbaijan  2019  Tax as % of total cost of mobile ownership
# 59               Burundi  2019  Tax as % of total cost of mobile ownership
# 65               Belgium  2019  Tax as % of total cost of mobile ownership
# 71                 Benin  2019  Tax as % of total cost of mobile ownership
# 77          Burkina Faso  2019  Tax as % of total cost of mobile ownership
# 83            Bangladesh  2019  Tax as % of total cost of mobile ownership
# 89              Bulgaria  2019  Tax as % of total cost of mobile ownership
#
#     data_col  new_rank_score  higher_is_better
# 5      79.16          2.0420             False
# 11     65.83          2.7085             False
# 17     50.00          3.5000             False
# 23     82.31          1.8845             False
# 29      5.23          5.7385             False
# 35     57.58          3.1210             False
# 41     75.00          2.2500             False
# 47     50.00          3.5000             False
# 53     36.41          4.1795             False
# 59     44.57          3.7715             False
# 65     47.50          3.6250             False
# 71     53.75          3.3125             False
# 77     61.02          2.9490             False
# 83      0.00          6.0000             False
# 89     50.00          3.5000             False

# %%
### 33. % of population with a SIM card

# %%
indicators[32]

# load data
indicator = indicators[32]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population with a SIM card
# ITU_database

# %%
df = df[df.Year==2019]
df = df[df['Indicator name'] == 'Mobile-cellular subscriptions per 100 inhabitants']
df
# Out:
#                    Country        Region  ISO  \
# 32279               Angola        Africa  AGO
# 32280                Benin        Africa  BEN
# 32281             Botswana        Africa  BWA
# 32282         Burkina Faso        Africa  BFA
# 32283              Burundi        Africa  BDI
# ...                    ...           ...  ...
# 32470             Suriname  The Americas  SUR
# 32471  Trinidad and Tobago  The Americas  TTO
# 32472        United States  The Americas  USA
# 32473              Uruguay  The Americas  URY
# 32474            Venezuela  The Americas  VEN
#
#                                           Indicator name    Year       Value  \
# 32279  Mobile-cellular subscriptions per 100 inhabitants  2019.0   46.598638
# 32280  Mobile-cellular subscriptions per 100 inhabitants  2019.0   87.702013
# 32281  Mobile-cellular subscriptions per 100 inhabitants  2019.0  162.641181
# 32282  Mobile-cellular subscriptions per 100 inhabitants  2019.0  100.212239
# 32283  Mobile-cellular subscriptions per 100 inhabitants  2019.0   56.649700
# ...                                                  ...     ...         ...
# 32470  Mobile-cellular subscriptions per 100 inhabitants  2019.0  139.986790
# 32471  Mobile-cellular subscriptions per 100 inhabitants  2019.0  155.108737
# 32472  Mobile-cellular subscriptions per 100 inhabitants  2019.0  134.458879
# 32473  Mobile-cellular subscriptions per 100 inhabitants  2019.0  138.074936
# 32474  Mobile-cellular subscriptions per 100 inhabitants  2019.0   64.792912
#
#        data_country  data_year
# 32279           NaN        NaN
# 32280           NaN        NaN
# 32281           NaN        NaN
# 32282           NaN        NaN
# 32283           NaN        NaN
# ...             ...        ...
# 32470           NaN        NaN
# 32471           NaN        NaN
# 32472           NaN        NaN
# 32473           NaN        NaN
# 32474           NaN        NaN
#
# [196 rows x 8 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country Name    Year                        Indicator  \
# 32279                  Angola  2019.0  % of population with a SIM card
# 32280                   Benin  2019.0  % of population with a SIM card
# 32281                Botswana  2019.0  % of population with a SIM card
# 32282            Burkina Faso  2019.0  % of population with a SIM card
# 32283                 Burundi  2019.0  % of population with a SIM card
# 32284              Cabo Verde  2019.0  % of population with a SIM card
# 32285                Cameroon  2019.0  % of population with a SIM card
# 32286    Central African Rep.  2019.0  % of population with a SIM card
# 32287                    Chad  2019.0  % of population with a SIM card
# 32288     Congo (Rep. of the)  2019.0  % of population with a SIM card
# 32289           Côte d'Ivoire  2019.0  % of population with a SIM card
# 32290  Dem. Rep. of the Congo  2019.0  % of population with a SIM card
# 32291       Equatorial Guinea  2019.0  % of population with a SIM card
# 32292                 Eritrea  2019.0  % of population with a SIM card
# 32293                Eswatini  2019.0  % of population with a SIM card
#
#          data_col  new_rank_score  higher_is_better
# 32279   46.598638        1.493811              True
# 32280   87.702013        2.259390              True
# 32281  162.641181        3.655183              True
# 32282  100.212239        2.492401              True
# 32283   56.649700        1.681019              True
# 32284  108.318438        2.643385              True
# 32285   82.703748        2.166294              True
# 32286   33.619216        1.252060              True
# 32287   48.064831        1.521120              True
# 32288         NaN             NaN              True
# 32289  145.340692        3.332950              True
# 32290   42.773321        1.422562              True
# 32291         NaN             NaN              True
# 32292         NaN             NaN              True
# 32293         NaN             NaN              True

# %%
### 34. % of population with a smartphone

# %%
indicators[33]

# load data
indicator = indicators[33]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population with a smartphone
# population_with_smartphones

# %%
df.head(15)
# Out:
#     Unnamed: 0         Country Total Population  Smartphone Penetration Rate  \
# 0            1           China            1.44B                         0.64
# 1            2           India            1.38B                         0.32
# 2            3   United States             331M                         0.82
# 3            4       Indonesia          273.52M                         0.59
# 4            5          Brazil          212.56M                         0.51
# 5            6          Russia          145.93M                         0.69
# 6            7           Japan          126.48M                         0.63
# 7            8          Mexico          128.93M                         0.54
# 8            9         Germany           83.78M                         0.78
# 9           10         Vietnam           97.34M                         0.63
# 10          11  United Kingdom           67.89M                         0.79
# 11          12      Bangladesh          164.69M                         0.32
# 12          13            Iran           83.99M                         0.63
# 13          14          Turkey           84.34M                         0.62
# 14          15          France           65.27M                         0.78
#
#    Smartphone Users
# 0           918.45M
# 1           439.42M
# 2              270M
# 3           160.23M
# 4           109.34M
# 5            99.93M
# 6               80M
# 7            70.14M
# 8            65.24M
# 9            61.37M
# 10           53.58M
# 11            53.3M
# 12           52.81M
# 13           52.06M
# 14           50.66M

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Smartphone Penetration Rate'] 
df['Country Name'] = df['Country']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#       Country Name  Year                          Indicator  data_col  \
# 0            China  2020  % of population with a smartphone      0.64
# 1            India  2020  % of population with a smartphone      0.32
# 2    United States  2020  % of population with a smartphone      0.82
# 3        Indonesia  2020  % of population with a smartphone      0.59
# 4           Brazil  2020  % of population with a smartphone      0.51
# 5           Russia  2020  % of population with a smartphone      0.69
# 6            Japan  2020  % of population with a smartphone      0.63
# 7           Mexico  2020  % of population with a smartphone      0.54
# 8          Germany  2020  % of population with a smartphone      0.78
# 9          Vietnam  2020  % of population with a smartphone      0.63
# 10  United Kingdom  2020  % of population with a smartphone      0.79
# 11      Bangladesh  2020  % of population with a smartphone      0.32
# 12            Iran  2020  % of population with a smartphone      0.63
# 13          Turkey  2020  % of population with a smartphone      0.62
# 14          France  2020  % of population with a smartphone      0.78
#
#     new_rank_score  higher_is_better
# 0         4.593750              True
# 1         2.093750              True
# 2         6.000000              True
# 3         4.203125              True
# 4         3.578125              True
# 5         4.984375              True
# 6         4.515625              True
# 7         3.812500              True
# 8         5.687500              True
# 9         4.515625              True
# 10        5.765625              True
# 11        2.093750              True
# 12        4.515625              True
# 13        4.437500              True
# 14        5.687500              True

# %%
### 35. Gender gap in internet usage

# %%
indicators[34]

# load data
indicator = indicators[34]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Gender gap in internet usage
# ITU_database

# %%
df.head(15)
# Out:
#                    Country  Region  ISO  \
# 0                   Angola  Africa  AGO
# 1                    Benin  Africa  BEN
# 2                 Botswana  Africa  BWA
# 3             Burkina Faso  Africa  BFA
# 4                  Burundi  Africa  BDI
# 5               Cabo Verde  Africa  CPV
# 6                 Cameroon  Africa  CMR
# 7     Central African Rep.  Africa  CAF
# 8                     Chad  Africa  TCD
# 9      Congo (Rep. of the)  Africa  COG
# 10           Côte d'Ivoire  Africa  CIV
# 11  Dem. Rep. of the Congo  Africa  COD
# 12       Equatorial Guinea  Africa  GNQ
# 13                 Eritrea  Africa  ERI
# 14                Eswatini  Africa  SWZ
#
#                                        Indicator name    Year  Value  \
# 0   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 10  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 11  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 12  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 13  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 14  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
df = df[(df['Indicator name'] == 'Female Internet users as a % of total female population')]
df = df[(df.Year == 2019)]
df
# Out:
#              Country        Region  ISO  \
# 40307     Cabo Verde        Africa  CPV
# 40308  Côte d'Ivoire        Africa  CIV
# 40309          Kenya        Africa  KEN
# 40310        Lesotho        Africa  LSO
# 40311      Mauritius        Africa  MUS
# ...              ...           ...  ...
# 40388         Mexico  The Americas  MEX
# 40389         Panama  The Americas  PAN
# 40390       Paraguay  The Americas  PRY
# 40391           Peru  The Americas  PER
# 40392        Uruguay  The Americas  URY
#
#                                           Indicator name    Year      Value  \
# 40307  Female Internet users as a % of total female p...  2019.0  60.965017
# 40308  Female Internet users as a % of total female p...  2019.0  32.924445
# 40309  Female Internet users as a % of total female p...  2019.0  20.125122
# 40310  Female Internet users as a % of total female p...  2019.0  44.922768
# 40311  Female Internet users as a % of total female p...  2019.0  60.130645
# ...                                                  ...     ...        ...
# 40388  Female Internet users as a % of total female p...  2019.0  68.574653
# 40389  Female Internet users as a % of total female p...  2019.0  63.811494
# 40390  Female Internet users as a % of total female p...  2019.0  69.017230
# 40391  Female Internet users as a % of total female p...  2019.0  56.992144
# 40392  Female Internet users as a % of total female p...  2019.0  83.835706
#
#        data_country  data_year
# 40307           NaN        NaN
# 40308           NaN        NaN
# 40309           NaN        NaN
# 40310           NaN        NaN
# 40311           NaN        NaN
# ...             ...        ...
# 40388           NaN        NaN
# 40389           NaN        NaN
# 40390           NaN        NaN
# 40391           NaN        NaN
# 40392           NaN        NaN
#
# [86 rows x 8 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
### 36. Gender gap in mobile usage

# %%
indicators[35]

# load data
indicator = indicators[35]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Gender gap in mobile ownership'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 37. Mobile Device Penetration

# %%
indicators[36]

# load data
indicator = indicators[36]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Mobile Ownership'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 38. Mobile Device Penetration (female)

# %%
indicators[37]

# load data
indicator = indicators[37]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Gender gap in mobile ownership'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
