# %%
import pandas as pd
import numpy as np

# %%
### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False           Countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              20         25
# Foundations            9         12
# Government            10         15
# Infrastructure        45         48
# People                39         47
# Regulation             6          7
# Strategy               1          1

# %%
### People

# %%
bnames = names[(names.check=='People')&(~names.Filename.isna())]#&(names.Index==False)]
bnames
# Out:
#                                              Indicator   check  \
# 99                           Human Capital Index (HCI)  People
# 100               % of population using internet (all)  People
# 101            % of population using internet (female)  People
# 102              % of population using internet (male)  People
# 103                      SDG 4.4 Digital literacy data  People
# 104                UNDP Human Development Index (HDI)   People
# 105                Facebook Social Connectedness Index  People
# 106  Share of individuals using the Internet to int...  People
# 107  Level of satisfaction for online public servic...  People
# 108  Number of mobile apps available in national la...  People
# 109  Device Addiction (time of use on internet / on...  People
# 110                           Gross National Wellbeing  People
# 112         % of internet users who own cryptocurrency  People
# 115  Percentage of individuals not buying online du...  People
# 116  Percentage of individuals not buying online du...  People
# 117        E-waste generated, kilograms per inhabitant  People
# 118                        Automation-led unemployment  People
# 122                                      Cyberbullying  People
# 126  Global Wellbeing Initiative (World Happiness I...  People
# 127                            Financial Inclusiveness  People
# 128  E-commerce activity (% of individuals buying o...  People
# 129  E-commerce activity (Types of goods and servic...  People
# 130                               Top Visited websites  People
# 131                               Top YouTube Searches  People
# 132                                Top Google searches  People
# 133                                     Internet Usage  People
# 134  Households with a computer and with Internet a...  People
# 135                     % of population using Facebook  People
# 136                    Gender gap for social media use  People
# 137   % of population using digital financial services  People
# 138                Mobile Broadband Pricing (pre-paid)  People
# 139         Tax as % of total cost of mobile ownership  People
# 140                    % of population with a SIM card  People
# 141                  % of population with a smartphone  People
# 142                       Gender gap in internet usage  People
# 143                         Gender gap in mobile usage  People
# 144                          Mobile Device Penetration  People
# 145                 Mobile Device Penetration (female)  People
# 146                              Crypto Adoption Index  People
#
#                                            Data Source  Index  \
# 99                                                DESA   True
# 100                                                ITU  False
# 101                                                ITU  False
# 102                                                ITU  False
# 103                                             UNESCO  False
# 104                                               UNDP   True
# 105                                           Facebook   True
# 106                                               OECD  False
# 107                 Boston Consulting Group/SalesForce  False
# 108                     GSMA Mobile Connectivity Index  False
# 109  Statista/DataReportal; Hootsuite; We Are Social\n  False
# 110                                Portulans Institute  TRUE
# 112                                           Statista  False
# 115                                               OECD  False
# 116                                               OECD  False
# 117                                         UNU UNITAR   True
# 118                          McKinsey Global Institute  False
# 122                                              IPSOS  False
# 126                             World Happiness Report  TRUE
# 127                                         World Bank  TRUE
# 128                                Portulans Institute  False
# 129                   Statista/Salesforce Research\n\n  False
# 130                                      Data Reportal  False
# 131                                      Data Reportal  False
# 132                                      Data Reportal  False
# 133                                                ITU  False
# 134                                                ITU  False
# 135                            World Population Review  False
# 136                     GSMA Mobile Connectivity Index  False
# 137                                         World Bank  False
# 138                   Alliance for Affordable Internet  False
# 139                     GSMA Mobile Connectivity Index  False
# 140                                                ITU  False
# 141                                    Statista/Newzoo  False
# 142                                                ITU  False
# 143                     GSMA Mobile Connectivity Index  False
# 144                     GSMA Mobile Connectivity Index  False
# 145                     GSMA Mobile Connectivity Index  False
# 146                                      Chainanalysis  TRUE
#
#                                              Filename
# 99                                 e_government_index
# 100                                      ITU_database
# 101                                      ITU_database
# 102                                      ITU_database
# 103                         SDG_digital_literacy_data
# 104                             undp_human_developmnt
# 105                           fb_social_connectedness
# 106           population_interacting_public_officials
# 107                        digital_public_service_use
# 108                         apps_in_national_language
# 109                                 time_spent_online
# 110                                   happiness_score
# 112                           cryptocurrency_adoption
# 115         not_buying_online_concern_about_returning
# 116          not_buying_online_concern_about_security
# 117                             ewaste_per_inhabitant
# 118                       automation_led_unemployment
# 122                                cyberbullying_rate
# 126                      global_wellbeing_initiative
# 127                          financial_inclusiveness
# 128               individuals_buying_online_frequency
# 129                               e-commerce_activity
# 130                                         top_sites
# 131                                  youtube_searches
# 132                                     google_trends
# 133                                      ITU_database
# 134                                      ITU_database
# 135                                          FB_users
# 136                                       gender_gaps
# 137             population_digital_financial_services
# 138                          mobile_broadband_pricing
# 139                      tax_percent_mobile_ownership
# 140                                      ITU_database
# 141                       population_with_smartphones
# 142                                      ITU_database
# 143                                       gender_gaps
# 144                     countries_mobile_connectivity
# 145                                       gender_gaps
# 146  Chainalysis_2020_Geography_Cryptocurrency_Report

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['e_government_index', 'ITU_database', 'SDG_digital_literacy_data',
#        'undp_human_developmnt', 'fb_social_connectedness',
#        'population_interacting_public_officials',
#        'digital_public_service_use', 'apps_in_national_language',
#        'time_spent_online', 'happiness_score', 'cryptocurrency_adoption',
#        'not_buying_online_concern_about_returning',
#        'not_buying_online_concern_about_security',
#        'ewaste_per_inhabitant', 'automation_led_unemployment',
#        'cyberbullying_rate', 'global_wellbeing_initiative ',
#        'financial_inclusiveness ', 'individuals_buying_online_frequency',
#        'e-commerce_activity', 'top_sites', 'youtube_searches',
#        'google_trends', 'FB_users', 'gender_gaps',
#        'population_digital_financial_services',
#        'mobile_broadband_pricing', 'tax_percent_mobile_ownership',
#        'population_with_smartphones', 'countries_mobile_connectivity',
#        'Chainalysis_2020_Geography_Cryptocurrency_Report'], dtype=object)

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %%
### 1. Human Capital Index (HCI)

# %%
indicators[0]

# load data
indicator = indicators[0]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Human Capital Index (HCI)
# e_government_index

# %%
df.head(10)
# Out:
#    Survey Year Country Name  E-Government Rank  E-Government Index  \
# 0         2020        Iraq                 143              0.4360
# 1         2020     Ireland                  27              0.8433
# 2         2020      Israel                  30              0.8361
# 3         2020       Italy                  37              0.8231
# 4         2020     Jamaica                 114              0.5392
# 5         2020       Japan                  14              0.8989
# 6         2020      Jordan                 117              0.5309
# 7         2020  Kazakhstan                  29              0.8375
# 8         2020       Kenya                 116              0.5326
# 9         2020    Kiribati                 145              0.4320
#
#    E-Participation Index  Online Service Index  Human Capital Index  \
# 0                 0.3095                0.3353               0.4358
# 1                 0.8571                0.7706               0.9494
# 2                 0.7143                0.7471               0.8924
# 3                 0.8214                0.8294               0.8466
# 4                 0.3690                0.3882               0.7142
# 5                 0.9881                0.9059               0.8684
# 6                 0.3333                0.3588               0.6800
# 7                 0.8810                0.9235               0.8866
# 8                 0.5952                0.6765               0.5812
# 9                 0.5595                0.4941               0.6778
#
#    Telecommunication Infrastructure Index
# 0                                  0.5370
# 1                                  0.8100
# 2                                  0.8689
# 3                                  0.7932
# 4                                  0.5151
# 5                                  0.9223
# 6                                  0.5540
# 7                                  0.7024
# 8                                  0.3402
# 9                                  0.1241

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Human Capital Index'] 
df['Year'] = df['Survey Year']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                          Country Name  Year                  Indicator  \
# 0                               Iraq   2020  Human Capital Index (HCI)
# 1                            Ireland   2020  Human Capital Index (HCI)
# 2                             Israel   2020  Human Capital Index (HCI)
# 3                              Italy   2020  Human Capital Index (HCI)
# 4                            Jamaica   2020  Human Capital Index (HCI)
# 5                              Japan   2020  Human Capital Index (HCI)
# 6                             Jordan   2020  Human Capital Index (HCI)
# 7                         Kazakhstan   2020  Human Capital Index (HCI)
# 8                              Kenya   2020  Human Capital Index (HCI)
# 9                           Kiribati   2020  Human Capital Index (HCI)
# 10                            Kuwait   2020  Human Capital Index (HCI)
# 11                        Kyrgyzstan   2020  Human Capital Index (HCI)
# 12  Lao People's Democratic Republic   2020  Human Capital Index (HCI)
# 13                            Latvia   2020  Human Capital Index (HCI)
# 14                           Lebanon   2020  Human Capital Index (HCI)
#
#     data_col  new_rank_score  higher_is_better
# 0     0.4358          3.1790              True
# 1     0.9494          5.7470              True
# 2     0.8924          5.4620              True
# 3     0.8466          5.2330              True
# 4     0.7142          4.5710              True
# 5     0.8684          5.3420              True
# 6     0.6800          4.4000              True
# 7     0.8866          5.4330              True
# 8     0.5812          3.9060              True
# 9     0.6778          4.3890              True
# 10    0.7470          4.7350              True
# 11    0.7873          4.9365              True
# 12    0.5539          3.7695              True
# 13    0.9172          5.5860              True
# 14    0.6567          4.2835              True

# %%
### 2. % of population using internet (all)

# %%
indicators[1]

# load data
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population using internet (all)
# ITU_database

# %%
df.head(150)
# Out:
#              Country  Region  ISO  \
# 0             Angola  Africa  AGO
# 1              Benin  Africa  BEN
# 2           Botswana  Africa  BWA
# 3       Burkina Faso  Africa  BFA
# 4            Burundi  Africa  BDI
# ..               ...     ...  ...
# 145  North Macedonia  Europe  MKD
# 146           Norway  Europe  NOR
# 147           Poland  Europe  POL
# 148         Portugal  Europe  PRT
# 149          Romania  Europe  ROU
#
#                                         Indicator name    Year  Value  \
# 0    Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1    Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2    Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3    Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4    Female mobile phone ownership as a % of total ...  2010.0    NaN
# ..                                                 ...     ...    ...
# 145  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 146  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 147  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 148  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 149  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#      data_country  data_year
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
# ..            ...        ...
# 145           NaN        NaN
# 146           NaN        NaN
# 147           NaN        NaN
# 148           NaN        NaN
# 149           NaN        NaN
#
# [150 rows x 8 columns]

# %%
df = df[(df.Year==2019)]
df = df[(df.iloc[:,3] =='Internet users: 25-74 years as a % of all 25-74 years')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Country Name'] = df['Country']


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(100)
# Out:
#          Country Name    Year                             Indicator  \
# 7750           Angola  2019.0  % of population using internet (all)
# 7751            Benin  2019.0  % of population using internet (all)
# 7752         Botswana  2019.0  % of population using internet (all)
# 7753     Burkina Faso  2019.0  % of population using internet (all)
# 7754          Burundi  2019.0  % of population using internet (all)
# ...               ...     ...                                   ...
# 7845            Samoa  2019.0  % of population using internet (all)
# 7846        Singapore  2019.0  % of population using internet (all)
# 7847  Solomon Islands  2019.0  % of population using internet (all)
# 7848        Sri Lanka  2019.0  % of population using internet (all)
# 7849         Thailand  2019.0  % of population using internet (all)
#
#        data_col  new_rank_score  higher_is_better
# 7750        NaN             NaN              True
# 7751        NaN             NaN              True
# 7752        NaN             NaN              True
# 7753        NaN             NaN              True
# 7754        NaN             NaN              True
# ...         ...             ...               ...
# 7845        NaN             NaN              True
# 7846        NaN             NaN              True
# 7847        NaN             NaN              True
# 7848        NaN             NaN              True
# 7849  63.749684        3.080025              True
#
# [100 rows x 6 columns]

# %%
### 3. % of population using internet (female)

# %%
indicators[2]

# load data
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population using internet (female)
# ITU_database

# %%
df.head(10)

# Must convert the string in the dataset to float
# Out:
#                 Country  Region  ISO  \
# 0                Angola  Africa  AGO
# 1                 Benin  Africa  BEN
# 2              Botswana  Africa  BWA
# 3          Burkina Faso  Africa  BFA
# 4               Burundi  Africa  BDI
# 5            Cabo Verde  Africa  CPV
# 6              Cameroon  Africa  CMR
# 7  Central African Rep.  Africa  CAF
# 8                  Chad  Africa  TCD
# 9   Congo (Rep. of the)  Africa  COG
#
#                                       Indicator name    Year  Value  \
# 0  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#    data_country  data_year
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# 5           NaN        NaN
# 6           NaN        NaN
# 7           NaN        NaN
# 8           NaN        NaN
# 9           NaN        NaN

# %%
df = df[(df.iloc[:,3] =='Female Internet users as a % of total female population')]
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value']
df['Country Name'] = df['Country']


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#                Country Name    Year                                Indicator  \
# 40307            Cabo Verde  2019.0  % of population using internet (female)
# 40308         Côte d'Ivoire  2019.0  % of population using internet (female)
# 40309                 Kenya  2019.0  % of population using internet (female)
# 40310               Lesotho  2019.0  % of population using internet (female)
# 40311             Mauritius  2019.0  % of population using internet (female)
# 40312               Bahrain  2019.0  % of population using internet (female)
# 40313                 Egypt  2019.0  % of population using internet (female)
# 40314                Kuwait  2019.0  % of population using internet (female)
# 40315               Morocco  2019.0  % of population using internet (female)
# 40316                  Oman  2019.0  % of population using internet (female)
# 40317             Palestine  2019.0  % of population using internet (female)
# 40318                 Qatar  2019.0  % of population using internet (female)
# 40319          Saudi Arabia  2019.0  % of population using internet (female)
# 40320               Tunisia  2019.0  % of population using internet (female)
# 40321  United Arab Emirates  2019.0  % of population using internet (female)
# 40322     Brunei Darussalam  2019.0  % of population using internet (female)
# 40323              Cambodia  2019.0  % of population using internet (female)
# 40324                 China  2019.0  % of population using internet (female)
# 40325      Hong Kong, China  2019.0  % of population using internet (female)
# 40326             Indonesia  2019.0  % of population using internet (female)
#
#         data_col  new_rank_score  higher_is_better
# 40307  60.965017        3.766390              True
# 40308  32.924445        2.151554              True
# 40309  20.125122        1.414451              True
# 40310  44.922768        2.842529              True
# 40311  60.130645        3.718339              True
# 40312  99.316403        5.975016              True
# 40313  52.986990        3.306941              True
# 40314  99.579959        5.990194              True
# 40315  70.167130        4.296332              True
# 40316  97.153466        5.850455              True
# 40317  68.934490        4.225345              True
# 40318  99.319498        5.975195              True
# 40319  94.566890        5.701496              True
# 40320  61.112559        3.774886              True
# 40321  99.501508        5.985676              True
# 40322  99.750226        6.000000              True
# 40323  77.783786        4.734970              True
# 40324  63.524052        3.913762              True
# 40325  90.472168        5.465684              True
# 40326  44.864022        2.839146              True

# %%
### 4. % of population using internet (male)

# %%
indicators[3]

# load data
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population using internet (male)
# ITU_database

# %%
df.head(10)
# Out:
#                 Country  Region  ISO  \
# 0                Angola  Africa  AGO
# 1                 Benin  Africa  BEN
# 2              Botswana  Africa  BWA
# 3          Burkina Faso  Africa  BFA
# 4               Burundi  Africa  BDI
# 5            Cabo Verde  Africa  CPV
# 6              Cameroon  Africa  CMR
# 7  Central African Rep.  Africa  CAF
# 8                  Chad  Africa  TCD
# 9   Congo (Rep. of the)  Africa  COG
#
#                                       Indicator name    Year  Value  \
# 0  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#    data_country  data_year
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# 5           NaN        NaN
# 6           NaN        NaN
# 7           NaN        NaN
# 8           NaN        NaN
# 9           NaN        NaN

# %%
df = df[(df.iloc[:,3] =='Male Internet users as a % of total male population')]
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value']
df['Country Name'] = df['Country']


min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)
# Out:
#                Country Name    Year                              Indicator  \
# 41078            Cabo Verde  2019.0  % of population using internet (male)
# 41079         Côte d'Ivoire  2019.0  % of population using internet (male)
# 41080                 Kenya  2019.0  % of population using internet (male)
# 41081               Lesotho  2019.0  % of population using internet (male)
# 41082             Mauritius  2019.0  % of population using internet (male)
# 41083               Bahrain  2019.0  % of population using internet (male)
# 41084                 Egypt  2019.0  % of population using internet (male)
# 41085                Kuwait  2019.0  % of population using internet (male)
# 41086               Morocco  2019.0  % of population using internet (male)
# 41087                  Oman  2019.0  % of population using internet (male)
# 41088             Palestine  2019.0  % of population using internet (male)
# 41089                 Qatar  2019.0  % of population using internet (male)
# 41090          Saudi Arabia  2019.0  % of population using internet (male)
# 41091               Tunisia  2019.0  % of population using internet (male)
# 41092  United Arab Emirates  2019.0  % of population using internet (male)
# 41093     Brunei Darussalam  2019.0  % of population using internet (male)
# 41094              Cambodia  2019.0  % of population using internet (male)
# 41095                 China  2019.0  % of population using internet (male)
# 41096      Hong Kong, China  2019.0  % of population using internet (male)
# 41097             Indonesia  2019.0  % of population using internet (male)
#
#         data_col  new_rank_score  higher_is_better
# 41078  62.921166        3.643039              True
# 41079  39.808871        2.173867              True
# 41080  25.071668        1.237071              True
# 41081  38.349985        2.081130              True
# 41082  63.393093        3.673038              True
# 41083  99.910314        5.994317              True
# 41084  61.541347        3.555329              True
# 41085  99.521506        5.969602              True
# 41086  78.636833        4.642032              True
# 41087  94.404849        5.644353              True
# 41088  72.262563        4.236841              True
# 41089  99.999712        6.000000              True
# 41090  96.531207        5.779519              True
# 41091  72.462033        4.249521              True
# 41092  99.030014        5.938359              True
# 41093  91.833183        5.480881              True
# 41094  78.788371        4.651665              True
# 41095  65.569645        3.811394              True
# 41096  93.150818        5.564638              True
# 41097  50.497113        2.853283              True

# %%
### 5. SDG 4.4 Digital literacy data

# %%
indicators[4]

# load data
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# The indicators are all jumbled, need to unclutter this
# Out:
# SDG 4.4 Digital literacy data
# SDG_digital_literacy_data

# %%
df.head(15)
# Out:
#                    SDG_IND                                          Indicator  \
# 0   ICTSKILLTRANSFERFILE_M  Proportion of youth and adults who have transf...
# 1   ICTSKILLTRANSFERFILE_M  Proportion of youth and adults who have transf...
# 2   ICTSKILLTRANSFERFILE_M  Proportion of youth and adults who have transf...
# 3   ICTSKILLTRANSFERFILE_M  Proportion of youth and adults who have transf...
# 4         ICTSKILLDUPLIC_M  Proportion of youth and adults who have used c...
# 5         ICTSKILLDUPLIC_M  Proportion of youth and adults who have used c...
# 6         ICTSKILLDUPLIC_M  Proportion of youth and adults who have used c...
# 7         ICTSKILLDUPLIC_M  Proportion of youth and adults who have used c...
# 8     ICTSKILLTRANSFERFILE  Proportion of youth and adults who have transf...
# 9     ICTSKILLTRANSFERFILE  Proportion of youth and adults who have transf...
# 10    ICTSKILLTRANSFERFILE  Proportion of youth and adults who have transf...
# 11    ICTSKILLTRANSFERFILE  Proportion of youth and adults who have transf...
# 12    ICTSKILLTRANSFERFILE  Proportion of youth and adults who have transf...
# 13       ICTSKILLFORMULA_M  Proportion of youth and adults who have used b...
# 14       ICTSKILLFORMULA_M  Proportion of youth and adults who have used b...
#
#    LOCATION Country  TIME  Time     Value  Flag Codes  Flags
# 0       BRA  Brazil  2014  2014  23.31007         NaN    NaN
# 1       BRA  Brazil  2016  2016  21.53173         NaN    NaN
# 2       BRA  Brazil  2017  2017  21.14880         NaN    NaN
# 3       BRA  Brazil  2018  2018  21.84886         NaN    NaN
# 4       BRA  Brazil  2014  2014  25.64427         NaN    NaN
# 5       BRA  Brazil  2016  2016  22.01463         NaN    NaN
# 6       BRA  Brazil  2017  2017  22.69577         NaN    NaN
# 7       BRA  Brazil  2018  2018  22.59234         NaN    NaN
# 8       TUR  Turkey  2014  2014  27.72807         NaN    NaN
# 9       TUR  Turkey  2015  2015  25.66142         NaN    NaN
# 10      TUR  Turkey  2016  2016  31.29833         NaN    NaN
# 11      TUR  Turkey  2017  2017  37.06352         NaN    NaN
# 12      TUR  Turkey  2019  2019  38.18440         NaN    NaN
# 13      EGY   Egypt  2014  2014   1.69992         NaN    NaN
# 14      EGY   Egypt  2015  2015   2.14629         NaN    NaN

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value']
df['Country Name'] = df['Country']
df['Year'] = df['Time']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
### 6. UNDP Human Development Index (HDI)

# %%
indicators[5]

# load data
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# UNDP Human Development Index (HDI)
# undp_human_developmnt

# %%
df.head(15)
# Need to move the top row down
# Maybe something is wrong with the link although the one in data manifest works perfectly
# Out:
#     HDI rank                      Country  Value  Unnamed: 3      (years)  \
# 0        NaN                          NaN   2019         NaN         2019
# 1        NaN  VERY HIGH HUMAN DEVELOPMENT    NaN         NaN          NaN
# 2        1.0                       Norway  0.957         NaN     12.89775
# 3        2.0                      Ireland  0.955         NaN   12.6663305
# 4        2.0                  Switzerland  0.955         NaN  13.38081241
# 5        4.0       Hong Kong, China (SAR)  0.949         NaN     12.27996
# 6        4.0                      Iceland  0.949         NaN  12.77278684
# 7        6.0                      Germany  0.947         NaN     14.15168
# 8        7.0                       Sweden  0.945         NaN     12.54847
# 9        8.0                    Australia  0.944         NaN  12.72469119
# 10       8.0                  Netherlands  0.944         NaN      12.4148
# 11      10.0                      Denmark   0.94         NaN  12.61380326
# 12      11.0                      Finland  0.938         NaN     12.82413
# 13      11.0                    Singapore  0.938         NaN     11.62461
# 14      13.0               United Kingdom  0.932         NaN     13.24287
#
#    (2017 PPP $)  data_country  data_year
# 0          2019           NaN        NaN
# 1           NaN           NaN        NaN
# 2   66494.25217           NaN        NaN
# 3   68370.58737           NaN        NaN
# 4   69393.52076           NaN        NaN
# 5   62984.76553           NaN        NaN
# 6   54682.38057           NaN        NaN
# 7   55314.35355           NaN        NaN
# 8   54507.80504           NaN        NaN
# 9   48084.84207           NaN        NaN
# 10  57707.06867           NaN        NaN
# 11  58661.87084           NaN        NaN
# 12   48511.3978           NaN        NaN
# 13  88155.21431           NaN        NaN
# 14  46070.64481           NaN        NaN

# %%
# choose only the rows where column HDI rank is numeric

df = df.iloc[0:194,:]
df = df[pd.to_numeric(df['HDI rank'], errors='coerce').notnull()]

# %%
df.head(15)
# Out:
#     HDI rank                 Country  Value  Unnamed: 3      (years)  \
# 2        1.0                  Norway  0.957         NaN     12.89775
# 3        2.0                 Ireland  0.955         NaN   12.6663305
# 4        2.0             Switzerland  0.955         NaN  13.38081241
# 5        4.0  Hong Kong, China (SAR)  0.949         NaN     12.27996
# 6        4.0                 Iceland  0.949         NaN  12.77278684
# 7        6.0                 Germany  0.947         NaN     14.15168
# 8        7.0                  Sweden  0.945         NaN     12.54847
# 9        8.0               Australia  0.944         NaN  12.72469119
# 10       8.0             Netherlands  0.944         NaN      12.4148
# 11      10.0                 Denmark   0.94         NaN  12.61380326
# 12      11.0                 Finland  0.938         NaN     12.82413
# 13      11.0               Singapore  0.938         NaN     11.62461
# 14      13.0          United Kingdom  0.932         NaN     13.24287
# 15      14.0                 Belgium  0.931         NaN     12.05027
# 16      14.0             New Zealand  0.931         NaN  12.78207732
#
#    (2017 PPP $)  data_country  data_year
# 2   66494.25217           NaN        NaN
# 3   68370.58737           NaN        NaN
# 4   69393.52076           NaN        NaN
# 5   62984.76553           NaN        NaN
# 6   54682.38057           NaN        NaN
# 7   55314.35355           NaN        NaN
# 8   54507.80504           NaN        NaN
# 9   48084.84207           NaN        NaN
# 10  57707.06867           NaN        NaN
# 11  58661.87084           NaN        NaN
# 12   48511.3978           NaN        NaN
# 13  88155.21431           NaN        NaN
# 14  46070.64481           NaN        NaN
# 15  52084.59209           NaN        NaN
# 16   40798.7196           NaN        NaN

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value']
df['Country Name'] = df['Country']
df['Year'] = 2019

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-69f7ec1a2307> in <module>
#      11
#      12 # transform 0-1 rank into 1-6
# ---> 13 df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
#
# D:\Apps\Anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-85-69f7ec1a2307> in <lambda>(row)
#      11
#      12 # transform 0-1 rank into 1-6
# ---> 13 df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))
#
# <ipython-input-14-020bafb9c04d> in convert_rank(old_value, old_min, old_max, new_min, new_max)
#       2 def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
#       3     """ Convert old scale values scale into new scale values"""
# ----> 4     old_range = old_max - old_min
#       5     new_range = new_max - new_min
#       6     new_value = (((old_value-old_min)*new_range)/old_range)+new_min
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
### 7. Facebook Social Connectedness Index

# %%
indicators[6]

# load data
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Facebook Social Connectedness Index
# fb_social_connectedness

# %%
df.head(25)
# Out:
#     user_loc fr_loc  scaled_sci
# 0       1001     AE        8729
# 1       1001     AG       95256
# 2       1001     AL        3122
# 3       1001     AM        3470
# 4       1001     AO        2839
# 5       1001     AR        3729
# 6       1001     AT        6977
# 7       1001     AU       21136
# 8       1001     AW       27607
# 9       1001     AZ        1108
# 10      1001     BA        3183
# 11      1001     BB       44020
# 12      1001     BD        1244
# 13      1001     BE       10933
# 14      1001     BF        2159
# 15      1001     BG        4085
# 16      1001     BH       14541
# 17      1001     BI        3778
# 18      1001     BJ        3308
# 19      1001     BN        3155
# 20      1001     BO        2724
# 21      1001     BR        4593
# 22      1001     BS      128531
# 23      1001     BT        1375
# 24      1001     BW        5455

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['scaled_sci'] 
df['Country Name'] = df['fr_loc']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Indicator','data_col','new_rank_score','higher_is_better']].head(30)

# Need to find a way to convert ISO codes to full country names

# %%
### 8. Share of individuals using the Internet to interact with officials

# %%
indicators[7]

# load data
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year
df = df[(df.Time==2019)]
df = df[(df.Indicator=='Individuals using the Internet for visiting or interacting with public authorities websites - last 12 m (%)')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Year'] = df['Time']
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 9. Level of satisfaction for online public service

# %%
indicators[8]

# load data
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Net Perception (%)'] 
df['Year'] = 2020
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# Need to replace the % mark

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 10. Number of mobile apps available in national language

# %%
indicators[9]

# load data
indicator = indicators[9]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year and global value
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Number of apps in national language'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 11. Device Addiction (time of use on internet)

# %%
indicators[10]

# load data
indicator = indicators[10]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# Need to move the row further down

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Average daily time spent using the internet by online users worldwide as of 3rd quarter 2020, by region (in hours.minutes)'] 
df['Country Name'] = df['Country']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 12. Gross National Wellbeing

# %%
indicators[11]

# load data
indicator = indicators[11]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# happiness_score is missing looks like the problem is in a redundant space before it in the filename matching

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['VALUE'] 
df['Country Name'] = df['COUNTRY/ECONOMY']
df['Year'] = 2019

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Average daily time spent using the internet by online users worldwide as of 3rd quarter 2020, by region (in hours.minutes)'] 
df['Country Name'] = df['Country']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
### 13. % of internet users who own cryptocurrency

# %%
indicators[12]

# load data
indicator = indicators[12]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Share of respondents who indicated they either owned or used cryptocurrencies in 55 countries worldwide in 2020'] 
df['Country Name'] = df['Country']
df['Year'] = 2020

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 14. Percentage of individuals not buying online due to concerns about returning products

# %%
indicators[13]

# load data
indicator = indicators[13]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year and global value
df = df[(df.Time==2019)]
df = df[(df.Scope =='All individuals (aged 16-74)')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = False
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Year'] = df['Time']
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 15. Percentage of individuals not buying online due to payment security concerns

# %%
indicators[14]

# load data
indicator = indicators[14]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year and global value
df = df[(df.Time==2019)]
df = df[(df.Scope =='All individuals (aged 16-74)')]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = False
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df['Year'] = df['Time']
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 16. E-waste generated, kilograms per inhabitant

# %%
indicators[15]

# load data
indicator = indicators[15]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
# Use special_waste_e_waste_tons_year times one thousand and divde by total population
df['data_col'] = df['special_waste_e_waste_tons_year']*1000/df['population_population_number_of_people'] 
df['Year'] = 2021
df['Country Name'] = df['country_name']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 17. Automation-led unemployment

# %%
indicators[16]

# load data
indicator = indicators[16]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Potential Rate of Automation (%)'] 
df['Year'] = 2018
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 18. Cyberbullying

# %%
indicators[17]

# load data
indicator = indicators[17]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# Need to move the top row down further

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2018'] 
df['Year'] = 2018
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 19. Global Wellbeing Initiative

# %%
indicators[18]

# load data
indicator = indicators[18]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Strange the global_wellbeing_initiative is clearly in the data manifest and the link works well 
# but it has not been moved to the processed folder
# Out:
# Global Wellbeing Initiative (World Happiness Index)
# global_wellbeing_initiative
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-fd68f7cc1679> in <module>
#       7 print(bf)
#       8
# ----> 9 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#      10
#      11 # Strange the global_wellbeing_initiative is clearly in the data manifest and the link works well
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/global_wellbeing_initiative .csv'

# %%
### 20. Financial Inclusiveness

# %%
indicators[19]

# load data
indicator = indicators[19]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)


df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Strange the global_wellbeing_initiative is clearly in the data manifest and the link works well 
# but it has not been moved to the processed folder
# Out:
# Financial Inclusiveness
# financial_inclusiveness
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-f7b10ddcde16> in <module>
#       8
#       9
# ---> 10 df = pd.read_csv('../../processed/{}.csv'.format(bf))
#      11 # Strange the global_wellbeing_initiative is clearly in the data manifest and the link works well
#      12 # but it has not been moved to the processed folder
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# D:\Apps\Anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../processed/financial_inclusiveness .csv'

# %%
### 21. E-commerce activity (% of individuals buying online and frequency)

# %%
indicators[20]

# load data
indicator = indicators[20]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Added _ between spaces to see if this changes anything

# %%
df.head(15)

# Move the top row down further

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['VALUE (%)'] 
df['Country Name'] = df['COUNTRY/ECONOMY']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name', 'Year','Indicator','data_col','new_rank_score','higher_is_better']].head(20)

# %%
### 22. E-commerce activity (Types of goods and services purchased online)

# %%
indicators[21]

# load data
indicator = indicators[21]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Move the top row down further
# This is a list of categories, wonder if it will do

# %%
df.head(15)

# %%
### 23. Top Visited websites

# %%
indicators[22]

# load data
indicator = indicators[22]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
### 24. Top YouTube Searches

# %%
indicators[23]

# load data
indicator = indicators[23]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
### 25. Top Google searches

# %%
indicators[24]

# load data
indicator = indicators[24]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
### 26. Internet Usage

# %%
indicators[25]

# load data
indicator = indicators[25]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2019_value'] 
df['Year'] = 2019
df['Country Name'] = df['ShortName']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# convert 1-190 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row, old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 27. Households with a computer and with Internet Access

# %%
indicators[26]

# load data
indicator = indicators[26]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# have to replace 'No data' with blank

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2016'] 
df['Year'] = 2016
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 28. % of population using Facebook

# %%
indicators[27]

# load data
indicator = indicators[27]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Percentage of Facebook Users'] 
df['Year'] = 2021
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 29. Gender gap for social media use

# %%
indicators[28]

# load data
indicator = indicators[28]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df = df[df.Year==2019]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Gender gap in social media use'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 30. % of population using digital financial services

# %%
indicators[29]

# load data
indicator = indicators[29]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# May have to convert the data to csv file as the original file is missing many important columns

# %%
### 31. Mobile Broadband Pricing (pre-paid)

# %%
indicators[30]

# load data
indicator = indicators[30]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# File not found despite its presence in the personal repo and the data manifest

# %%
### 32. Tax as % of total cost of mobile ownership

# %%
indicators[31]

# load data
indicator = indicators[31]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df = df[df.Year==2019]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = False
df['Indicator'] = indicator
df['data_col'] = df['Tax as a % of TCMO'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# invert since to put as higher is  better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 33. % of population with a SIM card

# %%
indicators[32]

# load data
indicator = indicators[32]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# File not found despite its presence in the personal repo and the data manifest

# %%
### 34. % of population with a smartphone

# %%
indicators[33]

# load data
indicator = indicators[33]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Smartphone Penetration Rate'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# Must delete the % mark in the fourth column

# %%
### 35. Gender gap in internet usage

# %%
indicators[34]

# load data
indicator = indicators[34]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# The problem with the data base is that it has ... in the Male and Female columns, making it string columns, not numerical
# This will present problems when trying to calculate ranking

# %%
### 36. Gender gap in mobile usage

# %%
indicators[35]

# load data
indicator = indicators[35]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Gender gap in mobile ownership'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 37. Mobile Device Penetration

# %%
indicators[36]

# load data
indicator = indicators[36]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Mobile Ownership'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 38. Mobile Device Penetration (female)

# %%
indicators[37]

# load data
indicator = indicators[37]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Gender gap in mobile ownership'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
