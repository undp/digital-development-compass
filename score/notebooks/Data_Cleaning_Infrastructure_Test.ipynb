# %%
import pandas as pd
import numpy as np

# %%
### Get all the pillar names from the excel

# %%
names = pd.read_excel('../../UNDP Digital Assessment Data Framework Filename Matching V7.xlsx')

# %%
col_names = ['Indicator','check', 'Data Source','Index','Filename']

# %%
names = names[col_names]

# %%
names.head()
# Out:
#                                            Indicator           check  \
# 0                                          Countries             NaN
# 1  Database of Global Administrative Areas (GADM,...             NaN
# 2  High Resolution Population Density Maps + Demo...             NaN
# 3  population density vs openstreetmap object den...             NaN
# 4                                 Population Density  Infrastructure
#
#           Data Source  Index            Filename
# 0      United Nations  False           Countries
# 1  GADM maps and data  False                 NaN
# 2            Facebook  False                 NaN
# 3              Kontur  False                 NaN
# 4          World Bank  False  population_density

# %%
# get all the files per pillar
data_stats = names.groupby('check').agg({'Filename':'count','Indicator':'count'})

# %%
data_stats
# Out:
#                 Filename  Indicator
# check
# Business              20         25
# Foundations            9         12
# Government            10         15
# Infrastructure        39         48
# People                39         47
# Regulation             6          7
# Strategy               1          1

# %%
### Infrastructure

# %%
bnames = names[(names.check=='Infrastructure')&(~names.Filename.isna())]#&(names.Index==False)]
bnames.head(25)
# Out:
#                                             Indicator           check  \
# 4                                  Population Density  Infrastructure
# 5                                   Broadband Density  Infrastructure
# 6    % of population covered by internet connectivity  Infrastructure
# 7   % of population covered by mobile 2G+ data con...  Infrastructure
# 8   % of population covered by mobile 3G+ data con...  Infrastructure
# 9   % of population covered by mobile 4G+ data con...  Infrastructure
# 10  % of population covered by mobile 5G+ data con...  Infrastructure
# 11                               Mobile Coverage Maps  Infrastructure
# 12                                Electricity Density  Infrastructure
# 13             % of population covered by electricity  Infrastructure
# 14                         Electricity supply quality  Infrastructure
# 15           Electricity Environmental Sustainability  Infrastructure
# 17                           Cellphone Signal Density  Infrastructure
# 18       Telecommunication Infrastructure Index (TII)  Infrastructure
# 19                    GSMA Mobile Connectivity Index   Infrastructure
# 20             Spectrum Allocated to Mobile Providers  Infrastructure
# 23                Internet Exchange Points (IXPs) map  Infrastructure
# 26               ISP internet download speed average   Infrastructure
# 28  Mobile dowload speed at the slowest hour of th...  Infrastructure
# 29                     Mobile download speed average   Infrastructure
# 30   Individuals using the Internet (% of population)  Infrastructure
# 31     Mobile cellular subscriptions (per 100 people)  Infrastructure
# 32           Average fixed broadband download speeds   Infrastructure
# 35                                    Postal Coverage  Infrastructure
# 36  Logistics Performance Index (LPI) - Infrastruc...  Infrastructure
#
#                                           Data Source  Index  \
# 4                                          World Bank  False
# 5                                                 ITU  False
# 6                                                 ITU  False
# 7                      GSMA Mobile Connectivity Index  False
# 8                      GSMA Mobile Connectivity Index  False
# 9                      GSMA Mobile Connectivity Index  False
# 10                     GSMA Mobile Connectivity Index  False
# 11                                                ITU  False
# 12                                        Energy Data  False
# 13                                        World Bank   False
# 14  International Energy Agency / Global Competiti...  False
# 15  The Sustainable Development Report/ Cambridge ...  False
# 17                     GSMA Mobile Connectivity Index  False
# 18                                               DESA   True
# 19                     GSMA Mobile Connectivity Index   True
# 20                     GSMA Mobile Connectivity Index  False
# 23                              Packet Clearing House  False
# 26                     Ookla's Speedtest Intelligence  False
# 28                     GSMA Mobile Connectivity Index  False
# 29                     Ookla's Speedtest Intelligence  False
# 30                                                ITU  False
# 31                                                ITU  False
# 32                     Ookla's Speedtest Intelligence  False
# 35                             Universal Postal Union  False
# 36                                         World Bank   True
#
#                                Filename
# 4                    population_density
# 5                          ITU_database
# 6                          ITU_database
# 7         countries_mobile_connectivity
# 8         countries_mobile_connectivity
# 9         countries_mobile_connectivity
# 10        countries_mobile_connectivity
# 11                         ITU_database
# 12                 electricity_yearbook
# 13      population_electricity_coverage
# 14                 elect_supply_quality
# 15                 sustainability_index
# 17                       mobile_density
# 18                   e_government_index
# 19        countries_mobile_connectivity
# 20  spectrum_allocated_mobile_providers
# 23                        countries_ixp
# 26                       internet_speed
# 28                       mobile_latency
# 29                         mobile_speed
# 30                         ITU_database
# 31                         ITU_database
# 32                 fixed_bdbd_spd_dl_ul
# 35                      postal_coverage
# 36          logistics_performance_index

# %%
# get list of names for all indicators
indicators = bnames.Indicator.unique()

# %%
# get all file names
bfiles = bnames.Filename.unique()

# %%
bfiles
# Out:
# array(['population_density', 'ITU_database',
#        'countries_mobile_connectivity', 'electricity_yearbook',
#        'population_electricity_coverage', 'elect_supply_quality',
#        'sustainability_index', 'mobile_density', 'e_government_index',
#        'spectrum_allocated_mobile_providers', 'countries_ixp',
#        'internet_speed', 'mobile_latency', 'mobile_speed',
#        'fixed_bdbd_spd_dl_ul', 'postal_coverage',
#        'logistics_performance_index', 'national_cybersecurity_index',
#        'dice_export_global_cybersecurity_index',
#        'software_developer_ecosystem_size',
#        'digital_platform_economy_index', 'migration_skill',
#        'migration_industry', 'migration_country',
#        'global_fintech_ranking', 'tech_hubs', 'banking_sector_size',
#        'angel_investment', 'startup_eco_size',
#        'international_co_inventions'], dtype=object)

# %%
# formula for converting scale
def convert_rank(old_value, old_min=1, old_max=7, new_min=1, new_max=6 ):
    """ Convert old scale values scale into new scale values"""
    old_range = old_max - old_min
    new_range = new_max - new_min
    new_value = (((old_value-old_min)*new_range)/old_range)+new_min
    return new_value

# %%
### 2. Broadband Density

# %%
indicators[1]

# load data
indicator = indicators[1]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Broadband Density
# ITU_database

# %%
df.head(15)
# Out:
#                    Country  Region  ISO  \
# 0                   Angola  Africa  AGO
# 1                    Benin  Africa  BEN
# 2                 Botswana  Africa  BWA
# 3             Burkina Faso  Africa  BFA
# 4                  Burundi  Africa  BDI
# 5               Cabo Verde  Africa  CPV
# 6                 Cameroon  Africa  CMR
# 7     Central African Rep.  Africa  CAF
# 8                     Chad  Africa  TCD
# 9      Congo (Rep. of the)  Africa  COG
# 10           Côte d'Ivoire  Africa  CIV
# 11  Dem. Rep. of the Congo  Africa  COD
# 12       Equatorial Guinea  Africa  GNQ
# 13                 Eritrea  Africa  ERI
# 14                Eswatini  Africa  SWZ
#
#                                        Indicator name    Year  Value  \
# 0   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 10  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 11  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 12  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 13  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 14  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
df = df[(df.Year == 2020)]
df = df[(df['Indicator name']== 'Fixed broadband subscriptions per 100 inhabitants')]
df
# Out:
#                    Country        Region  ISO  \
# 36787               Angola        Africa  AGO
# 36788                Benin        Africa  BEN
# 36789             Botswana        Africa  BWA
# 36790         Burkina Faso        Africa  BFA
# 36791              Burundi        Africa  BDI
# ...                    ...           ...  ...
# 36978             Suriname  The Americas  SUR
# 36979  Trinidad and Tobago  The Americas  TTO
# 36980        United States  The Americas  USA
# 36981              Uruguay  The Americas  URY
# 36982            Venezuela  The Americas  VEN
#
#                                           Indicator name    Year      Value  \
# 36787  Fixed broadband subscriptions per 100 inhabitants  2020.0   0.701662
# 36788  Fixed broadband subscriptions per 100 inhabitants  2020.0   0.247303
# 36789  Fixed broadband subscriptions per 100 inhabitants  2020.0   3.057373
# 36790  Fixed broadband subscriptions per 100 inhabitants  2020.0   0.066875
# 36791  Fixed broadband subscriptions per 100 inhabitants  2020.0   0.035574
# ...                                                  ...     ...        ...
# 36978  Fixed broadband subscriptions per 100 inhabitants  2020.0  15.728770
# 36979  Fixed broadband subscriptions per 100 inhabitants  2020.0  26.866254
# 36980  Fixed broadband subscriptions per 100 inhabitants  2020.0  36.413908
# 36981  Fixed broadband subscriptions per 100 inhabitants  2020.0        NaN
# 36982  Fixed broadband subscriptions per 100 inhabitants  2020.0   8.465298
#
#        data_country  data_year
# 36787           NaN        NaN
# 36788           NaN        NaN
# 36789           NaN        NaN
# 36790           NaN        NaN
# 36791           NaN        NaN
# ...             ...        ...
# 36978           NaN        NaN
# 36979           NaN        NaN
# 36980           NaN        NaN
# 36981           NaN        NaN
# 36982           NaN        NaN
#
# [196 rows x 8 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value']
df.rename(columns={'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country Name    Year          Indicator  data_col  \
# 36787                  Angola  2020.0  Broadband Density  0.701662
# 36788                   Benin  2020.0  Broadband Density  0.247303
# 36789                Botswana  2020.0  Broadband Density  3.057373
# 36790            Burkina Faso  2020.0  Broadband Density  0.066875
# 36791                 Burundi  2020.0  Broadband Density  0.035574
# 36792              Cabo Verde  2020.0  Broadband Density  4.467550
# 36793                Cameroon  2020.0  Broadband Density  2.689101
# 36794    Central African Rep.  2020.0  Broadband Density       NaN
# 36795                    Chad  2020.0  Broadband Density  0.000000
# 36796     Congo (Rep. of the)  2020.0  Broadband Density       NaN
# 36797           Côte d'Ivoire  2020.0  Broadband Density  0.986027
# 36798  Dem. Rep. of the Congo  2020.0  Broadband Density       NaN
# 36799       Equatorial Guinea  2020.0  Broadband Density       NaN
# 36800                 Eritrea  2020.0  Broadband Density       NaN
# 36801                Eswatini  2020.0  Broadband Density       NaN
#
#        new_rank_score  higher_is_better
# 36787        1.065945              True
# 36788        1.023242              True
# 36789        1.287344              True
# 36790        1.006285              True
# 36791        1.003343              True
# 36792        1.419877              True
# 36793        1.252732              True
# 36794             NaN              True
# 36795        1.000000              True
# 36796             NaN              True
# 36797        1.092671              True
# 36798             NaN              True
# 36799             NaN              True
# 36800             NaN              True
# 36801             NaN              True

# %%
### 3. % of population covered by internet connectivity

# %%
indicators[2]

# load data
indicator = indicators[2]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by internet connectivity
# ITU_database

# %%
df = df[(df.Year == 2020)]
df = df[(df['Indicator name']== 'Individuals using the Internet, total (%)')]
df
# Out:
#                                 Country        Region  ISO  \
# 47744                         Mauritius        Africa  MUS
# 47745                            Uganda        Africa  UGA
# 47746                           Bahrain   Arab States  BHR
# 47747                             Egypt   Arab States  EGY
# 47748                              Iraq   Arab States  IRQ
# ...                                 ...           ...  ...
# 47805  Bolivia (Plurinational State of)  The Americas  BOL
# 47806                        Costa Rica  The Americas  CRI
# 47807                            Mexico  The Americas  MEX
# 47808                          Paraguay  The Americas  PRY
# 47809                              Peru  The Americas  PER
#
#                                   Indicator name    Year      Value  \
# 47744  Individuals using the Internet, total (%)  2020.0  64.884904
# 47745  Individuals using the Internet, total (%)  2020.0        NaN
# 47746  Individuals using the Internet, total (%)  2020.0  99.539512
# 47747  Individuals using the Internet, total (%)  2020.0  71.914200
# 47748  Individuals using the Internet, total (%)  2020.0        NaN
# ...                                          ...     ...        ...
# 47805  Individuals using the Internet, total (%)  2020.0  55.139051
# 47806  Individuals using the Internet, total (%)  2020.0  80.530186
# 47807  Individuals using the Internet, total (%)  2020.0  71.970000
# 47808  Individuals using the Internet, total (%)  2020.0  74.515240
# 47809  Individuals using the Internet, total (%)  2020.0  65.251799
#
#        data_country  data_year
# 47744           NaN        NaN
# 47745           NaN        NaN
# 47746           NaN        NaN
# 47747           NaN        NaN
# 47748           NaN        NaN
# ...             ...        ...
# 47805           NaN        NaN
# 47806           NaN        NaN
# 47807           NaN        NaN
# 47808           NaN        NaN
# 47809           NaN        NaN
#
# [66 rows x 8 columns]

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value']
df.rename(columns={'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                Country Name    Year  \
# 47744             Mauritius  2020.0
# 47745                Uganda  2020.0
# 47746               Bahrain  2020.0
# 47747                 Egypt  2020.0
# 47748                  Iraq  2020.0
# 47749                Kuwait  2020.0
# 47750               Morocco  2020.0
# 47751                  Oman  2020.0
# 47752                 Qatar  2020.0
# 47753          Saudi Arabia  2020.0
# 47754  United Arab Emirates  2020.0
# 47755              Cambodia  2020.0
# 47756                 China  2020.0
# 47757      Hong Kong, China  2020.0
# 47758             Indonesia  2020.0
#
#                                               Indicator    data_col  \
# 47744  % of population covered by internet connectivity   64.884904
# 47745  % of population covered by internet connectivity         NaN
# 47746  % of population covered by internet connectivity   99.539512
# 47747  % of population covered by internet connectivity   71.914200
# 47748  % of population covered by internet connectivity         NaN
# 47749  % of population covered by internet connectivity   98.599995
# 47750  % of population covered by internet connectivity   84.120363
# 47751  % of population covered by internet connectivity   95.232293
# 47752  % of population covered by internet connectivity   99.652794
# 47753  % of population covered by internet connectivity   97.862332
# 47754  % of population covered by internet connectivity  100.000000
# 47755  % of population covered by internet connectivity   78.800000
# 47756  % of population covered by internet connectivity   70.642143
# 47757  % of population covered by internet connectivity   92.413136
# 47758  % of population covered by internet connectivity   53.726494
#
#        new_rank_score  higher_is_better
# 47744        3.298839              True
# 47745             NaN              True
# 47746        5.964578              True
# 47747        3.839554              True
# 47748             NaN              True
# 47749        5.892307              True
# 47750        4.778489              True
# 47751        5.633253              True
# 47752        5.973292              True
# 47753        5.835564              True
# 47754        6.000000              True
# 47755        4.369231              True
# 47756        3.741703              True
# 47757        5.416395              True
# 47758        2.440500              True

# %%
### 4. % of population covered by mobile 2G

# %%
indicators[3]
# Out:
# '% of population covered by mobile 2G+ data connectivity'

# %%
# load data
indicator = indicators[3]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 2G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 2G+ data con...     90.00
# 11  % of population covered by mobile 2G+ data con...     90.00
# 17  % of population covered by mobile 2G+ data con...     99.86
# 23  % of population covered by mobile 2G+ data con...    100.00
# 29  % of population covered by mobile 2G+ data con...     98.00
# 35  % of population covered by mobile 2G+ data con...    100.00
# 41  % of population covered by mobile 2G+ data con...     99.40
# 47  % of population covered by mobile 2G+ data con...     99.00
# 53  % of population covered by mobile 2G+ data con...    100.00
# 59  % of population covered by mobile 2G+ data con...     53.65
# 65  % of population covered by mobile 2G+ data con...    100.00
# 71  % of population covered by mobile 2G+ data con...     98.00
# 77  % of population covered by mobile 2G+ data con...     97.90
# 83  % of population covered by mobile 2G+ data con...     99.60
# 89  % of population covered by mobile 2G+ data con...    100.00
#
#     new_rank_score  higher_is_better
# 5         4.921251              True
# 11        4.921251              True
# 17        5.984898              True
# 23        6.000000              True
# 29        5.784250              True
# 35        6.000000              True
# 41        5.935275              True
# 47        5.892125              True
# 53        6.000000              True
# 59        1.000000              True
# 65        6.000000              True
# 71        5.784250              True
# 77        5.773463              True
# 83        5.956850              True
# 89        6.000000              True

# %%
### 5. % of population covered by mobile 3G

# %%
indicators[4]

# load data
indicator = indicators[4]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 3G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['3G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 3G+ data con...      58.7
# 11  % of population covered by mobile 3G+ data con...      71.0
# 17  % of population covered by mobile 3G+ data con...      97.0
# 23  % of population covered by mobile 3G+ data con...     100.0
# 29  % of population covered by mobile 3G+ data con...      95.0
# 35  % of population covered by mobile 3G+ data con...      99.0
# 41  % of population covered by mobile 3G+ data con...      99.5
# 47  % of population covered by mobile 3G+ data con...      99.0
# 53  % of population covered by mobile 3G+ data con...      95.0
# 59  % of population covered by mobile 3G+ data con...      40.0
# 65  % of population covered by mobile 3G+ data con...     100.0
# 71  % of population covered by mobile 3G+ data con...      89.0
# 77  % of population covered by mobile 3G+ data con...      65.0
# 83  % of population covered by mobile 3G+ data con...      95.0
# 89  % of population covered by mobile 3G+ data con...     100.0
#
#     new_rank_score  higher_is_better
# 5         3.282895              True
# 11        4.092105              True
# 17        5.802632              True
# 23        6.000000              True
# 29        5.671053              True
# 35        5.934211              True
# 41        5.967105              True
# 47        5.934211              True
# 53        5.671053              True
# 59        2.052632              True
# 65        6.000000              True
# 71        5.276316              True
# 77        3.697368              True
# 83        5.671053              True
# 89        6.000000              True

# %%
### 6. % of population covered by mobile 4G

# %%
indicators[5]

# load data
indicator = indicators[5]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 4G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['4G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#             Country Name  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 4G+ data con...     15.00
# 11  % of population covered by mobile 4G+ data con...     50.00
# 17  % of population covered by mobile 4G+ data con...     96.00
# 23  % of population covered by mobile 4G+ data con...     99.00
# 29  % of population covered by mobile 4G+ data con...     89.77
# 35  % of population covered by mobile 4G+ data con...     95.00
# 41  % of population covered by mobile 4G+ data con...     99.20
# 47  % of population covered by mobile 4G+ data con...     99.00
# 53  % of population covered by mobile 4G+ data con...     90.00
# 59  % of population covered by mobile 4G+ data con...     25.00
# 65  % of population covered by mobile 4G+ data con...    100.00
# 71  % of population covered by mobile 4G+ data con...     45.00
# 77  % of population covered by mobile 4G+ data con...      8.64
# 83  % of population covered by mobile 4G+ data con...     80.00
# 89  % of population covered by mobile 4G+ data con...    100.00
#
#     new_rank_score  higher_is_better
# 5           1.7500              True
# 11          3.5000              True
# 17          5.8000              True
# 23          5.9500              True
# 29          5.4885              True
# 35          5.7500              True
# 41          5.9600              True
# 47          5.9500              True
# 53          5.5000              True
# 59          2.2500              True
# 65          6.0000              True
# 71          3.2500              True
# 77          1.4320              True
# 83          5.0000              True
# 89          6.0000              True

# %%
### 7. % of population covered by mobile 5G

# %%
indicators[6]

# load data
indicator = indicators[6]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by mobile 5G+ data connectivity
# countries_mobile_connectivity

# %%
df.head(10)
# Out:
#   ISO Code      Country              Region  Year     Cluster  Index  \
# 0      AFG  Afghanistan          South Asia  2014  Discoverer  22.12
# 1      AFG  Afghanistan          South Asia  2015  Discoverer  22.99
# 2      AFG  Afghanistan          South Asia  2016  Discoverer  23.71
# 3      AFG  Afghanistan          South Asia  2017  Discoverer  25.82
# 4      AFG  Afghanistan          South Asia  2018  Discoverer  28.39
# 5      AFG  Afghanistan          South Asia  2019  Discoverer  28.94
# 6      AGO       Angola  Sub-Saharan Africa  2014  Discoverer  32.78
# 7      AGO       Angola  Sub-Saharan Africa  2015    Emerging  37.18
# 8      AGO       Angola  Sub-Saharan Africa  2016    Emerging  39.85
# 9      AGO       Angola  Sub-Saharan Africa  2017    Emerging  42.89
#
#    Infrastructure  Affordability  Consumer Readiness  Content and Services  \
# 0           21.74          31.79               24.40                 14.19
# 1           22.82          30.81               25.28                 15.71
# 2           26.92          26.75               26.07                 16.83
# 3           33.54          27.22               28.56                 17.04
# 4           30.91          42.64               29.24                 16.87
# 5           32.34          41.53               29.72                 17.58
# 6           25.99          35.99               44.33                 27.85
# 7           33.09          42.01               45.41                 30.27
# 8           37.80          44.74               46.47                 32.11
# 9           48.60          47.94               46.32                 31.36
#
#    ...  Gender gap in mobile ownership  TLDs per capita  E-Government Score  \
# 0  ...                            0.00            39.55               18.11
# 1  ...                            0.00            39.57               24.27
# 2  ...                            0.00            39.58               30.43
# 3  ...                            0.00            39.47               30.50
# 4  ...                            0.00            39.39               30.56
# 5  ...                            0.00            39.41               41.18
# 6  ...                           51.65             0.00               29.92
# 7  ...                           57.00             0.31               32.35
# 8  ...                           63.73             0.00               34.78
# 9  ...                           53.97             0.00               37.88
#
#    Mobile Social Media Penetration  Apps developed per person  \
# 0                             3.28                      20.98
# 1                             4.36                      22.93
# 2                             6.73                      30.31
# 3                             7.78                      31.62
# 4                             8.54                      36.54
# 5                             9.39                      39.36
# 6                             3.99                      22.74
# 7                             5.26                      22.12
# 8                             6.27                      27.46
# 9                             4.26                      31.94
#
#    Number of apps in national language  Accessibility of top ranked apps  \
# 0                                 2.44                              4.37
# 1                                 2.79                              8.03
# 2                                 2.85                              5.90
# 3                                 2.91                              6.15
# 4                                 2.96                              8.66
# 5                                 3.00                              5.72
# 6                                53.33                             49.09
# 7                                55.08                             58.33
# 8                                56.52                             61.73
# 9                                57.06                             55.09
#
#    Cybersecurity Index  data_country  data_year
# 0                26.50           NaN        NaN
# 1                25.83           NaN        NaN
# 2                25.17           NaN        NaN
# 3                24.50           NaN        NaN
# 4                17.70           NaN        NaN
# 5                17.70           NaN        NaN
# 6                 8.80           NaN        NaN
# 7                 8.47           NaN        NaN
# 8                 8.13           NaN        NaN
# 9                 7.80           NaN        NaN
#
# [10 rows x 66 columns]

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['5G Coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country  Year  \
# 5            Afghanistan  2019
# 11                Angola  2019
# 17               Albania  2019
# 23  United Arab Emirates  2019
# 29             Argentina  2019
# 35               Armenia  2019
# 41             Australia  2019
# 47               Austria  2019
# 53            Azerbaijan  2019
# 59               Burundi  2019
# 65               Belgium  2019
# 71                 Benin  2019
# 77          Burkina Faso  2019
# 83            Bangladesh  2019
# 89              Bulgaria  2019
#
#                                             Indicator  data_col  \
# 5   % of population covered by mobile 5G+ data con...       0.0
# 11  % of population covered by mobile 5G+ data con...       0.0
# 17  % of population covered by mobile 5G+ data con...       0.0
# 23  % of population covered by mobile 5G+ data con...     100.0
# 29  % of population covered by mobile 5G+ data con...       0.0
# 35  % of population covered by mobile 5G+ data con...       0.0
# 41  % of population covered by mobile 5G+ data con...     100.0
# 47  % of population covered by mobile 5G+ data con...     100.0
# 53  % of population covered by mobile 5G+ data con...       0.0
# 59  % of population covered by mobile 5G+ data con...       0.0
# 65  % of population covered by mobile 5G+ data con...       0.0
# 71  % of population covered by mobile 5G+ data con...       0.0
# 77  % of population covered by mobile 5G+ data con...       0.0
# 83  % of population covered by mobile 5G+ data con...       0.0
# 89  % of population covered by mobile 5G+ data con...       0.0
#
#     new_rank_score  higher_is_better
# 5              1.0              True
# 11             1.0              True
# 17             1.0              True
# 23             6.0              True
# 29             1.0              True
# 35             1.0              True
# 41             6.0              True
# 47             6.0              True
# 53             1.0              True
# 59             1.0              True
# 65             1.0              True
# 71             1.0              True
# 77             1.0              True
# 83             1.0              True
# 89             1.0              True

# %%
### 8. Mobile Coverage Maps

# %%
indicators[7]

# load data
indicator = indicators[7]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Mobile Coverage Maps
# ITU_database

# %%
df.head(15)
# Out:
#                    Country  Region  ISO  \
# 0                   Angola  Africa  AGO
# 1                    Benin  Africa  BEN
# 2                 Botswana  Africa  BWA
# 3             Burkina Faso  Africa  BFA
# 4                  Burundi  Africa  BDI
# 5               Cabo Verde  Africa  CPV
# 6                 Cameroon  Africa  CMR
# 7     Central African Rep.  Africa  CAF
# 8                     Chad  Africa  TCD
# 9      Congo (Rep. of the)  Africa  COG
# 10           Côte d'Ivoire  Africa  CIV
# 11  Dem. Rep. of the Congo  Africa  COD
# 12       Equatorial Guinea  Africa  GNQ
# 13                 Eritrea  Africa  ERI
# 14                Eswatini  Africa  SWZ
#
#                                        Indicator name    Year  Value  \
# 0   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 1   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 2   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 3   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 4   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 5   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 6   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 7   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 8   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 9   Female mobile phone ownership as a % of total ...  2010.0    NaN
# 10  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 11  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 12  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 13  Female mobile phone ownership as a % of total ...  2010.0    NaN
# 14  Female mobile phone ownership as a % of total ...  2010.0    NaN
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN

# %%
df = df[(df.Year == 2020)]
df = df[(df['Indicator name']== 'Mobile-cellular subscriptions per 100 inhabitants')]
df
# Out:
#                    Country        Region  ISO  \
# 32475               Angola        Africa  AGO
# 32476                Benin        Africa  BEN
# 32477             Botswana        Africa  BWA
# 32478         Burkina Faso        Africa  BFA
# 32479              Burundi        Africa  BDI
# ...                    ...           ...  ...
# 32666             Suriname  The Americas  SUR
# 32667  Trinidad and Tobago  The Americas  TTO
# 32668        United States  The Americas  USA
# 32669              Uruguay  The Americas  URY
# 32670            Venezuela  The Americas  VEN
#
#                                           Indicator name    Year       Value  \
# 32475  Mobile-cellular subscriptions per 100 inhabitants  2020.0   44.559511
# 32476  Mobile-cellular subscriptions per 100 inhabitants  2020.0   91.897280
# 32477  Mobile-cellular subscriptions per 100 inhabitants  2020.0  162.399011
# 32478  Mobile-cellular subscriptions per 100 inhabitants  2020.0  105.807440
# 32479  Mobile-cellular subscriptions per 100 inhabitants  2020.0   55.767172
# ...                                                  ...     ...         ...
# 32666  Mobile-cellular subscriptions per 100 inhabitants  2020.0  153.305479
# 32667  Mobile-cellular subscriptions per 100 inhabitants  2020.0  142.051665
# 32668  Mobile-cellular subscriptions per 100 inhabitants  2020.0         NaN
# 32669  Mobile-cellular subscriptions per 100 inhabitants  2020.0         NaN
# 32670  Mobile-cellular subscriptions per 100 inhabitants  2020.0   63.400007
#
#        data_country  data_year
# 32475           NaN        NaN
# 32476           NaN        NaN
# 32477           NaN        NaN
# 32478           NaN        NaN
# 32479           NaN        NaN
# ...             ...        ...
# 32666           NaN        NaN
# 32667           NaN        NaN
# 32668           NaN        NaN
# 32669           NaN        NaN
# 32670           NaN        NaN
#
# [196 rows x 8 columns]

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                  Country Name    Year             Indicator    data_col  \
# 32475                  Angola  2020.0  Mobile Coverage Maps   44.559511
# 32476                   Benin  2020.0  Mobile Coverage Maps   91.897280
# 32477                Botswana  2020.0  Mobile Coverage Maps  162.399011
# 32478            Burkina Faso  2020.0  Mobile Coverage Maps  105.807440
# 32479                 Burundi  2020.0  Mobile Coverage Maps   55.767172
# 32480              Cabo Verde  2020.0  Mobile Coverage Maps   97.975133
# 32481                Cameroon  2020.0  Mobile Coverage Maps   95.100069
# 32482    Central African Rep.  2020.0  Mobile Coverage Maps         NaN
# 32483                    Chad  2020.0  Mobile Coverage Maps   52.887026
# 32484     Congo (Rep. of the)  2020.0  Mobile Coverage Maps         NaN
# 32485           Côte d'Ivoire  2020.0  Mobile Coverage Maps  152.001022
# 32486  Dem. Rep. of the Congo  2020.0  Mobile Coverage Maps   45.553547
# 32487       Equatorial Guinea  2020.0  Mobile Coverage Maps         NaN
# 32488                 Eritrea  2020.0  Mobile Coverage Maps         NaN
# 32489                Eswatini  2020.0  Mobile Coverage Maps         NaN
#
#        new_rank_score  higher_is_better
# 32475        1.012692              True
# 32476        1.968150              True
# 32477        3.391146              True
# 32478        2.248911              True
# 32479        1.238906              True
# 32480        2.090825              True
# 32481        2.032795              True
# 32482             NaN              True
# 32483        1.180774              True
# 32484             NaN              True
# 32485        3.181275              True
# 32486        1.032756              True
# 32487             NaN              True
# 32488             NaN              True
# 32489             NaN              True

# %%
### 9. Electricity Density

# %%
indicators[8]

# load data
indicator = indicators[8]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electricity Density
# electricity_yearbook

# %%
df.head(20)
# Out:
#        1990     1991     1992     1993     1994     1995     1996     1997  \
# 0   11894.0  12173.0  12284.0  12574.0  12881.0  13327.0  13754.0  14045.0
# 1    7712.0   7900.0   7975.0   8160.0   8389.0   8646.0   8889.0   9014.0
# 2    6089.0   6236.0   6277.0   6414.0   6578.0   6760.0   6944.0   6985.0
# 3    2386.0   2468.0   2510.0   2583.0   2637.0   2754.0   2863.0   2961.0
# 4    2900.0   2937.0   2926.0   2931.0   2976.0   3071.0   3164.0   3199.0
# 5    2595.0   2640.0   2624.0   2626.0   2667.0   2744.0   2846.0   2857.0
# 6      71.0     72.0     72.0     71.0     72.0     74.0     76.0     79.0
# 7      63.0     61.0     59.0     59.0     59.0     61.0     64.0     65.0
# 8     421.0    456.0    464.0    473.0    477.0    494.0    513.0    505.0
# 9     550.0    540.0    537.0    526.0    529.0    537.0    555.0    552.0
# 10    217.0    222.0    226.0    223.0    232.0    241.0    244.0    251.0
# 11     72.0     74.0     77.0     77.0     80.0     81.0     85.0     87.0
# 12    136.0    135.0    133.0    134.0    135.0    139.0    143.0    143.0
# 13     29.0     30.0     30.0     31.0     31.0     33.0     35.0     34.0
# 14     64.0     57.0     54.0     55.0     55.0     59.0     61.0     57.0
# 15    152.0    156.0    159.0    157.0    162.0    167.0    174.0    190.0
# 16    147.0    147.0    146.0    146.0    143.0    148.0    141.0    149.0
# 17    320.0    323.0    321.0    323.0    326.0    334.0    351.0    351.0
# 18    122.0    111.0    118.0    120.0    113.0    123.0    105.0    112.0
# 19     58.0     60.0     67.0     74.0     78.0     86.0     95.0    103.0
#
#        1998     1999  ...     2013     2014     2015     2016     2017  \
# 0   14414.0  14823.0  ...  23424.0  23910.0  24317.0  24918.0  25592.0
# 1    9244.0   9451.0  ...  10902.0  10875.0  10914.0  10967.0  11069.0
# 2    7142.0   7272.0  ...   7897.0   7876.0   7867.0   7848.0   7898.0
# 3    3026.0   3170.0  ...   8524.0   8880.0   9142.0   9550.0  10000.0
# 4    3280.0   3327.0  ...   3813.0   3744.0   3802.0   3839.0   3886.0
# 5    2923.0   2955.0  ...   3269.0   3191.0   3234.0   3253.0   3275.0
# 6      83.0     85.0  ...     83.0     73.0     71.0     86.0     87.0
# 7      65.0     65.0  ...     87.0     86.0     84.0     83.0     87.0
# 8     511.0    526.0  ...    572.0    564.0    568.0    553.0    551.0
# 9     556.0    556.0  ...    639.0    628.0    647.0    648.0    653.0
# 10    260.0    266.0  ...    290.0    280.0    283.0    289.0    295.0
# 11     91.0     87.0  ...    102.0    103.0    110.0    115.0    117.0
# 12    143.0    142.0  ...    165.0    159.0    165.0    167.0    171.0
# 13     39.0     43.0  ...     52.0     53.0     52.0     60.0     60.0
# 14     53.0     51.0  ...     59.0     66.0     66.0     67.0     64.0
# 15    195.0    208.0  ...    286.0    279.0    281.0    275.0    275.0
# 16    159.0    155.0  ...    153.0    154.0    162.0    155.0    163.0
# 17    363.0    368.0  ...    358.0    338.0    339.0    339.0    336.0
# 18    117.0    123.0  ...    134.0    142.0    145.0    150.0    149.0
# 19    111.0    116.0  ...    240.0    252.0    262.0    274.0    296.0
#
#        Unnamed: 28  2016 - 2017 (%)   2000 - 2017 (%/year)     data_country  \
# 0            World               2.7                    3.0           World
# 1             OECD               0.9                    0.7            OECD
# 2               G7               0.6                    0.3              G7
# 3            BRICS               4.7                    6.6           BRICS
# 4           Europe               1.2                    0.7          Europe
# 5   European Union               0.7                    0.4  European Union
# 6          Belgium               0.5                    0.2         Belgium
# 7       Czech Rep.               4.5                    1.0      Czech Rep.
# 8           France              -0.4                    0.1          France
# 9          Germany               0.6                    0.7         Germany
# 10           Italy               1.9                    0.4           Italy
# 11     Netherlands               1.3                    1.6     Netherlands
# 12          Poland               2.4                    1.0          Poland
# 13        Portugal               0.0                    1.9        Portugal
# 14         Romania              -3.7                    1.2         Romania
# 15           Spain               0.2                    1.2           Spain
# 16          Sweden               5.0                    0.7          Sweden
# 17  United Kingdom              -1.0                   -0.7  United Kingdom
# 18          Norway              -0.2                    0.3          Norway
# 19          Turkey               7.7                    5.2          Turkey
#
#          data_year
# 0            World
# 1             OECD
# 2               G7
# 3            BRICS
# 4           Europe
# 5   European Union
# 6          Belgium
# 7       Czech Rep.
# 8           France
# 9          Germany
# 10           Italy
# 11     Netherlands
# 12          Poland
# 13        Portugal
# 14         Romania
# 15           Spain
# 16          Sweden
# 17  United Kingdom
# 18          Norway
# 19          Turkey
#
# [20 rows x 33 columns]

# %%
# create standard columns
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2017'] 
df['Country Name'] = df['Unnamed: 28']
df['Year'] = 2017

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#       Country Name  Year            Indicator  data_col  new_rank_score  \
# 0            World  2017  Electricity Density   25592.0        6.000000
# 1             OECD  2017  Electricity Density   11069.0        3.159482
# 2               G7  2017  Electricity Density    7898.0        2.539274
# 3            BRICS  2017  Electricity Density   10000.0        2.950399
# 4           Europe  2017  Electricity Density    3886.0        1.754577
# 5   European Union  2017  Electricity Density    3275.0        1.635073
# 6          Belgium  2017  Electricity Density      87.0        1.011540
# 7       Czech Rep.  2017  Electricity Density      87.0        1.011540
# 8           France  2017  Electricity Density     551.0        1.102292
# 9          Germany  2017  Electricity Density     653.0        1.122242
# 10           Italy  2017  Electricity Density     295.0        1.052222
# 11     Netherlands  2017  Electricity Density     117.0        1.017407
# 12          Poland  2017  Electricity Density     171.0        1.027969
# 13        Portugal  2017  Electricity Density      60.0        1.006259
# 14         Romania  2017  Electricity Density      64.0        1.007041
#
#     higher_is_better
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True

# %%
### 10. % of population covered by electricity

# %%
indicators[9]

# load data
indicator = indicators[9]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# % of population covered by electricity
# population_electricity_coverage

# %%
df.head(15)
# Out:
#     1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  \
# 0    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 6    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 12   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 13   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 14   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#           2017        2018        2019  2020                 Country Name  \
# 0   100.000000  100.000000  100.000000   NaN                        Aruba
# 1    39.754201   42.168241   43.640661   NaN  Africa Eastern and Southern
# 2    97.700000   98.715622   97.700000   NaN                  Afghanistan
# 3    48.848205   51.253253   51.341421   NaN   Africa Western and Central
# 4    43.001610   45.290000   45.670315   NaN                       Angola
# 5    99.890000  100.000000  100.000000   NaN                      Albania
# 6   100.000000  100.000000  100.000000   NaN                      Andorra
# 7    89.623427   88.306324   89.512282   NaN                   Arab World
# 8   100.000000  100.000000  100.000000   NaN         United Arab Emirates
# 9   100.000000  100.000000  100.000000   NaN                    Argentina
# 10   99.700000   99.900000  100.000000   NaN                      Armenia
# 11         NaN         NaN         NaN   NaN               American Samoa
# 12  100.000000   99.999725  100.000000   NaN          Antigua and Barbuda
# 13  100.000000  100.000000  100.000000   NaN                    Australia
# 14  100.000000  100.000000  100.000000   NaN                      Austria
#
#     Country Code                           Indicator Name  Indicator Code  \
# 0            ABW  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 1            AFE  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 2            AFG  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 3            AFW  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 4            AGO  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 5            ALB  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 6            AND  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 7            ARB  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 8            ARE  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 9            ARG  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 10           ARM  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 11           ASM  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 12           ATG  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 13           AUS  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 14           AUT  Access to electricity (% of population)  EG.ELC.ACCS.ZS
#
#     data_country  data_year
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# 5            NaN        NaN
# 6            NaN        NaN
# 7            NaN        NaN
# 8            NaN        NaN
# 9            NaN        NaN
# 10           NaN        NaN
# 11           NaN        NaN
# 12           NaN        NaN
# 13           NaN        NaN
# 14           NaN        NaN
#
# [15 rows x 67 columns]

# %%
# create standard columns
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2019'] 
df['Year'] = 2019

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Out:
#                    Country Name  Year                               Indicator  \
# 0                         Aruba  2019  % of population covered by electricity
# 1   Africa Eastern and Southern  2019  % of population covered by electricity
# 2                   Afghanistan  2019  % of population covered by electricity
# 3    Africa Western and Central  2019  % of population covered by electricity
# 4                        Angola  2019  % of population covered by electricity
# 5                       Albania  2019  % of population covered by electricity
# 6                       Andorra  2019  % of population covered by electricity
# 7                    Arab World  2019  % of population covered by electricity
# 8          United Arab Emirates  2019  % of population covered by electricity
# 9                     Argentina  2019  % of population covered by electricity
# 10                      Armenia  2019  % of population covered by electricity
# 11               American Samoa  2019  % of population covered by electricity
# 12          Antigua and Barbuda  2019  % of population covered by electricity
# 13                    Australia  2019  % of population covered by electricity
# 14                      Austria  2019  % of population covered by electricity
#
#       data_col  new_rank_score  higher_is_better
# 0   100.000000        6.000000              True
# 1    43.640661        2.979006              True
# 2    97.700000        5.876715              True
# 3    51.341421        3.391785              True
# 4    45.670315        3.087800              True
# 5   100.000000        6.000000              True
# 6   100.000000        6.000000              True
# 7    89.512282        5.437834              True
# 8   100.000000        6.000000              True
# 9   100.000000        6.000000              True
# 10  100.000000        6.000000              True
# 11         NaN             NaN              True
# 12  100.000000        6.000000              True
# 13  100.000000        6.000000              True
# 14  100.000000        6.000000              True

# %%
### 11. Electricity Supply Quality

# %%
indicators[10]

# load data
indicator = indicators[10]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))
# Out:
# Electricity supply quality
# elect_supply_quality

# %%
df.head(10)

# %%
# The data needs to be transposed as countries are now in columns, not rows, which could present problems for later.

# %%
### 12. Electricity Environmental Sustainability

# %%
indicators[11]

# load data
indicator = indicators[11]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['2021 SDG Index Score'] 
df['Year'] = 2021

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 13. Cellphone Signal Density

# %%
indicators[12]

# load data
indicator = indicators[12]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
df = df[(df.Year == 2019)]

# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)
df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Network coverage'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 14. Telecommunication Infrastructure Index (TII)

# %%
indicators[13]

# load data
indicator = indicators[13]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Telecommunication Infrastructure Index'] 
df['Year'] = df['Survey Year']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 15. GSMA Mobile Connectivity Index

# %%
indicators[14]

# load data
indicator = indicators[14]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(10)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Index'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 16. Spectrum Allocated to Mobile Providers

# %%
indicators[15]

# load data
indicator = indicators[15]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
df.rename(columns={'Country':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Spectrum'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 17. Internet Exchange Points (IXPs)

# %%
indicators[16]

# load data
indicator = indicators[16]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df['Country Name'] = df['Country']
df.head(15)

# %%
agg_df = df.groupby('Country Name').agg({'Country':'count'})
agg_df

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

agg_df['higher_is_better'] = True
agg_df['Indicator'] = indicator
agg_df['data_col'] = agg_df['Country'] 
agg_df['Year'] = 2019

min_rank = agg_df['data_col'].min()
max_rank = agg_df['data_col'].max()

# transform 0-1 rank into 1-6
agg_df['new_rank_score'] = agg_df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
agg_df[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(150)

# %%
### 18. ISP internet download speed averag

# %%
indicators[17]

# load data
indicator = indicators[17]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Download speed (Mbps)'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 19. Mobile dowload speed at the slowest hour

# %%
indicators[18]

# load data
indicator = indicators[18]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# Waiting for internet_speed to be added to the processed folder

# %%
df.head(15)

# %%
# filter most recent year
df = df[(df.Year==2019)]

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Mobile latencies'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))


# invert since to lower rank is better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 20. Mobile download speed average

# %%
indicators[19]

# load data
indicator = indicators[19]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Mbps'] 
df['Country Name'] = df['Country']

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 21. Individuals using the Internet (% of population)

# %%
indicators[20]

# load data
indicator = indicators[20]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df = df[(df['Indicator name'] == 'Individuals using the Internet, total (%)')]
df = df[(df.Year==2019)]
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df.rename(columns = {'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(150)

# %%
### 22. Mobile-cellular subscriptions per 100 inhabitants

# %%
indicators[21]

# load data
indicator = indicators[21]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df = df[(df['Indicator name'] == 'Individuals using the Internet, total (%)')]
df = df[(df.Year==2020)]
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Indicator'] = indicator
df['data_col'] = df['Value'] 
df.rename(columns = {'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(150)

# %%
### 23. Average fixed broadband download speeds

# %%
indicators[22]

# load data
indicator = indicators[22]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df['broadband'] 
df.rename(columns = {'country':'Country'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 24. Postal Coverage

# %%
indicators[23]

# load data
indicator = indicators[23]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
#Choose 'Percent of Population Having Mail Delivered at Home' as the data column
df = df[(df.Indicator=='Percent of Population Having Mail Delivered at Home')]
df.head(15)

# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2015
df['Indicator'] = indicator
df['data_col'] = df['2015'] 

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 25. Logistics Performance Index (LPI)

# %%
indicators[24]

# load data
indicator = indicators[24]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2018
df['Indicator'] = indicator
df['data_col'] = df['score']
df.rename(columns={'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 26. National cyber security index

# %%
indicators[25]

# load data
indicator = indicators[25]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df['National Cyber Security Index']
df.rename(columns={'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 27. Global Cybersecurity Index (GCI)

# %%
indicators[26]

# load data
indicator = indicators[26]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2020
df['Indicator'] = indicator
df['data_col'] = df['Score (2020)'] 
df.rename(columns={'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 28. Software Developer Ecosystem size

# %%
indicators[27]

# load data
indicator = indicators[27]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['higher_is_better'] = True
df['Year'] = 2018
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,[1]]
df.rename(columns={'Country':'Country Name'}, inplace=True)
    
min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 29. Digital Work Ecosystem size

# %%
indicators[28]

# load data
indicator = indicators[28]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = False
df['Year'] = 2020
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,[0]].astype(float)
df.rename(columns={'Country':'Country Name'}, inplace=True)
    
min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# invert since to lower rank is better
df['new_rank_score'] = df['new_rank_score'].apply(lambda row: (6-row)+1)

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)
# Two problems: 1. cannot use the name of the column, have to use iloc, 2. cannot use the index column
# because the number format is not standard, have to use the rank column

# %%
### 30. Country, Industry, Skill Migration Data (Skill)

# %%
indicators[29]

# load data
indicator = indicators[29]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['Country Name'] = df.iloc[:,[1]]

df_sum = df.groupby('Country Name')[['net_per_10K_2019']].sum()
df_sum

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 31. Country, Industry, Skill Migration Data (Industry)

# %%
indicators[30]

# load data
indicator = indicators[30]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['Country Name'] = df.iloc[:,[1]]

df_sum = df.groupby('Country Name')[['net_per_10K_2019']].sum()
df_sum

# %%
## create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 32. Country, Industry, Skill Migration Data (Nation)

# %%
indicators[31]

# load data
indicator = indicators[31]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
df['Country Name'] = df.iloc[:,[1]]

df_sum = df.groupby('Country Name')[['net_per_10K_2019']].sum()
df_sum

# %%
## create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2019
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum['net_per_10K_2019']


min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 33. Digital Finance Ecosystem size

# %%
indicators[32]

# load data
indicator = indicators[32]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2021
df['Indicator'] = indicator
df['data_col'] = df.iloc[:,[2]]
df['Country Name'] = df.iloc[:,[1]]

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# Have to shorten the column names to see if this works

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# %%
### 34. Tech hubs & spaces size

# %%
indicators[33]

# load data
indicator = indicators[33]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

#There are two problems:
#1. The column names need some overhaul (moving the second column to the top and make it the column names)
#2. This is a list of cities, not countries, may present probkems later.

# %%
### 35. Banking Ecosystem size

# %%
indicators[34]

# load data
indicator = indicators[34]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2017
df['Indicator'] = indicator
df['data_col'] = df['Bank assets, percent of GDP, 2017']
df.rename(columns={'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but will have to remove number from the Country column, leaving only characters.

# %%
### 36. Angel Ecosystem size

# %%
indicators[35]

# load data
indicator = indicators[35]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df['higher_is_better'] = True
df['Year'] = 2019
df['Indicator'] = indicator
df['data_col'] = df['Business angel investments (in million Euros)']
df.rename(columns={'Country':'Country Name'}, inplace=True)

min_rank = df['data_col'].min()
max_rank = df['data_col'].max()

# transform 0-1 rank into 1-6
df['new_rank_score'] = df['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df[['Country Name','Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but there are only EU countries

# %%
### 37. Startup Ecosystem size

# %%
indicators[36]

# load data
indicator = indicators[36]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# This is a list of cities, not countries, wonder if it will work

# %%
### 38. Venture Ecosystem size

indicators[37]

# load data
indicator = indicators[37]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# Similar to the previous one

# %%
### 39. International Co-Inventions

# %%
indicators[38]

# load data
indicator = indicators[38]
print(indicator)
bf = bnames[bnames['Indicator']==indicator]['Filename'].values[0]
print(bf)

df = pd.read_csv('../../processed/{}.csv'.format(bf))

# %%
df.head(15)

# %%
# filter most recent year and global value
df = df[(df.Time==2017)]
df = df[(df.Country!='World')]
df ['Country Name'] = df ['Country']
df

# %%
# Create summarization
df_sum = df.groupby('Country Name')[['Value']].sum()
df_sum

# %%
# create standard columns
# df.rename(columns={'COUNTRY/ECONOMY':'Country Name'}, inplace=True)

df_sum['higher_is_better'] = True
df_sum['Year'] = 2017
df_sum['Indicator'] = indicator
df_sum['data_col'] = df_sum.iloc[:,[0]]

min_rank = df_sum['data_col'].min()
max_rank = df_sum['data_col'].max()

# transform 0-1 rank into 1-6
df_sum['new_rank_score'] = df_sum['data_col'].apply(lambda row: convert_rank(row,old_min=min_rank,old_max=max_rank))

# %%
df_sum[['Year','Indicator','data_col','new_rank_score','higher_is_better']].head(15)

# Okay but the data is too general with many missing countries
