# %%
import pandas as pd
import numpy as np
import os 
import re

# %%
### Score Aggregating by Subpillars

# %%
# get list of files in scores folder
scores = os.listdir('../subpillar_score/')
scores

df = pd.concat([pd.read_csv('../subpillar_score/{}'.format(s)) for s in scores])

# %%
df['Country Name'] = df['Country Name'].str.strip()
df['Country Name'] = df['Country Name'].str.strip('**')
df['Country Name'] = df['Country Name'].str.strip('*')
df['Country Name'] = df['Country Name'].str.strip('*')

# Replace as much code with country names as much as possible
df['Country Name'] = df['Country Name'].replace('UZ','Uzbekistan')
df['Country Name'] = df['Country Name'].replace('Vietnam','Viet Nam')
df['Country Name'] = df['Country Name'].replace('United States','United States of America')
df['Country Name'] = df['Country Name'].replace('UK','United Kingdom')
df['Country Name'] = df['Country Name'].replace('-',np.nan)
df['Country Name'] = df['Country Name'].replace('0.03',np.nan)
df = df.dropna()

# %%
sorted(df['Country Name'].unique().tolist())
# Out:
# ['Afghanistan',
#  'Africa',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Ant.& Barb.',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Arab world',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Asia Pacific',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'B:',
#  'Bahamas',
#  'Bahamas, The',
#  'Bahrain',
#  'Bahrain (Kingdom of)',
#  'Bangladesh',
#  'Bangladesh Chittagong',
#  'Bangladesh Dhaka',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belgium Estonia',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bolivia (Plurinational State of)',
#  'Bolivia, Plurinational State of',
#  'Bosnia & Herz.',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brazil Rio de Janeiro',
#  'Brazil São Paulo',
#  'British Virgin Islands',
#  'Brunei',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Bulgaria (Rep.)',
#  'Burkina Faso',
#  'Burma',
#  'Burundi',
#  'C.A. Republic',
#  'CAN',
#  'CHE',
#  'CIS',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Rep.',
#  'Central African Republic',
#  'Central America',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  "China (People's Rep.)",
#  'China Beijing',
#  'China Shanghai',
#  'China, Hong Kong SAR',
#  'Chinese Taipei',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Congo (Brazzaville)',
#  'Congo (Democratic Republic of the)',
#  'Congo (Rep. of the)',
#  'Congo (Rep.)',
#  'Congo, Dem. Rep.',
#  'Congo, Democratic Republic',
#  'Congo, Rep.',
#  'Congo, The Democratic Republic of the',
#  'Cook Islands',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Cote dIvoire',
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Rep.',
#  'Czech Republic',
#  'Czechia',
#  "Côte d'Ivoire",
#  "Côte d'Ivoire (Rep.)",
#  'Côte d’Ivoire',
#  "Cōte d'Ivoire",
#  'D:',
#  'DEU',
#  'DR Congo',
#  'Data extracted on 10 Sep 2021 15:04 UTC (GMT) from OECD.Stat',
#  "Dem. People's Rep. of Korea",
#  'Dem. Rep. of the Congo',
#  "Democratic People's Republic of Korea",
#  'Democratic Republic of Congo',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Developing',
#  'Djibouti',
#  'Domin. Rep.',
#  'Dominica',
#  'Dominica (Commonwealth of)',
#  'Dominican Rep.',
#  'Dominican Republic',
#  'ESP',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'East Asia & Pacific (excluding high income)',
#  'East and South Asia',
#  'Eastern Africa',
#  'Eastern Europe and Central Asia',
#  'Ecuador',
#  'Egypt',
#  'Egypt, Arab Rep.',
#  'El Salvador',
#  'Eq. Guinea',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Eswatini (Kingdom of)',
#  'Ethiopia',
#  'Euro area',
#  'Europe',
#  'Europe & Central Asia',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Europe & Central Asia (excluding high income)',
#  'Europe (other)',
#  'European Union',
#  'European Union (28 countries)',
#  'FIN',
#  'Faeroe Islands',
#  'Falkland Islands',
#  'Faroe Islands',
#  'Faröe Islands',
#  'Fiji',
#  'Finland',
#  'Fragile and conflict affected situations',
#  'France',
#  'French Guiana',
#  'French Polynesia',
#  'G.-Bissau',
#  'Gabon',
#  'Gambia',
#  'Gambia, The',
#  'Georgia',
#  'Georgia (Country)',
#  'Germany',
#  'Germany France',
#  'Ghana',
#  'Gibraltar',
#  'Great Britain',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'High income: OECD',
#  'High-income Countries',
#  'Honduras',
#  'Honduras (Rep.)',
#  'Hong Kong',
#  'Hong Kong (China)',
#  'Hong Kong (SAR)',
#  'Hong Kong S.A.R. of China',
#  'Hong Kong SAR, China',
#  'Hong Kong, China',
#  'Hong Kong, China (SAR)',
#  'Hongkong, China',
#  'Hungary',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA blend',
#  'IDA only',
#  'IDA total',
#  'IRL',
#  'ITA',
#  'Iceland',
#  'India',
#  'India Delhi',
#  'India Mumbai',
#  'Indonesia',
#  'Indonesia Jakarta',
#  'Indonesia Surabaya',
#  'Iran',
#  'Iran (Islamic Rep.)',
#  'Iran (Islamic Republic of)',
#  'Iran, Islamic Rep.',
#  'Iran, Islamic Republic of',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Japan Osaka',
#  'Japan Tokyo',
#  'Jersey',
#  'Jordan',
#  'KOR',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Korea',
#  'Korea (Rep. of)',
#  'Korea (Rep.)',
#  'Korea (Republic of)',
#  'Korea, DPR',
#  "Korea, Dem. People's Rep.",
#  'Korea, Dem. Rep.',
#  'Korea, Rep.',
#  'Korea, Republic of',
#  'Korea, South',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyz Republic',
#  'Kyrgyzstan',
#  'Lao P.D.R.',
#  'Lao PDR',
#  "Lao People's Dem. Rep.",
#  "Lao People's Democratic Republic",
#  'Laos',
#  'Late-demographic dividend',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean (excluding high income)',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Latin America and the Caribbean',
#  'Latvia',
#  'Least developed countries: UN classification',
#  'Lebanon',
#  'Legend:',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Low & middle income',
#  'Low income',
#  'Low-income Countries',
#  'Lower middle income',
#  'Lower-middle-income Countries',
#  'Luxembourg',
#  'Macao',
#  'Macao SAR, China',
#  'Macao, China',
#  'Macau',
#  'Macau (SAR)',
#  'Macedonia',
#  'Macedonia, FYR',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Martinique',
#  'Mauritania',
#  'Mauritius',
#  'Mayotte',
#  'Mexico',
#  'Mexico Mexico City',
#  'Mexico Monterrey',
#  'Micronesia',
#  'Micronesia (Federated States of)',
#  'Micronesia, Fed. Sts.',
#  'Middle Africa',
#  'Middle East',
#  'Middle East & North Africa',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Middle East & North Africa (excluding high income)',
#  'Middle East and North Africa',
#  'Middle income',
#  'Moldova',
#  'Moldova (Republic of)',
#  'Moldova, Republic of',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Morroco',
#  'Mozambique',
#  'Myanmar',
#  'NZL',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Nepal (Republic of)',
#  'Netherlands',
#  'Netherlands Antilles',
#  'New Caledonia',
#  'New Zealand',
#  'New Zeland',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Nigeria Kano',
#  'Nigeria Lagos',
#  'Niue',
#  'North America',
#  'North Cyprus',
#  'North Korea',
#  'North Macedonia',
#  'Northern Ireland',
#  'Northern Mariana Islands',
#  'Norway',
#  'Not classified',
#  'OECD members',
#  'Oceania',
#  'Oman',
#  'Other Asia & Pacific',
#  'Other CIS',
#  'Other Caribbean',
#  'Other Middle East',
#  'Other Northern Africa',
#  'Other South America',
#  'Other Southern Africa',
#  'Other small states',
#  'Pacific island small states',
#  'Pakistan',
#  'Pakistan Karachi',
#  'Pakistan Lahore',
#  'Palau',
#  'Palestine',
#  'Palestine, State of',
#  'Palestinian Territories',
#  'Panama',
#  'Panama (Rep.)',
#  'Papua N.G.',
#  'Papua New Guinea',
#  'Paraguay',
#  'Personal Card',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Post-demographic dividend',
#  'Pre-demographic dividend',
#  'Puerto Rico',
#  'Puerto Rico (U.S.)',
#  'Qatar',
#  'R. of Congo',
#  'Republic of Korea',
#  'Republic of Moldova',
#  'Republic of the Congo',
#  'Republic of the Union of Myanmar',
#  'Reunion',
#  'Romania',
#  'Russia',
#  'Russian Federation',
#  'Russian Federation Moscow',
#  'Russian Federation Saint Petersburg',
#  'Rwanda',
#  'S.T.&Principe',
#  'Saint Christopher (St. Kitts) and Nevis',
#  'Saint Helena',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Martin',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Sint Maarten',
#  'Sint Maarten (Dutch part)',
#  'Slovak Republic',
#  'Slovakia',
#  'Slovenia',
#  'Small Island Developing States',
#  'Small states',
#  'Solomon Isl.',
#  'Solomon Islands',
#  'Somalia',
#  'South & Central America',
#  'South Africa',
#  'South Asia',
#  'South Asia (IDA & IBRD)',
#  'South Korea',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Martin (French part)',
#  'St. Vincent & ...',
#  'St. Vincent and the Grenadines',
#  'State of Palestine',
#  'Sub-Saharan Africa',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sudan',
#  'Suriname',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Syrian Arab Rep.',
#  'Syrian Arab Republic',
#  'São Tomé and Principe',
#  'São Tomé and Príncipe',
#  'Taiwan',
#  'Taiwan Province of China',
#  'Taiwan, China',
#  'Taiwan, province of China',
#  'Tajikistan',
#  'Tanzania',
#  'Tanzania (United Rep.)',
#  'Tanzania (United Republic of)',
#  'Tanzania, United Republic of',
#  'Thailand',
#  'The Bahamas',
#  'The Gambia',
#  'The Netherlands',
#  'Timor-Leste',
#  'Timor-Leste (Dem. Rep.)',
#  'Togo',
#  'Tokelau',
#  'Tonga',
#  'Tr.&Tobago',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'U.A.E',
#  'UA Emirates',
#  'UAE',
#  'USA',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'United Republic of Tanzania',
#  'United States Los Angeles',
#  'United States New York City',
#  'United States Virgin Islands',
#  'United States of America',
#  'Upper middle income',
#  'Upper-middle-income Countries',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vatican',
#  'Vatican City',
#  'Venezuela',
#  'Venezuela (Bolivarian Rep. of)',
#  'Venezuela (Bolivarian Rep.)',
#  'Venezuela (Bolivarian Republic of)',
#  'Venezuela, RB',
#  'Viet Nam',
#  'Virgin Islands (U.S.)',
#  'Virgin Islands, U.S.',
#  'Wallis and Futuna',
#  'West Bank and Gaza',
#  'Western Africa',
#  'Western Sahara',
#  'World',
#  'Worldwide',
#  'Yemen',
#  'Yemen, Arab Republic',
#  'Yemen, Rep.',
#  'Zambia',
#  'Zimbabwe']

# %%
# Test Uzbekistan

# %%
uzb = df[(df['Country Name'] == 'Uzbekistan')]
uzb
uzb.to_csv('../country_scores/Uzbekistan.csv',index = False)

# %%
# Test Japan

# %%
jp = df[(df['Country Name'] == 'Japan')]
jp
jp.to_csv('../country_scores/Japan.csv',index = False)

# %%
# Test Germany

# %%
gr = df[(df['Country Name'] == 'Germany')]
gr
gr.to_csv('../country_scores/Germany.csv',index = False)

# %%
# Test France

# %%
fr = df[(df['Country Name'] == 'France')]
fr
fr.to_csv('../country_scores/France.csv',index = False)

# %%
# Test Sweden

# %%
sw = df[(df['Country Name'] == 'Sweden')]
sw
sw.to_csv('../country_scores/Sweden.csv',index = False)

# %%
# Test Viet Nam

# %%
vn = df[(df['Country Name'] == 'Viet Nam')]
vn
vn.to_csv('../country_scores/Viet Nam.csv',index = False)

# %%
# Test Armenia

# %%
am = df[(df['Country Name'] == 'Armenia')]
am
am.to_csv('../country_scores/Armenia.csv',index = False)

# %%
# Test USA

# %%
usa = df[(df['Country Name'] == 'United States of America')]
usa
usa.to_csv('../country_scores/USA.csv',index = False)

# %%
# Test All

# %%
df = df[['Country Name','Pillar','Sub-Pillar','agg_score','count_source','agg_score_wt']]
df.to_excel('../country_scores/All.xlsx',index = False)

# %%
### Score Aggregating by Individual Indicators

# %%
# get list of files in scores folder
scores = os.listdir('../indicator_scores/')
scores
df = pd.concat([pd.read_csv('../indicator_scores/{}'.format(s)) for s in scores])    
df = df[['Sub-Pillar','Indicator','Country Name','Year','data_col','new_rank_score','higher_is_better']]
df
# Out:
#               Sub-Pillar                                 Indicator  \
# 0    Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 1    Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 2    Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 3    Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 4    Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# ..                   ...                                       ...
# 200             Ambition                                 SDG Index
# 201             Ambition                                 SDG Index
# 202             Ambition                                 SDG Index
# 203             Ambition                                 SDG Index
# 204             Ambition                                 SDG Index
#
#                       Country Name    Year  data_col  new_rank_score  \
# 0                          Germany  2018.0      18.2           1.910
# 1                            Japan  2018.0      20.3           2.015
# 2                    United States  2018.0      18.0           1.900
# 3                   United Kingdom  2018.0      19.8           1.990
# 4                        Australia  2018.0      16.1           1.805
# ..                             ...     ...       ...             ...
# 200             Sub-Saharan Africa  2019.0      51.9           3.595
# 201           Low-income Countries  2019.0      51.0           3.550
# 202  Lower-middle-income Countries  2019.0      60.1           4.005
# 203  Upper-middle-income Countries  2019.0      70.8           4.540
# 204          High-income Countries  2019.0      78.1           4.905
#
#      higher_is_better
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# ..                ...
# 200              True
# 201              True
# 202              True
# 203              True
# 204              True
#
# [13797 rows x 7 columns]

# %%
df['Country Name'] = df['Country Name'].str.strip()
df['Country Name'] = df['Country Name'].str.strip('**')
df['Country Name'] = df['Country Name'].str.strip('*')
df['Country Name'] = df['Country Name'].str.strip('*')
df = df.dropna()

# %%
# Replace as much code with country names as much as possible

df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bahamas.*$)', 'Bahamas (the)')
df['Country Name'] = df['Country Name'].replace('Bahrain (Kingdom of)','Bahrain')
df['Country Name'] = df['Country Name'].replace('Bolivia','Bolivia (Plurinational State of)')
df['Country Name'] = df['Country Name'].replace('Bolivia, Plurinational State of','Bolivia (Plurinational State of)')
df['Country Name'] = df['Country Name'].replace('Brunei','Brunei Darussalam')
df['Country Name'] = df['Country Name'].replace('Bulgaria (Rep.)','Bulgaria')
df['Country Name'] = df['Country Name'].replace('Central African Republic','Central African Republic (the)')
df['Country Name'] = df['Country Name'].replace('Central African Rep.','Central African Republic (the)')
df['Country Name'] = df['Country Name'].replace("China (People's Rep.)",'China')
df['Country Name'] = df['Country Name'].replace("Comoros",'Comoros (the)')
df['Country Name'] = df['Country Name'].replace("Congo",'Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo (Brazzaville)",'Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo (Rep. of the)",'Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo (Democratic Republic of the)",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo, Dem. Rep.",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Congo, The Democratic Republic of the",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("DR Congo",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Democratic Republic of Congo",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Democratic Republic of the Congo",'Democratic Republic of the Congo (the)')
df['Country Name'] = df['Country Name'].replace("Dem. Rep. of the Congo",'Democratic Republic of the Congo (the)')



df['Country Name'] = df['Country Name'].replace("Cote d'Ivoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Côte d’Ivoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Cote dIvoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Cōte d'Ivoire","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Ivory Coast","Côte d'Ivoire")
df['Country Name'] = df['Country Name'].replace("Dem. People's Rep. of Korea","Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].replace("Democratic People's Republic of Korea","Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].replace("Korea, Dem. People's Rep.","Democratic People's Republic of Korea (the)")
df['Country Name'] = df['Country Name'].replace("North Korea","Democratic People's Republic of Korea (the)")
# Out:
# <ipython-input-27-a581e3982e53>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bahamas.*$)', 'Bahamas (the)')
# <ipython-input-27-a581e3982e53>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Bahamas.*$)', 'Bahamas (the)')
# <ipython-input-27-a581e3982e53>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Bahrain (Kingdom of)','Bahrain')
# <ipython-input-27-a581e3982e53>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Bolivia','Bolivia (Plurinational State of)')
# <ipython-input-27-a581e3982e53>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Bolivia, Plurinational State of','Bolivia (Plurinational State of)')
# <ipython-input-27-a581e3982e53>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Brunei','Brunei Darussalam')
# <ipython-input-27-a581e3982e53>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Bulgaria (Rep.)','Bulgaria')
# <ipython-input-27-a581e3982e53>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Central African Republic','Central African Republic (the)')
# <ipython-input-27-a581e3982e53>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Central African Rep.','Central African Republic (the)')
# <ipython-input-27-a581e3982e53>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("China (People's Rep.)",'China')
# <ipython-input-27-a581e3982e53>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Comoros",'Comoros (the)')
# <ipython-input-27-a581e3982e53>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo",'Congo (the)')
# <ipython-input-27-a581e3982e53>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo (Brazzaville)",'Congo (the)')
# <ipython-input-27-a581e3982e53>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo (Rep. of the)",'Congo (the)')
# <ipython-input-27-a581e3982e53>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo (Democratic Republic of the)",'Democratic Republic of the Congo (the)')
# <ipython-input-27-a581e3982e53>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo, Dem. Rep.",'Democratic Republic of the Congo (the)')
# <ipython-input-27-a581e3982e53>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Congo, The Democratic Republic of the",'Democratic Republic of the Congo (the)')
# <ipython-input-27-a581e3982e53>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("DR Congo",'Democratic Republic of the Congo (the)')
# <ipython-input-27-a581e3982e53>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Democratic Republic of Congo",'Democratic Republic of the Congo (the)')
# <ipython-input-27-a581e3982e53>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Democratic Republic of the Congo",'Democratic Republic of the Congo (the)')
# <ipython-input-27-a581e3982e53>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Dem. Rep. of the Congo",'Democratic Republic of the Congo (the)')
# <ipython-input-27-a581e3982e53>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Cote d'Ivoire","Côte d'Ivoire")
# <ipython-input-27-a581e3982e53>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Côte d’Ivoire","Côte d'Ivoire")
# <ipython-input-27-a581e3982e53>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Cote dIvoire","Côte d'Ivoire")
# <ipython-input-27-a581e3982e53>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Cōte d'Ivoire","Côte d'Ivoire")
# <ipython-input-27-a581e3982e53>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Ivory Coast","Côte d'Ivoire")
# <ipython-input-27-a581e3982e53>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Dem. People's Rep. of Korea","Democratic People's Republic of Korea (the)")
# <ipython-input-27-a581e3982e53>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Democratic People's Republic of Korea","Democratic People's Republic of Korea (the)")
# <ipython-input-27-a581e3982e53>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea, Dem. People's Rep.","Democratic People's Republic of Korea (the)")
# <ipython-input-27-a581e3982e53>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("North Korea","Democratic People's Republic of Korea (the)")

# %%
# Continue

df['Country Name'] = df['Country Name'].str.replace(r'(^.*Czech.*$)', 'Czechia')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Dominican Re.*$)', 'Dominican Republic (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hong Kong.*$)', 'China, Hong Kong Special Administrative Region')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hongkong.*$)', 'China, Hong Kong Special Administrative Region')
df['Country Name'] = df['Country Name'].replace("Eswatini (Kingdom of)",'Eswatini')
df['Country Name'] = df['Country Name'].replace("Swaziland",'Eswatini')
df['Country Name'] = df['Country Name'].replace("Faröe Islands",'Faroe Islands')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Gambia.*$)', 'Gambia (the)')
df['Country Name'] = df['Country Name'].replace("Georgia (Country)",'Georgia')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Iran.*$)', 'Iran (Islamic Republic of)')
df['Country Name'] = df['Country Name'].replace("Korea",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea (Rep. of)",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea (Rep.)",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea (Republic of)",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Korea, Rep.*$)', 'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Korea, South",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("South Korea",'Republic of Korea (the)')
df['Country Name'] = df['Country Name'].replace("Republic of Korea",'Republic of Korea (the)')
# Out:
# <ipython-input-28-9aacfedafa6a>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Czech.*$)', 'Czechia')
# <ipython-input-28-9aacfedafa6a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Czech.*$)', 'Czechia')
# <ipython-input-28-9aacfedafa6a>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Dominican Re.*$)', 'Dominican Republic (the)')
# <ipython-input-28-9aacfedafa6a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Dominican Re.*$)', 'Dominican Republic (the)')
# <ipython-input-28-9aacfedafa6a>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hong Kong.*$)', 'China, Hong Kong Special Administrative Region')
# <ipython-input-28-9aacfedafa6a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hong Kong.*$)', 'China, Hong Kong Special Administrative Region')
# <ipython-input-28-9aacfedafa6a>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hongkong.*$)', 'China, Hong Kong Special Administrative Region')
# <ipython-input-28-9aacfedafa6a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Hongkong.*$)', 'China, Hong Kong Special Administrative Region')
# <ipython-input-28-9aacfedafa6a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Eswatini (Kingdom of)",'Eswatini')
# <ipython-input-28-9aacfedafa6a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Swaziland",'Eswatini')
# <ipython-input-28-9aacfedafa6a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Faröe Islands",'Faroe Islands')
# <ipython-input-28-9aacfedafa6a>:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Gambia.*$)', 'Gambia (the)')
# <ipython-input-28-9aacfedafa6a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Gambia.*$)', 'Gambia (the)')
# <ipython-input-28-9aacfedafa6a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Georgia (Country)",'Georgia')
# <ipython-input-28-9aacfedafa6a>:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Iran.*$)', 'Iran (Islamic Republic of)')
# <ipython-input-28-9aacfedafa6a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Iran.*$)', 'Iran (Islamic Republic of)')
# <ipython-input-28-9aacfedafa6a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea",'Republic of Korea (the)')
# <ipython-input-28-9aacfedafa6a>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea (Rep. of)",'Republic of Korea (the)')
# <ipython-input-28-9aacfedafa6a>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea (Rep.)",'Republic of Korea (the)')
# <ipython-input-28-9aacfedafa6a>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea (Republic of)",'Republic of Korea (the)')
# <ipython-input-28-9aacfedafa6a>:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Korea, Rep.*$)', 'Republic of Korea (the)')
# <ipython-input-28-9aacfedafa6a>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Korea, Rep.*$)', 'Republic of Korea (the)')
# <ipython-input-28-9aacfedafa6a>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Korea, South",'Republic of Korea (the)')
# <ipython-input-28-9aacfedafa6a>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("South Korea",'Republic of Korea (the)')
# <ipython-input-28-9aacfedafa6a>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Republic of Korea",'Republic of Korea (the)')

# %%
# Continue
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kyrgyz.*$)', 'Kyrgyzstan')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lao.*$)', "Lao People's Democratic Republic (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macao.*$)', "China, Macao Special Administrative Region")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macau.*$)', "China, Macao Special Administrative Region")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Micronesia.*$)', "Micronesia (Federated States of)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Moldova.*$)', "Republic of Moldova (the)")
df['Country Name'] = df['Country Name'].replace("Morroco",'Morocco')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Nepal.*$)', "Nepal")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
df['Country Name'] = df['Country Name'].replace("Niger",'Niger (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macedonia.*$)', "North Macedonia")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Palestin.*$)', "State of Palestine (the)")
df['Country Name'] = df['Country Name'].replace("West Bank and Gaza",'State of Palestine (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Panama.*$)', "Panama")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Philippines.*$)', "Philippines (the)")
df['Country Name'] = df['Country Name'].replace("Republic of the Congo",'Congo (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Myanmar.*$)', "Myanmar")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Puerto Rico.*$)', "Puerto Rico")
df['Country Name'] = df['Country Name'].replace("Russia",'Russian Federation (the)')
df['Country Name'] = df['Country Name'].replace("Russian Federation",'Russian Federation (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Slovak.*$)', "Slovakia")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Sudan.*$)', "Sudan (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Syria.*$)', "Syrian Arab Republic (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*São Tomé.*$)', "Sao Tome and Principe")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taiwan.*$)', "Taiwan")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Tanzania.*$)', "United Republic of Tanzania (the)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Netherlands.*$)', "Netherlands (the)")
# Out:
# <ipython-input-29-f522e1be51bc>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kyrgyz.*$)', 'Kyrgyzstan')
# <ipython-input-29-f522e1be51bc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Kyrgyz.*$)', 'Kyrgyzstan')
# <ipython-input-29-f522e1be51bc>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lao.*$)', "Lao People's Democratic Republic (the)")
# <ipython-input-29-f522e1be51bc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Lao.*$)', "Lao People's Democratic Republic (the)")
# <ipython-input-29-f522e1be51bc>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macao.*$)', "China, Macao Special Administrative Region")
# <ipython-input-29-f522e1be51bc>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macao.*$)', "China, Macao Special Administrative Region")
# <ipython-input-29-f522e1be51bc>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macau.*$)', "China, Macao Special Administrative Region")
# <ipython-input-29-f522e1be51bc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macau.*$)', "China, Macao Special Administrative Region")
# <ipython-input-29-f522e1be51bc>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Micronesia.*$)', "Micronesia (Federated States of)")
# <ipython-input-29-f522e1be51bc>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Micronesia.*$)', "Micronesia (Federated States of)")
# <ipython-input-29-f522e1be51bc>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Moldova.*$)', "Republic of Moldova (the)")
# <ipython-input-29-f522e1be51bc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Moldova.*$)', "Republic of Moldova (the)")
# <ipython-input-29-f522e1be51bc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Morroco",'Morocco')
# <ipython-input-29-f522e1be51bc>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Nepal.*$)', "Nepal")
# <ipython-input-29-f522e1be51bc>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Nepal.*$)', "Nepal")
# <ipython-input-29-f522e1be51bc>:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
# <ipython-input-29-f522e1be51bc>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
# <ipython-input-29-f522e1be51bc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Niger",'Niger (the)')
# <ipython-input-29-f522e1be51bc>:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macedonia.*$)', "North Macedonia")
# <ipython-input-29-f522e1be51bc>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Macedonia.*$)', "North Macedonia")
# <ipython-input-29-f522e1be51bc>:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
# <ipython-input-29-f522e1be51bc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*New Ze.*$)', "New Zealand")
# <ipython-input-29-f522e1be51bc>:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Palestin.*$)', "State of Palestine (the)")
# <ipython-input-29-f522e1be51bc>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Palestin.*$)', "State of Palestine (the)")
# <ipython-input-29-f522e1be51bc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("West Bank and Gaza",'State of Palestine (the)')
# <ipython-input-29-f522e1be51bc>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Panama.*$)', "Panama")
# <ipython-input-29-f522e1be51bc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Panama.*$)', "Panama")
# <ipython-input-29-f522e1be51bc>:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Philippines.*$)', "Philippines (the)")
# <ipython-input-29-f522e1be51bc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Philippines.*$)', "Philippines (the)")
# <ipython-input-29-f522e1be51bc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Republic of the Congo",'Congo (the)')
# <ipython-input-29-f522e1be51bc>:19: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Myanmar.*$)', "Myanmar")
# <ipython-input-29-f522e1be51bc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Myanmar.*$)', "Myanmar")
# <ipython-input-29-f522e1be51bc>:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Puerto Rico.*$)', "Puerto Rico")
# <ipython-input-29-f522e1be51bc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Puerto Rico.*$)', "Puerto Rico")
# <ipython-input-29-f522e1be51bc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Russia",'Russian Federation (the)')
# <ipython-input-29-f522e1be51bc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Russian Federation",'Russian Federation (the)')
# <ipython-input-29-f522e1be51bc>:23: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Slovak.*$)', "Slovakia")
# <ipython-input-29-f522e1be51bc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Slovak.*$)', "Slovakia")
# <ipython-input-29-f522e1be51bc>:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Sudan.*$)', "Sudan (the)")
# <ipython-input-29-f522e1be51bc>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Sudan.*$)', "Sudan (the)")
# <ipython-input-29-f522e1be51bc>:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Syria.*$)', "Syrian Arab Republic (the)")
# <ipython-input-29-f522e1be51bc>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Syria.*$)', "Syrian Arab Republic (the)")
# <ipython-input-29-f522e1be51bc>:26: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*São Tomé.*$)', "Sao Tome and Principe")
# <ipython-input-29-f522e1be51bc>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*São Tomé.*$)', "Sao Tome and Principe")
# <ipython-input-29-f522e1be51bc>:27: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taiwan.*$)', "Taiwan")
# <ipython-input-29-f522e1be51bc>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Taiwan.*$)', "Taiwan")
# <ipython-input-29-f522e1be51bc>:28: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Tanzania.*$)', "United Republic of Tanzania (the)")
# <ipython-input-29-f522e1be51bc>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Tanzania.*$)', "United Republic of Tanzania (the)")
# <ipython-input-29-f522e1be51bc>:29: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Netherlands.*$)', "Netherlands (the)")
# <ipython-input-29-f522e1be51bc>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Netherlands.*$)', "Netherlands (the)")

# %%
# Continue
df['Country Name'] = df['Country Name'].replace("UAE",'United Arab Emirates (the)')
df['Country Name'] = df['Country Name'].replace("U.A.E",'United Arab Emirates (the)')
df['Country Name'] = df['Country Name'].replace("United Arab Emirates",'United Arab Emirates (the)')
df['Country Name'] = df['Country Name'].replace('United Kingdom','United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace('UK','United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace("Great Britain",'United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace("United Kingdom of Great Britain and Northern Ireland",'United Kingdom of Great Britain and Northern Ireland (the)')
df['Country Name'] = df['Country Name'].replace('UZ','Uzbekistan')
df['Country Name'] = df['Country Name'].replace('Vietnam','Viet Nam')
df['Country Name'] = df['Country Name'].replace('United States','United States of America (the)')
df['Country Name'] = df['Country Name'].replace('USA','United States of America (the)')
df['Country Name'] = df['Country Name'].replace('United States of America','United States of America (the)')
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Virgin Islands.*$)', "United States Virgin Islands")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vatican.*$)', "Vatican")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Venezuela.*$)', "Venezuela (Bolivarian Republic of)")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Yemen.*$)', "Yemen")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*Arab world.*$)', "Arab World")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*World.*$)', "World")
df['Country Name'] = df['Country Name'].str.replace(r'(^.*St. .*$)', "Saint")
# Out:
# <ipython-input-30-0c69b166feac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("UAE",'United Arab Emirates (the)')
# <ipython-input-30-0c69b166feac>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("U.A.E",'United Arab Emirates (the)')
# <ipython-input-30-0c69b166feac>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("United Arab Emirates",'United Arab Emirates (the)')
# <ipython-input-30-0c69b166feac>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('United Kingdom','United Kingdom of Great Britain and Northern Ireland (the)')
# <ipython-input-30-0c69b166feac>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('UK','United Kingdom of Great Britain and Northern Ireland (the)')
# <ipython-input-30-0c69b166feac>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("Great Britain",'United Kingdom of Great Britain and Northern Ireland (the)')
# <ipython-input-30-0c69b166feac>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace("United Kingdom of Great Britain and Northern Ireland",'United Kingdom of Great Britain and Northern Ireland (the)')
# <ipython-input-30-0c69b166feac>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('UZ','Uzbekistan')
# <ipython-input-30-0c69b166feac>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('Vietnam','Viet Nam')
# <ipython-input-30-0c69b166feac>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('United States','United States of America (the)')
# <ipython-input-30-0c69b166feac>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('USA','United States of America (the)')
# <ipython-input-30-0c69b166feac>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].replace('United States of America','United States of America (the)')
# <ipython-input-30-0c69b166feac>:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Virgin Islands.*$)', "United States Virgin Islands")
# <ipython-input-30-0c69b166feac>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Virgin Islands.*$)', "United States Virgin Islands")
# <ipython-input-30-0c69b166feac>:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vatican.*$)', "Vatican")
# <ipython-input-30-0c69b166feac>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Vatican.*$)', "Vatican")
# <ipython-input-30-0c69b166feac>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Venezuela.*$)', "Venezuela (Bolivarian Republic of)")
# <ipython-input-30-0c69b166feac>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Venezuela.*$)', "Venezuela (Bolivarian Republic of)")
# <ipython-input-30-0c69b166feac>:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Yemen.*$)', "Yemen")
# <ipython-input-30-0c69b166feac>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Yemen.*$)', "Yemen")
# <ipython-input-30-0c69b166feac>:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Arab world.*$)', "Arab World")
# <ipython-input-30-0c69b166feac>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*Arab world.*$)', "Arab World")
# <ipython-input-30-0c69b166feac>:19: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*World.*$)', "World")
# <ipython-input-30-0c69b166feac>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*World.*$)', "World")
# <ipython-input-30-0c69b166feac>:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*St. .*$)', "Saint")
# <ipython-input-30-0c69b166feac>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].str.replace(r'(^.*St. .*$)', "Saint")

# %%
country_list = sorted(df['Country Name'].unique().tolist())
country_list
# Out:
# ['Afghanistan',
#  'Africa',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas (the)',
#  'Bahrain',
#  'Bangladesh',
#  'Bangladesh Chittagong',
#  'Bangladesh Dhaka',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belgium Estonia',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia (Plurinational State of)',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brazil Rio de Janeiro',
#  'Brazil São Paulo',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'CAN',
#  'CHE',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic (the)',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'China Beijing',
#  'China Shanghai',
#  'China, Hong Kong Special Administrative Region',
#  'China, Macao Special Administrative Region',
#  'Colombia',
#  'Comoros (the)',
#  'Congo (the)',
#  'Congo, Democratic Republic',
#  'Congo, Rep.',
#  'Cook Islands',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czechia',
#  "Côte d'Ivoire",
#  'DEU',
#  "Democratic People's Republic of Korea (the)",
#  'Democratic Republic of the Congo (the)',
#  'Denmark',
#  'Developing',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic (the)',
#  'ESP',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'East Asia & Pacific (excluding high income)',
#  'East and South Asia',
#  'Eastern Europe and Central Asia',
#  'Ecuador',
#  'Egypt',
#  'Egypt, Arab Rep.',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Euro area',
#  'Europe',
#  'Europe & Central Asia',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Europe & Central Asia (excluding high income)',
#  'European Union',
#  'European Union (28 countries)',
#  'FIN',
#  'Falkland Islands',
#  'Faroe Islands',
#  'Fiji',
#  'Finland',
#  'Fragile and conflict affected situations',
#  'France',
#  'French Guiana',
#  'French Polynesia',
#  'Gabon',
#  'Gambia (the)',
#  'Georgia',
#  'Germany',
#  'Germany France',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Heavily indebted poor countries (HIPC)',
#  'High income',
#  'High income: OECD',
#  'High-income Countries',
#  'Honduras',
#  'Hungary',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA blend',
#  'IDA only',
#  'IDA total',
#  'IRL',
#  'ITA',
#  'Iceland',
#  'India',
#  'India Delhi',
#  'India Mumbai',
#  'Indonesia',
#  'Indonesia Jakarta',
#  'Indonesia Surabaya',
#  'Iran (Islamic Republic of)',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Japan Osaka',
#  'Japan Tokyo',
#  'Jersey',
#  'Jordan',
#  'KOR',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  "Lao People's Democratic Republic (the)",
#  'Late-demographic dividend',
#  'Latin America & Caribbean',
#  'Latin America & Caribbean (excluding high income)',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Latin America and the Caribbean',
#  'Latvia',
#  'Least developed countries: UN classification',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Low & middle income',
#  'Low income',
#  'Low-income Countries',
#  'Lower middle income',
#  'Lower-middle-income Countries',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Martinique',
#  'Mauritania',
#  'Mauritius',
#  'Mayotte',
#  'Mexico',
#  'Mexico Mexico City',
#  'Mexico Monterrey',
#  'Micronesia (Federated States of)',
#  'Middle East & North Africa',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Middle East & North Africa (excluding high income)',
#  'Middle East and North Africa',
#  'Middle income',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'NZL',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands (the)',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger (the)',
#  'Nigeria',
#  'Nigeria Kano',
#  'Nigeria Lagos',
#  'Niue',
#  'North America',
#  'North Cyprus',
#  'North Macedonia',
#  'Northern Ireland',
#  'Northern Mariana Islands',
#  'Norway',
#  'OECD members',
#  'Oceania',
#  'Oman',
#  'Other small states',
#  'Pacific island small states',
#  'Pakistan',
#  'Pakistan Karachi',
#  'Pakistan Lahore',
#  'Palau',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines (the)',
#  'Poland',
#  'Portugal',
#  'Post-demographic dividend',
#  'Pre-demographic dividend',
#  'Puerto Rico',
#  'Qatar',
#  'Republic of Korea (the)',
#  'Republic of Moldova (the)',
#  'Reunion',
#  'Romania',
#  'Russian Federation (the)',
#  'Russian Federation Moscow',
#  'Russian Federation Saint Petersburg',
#  'Rwanda',
#  'Saint',
#  'Saint Helena',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Martin',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Sint Maarten',
#  'Sint Maarten (Dutch part)',
#  'Slovakia',
#  'Slovenia',
#  'Small Island Developing States',
#  'Small states',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Asia',
#  'South Asia (IDA & IBRD)',
#  'Spain',
#  'Sri Lanka',
#  'State of Palestine (the)',
#  'Sub-Saharan Africa',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sudan (the)',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Republic (the)',
#  'Taiwan',
#  'Tajikistan',
#  'Thailand',
#  'Timor-Leste',
#  'Togo',
#  'Tokelau',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates (the)',
#  'United Kingdom of Great Britain and Northern Ireland (the)',
#  'United Republic of Tanzania (the)',
#  'United States Los Angeles',
#  'United States New York City',
#  'United States Virgin Islands',
#  'United States of America (the)',
#  'Upper middle income',
#  'Upper-middle-income Countries',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vatican',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam',
#  'Wallis and Futuna',
#  'Western Sahara',
#  'World',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
df.insert(0,'Pillar','')
df.loc[(df['Sub-Pillar'] == 'Connectivity Technology') | (df['Sub-Pillar'] == 'Innovation Ecosystem'), 'Pillar'] = 'Infrastructure'
df.loc[(df['Sub-Pillar'] == 'Financing Incentives') | (df['Sub-Pillar'] == 'Technology Adoption') | (df['Sub-Pillar'] == 'Startup Environment'), 'Pillar'] = 'Business'
df.loc[(df['Sub-Pillar'] == 'Data Exchange') | (df['Sub-Pillar'] == 'Digital Legal Identity') | (df['Sub-Pillar'] == 'Digital Payments'), 'Pillar'] = 'Foundations'
df.loc[(df['Sub-Pillar'] == 'Capabilities') | (df['Sub-Pillar'] == 'Digital Public Services') | (df['Sub-Pillar'] == 'Funding and procurement') | (df['Sub-Pillar'] == 'Leadership and coordination'), 'Pillar'] = 'Government'
df.loc[(df['Sub-Pillar'] == 'Culture') | (df['Sub-Pillar'] == 'Digital Literacy Skills') | (df['Sub-Pillar'] == 'Digital Wellbeing')| (df['Sub-Pillar'] == 'Usage and ownership'), 'Pillar'] = 'People'
df.loc[(df['Sub-Pillar'] == 'Cybersecurity') | (df['Sub-Pillar'] == 'Ethical Standards'), 'Pillar'] = 'Regulation'
df.loc[(df['Sub-Pillar'] == 'Ambition'), 'Pillar'] = 'Strategy'

df
# Out:
# D:\Apps\Anaconda\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#        Pillar           Sub-Pillar                                 Indicator  \
# 0    Business  Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 1    Business  Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 2    Business  Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 3    Business  Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# 4    Business  Technology Adoption  Cloud Services (Spend, IT Forecast Data)
# ..        ...                  ...                                       ...
# 200  Strategy             Ambition                                 SDG Index
# 201  Strategy             Ambition                                 SDG Index
# 202  Strategy             Ambition                                 SDG Index
# 203  Strategy             Ambition                                 SDG Index
# 204  Strategy             Ambition                                 SDG Index
#
#                                           Country Name    Year  data_col  \
# 0                                              Germany  2018.0      18.2
# 1                                                Japan  2018.0      20.3
# 2                       United States of America (the)  2018.0      18.0
# 3    United Kingdom of Great Britain and Northern I...  2018.0      19.8
# 4                                            Australia  2018.0      16.1
# ..                                                 ...     ...       ...
# 200                                 Sub-Saharan Africa  2019.0      51.9
# 201                               Low-income Countries  2019.0      51.0
# 202                      Lower-middle-income Countries  2019.0      60.1
# 203                      Upper-middle-income Countries  2019.0      70.8
# 204                              High-income Countries  2019.0      78.1
#
#      new_rank_score  higher_is_better
# 0             1.910              True
# 1             2.015              True
# 2             1.900              True
# 3             1.990              True
# 4             1.805              True
# ..              ...               ...
# 200           3.595              True
# 201           3.550              True
# 202           4.005              True
# 203           4.540              True
# 204           4.905              True
#
# [12314 rows x 8 columns]

# %%
# For all country
df = df[['Country Name','Year','Pillar','Sub-Pillar','Indicator','data_col','new_rank_score','higher_is_better']]
df.to_excel('../country_scores/All_Indicator.xlsx',index = False)

# %%
uzb = df[(df['Country Name'] == 'Uzbekistan')]
uzb

uzb.to_csv('../country_scores/Uzbekistan_Indicator.csv',index = False)

# %%
jp = df[(df['Country Name'] == 'Japan')]
jp

jp.to_csv('../country_scores/Japan_Indicator.csv',index = False)

# %%
vn = df[(df['Country Name'] == 'Viet Nam')]
vn

vn.to_csv('../country_scores/Viet Nam_Indicator.csv',index = False)

# %%
am = df[(df['Country Name'] == 'Armenia')]
am = am.dropna(subset=['data_col'])

am.to_csv('../country_scores/Armenia_Indicator.csv',index = False)

# %%
usa = df[(df['Country Name'] == 'United States of America (the)')]
usa = usa.dropna(subset=['data_col'])

usa.to_csv('../country_scores/USA_Indicator.csv',index = False)
